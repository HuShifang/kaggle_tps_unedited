# %% [markdown]
# # Super-Learner Manual Implementation
# Since `mlens.ensemble.SuperLearner` does not appear to be capable of correctly outputting probabilities in binary classification tasks, I'm going to roll my own implementation of the underlying algorithm.

# %% [markdown]
# # Setup

# %%
# two manual flags (ex-config)
colab = False
gpu_available = False
libraries = ['xgboost', 'lightgbm', 'catboost']

# %%
# basic imports
from pathlib import Path
import os
import math
from datetime import datetime

# %%
# %matplotlib inline
# %config Completer.use_jedi = False
os.environ['WANDB_NOTEBOOK_NAME'] = f"super-learner_manual_{datetime.now().strftime('%Y%m%d')}.ipynb"

# %%
# handle Google Colab-specific library installation/updating
if colab:
    # much of the below inspired by or cribbed from the May 2021 Kaggle Tabular Playground winner, at 
    # https://colab.research.google.com/gist/academicsuspect/0aac7bd6e506f5f70295bfc9a3dc2250/tabular-may-baseline.ipynb?authuser=1#scrollTo=LJoVKJb5wN0L
    
    # Kaggle API for downloading the datasets
    # !pip install --upgrade -q kaggle

    # weights and biases
    # !pip install -qqqU wandb
    
    # Optuna for parameter search
    # !pip install -q optuna

    # upgrade sklearn
    # !pip install --upgrade scikit-learn

    # !pip install category_encoders
    
    if 'catboost' in libraries:
        # !pip install catboost
    
    if 'xgboost' in libraries:
        if gpu_available: 
            # this part is from https://github.com/rapidsai/gputreeshap/issues/24
            # !pip install cmake --upgrade
            # !pip install sklearn --upgrade
            # !git clone --recursive https://github.com/dmlc/xgboost
            # %cd /content/xgboost
            # !mkdir build
            # %cd build
            # !cmake .. -DUSE_CUDA=ON
            # !make -j4
            # %cd /content/xgboost/python-package
            # !python setup.py install --use-cuda --use-nccl
            # !/opt/bin/nvidia-smi
            # !pip install shap
        else:
            # !pip install --upgrade xgboost
    if 'lightgbm' in libraries:
        if gpu_available:
            # lighgbm gpu compatible
            # !git clone --recursive https://github.com/Microsoft/LightGBM
            ! cd LightGBM && rm -rf build && mkdir build && cd build && cmake -DUSE_GPU=1 ../../LightGBM && make -j4 && cd ../python-package && python3 setup.py install --precompile --gpu;
        else:
            # !pip install --upgrade lightgbm

# %% [markdown]
# Now, non-stdlib imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# general ML tooling
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import log_loss, roc_auc_score
import wandb
from wandb.xgboost import wandb_callback
from wandb.lightgbm import wandb_callback
from sklearn.impute import SimpleImputer #, KNNImputer
# import timm
import seaborn as sns

from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import StackingClassifier, RandomForestClassifier
# from mlens.ensemble import SuperLearner
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler #, MinMaxScaler, MaxAbsScaler, RobustScaler, PolynomialFeatures
# from sklearn.feature_selection import SelectKBest, f_regression
from joblib import dump, load
# feature engineering tools
# from sklearn.feature_selection import mutual_info_regression
# import featuretools as ft
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# Now, datapath setup

# %%
# # This is the code for reading the train.csv and converting it to a .feather file
# df = pd.read_csv(datapath/'train.csv', index_col='id', low_memory=False)
# df.index.name = None
# df.to_feather(path='./dataset_df.feather')

# %%
if colab:
    # mount Google Drive
    from google.colab import drive
    drive.mount('/content/drive')
    
    # handling datapath
    datapath = Path('/content/drive/MyDrive/kaggle/tabular_playgrounds/sep2021/')
    
else:
    # if on local machine
    datapath = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/')

# %% [markdown]
# ## Ex-Model Config

# %%
# meta-config for preprocessing and cross-validation, but NOT for model parameters
exmodel_config = {
    # model config
#     "model": XGBClassifier,
#     "n_estimators": 100, 
#     "max_depth": 3,
#     "learning_rate": 0.1,
#     "test_size": 0.2,
#     "reg_lambda": None, 
    "library": libraries,
    "scaler": StandardScaler, # TODO: experiment with others (but imputation may be slow)
    "scale_b4_impute": False,
    "imputer": SimpleImputer(strategy='median', add_indicator=True),
#     "knn_imputer_n_neighbors": None, # None if a different imputer is used
#     "feature_selector": SelectKBest,
#     "k_best": 80,
#     "feature_selection_scoring": f_regression,
    'random_state': 42,
#     'subsample': 1,
#     'cross_val_strategy': KFold, # None for holdout, or the relevant sklearn class
#     'kfolds': 5, # if 1, that means just doing holdout
#     'test_size': 0.2,
#     'features_created': False,
#     'feature_creator': None,
}

# %% [markdown]
# ## Data Setup

# %% [markdown]
# **TODO** Write some conditional logic here to automate it -- possibly as part of a sklearn.*pipeline

# %%
# if exmodel_config['scaler']:
#     scaler = exmodel_config['scaler']()
#     scaler.fit_transform()

# %%
# # here's how to load the original, unaltered dataset and separate features from targets
# df = pd.read_feather(path=datapath/'dataset_df.feather') # this is the unaltered original dataset
# features = [x for x in df.columns if x != 'claim']
# X = df[features]
# y = df.claim



# load the version of the dataset with imputations; X and y were stored separately, as feather and joblib respectively
X = pd.read_feather(datapath/'X_NaNcounts_imputed-Median-wIndicators-StandardScaled.feather') 
y = load(datapath/'y.joblib')    
X.index.name = 'id'
y.index.name = 'id'

exmodel_config['feature_count'] = len(X.columns)
exmodel_config['feature_generator'] = None

# %%
# scaler = exmodel_config['scaler']()
# X_scaled = scaler.fit_transform(X)
# X = pd.DataFrame(X_scaled, columns=X.columns)

# %%
X.head()
# Out:
#            0         1         2         3         4         5         6  \
# id
# 0   0.425545 -2.357891 -0.637206 -0.866657 -0.111568 -4.829243 -1.171229
# 1   0.247600 -0.323982  1.223569  0.361863  1.071182 -0.361140  0.082051
# 2   2.032371 -2.435680 -0.488960  0.341193  1.069656  0.118532  0.537069
# 3   1.438373 -2.337605 -0.508914 -0.829607  1.485682  3.592008 -1.189087
# 4   0.602333  1.076218 -0.648438  0.463365  0.275053 -0.157989  0.727338
#
#            7         8         9  ...       227       228       229       230  \
# id                                ...
# 0  -0.603397 -0.596871 -0.516828  ... -0.128368 -0.127677 -0.128242 -0.127867
# 1  -0.746590  0.899454  0.469668  ... -0.128368 -0.127677 -0.128242 -0.127867
# 2  -0.044075 -0.763516  1.056879  ... -0.128368 -0.127677 -0.128242 -0.127867
# 3  -0.339152 -0.735281 -0.529158  ... -0.128368 -0.127677 -0.128242 -0.127867
# 4  -0.905498  0.052478 -0.511066  ... -0.128368 -0.127677 -0.128242 -0.127867
#
#          231       232       233      234       235      236
# id
# 0  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 1  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 2  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 3  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 4  -0.127119 -0.127985 -0.128494 -0.12862  7.821398 -0.12703
#
# [5 rows x 237 columns]

# %%
y.head()
# Out:
# id
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: claim, dtype: int64

# %% [markdown]
# ### Model Config

# %%
def model_configurator(library, gpu_available=True):#, config=universal_config):
    """
    Function that provide task-specific or general preference arguments for the various models. 
    
    At first, will rely largely on defaults for hyperparameters, but later this function 
    can be supplemented later with optimal values, as they're learned in sweeps.
    .
    
    Rationale: creating a helper function will allow more experimentation later, and also
    composite runs that cycle through a series of models.
    
    :param model: A model from [XGBClassifier, LGBMClassifier, CatBoostClassifier]
    :return config: A dict that supplements default hyperparameter values with 1) 
                    task-appropriate ones, and perhaps later 2) optimal hyperparameter values.
    """
    config = {}
    
    # library-specific config
    if library in ['xgboost', 'lightgbm']:
        config['n_jobs'] = -1
        
    # best params per sweep `icac24c5`, generated from notebook `sweep_20210905.ipynb`
    # runtime per fold should be around 12m 38s
    # should get auc of 0.7434 on the random_state=42 holdout
    # haven't yet tried dart
    if library == 'xgboost':
#         config['tree_method'] = 'auto'
#         config['booster'] = 'gbtree' # or 'dart'
#         config['model'] = XGBClassifier
        config['verbosity'] = 1
        config['objective'] = 'binary:logistic'
#         config['eval_metric'] = ['auc', 'logloss', 'aucpr'],
        config['tree_method'] = 'gpu_hist' if (gpu_available and colab) else 'auto' 
        
        # comment out the below to get defaults
        config['n_estimators'] = 902
        config['learning_rate'] = 0.0304
        config['max_depth'] = 3
        config['reg_alpha'] = 0.863
        config['reg_lambda'] = 2.442
        config['subsample'] = 0.8627

    # best params per sweep `sjghewf0`, generated from notebook `sweep_lightgbm_20210907`
    # run name `sweep_lightgbm_20210907_195641`
    # runtime per fold should be around 39s
    # should get an auc of 0.7435 on random_state=42 holdout
    if library == 'lightgbm':
#         config['model'] = LGBMClassifier
        config['objective'] = 'binary'
        config['eval_metric'] = ['auc', 'logloss']
        config['boosting_type'] = 'gbdt' # or 'dart'
        config['device_type'] = 'cuda' if (gpu_available and colab) else 'cpu' # 'gpu' also possible, 'cpu' is default
        
        # comment out the below for defaults
        config['n_estimators'] = 1286
        config['learning_rate'] = 0.03221
        config['max_depth'] = 2
        config['reg_alpha'] = 0.4687
        config['reg_lambda'] = 0.1763
        config['subsample'] = 0.6621
        

#     if config['model'] == CatBoostClassifier:
    if library == 'catboost':
#         config['model'] = CatBoostClassifier
        config['task_type'] = 'GPU' if gpu_available else 'CPU'
        config['custom_metrics'] = ['Logloss', 'AUC'] # objective (loss fn) must be singular, defaults to Logloss
        config['n_estimators'] = 2000 # logged as "iterations" otherwise

    return config

# %% [markdown]
# ## Weights and Biases Run Config

# %% [markdown]
# Below is the configuration for a Weights and Biases (`wandb`) run.

# %%
# wandb config:
config_run = {
    'name': f"{os.environ['WANDB_NOTEBOOK_NAME'][:-6]}_{datetime.now().strftime('%H%M%S')}", # just removes the .ipynb extension, leaving the notebook filename's stem
    'tags': ['super-learner', 'experiment', 'attempt'],
    'notes': "Since `mlens.ensemble.SuperLearner` does not appear to be capable of correctly outputting probabilities in binary classification tasks, I'm going to roll my own implementation of the underlying algorithm.",
}

# %% [markdown]
# # Preprocessing
# Scaling has already occurred -- used `StandardScaler` as a precursor to using `KNNImputer(n_neighbors=5)`, on the premise that imputation would proceed more quickly if things were already scaled. I may try different permutations of this later: using `IterativeImputer` instead, before or after scaling, potentially with different scalers.

# %% [markdown]
# # Feature Creation and Selection

# %%
# load all the polynomialfeatures generated with `PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)`
# X_np = np.load(datapath/'X_poly_unscaled.npy')
# X = pd.DataFrame(X_np)

# %%
# X.columns

# %%
# generation polynomial features
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_poly = poly.fit_transform(X)

# %%
# X_poly_names = poly.get_feature_names(X.columns)
# # X_poly_names[100:150]
# features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
# checks = [feature in X_poly_names for feature in features]
# checks

# %%
# X = pd.DataFrame(X_poly, columns=X_poly_names)

# %%
# X = X[features[1:]]

# %% [markdown]
# # Training

# %%
def super_train(X_train, X_valid, y_train, y_valid, model_config, 
                                              random_state=42,
                                              exmodel_config=exmodel_config, 
                                              config_run=config_run):#, scaler): # passed in via config dict for now
    """
    Basic training function. Note that some of the options passed via the argument are
    in fact hard-coded in, to avoid inconveniences.
    :param X_train: the training set features
    :param X_valid: the validation set features
    :param y_train: the training set targets
    :param y_valid: the validation set targets
    :param random_staKFold: for reproducibility
    :param exmodel_config: dict containing configuration details including the library 
                            (thus model) used, preprocessing, and cross-validation
    :param model_config: dict containing hyperparameter specifications for the model
    :param config_run: dict containing wandb run configuration (name, etc)
    """
    
    
    wandb.init(
        project="202109_Kaggle_tabular_playground",
        save_code=True,
        tags=config_run['tags'],
        name=config_run['name'],
        notes=config_run['notes'],
        config=exmodel_config)   
        
    if exmodel_config['library'] == 'xgboost':
        model = XGBClassifier(
            tree_method=model_config['tree_method'],
            random_state=random_state,
            n_jobs=model_config['n_jobs'], 
            verbosity=model_config['verbosity'], 
            objective=model_config['objective'],
            # #             eval_metric=model_config['eval_metric'],

            # comment out the below for a fairly default model
#             booster=model_config['booster'],
            max_depth=model_config['max_depth'],
            learning_rate=model_config['learning_rate'], 
            subsample=model_config['subsample'],
            reg_alpha=model_config['reg_alpha'],
            reg_lambda=model_config['reg_lambda'],
            n_estimators=model_config['n_estimators'],
        )
        
        model.fit(X_train, y_train, callbacks=[wandb.xgboost.wandb_callback()],
#                                     eval_metric=model_config['eval_metric'],
                 )


    elif exmodel_config['library'] == 'lightgbm':
        model = LGBMClassifier(
#             boosting_type=model_config['boosting_type'],
#             max_depth=model_config['max_depth']
            # TODO
            random_state=random_state,
            n_jobs=model_config['n_jobs'],
            objective=model_config['objective'],
#             eval_metric=model_config['eval_metric'],
            boosting_type=model_config['boosting_type'],
            device_type=model_config['device_type'],
            
            # comment out the below for a basically default model
            n_estimators=model_config['n_estimators'],
            learning_rate=model_config['learning_rate'],
            max_depth=model_config['max_depth'],
            reg_alpha=model_config['reg_alpha'],
            reg_lambda=model_config['reg_lambda'],
            subsample=model_config['subsample'],
        )
        
        model.fit(X_train, y_train, callbacks=[wandb.lightgbm.wandb_callback()],
#                                     eval_metric=model_config['eval_metric'],
                 )
        
    elif exmodel_config['library'] == 'catboost':
        print("CatBoost, therefore no WandB callback.")
        model = CatBoostClassifier(
#             n_estimators=config['n_estimators'],
#             learning_rate=config['learning_rate'],
#             max_depth=config['max_depth'],
            task_type=model_config['task_type'],
    #         n_jobs=config['n_jobs'],
    #         verbosity=config['verbosity'],
    #         subsample=config['subsample'],
            n_estimators=model_config['n_estimators'],
            random_state=random_state,
            # objective='Logloss', # default, accepts only one
#             custom_metrics=model_config['custom_metrics'],
    #         bootstrap_type=config['bootstrap_type'],
    #         device:config['device']
        ) 
        model.fit(X_train, y_train)
        
#     y_train_pred = model.predict(X_train)
    y_train_pred = model.predict_proba(X_train)[:,1]

    train_loss = log_loss(y_train, y_train_pred)
    train_auc = roc_auc_score(y_train, y_train_pred)
    wandb.log({'train_loss': train_loss, 'train_auc': train_auc})

    if exmodel_config['library'] == 'catboost':
        print(model.get_all_params())
        wandb.log(model.get_all_params())
    else:
        wandb.log(model.get_params()) # logging model parameters, trying bare-invocation rather than params: model.get_params()
    
    # trying with predict_proba
    y_pred = model.predict_proba(X_valid)[:,1]
#     y_pred = model.predict(X_valid)

    valid_loss = log_loss(y_valid, y_pred)
    valid_auc = roc_auc_score(y_valid, y_pred)
    wandb.log({'valid_loss':valid_loss, 'valid_auc':valid_auc})
    print(f"Valid log-loss is {valid_loss}\nValid AUC is {valid_auc}")   
#     wandb.finish()   
    return model, y_pred

# %%
random_state = 42
model_list = []
#     XGBClassifer(
#         verbosity=1,
#         n_jobs=-1,
#         objective='binary:logistic',
#         tree_method= 'gpu_hist' if (gpu_available and colab) else 'auto',
#         n_estimators=902,
#         learning_rate=0.0304,
#         max_depth=3,
#         reg_alpha = 0.863,
#         reg_lambda = 2.442,
#         subsample= 0.8627,
#         random_state=exmodel_config['random_state'],
#     ),
model_config = model_configurator('xgboost')
model_list.append(
    ('xgboost', XGBClassifier(
        tree_method=model_config['tree_method'],
        random_state=random_state,
        n_jobs=model_config['n_jobs'], 
        verbosity=model_config['verbosity'], 
        objective=model_config['objective'],
        # #             eval_metric=model_config['eval_metric'],

        # comment out the below for a fairly default model
#             booster=model_config['booster'],
        max_depth=model_config['max_depth'],
        learning_rate=model_config['learning_rate'], 
        subsample=model_config['subsample'],
        reg_alpha=model_config['reg_alpha'],
        reg_lambda=model_config['reg_lambda'],
        n_estimators=model_config['n_estimators'],
    ))
)

model_config = model_configurator('lightgbm')
model_list.append(
    ('lightgbm', LGBMClassifier(
#         verbose=model_config['verbosity'], 
        random_state=random_state,
        n_jobs=model_config['n_jobs'],
        objective=model_config['objective'],
#             eval_metric=model_config['eval_metric'],
        boosting_type=model_config['boosting_type'],
        device_type=model_config['device_type'],

        # comment out the below for a basically default model
        n_estimators=model_config['n_estimators'],
        learning_rate=model_config['learning_rate'],
        max_depth=model_config['max_depth'],
        reg_alpha=model_config['reg_alpha'],
        reg_lambda=model_config['reg_lambda'],
        subsample=model_config['subsample'],
    ))
)

model_config = model_configurator('catboost', gpu_available=False)
model_list.append(
    ('catboost', CatBoostClassifier(
#             n_estimators=config['n_estimators'],
#             learning_rate=config['learning_rate'],
#             max_depth=config['max_depth'],
        task_type=model_config['task_type'],
#         n_jobs=config['n_jobs'],
#         verbosity=config['verbosity'],
#         subsample=config['subsample'],
        n_estimators=model_config['n_estimators'],
        random_state=random_state,
                # objective='Logloss', # default, accepts only one
    #             custom_metrics=model_config['custom_metrics'],
        #         bootstrap_type=config['bootstrap_type'],
        #         device:config['device']
            ))
)

# %%
# TRYING TO REVISE THIS BELOW

# def super_cross_validation(model_list=model_list, X=X, y=y, start_fold=0, exmodel_config=exmodel_config, random_state=42):
#     """
#     Function to handle model training process in the context of cross-validation -- via hold-out or via k-fold.
#     If exmodel_config['cross_val_strategy'] == None, then any kfolds= input is ignored; otherwise, the number specified is used.
    
#     :param kfolds: int specifying number of k-folds to use in cross-validation
#     :param exmodel_config: dict containing general config including for cross-validation -- `kfold=1` implies hold-out
#     """
# #     if exmodel_config['kfolds'] == 1:
# #         print("Proceeding with holdout")
# #         X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
# #                                                       test_size=exmodel_config['test_size'], 
# #                                                       random_state=random_state,
# #                                                      )
# #         model = train(X_train, X_valid, y_train, y_valid, exmodel_config=exmodel_config, 
# #                                                     model_config=model_config,
# #                                                     config_run=config_run)
# #         wandb.finish()
        
# #     else:

#     wandb.init(
#         project="202109_Kaggle_tabular_playground",
#         save_code=True,
#         tags=config_run['tags'],
#         name=config_run['name'],
#         notes=config_run['notes'],
#         config=exmodel_config)  
    
#     X, y = X.to_numpy(), y.to_numpy()
#     # from https://machinelearningmastery.com/super-learner-ensemble-in-python/ # Super Learner for Classification
#     X_meta, y_meta = [], [] # for the meta-learner; might concat the X with the data later for a passthrough=True run
#     exmodel_config['kfolds'] = 5
#     kfold = KFold(n_splits=exmodel_config['kfolds'], shuffle=True, random_state=random_state)
#     trained_models = {}
# #         oof_preds = {}
#     model_path = Path(datapath/f"models/{config_run['name']}_{exmodel_config['kfolds']}folds/")
#     (model_path).mkdir(exist_ok=True)
#     preds_path = Path(datapath/f"preds/{config_run['name']}_{exmodel_config['kfolds']}folds/")
#     (preds_path).mkdir(exist_ok=True)
#     for fold, (train_ids, valid_ids) in enumerate(kfold.split(X,y)):
#         if fold < start_fold:
#             continue
#         else:
#             print(f"FOLD {fold}")
#             print("---------------------------------------------------")
#             fold_preds = []
#             X_train, X_valid = X[train_ids], X[valid_ids]
#             y_train, y_valid = y[train_ids], y[valid_ids]
#             y_meta.extend(y_valid) # building this "meta" y as we go - check RAM can manage
#             for model in model_list:
#                 model[1].fit(X_train, y_train)
#                 y_train_pred = model[1].predict_proba(X_train)[:,1]

#                 train_loss = log_loss(y_train, y_train_pred)
#                 train_auc = roc_auc_score(y_train, y_train_pred)
# #                     wandb.log({'train_loss': train_loss, 'train_auc': train_auc})

#                 if model[0] == 'catboost':
# #                         print(model[1].get_all_params())
#                     wandb.log({'catboost_params': str(model[1].get_all_params())})                        
#                 else:
#                     wandb.log({f'{model[0]}_params': str(model[1].get_params())}) 
#                 y_pred = model[1].predict_proba(X_valid)[:,1]
#                 fold_preds.append(y_pred)

#                 valid_loss = log_loss(y_valid, y_pred)
#                 valid_auc = roc_auc_score(y_valid, y_pred)
#                 wandb.log({'valid_loss':valid_loss, 'valid_auc':valid_auc})
#                 print(f"Valid log-loss is {valid_loss}\nValid AUC is {valid_auc}")   
# #                     oof_preds = super_train(X_train, X_valid, y_train, y_valid, exmodel_config=exmodel_config, 
# # #                                                     model_config=model_config,
# #                                                     config_run=config_run)
#                 wandb.log({'fold': fold})
#                 dump(y_pred, Path(preds_path/f"{model[0]}_fold{fold}_oof-preds.joblib"))

# #                     models[fold] = model
# #                 preds[fold] = oof_preds
#             X_meta.append(np.hstack(fold_preds))
#             dump(fold_preds, Path(preds_path/f"all_fold{fold}_oof-preds.joblib"))
# #                     dump(model, Path(model_path/f"{exmodel_config['library']}_fold{fold}_model.joblib"))

# #                 wandb.finish()
# #     return np.vstack(X_meta), np.asarray(y_meta)
#     return X_meta, y_meta

# %%
# X.shape

# %%
# kfold = KFold(n_splits=exmodel_config['kfolds'], shuffle=True, random_state=42)
# X_np, y_np = {}, {}
# X_trains, y_trains = {}, {}
# X_valids, y_valids = {}, {}
# for fold, (train_ids, valid_ids) in enumerate(kfold.split(X,y)):
#     print(type(train_ids))
#     print(train_ids[:20])
#     print(X.loc[train_ids])
#     print(fold)
#     X_np[fold] = X.to_numpy()
#     y_np[fold] = y.to_numpy()
#     X_trains[fold] = X[train_ids]
#     X_valids[fold] = X[valid_ids]
#     y_trains[fold], y_valids[fold] = y[train_ids], y[valid_ids]
# #     X_trains[fold] = X_np[fold][train_ids]
# #     X_valids[fold] = X_np[fold][valid_ids]
# #     y_trains[fold], y_valids[fold] = y_np[fold][train_ids], y_np[fold][valid_ids]
#     print(f"X_train shape is {X_train.shape}, X_valid shape is {X_valid.shape}")
#     print(f"y_train.shape is {y_train.shape}, y_valid shape is {y_valid.shape}")

# %%
# splitted = kfold.split(X,y)

# %%
# for fold, (train_ids, valid_ids) in enumerate(splitted):
#     print(f"Fold {fold} has {len(train_ids)} training items and {len(valid_ids)} valid items")

# %% [markdown]
# Oddly, it seems that the shapes are different if you you're explicitly

# %%
# X_meta, y_meta = super_cross_validation()
# X_meta_df = pd.DataFrame(X_meta, columns=[str(x) for x in range(X_meta.shape[1])])
# X_meta_df.to_feather((datapath/'X_super-learner_meta.feather'))
# dump(y_meta, datapath/"y_super-learner_meta.joblib")

# %%
# test = pd.DataFrame({'col1': [1,2,3,4], 'col2': [11,12,13,14]})

# %%
# test1 = pd.DataFrame({'col1': [5,6,7,8], 'col2': [15,16,17,18]})

# %%
# test_concat = pd.concat([test, test1], axis=0)

# %%
# test_concat

# %%
test = pd.DataFrame()

# %%
type(test)
# Out:
# pandas.core.frame.DataFrame

# %%
test_list = model_list[1:]

# %%
test_list
# Out:
# [('lightgbm',
#   LGBMClassifier(device_type='cpu', learning_rate=0.03221, max_depth=2,
#                  n_estimators=1286, objective='binary', random_state=42,
#                  reg_alpha=0.4687, reg_lambda=0.1763, subsample=0.6621)),
#  ('catboost', <catboost.core.CatBoostClassifier at 0x7ff3d04dec70>)]

# %%
def super_cross_validation(model_list=model_list, 
                           X=X, 
                           y=y, 
                           start_fold=0, 
                           exmodel_config=exmodel_config, 
                           random_state=42, 
                           wandb_run=True, 
                           passthrough=False):
    """
    Function to handle model training process in the context of cross-validation -- via hold-out or via k-fold.
    If exmodel_config['cross_val_strategy'] == None, then any kfolds= input is ignored; otherwise, the number specified is used.
    
    :param kfolds: int specifying number of k-folds to use in cross-validation
    :param exmodel_config: dict containing general config including for cross-validation -- `kfold=1` implies hold-out
    """
#     if exmodel_config['kfolds'] == 1:
#         print("Proceeding with holdout")
#         X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
#                                                       test_size=exmodel_config['test_size'], 
#                                                       random_state=random_state,
#                                                      )
#         model = train(X_train, X_valid, y_train, y_valid, exmodel_config=exmodel_config, 
#                                                     model_config=model_config,
#                                                     config_run=config_run)
#         wandb.finish()
        
#     else:

    if wandb_run:
        wandb.init(
            project="202109_Kaggle_tabular_playground",
            save_code=True,
            tags=config_run['tags'],
            name=config_run['name'],
            notes=config_run['notes'],
            config=exmodel_config)  
    
    X_np, y_np = X.to_numpy(), y.to_numpy()
    # from https://machinelearningmastery.com/super-learner-ensemble-in-python/ # Super Learner for Classification
#     X_meta, y_meta = X, y # for the meta-learner; might concat the X with the data later for a passthrough=True run
#     X_baseline_preds = 
    X_meta, y_meta = [], []
    exmodel_config['kfolds'] = 5
    exmodel_config['cross_val_strategy'] = 'KFold'
    kfold = KFold(n_splits=exmodel_config['kfolds'], shuffle=True, random_state=random_state)
#     trained_models = {}
#         oof_preds = {}
#     model_path = Path(datapath/f"models/{config_run['name']}_{exmodel_config['kfolds']}folds/")
#     (model_path).mkdir(exist_ok=True)
    preds_path = Path(datapath/f"preds/{config_run['name']}_{exmodel_config['kfolds']}folds/")
    (preds_path).mkdir(exist_ok=True)
    for fold, (train_ids, valid_ids) in enumerate(kfold.split(X,y)):
        if fold < start_fold:
            continue
        else:
            fold_preds = [] # initializing the list of predictions for the fold
            print(f"FOLD {fold}")
            print("---------------------------------------------------")
            X_np, y_np = X.to_numpy(), y.to_numpy()
            
#             fold_preds = []
            # proeeding with `pd.DataFrame`s rather than `np.ndarray`s
#             X_train, X_valid = X.loc[train_ids], X.loc[valid_ids]
#             y_train, y_valid = y.loc[train_ids], y.loc[valid_ids]
            X_train, X_valid = X_np[train_ids], X_np[valid_ids]
            y_train, y_valid = y_np[train_ids], y_np[valid_ids]
            print(f"type(X_train) = {type(X_train)}")
            print(f"type(y_trian) = {type(y_train)}")
            # append the y_valid to y_meta
#             pd.concat(y_meta, y_valid, axis=0) # building this "meta" y as we go - the valid for each fold go at the bottom of the col/pd.Series
            y_meta.append(y_valid) # assumes y_meta is a list
#             y_meta = pd.concat(y_meta, pd.Series(y_valid))
            for model in model_list: # presumes tuples of the form (str, model)
                model[1].fit(X_train, y_train)
                y_train_pred = model[1].predict_proba(X_train)[:,1]

                train_loss = log_loss(y_train, y_train_pred)
                train_auc = roc_auc_score(y_train, y_train_pred)
                if wandb_run:
                    wandb.log({'train_loss': train_loss, 'train_auc': train_auc})
                    if model[0] == 'catboost':
    #                         print(model[1].get_all_params())
                        wandb.log({'catboost_params': str(model[1].get_all_params())})                        
                    else:
                        wandb.log({f'{model[0]}_params': str(model[1].get_params())}) 
                y_pred = model[1].predict_proba(X_valid)[:,1]
                fold_preds.append(y_pred.reshape(len(y_pred), 1))
                
                valid_loss = log_loss(y_valid, y_pred)
                valid_auc = roc_auc_score(y_valid, y_pred)
                
                print(f"Valid log-loss is {valid_loss}\nValid AUC is {valid_auc}")   
#                     oof_preds = super_train(X_train, X_valid, y_train, y_valid, exmodel_config=exmodel_config, 
# #                                                     model_config=model_config,
#                                                     config_run=config_run)
                
                if wandb_run:
                    wandb.log({'valid_loss':valid_loss, 'valid_auc':valid_auc})
                    wandb.log({'fold': fold})
                dump(y_pred, Path(preds_path/f"{model[0]}_fold{fold}_oof-preds.joblib"))
                
#                     models[fold] = model
#           y      preds[fold] = oof_preds
            X_meta.append(np.hstack(fold_preds))
            dump(fold_preds, Path(preds_path/f"all_fold{fold}_oof-preds.joblib"))
#                     dump(model, Path(model_path/f"{exmodel_config['library']}_fold{fold}_model.joblib"))

#                 wandb.finish()
#     return np.vstack(X_meta), np.asarray(y_meta)
    # at this point, X_meta is a length-5 list of np.ndarrays; each array has as many columns as estimators. The number of rows across folds sum to the number in the dataset.
    # meanwhile, y_meta is a length-5 list of np.ndarrays containing the labels for each fold.
    # on the way out, let's get them into the proper format
#     return X_meta, y_meta 
    return np.vstack(X_meta), np.asarray(y_meta)

# %%
# this will define the features and labels for the meta-learner
X_meta, y_meta = super_cross_validation(test_list, wandb_run=False)
# Out:
# FOLD 0
# ---------------------------------------------------
# type(X_train) = <class 'numpy.ndarray'>
# type(y_trian) = <class 'numpy.ndarray'>
# Valid log-loss is 0.5113911181729013
# Valid AUC is 0.8114826365905788
# Learning rate set to 0.093011
# 0:	learn: 0.6580718	total: 140ms	remaining: 4m 39s
# 1:	learn: 0.6298703	total: 228ms	remaining: 3m 47s
# 2:	learn: 0.6072111	total: 320ms	remaining: 3m 33s
# 3:	learn: 0.5889982	total: 410ms	remaining: 3m 24s
# 4:	learn: 0.5743639	total: 510ms	remaining: 3m 23s
# 5:	learn: 0.5625637	total: 595ms	remaining: 3m 17s
# 6:	learn: 0.5530566	total: 678ms	remaining: 3m 13s
# 7:	learn: 0.5454104	total: 773ms	remaining: 3m 12s
# 8:	learn: 0.5392238	total: 859ms	remaining: 3m 9s
# 9:	learn: 0.5342211	total: 951ms	remaining: 3m 9s
# 10:	learn: 0.5301457	total: 1.04s	remaining: 3m 8s
# 11:	learn: 0.5268757	total: 1.13s	remaining: 3m 7s
# 12:	learn: 0.5242039	total: 1.21s	remaining: 3m 4s
# 13:	learn: 0.5220363	total: 1.3s	remaining: 3m 5s
# 14:	learn: 0.5202507	total: 1.39s	remaining: 3m 3s
# 15:	learn: 0.5188851	total: 1.47s	remaining: 3m 1s
# 16:	learn: 0.5176763	total: 1.56s	remaining: 3m 1s
# 17:	learn: 0.5167425	total: 1.64s	remaining: 3m
# 18:	learn: 0.5159180	total: 1.72s	remaining: 2m 59s
# 19:	learn: 0.5152346	total: 1.82s	remaining: 2m 59s
# 20:	learn: 0.5146921	total: 1.9s	remaining: 2m 59s
# 21:	learn: 0.5142470	total: 1.98s	remaining: 2m 58s
# 22:	learn: 0.5138785	total: 2.07s	remaining: 2m 58s
# 23:	learn: 0.5135251	total: 2.15s	remaining: 2m 57s
# 24:	learn: 0.5132441	total: 2.24s	remaining: 2m 56s
# 25:	learn: 0.5130166	total: 2.33s	remaining: 2m 56s
# 26:	learn: 0.5128093	total: 2.41s	remaining: 2m 56s
# 27:	learn: 0.5126455	total: 2.5s	remaining: 2m 56s
# 28:	learn: 0.5124710	total: 2.6s	remaining: 2m 56s
# 29:	learn: 0.5123086	total: 2.68s	remaining: 2m 55s
# 30:	learn: 0.5121819	total: 2.76s	remaining: 2m 55s
# 31:	learn: 0.5120554	total: 2.85s	remaining: 2m 55s
# 32:	learn: 0.5119419	total: 2.94s	remaining: 2m 55s
# 33:	learn: 0.5118495	total: 3.02s	remaining: 2m 54s
# 34:	learn: 0.5117441	total: 3.11s	remaining: 2m 54s
# 35:	learn: 0.5116619	total: 3.2s	remaining: 2m 54s
# 36:	learn: 0.5115803	total: 3.28s	remaining: 2m 54s
# 37:	learn: 0.5115052	total: 3.37s	remaining: 2m 54s
# 38:	learn: 0.5114414	total: 3.45s	remaining: 2m 53s
# 39:	learn: 0.5113737	total: 3.54s	remaining: 2m 53s
# 40:	learn: 0.5113226	total: 3.64s	remaining: 2m 53s
# 41:	learn: 0.5112584	total: 3.72s	remaining: 2m 53s
# 42:	learn: 0.5112094	total: 3.81s	remaining: 2m 53s
# 43:	learn: 0.5111644	total: 3.9s	remaining: 2m 53s
# 44:	learn: 0.5111160	total: 3.98s	remaining: 2m 52s
# 45:	learn: 0.5110580	total: 4.06s	remaining: 2m 52s
# 46:	learn: 0.5110091	total: 4.15s	remaining: 2m 52s
# 47:	learn: 0.5109592	total: 4.23s	remaining: 2m 51s
# 48:	learn: 0.5109098	total: 4.31s	remaining: 2m 51s
# 49:	learn: 0.5108653	total: 4.4s	remaining: 2m 51s
# 50:	learn: 0.5108186	total: 4.49s	remaining: 2m 51s
# 51:	learn: 0.5107718	total: 4.57s	remaining: 2m 51s
# 52:	learn: 0.5107374	total: 4.66s	remaining: 2m 51s
# 53:	learn: 0.5106943	total: 4.74s	remaining: 2m 50s
# 54:	learn: 0.5106512	total: 4.82s	remaining: 2m 50s
# 55:	learn: 0.5106198	total: 4.91s	remaining: 2m 50s
# 56:	learn: 0.5105798	total: 4.99s	remaining: 2m 50s
# 57:	learn: 0.5105370	total: 5.08s	remaining: 2m 49s
# 58:	learn: 0.5105046	total: 5.17s	remaining: 2m 50s
# 59:	learn: 0.5104673	total: 5.25s	remaining: 2m 49s
# 60:	learn: 0.5104315	total: 5.33s	remaining: 2m 49s
# 61:	learn: 0.5103915	total: 5.42s	remaining: 2m 49s
# 62:	learn: 0.5103493	total: 5.51s	remaining: 2m 49s
# 63:	learn: 0.5103083	total: 5.59s	remaining: 2m 49s
# 64:	learn: 0.5102768	total: 5.68s	remaining: 2m 49s
# 65:	learn: 0.5102416	total: 5.76s	remaining: 2m 48s
# 66:	learn: 0.5102068	total: 5.84s	remaining: 2m 48s
# 67:	learn: 0.5101693	total: 5.93s	remaining: 2m 48s
# 68:	learn: 0.5101361	total: 6.02s	remaining: 2m 48s
# 69:	learn: 0.5101040	total: 6.1s	remaining: 2m 48s
# 70:	learn: 0.5100726	total: 6.18s	remaining: 2m 48s
# 71:	learn: 0.5100347	total: 6.27s	remaining: 2m 47s
# 72:	learn: 0.5100024	total: 6.34s	remaining: 2m 47s
# 73:	learn: 0.5099751	total: 6.44s	remaining: 2m 47s
# 74:	learn: 0.5099435	total: 6.52s	remaining: 2m 47s
# 75:	learn: 0.5099129	total: 6.61s	remaining: 2m 47s
# 76:	learn: 0.5098832	total: 6.7s	remaining: 2m 47s
# 77:	learn: 0.5098497	total: 6.77s	remaining: 2m 46s
# 78:	learn: 0.5098175	total: 6.86s	remaining: 2m 46s
# 79:	learn: 0.5097855	total: 6.95s	remaining: 2m 46s
# 80:	learn: 0.5097554	total: 7.04s	remaining: 2m 46s
# 81:	learn: 0.5097264	total: 7.12s	remaining: 2m 46s
# 82:	learn: 0.5096965	total: 7.21s	remaining: 2m 46s
# 83:	learn: 0.5096669	total: 7.28s	remaining: 2m 46s
# 84:	learn: 0.5096372	total: 7.37s	remaining: 2m 45s
# 85:	learn: 0.5096041	total: 7.46s	remaining: 2m 45s
# 86:	learn: 0.5095754	total: 7.54s	remaining: 2m 45s
# 87:	learn: 0.5095412	total: 7.62s	remaining: 2m 45s
# 88:	learn: 0.5095108	total: 7.71s	remaining: 2m 45s
# 89:	learn: 0.5094720	total: 7.79s	remaining: 2m 45s
# 90:	learn: 0.5094467	total: 7.88s	remaining: 2m 45s
# 91:	learn: 0.5094223	total: 7.97s	remaining: 2m 45s
# 92:	learn: 0.5093921	total: 8.05s	remaining: 2m 45s
# 93:	learn: 0.5093638	total: 8.14s	remaining: 2m 44s
# 94:	learn: 0.5093372	total: 8.23s	remaining: 2m 45s
# 95:	learn: 0.5093101	total: 8.31s	remaining: 2m 44s
# 96:	learn: 0.5092839	total: 8.39s	remaining: 2m 44s
# 97:	learn: 0.5092577	total: 8.48s	remaining: 2m 44s
# 98:	learn: 0.5092339	total: 8.57s	remaining: 2m 44s
# 99:	learn: 0.5092133	total: 8.64s	remaining: 2m 44s
# 100:	learn: 0.5091843	total: 8.72s	remaining: 2m 44s
# 101:	learn: 0.5091576	total: 8.81s	remaining: 2m 43s
# 102:	learn: 0.5091308	total: 8.89s	remaining: 2m 43s
# 103:	learn: 0.5090967	total: 8.98s	remaining: 2m 43s
# 104:	learn: 0.5090700	total: 9.06s	remaining: 2m 43s
# 105:	learn: 0.5090417	total: 9.15s	remaining: 2m 43s
# 106:	learn: 0.5090174	total: 9.24s	remaining: 2m 43s
# 107:	learn: 0.5089946	total: 9.33s	remaining: 2m 43s
# 108:	learn: 0.5089712	total: 9.41s	remaining: 2m 43s
# 109:	learn: 0.5089326	total: 9.5s	remaining: 2m 43s
# 110:	learn: 0.5089072	total: 9.59s	remaining: 2m 43s
# 111:	learn: 0.5088812	total: 9.67s	remaining: 2m 43s
# 112:	learn: 0.5088516	total: 9.76s	remaining: 2m 42s
# 113:	learn: 0.5088283	total: 9.84s	remaining: 2m 42s
# 114:	learn: 0.5088022	total: 9.93s	remaining: 2m 42s
# 115:	learn: 0.5087754	total: 10s	remaining: 2m 42s
# 116:	learn: 0.5087504	total: 10.1s	remaining: 2m 42s
# 117:	learn: 0.5087275	total: 10.2s	remaining: 2m 42s
# 118:	learn: 0.5087025	total: 10.3s	remaining: 2m 42s
# 119:	learn: 0.5086789	total: 10.4s	remaining: 2m 42s
# 120:	learn: 0.5086579	total: 10.4s	remaining: 2m 42s
# 121:	learn: 0.5086347	total: 10.5s	remaining: 2m 42s
# 122:	learn: 0.5086151	total: 10.6s	remaining: 2m 41s
# 123:	learn: 0.5085935	total: 10.7s	remaining: 2m 41s
# 124:	learn: 0.5085704	total: 10.8s	remaining: 2m 41s
# 125:	learn: 0.5085403	total: 10.9s	remaining: 2m 41s
# 126:	learn: 0.5085187	total: 11s	remaining: 2m 41s
# 127:	learn: 0.5084947	total: 11s	remaining: 2m 41s
# 128:	learn: 0.5084647	total: 11.1s	remaining: 2m 41s
# 129:	learn: 0.5084420	total: 11.2s	remaining: 2m 41s
# 130:	learn: 0.5084205	total: 11.3s	remaining: 2m 41s
# 131:	learn: 0.5083981	total: 11.4s	remaining: 2m 40s
# 132:	learn: 0.5083727	total: 11.5s	remaining: 2m 40s
# 133:	learn: 0.5083504	total: 11.5s	remaining: 2m 40s
# 134:	learn: 0.5083262	total: 11.6s	remaining: 2m 40s
# 135:	learn: 0.5083002	total: 11.7s	remaining: 2m 40s
# 136:	learn: 0.5082773	total: 11.8s	remaining: 2m 40s
# 137:	learn: 0.5082519	total: 11.9s	remaining: 2m 40s
# 138:	learn: 0.5082289	total: 12s	remaining: 2m 40s
# 139:	learn: 0.5082058	total: 12.1s	remaining: 2m 40s
# 140:	learn: 0.5081843	total: 12.1s	remaining: 2m 40s
# 141:	learn: 0.5081613	total: 12.2s	remaining: 2m 39s
# 142:	learn: 0.5081431	total: 12.3s	remaining: 2m 39s
# 143:	learn: 0.5081184	total: 12.4s	remaining: 2m 39s
# 144:	learn: 0.5080952	total: 12.5s	remaining: 2m 39s
# 145:	learn: 0.5080702	total: 12.5s	remaining: 2m 39s
# 146:	learn: 0.5080470	total: 12.6s	remaining: 2m 39s
# 147:	learn: 0.5080245	total: 12.7s	remaining: 2m 39s
# 148:	learn: 0.5079829	total: 12.8s	remaining: 2m 38s
# 149:	learn: 0.5079578	total: 12.9s	remaining: 2m 38s
# 150:	learn: 0.5079328	total: 13s	remaining: 2m 38s
# 151:	learn: 0.5079087	total: 13s	remaining: 2m 38s
# 152:	learn: 0.5078805	total: 13.1s	remaining: 2m 38s
# 153:	learn: 0.5078562	total: 13.2s	remaining: 2m 38s
# 154:	learn: 0.5078246	total: 13.3s	remaining: 2m 38s
# 155:	learn: 0.5077970	total: 13.4s	remaining: 2m 38s
# 156:	learn: 0.5077646	total: 13.5s	remaining: 2m 38s
# 157:	learn: 0.5077371	total: 13.6s	remaining: 2m 38s
# 158:	learn: 0.5077080	total: 13.7s	remaining: 2m 38s
# 159:	learn: 0.5076820	total: 13.7s	remaining: 2m 38s
# 160:	learn: 0.5076568	total: 13.8s	remaining: 2m 38s
# 161:	learn: 0.5076306	total: 13.9s	remaining: 2m 38s
# 162:	learn: 0.5076051	total: 14s	remaining: 2m 37s
# 163:	learn: 0.5075802	total: 14.1s	remaining: 2m 37s
# 164:	learn: 0.5075363	total: 14.2s	remaining: 2m 37s
# 165:	learn: 0.5075076	total: 14.3s	remaining: 2m 37s
# 166:	learn: 0.5074838	total: 14.4s	remaining: 2m 37s
# 167:	learn: 0.5074553	total: 14.4s	remaining: 2m 37s
# 168:	learn: 0.5074278	total: 14.5s	remaining: 2m 37s
# 169:	learn: 0.5074017	total: 14.6s	remaining: 2m 37s
# 170:	learn: 0.5073699	total: 14.7s	remaining: 2m 37s
# 171:	learn: 0.5073416	total: 14.8s	remaining: 2m 37s
# 172:	learn: 0.5073149	total: 14.9s	remaining: 2m 37s
# 173:	learn: 0.5072891	total: 15s	remaining: 2m 36s
# 174:	learn: 0.5072598	total: 15s	remaining: 2m 36s
# 175:	learn: 0.5072337	total: 15.1s	remaining: 2m 36s
# 176:	learn: 0.5072062	total: 15.2s	remaining: 2m 36s
# 177:	learn: 0.5071801	total: 15.3s	remaining: 2m 36s
# 178:	learn: 0.5071554	total: 15.4s	remaining: 2m 36s
# 179:	learn: 0.5071263	total: 15.5s	remaining: 2m 36s
# 180:	learn: 0.5070958	total: 15.6s	remaining: 2m 36s
# 181:	learn: 0.5070692	total: 15.7s	remaining: 2m 36s
# 182:	learn: 0.5070392	total: 15.7s	remaining: 2m 36s
# 183:	learn: 0.5070130	total: 15.8s	remaining: 2m 36s
# 184:	learn: 0.5069870	total: 15.9s	remaining: 2m 36s
# 185:	learn: 0.5069630	total: 16s	remaining: 2m 36s
# 186:	learn: 0.5069393	total: 16.1s	remaining: 2m 35s
# 187:	learn: 0.5069142	total: 16.2s	remaining: 2m 35s
# 188:	learn: 0.5068898	total: 16.2s	remaining: 2m 35s
# 189:	learn: 0.5068619	total: 16.3s	remaining: 2m 35s
# 190:	learn: 0.5068376	total: 16.4s	remaining: 2m 35s
# 191:	learn: 0.5068129	total: 16.5s	remaining: 2m 35s
# 192:	learn: 0.5067874	total: 16.6s	remaining: 2m 35s
# 193:	learn: 0.5067629	total: 16.7s	remaining: 2m 35s
# 194:	learn: 0.5067339	total: 16.8s	remaining: 2m 35s
# 195:	learn: 0.5067051	total: 16.8s	remaining: 2m 34s
# 196:	learn: 0.5066769	total: 16.9s	remaining: 2m 34s
# 197:	learn: 0.5066496	total: 17s	remaining: 2m 34s
# 198:	learn: 0.5066240	total: 17.1s	remaining: 2m 34s
# 199:	learn: 0.5065996	total: 17.2s	remaining: 2m 34s
# 200:	learn: 0.5065662	total: 17.2s	remaining: 2m 34s
# 201:	learn: 0.5065404	total: 17.3s	remaining: 2m 34s
# 202:	learn: 0.5065125	total: 17.4s	remaining: 2m 34s
# 203:	learn: 0.5064871	total: 17.5s	remaining: 2m 34s
# 204:	learn: 0.5064606	total: 17.6s	remaining: 2m 33s
# 205:	learn: 0.5064368	total: 17.7s	remaining: 2m 33s
# 206:	learn: 0.5064109	total: 17.7s	remaining: 2m 33s
# 207:	learn: 0.5063835	total: 17.8s	remaining: 2m 33s
# 208:	learn: 0.5063604	total: 17.9s	remaining: 2m 33s
# 209:	learn: 0.5063356	total: 18s	remaining: 2m 33s
# 210:	learn: 0.5063114	total: 18.1s	remaining: 2m 33s
# 211:	learn: 0.5062829	total: 18.2s	remaining: 2m 33s
# 212:	learn: 0.5062574	total: 18.3s	remaining: 2m 33s
# 213:	learn: 0.5062347	total: 18.3s	remaining: 2m 33s
# 214:	learn: 0.5062105	total: 18.4s	remaining: 2m 33s
# 215:	learn: 0.5061837	total: 18.5s	remaining: 2m 32s
# 216:	learn: 0.5061600	total: 18.6s	remaining: 2m 32s
# 217:	learn: 0.5061373	total: 18.7s	remaining: 2m 32s
# 218:	learn: 0.5061143	total: 18.8s	remaining: 2m 32s
# 219:	learn: 0.5060912	total: 18.9s	remaining: 2m 32s
# 220:	learn: 0.5060678	total: 18.9s	remaining: 2m 32s
# 221:	learn: 0.5060435	total: 19s	remaining: 2m 32s
# 222:	learn: 0.5060161	total: 19.1s	remaining: 2m 32s
# 223:	learn: 0.5059916	total: 19.2s	remaining: 2m 32s
# 224:	learn: 0.5059689	total: 19.3s	remaining: 2m 32s
# 225:	learn: 0.5059462	total: 19.4s	remaining: 2m 31s
# 226:	learn: 0.5059209	total: 19.4s	remaining: 2m 31s
# 227:	learn: 0.5058960	total: 19.5s	remaining: 2m 31s
# 228:	learn: 0.5058712	total: 19.6s	remaining: 2m 31s
# 229:	learn: 0.5058469	total: 19.7s	remaining: 2m 31s
# 230:	learn: 0.5058210	total: 19.8s	remaining: 2m 31s
# 231:	learn: 0.5057993	total: 19.9s	remaining: 2m 31s
# 232:	learn: 0.5057724	total: 20s	remaining: 2m 31s
# 233:	learn: 0.5057489	total: 20s	remaining: 2m 31s
# 234:	learn: 0.5057258	total: 20.1s	remaining: 2m 31s
# 235:	learn: 0.5057052	total: 20.2s	remaining: 2m 30s
# 236:	learn: 0.5056787	total: 20.3s	remaining: 2m 30s
# 237:	learn: 0.5056548	total: 20.4s	remaining: 2m 30s
# 238:	learn: 0.5056302	total: 20.4s	remaining: 2m 30s
# 239:	learn: 0.5056031	total: 20.5s	remaining: 2m 30s
# 240:	learn: 0.5055808	total: 20.6s	remaining: 2m 30s
# 241:	learn: 0.5055608	total: 20.7s	remaining: 2m 30s
# 242:	learn: 0.5055371	total: 20.8s	remaining: 2m 30s
# 243:	learn: 0.5055139	total: 20.9s	remaining: 2m 30s
# 244:	learn: 0.5054895	total: 21s	remaining: 2m 30s
# 245:	learn: 0.5054677	total: 21s	remaining: 2m 29s
# 246:	learn: 0.5054436	total: 21.1s	remaining: 2m 29s
# 247:	learn: 0.5054190	total: 21.2s	remaining: 2m 29s
# 248:	learn: 0.5053951	total: 21.3s	remaining: 2m 29s
# 249:	learn: 0.5053721	total: 21.4s	remaining: 2m 29s
# 250:	learn: 0.5053537	total: 21.5s	remaining: 2m 29s
# 251:	learn: 0.5053319	total: 21.5s	remaining: 2m 29s
# 252:	learn: 0.5053104	total: 21.6s	remaining: 2m 29s
# 253:	learn: 0.5052885	total: 21.7s	remaining: 2m 29s
# 254:	learn: 0.5052627	total: 21.8s	remaining: 2m 29s
# 255:	learn: 0.5052407	total: 21.9s	remaining: 2m 29s
# 256:	learn: 0.5052162	total: 22s	remaining: 2m 29s
# 257:	learn: 0.5051953	total: 22.1s	remaining: 2m 28s
# 258:	learn: 0.5051702	total: 22.1s	remaining: 2m 28s
# 259:	learn: 0.5051470	total: 22.2s	remaining: 2m 28s
# 260:	learn: 0.5051254	total: 22.3s	remaining: 2m 28s
# 261:	learn: 0.5051006	total: 22.4s	remaining: 2m 28s
# 262:	learn: 0.5050757	total: 22.5s	remaining: 2m 28s
# 263:	learn: 0.5050522	total: 22.6s	remaining: 2m 28s
# 264:	learn: 0.5050292	total: 22.6s	remaining: 2m 28s
# 265:	learn: 0.5050071	total: 22.7s	remaining: 2m 28s
# 266:	learn: 0.5049829	total: 22.8s	remaining: 2m 27s
# 267:	learn: 0.5049643	total: 22.9s	remaining: 2m 27s
# 268:	learn: 0.5049390	total: 23s	remaining: 2m 27s
# 269:	learn: 0.5049182	total: 23s	remaining: 2m 27s
# 270:	learn: 0.5048972	total: 23.1s	remaining: 2m 27s
# 271:	learn: 0.5048753	total: 23.2s	remaining: 2m 27s
# 272:	learn: 0.5048508	total: 23.3s	remaining: 2m 27s
# 273:	learn: 0.5048270	total: 23.4s	remaining: 2m 27s
# 274:	learn: 0.5048056	total: 23.5s	remaining: 2m 27s
# 275:	learn: 0.5047815	total: 23.6s	remaining: 2m 27s
# 276:	learn: 0.5047554	total: 23.6s	remaining: 2m 27s
# 277:	learn: 0.5047310	total: 23.7s	remaining: 2m 27s
# 278:	learn: 0.5047099	total: 23.8s	remaining: 2m 26s
# 279:	learn: 0.5046866	total: 23.9s	remaining: 2m 26s
# 280:	learn: 0.5046647	total: 24s	remaining: 2m 26s
# 281:	learn: 0.5046433	total: 24.1s	remaining: 2m 26s
# 282:	learn: 0.5046208	total: 24.2s	remaining: 2m 26s
# 283:	learn: 0.5045996	total: 24.2s	remaining: 2m 26s
# 284:	learn: 0.5045790	total: 24.3s	remaining: 2m 26s
# 285:	learn: 0.5045591	total: 24.4s	remaining: 2m 26s
# 286:	learn: 0.5045381	total: 24.5s	remaining: 2m 26s
# 287:	learn: 0.5045201	total: 24.6s	remaining: 2m 26s
# 288:	learn: 0.5044975	total: 24.7s	remaining: 2m 25s
# 289:	learn: 0.5044751	total: 24.7s	remaining: 2m 25s
# 290:	learn: 0.5044523	total: 24.8s	remaining: 2m 25s
# 291:	learn: 0.5044280	total: 24.9s	remaining: 2m 25s
# 292:	learn: 0.5044051	total: 25s	remaining: 2m 25s
# 293:	learn: 0.5043850	total: 25.1s	remaining: 2m 25s
# 294:	learn: 0.5043656	total: 25.2s	remaining: 2m 25s
# 295:	learn: 0.5043419	total: 25.3s	remaining: 2m 25s
# 296:	learn: 0.5043183	total: 25.3s	remaining: 2m 25s
# 297:	learn: 0.5042986	total: 25.4s	remaining: 2m 25s
# 298:	learn: 0.5042763	total: 25.5s	remaining: 2m 25s
# 299:	learn: 0.5042533	total: 25.6s	remaining: 2m 25s
# 300:	learn: 0.5042336	total: 25.7s	remaining: 2m 24s
# 301:	learn: 0.5042141	total: 25.8s	remaining: 2m 24s
# 302:	learn: 0.5041955	total: 25.8s	remaining: 2m 24s
# 303:	learn: 0.5041732	total: 25.9s	remaining: 2m 24s
# 304:	learn: 0.5041523	total: 26s	remaining: 2m 24s
# 305:	learn: 0.5041301	total: 26.1s	remaining: 2m 24s
# 306:	learn: 0.5041115	total: 26.2s	remaining: 2m 24s
# 307:	learn: 0.5040881	total: 26.3s	remaining: 2m 24s
# 308:	learn: 0.5040678	total: 26.4s	remaining: 2m 24s
# 309:	learn: 0.5040450	total: 26.4s	remaining: 2m 24s
# 310:	learn: 0.5040225	total: 26.5s	remaining: 2m 24s
# 311:	learn: 0.5039971	total: 26.6s	remaining: 2m 23s
# 312:	learn: 0.5039753	total: 26.7s	remaining: 2m 23s
# 313:	learn: 0.5039513	total: 26.8s	remaining: 2m 23s
# 314:	learn: 0.5039336	total: 26.9s	remaining: 2m 23s
# 315:	learn: 0.5039127	total: 27s	remaining: 2m 23s
# 316:	learn: 0.5038944	total: 27.1s	remaining: 2m 23s
# 317:	learn: 0.5038718	total: 27.1s	remaining: 2m 23s
# 318:	learn: 0.5038508	total: 27.2s	remaining: 2m 23s
# 319:	learn: 0.5038286	total: 27.3s	remaining: 2m 23s
# 320:	learn: 0.5038072	total: 27.4s	remaining: 2m 23s
# 321:	learn: 0.5037862	total: 27.5s	remaining: 2m 23s
# 322:	learn: 0.5037649	total: 27.6s	remaining: 2m 23s
# 323:	learn: 0.5037439	total: 27.6s	remaining: 2m 22s
# 324:	learn: 0.5037217	total: 27.7s	remaining: 2m 22s
# 325:	learn: 0.5036991	total: 27.8s	remaining: 2m 22s
# 326:	learn: 0.5036750	total: 27.9s	remaining: 2m 22s
# 327:	learn: 0.5036551	total: 28s	remaining: 2m 22s
# 328:	learn: 0.5036307	total: 28.1s	remaining: 2m 22s
# 329:	learn: 0.5036083	total: 28.2s	remaining: 2m 22s
# 330:	learn: 0.5035852	total: 28.2s	remaining: 2m 22s
# 331:	learn: 0.5035606	total: 28.3s	remaining: 2m 22s
# 332:	learn: 0.5035374	total: 28.4s	remaining: 2m 22s
# 333:	learn: 0.5035151	total: 28.5s	remaining: 2m 22s
# 334:	learn: 0.5034941	total: 28.6s	remaining: 2m 22s
# 335:	learn: 0.5034699	total: 28.7s	remaining: 2m 22s
# 336:	learn: 0.5034457	total: 28.8s	remaining: 2m 22s
# 337:	learn: 0.5034259	total: 28.9s	remaining: 2m 22s
# 338:	learn: 0.5034052	total: 29s	remaining: 2m 21s
# 339:	learn: 0.5033864	total: 29s	remaining: 2m 21s
# 340:	learn: 0.5033667	total: 29.1s	remaining: 2m 21s
# 341:	learn: 0.5033440	total: 29.2s	remaining: 2m 21s
# 342:	learn: 0.5033241	total: 29.3s	remaining: 2m 21s
# 343:	learn: 0.5033025	total: 29.4s	remaining: 2m 21s
# 344:	learn: 0.5032809	total: 29.5s	remaining: 2m 21s
# 345:	learn: 0.5032586	total: 29.6s	remaining: 2m 21s
# 346:	learn: 0.5032391	total: 29.6s	remaining: 2m 21s
# 347:	learn: 0.5032144	total: 29.7s	remaining: 2m 21s
# 348:	learn: 0.5031970	total: 29.8s	remaining: 2m 21s
# 349:	learn: 0.5031744	total: 29.9s	remaining: 2m 20s
# 350:	learn: 0.5031514	total: 30s	remaining: 2m 20s
# 351:	learn: 0.5031289	total: 30.1s	remaining: 2m 20s
# 352:	learn: 0.5031075	total: 30.2s	remaining: 2m 20s
# 353:	learn: 0.5030882	total: 30.2s	remaining: 2m 20s
# 354:	learn: 0.5030698	total: 30.3s	remaining: 2m 20s
# 355:	learn: 0.5030516	total: 30.4s	remaining: 2m 20s
# 356:	learn: 0.5030338	total: 30.5s	remaining: 2m 20s
# 357:	learn: 0.5030118	total: 30.6s	remaining: 2m 20s
# 358:	learn: 0.5029897	total: 30.7s	remaining: 2m 20s
# 359:	learn: 0.5029680	total: 30.7s	remaining: 2m 20s
# 360:	learn: 0.5029501	total: 30.8s	remaining: 2m 19s
# 361:	learn: 0.5029309	total: 30.9s	remaining: 2m 19s
# 362:	learn: 0.5029106	total: 31s	remaining: 2m 19s
# 363:	learn: 0.5028917	total: 31.1s	remaining: 2m 19s
# 364:	learn: 0.5028730	total: 31.2s	remaining: 2m 19s
# 365:	learn: 0.5028565	total: 31.2s	remaining: 2m 19s
# 366:	learn: 0.5028349	total: 31.3s	remaining: 2m 19s
# 367:	learn: 0.5028161	total: 31.4s	remaining: 2m 19s
# 368:	learn: 0.5027953	total: 31.5s	remaining: 2m 19s
# 369:	learn: 0.5027770	total: 31.6s	remaining: 2m 19s
# 370:	learn: 0.5027575	total: 31.7s	remaining: 2m 19s
# 371:	learn: 0.5027368	total: 31.7s	remaining: 2m 18s
# 372:	learn: 0.5027149	total: 31.8s	remaining: 2m 18s
# 373:	learn: 0.5026932	total: 31.9s	remaining: 2m 18s
# 374:	learn: 0.5026734	total: 32s	remaining: 2m 18s
# 375:	learn: 0.5026515	total: 32.1s	remaining: 2m 18s
# 376:	learn: 0.5026309	total: 32.2s	remaining: 2m 18s
# 377:	learn: 0.5026111	total: 32.3s	remaining: 2m 18s
# 378:	learn: 0.5025903	total: 32.3s	remaining: 2m 18s
# 379:	learn: 0.5025687	total: 32.4s	remaining: 2m 18s
# 380:	learn: 0.5025482	total: 32.5s	remaining: 2m 18s
# 381:	learn: 0.5025243	total: 32.6s	remaining: 2m 18s
# 382:	learn: 0.5025029	total: 32.7s	remaining: 2m 18s
# 383:	learn: 0.5024825	total: 32.8s	remaining: 2m 17s
# 384:	learn: 0.5024648	total: 32.9s	remaining: 2m 17s
# 385:	learn: 0.5024437	total: 33s	remaining: 2m 17s
# 386:	learn: 0.5024237	total: 33s	remaining: 2m 17s
# 387:	learn: 0.5024050	total: 33.1s	remaining: 2m 17s
# 388:	learn: 0.5023868	total: 33.2s	remaining: 2m 17s
# 389:	learn: 0.5023683	total: 33.3s	remaining: 2m 17s
# 390:	learn: 0.5023496	total: 33.4s	remaining: 2m 17s
# 391:	learn: 0.5023285	total: 33.5s	remaining: 2m 17s
# 392:	learn: 0.5023133	total: 33.6s	remaining: 2m 17s
# 393:	learn: 0.5022950	total: 33.6s	remaining: 2m 17s
# 394:	learn: 0.5022742	total: 33.7s	remaining: 2m 17s
# 395:	learn: 0.5022540	total: 33.8s	remaining: 2m 16s
# 396:	learn: 0.5022343	total: 33.9s	remaining: 2m 16s
# 397:	learn: 0.5022138	total: 34s	remaining: 2m 16s
# 398:	learn: 0.5021925	total: 34.1s	remaining: 2m 16s
# 399:	learn: 0.5021708	total: 34.2s	remaining: 2m 16s
# 400:	learn: 0.5021490	total: 34.2s	remaining: 2m 16s
# 401:	learn: 0.5021267	total: 34.3s	remaining: 2m 16s
# 402:	learn: 0.5021072	total: 34.4s	remaining: 2m 16s
# 403:	learn: 0.5020856	total: 34.5s	remaining: 2m 16s
# 404:	learn: 0.5020660	total: 34.6s	remaining: 2m 16s
# 405:	learn: 0.5020462	total: 34.7s	remaining: 2m 16s
# 406:	learn: 0.5020263	total: 34.7s	remaining: 2m 16s
# 407:	learn: 0.5020046	total: 34.8s	remaining: 2m 15s
# 408:	learn: 0.5019823	total: 34.9s	remaining: 2m 15s
# 409:	learn: 0.5019619	total: 35s	remaining: 2m 15s
# 410:	learn: 0.5019419	total: 35.1s	remaining: 2m 15s
# 411:	learn: 0.5019258	total: 35.2s	remaining: 2m 15s
# 412:	learn: 0.5019059	total: 35.3s	remaining: 2m 15s
# 413:	learn: 0.5018867	total: 35.3s	remaining: 2m 15s
# 414:	learn: 0.5018654	total: 35.4s	remaining: 2m 15s
# 415:	learn: 0.5018481	total: 35.5s	remaining: 2m 15s
# 416:	learn: 0.5018286	total: 35.6s	remaining: 2m 15s
# 417:	learn: 0.5018054	total: 35.7s	remaining: 2m 15s
# 418:	learn: 0.5017843	total: 35.8s	remaining: 2m 14s
# 419:	learn: 0.5017668	total: 35.8s	remaining: 2m 14s
# 420:	learn: 0.5017477	total: 35.9s	remaining: 2m 14s
# 421:	learn: 0.5017250	total: 36s	remaining: 2m 14s
# 422:	learn: 0.5017029	total: 36.1s	remaining: 2m 14s
# 423:	learn: 0.5016844	total: 36.2s	remaining: 2m 14s
# 424:	learn: 0.5016654	total: 36.3s	remaining: 2m 14s
# 425:	learn: 0.5016454	total: 36.4s	remaining: 2m 14s
# 426:	learn: 0.5016268	total: 36.5s	remaining: 2m 14s
# 427:	learn: 0.5016060	total: 36.5s	remaining: 2m 14s
# 428:	learn: 0.5015852	total: 36.6s	remaining: 2m 14s
# 429:	learn: 0.5015645	total: 36.7s	remaining: 2m 14s
# 430:	learn: 0.5015457	total: 36.8s	remaining: 2m 13s
# 431:	learn: 0.5015252	total: 36.9s	remaining: 2m 13s
# 432:	learn: 0.5015039	total: 37s	remaining: 2m 13s
# 433:	learn: 0.5014842	total: 37s	remaining: 2m 13s
# 434:	learn: 0.5014626	total: 37.1s	remaining: 2m 13s
# 435:	learn: 0.5014430	total: 37.2s	remaining: 2m 13s
# 436:	learn: 0.5014209	total: 37.3s	remaining: 2m 13s
# 437:	learn: 0.5014024	total: 37.4s	remaining: 2m 13s
# 438:	learn: 0.5013821	total: 37.5s	remaining: 2m 13s
# 439:	learn: 0.5013598	total: 37.5s	remaining: 2m 13s
# 440:	learn: 0.5013380	total: 37.6s	remaining: 2m 13s
# 441:	learn: 0.5013153	total: 37.7s	remaining: 2m 12s
# 442:	learn: 0.5012933	total: 37.8s	remaining: 2m 12s
# 443:	learn: 0.5012767	total: 37.9s	remaining: 2m 12s
# 444:	learn: 0.5012586	total: 38s	remaining: 2m 12s
# 445:	learn: 0.5012374	total: 38.1s	remaining: 2m 12s
# 446:	learn: 0.5012173	total: 38.1s	remaining: 2m 12s
# 447:	learn: 0.5011974	total: 38.2s	remaining: 2m 12s
# 448:	learn: 0.5011798	total: 38.3s	remaining: 2m 12s
# 449:	learn: 0.5011592	total: 38.4s	remaining: 2m 12s
# 450:	learn: 0.5011398	total: 38.5s	remaining: 2m 12s
# 451:	learn: 0.5011193	total: 38.6s	remaining: 2m 12s
# 452:	learn: 0.5011043	total: 38.7s	remaining: 2m 12s
# 453:	learn: 0.5010829	total: 38.8s	remaining: 2m 11s
# 454:	learn: 0.5010621	total: 38.8s	remaining: 2m 11s
# 455:	learn: 0.5010427	total: 38.9s	remaining: 2m 11s
# 456:	learn: 0.5010252	total: 39s	remaining: 2m 11s
# 457:	learn: 0.5010050	total: 39.1s	remaining: 2m 11s
# 458:	learn: 0.5009844	total: 39.2s	remaining: 2m 11s
# 459:	learn: 0.5009638	total: 39.3s	remaining: 2m 11s
# 460:	learn: 0.5009435	total: 39.4s	remaining: 2m 11s
# 461:	learn: 0.5009243	total: 39.5s	remaining: 2m 11s
# 462:	learn: 0.5009042	total: 39.5s	remaining: 2m 11s
# 463:	learn: 0.5008878	total: 39.6s	remaining: 2m 11s
# 464:	learn: 0.5008647	total: 39.7s	remaining: 2m 11s
# 465:	learn: 0.5008466	total: 39.8s	remaining: 2m 11s
# 466:	learn: 0.5008298	total: 39.9s	remaining: 2m 11s
# 467:	learn: 0.5008124	total: 40s	remaining: 2m 10s
# 468:	learn: 0.5007961	total: 40.1s	remaining: 2m 10s
# 469:	learn: 0.5007760	total: 40.1s	remaining: 2m 10s
# 470:	learn: 0.5007558	total: 40.2s	remaining: 2m 10s
# 471:	learn: 0.5007323	total: 40.3s	remaining: 2m 10s
# 472:	learn: 0.5007118	total: 40.4s	remaining: 2m 10s
# 473:	learn: 0.5006924	total: 40.5s	remaining: 2m 10s
# 474:	learn: 0.5006698	total: 40.6s	remaining: 2m 10s
# 475:	learn: 0.5006503	total: 40.7s	remaining: 2m 10s
# 476:	learn: 0.5006289	total: 40.8s	remaining: 2m 10s
# 477:	learn: 0.5006109	total: 40.8s	remaining: 2m 10s
# 478:	learn: 0.5005878	total: 40.9s	remaining: 2m 9s
# 479:	learn: 0.5005730	total: 41s	remaining: 2m 9s
# 480:	learn: 0.5005564	total: 41.1s	remaining: 2m 9s
# 481:	learn: 0.5005382	total: 41.2s	remaining: 2m 9s
# 482:	learn: 0.5005185	total: 41.3s	remaining: 2m 9s
# 483:	learn: 0.5004967	total: 41.4s	remaining: 2m 9s
# 484:	learn: 0.5004830	total: 41.4s	remaining: 2m 9s
# 485:	learn: 0.5004650	total: 41.5s	remaining: 2m 9s
# 486:	learn: 0.5004454	total: 41.6s	remaining: 2m 9s
# 487:	learn: 0.5004271	total: 41.7s	remaining: 2m 9s
# 488:	learn: 0.5004076	total: 41.8s	remaining: 2m 9s
# 489:	learn: 0.5003899	total: 41.9s	remaining: 2m 8s
# 490:	learn: 0.5003690	total: 41.9s	remaining: 2m 8s
# 491:	learn: 0.5003488	total: 42s	remaining: 2m 8s
# 492:	learn: 0.5003276	total: 42.1s	remaining: 2m 8s
# 493:	learn: 0.5003057	total: 42.2s	remaining: 2m 8s
# 494:	learn: 0.5002840	total: 42.3s	remaining: 2m 8s
# 495:	learn: 0.5002663	total: 42.4s	remaining: 2m 8s
# 496:	learn: 0.5002455	total: 42.4s	remaining: 2m 8s
# 497:	learn: 0.5002264	total: 42.5s	remaining: 2m 8s
# 498:	learn: 0.5002086	total: 42.6s	remaining: 2m 8s
# 499:	learn: 0.5001915	total: 42.7s	remaining: 2m 8s
# 500:	learn: 0.5001698	total: 42.8s	remaining: 2m 8s
# 501:	learn: 0.5001496	total: 42.9s	remaining: 2m 7s
# 502:	learn: 0.5001296	total: 43s	remaining: 2m 7s
# 503:	learn: 0.5001093	total: 43.1s	remaining: 2m 7s
# 504:	learn: 0.5000884	total: 43.1s	remaining: 2m 7s
# 505:	learn: 0.5000722	total: 43.2s	remaining: 2m 7s
# 506:	learn: 0.5000548	total: 43.3s	remaining: 2m 7s
# 507:	learn: 0.5000364	total: 43.4s	remaining: 2m 7s
# 508:	learn: 0.5000175	total: 43.5s	remaining: 2m 7s
# 509:	learn: 0.4999997	total: 43.6s	remaining: 2m 7s
# 510:	learn: 0.4999802	total: 43.6s	remaining: 2m 7s
# 511:	learn: 0.4999646	total: 43.7s	remaining: 2m 7s
# 512:	learn: 0.4999467	total: 43.8s	remaining: 2m 7s
# 513:	learn: 0.4999268	total: 43.9s	remaining: 2m 6s
# 514:	learn: 0.4999079	total: 44s	remaining: 2m 6s
# 515:	learn: 0.4998899	total: 44.1s	remaining: 2m 6s
# 516:	learn: 0.4998684	total: 44.1s	remaining: 2m 6s
# 517:	learn: 0.4998453	total: 44.2s	remaining: 2m 6s
# 518:	learn: 0.4998265	total: 44.3s	remaining: 2m 6s
# 519:	learn: 0.4998077	total: 44.4s	remaining: 2m 6s
# 520:	learn: 0.4997899	total: 44.5s	remaining: 2m 6s
# 521:	learn: 0.4997724	total: 44.6s	remaining: 2m 6s
# 522:	learn: 0.4997530	total: 44.7s	remaining: 2m 6s
# 523:	learn: 0.4997325	total: 44.7s	remaining: 2m 6s
# 524:	learn: 0.4997129	total: 44.8s	remaining: 2m 5s
# 525:	learn: 0.4996953	total: 44.9s	remaining: 2m 5s
# 526:	learn: 0.4996750	total: 45s	remaining: 2m 5s
# 527:	learn: 0.4996549	total: 45.1s	remaining: 2m 5s
# 528:	learn: 0.4996339	total: 45.2s	remaining: 2m 5s
# 529:	learn: 0.4996149	total: 45.3s	remaining: 2m 5s
# 530:	learn: 0.4995935	total: 45.4s	remaining: 2m 5s
# 531:	learn: 0.4995736	total: 45.4s	remaining: 2m 5s
# 532:	learn: 0.4995556	total: 45.5s	remaining: 2m 5s
# 533:	learn: 0.4995362	total: 45.6s	remaining: 2m 5s
# 534:	learn: 0.4995195	total: 45.7s	remaining: 2m 5s
# 535:	learn: 0.4995004	total: 45.8s	remaining: 2m 5s
# 536:	learn: 0.4994784	total: 45.9s	remaining: 2m 4s
# 537:	learn: 0.4994615	total: 45.9s	remaining: 2m 4s
# 538:	learn: 0.4994416	total: 46s	remaining: 2m 4s
# 539:	learn: 0.4994237	total: 46.1s	remaining: 2m 4s
# 540:	learn: 0.4994022	total: 46.2s	remaining: 2m 4s
# 541:	learn: 0.4993837	total: 46.3s	remaining: 2m 4s
# 542:	learn: 0.4993653	total: 46.4s	remaining: 2m 4s
# 543:	learn: 0.4993497	total: 46.5s	remaining: 2m 4s
# 544:	learn: 0.4993299	total: 46.5s	remaining: 2m 4s
# 545:	learn: 0.4993100	total: 46.6s	remaining: 2m 4s
# 546:	learn: 0.4992901	total: 46.7s	remaining: 2m 4s
# 547:	learn: 0.4992703	total: 46.8s	remaining: 2m 3s
# 548:	learn: 0.4992545	total: 46.9s	remaining: 2m 3s
# 549:	learn: 0.4992362	total: 47s	remaining: 2m 3s
# 550:	learn: 0.4992154	total: 47s	remaining: 2m 3s
# 551:	learn: 0.4991927	total: 47.1s	remaining: 2m 3s
# 552:	learn: 0.4991751	total: 47.2s	remaining: 2m 3s
# 553:	learn: 0.4991574	total: 47.3s	remaining: 2m 3s
# 554:	learn: 0.4991370	total: 47.4s	remaining: 2m 3s
# 555:	learn: 0.4991170	total: 47.5s	remaining: 2m 3s
# 556:	learn: 0.4990983	total: 47.5s	remaining: 2m 3s
# 557:	learn: 0.4990791	total: 47.6s	remaining: 2m 3s
# 558:	learn: 0.4990592	total: 47.7s	remaining: 2m 2s
# 559:	learn: 0.4990414	total: 47.8s	remaining: 2m 2s
# 560:	learn: 0.4990251	total: 47.9s	remaining: 2m 2s
# 561:	learn: 0.4990061	total: 48s	remaining: 2m 2s
# 562:	learn: 0.4989878	total: 48.1s	remaining: 2m 2s
# 563:	learn: 0.4989660	total: 48.1s	remaining: 2m 2s
# 564:	learn: 0.4989472	total: 48.2s	remaining: 2m 2s
# 565:	learn: 0.4989291	total: 48.3s	remaining: 2m 2s
# 566:	learn: 0.4989091	total: 48.4s	remaining: 2m 2s
# 567:	learn: 0.4988899	total: 48.5s	remaining: 2m 2s
# 568:	learn: 0.4988699	total: 48.6s	remaining: 2m 2s
# 569:	learn: 0.4988494	total: 48.6s	remaining: 2m 2s
# 570:	learn: 0.4988280	total: 48.7s	remaining: 2m 1s
# 571:	learn: 0.4988083	total: 48.8s	remaining: 2m 1s
# 572:	learn: 0.4987918	total: 48.9s	remaining: 2m 1s
# 573:	learn: 0.4987760	total: 49s	remaining: 2m 1s
# 574:	learn: 0.4987560	total: 49.1s	remaining: 2m 1s
# 575:	learn: 0.4987379	total: 49.2s	remaining: 2m 1s
# 576:	learn: 0.4987197	total: 49.3s	remaining: 2m 1s
# 577:	learn: 0.4986987	total: 49.3s	remaining: 2m 1s
# 578:	learn: 0.4986798	total: 49.4s	remaining: 2m 1s
# 579:	learn: 0.4986581	total: 49.5s	remaining: 2m 1s
# 580:	learn: 0.4986404	total: 49.6s	remaining: 2m 1s
# 581:	learn: 0.4986242	total: 49.7s	remaining: 2m 1s
# 582:	learn: 0.4986042	total: 49.8s	remaining: 2m
# 583:	learn: 0.4985852	total: 49.8s	remaining: 2m
# 584:	learn: 0.4985703	total: 49.9s	remaining: 2m
# 585:	learn: 0.4985512	total: 50s	remaining: 2m
# 586:	learn: 0.4985311	total: 50.1s	remaining: 2m
# 587:	learn: 0.4985123	total: 50.2s	remaining: 2m
# 588:	learn: 0.4984932	total: 50.3s	remaining: 2m
# 589:	learn: 0.4984745	total: 50.4s	remaining: 2m
# 590:	learn: 0.4984548	total: 50.4s	remaining: 2m
# 591:	learn: 0.4984346	total: 50.5s	remaining: 2m
# 592:	learn: 0.4984179	total: 50.6s	remaining: 2m
# 593:	learn: 0.4983994	total: 50.7s	remaining: 1m 59s
# 594:	learn: 0.4983789	total: 50.8s	remaining: 1m 59s
# 595:	learn: 0.4983622	total: 50.9s	remaining: 1m 59s
# 596:	learn: 0.4983436	total: 50.9s	remaining: 1m 59s
# 597:	learn: 0.4983235	total: 51s	remaining: 1m 59s
# 598:	learn: 0.4983029	total: 51.1s	remaining: 1m 59s
# 599:	learn: 0.4982865	total: 51.2s	remaining: 1m 59s
# 600:	learn: 0.4982681	total: 51.3s	remaining: 1m 59s
# 601:	learn: 0.4982471	total: 51.4s	remaining: 1m 59s
# 602:	learn: 0.4982302	total: 51.4s	remaining: 1m 59s
# 603:	learn: 0.4982117	total: 51.5s	remaining: 1m 59s
# 604:	learn: 0.4981944	total: 51.6s	remaining: 1m 58s
# 605:	learn: 0.4981754	total: 51.7s	remaining: 1m 58s
# 606:	learn: 0.4981573	total: 51.8s	remaining: 1m 58s
# 607:	learn: 0.4981395	total: 51.9s	remaining: 1m 58s
# 608:	learn: 0.4981186	total: 52s	remaining: 1m 58s
# 609:	learn: 0.4980992	total: 52s	remaining: 1m 58s
# 610:	learn: 0.4980771	total: 52.1s	remaining: 1m 58s
# 611:	learn: 0.4980598	total: 52.2s	remaining: 1m 58s
# 612:	learn: 0.4980393	total: 52.3s	remaining: 1m 58s
# 613:	learn: 0.4980204	total: 52.4s	remaining: 1m 58s
# 614:	learn: 0.4980003	total: 52.5s	remaining: 1m 58s
# 615:	learn: 0.4979831	total: 52.5s	remaining: 1m 58s
# 616:	learn: 0.4979633	total: 52.6s	remaining: 1m 57s
# 617:	learn: 0.4979451	total: 52.7s	remaining: 1m 57s
# 618:	learn: 0.4979303	total: 52.8s	remaining: 1m 57s
# 619:	learn: 0.4979137	total: 52.9s	remaining: 1m 57s
# 620:	learn: 0.4978922	total: 53s	remaining: 1m 57s
# 621:	learn: 0.4978763	total: 53s	remaining: 1m 57s
# 622:	learn: 0.4978591	total: 53.1s	remaining: 1m 57s
# 623:	learn: 0.4978380	total: 53.2s	remaining: 1m 57s
# 624:	learn: 0.4978211	total: 53.3s	remaining: 1m 57s
# 625:	learn: 0.4978025	total: 53.4s	remaining: 1m 57s
# 626:	learn: 0.4977848	total: 53.5s	remaining: 1m 57s
# 627:	learn: 0.4977642	total: 53.6s	remaining: 1m 57s
# 628:	learn: 0.4977463	total: 53.7s	remaining: 1m 56s
# 629:	learn: 0.4977260	total: 53.7s	remaining: 1m 56s
# 630:	learn: 0.4977057	total: 53.8s	remaining: 1m 56s
# 631:	learn: 0.4976850	total: 53.9s	remaining: 1m 56s
# 632:	learn: 0.4976693	total: 54s	remaining: 1m 56s
# 633:	learn: 0.4976501	total: 54.1s	remaining: 1m 56s
# 634:	learn: 0.4976318	total: 54.2s	remaining: 1m 56s
# 635:	learn: 0.4976165	total: 54.3s	remaining: 1m 56s
# 636:	learn: 0.4975961	total: 54.3s	remaining: 1m 56s
# 637:	learn: 0.4975746	total: 54.4s	remaining: 1m 56s
# 638:	learn: 0.4975590	total: 54.5s	remaining: 1m 56s
# 639:	learn: 0.4975443	total: 54.6s	remaining: 1m 56s
# 640:	learn: 0.4975231	total: 54.7s	remaining: 1m 55s
# 641:	learn: 0.4975046	total: 54.8s	remaining: 1m 55s
# 642:	learn: 0.4974849	total: 54.9s	remaining: 1m 55s
# 643:	learn: 0.4974669	total: 55s	remaining: 1m 55s
# 644:	learn: 0.4974483	total: 55s	remaining: 1m 55s
# 645:	learn: 0.4974273	total: 55.1s	remaining: 1m 55s
# 646:	learn: 0.4974088	total: 55.2s	remaining: 1m 55s
# 647:	learn: 0.4973882	total: 55.3s	remaining: 1m 55s
# 648:	learn: 0.4973716	total: 55.4s	remaining: 1m 55s
# 649:	learn: 0.4973529	total: 55.5s	remaining: 1m 55s
# 650:	learn: 0.4973361	total: 55.5s	remaining: 1m 55s
# 651:	learn: 0.4973162	total: 55.6s	remaining: 1m 55s
# 652:	learn: 0.4972995	total: 55.7s	remaining: 1m 54s
# 653:	learn: 0.4972812	total: 55.8s	remaining: 1m 54s
# 654:	learn: 0.4972667	total: 55.9s	remaining: 1m 54s
# 655:	learn: 0.4972450	total: 56s	remaining: 1m 54s
# 656:	learn: 0.4972266	total: 56.1s	remaining: 1m 54s
# 657:	learn: 0.4972070	total: 56.1s	remaining: 1m 54s
# 658:	learn: 0.4971872	total: 56.2s	remaining: 1m 54s
# 659:	learn: 0.4971680	total: 56.3s	remaining: 1m 54s
# 660:	learn: 0.4971489	total: 56.4s	remaining: 1m 54s
# 661:	learn: 0.4971309	total: 56.5s	remaining: 1m 54s
# 662:	learn: 0.4971123	total: 56.6s	remaining: 1m 54s
# 663:	learn: 0.4970941	total: 56.7s	remaining: 1m 54s
# 664:	learn: 0.4970744	total: 56.8s	remaining: 1m 53s
# 665:	learn: 0.4970574	total: 56.8s	remaining: 1m 53s
# 666:	learn: 0.4970398	total: 56.9s	remaining: 1m 53s
# 667:	learn: 0.4970190	total: 57s	remaining: 1m 53s
# 668:	learn: 0.4970001	total: 57.1s	remaining: 1m 53s
# 669:	learn: 0.4969817	total: 57.2s	remaining: 1m 53s
# 670:	learn: 0.4969648	total: 57.3s	remaining: 1m 53s
# 671:	learn: 0.4969434	total: 57.4s	remaining: 1m 53s
# 672:	learn: 0.4969265	total: 57.5s	remaining: 1m 53s
# 673:	learn: 0.4969092	total: 57.5s	remaining: 1m 53s
# 674:	learn: 0.4968903	total: 57.6s	remaining: 1m 53s
# 675:	learn: 0.4968707	total: 57.7s	remaining: 1m 53s
# 676:	learn: 0.4968529	total: 57.8s	remaining: 1m 52s
# 677:	learn: 0.4968370	total: 57.9s	remaining: 1m 52s
# 678:	learn: 0.4968179	total: 58s	remaining: 1m 52s
# 679:	learn: 0.4967962	total: 58.1s	remaining: 1m 52s
# 680:	learn: 0.4967785	total: 58.2s	remaining: 1m 52s
# 681:	learn: 0.4967604	total: 58.2s	remaining: 1m 52s
# 682:	learn: 0.4967402	total: 58.3s	remaining: 1m 52s
# 683:	learn: 0.4967209	total: 58.4s	remaining: 1m 52s
# 684:	learn: 0.4967015	total: 58.5s	remaining: 1m 52s
# 685:	learn: 0.4966838	total: 58.6s	remaining: 1m 52s
# 686:	learn: 0.4966646	total: 58.7s	remaining: 1m 52s
# 687:	learn: 0.4966477	total: 58.7s	remaining: 1m 52s
# 688:	learn: 0.4966309	total: 58.8s	remaining: 1m 51s
# 689:	learn: 0.4966107	total: 58.9s	remaining: 1m 51s
# 690:	learn: 0.4965904	total: 59s	remaining: 1m 51s
# 691:	learn: 0.4965722	total: 59.1s	remaining: 1m 51s
# 692:	learn: 0.4965518	total: 59.2s	remaining: 1m 51s
# 693:	learn: 0.4965355	total: 59.3s	remaining: 1m 51s
# 694:	learn: 0.4965155	total: 59.4s	remaining: 1m 51s
# 695:	learn: 0.4964959	total: 59.4s	remaining: 1m 51s
# 696:	learn: 0.4964769	total: 59.5s	remaining: 1m 51s
# 697:	learn: 0.4964576	total: 59.6s	remaining: 1m 51s
# 698:	learn: 0.4964424	total: 59.7s	remaining: 1m 51s
# 699:	learn: 0.4964235	total: 59.8s	remaining: 1m 51s
# 700:	learn: 0.4964042	total: 59.9s	remaining: 1m 50s
# 701:	learn: 0.4963849	total: 60s	remaining: 1m 50s
# 702:	learn: 0.4963667	total: 1m	remaining: 1m 50s
# 703:	learn: 0.4963489	total: 1m	remaining: 1m 50s
# 704:	learn: 0.4963310	total: 1m	remaining: 1m 50s
# 705:	learn: 0.4963117	total: 1m	remaining: 1m 50s
# 706:	learn: 0.4962913	total: 1m	remaining: 1m 50s
# 707:	learn: 0.4962781	total: 1m	remaining: 1m 50s
# 708:	learn: 0.4962567	total: 1m	remaining: 1m 50s
# 709:	learn: 0.4962369	total: 1m	remaining: 1m 50s
# 710:	learn: 0.4962172	total: 1m	remaining: 1m 50s
# 711:	learn: 0.4961993	total: 1m	remaining: 1m 49s
# 712:	learn: 0.4961818	total: 1m	remaining: 1m 49s
# 713:	learn: 0.4961632	total: 1m	remaining: 1m 49s
# 714:	learn: 0.4961440	total: 1m 1s	remaining: 1m 49s
# 715:	learn: 0.4961254	total: 1m 1s	remaining: 1m 49s
# 716:	learn: 0.4961077	total: 1m 1s	remaining: 1m 49s
# 717:	learn: 0.4960893	total: 1m 1s	remaining: 1m 49s
# 718:	learn: 0.4960713	total: 1m 1s	remaining: 1m 49s
# 719:	learn: 0.4960513	total: 1m 1s	remaining: 1m 49s
# 720:	learn: 0.4960317	total: 1m 1s	remaining: 1m 49s
# 721:	learn: 0.4960116	total: 1m 1s	remaining: 1m 49s
# 722:	learn: 0.4959909	total: 1m 1s	remaining: 1m 49s
# 723:	learn: 0.4959695	total: 1m 1s	remaining: 1m 48s
# 724:	learn: 0.4959515	total: 1m 1s	remaining: 1m 48s
# 725:	learn: 0.4959324	total: 1m 1s	remaining: 1m 48s
# 726:	learn: 0.4959121	total: 1m 2s	remaining: 1m 48s
# 727:	learn: 0.4958921	total: 1m 2s	remaining: 1m 48s
# 728:	learn: 0.4958731	total: 1m 2s	remaining: 1m 48s
# 729:	learn: 0.4958522	total: 1m 2s	remaining: 1m 48s
# 730:	learn: 0.4958328	total: 1m 2s	remaining: 1m 48s
# 731:	learn: 0.4958159	total: 1m 2s	remaining: 1m 48s
# 732:	learn: 0.4957940	total: 1m 2s	remaining: 1m 48s
# 733:	learn: 0.4957782	total: 1m 2s	remaining: 1m 48s
# 734:	learn: 0.4957612	total: 1m 2s	remaining: 1m 47s
# 735:	learn: 0.4957435	total: 1m 2s	remaining: 1m 47s
# 736:	learn: 0.4957264	total: 1m 2s	remaining: 1m 47s
# 737:	learn: 0.4957067	total: 1m 3s	remaining: 1m 47s
# 738:	learn: 0.4956903	total: 1m 3s	remaining: 1m 47s
# 739:	learn: 0.4956732	total: 1m 3s	remaining: 1m 47s
# 740:	learn: 0.4956522	total: 1m 3s	remaining: 1m 47s
# 741:	learn: 0.4956357	total: 1m 3s	remaining: 1m 47s
# 742:	learn: 0.4956180	total: 1m 3s	remaining: 1m 47s
# 743:	learn: 0.4956004	total: 1m 3s	remaining: 1m 47s
# 744:	learn: 0.4955808	total: 1m 3s	remaining: 1m 47s
# 745:	learn: 0.4955639	total: 1m 3s	remaining: 1m 47s
# 746:	learn: 0.4955473	total: 1m 3s	remaining: 1m 46s
# 747:	learn: 0.4955293	total: 1m 3s	remaining: 1m 46s
# 748:	learn: 0.4955114	total: 1m 3s	remaining: 1m 46s
# 749:	learn: 0.4954917	total: 1m 4s	remaining: 1m 46s
# 750:	learn: 0.4954743	total: 1m 4s	remaining: 1m 46s
# 751:	learn: 0.4954566	total: 1m 4s	remaining: 1m 46s
# 752:	learn: 0.4954388	total: 1m 4s	remaining: 1m 46s
# 753:	learn: 0.4954213	total: 1m 4s	remaining: 1m 46s
# 754:	learn: 0.4954064	total: 1m 4s	remaining: 1m 46s
# 755:	learn: 0.4953874	total: 1m 4s	remaining: 1m 46s
# 756:	learn: 0.4953684	total: 1m 4s	remaining: 1m 46s
# 757:	learn: 0.4953499	total: 1m 4s	remaining: 1m 46s
# 758:	learn: 0.4953307	total: 1m 4s	remaining: 1m 46s
# 759:	learn: 0.4953136	total: 1m 4s	remaining: 1m 45s
# 760:	learn: 0.4952958	total: 1m 5s	remaining: 1m 45s
# 761:	learn: 0.4952767	total: 1m 5s	remaining: 1m 45s
# 762:	learn: 0.4952575	total: 1m 5s	remaining: 1m 45s
# 763:	learn: 0.4952385	total: 1m 5s	remaining: 1m 45s
# 764:	learn: 0.4952170	total: 1m 5s	remaining: 1m 45s
# 765:	learn: 0.4951987	total: 1m 5s	remaining: 1m 45s
# 766:	learn: 0.4951811	total: 1m 5s	remaining: 1m 45s
# 767:	learn: 0.4951610	total: 1m 5s	remaining: 1m 45s
# 768:	learn: 0.4951452	total: 1m 5s	remaining: 1m 45s
# 769:	learn: 0.4951292	total: 1m 5s	remaining: 1m 45s
# 770:	learn: 0.4951107	total: 1m 5s	remaining: 1m 45s
# 771:	learn: 0.4950912	total: 1m 6s	remaining: 1m 45s
# 772:	learn: 0.4950729	total: 1m 6s	remaining: 1m 45s
# 773:	learn: 0.4950558	total: 1m 6s	remaining: 1m 44s
# 774:	learn: 0.4950376	total: 1m 6s	remaining: 1m 44s
# 775:	learn: 0.4950204	total: 1m 6s	remaining: 1m 44s
# 776:	learn: 0.4950005	total: 1m 6s	remaining: 1m 44s
# 777:	learn: 0.4949848	total: 1m 6s	remaining: 1m 44s
# 778:	learn: 0.4949694	total: 1m 6s	remaining: 1m 44s
# 779:	learn: 0.4949499	total: 1m 6s	remaining: 1m 44s
# 780:	learn: 0.4949331	total: 1m 6s	remaining: 1m 44s
# 781:	learn: 0.4949150	total: 1m 6s	remaining: 1m 44s
# 782:	learn: 0.4948976	total: 1m 6s	remaining: 1m 44s
# 783:	learn: 0.4948777	total: 1m 7s	remaining: 1m 44s
# 784:	learn: 0.4948585	total: 1m 7s	remaining: 1m 43s
# 785:	learn: 0.4948401	total: 1m 7s	remaining: 1m 43s
# 786:	learn: 0.4948223	total: 1m 7s	remaining: 1m 43s
# 787:	learn: 0.4948058	total: 1m 7s	remaining: 1m 43s
# 788:	learn: 0.4947876	total: 1m 7s	remaining: 1m 43s
# 789:	learn: 0.4947695	total: 1m 7s	remaining: 1m 43s
# 790:	learn: 0.4947507	total: 1m 7s	remaining: 1m 43s
# 791:	learn: 0.4947315	total: 1m 7s	remaining: 1m 43s
# 792:	learn: 0.4947143	total: 1m 7s	remaining: 1m 43s
# 793:	learn: 0.4946932	total: 1m 7s	remaining: 1m 43s
# 794:	learn: 0.4946767	total: 1m 8s	remaining: 1m 43s
# 795:	learn: 0.4946598	total: 1m 8s	remaining: 1m 43s
# 796:	learn: 0.4946413	total: 1m 8s	remaining: 1m 42s
# 797:	learn: 0.4946195	total: 1m 8s	remaining: 1m 42s
# 798:	learn: 0.4946019	total: 1m 8s	remaining: 1m 42s
# 799:	learn: 0.4945827	total: 1m 8s	remaining: 1m 42s
# 800:	learn: 0.4945634	total: 1m 8s	remaining: 1m 42s
# 801:	learn: 0.4945442	total: 1m 8s	remaining: 1m 42s
# 802:	learn: 0.4945254	total: 1m 8s	remaining: 1m 42s
# 803:	learn: 0.4945084	total: 1m 8s	remaining: 1m 42s
# 804:	learn: 0.4944910	total: 1m 8s	remaining: 1m 42s
# 805:	learn: 0.4944734	total: 1m 9s	remaining: 1m 42s
# 806:	learn: 0.4944539	total: 1m 9s	remaining: 1m 42s
# 807:	learn: 0.4944333	total: 1m 9s	remaining: 1m 42s
# 808:	learn: 0.4944133	total: 1m 9s	remaining: 1m 42s
# 809:	learn: 0.4943933	total: 1m 9s	remaining: 1m 42s
# 810:	learn: 0.4943745	total: 1m 9s	remaining: 1m 41s
# 811:	learn: 0.4943553	total: 1m 9s	remaining: 1m 41s
# 812:	learn: 0.4943361	total: 1m 9s	remaining: 1m 41s
# 813:	learn: 0.4943187	total: 1m 9s	remaining: 1m 41s
# 814:	learn: 0.4942968	total: 1m 9s	remaining: 1m 41s
# 815:	learn: 0.4942800	total: 1m 10s	remaining: 1m 41s
# 816:	learn: 0.4942604	total: 1m 10s	remaining: 1m 41s
# 817:	learn: 0.4942416	total: 1m 10s	remaining: 1m 41s
# 818:	learn: 0.4942249	total: 1m 10s	remaining: 1m 41s
# 819:	learn: 0.4942062	total: 1m 10s	remaining: 1m 41s
# 820:	learn: 0.4941861	total: 1m 10s	remaining: 1m 41s
# 821:	learn: 0.4941681	total: 1m 10s	remaining: 1m 41s
# 822:	learn: 0.4941488	total: 1m 10s	remaining: 1m 41s
# 823:	learn: 0.4941283	total: 1m 10s	remaining: 1m 41s
# 824:	learn: 0.4941077	total: 1m 10s	remaining: 1m 40s
# 825:	learn: 0.4940923	total: 1m 10s	remaining: 1m 40s
# 826:	learn: 0.4940744	total: 1m 11s	remaining: 1m 40s
# 827:	learn: 0.4940602	total: 1m 11s	remaining: 1m 40s
# 828:	learn: 0.4940411	total: 1m 11s	remaining: 1m 40s
# 829:	learn: 0.4940240	total: 1m 11s	remaining: 1m 40s
# 830:	learn: 0.4940070	total: 1m 11s	remaining: 1m 40s
# 831:	learn: 0.4939901	total: 1m 11s	remaining: 1m 40s
# 832:	learn: 0.4939716	total: 1m 11s	remaining: 1m 40s
# 833:	learn: 0.4939532	total: 1m 11s	remaining: 1m 40s
# 834:	learn: 0.4939370	total: 1m 11s	remaining: 1m 40s
# 835:	learn: 0.4939236	total: 1m 12s	remaining: 1m 40s
# 836:	learn: 0.4939036	total: 1m 12s	remaining: 1m 40s
# 837:	learn: 0.4938860	total: 1m 12s	remaining: 1m 40s
# 838:	learn: 0.4938685	total: 1m 12s	remaining: 1m 40s
# 839:	learn: 0.4938503	total: 1m 12s	remaining: 1m 39s
# 840:	learn: 0.4938314	total: 1m 12s	remaining: 1m 39s
# 841:	learn: 0.4938114	total: 1m 12s	remaining: 1m 39s
# 842:	learn: 0.4937909	total: 1m 12s	remaining: 1m 39s
# 843:	learn: 0.4937731	total: 1m 12s	remaining: 1m 39s
# 844:	learn: 0.4937575	total: 1m 12s	remaining: 1m 39s
# 845:	learn: 0.4937406	total: 1m 12s	remaining: 1m 39s
# 846:	learn: 0.4937238	total: 1m 12s	remaining: 1m 39s
# 847:	learn: 0.4937043	total: 1m 13s	remaining: 1m 39s
# 848:	learn: 0.4936832	total: 1m 13s	remaining: 1m 39s
# 849:	learn: 0.4936662	total: 1m 13s	remaining: 1m 39s
# 850:	learn: 0.4936478	total: 1m 13s	remaining: 1m 39s
# 851:	learn: 0.4936303	total: 1m 13s	remaining: 1m 38s
# 852:	learn: 0.4936110	total: 1m 13s	remaining: 1m 38s
# 853:	learn: 0.4935962	total: 1m 13s	remaining: 1m 38s
# 854:	learn: 0.4935758	total: 1m 13s	remaining: 1m 38s
# 855:	learn: 0.4935599	total: 1m 13s	remaining: 1m 38s
# 856:	learn: 0.4935364	total: 1m 13s	remaining: 1m 38s
# 857:	learn: 0.4935204	total: 1m 13s	remaining: 1m 38s
# 858:	learn: 0.4935018	total: 1m 14s	remaining: 1m 38s
# 859:	learn: 0.4934841	total: 1m 14s	remaining: 1m 38s
# 860:	learn: 0.4934637	total: 1m 14s	remaining: 1m 38s
# 861:	learn: 0.4934430	total: 1m 14s	remaining: 1m 38s
# 862:	learn: 0.4934226	total: 1m 14s	remaining: 1m 38s
# 863:	learn: 0.4934051	total: 1m 14s	remaining: 1m 37s
# 864:	learn: 0.4933830	total: 1m 14s	remaining: 1m 37s
# 865:	learn: 0.4933656	total: 1m 14s	remaining: 1m 37s
# 866:	learn: 0.4933459	total: 1m 14s	remaining: 1m 37s
# 867:	learn: 0.4933261	total: 1m 14s	remaining: 1m 37s
# 868:	learn: 0.4933054	total: 1m 14s	remaining: 1m 37s
# 869:	learn: 0.4932854	total: 1m 15s	remaining: 1m 37s
# 870:	learn: 0.4932672	total: 1m 15s	remaining: 1m 37s
# 871:	learn: 0.4932461	total: 1m 15s	remaining: 1m 37s
# 872:	learn: 0.4932319	total: 1m 15s	remaining: 1m 37s
# 873:	learn: 0.4932133	total: 1m 15s	remaining: 1m 37s
# 874:	learn: 0.4931942	total: 1m 15s	remaining: 1m 37s
# 875:	learn: 0.4931769	total: 1m 15s	remaining: 1m 36s
# 876:	learn: 0.4931605	total: 1m 15s	remaining: 1m 36s
# 877:	learn: 0.4931470	total: 1m 15s	remaining: 1m 36s
# 878:	learn: 0.4931286	total: 1m 15s	remaining: 1m 36s
# 879:	learn: 0.4931094	total: 1m 15s	remaining: 1m 36s
# 880:	learn: 0.4930910	total: 1m 15s	remaining: 1m 36s
# 881:	learn: 0.4930740	total: 1m 16s	remaining: 1m 36s
# 882:	learn: 0.4930570	total: 1m 16s	remaining: 1m 36s
# 883:	learn: 0.4930378	total: 1m 16s	remaining: 1m 36s
# 884:	learn: 0.4930199	total: 1m 16s	remaining: 1m 36s
# 885:	learn: 0.4930041	total: 1m 16s	remaining: 1m 36s
# 886:	learn: 0.4929863	total: 1m 16s	remaining: 1m 36s
# 887:	learn: 0.4929706	total: 1m 16s	remaining: 1m 35s
# 888:	learn: 0.4929552	total: 1m 16s	remaining: 1m 35s
# 889:	learn: 0.4929375	total: 1m 16s	remaining: 1m 35s
# 890:	learn: 0.4929181	total: 1m 16s	remaining: 1m 35s
# 891:	learn: 0.4928989	total: 1m 16s	remaining: 1m 35s
# 892:	learn: 0.4928804	total: 1m 17s	remaining: 1m 35s
# 893:	learn: 0.4928642	total: 1m 17s	remaining: 1m 35s
# 894:	learn: 0.4928452	total: 1m 17s	remaining: 1m 35s
# 895:	learn: 0.4928310	total: 1m 17s	remaining: 1m 35s
# 896:	learn: 0.4928120	total: 1m 17s	remaining: 1m 35s
# 897:	learn: 0.4927974	total: 1m 17s	remaining: 1m 35s
# 898:	learn: 0.4927787	total: 1m 17s	remaining: 1m 34s
# 899:	learn: 0.4927620	total: 1m 17s	remaining: 1m 34s
# 900:	learn: 0.4927482	total: 1m 17s	remaining: 1m 34s
# 901:	learn: 0.4927295	total: 1m 17s	remaining: 1m 34s
# 902:	learn: 0.4927121	total: 1m 17s	remaining: 1m 34s
# 903:	learn: 0.4926914	total: 1m 17s	remaining: 1m 34s
# 904:	learn: 0.4926729	total: 1m 18s	remaining: 1m 34s
# 905:	learn: 0.4926558	total: 1m 18s	remaining: 1m 34s
# 906:	learn: 0.4926401	total: 1m 18s	remaining: 1m 34s
# ...
# 1705:	learn: 0.4794163	total: 2m 29s	remaining: 25.7s
# 1706:	learn: 0.4793975	total: 2m 29s	remaining: 25.6s
# 1707:	learn: 0.4793802	total: 2m 29s	remaining: 25.5s
# 1708:	learn: 0.4793648	total: 2m 29s	remaining: 25.4s
# 1709:	learn: 0.4793453	total: 2m 29s	remaining: 25.3s
# 1710:	learn: 0.4793290	total: 2m 29s	remaining: 25.3s
# 1711:	learn: 0.4793126	total: 2m 29s	remaining: 25.2s
# 1712:	learn: 0.4792930	total: 2m 29s	remaining: 25.1s
# 1713:	learn: 0.4792790	total: 2m 29s	remaining: 25s
# 1714:	learn: 0.4792618	total: 2m 29s	remaining: 24.9s
# 1715:	learn: 0.4792465	total: 2m 29s	remaining: 24.8s
# 1716:	learn: 0.4792300	total: 2m 30s	remaining: 24.7s
# 1717:	learn: 0.4792146	total: 2m 30s	remaining: 24.6s
# 1718:	learn: 0.4791973	total: 2m 30s	remaining: 24.6s
# 1719:	learn: 0.4791786	total: 2m 30s	remaining: 24.5s
# 1720:	learn: 0.4791605	total: 2m 30s	remaining: 24.4s
# 1721:	learn: 0.4791442	total: 2m 30s	remaining: 24.3s
# 1722:	learn: 0.4791261	total: 2m 30s	remaining: 24.2s
# 1723:	learn: 0.4791081	total: 2m 30s	remaining: 24.1s
# 1724:	learn: 0.4790899	total: 2m 30s	remaining: 24s
# 1725:	learn: 0.4790715	total: 2m 30s	remaining: 23.9s
# 1726:	learn: 0.4790495	total: 2m 30s	remaining: 23.9s
# 1727:	learn: 0.4790326	total: 2m 31s	remaining: 23.8s
# 1728:	learn: 0.4790190	total: 2m 31s	remaining: 23.7s
# 1729:	learn: 0.4790008	total: 2m 31s	remaining: 23.6s
# 1730:	learn: 0.4789852	total: 2m 31s	remaining: 23.5s
# 1731:	learn: 0.4789673	total: 2m 31s	remaining: 23.4s
# 1732:	learn: 0.4789491	total: 2m 31s	remaining: 23.3s
# 1733:	learn: 0.4789331	total: 2m 31s	remaining: 23.2s
# 1734:	learn: 0.4789154	total: 2m 31s	remaining: 23.2s
# 1735:	learn: 0.4788967	total: 2m 31s	remaining: 23.1s
# 1736:	learn: 0.4788787	total: 2m 31s	remaining: 23s
# 1737:	learn: 0.4788639	total: 2m 31s	remaining: 22.9s
# 1738:	learn: 0.4788450	total: 2m 32s	remaining: 22.8s
# 1739:	learn: 0.4788315	total: 2m 32s	remaining: 22.7s
# 1740:	learn: 0.4788136	total: 2m 32s	remaining: 22.6s
# 1741:	learn: 0.4787944	total: 2m 32s	remaining: 22.6s
# 1742:	learn: 0.4787773	total: 2m 32s	remaining: 22.5s
# 1743:	learn: 0.4787600	total: 2m 32s	remaining: 22.4s
# 1744:	learn: 0.4787430	total: 2m 32s	remaining: 22.3s
# 1745:	learn: 0.4787267	total: 2m 32s	remaining: 22.2s
# 1746:	learn: 0.4787104	total: 2m 32s	remaining: 22.1s
# 1747:	learn: 0.4786928	total: 2m 32s	remaining: 22s
# 1748:	learn: 0.4786763	total: 2m 32s	remaining: 21.9s
# 1749:	learn: 0.4786589	total: 2m 32s	remaining: 21.9s
# 1750:	learn: 0.4786423	total: 2m 33s	remaining: 21.8s
# 1751:	learn: 0.4786250	total: 2m 33s	remaining: 21.7s
# 1752:	learn: 0.4786072	total: 2m 33s	remaining: 21.6s
# 1753:	learn: 0.4785901	total: 2m 33s	remaining: 21.5s
# 1754:	learn: 0.4785747	total: 2m 33s	remaining: 21.4s
# 1755:	learn: 0.4785581	total: 2m 33s	remaining: 21.3s
# 1756:	learn: 0.4785406	total: 2m 33s	remaining: 21.2s
# 1757:	learn: 0.4785268	total: 2m 33s	remaining: 21.2s
# 1758:	learn: 0.4785079	total: 2m 33s	remaining: 21.1s
# 1759:	learn: 0.4784910	total: 2m 33s	remaining: 21s
# 1760:	learn: 0.4784770	total: 2m 33s	remaining: 20.9s
# 1761:	learn: 0.4784591	total: 2m 34s	remaining: 20.8s
# 1762:	learn: 0.4784405	total: 2m 34s	remaining: 20.7s
# 1763:	learn: 0.4784218	total: 2m 34s	remaining: 20.6s
# 1764:	learn: 0.4784040	total: 2m 34s	remaining: 20.5s
# 1765:	learn: 0.4783896	total: 2m 34s	remaining: 20.5s
# 1766:	learn: 0.4783735	total: 2m 34s	remaining: 20.4s
# 1767:	learn: 0.4783575	total: 2m 34s	remaining: 20.3s
# 1768:	learn: 0.4783407	total: 2m 34s	remaining: 20.2s
# 1769:	learn: 0.4783233	total: 2m 34s	remaining: 20.1s
# 1770:	learn: 0.4783080	total: 2m 34s	remaining: 20s
# 1771:	learn: 0.4782905	total: 2m 34s	remaining: 19.9s
# 1772:	learn: 0.4782756	total: 2m 34s	remaining: 19.8s
# 1773:	learn: 0.4782618	total: 2m 35s	remaining: 19.8s
# 1774:	learn: 0.4782423	total: 2m 35s	remaining: 19.7s
# 1775:	learn: 0.4782260	total: 2m 35s	remaining: 19.6s
# 1776:	learn: 0.4782118	total: 2m 35s	remaining: 19.5s
# 1777:	learn: 0.4781956	total: 2m 35s	remaining: 19.4s
# 1778:	learn: 0.4781782	total: 2m 35s	remaining: 19.3s
# 1779:	learn: 0.4781648	total: 2m 35s	remaining: 19.2s
# 1780:	learn: 0.4781492	total: 2m 35s	remaining: 19.1s
# 1781:	learn: 0.4781317	total: 2m 35s	remaining: 19.1s
# 1782:	learn: 0.4781151	total: 2m 35s	remaining: 19s
# 1783:	learn: 0.4780986	total: 2m 35s	remaining: 18.9s
# 1784:	learn: 0.4780824	total: 2m 36s	remaining: 18.8s
# 1785:	learn: 0.4780641	total: 2m 36s	remaining: 18.7s
# 1786:	learn: 0.4780470	total: 2m 36s	remaining: 18.6s
# 1787:	learn: 0.4780310	total: 2m 36s	remaining: 18.5s
# 1788:	learn: 0.4780139	total: 2m 36s	remaining: 18.4s
# 1789:	learn: 0.4779987	total: 2m 36s	remaining: 18.4s
# 1790:	learn: 0.4779811	total: 2m 36s	remaining: 18.3s
# 1791:	learn: 0.4779631	total: 2m 36s	remaining: 18.2s
# 1792:	learn: 0.4779482	total: 2m 36s	remaining: 18.1s
# 1793:	learn: 0.4779303	total: 2m 36s	remaining: 18s
# 1794:	learn: 0.4779130	total: 2m 36s	remaining: 17.9s
# 1795:	learn: 0.4778949	total: 2m 36s	remaining: 17.8s
# 1796:	learn: 0.4778772	total: 2m 37s	remaining: 17.7s
# 1797:	learn: 0.4778619	total: 2m 37s	remaining: 17.7s
# 1798:	learn: 0.4778456	total: 2m 37s	remaining: 17.6s
# 1799:	learn: 0.4778350	total: 2m 37s	remaining: 17.5s
# 1800:	learn: 0.4778171	total: 2m 37s	remaining: 17.4s
# 1801:	learn: 0.4778001	total: 2m 37s	remaining: 17.3s
# 1802:	learn: 0.4777849	total: 2m 37s	remaining: 17.2s
# 1803:	learn: 0.4777660	total: 2m 37s	remaining: 17.1s
# 1804:	learn: 0.4777511	total: 2m 37s	remaining: 17s
# 1805:	learn: 0.4777336	total: 2m 37s	remaining: 17s
# 1806:	learn: 0.4777159	total: 2m 37s	remaining: 16.9s
# 1807:	learn: 0.4776994	total: 2m 38s	remaining: 16.8s
# 1808:	learn: 0.4776856	total: 2m 38s	remaining: 16.7s
# 1809:	learn: 0.4776678	total: 2m 38s	remaining: 16.6s
# 1810:	learn: 0.4776517	total: 2m 38s	remaining: 16.5s
# 1811:	learn: 0.4776335	total: 2m 38s	remaining: 16.4s
# 1812:	learn: 0.4776162	total: 2m 38s	remaining: 16.3s
# 1813:	learn: 0.4775977	total: 2m 38s	remaining: 16.3s
# 1814:	learn: 0.4775801	total: 2m 38s	remaining: 16.2s
# 1815:	learn: 0.4775631	total: 2m 38s	remaining: 16.1s
# 1816:	learn: 0.4775480	total: 2m 38s	remaining: 16s
# 1817:	learn: 0.4775284	total: 2m 38s	remaining: 15.9s
# 1818:	learn: 0.4775124	total: 2m 39s	remaining: 15.8s
# 1819:	learn: 0.4774935	total: 2m 39s	remaining: 15.7s
# 1820:	learn: 0.4774807	total: 2m 39s	remaining: 15.7s
# 1821:	learn: 0.4774652	total: 2m 39s	remaining: 15.6s
# 1822:	learn: 0.4774482	total: 2m 39s	remaining: 15.5s
# 1823:	learn: 0.4774306	total: 2m 39s	remaining: 15.4s
# 1824:	learn: 0.4774135	total: 2m 39s	remaining: 15.3s
# 1825:	learn: 0.4774001	total: 2m 39s	remaining: 15.2s
# 1826:	learn: 0.4773838	total: 2m 39s	remaining: 15.1s
# 1827:	learn: 0.4773671	total: 2m 39s	remaining: 15s
# 1828:	learn: 0.4773516	total: 2m 39s	remaining: 14.9s
# 1829:	learn: 0.4773344	total: 2m 39s	remaining: 14.9s
# 1830:	learn: 0.4773173	total: 2m 40s	remaining: 14.8s
# 1831:	learn: 0.4773001	total: 2m 40s	remaining: 14.7s
# 1832:	learn: 0.4772805	total: 2m 40s	remaining: 14.6s
# 1833:	learn: 0.4772643	total: 2m 40s	remaining: 14.5s
# 1834:	learn: 0.4772469	total: 2m 40s	remaining: 14.4s
# 1835:	learn: 0.4772323	total: 2m 40s	remaining: 14.3s
# 1836:	learn: 0.4772138	total: 2m 40s	remaining: 14.3s
# 1837:	learn: 0.4771978	total: 2m 40s	remaining: 14.2s
# 1838:	learn: 0.4771817	total: 2m 40s	remaining: 14.1s
# 1839:	learn: 0.4771649	total: 2m 40s	remaining: 14s
# 1840:	learn: 0.4771492	total: 2m 40s	remaining: 13.9s
# 1841:	learn: 0.4771334	total: 2m 41s	remaining: 13.8s
# 1842:	learn: 0.4771177	total: 2m 41s	remaining: 13.7s
# 1843:	learn: 0.4771016	total: 2m 41s	remaining: 13.6s
# 1844:	learn: 0.4770827	total: 2m 41s	remaining: 13.6s
# 1845:	learn: 0.4770670	total: 2m 41s	remaining: 13.5s
# 1846:	learn: 0.4770509	total: 2m 41s	remaining: 13.4s
# 1847:	learn: 0.4770346	total: 2m 41s	remaining: 13.3s
# 1848:	learn: 0.4770168	total: 2m 41s	remaining: 13.2s
# 1849:	learn: 0.4769964	total: 2m 41s	remaining: 13.1s
# 1850:	learn: 0.4769806	total: 2m 41s	remaining: 13s
# 1851:	learn: 0.4769653	total: 2m 41s	remaining: 12.9s
# 1852:	learn: 0.4769493	total: 2m 42s	remaining: 12.9s
# 1853:	learn: 0.4769331	total: 2m 42s	remaining: 12.8s
# 1854:	learn: 0.4769163	total: 2m 42s	remaining: 12.7s
# 1855:	learn: 0.4768977	total: 2m 42s	remaining: 12.6s
# 1856:	learn: 0.4768813	total: 2m 42s	remaining: 12.5s
# 1857:	learn: 0.4768650	total: 2m 42s	remaining: 12.4s
# 1858:	learn: 0.4768488	total: 2m 42s	remaining: 12.3s
# 1859:	learn: 0.4768314	total: 2m 42s	remaining: 12.2s
# 1860:	learn: 0.4768132	total: 2m 42s	remaining: 12.2s
# 1861:	learn: 0.4767940	total: 2m 42s	remaining: 12.1s
# 1862:	learn: 0.4767763	total: 2m 42s	remaining: 12s
# 1863:	learn: 0.4767589	total: 2m 42s	remaining: 11.9s
# 1864:	learn: 0.4767405	total: 2m 43s	remaining: 11.8s
# 1865:	learn: 0.4767238	total: 2m 43s	remaining: 11.7s
# 1866:	learn: 0.4767048	total: 2m 43s	remaining: 11.6s
# 1867:	learn: 0.4766873	total: 2m 43s	remaining: 11.5s
# 1868:	learn: 0.4766697	total: 2m 43s	remaining: 11.5s
# 1869:	learn: 0.4766518	total: 2m 43s	remaining: 11.4s
# 1870:	learn: 0.4766389	total: 2m 43s	remaining: 11.3s
# 1871:	learn: 0.4766212	total: 2m 43s	remaining: 11.2s
# 1872:	learn: 0.4766081	total: 2m 43s	remaining: 11.1s
# 1873:	learn: 0.4765913	total: 2m 43s	remaining: 11s
# 1874:	learn: 0.4765729	total: 2m 43s	remaining: 10.9s
# 1875:	learn: 0.4765590	total: 2m 44s	remaining: 10.8s
# 1876:	learn: 0.4765416	total: 2m 44s	remaining: 10.8s
# 1877:	learn: 0.4765264	total: 2m 44s	remaining: 10.7s
# 1878:	learn: 0.4765081	total: 2m 44s	remaining: 10.6s
# 1879:	learn: 0.4764916	total: 2m 44s	remaining: 10.5s
# 1880:	learn: 0.4764752	total: 2m 44s	remaining: 10.4s
# 1881:	learn: 0.4764571	total: 2m 44s	remaining: 10.3s
# 1882:	learn: 0.4764411	total: 2m 44s	remaining: 10.2s
# 1883:	learn: 0.4764251	total: 2m 44s	remaining: 10.1s
# 1884:	learn: 0.4764103	total: 2m 44s	remaining: 10.1s
# 1885:	learn: 0.4763952	total: 2m 44s	remaining: 9.97s
# 1886:	learn: 0.4763778	total: 2m 44s	remaining: 9.88s
# 1887:	learn: 0.4763602	total: 2m 45s	remaining: 9.79s
# 1888:	learn: 0.4763424	total: 2m 45s	remaining: 9.7s
# 1889:	learn: 0.4763271	total: 2m 45s	remaining: 9.62s
# 1890:	learn: 0.4763085	total: 2m 45s	remaining: 9.53s
# 1891:	learn: 0.4762922	total: 2m 45s	remaining: 9.44s
# 1892:	learn: 0.4762778	total: 2m 45s	remaining: 9.36s
# 1893:	learn: 0.4762610	total: 2m 45s	remaining: 9.27s
# 1894:	learn: 0.4762420	total: 2m 45s	remaining: 9.18s
# 1895:	learn: 0.4762241	total: 2m 45s	remaining: 9.09s
# 1896:	learn: 0.4762086	total: 2m 45s	remaining: 9.01s
# 1897:	learn: 0.4761913	total: 2m 45s	remaining: 8.92s
# 1898:	learn: 0.4761754	total: 2m 46s	remaining: 8.83s
# 1899:	learn: 0.4761581	total: 2m 46s	remaining: 8.74s
# 1900:	learn: 0.4761409	total: 2m 46s	remaining: 8.66s
# 1901:	learn: 0.4761224	total: 2m 46s	remaining: 8.57s
# 1902:	learn: 0.4761059	total: 2m 46s	remaining: 8.48s
# 1903:	learn: 0.4760893	total: 2m 46s	remaining: 8.39s
# 1904:	learn: 0.4760745	total: 2m 46s	remaining: 8.31s
# 1905:	learn: 0.4760576	total: 2m 46s	remaining: 8.22s
# 1906:	learn: 0.4760415	total: 2m 46s	remaining: 8.13s
# 1907:	learn: 0.4760247	total: 2m 46s	remaining: 8.04s
# 1908:	learn: 0.4760095	total: 2m 46s	remaining: 7.96s
# 1909:	learn: 0.4759930	total: 2m 47s	remaining: 7.87s
# 1910:	learn: 0.4759757	total: 2m 47s	remaining: 7.78s
# 1911:	learn: 0.4759584	total: 2m 47s	remaining: 7.69s
# 1912:	learn: 0.4759434	total: 2m 47s	remaining: 7.61s
# 1913:	learn: 0.4759267	total: 2m 47s	remaining: 7.52s
# 1914:	learn: 0.4759111	total: 2m 47s	remaining: 7.43s
# 1915:	learn: 0.4758955	total: 2m 47s	remaining: 7.34s
# 1916:	learn: 0.4758783	total: 2m 47s	remaining: 7.26s
# 1917:	learn: 0.4758618	total: 2m 47s	remaining: 7.17s
# 1918:	learn: 0.4758456	total: 2m 47s	remaining: 7.08s
# 1919:	learn: 0.4758263	total: 2m 47s	remaining: 6.99s
# 1920:	learn: 0.4758104	total: 2m 47s	remaining: 6.91s
# 1921:	learn: 0.4757940	total: 2m 48s	remaining: 6.82s
# 1922:	learn: 0.4757775	total: 2m 48s	remaining: 6.73s
# 1923:	learn: 0.4757616	total: 2m 48s	remaining: 6.64s
# 1924:	learn: 0.4757450	total: 2m 48s	remaining: 6.56s
# 1925:	learn: 0.4757307	total: 2m 48s	remaining: 6.47s
# 1926:	learn: 0.4757145	total: 2m 48s	remaining: 6.38s
# 1927:	learn: 0.4756976	total: 2m 48s	remaining: 6.29s
# 1928:	learn: 0.4756806	total: 2m 48s	remaining: 6.21s
# 1929:	learn: 0.4756606	total: 2m 48s	remaining: 6.12s
# 1930:	learn: 0.4756423	total: 2m 48s	remaining: 6.03s
# 1931:	learn: 0.4756249	total: 2m 48s	remaining: 5.95s
# 1932:	learn: 0.4756056	total: 2m 48s	remaining: 5.86s
# 1933:	learn: 0.4755906	total: 2m 49s	remaining: 5.77s
# 1934:	learn: 0.4755732	total: 2m 49s	remaining: 5.68s
# 1935:	learn: 0.4755582	total: 2m 49s	remaining: 5.59s
# 1936:	learn: 0.4755414	total: 2m 49s	remaining: 5.51s
# 1937:	learn: 0.4755266	total: 2m 49s	remaining: 5.42s
# 1938:	learn: 0.4755102	total: 2m 49s	remaining: 5.33s
# 1939:	learn: 0.4754939	total: 2m 49s	remaining: 5.25s
# 1940:	learn: 0.4754804	total: 2m 49s	remaining: 5.16s
# 1941:	learn: 0.4754640	total: 2m 49s	remaining: 5.07s
# 1942:	learn: 0.4754440	total: 2m 49s	remaining: 4.98s
# 1943:	learn: 0.4754299	total: 2m 49s	remaining: 4.9s
# 1944:	learn: 0.4754119	total: 2m 50s	remaining: 4.81s
# 1945:	learn: 0.4753971	total: 2m 50s	remaining: 4.72s
# 1946:	learn: 0.4753806	total: 2m 50s	remaining: 4.63s
# 1947:	learn: 0.4753633	total: 2m 50s	remaining: 4.55s
# 1948:	learn: 0.4753452	total: 2m 50s	remaining: 4.46s
# 1949:	learn: 0.4753295	total: 2m 50s	remaining: 4.37s
# 1950:	learn: 0.4753128	total: 2m 50s	remaining: 4.28s
# 1951:	learn: 0.4752951	total: 2m 50s	remaining: 4.2s
# 1952:	learn: 0.4752794	total: 2m 50s	remaining: 4.11s
# 1953:	learn: 0.4752635	total: 2m 50s	remaining: 4.02s
# 1954:	learn: 0.4752448	total: 2m 50s	remaining: 3.93s
# 1955:	learn: 0.4752259	total: 2m 50s	remaining: 3.85s
# 1956:	learn: 0.4752077	total: 2m 51s	remaining: 3.76s
# 1957:	learn: 0.4751914	total: 2m 51s	remaining: 3.67s
# 1958:	learn: 0.4751756	total: 2m 51s	remaining: 3.58s
# 1959:	learn: 0.4751585	total: 2m 51s	remaining: 3.5s
# 1960:	learn: 0.4751414	total: 2m 51s	remaining: 3.41s
# 1961:	learn: 0.4751239	total: 2m 51s	remaining: 3.32s
# 1962:	learn: 0.4751068	total: 2m 51s	remaining: 3.23s
# 1963:	learn: 0.4750876	total: 2m 51s	remaining: 3.15s
# 1964:	learn: 0.4750724	total: 2m 51s	remaining: 3.06s
# 1965:	learn: 0.4750556	total: 2m 51s	remaining: 2.97s
# 1966:	learn: 0.4750374	total: 2m 51s	remaining: 2.88s
# 1967:	learn: 0.4750222	total: 2m 52s	remaining: 2.8s
# 1968:	learn: 0.4750057	total: 2m 52s	remaining: 2.71s
# 1969:	learn: 0.4749883	total: 2m 52s	remaining: 2.62s
# 1970:	learn: 0.4749730	total: 2m 52s	remaining: 2.54s
# 1971:	learn: 0.4749580	total: 2m 52s	remaining: 2.45s
# 1972:	learn: 0.4749413	total: 2m 52s	remaining: 2.36s
# 1973:	learn: 0.4749272	total: 2m 52s	remaining: 2.27s
# 1974:	learn: 0.4749090	total: 2m 52s	remaining: 2.19s
# 1975:	learn: 0.4748928	total: 2m 52s	remaining: 2.1s
# 1976:	learn: 0.4748778	total: 2m 52s	remaining: 2.01s
# 1977:	learn: 0.4748609	total: 2m 52s	remaining: 1.92s
# 1978:	learn: 0.4748441	total: 2m 52s	remaining: 1.83s
# 1979:	learn: 0.4748269	total: 2m 53s	remaining: 1.75s
# 1980:	learn: 0.4748093	total: 2m 53s	remaining: 1.66s
# 1981:	learn: 0.4747911	total: 2m 53s	remaining: 1.57s
# 1982:	learn: 0.4747721	total: 2m 53s	remaining: 1.49s
# 1983:	learn: 0.4747567	total: 2m 53s	remaining: 1.4s
# 1984:	learn: 0.4747388	total: 2m 53s	remaining: 1.31s
# 1985:	learn: 0.4747200	total: 2m 53s	remaining: 1.22s
# 1986:	learn: 0.4747028	total: 2m 53s	remaining: 1.14s
# 1987:	learn: 0.4746860	total: 2m 53s	remaining: 1.05s
# 1988:	learn: 0.4746682	total: 2m 53s	remaining: 962ms
# 1989:	learn: 0.4746501	total: 2m 53s	remaining: 874ms
# 1990:	learn: 0.4746337	total: 2m 54s	remaining: 787ms
# 1991:	learn: 0.4746165	total: 2m 54s	remaining: 699ms
# 1992:	learn: 0.4745993	total: 2m 54s	remaining: 612ms
# 1993:	learn: 0.4745822	total: 2m 54s	remaining: 525ms
# 1994:	learn: 0.4745644	total: 2m 54s	remaining: 437ms
# 1995:	learn: 0.4745484	total: 2m 54s	remaining: 350ms
# 1996:	learn: 0.4745325	total: 2m 54s	remaining: 262ms
# 1997:	learn: 0.4745156	total: 2m 54s	remaining: 175ms
# 1998:	learn: 0.4745003	total: 2m 54s	remaining: 87.4ms
# 1999:	learn: 0.4744827	total: 2m 54s	remaining: 0us
# Valid log-loss is 0.5071090517540354
# Valid AUC is 0.8149091535817894

# %%
X_meta_stacked = np.vstack(X_meta)

# %%
y_meta_array = np.asarray(y_meta)
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)

# %%
y_meta_hstack = np.hstack(y_meta_array,)

# %%
y_meta_hstack.shape
# Out:
# (957919,)

# %%
y_meta
# Out:
# [array([1, 1, 1, ..., 0, 0, 1]),
#  array([1, 0, 0, ..., 0, 1, 1]),
#  array([0, 1, 1, ..., 0, 0, 0]),
#  array([0, 1, 1, ..., 0, 1, 1]),
#  array([1, 0, 0, ..., 0, 1, 1])]

# %%
y_meta_hstack
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %%
meta_learner = LogisticRegression(n_jobs=-1)

# %%
np.isnan(y_meta_hstack).any()
# Out:
# False

# %%
type(y_meta_hstack)
# Out:
# numpy.ndarray

# %%
y_meta_array.shape
# Out:
# (5,)

# %%
X_meta_stacked.shape
# Out:
# (957919, 2)

# %%
meta_learner.fit(X_meta_stacked, y_meta_hstack)
# Out:
# LogisticRegression(n_jobs=-1)

# %%
X_preds = meta_learner.predict_proba(X_meta_stacked)

# %%
X_preds # prob of 0, prob of 1
# Out:
# array([[0.45478618, 0.54521382],
#        [0.31942728, 0.68057272],
#        [0.23111547, 0.76888453],
#        ...,
#        [0.87283967, 0.12716033],
#        [0.22200131, 0.77799869],
#        [0.17922862, 0.82077138]])

# %%
# for fold, content in enumerate(X_meta):
#     print(f"len(content) = {len(content)}")
#     print(f"For fold {fold}, first ten: {content[:10]}")
#     print(f"Last ten: {content[-10:]}")
# Out:
# len(content) = 574752
# For fold 0, first ten: [0.58256644 0.62629855 0.7662285  0.75499147 0.10017349 0.09074276
#  0.81610793 0.73974901 0.72552508 0.11378017]
# Last ten: [0.71544773 0.12926759 0.77998132 0.73316186 0.5522913  0.14362175
#  0.13898191 0.12458763 0.10432058 0.59388915]
# len(content) = 574752
# For fold 1, first ten: [0.7899453  0.76898772 0.1540149  0.1326734  0.13505521 0.135717
#  0.76631808 0.15017609 0.77063125 0.62637734]
# Last ten: [0.79133012 0.75843728 0.75821059 0.75214886 0.77777462 0.14167253
#  0.12332096 0.11199911 0.77826162 0.59577923]
# len(content) = 574752
# For fold 2, first ten: [0.14557232 0.13051899 0.731341   0.75136185 0.76965833 0.5596422
#  0.15574594 0.58632851 0.73949695 0.1217273 ]
# Last ten: [0.12980072 0.13182534 0.7620172  0.47812301 0.61756362 0.13219188
#  0.75631119 0.12209702 0.15794384 0.78886702]
# len(content) = 574752
# For fold 3, first ten: [0.15521842 0.75803405 0.78014207 0.77034795 0.14344598 0.11674909
#  0.71550232 0.56999534 0.71767098 0.57802474]
# Last ten: [0.79191139 0.15390743 0.59345427 0.47557157 0.11463466 0.73366089
#  0.62809734 0.12785491 0.71442834 0.71931407]
# len(content) = 574749
# For fold 4, first ten: [0.77324533 0.51835465 0.15568879 0.78063399 0.77089399 0.57074875
#  0.13649721 0.73943436 0.12940963 0.69027555]
# Last ten: [0.77449398 0.71875304 0.15385888 0.80472879 0.74546871 0.16486147
#  0.54191339 0.12395298 0.75245771 0.80293987]

# %%
X_augment, y_augment = super_cross_validation() # default args; should provide first layer
X_augment_df = pd.DataFrame(X_augment, columns=[str(x) for x in range(X_augment.shape[1])])
X_augment_df.to_feather(datapath/'X_super-learner_augment.feather')
dump(y_augment, datapath/'y_super-learner_augment.joblib')
# Out:
# Finishing last run (ID:l7l7lbhw) before initializing another...
# <br/>Waiting for W&B process to finish, PID 1485387<br/>Program ended successfully.
# VBox(children=(Label(value=' 1.72MB of 1.72MB uploaded (0.84MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210912_185940-l7l7lbhw/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210912_185940-l7l7lbhw/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>xgboost_params</td><td>{'objective': 'binar...</td></tr><tr><td>_runtime</td><td>476</td></tr><tr><td>_timestamp</td><td>1631498856</td></tr><tr><td>_step</td><td>2</td></tr><tr><td>valid_loss</td><td>0.51094</td></tr><tr><td>valid_auc</td><td>0.81226</td></tr><tr><td>fold</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁▁▁</td></tr><tr><td>_timestamp</td><td>▁▁▁</td></tr><tr><td>_step</td><td>▁▅█</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 3 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">super-learner_manual_20210912_185939</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/l7l7lbhw" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/l7l7lbhw</a><br/>
# ...Successfully finished last run (ID:l7l7lbhw). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">super-learner_manual_20210912_185939</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3tmb6fdj" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3tmb6fdj</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210912_191503-3tmb6fdj</code><br/><br/>
# FOLD 0
# ---------------------------------------------------
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:15:18] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Valid log-loss is 0.5109356389636417
# Valid AUC is 0.8122584973566012
# Valid log-loss is 0.5113911181729013
# Valid AUC is 0.8114826365905788
# Learning rate set to 0.012572
# 0:	learn: 0.6881615	total: 12.7ms	remaining: 25.4s
# 1:	learn: 0.6833118	total: 24.2ms	remaining: 24.2s
# 2:	learn: 0.6785923	total: 35.9ms	remaining: 23.9s
# 3:	learn: 0.6740079	total: 47.4ms	remaining: 23.6s
# 4:	learn: 0.6695553	total: 58.2ms	remaining: 23.2s
# 5:	learn: 0.6652220	total: 69.9ms	remaining: 23.2s
# 6:	learn: 0.6610044	total: 81.5ms	remaining: 23.2s
# 7:	learn: 0.6569123	total: 92.9ms	remaining: 23.1s
# 8:	learn: 0.6529273	total: 105ms	remaining: 23.3s
# 9:	learn: 0.6490559	total: 117ms	remaining: 23.2s
# 10:	learn: 0.6452946	total: 129ms	remaining: 23.3s
# 11:	learn: 0.6416326	total: 140ms	remaining: 23.2s
# 12:	learn: 0.6380744	total: 152ms	remaining: 23.3s
# 13:	learn: 0.6346183	total: 164ms	remaining: 23.2s
# 14:	learn: 0.6312602	total: 175ms	remaining: 23.2s
# 15:	learn: 0.6279932	total: 188ms	remaining: 23.3s
# 16:	learn: 0.6248198	total: 199ms	remaining: 23.2s
# 17:	learn: 0.6217369	total: 211ms	remaining: 23.2s
# 18:	learn: 0.6187365	total: 221ms	remaining: 23.1s
# 19:	learn: 0.6158189	total: 238ms	remaining: 23.5s
# 20:	learn: 0.6129818	total: 257ms	remaining: 24.2s
# 21:	learn: 0.6102258	total: 271ms	remaining: 24.4s
# 22:	learn: 0.6075497	total: 281ms	remaining: 24.2s
# 23:	learn: 0.6049462	total: 292ms	remaining: 24s
# 24:	learn: 0.6024169	total: 302ms	remaining: 23.9s
# 25:	learn: 0.5999562	total: 312ms	remaining: 23.7s
# 26:	learn: 0.5975669	total: 322ms	remaining: 23.5s
# 27:	learn: 0.5952417	total: 333ms	remaining: 23.4s
# 28:	learn: 0.5929732	total: 344ms	remaining: 23.4s
# 29:	learn: 0.5907741	total: 354ms	remaining: 23.3s
# 30:	learn: 0.5886389	total: 365ms	remaining: 23.2s
# 31:	learn: 0.5865614	total: 376ms	remaining: 23.1s
# 32:	learn: 0.5845441	total: 386ms	remaining: 23s
# 33:	learn: 0.5825813	total: 397ms	remaining: 22.9s
# 34:	learn: 0.5806726	total: 407ms	remaining: 22.8s
# 35:	learn: 0.5788204	total: 417ms	remaining: 22.7s
# 36:	learn: 0.5770182	total: 427ms	remaining: 22.6s
# 37:	learn: 0.5752671	total: 440ms	remaining: 22.7s
# 38:	learn: 0.5735578	total: 459ms	remaining: 23.1s
# 39:	learn: 0.5719017	total: 478ms	remaining: 23.4s
# 40:	learn: 0.5702922	total: 487ms	remaining: 23.3s
# 41:	learn: 0.5687248	total: 498ms	remaining: 23.2s
# 42:	learn: 0.5671994	total: 510ms	remaining: 23.2s
# 43:	learn: 0.5657151	total: 521ms	remaining: 23.2s
# 44:	learn: 0.5642765	total: 531ms	remaining: 23.1s
# 45:	learn: 0.5628746	total: 541ms	remaining: 23s
# 46:	learn: 0.5615097	total: 551ms	remaining: 22.9s
# 47:	learn: 0.5601852	total: 562ms	remaining: 22.9s
# 48:	learn: 0.5588896	total: 573ms	remaining: 22.8s
# 49:	learn: 0.5576379	total: 584ms	remaining: 22.8s
# 50:	learn: 0.5564188	total: 595ms	remaining: 22.8s
# 51:	learn: 0.5552350	total: 605ms	remaining: 22.7s
# 52:	learn: 0.5540845	total: 615ms	remaining: 22.6s
# 53:	learn: 0.5529630	total: 625ms	remaining: 22.5s
# 54:	learn: 0.5518717	total: 636ms	remaining: 22.5s
# 55:	learn: 0.5508098	total: 653ms	remaining: 22.7s
# 56:	learn: 0.5497825	total: 663ms	remaining: 22.6s
# 57:	learn: 0.5487833	total: 674ms	remaining: 22.6s
# 58:	learn: 0.5478062	total: 686ms	remaining: 22.6s
# 59:	learn: 0.5468553	total: 698ms	remaining: 22.6s
# 60:	learn: 0.5459336	total: 708ms	remaining: 22.5s
# 61:	learn: 0.5450373	total: 718ms	remaining: 22.4s
# 62:	learn: 0.5441642	total: 728ms	remaining: 22.4s
# 63:	learn: 0.5433144	total: 739ms	remaining: 22.4s
# 64:	learn: 0.5424880	total: 750ms	remaining: 22.3s
# 65:	learn: 0.5416858	total: 760ms	remaining: 22.3s
# 66:	learn: 0.5408989	total: 771ms	remaining: 22.3s
# 67:	learn: 0.5401390	total: 782ms	remaining: 22.2s
# 68:	learn: 0.5394009	total: 792ms	remaining: 22.2s
# 69:	learn: 0.5386837	total: 802ms	remaining: 22.1s
# 70:	learn: 0.5379832	total: 813ms	remaining: 22.1s
# 71:	learn: 0.5373042	total: 823ms	remaining: 22s
# 72:	learn: 0.5366423	total: 833ms	remaining: 22s
# 73:	learn: 0.5359982	total: 844ms	remaining: 22s
# 74:	learn: 0.5353697	total: 862ms	remaining: 22.1s
# 75:	learn: 0.5347594	total: 881ms	remaining: 22.3s
# 76:	learn: 0.5341599	total: 895ms	remaining: 22.4s
# 77:	learn: 0.5335847	total: 907ms	remaining: 22.3s
# 78:	learn: 0.5330238	total: 918ms	remaining: 22.3s
# 79:	learn: 0.5324759	total: 930ms	remaining: 22.3s
# 80:	learn: 0.5319434	total: 941ms	remaining: 22.3s
# 81:	learn: 0.5314281	total: 953ms	remaining: 22.3s
# 82:	learn: 0.5309191	total: 965ms	remaining: 22.3s
# 83:	learn: 0.5304288	total: 976ms	remaining: 22.3s
# 84:	learn: 0.5299524	total: 988ms	remaining: 22.3s
# 85:	learn: 0.5294860	total: 999ms	remaining: 22.2s
# 86:	learn: 0.5290368	total: 1.01s	remaining: 22.2s
# 87:	learn: 0.5285998	total: 1.02s	remaining: 22.2s
# 88:	learn: 0.5281700	total: 1.03s	remaining: 22.2s
# 89:	learn: 0.5277528	total: 1.04s	remaining: 22.2s
# 90:	learn: 0.5273420	total: 1.06s	remaining: 22.3s
# 91:	learn: 0.5269459	total: 1.07s	remaining: 22.3s
# 92:	learn: 0.5265608	total: 1.08s	remaining: 22.2s
# 93:	learn: 0.5261849	total: 1.09s	remaining: 22.2s
# 94:	learn: 0.5258189	total: 1.11s	remaining: 22.2s
# 95:	learn: 0.5254622	total: 1.12s	remaining: 22.2s
# 96:	learn: 0.5251163	total: 1.13s	remaining: 22.2s
# 97:	learn: 0.5247752	total: 1.14s	remaining: 22.2s
# 98:	learn: 0.5244501	total: 1.15s	remaining: 22.1s
# 99:	learn: 0.5241288	total: 1.16s	remaining: 22.1s
# 100:	learn: 0.5238107	total: 1.18s	remaining: 22.1s
# 101:	learn: 0.5235097	total: 1.19s	remaining: 22.1s
# 102:	learn: 0.5232150	total: 1.2s	remaining: 22.1s
# 103:	learn: 0.5229225	total: 1.21s	remaining: 22.1s
# 104:	learn: 0.5226410	total: 1.22s	remaining: 22.1s
# 105:	learn: 0.5223669	total: 1.23s	remaining: 22s
# 106:	learn: 0.5220975	total: 1.25s	remaining: 22s
# 107:	learn: 0.5218380	total: 1.26s	remaining: 22.1s
# 108:	learn: 0.5215891	total: 1.27s	remaining: 22.1s
# 109:	learn: 0.5213427	total: 1.29s	remaining: 22.1s
# 110:	learn: 0.5210990	total: 1.3s	remaining: 22.1s
# 111:	learn: 0.5208673	total: 1.31s	remaining: 22.1s
# 112:	learn: 0.5206389	total: 1.32s	remaining: 22.1s
# 113:	learn: 0.5204128	total: 1.33s	remaining: 22.1s
# 114:	learn: 0.5201969	total: 1.35s	remaining: 22.1s
# 115:	learn: 0.5199823	total: 1.36s	remaining: 22.1s
# 116:	learn: 0.5197788	total: 1.37s	remaining: 22s
# 117:	learn: 0.5195790	total: 1.38s	remaining: 22s
# 118:	learn: 0.5193841	total: 1.39s	remaining: 22s
# 119:	learn: 0.5191962	total: 1.4s	remaining: 22s
# 120:	learn: 0.5190115	total: 1.42s	remaining: 22s
# 121:	learn: 0.5188325	total: 1.43s	remaining: 22s
# 122:	learn: 0.5186583	total: 1.44s	remaining: 22s
# 123:	learn: 0.5184880	total: 1.45s	remaining: 22s
# 124:	learn: 0.5183191	total: 1.47s	remaining: 22s
# 125:	learn: 0.5181594	total: 1.48s	remaining: 22s
# 126:	learn: 0.5179993	total: 1.49s	remaining: 22s
# 127:	learn: 0.5178471	total: 1.5s	remaining: 22s
# 128:	learn: 0.5176935	total: 1.51s	remaining: 22s
# 129:	learn: 0.5175459	total: 1.53s	remaining: 22s
# 130:	learn: 0.5174051	total: 1.54s	remaining: 21.9s
# 131:	learn: 0.5172666	total: 1.55s	remaining: 21.9s
# 132:	learn: 0.5171307	total: 1.56s	remaining: 21.9s
# 133:	learn: 0.5169998	total: 1.57s	remaining: 21.9s
# 134:	learn: 0.5168710	total: 1.58s	remaining: 21.9s
# 135:	learn: 0.5167473	total: 1.59s	remaining: 21.9s
# 136:	learn: 0.5166227	total: 1.61s	remaining: 21.8s
# 137:	learn: 0.5165049	total: 1.62s	remaining: 21.8s
# 138:	learn: 0.5163923	total: 1.63s	remaining: 21.8s
# 139:	learn: 0.5162802	total: 1.64s	remaining: 21.8s
# 140:	learn: 0.5161670	total: 1.65s	remaining: 21.8s
# 141:	learn: 0.5160567	total: 1.67s	remaining: 21.9s
# 142:	learn: 0.5159497	total: 1.68s	remaining: 21.9s
# 143:	learn: 0.5158480	total: 1.7s	remaining: 21.9s
# 144:	learn: 0.5157478	total: 1.71s	remaining: 21.8s
# 145:	learn: 0.5156504	total: 1.72s	remaining: 21.8s
# 146:	learn: 0.5155551	total: 1.73s	remaining: 21.8s
# 147:	learn: 0.5154606	total: 1.74s	remaining: 21.8s
# 148:	learn: 0.5153682	total: 1.75s	remaining: 21.8s
# 149:	learn: 0.5152763	total: 1.77s	remaining: 21.8s
# 150:	learn: 0.5151904	total: 1.78s	remaining: 21.8s
# 151:	learn: 0.5151061	total: 1.79s	remaining: 21.8s
# 152:	learn: 0.5150222	total: 1.8s	remaining: 21.7s
# 153:	learn: 0.5149443	total: 1.81s	remaining: 21.7s
# 154:	learn: 0.5148627	total: 1.82s	remaining: 21.7s
# 155:	learn: 0.5147911	total: 1.83s	remaining: 21.7s
# 156:	learn: 0.5147169	total: 1.85s	remaining: 21.7s
# 157:	learn: 0.5146429	total: 1.86s	remaining: 21.7s
# 158:	learn: 0.5145682	total: 1.88s	remaining: 21.7s
# 159:	learn: 0.5144973	total: 1.89s	remaining: 21.7s
# 160:	learn: 0.5144256	total: 1.9s	remaining: 21.7s
# 161:	learn: 0.5143622	total: 1.91s	remaining: 21.7s
# 162:	learn: 0.5142967	total: 1.93s	remaining: 21.7s
# 163:	learn: 0.5142337	total: 1.94s	remaining: 21.7s
# 164:	learn: 0.5141749	total: 1.95s	remaining: 21.7s
# 165:	learn: 0.5141156	total: 1.96s	remaining: 21.6s
# 166:	learn: 0.5140539	total: 1.97s	remaining: 21.6s
# 167:	learn: 0.5139937	total: 1.98s	remaining: 21.6s
# 168:	learn: 0.5139362	total: 1.99s	remaining: 21.6s
# 169:	learn: 0.5138810	total: 2.01s	remaining: 21.6s
# 170:	learn: 0.5138280	total: 2.02s	remaining: 21.6s
# 171:	learn: 0.5137746	total: 2.03s	remaining: 21.6s
# 172:	learn: 0.5137228	total: 2.04s	remaining: 21.6s
# 173:	learn: 0.5136716	total: 2.05s	remaining: 21.6s
# 174:	learn: 0.5136261	total: 2.07s	remaining: 21.6s
# 175:	learn: 0.5135789	total: 2.08s	remaining: 21.6s
# 176:	learn: 0.5135320	total: 2.1s	remaining: 21.6s
# 177:	learn: 0.5134875	total: 2.11s	remaining: 21.6s
# 178:	learn: 0.5134439	total: 2.12s	remaining: 21.6s
# 179:	learn: 0.5134003	total: 2.13s	remaining: 21.6s
# 180:	learn: 0.5133600	total: 2.14s	remaining: 21.5s
# 181:	learn: 0.5133206	total: 2.15s	remaining: 21.5s
# 182:	learn: 0.5132807	total: 2.17s	remaining: 21.5s
# 183:	learn: 0.5132436	total: 2.18s	remaining: 21.5s
# 184:	learn: 0.5132022	total: 2.19s	remaining: 21.5s
# 185:	learn: 0.5131651	total: 2.2s	remaining: 21.5s
# 186:	learn: 0.5131295	total: 2.21s	remaining: 21.5s
# 187:	learn: 0.5130913	total: 2.22s	remaining: 21.4s
# 188:	learn: 0.5130542	total: 2.24s	remaining: 21.4s
# 189:	learn: 0.5130183	total: 2.25s	remaining: 21.4s
# 190:	learn: 0.5129855	total: 2.26s	remaining: 21.4s
# 191:	learn: 0.5129523	total: 2.27s	remaining: 21.4s
# 192:	learn: 0.5129212	total: 2.29s	remaining: 21.4s
# 193:	learn: 0.5128886	total: 2.3s	remaining: 21.4s
# 194:	learn: 0.5128606	total: 2.31s	remaining: 21.4s
# 195:	learn: 0.5128299	total: 2.32s	remaining: 21.4s
# 196:	learn: 0.5127995	total: 2.33s	remaining: 21.4s
# 197:	learn: 0.5127712	total: 2.34s	remaining: 21.3s
# 198:	learn: 0.5127405	total: 2.35s	remaining: 21.3s
# 199:	learn: 0.5127138	total: 2.37s	remaining: 21.3s
# 200:	learn: 0.5126860	total: 2.38s	remaining: 21.3s
# 201:	learn: 0.5126568	total: 2.39s	remaining: 21.3s
# 202:	learn: 0.5126290	total: 2.4s	remaining: 21.2s
# 203:	learn: 0.5126052	total: 2.41s	remaining: 21.2s
# 204:	learn: 0.5125776	total: 2.42s	remaining: 21.2s
# 205:	learn: 0.5125516	total: 2.43s	remaining: 21.2s
# 206:	learn: 0.5125278	total: 2.44s	remaining: 21.2s
# 207:	learn: 0.5125030	total: 2.45s	remaining: 21.1s
# 208:	learn: 0.5124768	total: 2.46s	remaining: 21.1s
# 209:	learn: 0.5124531	total: 2.48s	remaining: 21.2s
# 210:	learn: 0.5124303	total: 2.5s	remaining: 21.2s
# 211:	learn: 0.5124087	total: 2.52s	remaining: 21.2s
# 212:	learn: 0.5123876	total: 2.52s	remaining: 21.2s
# 213:	learn: 0.5123652	total: 2.54s	remaining: 21.2s
# 214:	learn: 0.5123431	total: 2.55s	remaining: 21.1s
# 215:	learn: 0.5123231	total: 2.56s	remaining: 21.1s
# 216:	learn: 0.5123023	total: 2.57s	remaining: 21.1s
# 217:	learn: 0.5122796	total: 2.58s	remaining: 21.1s
# 218:	learn: 0.5122586	total: 2.59s	remaining: 21.1s
# 219:	learn: 0.5122404	total: 2.6s	remaining: 21.1s
# 220:	learn: 0.5122197	total: 2.61s	remaining: 21s
# 221:	learn: 0.5122000	total: 2.63s	remaining: 21s
# 222:	learn: 0.5121816	total: 2.63s	remaining: 21s
# 223:	learn: 0.5121671	total: 2.65s	remaining: 21s
# 224:	learn: 0.5121476	total: 2.66s	remaining: 21s
# 225:	learn: 0.5121310	total: 2.67s	remaining: 21s
# 226:	learn: 0.5121153	total: 2.68s	remaining: 20.9s
# 227:	learn: 0.5120961	total: 2.7s	remaining: 21s
# 228:	learn: 0.5120778	total: 2.72s	remaining: 21s
# 229:	learn: 0.5120602	total: 2.73s	remaining: 21s
# 230:	learn: 0.5120448	total: 2.74s	remaining: 21s
# 231:	learn: 0.5120283	total: 2.75s	remaining: 21s
# 232:	learn: 0.5120150	total: 2.76s	remaining: 21s
# 233:	learn: 0.5119979	total: 2.78s	remaining: 21s
# 234:	learn: 0.5119819	total: 2.79s	remaining: 20.9s
# 235:	learn: 0.5119653	total: 2.8s	remaining: 20.9s
# 236:	learn: 0.5119513	total: 2.81s	remaining: 20.9s
# 237:	learn: 0.5119377	total: 2.82s	remaining: 20.9s
# 238:	learn: 0.5119256	total: 2.83s	remaining: 20.9s
# 239:	learn: 0.5119107	total: 2.85s	remaining: 20.9s
# 240:	learn: 0.5118971	total: 2.86s	remaining: 20.9s
# 241:	learn: 0.5118822	total: 2.87s	remaining: 20.8s
# 242:	learn: 0.5118690	total: 2.88s	remaining: 20.8s
# 243:	learn: 0.5118538	total: 2.9s	remaining: 20.9s
# 244:	learn: 0.5118387	total: 2.91s	remaining: 20.8s
# 245:	learn: 0.5118264	total: 2.92s	remaining: 20.8s
# 246:	learn: 0.5118132	total: 2.93s	remaining: 20.8s
# 247:	learn: 0.5118005	total: 2.94s	remaining: 20.8s
# 248:	learn: 0.5117860	total: 2.96s	remaining: 20.8s
# 249:	learn: 0.5117723	total: 2.97s	remaining: 20.8s
# 250:	learn: 0.5117624	total: 2.98s	remaining: 20.8s
# 251:	learn: 0.5117502	total: 2.99s	remaining: 20.7s
# 252:	learn: 0.5117382	total: 3s	remaining: 20.7s
# 253:	learn: 0.5117276	total: 3.01s	remaining: 20.7s
# 254:	learn: 0.5117164	total: 3.02s	remaining: 20.7s
# 255:	learn: 0.5117047	total: 3.04s	remaining: 20.7s
# 256:	learn: 0.5116944	total: 3.05s	remaining: 20.7s
# 257:	learn: 0.5116830	total: 3.06s	remaining: 20.7s
# 258:	learn: 0.5116702	total: 3.07s	remaining: 20.6s
# 259:	learn: 0.5116580	total: 3.09s	remaining: 20.7s
# 260:	learn: 0.5116472	total: 3.1s	remaining: 20.7s
# 261:	learn: 0.5116377	total: 3.12s	remaining: 20.7s
# 262:	learn: 0.5116263	total: 3.13s	remaining: 20.7s
# 263:	learn: 0.5116160	total: 3.14s	remaining: 20.6s
# 264:	learn: 0.5116059	total: 3.15s	remaining: 20.6s
# 265:	learn: 0.5115962	total: 3.16s	remaining: 20.6s
# 266:	learn: 0.5115847	total: 3.17s	remaining: 20.6s
# 267:	learn: 0.5115729	total: 3.18s	remaining: 20.6s
# 268:	learn: 0.5115630	total: 3.19s	remaining: 20.6s
# 269:	learn: 0.5115539	total: 3.21s	remaining: 20.5s
# 270:	learn: 0.5115428	total: 3.22s	remaining: 20.5s
# 271:	learn: 0.5115328	total: 3.23s	remaining: 20.5s
# 272:	learn: 0.5115221	total: 3.24s	remaining: 20.5s
# 273:	learn: 0.5115114	total: 3.25s	remaining: 20.5s
# 274:	learn: 0.5115018	total: 3.26s	remaining: 20.5s
# 275:	learn: 0.5114911	total: 3.27s	remaining: 20.4s
# 276:	learn: 0.5114816	total: 3.28s	remaining: 20.4s
# 277:	learn: 0.5114724	total: 3.3s	remaining: 20.5s
# 278:	learn: 0.5114632	total: 3.32s	remaining: 20.5s
# 279:	learn: 0.5114544	total: 3.33s	remaining: 20.5s
# 280:	learn: 0.5114441	total: 3.34s	remaining: 20.5s
# 281:	learn: 0.5114354	total: 3.35s	remaining: 20.4s
# 282:	learn: 0.5114258	total: 3.37s	remaining: 20.4s
# 283:	learn: 0.5114189	total: 3.38s	remaining: 20.4s
# 284:	learn: 0.5114083	total: 3.39s	remaining: 20.4s
# 285:	learn: 0.5113996	total: 3.4s	remaining: 20.4s
# 286:	learn: 0.5113925	total: 3.41s	remaining: 20.4s
# 287:	learn: 0.5113837	total: 3.42s	remaining: 20.3s
# 288:	learn: 0.5113757	total: 3.43s	remaining: 20.3s
# 289:	learn: 0.5113673	total: 3.44s	remaining: 20.3s
# 290:	learn: 0.5113589	total: 3.45s	remaining: 20.3s
# 291:	learn: 0.5113501	total: 3.47s	remaining: 20.3s
# 292:	learn: 0.5113430	total: 3.48s	remaining: 20.3s
# 293:	learn: 0.5113346	total: 3.49s	remaining: 20.3s
# 294:	learn: 0.5113261	total: 3.51s	remaining: 20.3s
# 295:	learn: 0.5113190	total: 3.53s	remaining: 20.3s
# 296:	learn: 0.5113104	total: 3.54s	remaining: 20.3s
# 297:	learn: 0.5113029	total: 3.55s	remaining: 20.3s
# 298:	learn: 0.5112958	total: 3.56s	remaining: 20.3s
# 299:	learn: 0.5112877	total: 3.58s	remaining: 20.3s
# 300:	learn: 0.5112796	total: 3.59s	remaining: 20.2s
# 301:	learn: 0.5112718	total: 3.6s	remaining: 20.2s
# 302:	learn: 0.5112633	total: 3.61s	remaining: 20.2s
# 303:	learn: 0.5112546	total: 3.62s	remaining: 20.2s
# 304:	learn: 0.5112467	total: 3.63s	remaining: 20.2s
# 305:	learn: 0.5112372	total: 3.64s	remaining: 20.2s
# 306:	learn: 0.5112290	total: 3.65s	remaining: 20.2s
# 307:	learn: 0.5112218	total: 3.67s	remaining: 20.1s
# 308:	learn: 0.5112147	total: 3.68s	remaining: 20.1s
# 309:	learn: 0.5112061	total: 3.69s	remaining: 20.1s
# 310:	learn: 0.5112002	total: 3.7s	remaining: 20.1s
# 311:	learn: 0.5111931	total: 3.72s	remaining: 20.1s
# 312:	learn: 0.5111853	total: 3.74s	remaining: 20.1s
# 313:	learn: 0.5111781	total: 3.75s	remaining: 20.1s
# 314:	learn: 0.5111735	total: 3.76s	remaining: 20.1s
# 315:	learn: 0.5111660	total: 3.77s	remaining: 20.1s
# 316:	learn: 0.5111589	total: 3.78s	remaining: 20.1s
# 317:	learn: 0.5111503	total: 3.79s	remaining: 20.1s
# 318:	learn: 0.5111426	total: 3.8s	remaining: 20s
# 319:	learn: 0.5111365	total: 3.81s	remaining: 20s
# 320:	learn: 0.5111299	total: 3.83s	remaining: 20s
# 321:	learn: 0.5111236	total: 3.84s	remaining: 20s
# 322:	learn: 0.5111172	total: 3.85s	remaining: 20s
# 323:	learn: 0.5111121	total: 3.86s	remaining: 20s
# 324:	learn: 0.5111070	total: 3.87s	remaining: 20s
# 325:	learn: 0.5110992	total: 3.88s	remaining: 19.9s
# 326:	learn: 0.5110929	total: 3.9s	remaining: 20s
# 327:	learn: 0.5110864	total: 3.92s	remaining: 20s
# 328:	learn: 0.5110789	total: 3.94s	remaining: 20s
# 329:	learn: 0.5110721	total: 3.94s	remaining: 20s
# 330:	learn: 0.5110669	total: 3.96s	remaining: 19.9s
# 331:	learn: 0.5110602	total: 3.97s	remaining: 19.9s
# 332:	learn: 0.5110535	total: 3.98s	remaining: 19.9s
# 333:	learn: 0.5110465	total: 3.99s	remaining: 19.9s
# 334:	learn: 0.5110414	total: 4s	remaining: 19.9s
# 335:	learn: 0.5110345	total: 4.01s	remaining: 19.9s
# 336:	learn: 0.5110277	total: 4.02s	remaining: 19.9s
# 337:	learn: 0.5110218	total: 4.03s	remaining: 19.8s
# 338:	learn: 0.5110166	total: 4.04s	remaining: 19.8s
# 339:	learn: 0.5110090	total: 4.06s	remaining: 19.8s
# 340:	learn: 0.5110038	total: 4.07s	remaining: 19.8s
# 341:	learn: 0.5109969	total: 4.08s	remaining: 19.8s
# 342:	learn: 0.5109906	total: 4.09s	remaining: 19.8s
# 343:	learn: 0.5109839	total: 4.1s	remaining: 19.7s
# 344:	learn: 0.5109779	total: 4.12s	remaining: 19.8s
# 345:	learn: 0.5109720	total: 4.14s	remaining: 19.8s
# 346:	learn: 0.5109651	total: 4.15s	remaining: 19.8s
# 347:	learn: 0.5109582	total: 4.16s	remaining: 19.8s
# 348:	learn: 0.5109516	total: 4.17s	remaining: 19.7s
# 349:	learn: 0.5109457	total: 4.18s	remaining: 19.7s
# 350:	learn: 0.5109392	total: 4.19s	remaining: 19.7s
# 351:	learn: 0.5109334	total: 4.2s	remaining: 19.7s
# 352:	learn: 0.5109261	total: 4.22s	remaining: 19.7s
# 353:	learn: 0.5109192	total: 4.23s	remaining: 19.7s
# 354:	learn: 0.5109141	total: 4.24s	remaining: 19.6s
# 355:	learn: 0.5109082	total: 4.25s	remaining: 19.6s
# 356:	learn: 0.5109026	total: 4.26s	remaining: 19.6s
# 357:	learn: 0.5108958	total: 4.27s	remaining: 19.6s
# 358:	learn: 0.5108895	total: 4.28s	remaining: 19.6s
# 359:	learn: 0.5108829	total: 4.29s	remaining: 19.5s
# 360:	learn: 0.5108769	total: 4.3s	remaining: 19.5s
# 361:	learn: 0.5108719	total: 4.32s	remaining: 19.5s
# 362:	learn: 0.5108678	total: 4.33s	remaining: 19.5s
# 363:	learn: 0.5108625	total: 4.35s	remaining: 19.6s
# 364:	learn: 0.5108583	total: 4.36s	remaining: 19.5s
# 365:	learn: 0.5108515	total: 4.37s	remaining: 19.5s
# 366:	learn: 0.5108459	total: 4.38s	remaining: 19.5s
# 367:	learn: 0.5108402	total: 4.39s	remaining: 19.5s
# 368:	learn: 0.5108340	total: 4.4s	remaining: 19.5s
# 369:	learn: 0.5108289	total: 4.42s	remaining: 19.5s
# 370:	learn: 0.5108234	total: 4.43s	remaining: 19.4s
# 371:	learn: 0.5108185	total: 4.44s	remaining: 19.4s
# 372:	learn: 0.5108127	total: 4.45s	remaining: 19.4s
# 373:	learn: 0.5108089	total: 4.46s	remaining: 19.4s
# 374:	learn: 0.5108032	total: 4.47s	remaining: 19.4s
# 375:	learn: 0.5107975	total: 4.48s	remaining: 19.3s
# 376:	learn: 0.5107924	total: 4.49s	remaining: 19.3s
# 377:	learn: 0.5107886	total: 4.5s	remaining: 19.3s
# 378:	learn: 0.5107826	total: 4.52s	remaining: 19.3s
# 379:	learn: 0.5107771	total: 4.54s	remaining: 19.3s
# 380:	learn: 0.5107703	total: 4.55s	remaining: 19.3s
# 381:	learn: 0.5107657	total: 4.56s	remaining: 19.3s
# 382:	learn: 0.5107599	total: 4.57s	remaining: 19.3s
# 383:	learn: 0.5107556	total: 4.58s	remaining: 19.3s
# 384:	learn: 0.5107519	total: 4.59s	remaining: 19.3s
# 385:	learn: 0.5107464	total: 4.6s	remaining: 19.2s
# 386:	learn: 0.5107404	total: 4.61s	remaining: 19.2s
# 387:	learn: 0.5107339	total: 4.62s	remaining: 19.2s
# 388:	learn: 0.5107303	total: 4.63s	remaining: 19.2s
# 389:	learn: 0.5107247	total: 4.65s	remaining: 19.2s
# 390:	learn: 0.5107188	total: 4.66s	remaining: 19.2s
# 391:	learn: 0.5107128	total: 4.67s	remaining: 19.2s
# 392:	learn: 0.5107062	total: 4.68s	remaining: 19.1s
# 393:	learn: 0.5107010	total: 4.69s	remaining: 19.1s
# 394:	learn: 0.5106958	total: 4.7s	remaining: 19.1s
# 395:	learn: 0.5106909	total: 4.72s	remaining: 19.1s
# 396:	learn: 0.5106861	total: 4.74s	remaining: 19.1s
# 397:	learn: 0.5106818	total: 4.75s	remaining: 19.1s
# 398:	learn: 0.5106756	total: 4.76s	remaining: 19.1s
# 399:	learn: 0.5106710	total: 4.78s	remaining: 19.1s
# 400:	learn: 0.5106653	total: 4.79s	remaining: 19.1s
# 401:	learn: 0.5106599	total: 4.8s	remaining: 19.1s
# 402:	learn: 0.5106551	total: 4.81s	remaining: 19s
# 403:	learn: 0.5106511	total: 4.82s	remaining: 19s
# 404:	learn: 0.5106472	total: 4.83s	remaining: 19s
# 405:	learn: 0.5106424	total: 4.84s	remaining: 19s
# 406:	learn: 0.5106375	total: 4.85s	remaining: 19s
# 407:	learn: 0.5106319	total: 4.86s	remaining: 19s
# 408:	learn: 0.5106246	total: 4.88s	remaining: 19s
# 409:	learn: 0.5106186	total: 4.88s	remaining: 18.9s
# 410:	learn: 0.5106128	total: 4.9s	remaining: 18.9s
# 411:	learn: 0.5106065	total: 4.91s	remaining: 18.9s
# 412:	learn: 0.5106015	total: 4.93s	remaining: 18.9s
# 413:	learn: 0.5105963	total: 4.95s	remaining: 18.9s
# 414:	learn: 0.5105906	total: 4.96s	remaining: 18.9s
# 415:	learn: 0.5105855	total: 4.96s	remaining: 18.9s
# 416:	learn: 0.5105805	total: 4.98s	remaining: 18.9s
# 417:	learn: 0.5105754	total: 4.99s	remaining: 18.9s
# 418:	learn: 0.5105699	total: 5s	remaining: 18.9s
# 419:	learn: 0.5105666	total: 5.01s	remaining: 18.8s
# 420:	learn: 0.5105610	total: 5.02s	remaining: 18.8s
# 421:	learn: 0.5105564	total: 5.03s	remaining: 18.8s
# 422:	learn: 0.5105530	total: 5.04s	remaining: 18.8s
# 423:	learn: 0.5105463	total: 5.05s	remaining: 18.8s
# 424:	learn: 0.5105407	total: 5.06s	remaining: 18.8s
# 425:	learn: 0.5105348	total: 5.07s	remaining: 18.7s
# 426:	learn: 0.5105298	total: 5.08s	remaining: 18.7s
# 427:	learn: 0.5105251	total: 5.09s	remaining: 18.7s
# 428:	learn: 0.5105203	total: 5.1s	remaining: 18.7s
# 429:	learn: 0.5105148	total: 5.12s	remaining: 18.7s
# 430:	learn: 0.5105096	total: 5.14s	remaining: 18.7s
# 431:	learn: 0.5105047	total: 5.15s	remaining: 18.7s
# 432:	learn: 0.5105006	total: 5.16s	remaining: 18.7s
# 433:	learn: 0.5104928	total: 5.17s	remaining: 18.7s
# 434:	learn: 0.5104891	total: 5.18s	remaining: 18.7s
# 435:	learn: 0.5104834	total: 5.2s	remaining: 18.6s
# 436:	learn: 0.5104783	total: 5.21s	remaining: 18.6s
# 437:	learn: 0.5104729	total: 5.22s	remaining: 18.6s
# 438:	learn: 0.5104696	total: 5.23s	remaining: 18.6s
# 439:	learn: 0.5104643	total: 5.24s	remaining: 18.6s
# 440:	learn: 0.5104602	total: 5.25s	remaining: 18.6s
# 441:	learn: 0.5104529	total: 5.26s	remaining: 18.5s
# 442:	learn: 0.5104481	total: 5.27s	remaining: 18.5s
# 443:	learn: 0.5104417	total: 5.28s	remaining: 18.5s
# 444:	learn: 0.5104354	total: 5.29s	remaining: 18.5s
# 445:	learn: 0.5104312	total: 5.3s	remaining: 18.5s
# 446:	learn: 0.5104262	total: 5.32s	remaining: 18.5s
# 447:	learn: 0.5104216	total: 5.34s	remaining: 18.5s
# 448:	learn: 0.5104171	total: 5.35s	remaining: 18.5s
# 449:	learn: 0.5104128	total: 5.36s	remaining: 18.5s
# 450:	learn: 0.5104076	total: 5.37s	remaining: 18.5s
# 451:	learn: 0.5104029	total: 5.38s	remaining: 18.4s
# 452:	learn: 0.5103982	total: 5.4s	remaining: 18.4s
# 453:	learn: 0.5103916	total: 5.41s	remaining: 18.4s
# 454:	learn: 0.5103856	total: 5.42s	remaining: 18.4s
# 455:	learn: 0.5103798	total: 5.43s	remaining: 18.4s
# 456:	learn: 0.5103745	total: 5.44s	remaining: 18.4s
# 457:	learn: 0.5103703	total: 5.45s	remaining: 18.4s
# 458:	learn: 0.5103641	total: 5.46s	remaining: 18.3s
# 459:	learn: 0.5103600	total: 5.47s	remaining: 18.3s
# 460:	learn: 0.5103558	total: 5.49s	remaining: 18.3s
# 461:	learn: 0.5103512	total: 5.5s	remaining: 18.3s
# 462:	learn: 0.5103458	total: 5.51s	remaining: 18.3s
# 463:	learn: 0.5103414	total: 5.53s	remaining: 18.3s
# 464:	learn: 0.5103363	total: 5.54s	remaining: 18.3s
# 465:	learn: 0.5103307	total: 5.55s	remaining: 18.3s
# 466:	learn: 0.5103265	total: 5.57s	remaining: 18.3s
# 467:	learn: 0.5103214	total: 5.58s	remaining: 18.3s
# 468:	learn: 0.5103172	total: 5.59s	remaining: 18.2s
# 469:	learn: 0.5103119	total: 5.6s	remaining: 18.2s
# 470:	learn: 0.5103073	total: 5.61s	remaining: 18.2s
# 471:	learn: 0.5103036	total: 5.62s	remaining: 18.2s
# 472:	learn: 0.5102993	total: 5.63s	remaining: 18.2s
# 473:	learn: 0.5102940	total: 5.64s	remaining: 18.2s
# 474:	learn: 0.5102889	total: 5.65s	remaining: 18.1s
# 475:	learn: 0.5102845	total: 5.66s	remaining: 18.1s
# 476:	learn: 0.5102802	total: 5.67s	remaining: 18.1s
# 477:	learn: 0.5102757	total: 5.68s	remaining: 18.1s
# 478:	learn: 0.5102712	total: 5.69s	remaining: 18.1s
# 479:	learn: 0.5102655	total: 5.71s	remaining: 18.1s
# 480:	learn: 0.5102608	total: 5.72s	remaining: 18.1s
# 481:	learn: 0.5102566	total: 5.74s	remaining: 18.1s
# 482:	learn: 0.5102515	total: 5.75s	remaining: 18.1s
# 483:	learn: 0.5102465	total: 5.76s	remaining: 18.1s
# 484:	learn: 0.5102417	total: 5.78s	remaining: 18s
# 485:	learn: 0.5102364	total: 5.79s	remaining: 18s
# 486:	learn: 0.5102322	total: 5.8s	remaining: 18s
# 487:	learn: 0.5102283	total: 5.81s	remaining: 18s
# 488:	learn: 0.5102234	total: 5.82s	remaining: 18s
# 489:	learn: 0.5102186	total: 5.83s	remaining: 18s
# 490:	learn: 0.5102138	total: 5.84s	remaining: 18s
# 491:	learn: 0.5102087	total: 5.85s	remaining: 17.9s
# 492:	learn: 0.5102050	total: 5.87s	remaining: 17.9s
# 493:	learn: 0.5102006	total: 5.88s	remaining: 17.9s
# 494:	learn: 0.5101959	total: 5.89s	remaining: 17.9s
# 495:	learn: 0.5101907	total: 5.9s	remaining: 17.9s
# 496:	learn: 0.5101848	total: 5.91s	remaining: 17.9s
# 497:	learn: 0.5101795	total: 5.92s	remaining: 17.9s
# 498:	learn: 0.5101759	total: 5.94s	remaining: 17.9s
# 499:	learn: 0.5101706	total: 5.96s	remaining: 17.9s
# 500:	learn: 0.5101662	total: 5.97s	remaining: 17.9s
# 501:	learn: 0.5101615	total: 5.98s	remaining: 17.9s
# 502:	learn: 0.5101567	total: 5.99s	remaining: 17.8s
# 503:	learn: 0.5101522	total: 6s	remaining: 17.8s
# 504:	learn: 0.5101490	total: 6.01s	remaining: 17.8s
# 505:	learn: 0.5101437	total: 6.02s	remaining: 17.8s
# 506:	learn: 0.5101393	total: 6.04s	remaining: 17.8s
# 507:	learn: 0.5101351	total: 6.05s	remaining: 17.8s
# 508:	learn: 0.5101306	total: 6.06s	remaining: 17.7s
# 509:	learn: 0.5101260	total: 6.07s	remaining: 17.7s
# 510:	learn: 0.5101212	total: 6.08s	remaining: 17.7s
# 511:	learn: 0.5101172	total: 6.08s	remaining: 17.7s
# 512:	learn: 0.5101121	total: 6.1s	remaining: 17.7s
# 513:	learn: 0.5101078	total: 6.11s	remaining: 17.7s
# 514:	learn: 0.5101037	total: 6.12s	remaining: 17.6s
# 515:	learn: 0.5100980	total: 6.13s	remaining: 17.6s
# 516:	learn: 0.5100938	total: 6.15s	remaining: 17.7s
# 517:	learn: 0.5100891	total: 6.17s	remaining: 17.6s
# 518:	learn: 0.5100864	total: 6.18s	remaining: 17.6s
# 519:	learn: 0.5100833	total: 6.19s	remaining: 17.6s
# 520:	learn: 0.5100785	total: 6.2s	remaining: 17.6s
# 521:	learn: 0.5100741	total: 6.21s	remaining: 17.6s
# 522:	learn: 0.5100679	total: 6.22s	remaining: 17.6s
# 523:	learn: 0.5100642	total: 6.23s	remaining: 17.6s
# 524:	learn: 0.5100591	total: 6.24s	remaining: 17.5s
# 525:	learn: 0.5100554	total: 6.25s	remaining: 17.5s
# 526:	learn: 0.5100513	total: 6.26s	remaining: 17.5s
# 527:	learn: 0.5100468	total: 6.27s	remaining: 17.5s
# 528:	learn: 0.5100428	total: 6.29s	remaining: 17.5s
# 529:	learn: 0.5100395	total: 6.29s	remaining: 17.5s
# 530:	learn: 0.5100365	total: 6.3s	remaining: 17.4s
# 531:	learn: 0.5100311	total: 6.32s	remaining: 17.4s
# 532:	learn: 0.5100272	total: 6.33s	remaining: 17.4s
# 533:	learn: 0.5100230	total: 6.35s	remaining: 17.4s
# 534:	learn: 0.5100194	total: 6.36s	remaining: 17.4s
# 535:	learn: 0.5100159	total: 6.38s	remaining: 17.4s
# 536:	learn: 0.5100108	total: 6.39s	remaining: 17.4s
# 537:	learn: 0.5100061	total: 6.4s	remaining: 17.4s
# 538:	learn: 0.5100022	total: 6.41s	remaining: 17.4s
# 539:	learn: 0.5099974	total: 6.42s	remaining: 17.4s
# 540:	learn: 0.5099946	total: 6.43s	remaining: 17.3s
# 541:	learn: 0.5099902	total: 6.44s	remaining: 17.3s
# 542:	learn: 0.5099874	total: 6.45s	remaining: 17.3s
# 543:	learn: 0.5099826	total: 6.46s	remaining: 17.3s
# 544:	learn: 0.5099785	total: 6.47s	remaining: 17.3s
# 545:	learn: 0.5099751	total: 6.48s	remaining: 17.3s
# 546:	learn: 0.5099711	total: 6.49s	remaining: 17.3s
# 547:	learn: 0.5099670	total: 6.51s	remaining: 17.2s
# 548:	learn: 0.5099625	total: 6.52s	remaining: 17.2s
# 549:	learn: 0.5099593	total: 6.53s	remaining: 17.2s
# 550:	learn: 0.5099555	total: 6.54s	remaining: 17.2s
# 551:	learn: 0.5099506	total: 6.56s	remaining: 17.2s
# 552:	learn: 0.5099465	total: 6.58s	remaining: 17.2s
# 553:	learn: 0.5099426	total: 6.59s	remaining: 17.2s
# 554:	learn: 0.5099386	total: 6.6s	remaining: 17.2s
# 555:	learn: 0.5099340	total: 6.61s	remaining: 17.2s
# 556:	learn: 0.5099320	total: 6.62s	remaining: 17.1s
# 557:	learn: 0.5099277	total: 6.63s	remaining: 17.1s
# 558:	learn: 0.5099242	total: 6.64s	remaining: 17.1s
# 559:	learn: 0.5099189	total: 6.65s	remaining: 17.1s
# 560:	learn: 0.5099149	total: 6.66s	remaining: 17.1s
# 561:	learn: 0.5099106	total: 6.67s	remaining: 17.1s
# 562:	learn: 0.5099071	total: 6.68s	remaining: 17.1s
# 563:	learn: 0.5099025	total: 6.69s	remaining: 17s
# 564:	learn: 0.5098989	total: 6.7s	remaining: 17s
# 565:	learn: 0.5098942	total: 6.72s	remaining: 17s
# 566:	learn: 0.5098898	total: 6.73s	remaining: 17s
# 567:	learn: 0.5098857	total: 6.74s	remaining: 17s
# 568:	learn: 0.5098812	total: 6.76s	remaining: 17s
# 569:	learn: 0.5098767	total: 6.77s	remaining: 17s
# 570:	learn: 0.5098724	total: 6.79s	remaining: 17s
# 571:	learn: 0.5098677	total: 6.79s	remaining: 17s
# 572:	learn: 0.5098640	total: 6.81s	remaining: 17s
# 573:	learn: 0.5098598	total: 6.82s	remaining: 16.9s
# 574:	learn: 0.5098551	total: 6.83s	remaining: 16.9s
# 575:	learn: 0.5098509	total: 6.84s	remaining: 16.9s
# 576:	learn: 0.5098456	total: 6.85s	remaining: 16.9s
# 577:	learn: 0.5098414	total: 6.86s	remaining: 16.9s
# 578:	learn: 0.5098377	total: 6.87s	remaining: 16.9s
# 579:	learn: 0.5098330	total: 6.88s	remaining: 16.8s
# 580:	learn: 0.5098287	total: 6.89s	remaining: 16.8s
# 581:	learn: 0.5098247	total: 6.9s	remaining: 16.8s
# 582:	learn: 0.5098200	total: 6.91s	remaining: 16.8s
# 583:	learn: 0.5098162	total: 6.92s	remaining: 16.8s
# 584:	learn: 0.5098125	total: 6.93s	remaining: 16.8s
# 585:	learn: 0.5098081	total: 6.95s	remaining: 16.8s
# 586:	learn: 0.5098045	total: 6.96s	remaining: 16.8s
# 587:	learn: 0.5098011	total: 6.97s	remaining: 16.7s
# 588:	learn: 0.5097945	total: 6.99s	remaining: 16.7s
# 589:	learn: 0.5097908	total: 7s	remaining: 16.7s
# 590:	learn: 0.5097868	total: 7.01s	remaining: 16.7s
# 591:	learn: 0.5097823	total: 7.02s	remaining: 16.7s
# 592:	learn: 0.5097788	total: 7.03s	remaining: 16.7s
# 593:	learn: 0.5097745	total: 7.04s	remaining: 16.7s
# 594:	learn: 0.5097698	total: 7.05s	remaining: 16.7s
# 595:	learn: 0.5097657	total: 7.06s	remaining: 16.6s
# 596:	learn: 0.5097620	total: 7.07s	remaining: 16.6s
# 597:	learn: 0.5097580	total: 7.08s	remaining: 16.6s
# 598:	learn: 0.5097528	total: 7.09s	remaining: 16.6s
# 599:	learn: 0.5097480	total: 7.11s	remaining: 16.6s
# 600:	learn: 0.5097446	total: 7.11s	remaining: 16.6s
# 601:	learn: 0.5097406	total: 7.13s	remaining: 16.5s
# 602:	learn: 0.5097360	total: 7.14s	remaining: 16.5s
# 603:	learn: 0.5097319	total: 7.16s	remaining: 16.5s
# 604:	learn: 0.5097288	total: 7.17s	remaining: 16.5s
# 605:	learn: 0.5097251	total: 7.18s	remaining: 16.5s
# 606:	learn: 0.5097187	total: 7.19s	remaining: 16.5s
# 607:	learn: 0.5097157	total: 7.2s	remaining: 16.5s
# 608:	learn: 0.5097119	total: 7.21s	remaining: 16.5s
# 609:	learn: 0.5097079	total: 7.22s	remaining: 16.5s
# 610:	learn: 0.5097015	total: 7.23s	remaining: 16.4s
# 611:	learn: 0.5096976	total: 7.25s	remaining: 16.4s
# 612:	learn: 0.5096941	total: 7.26s	remaining: 16.4s
# 613:	learn: 0.5096907	total: 7.27s	remaining: 16.4s
# 614:	learn: 0.5096857	total: 7.28s	remaining: 16.4s
# 615:	learn: 0.5096818	total: 7.29s	remaining: 16.4s
# 616:	learn: 0.5096780	total: 7.3s	remaining: 16.4s
# 617:	learn: 0.5096737	total: 7.31s	remaining: 16.3s
# 618:	learn: 0.5096701	total: 7.32s	remaining: 16.3s
# 619:	learn: 0.5096673	total: 7.33s	remaining: 16.3s
# 620:	learn: 0.5096631	total: 7.34s	remaining: 16.3s
# 621:	learn: 0.5096592	total: 7.36s	remaining: 16.3s
# 622:	learn: 0.5096557	total: 7.38s	remaining: 16.3s
# 623:	learn: 0.5096521	total: 7.38s	remaining: 16.3s
# 624:	learn: 0.5096484	total: 7.39s	remaining: 16.3s
# 625:	learn: 0.5096441	total: 7.41s	remaining: 16.3s
# 626:	learn: 0.5096406	total: 7.42s	remaining: 16.2s
# 627:	learn: 0.5096360	total: 7.43s	remaining: 16.2s
# 628:	learn: 0.5096328	total: 7.44s	remaining: 16.2s
# 629:	learn: 0.5096255	total: 7.45s	remaining: 16.2s
# 630:	learn: 0.5096217	total: 7.46s	remaining: 16.2s
# 631:	learn: 0.5096180	total: 7.47s	remaining: 16.2s
# 632:	learn: 0.5096144	total: 7.48s	remaining: 16.2s
# 633:	learn: 0.5096108	total: 7.49s	remaining: 16.1s
# 634:	learn: 0.5096066	total: 7.5s	remaining: 16.1s
# 635:	learn: 0.5096027	total: 7.51s	remaining: 16.1s
# 636:	learn: 0.5095995	total: 7.52s	remaining: 16.1s
# 637:	learn: 0.5095959	total: 7.53s	remaining: 16.1s
# 638:	learn: 0.5095918	total: 7.55s	remaining: 16.1s
# 639:	learn: 0.5095871	total: 7.57s	remaining: 16.1s
# 640:	learn: 0.5095833	total: 7.58s	remaining: 16.1s
# 641:	learn: 0.5095801	total: 7.59s	remaining: 16.1s
# 642:	learn: 0.5095751	total: 7.6s	remaining: 16s
# 643:	learn: 0.5095712	total: 7.61s	remaining: 16s
# 644:	learn: 0.5095677	total: 7.62s	remaining: 16s
# 645:	learn: 0.5095648	total: 7.63s	remaining: 16s
# 646:	learn: 0.5095590	total: 7.64s	remaining: 16s
# 647:	learn: 0.5095556	total: 7.65s	remaining: 16s
# 648:	learn: 0.5095516	total: 7.67s	remaining: 16s
# 649:	learn: 0.5095476	total: 7.67s	remaining: 15.9s
# 650:	learn: 0.5095453	total: 7.68s	remaining: 15.9s
# 651:	learn: 0.5095423	total: 7.7s	remaining: 15.9s
# 652:	learn: 0.5095380	total: 7.71s	remaining: 15.9s
# 653:	learn: 0.5095337	total: 7.72s	remaining: 15.9s
# 654:	learn: 0.5095298	total: 7.73s	remaining: 15.9s
# 655:	learn: 0.5095266	total: 7.74s	remaining: 15.9s
# 656:	learn: 0.5095229	total: 7.76s	remaining: 15.9s
# 657:	learn: 0.5095187	total: 7.78s	remaining: 15.9s
# 658:	learn: 0.5095148	total: 7.79s	remaining: 15.8s
# 659:	learn: 0.5095117	total: 7.8s	remaining: 15.8s
# 660:	learn: 0.5095079	total: 7.81s	remaining: 15.8s
# 661:	learn: 0.5095056	total: 7.82s	remaining: 15.8s
# 662:	learn: 0.5095011	total: 7.83s	remaining: 15.8s
# 663:	learn: 0.5094969	total: 7.84s	remaining: 15.8s
# 664:	learn: 0.5094930	total: 7.85s	remaining: 15.8s
# 665:	learn: 0.5094889	total: 7.86s	remaining: 15.7s
# 666:	learn: 0.5094837	total: 7.87s	remaining: 15.7s
# 667:	learn: 0.5094798	total: 7.88s	remaining: 15.7s
# 668:	learn: 0.5094749	total: 7.89s	remaining: 15.7s
# 669:	learn: 0.5094715	total: 7.9s	remaining: 15.7s
# 670:	learn: 0.5094679	total: 7.91s	remaining: 15.7s
# 671:	learn: 0.5094638	total: 7.92s	remaining: 15.7s
# 672:	learn: 0.5094602	total: 7.94s	remaining: 15.6s
# 673:	learn: 0.5094566	total: 7.95s	remaining: 15.6s
# 674:	learn: 0.5094525	total: 7.97s	remaining: 15.6s
# 675:	learn: 0.5094487	total: 7.99s	remaining: 15.6s
# 676:	learn: 0.5094448	total: 8.01s	remaining: 15.6s
# 677:	learn: 0.5094414	total: 8.02s	remaining: 15.6s
# 678:	learn: 0.5094379	total: 8.04s	remaining: 15.6s
# 679:	learn: 0.5094340	total: 8.04s	remaining: 15.6s
# 680:	learn: 0.5094297	total: 8.05s	remaining: 15.6s
# 681:	learn: 0.5094266	total: 8.07s	remaining: 15.6s
# 682:	learn: 0.5094221	total: 8.08s	remaining: 15.6s
# 683:	learn: 0.5094193	total: 8.09s	remaining: 15.6s
# 684:	learn: 0.5094130	total: 8.1s	remaining: 15.5s
# 685:	learn: 0.5094095	total: 8.11s	remaining: 15.5s
# 686:	learn: 0.5094053	total: 8.12s	remaining: 15.5s
# 687:	learn: 0.5094017	total: 8.13s	remaining: 15.5s
# 688:	learn: 0.5093994	total: 8.14s	remaining: 15.5s
# 689:	learn: 0.5093950	total: 8.15s	remaining: 15.5s
# 690:	learn: 0.5093925	total: 8.17s	remaining: 15.5s
# 691:	learn: 0.5093873	total: 8.19s	remaining: 15.5s
# 692:	learn: 0.5093839	total: 8.2s	remaining: 15.5s
# 693:	learn: 0.5093797	total: 8.21s	remaining: 15.4s
# 694:	learn: 0.5093773	total: 8.22s	remaining: 15.4s
# 695:	learn: 0.5093733	total: 8.23s	remaining: 15.4s
# 696:	learn: 0.5093695	total: 8.24s	remaining: 15.4s
# 697:	learn: 0.5093656	total: 8.25s	remaining: 15.4s
# 698:	learn: 0.5093628	total: 8.26s	remaining: 15.4s
# 699:	learn: 0.5093587	total: 8.27s	remaining: 15.4s
# 700:	learn: 0.5093554	total: 8.28s	remaining: 15.3s
# 701:	learn: 0.5093515	total: 8.29s	remaining: 15.3s
# 702:	learn: 0.5093481	total: 8.3s	remaining: 15.3s
# 703:	learn: 0.5093439	total: 8.32s	remaining: 15.3s
# 704:	learn: 0.5093413	total: 8.33s	remaining: 15.3s
# 705:	learn: 0.5093365	total: 8.34s	remaining: 15.3s
# 706:	learn: 0.5093333	total: 8.35s	remaining: 15.3s
# 707:	learn: 0.5093307	total: 8.37s	remaining: 15.3s
# 708:	learn: 0.5093275	total: 8.38s	remaining: 15.3s
# 709:	learn: 0.5093229	total: 8.39s	remaining: 15.2s
# 710:	learn: 0.5093198	total: 8.4s	remaining: 15.2s
# 711:	learn: 0.5093163	total: 8.41s	remaining: 15.2s
# 712:	learn: 0.5093139	total: 8.42s	remaining: 15.2s
# 713:	learn: 0.5093094	total: 8.43s	remaining: 15.2s
# 714:	learn: 0.5093056	total: 8.44s	remaining: 15.2s
# 715:	learn: 0.5093017	total: 8.45s	remaining: 15.2s
# 716:	learn: 0.5092985	total: 8.46s	remaining: 15.1s
# 717:	learn: 0.5092947	total: 8.48s	remaining: 15.1s
# 718:	learn: 0.5092910	total: 8.49s	remaining: 15.1s
# 719:	learn: 0.5092870	total: 8.5s	remaining: 15.1s
# 720:	learn: 0.5092837	total: 8.51s	remaining: 15.1s
# 721:	learn: 0.5092783	total: 8.52s	remaining: 15.1s
# 722:	learn: 0.5092752	total: 8.53s	remaining: 15.1s
# 723:	learn: 0.5092722	total: 8.54s	remaining: 15.1s
# 724:	learn: 0.5092678	total: 8.55s	remaining: 15s
# 725:	learn: 0.5092648	total: 8.57s	remaining: 15s
# 726:	learn: 0.5092609	total: 8.58s	remaining: 15s
# 727:	learn: 0.5092571	total: 8.6s	remaining: 15s
# 728:	learn: 0.5092538	total: 8.61s	remaining: 15s
# 729:	learn: 0.5092504	total: 8.62s	remaining: 15s
# 730:	learn: 0.5092475	total: 8.63s	remaining: 15s
# 731:	learn: 0.5092435	total: 8.64s	remaining: 15s
# 732:	learn: 0.5092397	total: 8.65s	remaining: 14.9s
# 733:	learn: 0.5092358	total: 8.66s	remaining: 14.9s
# 734:	learn: 0.5092328	total: 8.67s	remaining: 14.9s
# 735:	learn: 0.5092294	total: 8.68s	remaining: 14.9s
# 736:	learn: 0.5092263	total: 8.69s	remaining: 14.9s
# 737:	learn: 0.5092225	total: 8.7s	remaining: 14.9s
# 738:	learn: 0.5092187	total: 8.71s	remaining: 14.9s
# 739:	learn: 0.5092148	total: 8.72s	remaining: 14.8s
# 740:	learn: 0.5092115	total: 8.73s	remaining: 14.8s
# 741:	learn: 0.5092085	total: 8.74s	remaining: 14.8s
# 742:	learn: 0.5092053	total: 8.75s	remaining: 14.8s
# 743:	learn: 0.5092013	total: 8.76s	remaining: 14.8s
# 744:	learn: 0.5091982	total: 8.78s	remaining: 14.8s
# 745:	learn: 0.5091951	total: 8.8s	remaining: 14.8s
# 746:	learn: 0.5091915	total: 8.81s	remaining: 14.8s
# 747:	learn: 0.5091859	total: 8.82s	remaining: 14.8s
# 748:	learn: 0.5091816	total: 8.83s	remaining: 14.7s
# 749:	learn: 0.5091785	total: 8.84s	remaining: 14.7s
# 750:	learn: 0.5091761	total: 8.85s	remaining: 14.7s
# 751:	learn: 0.5091719	total: 8.86s	remaining: 14.7s
# 752:	learn: 0.5091690	total: 8.87s	remaining: 14.7s
# 753:	learn: 0.5091654	total: 8.88s	remaining: 14.7s
# 754:	learn: 0.5091621	total: 8.89s	remaining: 14.7s
# 755:	learn: 0.5091593	total: 8.9s	remaining: 14.6s
# 756:	learn: 0.5091567	total: 8.91s	remaining: 14.6s
# 757:	learn: 0.5091514	total: 8.92s	remaining: 14.6s
# 758:	learn: 0.5091489	total: 8.93s	remaining: 14.6s
# 759:	learn: 0.5091462	total: 8.94s	remaining: 14.6s
# 760:	learn: 0.5091426	total: 8.95s	remaining: 14.6s
# 761:	learn: 0.5091393	total: 8.96s	remaining: 14.6s
# 762:	learn: 0.5091362	total: 8.98s	remaining: 14.6s
# 763:	learn: 0.5091323	total: 9s	remaining: 14.6s
# 764:	learn: 0.5091285	total: 9.01s	remaining: 14.5s
# 765:	learn: 0.5091256	total: 9.02s	remaining: 14.5s
# 766:	learn: 0.5091226	total: 9.03s	remaining: 14.5s
# 767:	learn: 0.5091187	total: 9.04s	remaining: 14.5s
# 768:	learn: 0.5091153	total: 9.05s	remaining: 14.5s
# 769:	learn: 0.5091110	total: 9.06s	remaining: 14.5s
# 770:	learn: 0.5091074	total: 9.07s	remaining: 14.5s
# 771:	learn: 0.5091038	total: 9.08s	remaining: 14.4s
# 772:	learn: 0.5090994	total: 9.09s	remaining: 14.4s
# 773:	learn: 0.5090961	total: 9.1s	remaining: 14.4s
# 774:	learn: 0.5090918	total: 9.11s	remaining: 14.4s
# 775:	learn: 0.5090887	total: 9.12s	remaining: 14.4s
# 776:	learn: 0.5090853	total: 9.13s	remaining: 14.4s
# 777:	learn: 0.5090820	total: 9.14s	remaining: 14.4s
# 778:	learn: 0.5090773	total: 9.15s	remaining: 14.3s
# 779:	learn: 0.5090743	total: 9.17s	remaining: 14.3s
# 780:	learn: 0.5090711	total: 9.19s	remaining: 14.3s
# 781:	learn: 0.5090682	total: 9.2s	remaining: 14.3s
# 782:	learn: 0.5090642	total: 9.21s	remaining: 14.3s
# 783:	learn: 0.5090616	total: 9.22s	remaining: 14.3s
# 784:	learn: 0.5090590	total: 9.23s	remaining: 14.3s
# 785:	learn: 0.5090545	total: 9.24s	remaining: 14.3s
# 786:	learn: 0.5090515	total: 9.26s	remaining: 14.3s
# 787:	learn: 0.5090488	total: 9.27s	remaining: 14.3s
# 788:	learn: 0.5090451	total: 9.28s	remaining: 14.2s
# 789:	learn: 0.5090415	total: 9.29s	remaining: 14.2s
# 790:	learn: 0.5090382	total: 9.3s	remaining: 14.2s
# 791:	learn: 0.5090353	total: 9.31s	remaining: 14.2s
# 792:	learn: 0.5090299	total: 9.32s	remaining: 14.2s
# 793:	learn: 0.5090258	total: 9.33s	remaining: 14.2s
# 794:	learn: 0.5090225	total: 9.34s	remaining: 14.2s
# 795:	learn: 0.5090194	total: 9.35s	remaining: 14.1s
# 796:	learn: 0.5090152	total: 9.36s	remaining: 14.1s
# 797:	learn: 0.5090101	total: 9.38s	remaining: 14.1s
# 798:	learn: 0.5090066	total: 9.39s	remaining: 14.1s
# 799:	learn: 0.5090030	total: 9.4s	remaining: 14.1s
# 800:	learn: 0.5090007	total: 9.41s	remaining: 14.1s
# 801:	learn: 0.5089983	total: 9.43s	remaining: 14.1s
# 802:	learn: 0.5089962	total: 9.43s	remaining: 14.1s
# 803:	learn: 0.5089915	total: 9.44s	remaining: 14s
# 804:	learn: 0.5089882	total: 9.46s	remaining: 14s
# 805:	learn: 0.5089841	total: 9.47s	remaining: 14s
# 806:	learn: 0.5089801	total: 9.48s	remaining: 14s
# 807:	learn: 0.5089766	total: 9.49s	remaining: 14s
# 808:	learn: 0.5089742	total: 9.5s	remaining: 14s
# 809:	learn: 0.5089700	total: 9.51s	remaining: 14s
# 810:	learn: 0.5089673	total: 9.52s	remaining: 14s
# 811:	learn: 0.5089644	total: 9.53s	remaining: 13.9s
# 812:	learn: 0.5089602	total: 9.54s	remaining: 13.9s
# 813:	learn: 0.5089569	total: 9.55s	remaining: 13.9s
# 814:	learn: 0.5089533	total: 9.56s	remaining: 13.9s
# 815:	learn: 0.5089502	total: 9.58s	remaining: 13.9s
# 816:	learn: 0.5089477	total: 9.59s	remaining: 13.9s
# 817:	learn: 0.5089442	total: 9.6s	remaining: 13.9s
# 818:	learn: 0.5089420	total: 9.61s	remaining: 13.9s
# 819:	learn: 0.5089387	total: 9.63s	remaining: 13.9s
# 820:	learn: 0.5089347	total: 9.64s	remaining: 13.8s
# 821:	learn: 0.5089321	total: 9.65s	remaining: 13.8s
# 822:	learn: 0.5089259	total: 9.66s	remaining: 13.8s
# 823:	learn: 0.5089220	total: 9.67s	remaining: 13.8s
# 824:	learn: 0.5089187	total: 9.68s	remaining: 13.8s
# 825:	learn: 0.5089145	total: 9.69s	remaining: 13.8s
# 826:	learn: 0.5089107	total: 9.7s	remaining: 13.8s
# 827:	learn: 0.5089070	total: 9.71s	remaining: 13.7s
# 828:	learn: 0.5089036	total: 9.72s	remaining: 13.7s
# 829:	learn: 0.5089009	total: 9.73s	remaining: 13.7s
# 830:	learn: 0.5088979	total: 9.74s	remaining: 13.7s
# 831:	learn: 0.5088958	total: 9.76s	remaining: 13.7s
# 832:	learn: 0.5088927	total: 9.77s	remaining: 13.7s
# 833:	learn: 0.5088896	total: 9.78s	remaining: 13.7s
# 834:	learn: 0.5088859	total: 9.8s	remaining: 13.7s
# 835:	learn: 0.5088824	total: 9.81s	remaining: 13.7s
# 836:	learn: 0.5088785	total: 9.82s	remaining: 13.6s
# 837:	learn: 0.5088747	total: 9.83s	remaining: 13.6s
# 838:	learn: 0.5088717	total: 9.84s	remaining: 13.6s
# 839:	learn: 0.5088684	total: 9.85s	remaining: 13.6s
# 840:	learn: 0.5088653	total: 9.86s	remaining: 13.6s
# 841:	learn: 0.5088625	total: 9.87s	remaining: 13.6s
# 842:	learn: 0.5088596	total: 9.88s	remaining: 13.6s
# 843:	learn: 0.5088564	total: 9.89s	remaining: 13.6s
# 844:	learn: 0.5088537	total: 9.9s	remaining: 13.5s
# 845:	learn: 0.5088502	total: 9.91s	remaining: 13.5s
# 846:	learn: 0.5088472	total: 9.93s	remaining: 13.5s
# 847:	learn: 0.5088438	total: 9.94s	remaining: 13.5s
# 848:	learn: 0.5088392	total: 9.95s	remaining: 13.5s
# 849:	learn: 0.5088367	total: 9.96s	remaining: 13.5s
# 850:	learn: 0.5088332	total: 9.97s	remaining: 13.5s
# 851:	learn: 0.5088305	total: 9.98s	remaining: 13.5s
# 852:	learn: 0.5088277	total: 10s	remaining: 13.4s
# 853:	learn: 0.5088243	total: 10s	remaining: 13.4s
# 854:	learn: 0.5088211	total: 10s	remaining: 13.4s
# 855:	learn: 0.5088179	total: 10s	remaining: 13.4s
# 856:	learn: 0.5088156	total: 10s	remaining: 13.4s
# 857:	learn: 0.5088115	total: 10.1s	remaining: 13.4s
# ...
# 1724:	learn: 0.5069589	total: 18.5s	remaining: 2.95s
# 1725:	learn: 0.5069562	total: 18.5s	remaining: 2.94s
# 1726:	learn: 0.5069537	total: 18.5s	remaining: 2.92s
# 1727:	learn: 0.5069514	total: 18.5s	remaining: 2.91s
# 1728:	learn: 0.5069483	total: 18.5s	remaining: 2.9s
# 1729:	learn: 0.5069453	total: 18.5s	remaining: 2.89s
# 1730:	learn: 0.5069426	total: 18.5s	remaining: 2.88s
# 1731:	learn: 0.5069401	total: 18.6s	remaining: 2.87s
# 1732:	learn: 0.5069373	total: 18.6s	remaining: 2.86s
# 1733:	learn: 0.5069347	total: 18.6s	remaining: 2.85s
# 1734:	learn: 0.5069317	total: 18.6s	remaining: 2.84s
# 1735:	learn: 0.5069295	total: 18.6s	remaining: 2.83s
# 1736:	learn: 0.5069267	total: 18.6s	remaining: 2.82s
# 1737:	learn: 0.5069242	total: 18.6s	remaining: 2.81s
# 1738:	learn: 0.5069221	total: 18.6s	remaining: 2.8s
# 1739:	learn: 0.5069200	total: 18.6s	remaining: 2.79s
# 1740:	learn: 0.5069181	total: 18.7s	remaining: 2.77s
# 1741:	learn: 0.5069153	total: 18.7s	remaining: 2.76s
# 1742:	learn: 0.5069126	total: 18.7s	remaining: 2.75s
# 1743:	learn: 0.5069106	total: 18.7s	remaining: 2.74s
# 1744:	learn: 0.5069077	total: 18.7s	remaining: 2.73s
# 1745:	learn: 0.5069051	total: 18.7s	remaining: 2.72s
# 1746:	learn: 0.5069022	total: 18.7s	remaining: 2.71s
# 1747:	learn: 0.5068998	total: 18.7s	remaining: 2.7s
# 1748:	learn: 0.5068974	total: 18.7s	remaining: 2.69s
# 1749:	learn: 0.5068944	total: 18.8s	remaining: 2.68s
# 1750:	learn: 0.5068920	total: 18.8s	remaining: 2.67s
# 1751:	learn: 0.5068891	total: 18.8s	remaining: 2.66s
# 1752:	learn: 0.5068865	total: 18.8s	remaining: 2.65s
# 1753:	learn: 0.5068842	total: 18.8s	remaining: 2.63s
# 1754:	learn: 0.5068810	total: 18.8s	remaining: 2.62s
# 1755:	learn: 0.5068788	total: 18.8s	remaining: 2.61s
# 1756:	learn: 0.5068769	total: 18.8s	remaining: 2.6s
# 1757:	learn: 0.5068728	total: 18.8s	remaining: 2.59s
# 1758:	learn: 0.5068700	total: 18.8s	remaining: 2.58s
# 1759:	learn: 0.5068671	total: 18.9s	remaining: 2.57s
# 1760:	learn: 0.5068644	total: 18.9s	remaining: 2.56s
# 1761:	learn: 0.5068620	total: 18.9s	remaining: 2.55s
# 1762:	learn: 0.5068602	total: 18.9s	remaining: 2.54s
# 1763:	learn: 0.5068573	total: 18.9s	remaining: 2.53s
# 1764:	learn: 0.5068551	total: 18.9s	remaining: 2.52s
# 1765:	learn: 0.5068527	total: 18.9s	remaining: 2.51s
# 1766:	learn: 0.5068497	total: 18.9s	remaining: 2.5s
# 1767:	learn: 0.5068478	total: 18.9s	remaining: 2.48s
# 1768:	learn: 0.5068452	total: 18.9s	remaining: 2.47s
# 1769:	learn: 0.5068428	total: 19s	remaining: 2.46s
# 1770:	learn: 0.5068397	total: 19s	remaining: 2.45s
# 1771:	learn: 0.5068374	total: 19s	remaining: 2.44s
# 1772:	learn: 0.5068356	total: 19s	remaining: 2.43s
# 1773:	learn: 0.5068326	total: 19s	remaining: 2.42s
# 1774:	learn: 0.5068292	total: 19s	remaining: 2.41s
# 1775:	learn: 0.5068263	total: 19s	remaining: 2.4s
# 1776:	learn: 0.5068237	total: 19s	remaining: 2.39s
# 1777:	learn: 0.5068216	total: 19s	remaining: 2.38s
# 1778:	learn: 0.5068191	total: 19.1s	remaining: 2.37s
# 1779:	learn: 0.5068162	total: 19.1s	remaining: 2.36s
# 1780:	learn: 0.5068140	total: 19.1s	remaining: 2.35s
# 1781:	learn: 0.5068109	total: 19.1s	remaining: 2.33s
# 1782:	learn: 0.5068082	total: 19.1s	remaining: 2.32s
# 1783:	learn: 0.5068059	total: 19.1s	remaining: 2.31s
# 1784:	learn: 0.5068036	total: 19.1s	remaining: 2.3s
# 1785:	learn: 0.5068008	total: 19.1s	remaining: 2.29s
# 1786:	learn: 0.5067982	total: 19.1s	remaining: 2.28s
# 1787:	learn: 0.5067955	total: 19.2s	remaining: 2.27s
# 1788:	learn: 0.5067925	total: 19.2s	remaining: 2.26s
# 1789:	learn: 0.5067901	total: 19.2s	remaining: 2.25s
# 1790:	learn: 0.5067875	total: 19.2s	remaining: 2.24s
# 1791:	learn: 0.5067858	total: 19.2s	remaining: 2.23s
# 1792:	learn: 0.5067823	total: 19.2s	remaining: 2.22s
# 1793:	learn: 0.5067805	total: 19.2s	remaining: 2.21s
# 1794:	learn: 0.5067773	total: 19.2s	remaining: 2.2s
# 1795:	learn: 0.5067750	total: 19.2s	remaining: 2.19s
# 1796:	learn: 0.5067719	total: 19.3s	remaining: 2.17s
# 1797:	learn: 0.5067700	total: 19.3s	remaining: 2.16s
# 1798:	learn: 0.5067669	total: 19.3s	remaining: 2.15s
# 1799:	learn: 0.5067645	total: 19.3s	remaining: 2.14s
# 1800:	learn: 0.5067618	total: 19.3s	remaining: 2.13s
# 1801:	learn: 0.5067604	total: 19.3s	remaining: 2.12s
# 1802:	learn: 0.5067574	total: 19.3s	remaining: 2.11s
# 1803:	learn: 0.5067552	total: 19.3s	remaining: 2.1s
# 1804:	learn: 0.5067521	total: 19.3s	remaining: 2.09s
# 1805:	learn: 0.5067496	total: 19.3s	remaining: 2.08s
# 1806:	learn: 0.5067481	total: 19.4s	remaining: 2.07s
# 1807:	learn: 0.5067448	total: 19.4s	remaining: 2.06s
# 1808:	learn: 0.5067414	total: 19.4s	remaining: 2.04s
# 1809:	learn: 0.5067389	total: 19.4s	remaining: 2.04s
# 1810:	learn: 0.5067354	total: 19.4s	remaining: 2.02s
# 1811:	learn: 0.5067331	total: 19.4s	remaining: 2.01s
# 1812:	learn: 0.5067309	total: 19.4s	remaining: 2s
# 1813:	learn: 0.5067286	total: 19.4s	remaining: 1.99s
# 1814:	learn: 0.5067263	total: 19.4s	remaining: 1.98s
# 1815:	learn: 0.5067234	total: 19.4s	remaining: 1.97s
# 1816:	learn: 0.5067209	total: 19.5s	remaining: 1.96s
# 1817:	learn: 0.5067178	total: 19.5s	remaining: 1.95s
# 1818:	learn: 0.5067162	total: 19.5s	remaining: 1.94s
# 1819:	learn: 0.5067136	total: 19.5s	remaining: 1.93s
# 1820:	learn: 0.5067106	total: 19.5s	remaining: 1.92s
# 1821:	learn: 0.5067087	total: 19.5s	remaining: 1.91s
# 1822:	learn: 0.5067063	total: 19.5s	remaining: 1.9s
# 1823:	learn: 0.5067036	total: 19.5s	remaining: 1.89s
# 1824:	learn: 0.5067012	total: 19.5s	remaining: 1.87s
# 1825:	learn: 0.5066993	total: 19.6s	remaining: 1.86s
# 1826:	learn: 0.5066974	total: 19.6s	remaining: 1.85s
# 1827:	learn: 0.5066948	total: 19.6s	remaining: 1.84s
# 1828:	learn: 0.5066924	total: 19.6s	remaining: 1.83s
# 1829:	learn: 0.5066897	total: 19.6s	remaining: 1.82s
# 1830:	learn: 0.5066871	total: 19.6s	remaining: 1.81s
# 1831:	learn: 0.5066845	total: 19.6s	remaining: 1.8s
# 1832:	learn: 0.5066818	total: 19.7s	remaining: 1.79s
# 1833:	learn: 0.5066788	total: 19.7s	remaining: 1.78s
# 1834:	learn: 0.5066754	total: 19.7s	remaining: 1.77s
# 1835:	learn: 0.5066723	total: 19.7s	remaining: 1.76s
# 1836:	learn: 0.5066691	total: 19.7s	remaining: 1.75s
# 1837:	learn: 0.5066669	total: 19.7s	remaining: 1.74s
# 1838:	learn: 0.5066647	total: 19.7s	remaining: 1.73s
# 1839:	learn: 0.5066614	total: 19.7s	remaining: 1.72s
# 1840:	learn: 0.5066584	total: 19.7s	remaining: 1.7s
# 1841:	learn: 0.5066556	total: 19.8s	remaining: 1.69s
# 1842:	learn: 0.5066528	total: 19.8s	remaining: 1.68s
# 1843:	learn: 0.5066506	total: 19.8s	remaining: 1.67s
# 1844:	learn: 0.5066485	total: 19.8s	remaining: 1.66s
# 1845:	learn: 0.5066457	total: 19.8s	remaining: 1.65s
# 1846:	learn: 0.5066431	total: 19.8s	remaining: 1.64s
# 1847:	learn: 0.5066404	total: 19.8s	remaining: 1.63s
# 1848:	learn: 0.5066382	total: 19.8s	remaining: 1.62s
# 1849:	learn: 0.5066359	total: 19.8s	remaining: 1.61s
# 1850:	learn: 0.5066335	total: 19.8s	remaining: 1.6s
# 1851:	learn: 0.5066308	total: 19.9s	remaining: 1.59s
# 1852:	learn: 0.5066280	total: 19.9s	remaining: 1.57s
# 1853:	learn: 0.5066255	total: 19.9s	remaining: 1.56s
# 1854:	learn: 0.5066234	total: 19.9s	remaining: 1.55s
# 1855:	learn: 0.5066210	total: 19.9s	remaining: 1.54s
# 1856:	learn: 0.5066186	total: 19.9s	remaining: 1.53s
# 1857:	learn: 0.5066166	total: 19.9s	remaining: 1.52s
# 1858:	learn: 0.5066148	total: 19.9s	remaining: 1.51s
# 1859:	learn: 0.5066126	total: 19.9s	remaining: 1.5s
# 1860:	learn: 0.5066101	total: 19.9s	remaining: 1.49s
# 1861:	learn: 0.5066081	total: 20s	remaining: 1.48s
# 1862:	learn: 0.5066053	total: 20s	remaining: 1.47s
# 1863:	learn: 0.5066024	total: 20s	remaining: 1.46s
# 1864:	learn: 0.5066000	total: 20s	remaining: 1.45s
# 1865:	learn: 0.5065977	total: 20s	remaining: 1.44s
# 1866:	learn: 0.5065952	total: 20s	remaining: 1.43s
# 1867:	learn: 0.5065921	total: 20s	remaining: 1.42s
# 1868:	learn: 0.5065897	total: 20s	remaining: 1.4s
# 1869:	learn: 0.5065880	total: 20s	remaining: 1.39s
# 1870:	learn: 0.5065854	total: 20.1s	remaining: 1.38s
# 1871:	learn: 0.5065821	total: 20.1s	remaining: 1.37s
# 1872:	learn: 0.5065796	total: 20.1s	remaining: 1.36s
# 1873:	learn: 0.5065769	total: 20.1s	remaining: 1.35s
# 1874:	learn: 0.5065743	total: 20.1s	remaining: 1.34s
# 1875:	learn: 0.5065719	total: 20.1s	remaining: 1.33s
# 1876:	learn: 0.5065698	total: 20.1s	remaining: 1.32s
# 1877:	learn: 0.5065677	total: 20.1s	remaining: 1.31s
# 1878:	learn: 0.5065653	total: 20.2s	remaining: 1.3s
# 1879:	learn: 0.5065622	total: 20.2s	remaining: 1.29s
# 1880:	learn: 0.5065598	total: 20.2s	remaining: 1.28s
# 1881:	learn: 0.5065578	total: 20.2s	remaining: 1.26s
# 1882:	learn: 0.5065555	total: 20.2s	remaining: 1.25s
# 1883:	learn: 0.5065532	total: 20.2s	remaining: 1.24s
# 1884:	learn: 0.5065499	total: 20.2s	remaining: 1.23s
# 1885:	learn: 0.5065467	total: 20.2s	remaining: 1.22s
# 1886:	learn: 0.5065447	total: 20.2s	remaining: 1.21s
# 1887:	learn: 0.5065430	total: 20.3s	remaining: 1.2s
# 1888:	learn: 0.5065400	total: 20.3s	remaining: 1.19s
# 1889:	learn: 0.5065376	total: 20.3s	remaining: 1.18s
# 1890:	learn: 0.5065354	total: 20.3s	remaining: 1.17s
# 1891:	learn: 0.5065335	total: 20.3s	remaining: 1.16s
# 1892:	learn: 0.5065302	total: 20.3s	remaining: 1.15s
# 1893:	learn: 0.5065277	total: 20.3s	remaining: 1.14s
# 1894:	learn: 0.5065250	total: 20.3s	remaining: 1.13s
# 1895:	learn: 0.5065234	total: 20.3s	remaining: 1.11s
# 1896:	learn: 0.5065209	total: 20.4s	remaining: 1.1s
# 1897:	learn: 0.5065190	total: 20.4s	remaining: 1.09s
# 1898:	learn: 0.5065164	total: 20.4s	remaining: 1.08s
# 1899:	learn: 0.5065135	total: 20.4s	remaining: 1.07s
# 1900:	learn: 0.5065111	total: 20.4s	remaining: 1.06s
# 1901:	learn: 0.5065085	total: 20.4s	remaining: 1.05s
# 1902:	learn: 0.5065058	total: 20.4s	remaining: 1.04s
# 1903:	learn: 0.5065042	total: 20.4s	remaining: 1.03s
# 1904:	learn: 0.5065017	total: 20.4s	remaining: 1.02s
# 1905:	learn: 0.5064994	total: 20.5s	remaining: 1.01s
# 1906:	learn: 0.5064977	total: 20.5s	remaining: 998ms
# 1907:	learn: 0.5064941	total: 20.5s	remaining: 987ms
# 1908:	learn: 0.5064916	total: 20.5s	remaining: 976ms
# 1909:	learn: 0.5064896	total: 20.5s	remaining: 966ms
# 1910:	learn: 0.5064870	total: 20.5s	remaining: 955ms
# 1911:	learn: 0.5064844	total: 20.5s	remaining: 944ms
# 1912:	learn: 0.5064822	total: 20.5s	remaining: 933ms
# 1913:	learn: 0.5064796	total: 20.5s	remaining: 923ms
# 1914:	learn: 0.5064765	total: 20.5s	remaining: 912ms
# 1915:	learn: 0.5064740	total: 20.6s	remaining: 901ms
# 1916:	learn: 0.5064713	total: 20.6s	remaining: 890ms
# 1917:	learn: 0.5064686	total: 20.6s	remaining: 880ms
# 1918:	learn: 0.5064661	total: 20.6s	remaining: 869ms
# 1919:	learn: 0.5064639	total: 20.6s	remaining: 858ms
# 1920:	learn: 0.5064617	total: 20.6s	remaining: 847ms
# 1921:	learn: 0.5064594	total: 20.6s	remaining: 837ms
# 1922:	learn: 0.5064576	total: 20.6s	remaining: 826ms
# 1923:	learn: 0.5064549	total: 20.6s	remaining: 815ms
# 1924:	learn: 0.5064524	total: 20.6s	remaining: 804ms
# 1925:	learn: 0.5064499	total: 20.7s	remaining: 794ms
# 1926:	learn: 0.5064477	total: 20.7s	remaining: 783ms
# 1927:	learn: 0.5064447	total: 20.7s	remaining: 772ms
# 1928:	learn: 0.5064423	total: 20.7s	remaining: 762ms
# 1929:	learn: 0.5064396	total: 20.7s	remaining: 751ms
# 1930:	learn: 0.5064368	total: 20.7s	remaining: 740ms
# 1931:	learn: 0.5064343	total: 20.7s	remaining: 729ms
# 1932:	learn: 0.5064319	total: 20.7s	remaining: 719ms
# 1933:	learn: 0.5064291	total: 20.7s	remaining: 708ms
# 1934:	learn: 0.5064266	total: 20.8s	remaining: 697ms
# 1935:	learn: 0.5064241	total: 20.8s	remaining: 686ms
# 1936:	learn: 0.5064205	total: 20.8s	remaining: 676ms
# 1937:	learn: 0.5064182	total: 20.8s	remaining: 665ms
# 1938:	learn: 0.5064153	total: 20.8s	remaining: 654ms
# 1939:	learn: 0.5064131	total: 20.8s	remaining: 644ms
# 1940:	learn: 0.5064107	total: 20.8s	remaining: 633ms
# 1941:	learn: 0.5064080	total: 20.8s	remaining: 622ms
# 1942:	learn: 0.5064059	total: 20.8s	remaining: 611ms
# 1943:	learn: 0.5064033	total: 20.9s	remaining: 601ms
# 1944:	learn: 0.5064009	total: 20.9s	remaining: 590ms
# 1945:	learn: 0.5063982	total: 20.9s	remaining: 579ms
# 1946:	learn: 0.5063961	total: 20.9s	remaining: 569ms
# 1947:	learn: 0.5063929	total: 20.9s	remaining: 558ms
# 1948:	learn: 0.5063904	total: 20.9s	remaining: 547ms
# 1949:	learn: 0.5063881	total: 20.9s	remaining: 536ms
# 1950:	learn: 0.5063855	total: 20.9s	remaining: 526ms
# 1951:	learn: 0.5063823	total: 20.9s	remaining: 515ms
# 1952:	learn: 0.5063801	total: 20.9s	remaining: 504ms
# 1953:	learn: 0.5063780	total: 21s	remaining: 493ms
# 1954:	learn: 0.5063751	total: 21s	remaining: 483ms
# 1955:	learn: 0.5063724	total: 21s	remaining: 472ms
# 1956:	learn: 0.5063703	total: 21s	remaining: 461ms
# 1957:	learn: 0.5063675	total: 21s	remaining: 451ms
# 1958:	learn: 0.5063651	total: 21s	remaining: 440ms
# 1959:	learn: 0.5063628	total: 21s	remaining: 429ms
# 1960:	learn: 0.5063603	total: 21s	remaining: 418ms
# 1961:	learn: 0.5063578	total: 21.1s	remaining: 408ms
# 1962:	learn: 0.5063547	total: 21.1s	remaining: 397ms
# 1963:	learn: 0.5063527	total: 21.1s	remaining: 386ms
# 1964:	learn: 0.5063499	total: 21.1s	remaining: 376ms
# 1965:	learn: 0.5063484	total: 21.1s	remaining: 365ms
# 1966:	learn: 0.5063453	total: 21.1s	remaining: 354ms
# 1967:	learn: 0.5063426	total: 21.1s	remaining: 343ms
# 1968:	learn: 0.5063400	total: 21.1s	remaining: 333ms
# 1969:	learn: 0.5063374	total: 21.1s	remaining: 322ms
# 1970:	learn: 0.5063354	total: 21.1s	remaining: 311ms
# 1971:	learn: 0.5063326	total: 21.2s	remaining: 300ms
# 1972:	learn: 0.5063310	total: 21.2s	remaining: 290ms
# 1973:	learn: 0.5063279	total: 21.2s	remaining: 279ms
# 1974:	learn: 0.5063258	total: 21.2s	remaining: 268ms
# 1975:	learn: 0.5063236	total: 21.2s	remaining: 257ms
# 1976:	learn: 0.5063210	total: 21.2s	remaining: 247ms
# 1977:	learn: 0.5063183	total: 21.2s	remaining: 236ms
# 1978:	learn: 0.5063160	total: 21.2s	remaining: 225ms
# 1979:	learn: 0.5063138	total: 21.2s	remaining: 215ms
# 1980:	learn: 0.5063115	total: 21.3s	remaining: 204ms
# 1981:	learn: 0.5063088	total: 21.3s	remaining: 193ms
# 1982:	learn: 0.5063069	total: 21.3s	remaining: 182ms
# 1983:	learn: 0.5063046	total: 21.3s	remaining: 172ms
# 1984:	learn: 0.5063014	total: 21.3s	remaining: 161ms
# 1985:	learn: 0.5062988	total: 21.3s	remaining: 150ms
# 1986:	learn: 0.5062962	total: 21.3s	remaining: 139ms
# 1987:	learn: 0.5062940	total: 21.3s	remaining: 129ms
# 1988:	learn: 0.5062910	total: 21.3s	remaining: 118ms
# 1989:	learn: 0.5062886	total: 21.3s	remaining: 107ms
# 1990:	learn: 0.5062860	total: 21.4s	remaining: 96.6ms
# 1991:	learn: 0.5062837	total: 21.4s	remaining: 85.8ms
# 1992:	learn: 0.5062810	total: 21.4s	remaining: 75.1ms
# 1993:	learn: 0.5062788	total: 21.4s	remaining: 64.4ms
# 1994:	learn: 0.5062762	total: 21.4s	remaining: 53.6ms
# 1995:	learn: 0.5062739	total: 21.4s	remaining: 42.9ms
# 1996:	learn: 0.5062717	total: 21.4s	remaining: 32.2ms
# 1997:	learn: 0.5062686	total: 21.4s	remaining: 21.5ms
# 1998:	learn: 0.5062663	total: 21.4s	remaining: 10.7ms
# 1999:	learn: 0.5062636	total: 21.5s	remaining: 0us
# Valid log-loss is 0.5077745778849044
# Valid AUC is 0.8140873972216598
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-3787e0508bd4> in <module>
# ----> 1 X_augment, y_augment = super_cross_validation() # default args; should provide first layer
#       2 X_augment_df = pd.DataFrame(X_augment, columns=[str(x) for x in range(X_augment.shape[1])])
#       3 X_augment_df.to_feather(datapath/'X_super-learner_augment.feather')
#       4 dump(y_augment, datapath/'y_super-learner_augment.joblib')
#
# <ipython-input-27-b240f9ec60ac> in super_cross_validation(model_list, X, y, start_fold, exmodel_config, random_state)
#      82
#      83 #                 wandb.finish()
# ---> 84     return np.vstack(X_meta), np.asarray(y_meta)
#      85
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~/anaconda3/envs/tabular/lib/python3.8/site-packages/numpy/core/shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 574752 and the array at index 4 has size 574749

# %%
from sklearn.linear_model import LogisticRegression

# %%
meta_model = LogisticRegression(n_jobs=-1)
meta_model.fit(X_augment, y_augment)
dump(meta_model, Path(datapath/f"models/{config_run['name']}_{exmodel_config['kfolds']}folds/meta-model_LogisticRegression.joblib"))

# %%
# def super_fit_fullset(X,y,model_list):
#     for model in model_list:
#         model[1].fit(X,y)

# %%
# def super_learner_predictor(X, model_list, meta_model):
#     X_meta = []
#     for model in model_list:
#         y_pred = model[1].predict_proba(X)
#         X_meta.append(y_pred)
#     X_meta = np.hstack(X_meta)
#     return meta_model.predict(X_meta)

# %%
# # might encapsulate this in a new version of the above train function later
# exmodel_config['ensemble'] = 'mlens.ensemble.SuperLearner'

# wandb.init(
#         project="202109_Kaggle_tabular_playground",
#         save_code=True,
#         tags=config_run['tags'],
#         name=config_run['name'],
#         notes=config_run['notes'],
#         config=exmodel_config)   

# random_state = exmodel_config['random_state'] # 42

# model_config = model_configurator('xgboost')
# xgboost_model = XGBClassifier(
#             tree_method=model_config['tree_method'],
#             random_state=random_state,
# #             n_jobs=model_config['n_jobs'], 
#             verbosity=model_config['verbosity'], 
#             objective=model_config['objective'],
#             # #             eval_metric=model_config['eval_metric'],

#             # comment out the below for a fairly default model
# #             booster=model_config['booster'],
#             max_depth=model_config['max_depth'],
#             learning_rate=model_config['learning_rate'], 
#             subsample=model_config['subsample'],
#             reg_alpha=model_config['reg_alpha'],
#             reg_lambda=model_config['reg_lambda'],
#             n_estimators=model_config['n_estimators'],
#         )

# model_config = model_configurator('lightgbm')
# lightgbm_model = LGBMClassifier(
#             random_state=random_state,
# #             n_jobs=model_config['n_jobs'],
#             objective=model_config['objective'],
#             boosting_type=model_config['boosting_type'],
#             device_type=model_config['device_type'],
            
#             # comment out the below for a basically default model
#             n_estimators=model_config['n_estimators'],
#             learning_rate=model_config['learning_rate'],
#             max_depth=model_config['max_depth'],
#             reg_alpha=model_config['reg_alpha'],
#             reg_lambda=model_config['reg_lambda'],
#             subsample=model_config['subsample'],
#         )

# model_config = model_configurator('catboost', gpu_available=False) # set GPU false to avoid parallel threads blocking GPU
# catboost_model = CatBoostClassifier(
#             task_type=model_config['task_type'],
#             n_estimators=model_config['n_estimators'],
#             random_state=random_state,
#         ) 

# blender = SuperLearner(folds=5, 
#                              shuffle=False, 
#                              random_state=random_state,
#                              n_jobs=3,
#                              verbose=1,
# #                              scorer=roc_auc_score,
#                             )

# estimators_list = [
#     ('xgboost', xgboost_model),
#     ('lightgbm', lightgbm_model),
#     ('catboost', catboost_model)
# ]

# blender.add(estimators_list, 
#                   proba=True, # ensures use of predict_proba
#                   propagate_features=False # seemed to work better in stacking
#                  )

# blender.add_meta(LogisticRegression()) # a simple linear model should work best

# # wandb.log({'estimators': estimators_list})


# # blender = StackingClassifier(estimators=estimators_list,
# # #                              final_estimator=XGBRegressor(),
# #                              cv=5,
# #                              stack_method='predict_proba',
# #                              n_jobs=3,
# #                              passthrough=True,
# #                              verbose=1
# #                             )
# exmodel_config['blender-passthrough'] = False
# # exmodel_config['blender_final_estimator'] =
# Out:
# wandb: Currently logged in as: hushifang (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">super-learner_off-shelf_20210911_204351</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1ebqj2pm" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1ebqj2pm</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210911_204352-1ebqj2pm</code><br/><br/>

# %%
# wandb.log({'blender-final_estimator': LogisticRegression,
# #            'blender-final_estimator_params': str(blender.final_estimator.get_params()),
#            'blender-stack_mdethod': 'predict_proba',
#            'blender-cv': 5
#           })

# %%
# print(f"Starting fitting at {datetime.now().strftime('%Y%m%d_%H%M%S')}")
# blender.fit(X,y) # unsure of this -- given kwarg cv=5, is it producing the splits? Or do I have to somehow?
# print(f"Fitting complete at {datetime.now().strftime('%Y%m%d_%H%M%S')}")
# Out:
# Starting fitting at 20210911_204425
#
# Fitting 2 layers
# Learning rate set to 0.10231
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# 0:	learn: 0.6549103	total: 770ms	remaining: 25m 39s
# Learning rate set to 0.093011
# Learning rate set to 0.093011
# 1:	learn: 0.6248772	total: 1.29s	remaining: 21m 33s
# 0:	learn: 0.6582614	total: 248ms	remaining: 8m 16s
# 2:	learn: 0.6012832	total: 1.64s	remaining: 18m 12s
# 1:	learn: 0.6302052	total: 509ms	remaining: 8m 28s
# 0:	learn: 0.6581684	total: 339ms	remaining: 11m 16s
# 2:	learn: 0.6076621	total: 790ms	remaining: 8m 46s
# 3:	learn: 0.5827574	total: 1.96s	remaining: 16m 19s
# 1:	learn: 0.6300503	total: 745ms	remaining: 12m 23s
# 3:	learn: 0.5895252	total: 1.08s	remaining: 9m 1s
# 4:	learn: 0.5681846	total: 2.34s	remaining: 15m 32s
# 2:	learn: 0.6074422	total: 1.09s	remaining: 12m 5s
# 4:	learn: 0.5749554	total: 1.37s	remaining: 9m 5s
# 5:	learn: 0.5567044	total: 2.67s	remaining: 14m 46s
# 3:	learn: 0.5892795	total: 1.35s	remaining: 11m 16s
# 5:	learn: 0.5632307	total: 1.62s	remaining: 8m 58s
# 6:	learn: 0.5476754	total: 2.98s	remaining: 14m 9s
# 4:	learn: 0.5746635	total: 1.68s	remaining: 11m 10s
# 6:	learn: 0.5537855	total: 1.9s	remaining: 9m 1s
# 5:	learn: 0.5628879	total: 1.92s	remaining: 10m 36s
# 7:	learn: 0.5405359	total: 3.3s	remaining: 13m 41s
# 7:	learn: 0.5461535	total: 2.15s	remaining: 8m 54s
# 8:	learn: 0.5399928	total: 2.46s	remaining: 9m 3s
# 8:	learn: 0.5348910	total: 3.63s	remaining: 13m 23s
# 6:	learn: 0.5534214	total: 2.27s	remaining: 10m 45s
# 9:	learn: 0.5350143	total: 2.7s	remaining: 8m 58s
# 7:	learn: 0.5457717	total: 2.55s	remaining: 10m 35s
# 9:	learn: 0.5304279	total: 3.99s	remaining: 13m 14s
# 10:	learn: 0.5309882	total: 3s	remaining: 9m 2s
# 8:	learn: 0.5395955	total: 2.85s	remaining: 10m 30s
# 10:	learn: 0.5268835	total: 4.36s	remaining: 13m 7s
# 11:	learn: 0.5277171	total: 3.29s	remaining: 9m 5s
# 9:	learn: 0.5346038	total: 3.11s	remaining: 10m 18s
# 11:	learn: 0.5240562	total: 4.71s	remaining: 13m
# 12:	learn: 0.5250705	total: 3.62s	remaining: 9m 13s
# 10:	learn: 0.5305668	total: 3.45s	remaining: 10m 23s
# 12:	learn: 0.5217899	total: 5.03s	remaining: 12m 48s
# 13:	learn: 0.5229013	total: 3.92s	remaining: 9m 15s
# 11:	learn: 0.5272994	total: 3.73s	remaining: 10m 17s
# 13:	learn: 0.5199672	total: 5.33s	remaining: 12m 35s
# 14:	learn: 0.5211333	total: 4.23s	remaining: 9m 20s
# 12:	learn: 0.5246489	total: 4.06s	remaining: 10m 20s
# 14:	learn: 0.5185247	total: 5.61s	remaining: 12m 22s
# 15:	learn: 0.5197742	total: 4.47s	remaining: 9m 14s
# 13:	learn: 0.5224690	total: 4.36s	remaining: 10m 18s
# 16:	learn: 0.5185783	total: 4.76s	remaining: 9m 15s
# 15:	learn: 0.5173781	total: 5.94s	remaining: 12m 16s
# 14:	learn: 0.5206848	total: 4.59s	remaining: 10m 6s
# 15:	learn: 0.5192444	total: 4.82s	remaining: 9m 57s
# 17:	learn: 0.5175792	total: 5.05s	remaining: 9m 15s
# 16:	learn: 0.5164554	total: 6.26s	remaining: 12m 9s
# 16:	learn: 0.5180608	total: 5.1s	remaining: 9m 54s
# 18:	learn: 0.5167888	total: 5.36s	remaining: 9m 18s
# 17:	learn: 0.5157480	total: 6.54s	remaining: 12m
# 17:	learn: 0.5170846	total: 5.38s	remaining: 9m 52s
# 19:	learn: 0.5161196	total: 5.62s	remaining: 9m 16s
# 18:	learn: 0.5151064	total: 6.89s	remaining: 11m 58s
# 20:	learn: 0.5155847	total: 5.84s	remaining: 9m 10s
# 18:	learn: 0.5163219	total: 5.68s	remaining: 9m 52s
# 19:	learn: 0.5145644	total: 7.18s	remaining: 11m 51s
# 21:	learn: 0.5151559	total: 6.12s	remaining: 9m 10s
# 19:	learn: 0.5156910	total: 6.03s	remaining: 9m 57s
# 20:	learn: 0.5141085	total: 7.43s	remaining: 11m 40s
# 22:	learn: 0.5147825	total: 6.43s	remaining: 9m 13s
# 20:	learn: 0.5151083	total: 6.27s	remaining: 9m 50s
# 21:	learn: 0.5137705	total: 7.75s	remaining: 11m 36s
# 23:	learn: 0.5144891	total: 6.71s	remaining: 9m 12s
# 21:	learn: 0.5146351	total: 6.55s	remaining: 9m 49s
# 22:	learn: 0.5135075	total: 8.09s	remaining: 11m 35s
# 24:	learn: 0.5141840	total: 6.97s	remaining: 9m 10s
# 22:	learn: 0.5142611	total: 6.75s	remaining: 9m 40s
# 25:	learn: 0.5139575	total: 7.2s	remaining: 9m 6s
# 23:	learn: 0.5132776	total: 8.37s	remaining: 11m 28s
# 23:	learn: 0.5139252	total: 7.05s	remaining: 9m 40s
# 26:	learn: 0.5137584	total: 7.44s	remaining: 9m 3s
# 24:	learn: 0.5130949	total: 8.67s	remaining: 11m 24s
# 24:	learn: 0.5136269	total: 7.35s	remaining: 9m 41s
# 27:	learn: 0.5135702	total: 7.67s	remaining: 9m
# 25:	learn: 0.5129130	total: 9s	remaining: 11m 23s
# 25:	learn: 0.5134186	total: 7.62s	remaining: 9m 38s
# 28:	learn: 0.5134085	total: 7.99s	remaining: 9m 3s
# 26:	learn: 0.5132187	total: 7.9s	remaining: 9m 37s
# 26:	learn: 0.5127563	total: 9.33s	remaining: 11m 22s
# 29:	learn: 0.5132617	total: 8.28s	remaining: 9m 3s
# 27:	learn: 0.5130399	total: 8.21s	remaining: 9m 38s
# 27:	learn: 0.5126294	total: 9.65s	remaining: 11m 19s
# 30:	learn: 0.5131279	total: 8.52s	remaining: 9m
# 28:	learn: 0.5128634	total: 8.42s	remaining: 9m 32s
# 31:	learn: 0.5130091	total: 8.81s	remaining: 9m 1s
# 28:	learn: 0.5125050	total: 9.97s	remaining: 11m 17s
# 29:	learn: 0.5127093	total: 8.69s	remaining: 9m 30s
# 32:	learn: 0.5129069	total: 9.08s	remaining: 9m
# 30:	learn: 0.5125719	total: 8.94s	remaining: 9m 28s
# 29:	learn: 0.5123953	total: 10.4s	remaining: 11m 20s
# 33:	learn: 0.5127992	total: 9.34s	remaining: 9m
# 31:	learn: 0.5124500	total: 9.22s	remaining: 9m 27s
# 30:	learn: 0.5122969	total: 10.7s	remaining: 11m 17s
# 34:	learn: 0.5127072	total: 9.59s	remaining: 8m 58s
# 32:	learn: 0.5123401	total: 9.51s	remaining: 9m 26s
# 31:	learn: 0.5122063	total: 11s	remaining: 11m 15s
# 35:	learn: 0.5126168	total: 9.85s	remaining: 8m 57s
# 33:	learn: 0.5122491	total: 9.75s	remaining: 9m 24s
# 32:	learn: 0.5121087	total: 11.2s	remaining: 11m 9s
# 36:	learn: 0.5125311	total: 10.2s	remaining: 8m 59s
# 34:	learn: 0.5121579	total: 10s	remaining: 9m 22s
# 33:	learn: 0.5120470	total: 11.6s	remaining: 11m 8s
# 37:	learn: 0.5124644	total: 10.4s	remaining: 8m 57s
# 35:	learn: 0.5120718	total: 10.3s	remaining: 9m 19s
# 34:	learn: 0.5119794	total: 11.9s	remaining: 11m 5s
# 36:	learn: 0.5119927	total: 10.5s	remaining: 9m 16s
# 38:	learn: 0.5123921	total: 10.7s	remaining: 9m
# 35:	learn: 0.5119247	total: 12.1s	remaining: 11m 2s
# 39:	learn: 0.5123287	total: 11s	remaining: 8m 59s
# 37:	learn: 0.5119292	total: 10.8s	remaining: 9m 18s
# 36:	learn: 0.5118632	total: 12.5s	remaining: 11m
# 40:	learn: 0.5122735	total: 11.3s	remaining: 9m
# 38:	learn: 0.5118609	total: 11.1s	remaining: 9m 19s
# 37:	learn: 0.5118010	total: 12.8s	remaining: 10m 58s
# 39:	learn: 0.5117975	total: 11.4s	remaining: 9m 17s
# 41:	learn: 0.5122093	total: 11.7s	remaining: 9m 3s
# 38:	learn: 0.5117445	total: 13s	remaining: 10m 55s
# 42:	learn: 0.5121535	total: 11.9s	remaining: 9m 3s
# 40:	learn: 0.5117389	total: 11.7s	remaining: 9m 20s
# 39:	learn: 0.5116919	total: 13.3s	remaining: 10m 53s
# 41:	learn: 0.5116856	total: 12s	remaining: 9m 19s
# 43:	learn: 0.5120993	total: 12.3s	remaining: 9m 5s
# 40:	learn: 0.5116358	total: 13.6s	remaining: 10m 50s
# 42:	learn: 0.5116351	total: 12.3s	remaining: 9m 19s
# 44:	learn: 0.5120490	total: 12.6s	remaining: 9m 6s
# 43:	learn: 0.5115777	total: 12.6s	remaining: 9m 18s
# 41:	learn: 0.5115766	total: 13.9s	remaining: 10m 49s
# 45:	learn: 0.5119934	total: 12.8s	remaining: 9m 3s
# 46:	learn: 0.5119505	total: 13.1s	remaining: 9m 4s
# 42:	learn: 0.5115207	total: 14.3s	remaining: 10m 49s
# 44:	learn: 0.5115261	total: 12.9s	remaining: 9m 21s
# 47:	learn: 0.5119020	total: 13.4s	remaining: 9m 4s
# 45:	learn: 0.5114744	total: 13.2s	remaining: 9m 20s
# 43:	learn: 0.5114640	total: 14.6s	remaining: 10m 48s
# 46:	learn: 0.5114248	total: 13.4s	remaining: 9m 17s
# 48:	learn: 0.5118496	total: 13.7s	remaining: 9m 5s
# 44:	learn: 0.5114211	total: 14.8s	remaining: 10m 44s
# 47:	learn: 0.5113732	total: 13.7s	remaining: 9m 16s
# 49:	learn: 0.5118019	total: 14s	remaining: 9m 5s
# 45:	learn: 0.5113715	total: 15.2s	remaining: 10m 44s
# 48:	learn: 0.5113209	total: 14s	remaining: 9m 16s
# 50:	learn: 0.5117583	total: 14.3s	remaining: 9m 5s
# 46:	learn: 0.5113189	total: 15.5s	remaining: 10m 45s
# 51:	learn: 0.5117142	total: 14.5s	remaining: 9m 3s
# 49:	learn: 0.5112722	total: 14.3s	remaining: 9m 16s
# 47:	learn: 0.5112745	total: 15.8s	remaining: 10m 43s
# 52:	learn: 0.5116743	total: 14.8s	remaining: 9m 2s
# 50:	learn: 0.5112249	total: 14.6s	remaining: 9m 17s
# 48:	learn: 0.5112331	total: 16.2s	remaining: 10m 43s
# 53:	learn: 0.5116315	total: 15s	remaining: 9m 1s
# 51:	learn: 0.5111882	total: 14.8s	remaining: 9m 15s
# 54:	learn: 0.5115922	total: 15.3s	remaining: 9m 1s
# 52:	learn: 0.5111449	total: 15.1s	remaining: 9m 14s
# 49:	learn: 0.5111867	total: 16.6s	remaining: 10m 45s
# 55:	learn: 0.5115530	total: 15.6s	remaining: 9m
# 53:	learn: 0.5111052	total: 15.4s	remaining: 9m 14s
# 50:	learn: 0.5111447	total: 16.9s	remaining: 10m 44s
# 54:	learn: 0.5110632	total: 15.6s	remaining: 9m 11s
# 56:	learn: 0.5115171	total: 15.9s	remaining: 9m 1s
# 51:	learn: 0.5111089	total: 17.2s	remaining: 10m 44s
# 55:	learn: 0.5110271	total: 15.8s	remaining: 9m 10s
# 57:	learn: 0.5114764	total: 16.2s	remaining: 9m 1s
# 56:	learn: 0.5109920	total: 16.1s	remaining: 9m 9s
# 52:	learn: 0.5110760	total: 17.5s	remaining: 10m 43s
# 58:	learn: 0.5114335	total: 16.5s	remaining: 9m 2s
# 53:	learn: 0.5110358	total: 17.8s	remaining: 10m 41s
# 57:	learn: 0.5109489	total: 16.4s	remaining: 9m 9s
# 59:	learn: 0.5114009	total: 16.8s	remaining: 9m 4s
# 58:	learn: 0.5109072	total: 16.7s	remaining: 9m 10s
# 54:	learn: 0.5109914	total: 18.1s	remaining: 10m 40s
# 60:	learn: 0.5113634	total: 17.2s	remaining: 9m 6s
# 59:	learn: 0.5108699	total: 17s	remaining: 9m 9s
# 55:	learn: 0.5109569	total: 18.5s	remaining: 10m 42s
# 61:	learn: 0.5113229	total: 17.5s	remaining: 9m 6s
# 60:	learn: 0.5108306	total: 17.4s	remaining: 9m 12s
# 62:	learn: 0.5112890	total: 17.7s	remaining: 9m 5s
# 56:	learn: 0.5109197	total: 18.9s	remaining: 10m 44s
# 61:	learn: 0.5107980	total: 17.6s	remaining: 9m 11s
# 63:	learn: 0.5112542	total: 18s	remaining: 9m 5s
# 57:	learn: 0.5108665	total: 19.2s	remaining: 10m 43s
# 62:	learn: 0.5107590	total: 17.9s	remaining: 9m 11s
# 58:	learn: 0.5108238	total: 19.5s	remaining: 10m 41s
# 64:	learn: 0.5112166	total: 18.4s	remaining: 9m 6s
# 63:	learn: 0.5107211	total: 18.2s	remaining: 9m 11s
# 65:	learn: 0.5111812	total: 18.6s	remaining: 9m 6s
# 59:	learn: 0.5107867	total: 19.8s	remaining: 10m 40s
# 64:	learn: 0.5106834	total: 18.5s	remaining: 9m 10s
# 66:	learn: 0.5111462	total: 18.9s	remaining: 9m 5s
# 60:	learn: 0.5107503	total: 20.2s	remaining: 10m 40s
# 65:	learn: 0.5106521	total: 18.8s	remaining: 9m 10s
# 67:	learn: 0.5111090	total: 19.1s	remaining: 9m 3s
# 66:	learn: 0.5106167	total: 19.1s	remaining: 9m 9s
# 61:	learn: 0.5107174	total: 20.5s	remaining: 10m 41s
# 68:	learn: 0.5110802	total: 19.4s	remaining: 9m 3s
# 67:	learn: 0.5105697	total: 19.4s	remaining: 9m 10s
# 62:	learn: 0.5106839	total: 20.8s	remaining: 10m 39s
# 69:	learn: 0.5110469	total: 19.7s	remaining: 9m 3s
# 68:	learn: 0.5105304	total: 19.7s	remaining: 9m 10s
# 63:	learn: 0.5106552	total: 21.1s	remaining: 10m 37s
# 70:	learn: 0.5110146	total: 20s	remaining: 9m 2s
# 69:	learn: 0.5104889	total: 19.9s	remaining: 9m 9s
# 64:	learn: 0.5106194	total: 21.4s	remaining: 10m 37s
# 71:	learn: 0.5109736	total: 20.3s	remaining: 9m 4s
# 70:	learn: 0.5104622	total: 20.2s	remaining: 9m 9s
# 65:	learn: 0.5105889	total: 21.7s	remaining: 10m 35s
# 72:	learn: 0.5109384	total: 20.6s	remaining: 9m 4s
# 71:	learn: 0.5104305	total: 20.5s	remaining: 9m 8s
# 66:	learn: 0.5105597	total: 22s	remaining: 10m 33s
# 73:	learn: 0.5109064	total: 21s	remaining: 9m 5s
# 72:	learn: 0.5104020	total: 20.8s	remaining: 9m 7s
# 67:	learn: 0.5105264	total: 22.3s	remaining: 10m 33s
# 74:	learn: 0.5108751	total: 21.3s	remaining: 9m 5s
# 73:	learn: 0.5103708	total: 21s	remaining: 9m 7s
# 68:	learn: 0.5105002	total: 22.6s	remaining: 10m 33s
# 75:	learn: 0.5108469	total: 21.5s	remaining: 9m 4s
# 74:	learn: 0.5103374	total: 21.2s	remaining: 9m 5s
# 76:	learn: 0.5108145	total: 21.8s	remaining: 9m 4s
# 69:	learn: 0.5104685	total: 22.9s	remaining: 10m 32s
# 75:	learn: 0.5103006	total: 21.5s	remaining: 9m 5s
# 77:	learn: 0.5107829	total: 22.1s	remaining: 9m 3s
# 76:	learn: 0.5102720	total: 21.9s	remaining: 9m 5s
# 70:	learn: 0.5104385	total: 23.3s	remaining: 10m 33s
# 78:	learn: 0.5107537	total: 22.4s	remaining: 9m 3s
# 77:	learn: 0.5102435	total: 22.2s	remaining: 9m 5s
# 71:	learn: 0.5104088	total: 23.6s	remaining: 10m 30s
# 79:	learn: 0.5107141	total: 22.7s	remaining: 9m 3s
# 78:	learn: 0.5102131	total: 22.4s	remaining: 9m 5s
# 72:	learn: 0.5103750	total: 23.9s	remaining: 10m 29s
# 80:	learn: 0.5106833	total: 22.9s	remaining: 9m 3s
# 79:	learn: 0.5101811	total: 22.7s	remaining: 9m 5s
# 73:	learn: 0.5103381	total: 24.2s	remaining: 10m 30s
# 81:	learn: 0.5106511	total: 23.2s	remaining: 9m 2s
# 80:	learn: 0.5101544	total: 23s	remaining: 9m 5s
# 82:	learn: 0.5106185	total: 23.5s	remaining: 9m 1s
# 74:	learn: 0.5103086	total: 24.6s	remaining: 10m 31s
# 81:	learn: 0.5101257	total: 23.3s	remaining: 9m 4s
# 83:	learn: 0.5105854	total: 23.8s	remaining: 9m 1s
# 75:	learn: 0.5102822	total: 24.9s	remaining: 10m 30s
# 82:	learn: 0.5100816	total: 23.5s	remaining: 9m 3s
# 84:	learn: 0.5105486	total: 24s	remaining: 9m 1s
# 76:	learn: 0.5102503	total: 25.2s	remaining: 10m 29s
# 83:	learn: 0.5100511	total: 23.9s	remaining: 9m 5s
# 85:	learn: 0.5105183	total: 24.3s	remaining: 8m 59s
# 77:	learn: 0.5102223	total: 25.5s	remaining: 10m 29s
# 84:	learn: 0.5100154	total: 24.2s	remaining: 9m 4s
# 86:	learn: 0.5104792	total: 24.5s	remaining: 8m 57s
# 78:	learn: 0.5101873	total: 25.9s	remaining: 10m 28s
# 85:	learn: 0.5099903	total: 24.5s	remaining: 9m 4s
# 87:	learn: 0.5104488	total: 24.8s	remaining: 8m 58s
# 79:	learn: 0.5101510	total: 26.1s	remaining: 10m 27s
# 86:	learn: 0.5099577	total: 24.8s	remaining: 9m 4s
# 88:	learn: 0.5104197	total: 25.1s	remaining: 8m 58s
# 87:	learn: 0.5099299	total: 25s	remaining: 9m 3s
# 80:	learn: 0.5101211	total: 26.5s	remaining: 10m 27s
# 89:	learn: 0.5103945	total: 25.3s	remaining: 8m 57s
# 88:	learn: 0.5099016	total: 25.3s	remaining: 9m 3s
# 90:	learn: 0.5103671	total: 25.6s	remaining: 8m 57s
# 81:	learn: 0.5100954	total: 26.8s	remaining: 10m 27s
# 89:	learn: 0.5098728	total: 25.6s	remaining: 9m 3s
# 91:	learn: 0.5103412	total: 25.9s	remaining: 8m 57s
# 82:	learn: 0.5100656	total: 27.2s	remaining: 10m 27s
# 90:	learn: 0.5098466	total: 25.8s	remaining: 9m 1s
# 92:	learn: 0.5103132	total: 26.2s	remaining: 8m 57s
# 83:	learn: 0.5100392	total: 27.5s	remaining: 10m 26s
# 91:	learn: 0.5098195	total: 26.1s	remaining: 9m 2s
# 93:	learn: 0.5102838	total: 26.5s	remaining: 8m 58s
# 84:	learn: 0.5100112	total: 27.8s	remaining: 10m 25s
# 92:	learn: 0.5097936	total: 26.5s	remaining: 9m 2s
# 94:	learn: 0.5102598	total: 26.8s	remaining: 8m 57s
# 93:	learn: 0.5097660	total: 26.7s	remaining: 9m 1s
# 85:	learn: 0.5099821	total: 28.1s	remaining: 10m 25s
# 95:	learn: 0.5102323	total: 27.1s	remaining: 8m 57s
# 94:	learn: 0.5097332	total: 26.9s	remaining: 9m
# 86:	learn: 0.5099540	total: 28.5s	remaining: 10m 26s
# 96:	learn: 0.5102045	total: 27.4s	remaining: 8m 57s
# 95:	learn: 0.5097076	total: 27.2s	remaining: 8m 59s
# 87:	learn: 0.5099240	total: 28.8s	remaining: 10m 25s
# 97:	learn: 0.5101798	total: 27.7s	remaining: 8m 57s
# 96:	learn: 0.5096854	total: 27.5s	remaining: 8m 58s
# 88:	learn: 0.5098952	total: 29.1s	remaining: 10m 24s
# 98:	learn: 0.5101544	total: 28s	remaining: 8m 57s
# 97:	learn: 0.5096587	total: 27.8s	remaining: 8m 59s
# 89:	learn: 0.5098664	total: 29.4s	remaining: 10m 23s
# 99:	learn: 0.5101267	total: 28.3s	remaining: 8m 57s
# 98:	learn: 0.5096337	total: 28.1s	remaining: 8m 59s
# 100:	learn: 0.5101023	total: 28.5s	remaining: 8m 56s
# 90:	learn: 0.5098381	total: 29.7s	remaining: 10m 23s
# 99:	learn: 0.5096064	total: 28.4s	remaining: 8m 58s
# 101:	learn: 0.5100764	total: 28.8s	remaining: 8m 56s
# 100:	learn: 0.5095790	total: 28.6s	remaining: 8m 58s
# 91:	learn: 0.5098122	total: 30.1s	remaining: 10m 23s
# 102:	learn: 0.5100321	total: 29.1s	remaining: 8m 56s
# 92:	learn: 0.5097886	total: 30.3s	remaining: 10m 21s
# 101:	learn: 0.5095543	total: 29s	remaining: 8m 58s
# 103:	learn: 0.5100001	total: 29.4s	remaining: 8m 56s
# 93:	learn: 0.5097609	total: 30.6s	remaining: 10m 20s
# 102:	learn: 0.5095249	total: 29.2s	remaining: 8m 58s
# 104:	learn: 0.5099732	total: 29.7s	remaining: 8m 55s
# 103:	learn: 0.5095031	total: 29.5s	remaining: 8m 58s
# 94:	learn: 0.5097390	total: 31s	remaining: 10m 21s
# 105:	learn: 0.5099491	total: 30s	remaining: 8m 56s
# 104:	learn: 0.5094777	total: 29.8s	remaining: 8m 57s
# 95:	learn: 0.5097158	total: 31.3s	remaining: 10m 21s
# 106:	learn: 0.5099253	total: 30.2s	remaining: 8m 54s
# 105:	learn: 0.5094518	total: 30s	remaining: 8m 56s
# 107:	learn: 0.5099027	total: 30.5s	remaining: 8m 53s
# 96:	learn: 0.5096916	total: 31.7s	remaining: 10m 21s
# 106:	learn: 0.5094187	total: 30.3s	remaining: 8m 56s
# 108:	learn: 0.5098796	total: 30.7s	remaining: 8m 53s
# 97:	learn: 0.5096483	total: 31.9s	remaining: 10m 19s
# 107:	learn: 0.5093930	total: 30.6s	remaining: 8m 55s
# 109:	learn: 0.5098556	total: 31.1s	remaining: 8m 53s
# 108:	learn: 0.5093732	total: 30.8s	remaining: 8m 55s
# 98:	learn: 0.5096227	total: 32.3s	remaining: 10m 19s
# 110:	learn: 0.5098305	total: 31.4s	remaining: 8m 53s
# 109:	learn: 0.5093486	total: 31.1s	remaining: 8m 54s
# 99:	learn: 0.5095997	total: 32.6s	remaining: 10m 20s
# 111:	learn: 0.5098084	total: 31.7s	remaining: 8m 53s
# 110:	learn: 0.5093206	total: 31.4s	remaining: 8m 54s
# 100:	learn: 0.5095742	total: 33s	remaining: 10m 20s
# 111:	learn: 0.5092980	total: 31.7s	remaining: 8m 53s
# 112:	learn: 0.5097839	total: 31.9s	remaining: 8m 53s
# 101:	learn: 0.5095520	total: 33.3s	remaining: 10m 19s
# 113:	learn: 0.5097635	total: 32.2s	remaining: 8m 52s
# 112:	learn: 0.5092745	total: 32s	remaining: 8m 54s
# 102:	learn: 0.5095295	total: 33.6s	remaining: 10m 18s
# 114:	learn: 0.5097353	total: 32.5s	remaining: 8m 52s
# 113:	learn: 0.5092537	total: 32.3s	remaining: 8m 54s
# 115:	learn: 0.5097032	total: 32.7s	remaining: 8m 51s
# 103:	learn: 0.5095065	total: 33.9s	remaining: 10m 18s
# 114:	learn: 0.5092298	total: 32.6s	remaining: 8m 54s
# 116:	learn: 0.5096807	total: 33s	remaining: 8m 51s
# 104:	learn: 0.5094827	total: 34.2s	remaining: 10m 17s
# 115:	learn: 0.5092039	total: 32.9s	remaining: 8m 54s
# 117:	learn: 0.5096478	total: 33.3s	remaining: 8m 51s
# 105:	learn: 0.5094554	total: 34.6s	remaining: 10m 17s
# 116:	learn: 0.5091794	total: 33.2s	remaining: 8m 54s
# 118:	learn: 0.5096256	total: 33.5s	remaining: 8m 50s
# 106:	learn: 0.5094138	total: 34.9s	remaining: 10m 16s
# 117:	learn: 0.5091520	total: 33.5s	remaining: 8m 54s
# 119:	learn: 0.5096023	total: 33.8s	remaining: 8m 49s
# 107:	learn: 0.5093900	total: 35.2s	remaining: 10m 16s
# 120:	learn: 0.5095799	total: 34.1s	remaining: 8m 49s
# 118:	learn: 0.5091306	total: 33.8s	remaining: 8m 54s
# 121:	learn: 0.5095601	total: 34.3s	remaining: 8m 48s
# 108:	learn: 0.5093657	total: 35.5s	remaining: 10m 15s
# 119:	learn: 0.5091070	total: 34.2s	remaining: 8m 55s
# 122:	learn: 0.5095344	total: 34.6s	remaining: 8m 47s
# 109:	learn: 0.5093442	total: 35.8s	remaining: 10m 15s
# 120:	learn: 0.5090851	total: 34.5s	remaining: 8m 55s
# 123:	learn: 0.5095076	total: 34.8s	remaining: 8m 46s
# 110:	learn: 0.5093203	total: 36.1s	remaining: 10m 14s
# 121:	learn: 0.5090586	total: 34.8s	remaining: 8m 55s
# 124:	learn: 0.5094808	total: 35.1s	remaining: 8m 47s
# 111:	learn: 0.5092935	total: 36.4s	remaining: 10m 13s
# 122:	learn: 0.5090220	total: 35.1s	remaining: 8m 55s
# 125:	learn: 0.5094580	total: 35.4s	remaining: 8m 46s
# 112:	learn: 0.5092679	total: 36.7s	remaining: 10m 12s
# 123:	learn: 0.5089992	total: 35.4s	remaining: 8m 55s
# 126:	learn: 0.5094303	total: 35.7s	remaining: 8m 46s
# 113:	learn: 0.5092392	total: 37s	remaining: 10m 11s
# 124:	learn: 0.5089812	total: 35.6s	remaining: 8m 54s
# 127:	learn: 0.5094015	total: 36s	remaining: 8m 45s
# 114:	learn: 0.5092131	total: 37.3s	remaining: 10m 10s
# 125:	learn: 0.5089548	total: 36s	remaining: 8m 54s
# 128:	learn: 0.5093783	total: 36.2s	remaining: 8m 45s
# 115:	learn: 0.5091906	total: 37.6s	remaining: 10m 10s
# 126:	learn: 0.5089295	total: 36.2s	remaining: 8m 54s
# 129:	learn: 0.5093536	total: 36.5s	remaining: 8m 45s
# 127:	learn: 0.5089048	total: 36.5s	remaining: 8m 53s
# 116:	learn: 0.5091673	total: 37.9s	remaining: 10m 10s
# 130:	learn: 0.5093330	total: 36.8s	remaining: 8m 45s
# 128:	learn: 0.5088789	total: 36.8s	remaining: 8m 53s
# 131:	learn: 0.5093073	total: 37.1s	remaining: 8m 44s
# 117:	learn: 0.5091410	total: 38.3s	remaining: 10m 10s
# 129:	learn: 0.5088538	total: 37.1s	remaining: 8m 53s
# 132:	learn: 0.5092856	total: 37.4s	remaining: 8m 44s
# 118:	learn: 0.5091211	total: 38.6s	remaining: 10m 9s
# 130:	learn: 0.5088305	total: 37.3s	remaining: 8m 52s
# 133:	learn: 0.5092563	total: 37.6s	remaining: 8m 43s
# 119:	learn: 0.5091007	total: 38.9s	remaining: 10m 9s
# 131:	learn: 0.5088014	total: 37.6s	remaining: 8m 52s
# 134:	learn: 0.5092345	total: 37.9s	remaining: 8m 43s
# 120:	learn: 0.5090734	total: 39.2s	remaining: 10m 9s
# 132:	learn: 0.5087778	total: 37.9s	remaining: 8m 51s
# 135:	learn: 0.5092060	total: 38.1s	remaining: 8m 42s
# 136:	learn: 0.5091756	total: 38.4s	remaining: 8m 42s
# 133:	learn: 0.5087542	total: 38.1s	remaining: 8m 51s
# 121:	learn: 0.5090520	total: 39.6s	remaining: 10m 9s
# 134:	learn: 0.5087310	total: 38.4s	remaining: 8m 50s
# 137:	learn: 0.5091534	total: 38.7s	remaining: 8m 41s
# 122:	learn: 0.5090279	total: 39.9s	remaining: 10m 9s
# 138:	learn: 0.5091302	total: 38.9s	remaining: 8m 40s
# 135:	learn: 0.5087056	total: 38.7s	remaining: 8m 50s
# 123:	learn: 0.5090083	total: 40.2s	remaining: 10m 8s
# 139:	learn: 0.5091051	total: 39.2s	remaining: 8m 40s
# 136:	learn: 0.5086797	total: 38.9s	remaining: 8m 49s
# 137:	learn: 0.5086535	total: 39.2s	remaining: 8m 48s
# 124:	learn: 0.5089737	total: 40.6s	remaining: 10m 8s
# 140:	learn: 0.5090809	total: 39.5s	remaining: 8m 41s
# 138:	learn: 0.5086321	total: 39.4s	remaining: 8m 47s
# 125:	learn: 0.5089453	total: 40.8s	remaining: 10m 7s
# 141:	learn: 0.5090450	total: 39.8s	remaining: 8m 40s
# 139:	learn: 0.5086087	total: 39.7s	remaining: 8m 47s
# 142:	learn: 0.5090233	total: 40s	remaining: 8m 38s
# 126:	learn: 0.5089201	total: 41.2s	remaining: 10m 8s
# 143:	learn: 0.5089988	total: 40.2s	remaining: 8m 38s
# 140:	learn: 0.5085844	total: 40s	remaining: 8m 46s
# 127:	learn: 0.5088877	total: 41.5s	remaining: 10m 7s
# 144:	learn: 0.5089721	total: 40.5s	remaining: 8m 37s
# 141:	learn: 0.5085627	total: 40.3s	remaining: 8m 46s
# 145:	learn: 0.5089449	total: 40.7s	remaining: 8m 36s
# 128:	learn: 0.5088655	total: 41.8s	remaining: 10m 6s
# 142:	learn: 0.5085427	total: 40.6s	remaining: 8m 47s
# 146:	learn: 0.5089193	total: 41s	remaining: 8m 36s
# 129:	learn: 0.5088426	total: 42.2s	remaining: 10m 6s
# 143:	learn: 0.5085194	total: 40.9s	remaining: 8m 46s
# 147:	learn: 0.5088929	total: 41.2s	remaining: 8m 36s
# 130:	learn: 0.5088182	total: 42.5s	remaining: 10m 6s
# 144:	learn: 0.5084991	total: 41.2s	remaining: 8m 46s
# 148:	learn: 0.5088680	total: 41.5s	remaining: 8m 35s
# 131:	learn: 0.5087765	total: 42.8s	remaining: 10m 5s
# 145:	learn: 0.5084741	total: 41.5s	remaining: 8m 46s
# 149:	learn: 0.5088433	total: 41.8s	remaining: 8m 35s
# 132:	learn: 0.5087419	total: 43.1s	remaining: 10m 5s
# 146:	learn: 0.5084504	total: 41.7s	remaining: 8m 46s
# 150:	learn: 0.5088162	total: 42.1s	remaining: 8m 35s
# 133:	learn: 0.5087218	total: 43.4s	remaining: 10m 4s
# 147:	learn: 0.5084248	total: 42s	remaining: 8m 46s
# 151:	learn: 0.5087920	total: 42.3s	remaining: 8m 34s
# 148:	learn: 0.5083988	total: 42.3s	remaining: 8m 46s
# 152:	learn: 0.5087682	total: 42.6s	remaining: 8m 34s
# 134:	learn: 0.5086965	total: 43.8s	remaining: 10m 5s
# 149:	learn: 0.5083754	total: 42.6s	remaining: 8m 45s
# 153:	learn: 0.5087408	total: 42.9s	remaining: 8m 34s
# 135:	learn: 0.5086689	total: 44.2s	remaining: 10m 5s
# 150:	learn: 0.5083468	total: 42.9s	remaining: 8m 45s
# 154:	learn: 0.5087162	total: 43.2s	remaining: 8m 33s
# 136:	learn: 0.5086460	total: 44.5s	remaining: 10m 4s
# 151:	learn: 0.5083173	total: 43.2s	remaining: 8m 44s
# 155:	learn: 0.5086900	total: 43.4s	remaining: 8m 33s
# 137:	learn: 0.5086212	total: 44.8s	remaining: 10m 4s
# 152:	learn: 0.5082911	total: 43.4s	remaining: 8m 44s
# 156:	learn: 0.5086641	total: 43.7s	remaining: 8m 33s
# 153:	learn: 0.5082670	total: 43.7s	remaining: 8m 43s
# 138:	learn: 0.5085997	total: 45.1s	remaining: 10m 3s
# 157:	learn: 0.5086295	total: 44s	remaining: 8m 33s
# 139:	learn: 0.5085771	total: 45.4s	remaining: 10m 2s
# 154:	learn: 0.5082365	total: 44s	remaining: 8m 43s
# 158:	learn: 0.5086010	total: 44.3s	remaining: 8m 32s
# 155:	learn: 0.5082004	total: 44.3s	remaining: 8m 43s
# 140:	learn: 0.5085534	total: 45.7s	remaining: 10m 2s
# 159:	learn: 0.5085767	total: 44.6s	remaining: 8m 32s
# 156:	learn: 0.5081756	total: 44.6s	remaining: 8m 43s
# 160:	learn: 0.5085496	total: 44.9s	remaining: 8m 32s
# 141:	learn: 0.5085279	total: 46.1s	remaining: 10m 2s
# 161:	learn: 0.5085219	total: 45.1s	remaining: 8m 32s
# 157:	learn: 0.5081454	total: 44.9s	remaining: 8m 43s
# 142:	learn: 0.5084975	total: 46.4s	remaining: 10m 2s
# 162:	learn: 0.5084970	total: 45.4s	remaining: 8m 32s
# 158:	learn: 0.5081205	total: 45.2s	remaining: 8m 43s
# 143:	learn: 0.5084714	total: 46.7s	remaining: 10m 2s
# 163:	learn: 0.5084707	total: 45.7s	remaining: 8m 31s
# 159:	learn: 0.5080944	total: 45.5s	remaining: 8m 43s
# 144:	learn: 0.5084404	total: 47s	remaining: 10m 1s
# 164:	learn: 0.5084459	total: 46s	remaining: 8m 31s
# 160:	learn: 0.5080526	total: 45.8s	remaining: 8m 43s
# 145:	learn: 0.5084168	total: 47.3s	remaining: 10m
# 165:	learn: 0.5084180	total: 46.2s	remaining: 8m 30s
# 161:	learn: 0.5080271	total: 46.1s	remaining: 8m 43s
# 166:	learn: 0.5083905	total: 46.5s	remaining: 8m 30s
# 146:	learn: 0.5083813	total: 47.6s	remaining: 10m
# 162:	learn: 0.5080011	total: 46.4s	remaining: 8m 43s
# 147:	learn: 0.5083585	total: 47.9s	remaining: 9m 59s
# 167:	learn: 0.5083639	total: 46.8s	remaining: 8m 30s
# 163:	learn: 0.5079744	total: 46.7s	remaining: 8m 42s
# 148:	learn: 0.5083326	total: 48.3s	remaining: 9m 59s
# 168:	learn: 0.5083350	total: 47.1s	remaining: 8m 30s
# 164:	learn: 0.5079389	total: 47s	remaining: 8m 42s
# 169:	learn: 0.5083102	total: 47.4s	remaining: 8m 30s
# 149:	learn: 0.5083066	total: 48.6s	remaining: 9m 59s
# 165:	learn: 0.5079123	total: 47.2s	remaining: 8m 41s
# 170:	learn: 0.5082792	total: 47.7s	remaining: 8m 29s
# 150:	learn: 0.5082799	total: 48.9s	remaining: 9m 58s
# 166:	learn: 0.5078857	total: 47.5s	remaining: 8m 41s
# 171:	learn: 0.5082513	total: 47.9s	remaining: 8m 29s
# 167:	learn: 0.5078522	total: 47.8s	remaining: 8m 41s
# 151:	learn: 0.5082542	total: 49.2s	remaining: 9m 58s
# 172:	learn: 0.5082267	total: 48.2s	remaining: 8m 29s
# 168:	learn: 0.5078280	total: 48s	remaining: 8m 40s
# 152:	learn: 0.5082303	total: 49.5s	remaining: 9m 57s
# 173:	learn: 0.5081863	total: 48.5s	remaining: 8m 29s
# 169:	learn: 0.5078001	total: 48.3s	remaining: 8m 40s
# 153:	learn: 0.5082029	total: 49.8s	remaining: 9m 57s
# 174:	learn: 0.5081587	total: 48.8s	remaining: 8m 28s
# 170:	learn: 0.5077730	total: 48.6s	remaining: 8m 40s
# 154:	learn: 0.5081730	total: 50.1s	remaining: 9m 56s
# 175:	learn: 0.5081305	total: 49.1s	remaining: 8m 28s
# 171:	learn: 0.5077437	total: 48.9s	remaining: 8m 39s
# 155:	learn: 0.5081486	total: 50.4s	remaining: 9m 55s
# 176:	learn: 0.5081036	total: 49.4s	remaining: 8m 28s
# 172:	learn: 0.5077187	total: 49.2s	remaining: 8m 39s
# 156:	learn: 0.5081235	total: 50.7s	remaining: 9m 55s
# 177:	learn: 0.5080767	total: 49.6s	remaining: 8m 27s
# 173:	learn: 0.5076934	total: 49.5s	remaining: 8m 39s
# 178:	learn: 0.5080502	total: 49.9s	remaining: 8m 27s
# 157:	learn: 0.5080971	total: 51.1s	remaining: 9m 55s
# 174:	learn: 0.5076623	total: 49.8s	remaining: 8m 39s
# 158:	learn: 0.5080646	total: 51.3s	remaining: 9m 54s
# 179:	learn: 0.5080236	total: 50.2s	remaining: 8m 27s
# 175:	learn: 0.5076364	total: 50.1s	remaining: 8m 39s
# 180:	learn: 0.5079984	total: 50.4s	remaining: 8m 26s
# 159:	learn: 0.5080354	total: 51.6s	remaining: 9m 53s
# 176:	learn: 0.5076099	total: 50.4s	remaining: 8m 39s
# 181:	learn: 0.5079715	total: 50.7s	remaining: 8m 26s
# 160:	learn: 0.5080125	total: 51.9s	remaining: 9m 53s
# 177:	learn: 0.5075808	total: 50.7s	remaining: 8m 38s
# 182:	learn: 0.5079432	total: 51s	remaining: 8m 26s
# 161:	learn: 0.5079867	total: 52.2s	remaining: 9m 52s
# 178:	learn: 0.5075503	total: 50.9s	remaining: 8m 38s
# 183:	learn: 0.5079151	total: 51.3s	remaining: 8m 26s
# 162:	learn: 0.5079606	total: 52.5s	remaining: 9m 52s
# 179:	learn: 0.5075228	total: 51.2s	remaining: 8m 37s
# 184:	learn: 0.5078877	total: 51.6s	remaining: 8m 26s
# 163:	learn: 0.5079349	total: 52.8s	remaining: 9m 51s
# 180:	learn: 0.5074946	total: 51.5s	remaining: 8m 37s
# 185:	learn: 0.5078516	total: 51.9s	remaining: 8m 26s
# 181:	learn: 0.5074692	total: 51.7s	remaining: 8m 36s
# 164:	learn: 0.5079118	total: 53.2s	remaining: 9m 51s
# 186:	learn: 0.5078213	total: 52.2s	remaining: 8m 26s
# 182:	learn: 0.5074428	total: 52s	remaining: 8m 36s
# 165:	learn: 0.5078855	total: 53.5s	remaining: 9m 50s
# 187:	learn: 0.5077975	total: 52.5s	remaining: 8m 25s
# 183:	learn: 0.5074182	total: 52.3s	remaining: 8m 36s
# 166:	learn: 0.5078600	total: 53.9s	remaining: 9m 51s
# 188:	learn: 0.5077685	total: 52.7s	remaining: 8m 25s
# 184:	learn: 0.5073907	total: 52.6s	remaining: 8m 35s
# 167:	learn: 0.5078331	total: 54.2s	remaining: 9m 50s
# 189:	learn: 0.5077411	total: 53s	remaining: 8m 25s
# 185:	learn: 0.5073647	total: 52.9s	remaining: 8m 35s
# 190:	learn: 0.5077149	total: 53.3s	remaining: 8m 25s
# 168:	learn: 0.5078042	total: 54.5s	remaining: 9m 50s
# 186:	learn: 0.5073408	total: 53.2s	remaining: 8m 35s
# 191:	learn: 0.5076913	total: 53.6s	remaining: 8m 24s
# 169:	learn: 0.5077814	total: 54.9s	remaining: 9m 50s
# 187:	learn: 0.5073125	total: 53.5s	remaining: 8m 35s
# 192:	learn: 0.5076578	total: 53.8s	remaining: 8m 23s
# 188:	learn: 0.5072880	total: 53.7s	remaining: 8m 34s
# 193:	learn: 0.5076310	total: 54s	remaining: 8m 23s
# 170:	learn: 0.5077565	total: 55.3s	remaining: 9m 51s
# 189:	learn: 0.5072614	total: 54.1s	remaining: 8m 35s
# 194:	learn: 0.5076063	total: 54.3s	remaining: 8m 22s
# 171:	learn: 0.5077342	total: 55.6s	remaining: 9m 50s
# 190:	learn: 0.5072336	total: 54.3s	remaining: 8m 34s
# 195:	learn: 0.5075816	total: 54.6s	remaining: 8m 22s
# 172:	learn: 0.5077101	total: 55.9s	remaining: 9m 50s
# 196:	learn: 0.5075547	total: 54.9s	remaining: 8m 22s
# 191:	learn: 0.5072067	total: 54.7s	remaining: 8m 34s
# 197:	learn: 0.5075280	total: 55.1s	remaining: 8m 21s
# 173:	learn: 0.5076851	total: 56.3s	remaining: 9m 50s
# 192:	learn: 0.5071784	total: 55s	remaining: 8m 34s
# 198:	learn: 0.5075053	total: 55.4s	remaining: 8m 21s
# 174:	learn: 0.5076582	total: 56.6s	remaining: 9m 50s
# 193:	learn: 0.5071499	total: 55.2s	remaining: 8m 33s
# 199:	learn: 0.5074773	total: 55.7s	remaining: 8m 21s
# 175:	learn: 0.5076318	total: 56.9s	remaining: 9m 49s
# 194:	learn: 0.5071236	total: 55.5s	remaining: 8m 33s
# 200:	learn: 0.5074524	total: 55.9s	remaining: 8m 20s
# 195:	learn: 0.5070954	total: 55.8s	remaining: 8m 33s
# 176:	learn: 0.5076066	total: 57.3s	remaining: 9m 49s
# 201:	learn: 0.5074263	total: 56.2s	remaining: 8m 20s
# 196:	learn: 0.5070685	total: 56.1s	remaining: 8m 33s
# 177:	learn: 0.5075826	total: 57.6s	remaining: 9m 49s
# 202:	learn: 0.5074028	total: 56.4s	remaining: 8m 19s
# 197:	learn: 0.5070426	total: 56.4s	remaining: 8m 32s
# 203:	learn: 0.5073745	total: 56.7s	remaining: 8m 19s
# 178:	learn: 0.5075593	total: 57.9s	remaining: 9m 49s
# 198:	learn: 0.5070161	total: 56.6s	remaining: 8m 32s
# 204:	learn: 0.5073481	total: 57s	remaining: 8m 19s
# 199:	learn: 0.5069912	total: 56.8s	remaining: 8m 31s
# 179:	learn: 0.5075334	total: 58.3s	remaining: 9m 49s
# 205:	learn: 0.5073239	total: 57.3s	remaining: 8m 18s
# 200:	learn: 0.5069664	total: 57.1s	remaining: 8m 30s
# 180:	learn: 0.5075099	total: 58.6s	remaining: 9m 49s
# 206:	learn: 0.5072988	total: 57.5s	remaining: 8m 18s
# 201:	learn: 0.5069375	total: 57.4s	remaining: 8m 30s
# 181:	learn: 0.5074842	total: 59s	remaining: 9m 49s
# 207:	learn: 0.5072705	total: 57.8s	remaining: 8m 18s
# 202:	learn: 0.5069122	total: 57.6s	remaining: 8m 30s
# 208:	learn: 0.5072442	total: 58.1s	remaining: 8m 17s
# 182:	learn: 0.5074594	total: 59.3s	remaining: 9m 48s
# 203:	learn: 0.5068785	total: 57.9s	remaining: 8m 29s
# 209:	learn: 0.5072202	total: 58.4s	remaining: 8m 17s
# 204:	learn: 0.5068527	total: 58.1s	remaining: 8m 29s
# 183:	learn: 0.5074359	total: 59.6s	remaining: 9m 48s
# 210:	learn: 0.5071961	total: 58.7s	remaining: 8m 17s
# 205:	learn: 0.5068295	total: 58.5s	remaining: 8m 29s
# 184:	learn: 0.5074080	total: 59.9s	remaining: 9m 47s
# 211:	learn: 0.5071681	total: 59s	remaining: 8m 17s
# 206:	learn: 0.5068008	total: 58.8s	remaining: 8m 28s
# 185:	learn: 0.5073875	total: 1m	remaining: 9m 47s
# 212:	learn: 0.5071426	total: 59.2s	remaining: 8m 16s
# 207:	learn: 0.5067730	total: 59s	remaining: 8m 28s
# 186:	learn: 0.5073626	total: 1m	remaining: 9m 47s
# 213:	learn: 0.5071154	total: 59.5s	remaining: 8m 16s
# 208:	learn: 0.5067507	total: 59.3s	remaining: 8m 27s
# 187:	learn: 0.5073350	total: 1m	remaining: 9m 46s
# 214:	learn: 0.5070922	total: 59.7s	remaining: 8m 15s
# 209:	learn: 0.5067259	total: 59.6s	remaining: 8m 27s
# 188:	learn: 0.5073105	total: 1m 1s	remaining: 9m 46s
# 210:	learn: 0.5066993	total: 59.8s	remaining: 8m 27s
# 215:	learn: 0.5070651	total: 1m	remaining: 8m 15s
# 189:	learn: 0.5072852	total: 1m 1s	remaining: 9m 45s
# 216:	learn: 0.5070372	total: 1m	remaining: 8m 15s
# 211:	learn: 0.5066744	total: 1m	remaining: 8m 27s
# 217:	learn: 0.5070131	total: 1m	remaining: 8m 15s
# 190:	learn: 0.5072599	total: 1m 1s	remaining: 9m 45s
# 212:	learn: 0.5066503	total: 1m	remaining: 8m 26s
# 218:	learn: 0.5069871	total: 1m	remaining: 8m 15s
# 213:	learn: 0.5066236	total: 1m	remaining: 8m 26s
# 191:	learn: 0.5072367	total: 1m 2s	remaining: 9m 45s
# 219:	learn: 0.5069588	total: 1m 1s	remaining: 8m 14s
# 214:	learn: 0.5065986	total: 1m	remaining: 8m 26s
# 192:	learn: 0.5072074	total: 1m 2s	remaining: 9m 45s
# 220:	learn: 0.5069324	total: 1m 1s	remaining: 8m 14s
# 215:	learn: 0.5065739	total: 1m 1s	remaining: 8m 25s
# 193:	learn: 0.5071832	total: 1m 2s	remaining: 9m 44s
# 221:	learn: 0.5069066	total: 1m 1s	remaining: 8m 14s
# 216:	learn: 0.5065516	total: 1m 1s	remaining: 8m 25s
# 194:	learn: 0.5071558	total: 1m 3s	remaining: 9m 44s
# 222:	learn: 0.5068841	total: 1m 2s	remaining: 8m 14s
# 217:	learn: 0.5065253	total: 1m 1s	remaining: 8m 25s
# 195:	learn: 0.5071321	total: 1m 3s	remaining: 9m 44s
# 223:	learn: 0.5068598	total: 1m 2s	remaining: 8m 13s
# 218:	learn: 0.5065040	total: 1m 2s	remaining: 8m 24s
# 224:	learn: 0.5068365	total: 1m 2s	remaining: 8m 13s
# 219:	learn: 0.5064782	total: 1m 2s	remaining: 8m 24s
# 196:	learn: 0.5071100	total: 1m 3s	remaining: 9m 43s
# 225:	learn: 0.5068097	total: 1m 2s	remaining: 8m 13s
# 220:	learn: 0.5064528	total: 1m 2s	remaining: 8m 24s
# 197:	learn: 0.5070874	total: 1m 4s	remaining: 9m 43s
# 226:	learn: 0.5067870	total: 1m 3s	remaining: 8m 13s
# 221:	learn: 0.5064258	total: 1m 3s	remaining: 8m 24s
# 198:	learn: 0.5070632	total: 1m 4s	remaining: 9m 43s
# 227:	learn: 0.5067664	total: 1m 3s	remaining: 8m 12s
# 222:	learn: 0.5064004	total: 1m 3s	remaining: 8m 24s
# 199:	learn: 0.5070383	total: 1m 4s	remaining: 9m 42s
# 228:	learn: 0.5067405	total: 1m 3s	remaining: 8m 12s
# 223:	learn: 0.5063778	total: 1m 3s	remaining: 8m 24s
# 229:	learn: 0.5067162	total: 1m 3s	remaining: 8m 11s
# 200:	learn: 0.5070158	total: 1m 5s	remaining: 9m 42s
# 224:	learn: 0.5063530	total: 1m 3s	remaining: 8m 23s
# 230:	learn: 0.5066953	total: 1m 4s	remaining: 8m 11s
# 201:	learn: 0.5069938	total: 1m 5s	remaining: 9m 42s
# 225:	learn: 0.5063285	total: 1m 4s	remaining: 8m 23s
# 231:	learn: 0.5066698	total: 1m 4s	remaining: 8m 11s
# 202:	learn: 0.5069697	total: 1m 5s	remaining: 9m 42s
# 226:	learn: 0.5063046	total: 1m 4s	remaining: 8m 23s
# 232:	learn: 0.5066450	total: 1m 4s	remaining: 8m 11s
# 203:	learn: 0.5069445	total: 1m 6s	remaining: 9m 41s
# 227:	learn: 0.5062795	total: 1m 4s	remaining: 8m 23s
# 233:	learn: 0.5066228	total: 1m 4s	remaining: 8m 10s
# 204:	learn: 0.5069210	total: 1m 6s	remaining: 9m 40s
# 228:	learn: 0.5062547	total: 1m 4s	remaining: 8m 22s
# 234:	learn: 0.5065986	total: 1m 5s	remaining: 8m 10s
# 205:	learn: 0.5068996	total: 1m 6s	remaining: 9m 40s
# 229:	learn: 0.5062268	total: 1m 5s	remaining: 8m 22s
# 235:	learn: 0.5065739	total: 1m 5s	remaining: 8m 9s
# 230:	learn: 0.5061999	total: 1m 5s	remaining: 8m 21s
# 236:	learn: 0.5065517	total: 1m 5s	remaining: 8m 9s
# 206:	learn: 0.5068775	total: 1m 7s	remaining: 9m 40s
# 207:	learn: 0.5068545	total: 1m 7s	remaining: 9m 39s
# 231:	learn: 0.5061725	total: 1m 5s	remaining: 8m 21s
# 237:	learn: 0.5065283	total: 1m 6s	remaining: 8m 9s
# 232:	learn: 0.5061501	total: 1m 6s	remaining: 8m 21s
# 208:	learn: 0.5068311	total: 1m 7s	remaining: 9m 39s
# 238:	learn: 0.5065040	total: 1m 6s	remaining: 8m 9s
# 233:	learn: 0.5061268	total: 1m 6s	remaining: 8m 21s
# 239:	learn: 0.5064819	total: 1m 6s	remaining: 8m 8s
# 209:	learn: 0.5068105	total: 1m 7s	remaining: 9m 38s
# 234:	learn: 0.5061016	total: 1m 6s	remaining: 8m 20s
# 240:	learn: 0.5064570	total: 1m 6s	remaining: 8m 8s
# 210:	learn: 0.5067883	total: 1m 8s	remaining: 9m 39s
# 235:	learn: 0.5060789	total: 1m 6s	remaining: 8m 20s
# 241:	learn: 0.5064313	total: 1m 7s	remaining: 8m 8s
# 211:	learn: 0.5067658	total: 1m 8s	remaining: 9m 38s
# 242:	learn: 0.5064043	total: 1m 7s	remaining: 8m 7s
# 236:	learn: 0.5060548	total: 1m 7s	remaining: 8m 20s
# 237:	learn: 0.5060318	total: 1m 7s	remaining: 8m 19s
# 212:	learn: 0.5067440	total: 1m 8s	remaining: 9m 38s
# 243:	learn: 0.5063783	total: 1m 7s	remaining: 8m 7s
# 238:	learn: 0.5060096	total: 1m 7s	remaining: 8m 19s
# 244:	learn: 0.5063528	total: 1m 8s	remaining: 8m 7s
# 213:	learn: 0.5067185	total: 1m 9s	remaining: 9m 37s
# 239:	learn: 0.5059863	total: 1m 8s	remaining: 8m 19s
# 245:	learn: 0.5063263	total: 1m 8s	remaining: 8m 7s
# 214:	learn: 0.5066957	total: 1m 9s	remaining: 9m 37s
# 240:	learn: 0.5059645	total: 1m 8s	remaining: 8m 19s
# 246:	learn: 0.5063005	total: 1m 8s	remaining: 8m 7s
# 215:	learn: 0.5066725	total: 1m 9s	remaining: 9m 37s
# 241:	learn: 0.5059448	total: 1m 8s	remaining: 8m 18s
# 247:	learn: 0.5062771	total: 1m 8s	remaining: 8m 6s
# 216:	learn: 0.5066509	total: 1m 10s	remaining: 9m 37s
# 242:	learn: 0.5059212	total: 1m 8s	remaining: 8m 18s
# 248:	learn: 0.5062534	total: 1m 9s	remaining: 8m 6s
# 217:	learn: 0.5066280	total: 1m 10s	remaining: 9m 36s
# 243:	learn: 0.5058976	total: 1m 9s	remaining: 8m 18s
# 249:	learn: 0.5062309	total: 1m 9s	remaining: 8m 6s
# 218:	learn: 0.5066082	total: 1m 10s	remaining: 9m 35s
# 250:	learn: 0.5062078	total: 1m 9s	remaining: 8m 6s
# 244:	learn: 0.5058735	total: 1m 9s	remaining: 8m 18s
# 219:	learn: 0.5065838	total: 1m 11s	remaining: 9m 35s
# 251:	learn: 0.5061843	total: 1m 10s	remaining: 8m 5s
# 245:	learn: 0.5058484	total: 1m 9s	remaining: 8m 18s
# 220:	learn: 0.5065619	total: 1m 11s	remaining: 9m 35s
# 252:	learn: 0.5061623	total: 1m 10s	remaining: 8m 5s
# 246:	learn: 0.5058249	total: 1m 10s	remaining: 8m 17s
# 221:	learn: 0.5065408	total: 1m 11s	remaining: 9m 34s
# 247:	learn: 0.5058000	total: 1m 10s	remaining: 8m 16s
# 253:	learn: 0.5061384	total: 1m 10s	remaining: 8m 5s
# 248:	learn: 0.5057693	total: 1m 10s	remaining: 8m 16s
# 222:	learn: 0.5065202	total: 1m 12s	remaining: 9m 34s
# 254:	learn: 0.5061149	total: 1m 10s	remaining: 8m 5s
# 249:	learn: 0.5057437	total: 1m 10s	remaining: 8m 16s
# 255:	learn: 0.5060902	total: 1m 11s	remaining: 8m 5s
# 223:	learn: 0.5065017	total: 1m 12s	remaining: 9m 33s
# 250:	learn: 0.5057199	total: 1m 11s	remaining: 8m 16s
# 256:	learn: 0.5060673	total: 1m 11s	remaining: 8m 4s
# 224:	learn: 0.5064792	total: 1m 12s	remaining: 9m 33s
# 251:	learn: 0.5056992	total: 1m 11s	remaining: 8m 15s
# 257:	learn: 0.5060446	total: 1m 11s	remaining: 8m 4s
# 225:	learn: 0.5064586	total: 1m 13s	remaining: 9m 33s
# 252:	learn: 0.5056766	total: 1m 11s	remaining: 8m 15s
# 258:	learn: 0.5060219	total: 1m 12s	remaining: 8m 4s
# 226:	learn: 0.5064380	total: 1m 13s	remaining: 9m 33s
# 253:	learn: 0.5056525	total: 1m 12s	remaining: 8m 15s
# 259:	learn: 0.5059991	total: 1m 12s	remaining: 8m 4s
# 227:	learn: 0.5064152	total: 1m 13s	remaining: 9m 32s
# 254:	learn: 0.5056317	total: 1m 12s	remaining: 8m 14s
# 260:	learn: 0.5059753	total: 1m 12s	remaining: 8m 4s
# 255:	learn: 0.5056089	total: 1m 12s	remaining: 8m 14s
# 228:	learn: 0.5063928	total: 1m 14s	remaining: 9m 32s
# 261:	learn: 0.5059533	total: 1m 12s	remaining: 8m 3s
# 256:	learn: 0.5055849	total: 1m 12s	remaining: 8m 13s
# 229:	learn: 0.5063743	total: 1m 14s	remaining: 9m 31s
# 262:	learn: 0.5059274	total: 1m 13s	remaining: 8m 3s
# 257:	learn: 0.5055607	total: 1m 13s	remaining: 8m 13s
# 230:	learn: 0.5063521	total: 1m 14s	remaining: 9m 31s
# 263:	learn: 0.5059054	total: 1m 13s	remaining: 8m 3s
# 258:	learn: 0.5055408	total: 1m 13s	remaining: 8m 13s
# 231:	learn: 0.5063298	total: 1m 14s	remaining: 9m 31s
# 264:	learn: 0.5058818	total: 1m 13s	remaining: 8m 2s
# 259:	learn: 0.5055172	total: 1m 13s	remaining: 8m 13s
# 265:	learn: 0.5058562	total: 1m 14s	remaining: 8m 2s
# 232:	learn: 0.5063084	total: 1m 15s	remaining: 9m 30s
# 260:	learn: 0.5054950	total: 1m 14s	remaining: 8m 13s
# 266:	learn: 0.5058313	total: 1m 14s	remaining: 8m 2s
# 233:	learn: 0.5062855	total: 1m 15s	remaining: 9m 30s
# 261:	learn: 0.5054715	total: 1m 14s	remaining: 8m 12s
# 267:	learn: 0.5058093	total: 1m 14s	remaining: 8m 2s
# 234:	learn: 0.5062639	total: 1m 15s	remaining: 9m 29s
# 262:	learn: 0.5054478	total: 1m 14s	remaining: 8m 12s
# 268:	learn: 0.5057888	total: 1m 14s	remaining: 8m 2s
# 235:	learn: 0.5062437	total: 1m 16s	remaining: 9m 29s
# 263:	learn: 0.5054256	total: 1m 14s	remaining: 8m 12s
# 269:	learn: 0.5057654	total: 1m 15s	remaining: 8m 2s
# 236:	learn: 0.5062224	total: 1m 16s	remaining: 9m 28s
# 264:	learn: 0.5054028	total: 1m 15s	remaining: 8m 11s
# 270:	learn: 0.5057424	total: 1m 15s	remaining: 8m 1s
# 237:	learn: 0.5061987	total: 1m 16s	remaining: 9m 28s
# 265:	learn: 0.5053805	total: 1m 15s	remaining: 8m 11s
# 271:	learn: 0.5057204	total: 1m 15s	remaining: 8m 1s
# 266:	learn: 0.5053559	total: 1m 15s	remaining: 8m 11s
# 238:	learn: 0.5061781	total: 1m 17s	remaining: 9m 28s
# 272:	learn: 0.5056969	total: 1m 16s	remaining: 8m 1s
# 267:	learn: 0.5053329	total: 1m 15s	remaining: 8m 10s
# 239:	learn: 0.5061567	total: 1m 17s	remaining: 9m 28s
# 273:	learn: 0.5056754	total: 1m 16s	remaining: 8m 1s
# 268:	learn: 0.5053126	total: 1m 16s	remaining: 8m 10s
# 240:	learn: 0.5061354	total: 1m 17s	remaining: 9m 27s
# 274:	learn: 0.5056538	total: 1m 16s	remaining: 8m 1s
# 269:	learn: 0.5052905	total: 1m 16s	remaining: 8m 10s
# 275:	learn: 0.5056325	total: 1m 16s	remaining: 8m
# 241:	learn: 0.5061143	total: 1m 18s	remaining: 9m 27s
# 270:	learn: 0.5052688	total: 1m 16s	remaining: 8m 9s
# 276:	learn: 0.5056087	total: 1m 17s	remaining: 8m
# 242:	learn: 0.5060930	total: 1m 18s	remaining: 9m 26s
# 271:	learn: 0.5052451	total: 1m 17s	remaining: 8m 9s
# 277:	learn: 0.5055876	total: 1m 17s	remaining: 7m 59s
# 243:	learn: 0.5060695	total: 1m 18s	remaining: 9m 26s
# 272:	learn: 0.5052222	total: 1m 17s	remaining: 8m 9s
# 278:	learn: 0.5055627	total: 1m 17s	remaining: 7m 59s
# 273:	learn: 0.5052002	total: 1m 17s	remaining: 8m 8s
# 244:	learn: 0.5060468	total: 1m 19s	remaining: 9m 26s
# 279:	learn: 0.5055398	total: 1m 17s	remaining: 7m 59s
# 274:	learn: 0.5051784	total: 1m 17s	remaining: 8m 8s
# 280:	learn: 0.5055159	total: 1m 18s	remaining: 7m 58s
# 245:	learn: 0.5060231	total: 1m 19s	remaining: 9m 26s
# 275:	learn: 0.5051546	total: 1m 18s	remaining: 8m 8s
# 281:	learn: 0.5054916	total: 1m 18s	remaining: 7m 58s
# 246:	learn: 0.5060022	total: 1m 19s	remaining: 9m 25s
# 276:	learn: 0.5051291	total: 1m 18s	remaining: 8m 8s
# 282:	learn: 0.5054697	total: 1m 18s	remaining: 7m 58s
# 247:	learn: 0.5059824	total: 1m 20s	remaining: 9m 25s
# 277:	learn: 0.5051045	total: 1m 18s	remaining: 8m 8s
# 283:	learn: 0.5054492	total: 1m 19s	remaining: 7m 57s
# 248:	learn: 0.5059601	total: 1m 20s	remaining: 9m 24s
# 278:	learn: 0.5050823	total: 1m 19s	remaining: 8m 7s
# 284:	learn: 0.5054236	total: 1m 19s	remaining: 7m 57s
# 249:	learn: 0.5059400	total: 1m 20s	remaining: 9m 24s
# 279:	learn: 0.5050597	total: 1m 19s	remaining: 8m 7s
# 285:	learn: 0.5054000	total: 1m 19s	remaining: 7m 57s
# 250:	learn: 0.5059199	total: 1m 20s	remaining: 9m 23s
# 280:	learn: 0.5050382	total: 1m 19s	remaining: 8m 7s
# 286:	learn: 0.5053751	total: 1m 19s	remaining: 7m 56s
# 251:	learn: 0.5058984	total: 1m 21s	remaining: 9m 24s
# 281:	learn: 0.5050142	total: 1m 19s	remaining: 8m 6s
# 287:	learn: 0.5053521	total: 1m 20s	remaining: 7m 56s
# 282:	learn: 0.5049892	total: 1m 20s	remaining: 8m 6s
# 288:	learn: 0.5053310	total: 1m 20s	remaining: 7m 56s
# 252:	learn: 0.5058781	total: 1m 21s	remaining: 9m 23s
# 283:	learn: 0.5049688	total: 1m 20s	remaining: 8m 6s
# 289:	learn: 0.5053101	total: 1m 20s	remaining: 7m 55s
# 253:	learn: 0.5058559	total: 1m 21s	remaining: 9m 23s
# 284:	learn: 0.5049482	total: 1m 20s	remaining: 8m 5s
# 290:	learn: 0.5052883	total: 1m 20s	remaining: 7m 55s
# 254:	learn: 0.5058347	total: 1m 22s	remaining: 9m 22s
# 285:	learn: 0.5049253	total: 1m 20s	remaining: 8m 5s
# 291:	learn: 0.5052632	total: 1m 21s	remaining: 7m 55s
# 255:	learn: 0.5058143	total: 1m 22s	remaining: 9m 22s
# 286:	learn: 0.5049018	total: 1m 21s	remaining: 8m 5s
# 292:	learn: 0.5052397	total: 1m 21s	remaining: 7m 55s
# 287:	learn: 0.5048771	total: 1m 21s	remaining: 8m 4s
# 256:	learn: 0.5057943	total: 1m 22s	remaining: 9m 22s
# 293:	learn: 0.5052182	total: 1m 21s	remaining: 7m 55s
# 288:	learn: 0.5048553	total: 1m 21s	remaining: 8m 3s
# 257:	learn: 0.5057764	total: 1m 23s	remaining: 9m 22s
# 294:	learn: 0.5051958	total: 1m 22s	remaining: 7m 54s
# 289:	learn: 0.5048329	total: 1m 22s	remaining: 8m 3s
# 258:	learn: 0.5057560	total: 1m 23s	remaining: 9m 21s
# 295:	learn: 0.5051750	total: 1m 22s	remaining: 7m 54s
# 290:	learn: 0.5048125	total: 1m 22s	remaining: 8m 3s
# 296:	learn: 0.5051521	total: 1m 22s	remaining: 7m 54s
# 259:	learn: 0.5057368	total: 1m 23s	remaining: 9m 21s
# 291:	learn: 0.5047912	total: 1m 22s	remaining: 8m 2s
# 297:	learn: 0.5051327	total: 1m 22s	remaining: 7m 53s
# 260:	learn: 0.5057146	total: 1m 24s	remaining: 9m 20s
# 292:	learn: 0.5047690	total: 1m 22s	remaining: 8m 2s
# 298:	learn: 0.5051104	total: 1m 23s	remaining: 7m 53s
# 261:	learn: 0.5056962	total: 1m 24s	remaining: 9m 20s
# 293:	learn: 0.5047472	total: 1m 23s	remaining: 8m 2s
# 299:	learn: 0.5050856	total: 1m 23s	remaining: 7m 52s
# 262:	learn: 0.5056739	total: 1m 24s	remaining: 9m 19s
# 294:	learn: 0.5047242	total: 1m 23s	remaining: 8m 2s
# 300:	learn: 0.5050639	total: 1m 23s	remaining: 7m 52s
# 263:	learn: 0.5056519	total: 1m 25s	remaining: 9m 19s
# 301:	learn: 0.5050438	total: 1m 23s	remaining: 7m 52s
# 295:	learn: 0.5047001	total: 1m 23s	remaining: 8m 2s
# 302:	learn: 0.5050218	total: 1m 24s	remaining: 7m 51s
# 296:	learn: 0.5046770	total: 1m 24s	remaining: 8m 1s
# 264:	learn: 0.5056313	total: 1m 25s	remaining: 9m 19s
# 303:	learn: 0.5049957	total: 1m 24s	remaining: 7m 51s
# 297:	learn: 0.5046529	total: 1m 24s	remaining: 8m 1s
# 265:	learn: 0.5056101	total: 1m 25s	remaining: 9m 20s
# 304:	learn: 0.5049707	total: 1m 24s	remaining: 7m 51s
# 298:	learn: 0.5046321	total: 1m 24s	remaining: 8m 1s
# 266:	learn: 0.5055896	total: 1m 26s	remaining: 9m 19s
# 305:	learn: 0.5049504	total: 1m 25s	remaining: 7m 50s
# 299:	learn: 0.5046087	total: 1m 24s	remaining: 8m 1s
# 306:	learn: 0.5049282	total: 1m 25s	remaining: 7m 50s
# 267:	learn: 0.5055706	total: 1m 26s	remaining: 9m 19s
# 300:	learn: 0.5045866	total: 1m 25s	remaining: 8m
# 307:	learn: 0.5049061	total: 1m 25s	remaining: 7m 50s
# 268:	learn: 0.5055497	total: 1m 26s	remaining: 9m 18s
# 301:	learn: 0.5045617	total: 1m 25s	remaining: 8m 1s
# 308:	learn: 0.5048847	total: 1m 25s	remaining: 7m 49s
# 269:	learn: 0.5055284	total: 1m 27s	remaining: 9m 18s
# 302:	learn: 0.5045400	total: 1m 25s	remaining: 8m
# 309:	learn: 0.5048629	total: 1m 26s	remaining: 7m 49s
# 270:	learn: 0.5055111	total: 1m 27s	remaining: 9m 17s
# 303:	learn: 0.5045183	total: 1m 26s	remaining: 8m
# 310:	learn: 0.5048397	total: 1m 26s	remaining: 7m 49s
# 271:	learn: 0.5054920	total: 1m 27s	remaining: 9m 17s
# 304:	learn: 0.5044983	total: 1m 26s	remaining: 8m
# 311:	learn: 0.5048176	total: 1m 26s	remaining: 7m 49s
# 312:	learn: 0.5047967	total: 1m 26s	remaining: 7m 48s
# 272:	learn: 0.5054719	total: 1m 28s	remaining: 9m 17s
# 305:	learn: 0.5044762	total: 1m 26s	remaining: 8m
# 313:	learn: 0.5047732	total: 1m 27s	remaining: 7m 48s
# 306:	learn: 0.5044567	total: 1m 26s	remaining: 7m 59s
# 273:	learn: 0.5054516	total: 1m 28s	remaining: 9m 17s
# 314:	learn: 0.5047516	total: 1m 27s	remaining: 7m 47s
# 307:	learn: 0.5044360	total: 1m 27s	remaining: 7m 59s
# 274:	learn: 0.5054321	total: 1m 28s	remaining: 9m 17s
# 315:	learn: 0.5047330	total: 1m 27s	remaining: 7m 47s
# 308:	learn: 0.5044136	total: 1m 27s	remaining: 7m 59s
# 275:	learn: 0.5054097	total: 1m 29s	remaining: 9m 16s
# 316:	learn: 0.5047127	total: 1m 27s	remaining: 7m 47s
# 309:	learn: 0.5043904	total: 1m 27s	remaining: 7m 58s
# 276:	learn: 0.5053895	total: 1m 29s	remaining: 9m 15s
# 317:	learn: 0.5046940	total: 1m 28s	remaining: 7m 46s
# 310:	learn: 0.5043691	total: 1m 28s	remaining: 7m 58s
# ...
# 1587:	learn: 0.4809544	total: 7m 16s	remaining: 1m 53s
# 1906:	learn: 0.4754979	total: 8m 35s	remaining: 25.1s
# 1847:	learn: 0.4769851	total: 8m 25s	remaining: 41.6s
# 1588:	learn: 0.4809371	total: 7m 17s	remaining: 1m 53s
# 1907:	learn: 0.4754789	total: 8m 35s	remaining: 24.9s
# 1848:	learn: 0.4769728	total: 8m 25s	remaining: 41.3s
# 1589:	learn: 0.4809160	total: 7m 17s	remaining: 1m 52s
# 1908:	learn: 0.4754640	total: 8m 36s	remaining: 24.6s
# 1849:	learn: 0.4769567	total: 8m 26s	remaining: 41s
# 1590:	learn: 0.4809000	total: 7m 17s	remaining: 1m 52s
# 1909:	learn: 0.4754475	total: 8m 36s	remaining: 24.3s
# 1850:	learn: 0.4769384	total: 8m 26s	remaining: 40.8s
# 1910:	learn: 0.4754300	total: 8m 36s	remaining: 24.1s
# 1591:	learn: 0.4808829	total: 7m 17s	remaining: 1m 52s
# 1851:	learn: 0.4769205	total: 8m 26s	remaining: 40.5s
# 1911:	learn: 0.4754137	total: 8m 36s	remaining: 23.8s
# 1592:	learn: 0.4808645	total: 7m 18s	remaining: 1m 51s
# 1852:	learn: 0.4769024	total: 8m 26s	remaining: 40.2s
# 1912:	learn: 0.4753973	total: 8m 37s	remaining: 23.5s
# 1593:	learn: 0.4808467	total: 7m 18s	remaining: 1m 51s
# 1853:	learn: 0.4768832	total: 8m 27s	remaining: 39.9s
# 1913:	learn: 0.4753816	total: 8m 37s	remaining: 23.2s
# 1594:	learn: 0.4808299	total: 7m 18s	remaining: 1m 51s
# 1854:	learn: 0.4768652	total: 8m 27s	remaining: 39.7s
# 1914:	learn: 0.4753657	total: 8m 37s	remaining: 23s
# 1595:	learn: 0.4808138	total: 7m 19s	remaining: 1m 51s
# 1855:	learn: 0.4768491	total: 8m 27s	remaining: 39.4s
# 1915:	learn: 0.4753519	total: 8m 37s	remaining: 22.7s
# 1596:	learn: 0.4807946	total: 7m 19s	remaining: 1m 50s
# 1916:	learn: 0.4753369	total: 8m 38s	remaining: 22.4s
# 1856:	learn: 0.4768304	total: 8m 27s	remaining: 39.1s
# 1597:	learn: 0.4807770	total: 7m 19s	remaining: 1m 50s
# 1917:	learn: 0.4753196	total: 8m 38s	remaining: 22.2s
# 1857:	learn: 0.4768126	total: 8m 28s	remaining: 38.8s
# 1598:	learn: 0.4807582	total: 7m 19s	remaining: 1m 50s
# 1858:	learn: 0.4767939	total: 8m 28s	remaining: 38.6s
# 1918:	learn: 0.4753028	total: 8m 38s	remaining: 21.9s
# 1599:	learn: 0.4807417	total: 7m 20s	remaining: 1m 50s
# 1859:	learn: 0.4767780	total: 8m 28s	remaining: 38.3s
# 1919:	learn: 0.4752878	total: 8m 39s	remaining: 21.6s
# 1600:	learn: 0.4807257	total: 7m 20s	remaining: 1m 49s
# 1860:	learn: 0.4767628	total: 8m 29s	remaining: 38s
# 1920:	learn: 0.4752710	total: 8m 39s	remaining: 21.4s
# 1601:	learn: 0.4807078	total: 7m 20s	remaining: 1m 49s
# 1861:	learn: 0.4767440	total: 8m 29s	remaining: 37.7s
# 1921:	learn: 0.4752543	total: 8m 39s	remaining: 21.1s
# 1602:	learn: 0.4806888	total: 7m 21s	remaining: 1m 49s
# 1862:	learn: 0.4767260	total: 8m 29s	remaining: 37.5s
# 1922:	learn: 0.4752366	total: 8m 39s	remaining: 20.8s
# 1863:	learn: 0.4767084	total: 8m 29s	remaining: 37.2s
# 1603:	learn: 0.4806717	total: 7m 21s	remaining: 1m 48s
# 1923:	learn: 0.4752191	total: 8m 40s	remaining: 20.5s
# 1604:	learn: 0.4806534	total: 7m 21s	remaining: 1m 48s
# 1924:	learn: 0.4752025	total: 8m 40s	remaining: 20.3s
# 1864:	learn: 0.4766911	total: 8m 30s	remaining: 36.9s
# 1605:	learn: 0.4806395	total: 7m 21s	remaining: 1m 48s
# 1925:	learn: 0.4751851	total: 8m 40s	remaining: 20s
# 1865:	learn: 0.4766731	total: 8m 30s	remaining: 36.7s
# 1606:	learn: 0.4806216	total: 7m 22s	remaining: 1m 48s
# 1926:	learn: 0.4751675	total: 8m 40s	remaining: 19.7s
# 1866:	learn: 0.4766550	total: 8m 30s	remaining: 36.4s
# 1607:	learn: 0.4806030	total: 7m 22s	remaining: 1m 47s
# 1927:	learn: 0.4751507	total: 8m 41s	remaining: 19.5s
# 1867:	learn: 0.4766385	total: 8m 31s	remaining: 36.1s
# 1608:	learn: 0.4805852	total: 7m 22s	remaining: 1m 47s
# 1928:	learn: 0.4751347	total: 8m 41s	remaining: 19.2s
# 1868:	learn: 0.4766236	total: 8m 31s	remaining: 35.8s
# 1929:	learn: 0.4751170	total: 8m 41s	remaining: 18.9s
# 1609:	learn: 0.4805693	total: 7m 23s	remaining: 1m 47s
# 1869:	learn: 0.4766060	total: 8m 31s	remaining: 35.6s
# 1930:	learn: 0.4750992	total: 8m 41s	remaining: 18.6s
# 1610:	learn: 0.4805526	total: 7m 23s	remaining: 1m 47s
# 1870:	learn: 0.4765929	total: 8m 31s	remaining: 35.3s
# 1931:	learn: 0.4750819	total: 8m 42s	remaining: 18.4s
# 1611:	learn: 0.4805346	total: 7m 23s	remaining: 1m 46s
# 1871:	learn: 0.4765782	total: 8m 32s	remaining: 35s
# 1932:	learn: 0.4750633	total: 8m 42s	remaining: 18.1s
# 1612:	learn: 0.4805156	total: 7m 23s	remaining: 1m 46s
# 1872:	learn: 0.4765613	total: 8m 32s	remaining: 34.7s
# 1933:	learn: 0.4750472	total: 8m 42s	remaining: 17.8s
# 1613:	learn: 0.4804964	total: 7m 24s	remaining: 1m 46s
# 1873:	learn: 0.4765459	total: 8m 32s	remaining: 34.5s
# 1934:	learn: 0.4750298	total: 8m 43s	remaining: 17.6s
# 1614:	learn: 0.4804819	total: 7m 24s	remaining: 1m 45s
# 1874:	learn: 0.4765278	total: 8m 32s	remaining: 34.2s
# 1935:	learn: 0.4750137	total: 8m 43s	remaining: 17.3s
# 1875:	learn: 0.4765129	total: 8m 33s	remaining: 33.9s
# 1615:	learn: 0.4804646	total: 7m 24s	remaining: 1m 45s
# 1936:	learn: 0.4749943	total: 8m 43s	remaining: 17s
# 1876:	learn: 0.4764959	total: 8m 33s	remaining: 33.6s
# 1616:	learn: 0.4804466	total: 7m 25s	remaining: 1m 45s
# 1937:	learn: 0.4749804	total: 8m 43s	remaining: 16.8s
# 1617:	learn: 0.4804269	total: 7m 25s	remaining: 1m 45s
# 1877:	learn: 0.4764760	total: 8m 33s	remaining: 33.4s
# 1938:	learn: 0.4749638	total: 8m 44s	remaining: 16.5s
# 1618:	learn: 0.4804099	total: 7m 25s	remaining: 1m 44s
# 1939:	learn: 0.4749473	total: 8m 44s	remaining: 16.2s
# 1878:	learn: 0.4764596	total: 8m 34s	remaining: 33.1s
# 1940:	learn: 0.4749314	total: 8m 44s	remaining: 15.9s
# 1619:	learn: 0.4803907	total: 7m 25s	remaining: 1m 44s
# 1879:	learn: 0.4764420	total: 8m 34s	remaining: 32.8s
# 1620:	learn: 0.4803732	total: 7m 26s	remaining: 1m 44s
# 1941:	learn: 0.4749154	total: 8m 44s	remaining: 15.7s
# 1880:	learn: 0.4764249	total: 8m 34s	remaining: 32.6s
# 1621:	learn: 0.4803550	total: 7m 26s	remaining: 1m 44s
# 1881:	learn: 0.4764064	total: 8m 34s	remaining: 32.3s
# 1942:	learn: 0.4749004	total: 8m 45s	remaining: 15.4s
# 1622:	learn: 0.4803412	total: 7m 26s	remaining: 1m 43s
# 1882:	learn: 0.4763900	total: 8m 35s	remaining: 32s
# 1943:	learn: 0.4748824	total: 8m 45s	remaining: 15.1s
# 1623:	learn: 0.4803239	total: 7m 26s	remaining: 1m 43s
# 1883:	learn: 0.4763736	total: 8m 35s	remaining: 31.7s
# 1944:	learn: 0.4748653	total: 8m 45s	remaining: 14.9s
# 1624:	learn: 0.4803069	total: 7m 27s	remaining: 1m 43s
# 1884:	learn: 0.4763560	total: 8m 35s	remaining: 31.5s
# 1945:	learn: 0.4748465	total: 8m 46s	remaining: 14.6s
# 1625:	learn: 0.4802888	total: 7m 27s	remaining: 1m 42s
# 1885:	learn: 0.4763356	total: 8m 36s	remaining: 31.2s
# 1946:	learn: 0.4748315	total: 8m 46s	remaining: 14.3s
# 1626:	learn: 0.4802708	total: 7m 27s	remaining: 1m 42s
# 1886:	learn: 0.4763194	total: 8m 36s	remaining: 30.9s
# 1947:	learn: 0.4748149	total: 8m 46s	remaining: 14.1s
# 1887:	learn: 0.4763040	total: 8m 36s	remaining: 30.6s
# 1627:	learn: 0.4802526	total: 7m 28s	remaining: 1m 42s
# 1948:	learn: 0.4747991	total: 8m 46s	remaining: 13.8s
# 1628:	learn: 0.4802351	total: 7m 28s	remaining: 1m 42s
# 1888:	learn: 0.4762877	total: 8m 36s	remaining: 30.4s
# 1949:	learn: 0.4747835	total: 8m 47s	remaining: 13.5s
# 1889:	learn: 0.4762718	total: 8m 37s	remaining: 30.1s
# 1629:	learn: 0.4802185	total: 7m 28s	remaining: 1m 41s
# 1950:	learn: 0.4747674	total: 8m 47s	remaining: 13.2s
# 1890:	learn: 0.4762553	total: 8m 37s	remaining: 29.8s
# 1630:	learn: 0.4802004	total: 7m 28s	remaining: 1m 41s
# 1951:	learn: 0.4747495	total: 8m 47s	remaining: 13s
# 1891:	learn: 0.4762431	total: 8m 37s	remaining: 29.5s
# 1952:	learn: 0.4747330	total: 8m 47s	remaining: 12.7s
# 1631:	learn: 0.4801822	total: 7m 29s	remaining: 1m 41s
# 1892:	learn: 0.4762262	total: 8m 37s	remaining: 29.3s
# 1953:	learn: 0.4747134	total: 8m 48s	remaining: 12.4s
# 1632:	learn: 0.4801631	total: 7m 29s	remaining: 1m 41s
# 1893:	learn: 0.4762089	total: 8m 38s	remaining: 29s
# 1954:	learn: 0.4746982	total: 8m 48s	remaining: 12.2s
# 1633:	learn: 0.4801458	total: 7m 29s	remaining: 1m 40s
# 1955:	learn: 0.4746799	total: 8m 48s	remaining: 11.9s
# 1894:	learn: 0.4761915	total: 8m 38s	remaining: 28.7s
# 1634:	learn: 0.4801283	total: 7m 30s	remaining: 1m 40s
# 1956:	learn: 0.4746636	total: 8m 48s	remaining: 11.6s
# 1895:	learn: 0.4761760	total: 8m 38s	remaining: 28.5s
# 1635:	learn: 0.4801135	total: 7m 30s	remaining: 1m 40s
# 1957:	learn: 0.4746483	total: 8m 49s	remaining: 11.4s
# 1896:	learn: 0.4761606	total: 8m 39s	remaining: 28.2s
# 1636:	learn: 0.4800959	total: 7m 30s	remaining: 1m 39s
# 1897:	learn: 0.4761426	total: 8m 39s	remaining: 27.9s
# 1958:	learn: 0.4746322	total: 8m 49s	remaining: 11.1s
# 1637:	learn: 0.4800795	total: 7m 30s	remaining: 1m 39s
# 1959:	learn: 0.4746166	total: 8m 49s	remaining: 10.8s
# 1898:	learn: 0.4761274	total: 8m 39s	remaining: 27.6s
# 1638:	learn: 0.4800647	total: 7m 31s	remaining: 1m 39s
# 1899:	learn: 0.4761113	total: 8m 39s	remaining: 27.4s
# 1960:	learn: 0.4746002	total: 8m 50s	remaining: 10.5s
# 1639:	learn: 0.4800475	total: 7m 31s	remaining: 1m 39s
# 1900:	learn: 0.4760949	total: 8m 40s	remaining: 27.1s
# 1961:	learn: 0.4745815	total: 8m 50s	remaining: 10.3s
# 1640:	learn: 0.4800305	total: 7m 31s	remaining: 1m 38s
# 1901:	learn: 0.4760784	total: 8m 40s	remaining: 26.8s
# 1641:	learn: 0.4800125	total: 7m 31s	remaining: 1m 38s
# 1962:	learn: 0.4745645	total: 8m 50s	remaining: 10s
# 1642:	learn: 0.4799967	total: 7m 32s	remaining: 1m 38s
# 1902:	learn: 0.4760622	total: 8m 40s	remaining: 26.5s
# 1963:	learn: 0.4745497	total: 8m 50s	remaining: 9.73s
# 1643:	learn: 0.4799795	total: 7m 32s	remaining: 1m 37s
# 1903:	learn: 0.4760444	total: 8m 40s	remaining: 26.3s
# 1964:	learn: 0.4745343	total: 8m 51s	remaining: 9.46s
# 1904:	learn: 0.4760296	total: 8m 41s	remaining: 26s
# 1644:	learn: 0.4799624	total: 7m 32s	remaining: 1m 37s
# 1965:	learn: 0.4745156	total: 8m 51s	remaining: 9.19s
# 1645:	learn: 0.4799428	total: 7m 33s	remaining: 1m 37s
# 1905:	learn: 0.4760124	total: 8m 41s	remaining: 25.7s
# 1966:	learn: 0.4744974	total: 8m 51s	remaining: 8.92s
# 1646:	learn: 0.4799232	total: 7m 33s	remaining: 1m 37s
# 1967:	learn: 0.4744833	total: 8m 52s	remaining: 8.65s
# 1906:	learn: 0.4759955	total: 8m 41s	remaining: 25.4s
# 1647:	learn: 0.4799061	total: 7m 33s	remaining: 1m 36s
# 1907:	learn: 0.4759752	total: 8m 42s	remaining: 25.2s
# 1968:	learn: 0.4744659	total: 8m 52s	remaining: 8.38s
# 1648:	learn: 0.4798909	total: 7m 33s	remaining: 1m 36s
# 1649:	learn: 0.4798745	total: 7m 33s	remaining: 1m 36s
# 1969:	learn: 0.4744510	total: 8m 52s	remaining: 8.11s
# 1908:	learn: 0.4759583	total: 8m 42s	remaining: 24.9s
# 1650:	learn: 0.4798545	total: 7m 34s	remaining: 1m 36s
# 1909:	learn: 0.4759408	total: 8m 42s	remaining: 24.6s
# 1970:	learn: 0.4744375	total: 8m 52s	remaining: 7.84s
# 1910:	learn: 0.4759242	total: 8m 42s	remaining: 24.4s
# 1651:	learn: 0.4798394	total: 7m 34s	remaining: 1m 35s
# 1971:	learn: 0.4744222	total: 8m 53s	remaining: 7.57s
# 1911:	learn: 0.4759066	total: 8m 43s	remaining: 24.1s
# 1652:	learn: 0.4798239	total: 7m 34s	remaining: 1m 35s
# 1972:	learn: 0.4744039	total: 8m 53s	remaining: 7.3s
# 1653:	learn: 0.4798062	total: 7m 34s	remaining: 1m 35s
# 1912:	learn: 0.4758895	total: 8m 43s	remaining: 23.8s
# 1973:	learn: 0.4743853	total: 8m 53s	remaining: 7.03s
# 1654:	learn: 0.4797892	total: 7m 35s	remaining: 1m 34s
# 1913:	learn: 0.4758712	total: 8m 43s	remaining: 23.5s
# 1974:	learn: 0.4743681	total: 8m 54s	remaining: 6.76s
# 1655:	learn: 0.4797723	total: 7m 35s	remaining: 1m 34s
# 1914:	learn: 0.4758561	total: 8m 44s	remaining: 23.3s
# 1975:	learn: 0.4743501	total: 8m 54s	remaining: 6.49s
# 1656:	learn: 0.4797521	total: 7m 35s	remaining: 1m 34s
# 1915:	learn: 0.4758406	total: 8m 44s	remaining: 23s
# 1976:	learn: 0.4743325	total: 8m 54s	remaining: 6.22s
# 1657:	learn: 0.4797358	total: 7m 36s	remaining: 1m 34s
# 1916:	learn: 0.4758244	total: 8m 44s	remaining: 22.7s
# 1977:	learn: 0.4743144	total: 8m 54s	remaining: 5.95s
# 1658:	learn: 0.4797166	total: 7m 36s	remaining: 1m 33s
# 1917:	learn: 0.4758075	total: 8m 44s	remaining: 22.4s
# 1978:	learn: 0.4742960	total: 8m 55s	remaining: 5.68s
# 1659:	learn: 0.4796979	total: 7m 36s	remaining: 1m 33s
# 1918:	learn: 0.4757919	total: 8m 45s	remaining: 22.2s
# 1979:	learn: 0.4742796	total: 8m 55s	remaining: 5.41s
# 1660:	learn: 0.4796812	total: 7m 36s	remaining: 1m 33s
# 1919:	learn: 0.4757746	total: 8m 45s	remaining: 21.9s
# 1980:	learn: 0.4742617	total: 8m 55s	remaining: 5.14s
# 1920:	learn: 0.4757581	total: 8m 45s	remaining: 21.6s
# 1661:	learn: 0.4796638	total: 7m 37s	remaining: 1m 32s
# 1981:	learn: 0.4742438	total: 8m 55s	remaining: 4.87s
# 1921:	learn: 0.4757431	total: 8m 45s	remaining: 21.3s
# 1662:	learn: 0.4796485	total: 7m 37s	remaining: 1m 32s
# 1982:	learn: 0.4742267	total: 8m 56s	remaining: 4.6s
# 1922:	learn: 0.4757289	total: 8m 46s	remaining: 21.1s
# 1663:	learn: 0.4796320	total: 7m 37s	remaining: 1m 32s
# 1983:	learn: 0.4742088	total: 8m 56s	remaining: 4.33s
# 1923:	learn: 0.4757129	total: 8m 46s	remaining: 20.8s
# 1664:	learn: 0.4796152	total: 7m 38s	remaining: 1m 32s
# 1984:	learn: 0.4741915	total: 8m 56s	remaining: 4.06s
# 1924:	learn: 0.4756956	total: 8m 46s	remaining: 20.5s
# 1665:	learn: 0.4795995	total: 7m 38s	remaining: 1m 31s
# 1985:	learn: 0.4741756	total: 8m 57s	remaining: 3.79s
# 1925:	learn: 0.4756775	total: 8m 47s	remaining: 20.2s
# 1666:	learn: 0.4795813	total: 7m 38s	remaining: 1m 31s
# 1986:	learn: 0.4741612	total: 8m 57s	remaining: 3.52s
# 1926:	learn: 0.4756594	total: 8m 47s	remaining: 20s
# 1667:	learn: 0.4795603	total: 7m 38s	remaining: 1m 31s
# 1987:	learn: 0.4741443	total: 8m 57s	remaining: 3.25s
# 1927:	learn: 0.4756415	total: 8m 47s	remaining: 19.7s
# 1668:	learn: 0.4795439	total: 7m 39s	remaining: 1m 31s
# 1988:	learn: 0.4741272	total: 8m 57s	remaining: 2.97s
# 1928:	learn: 0.4756268	total: 8m 47s	remaining: 19.4s
# 1929:	learn: 0.4756105	total: 8m 47s	remaining: 19.1s
# 1989:	learn: 0.4741111	total: 8m 58s	remaining: 2.7s
# 1669:	learn: 0.4795250	total: 7m 39s	remaining: 1m 30s
# 1990:	learn: 0.4740959	total: 8m 58s	remaining: 2.43s
# 1670:	learn: 0.4795061	total: 7m 39s	remaining: 1m 30s
# 1930:	learn: 0.4755958	total: 8m 48s	remaining: 18.9s
# 1931:	learn: 0.4755774	total: 8m 48s	remaining: 18.6s
# 1991:	learn: 0.4740770	total: 8m 58s	remaining: 2.16s
# 1671:	learn: 0.4794894	total: 7m 40s	remaining: 1m 30s
# 1932:	learn: 0.4755590	total: 8m 48s	remaining: 18.3s
# 1992:	learn: 0.4740595	total: 8m 58s	remaining: 1.89s
# 1672:	learn: 0.4794720	total: 7m 40s	remaining: 1m 29s
# 1993:	learn: 0.4740403	total: 8m 59s	remaining: 1.62s
# 1933:	learn: 0.4755422	total: 8m 49s	remaining: 18.1s
# 1673:	learn: 0.4794565	total: 7m 40s	remaining: 1m 29s
# 1994:	learn: 0.4740227	total: 8m 59s	remaining: 1.35s
# 1934:	learn: 0.4755237	total: 8m 49s	remaining: 17.8s
# 1674:	learn: 0.4794401	total: 7m 40s	remaining: 1m 29s
# 1995:	learn: 0.4740073	total: 8m 59s	remaining: 1.08s
# 1935:	learn: 0.4755078	total: 8m 49s	remaining: 17.5s
# 1675:	learn: 0.4794248	total: 7m 41s	remaining: 1m 29s
# 1996:	learn: 0.4739899	total: 9m	remaining: 811ms
# 1936:	learn: 0.4754903	total: 8m 49s	remaining: 17.2s
# 1676:	learn: 0.4794061	total: 7m 41s	remaining: 1m 28s
# 1997:	learn: 0.4739762	total: 9m	remaining: 541ms
# 1937:	learn: 0.4754731	total: 8m 50s	remaining: 17s
# 1677:	learn: 0.4793892	total: 7m 41s	remaining: 1m 28s
# 1938:	learn: 0.4754574	total: 8m 50s	remaining: 16.7s
# 1998:	learn: 0.4739609	total: 9m	remaining: 270ms
# 1678:	learn: 0.4793708	total: 7m 42s	remaining: 1m 28s
# 1939:	learn: 0.4754411	total: 8m 50s	remaining: 16.4s
# 1999:	learn: 0.4739456	total: 9m	remaining: 0us
# 1679:	learn: 0.4793534	total: 7m 42s	remaining: 1m 28s
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# Fit complete                        | 01:36:38
# Fitting complete at 20210911_222104

# %%
# wandb.log({'xgboost_params':str(xgboost_model.get_params()),
#            'lightgbm_params':str(lightgbm_model.get_params()),
# #            'catboost_params':str(blender.estimators[2][1].get_all_params()),
#           })

# %%
# model_path = Path(datapath/f"models/{config_run['name']}/")
# (model_path).mkdir(exist_ok=True)
# dump(blender, filename=model_path/f"{config_run['name']}_super-learner.joblib")
# print(f"Blender model saved at {datetime.now().strftime('%Y%m%d_%H%M%S')}")
# Out:
# Blender model saved at 20210911_222109

# %%
# train_preds = blender.predict_proba(X)#[:,1]
# train_loss = log_loss(y_pred=train_preds, y_true=y)
# train_auc = roc_auc_score(y, train_preds)
# wandb.log({'train_loss': train_loss, 'train_auc': train_auc})
# print(f"train_loss is {train_loss}, train_auc is {train_auc}")
# Out:
# Predicting 2 layers
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# Predict complete                    | 00:00:04
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/sklearn/metrics/_classification.py:2283: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/sklearn/metrics/_classification.py:2283: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# train_loss is nan, train_auc is 0.7818530616374615

# %%
# train_preds[:20]

# %% [markdown]
# # Test set preprocessing

# %% [markdown]
# (Here's where encapsulating the transformations in a pipeline would come in handy. But I'll do it manually for now.)

# %%
# features = [x for x in test_df.columns if x != 'claim']
# X_test = test_df[features] # this is just for naming consistency

# %% [markdown]
# Now, let's get the features the model was trained on and subset the test set's features accordingly

# %%
# generation polynomial features
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_test_poly = poly.fit_transform(X_test)

# %%
# X_test_poly_names = poly.get_feature_names(X_test.columns)
# X_poly_names[100:150]
# features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
# checks = [feature in X_test_poly_names for feature in features]
# checks

# %%
# X_test_final = pd.DataFrame(X_test_poly, columns=X_test_poly_names)

# %%
# X_test_final = X_test_final[features[1:]]
# X_test_final = X_test

# %%
# X_test['nan_count'] = X_test.isnull().sum(axis=1)

# %%
# imputer = SimpleImputer(strategy='median', add_indicator=True)
# X_test_imputed_np = imputer.fit_transform(X_test)

# %%
# X_test_imputed = pd.DataFrame(X_test_imputed, columns=[str(x) for x in range(X_test_imputed.shape[1])])
# X_test_imputed.to_feather(path=datapath/'X_test_NaNcounts_imputed-Median-wIndicators.feather')

# %%
# scaler = exmodel_config['scaler']()
# X_test_imputed_scaled_np = scaler.fit_transform(X_test_imputed)
# X_test_imputed_scaled = pd.DataFrame(X_test_imputed_scaled_np, columns=X_test_imputed.columns)
# X_test_imputed_scaled.to_feather(path=datapath/'X_test_NaNcounts_imputed-Median-wIndicators_StandardScaled.feather')
# X_scaled_df = pd.DataFrame(X_scaled, columns=X_poly_names)

# %%
X_test_imputed_scaled = pd.read_feather(path=datapath/'X_test_NaNcounts_imputed-Median-wIndicators_StandardScaled.feather')

# %% [markdown]
# ## Prediction Generation

# %%
# preds_path = Path(datapath/"preds/")

# blender_preds = blender.predict_proba(X_test_imputed_scaled)#[:,1]
# dump(blender_preds, preds_path/f"{config_run['name']}_stack.joblib")
# Out:
# Predicting 2 layers
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# Predict complete                    | 00:00:02
# ['/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/preds/super-learner_off-shelf_20210911_204351_stack.joblib']

# %% [markdown]
# # Submission

# %%
sample_df = pd.read_csv(datapath/'sample_solution.csv')

# %%
sample_df.loc[:, 'claim'] = blender_preds

# %%
sample_df.head()
# Out:
#        id  claim
# 0  957919    1.0
# 1  957920    0.0
# 2  957921    1.0
# 3  957922    0.0
# 4  957923    0.0

# %%
submission_path = datapath/'submissions'
submission_path.mkdir(exist_ok=True)

# %%
sample_df.to_csv(submission_path/f"{config_run['name']}_blended.csv", index=False)

# %%
wandb.log({'leaderboard_auc':  })

# %%
wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 1451947<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.27MB of 0.27MB uploaded (0.08MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210911_144315-nkcfcyur/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210911_144315-nkcfcyur/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>blender-final_estimator</td><td>None</td></tr><tr><td>blender-stack_mdethod</td><td>predict_proba</td></tr><tr><td>blender-cv</td><td>5</td></tr><tr><td>_runtime</td><td>7379</td></tr><tr><td>_timestamp</td><td>1631403974</td></tr><tr><td>_step</td><td>3</td></tr><tr><td>xgboost_params</td><td>{'objective': 'binar...</td></tr><tr><td>lightgbm_params</td><td>{'boosting_type': 'g...</td></tr><tr><td>train_loss</td><td>0.49101</td></tr><tr><td>train_auc</td><td>0.84658</td></tr><tr><td>leaderboard_auc</td><td>0.81602</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>blender-cv</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▇▇█</td></tr><tr><td>_timestamp</td><td>▁▇▇█</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>leaderboard_auc</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">stacking_off-shelf_20210911_144315</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/nkcfcyur" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/nkcfcyur</a><br/>

# %% [markdown]
# ## Manual Stacking

# %%
X.head()
# Out:
#            0         1         2         3         4         5         6  \
# id
# 0   0.425545 -2.357891 -0.637206 -0.866657 -0.111568 -4.829243 -1.171229
# 1   0.247600 -0.323982  1.223569  0.361863  1.071182 -0.361140  0.082051
# 2   2.032371 -2.435680 -0.488960  0.341193  1.069656  0.118532  0.537069
# 3   1.438373 -2.337605 -0.508914 -0.829607  1.485682  3.592008 -1.189087
# 4   0.602333  1.076218 -0.648438  0.463365  0.275053 -0.157989  0.727338
#
#            7         8         9  ...       227       228       229       230  \
# id                                ...
# 0  -0.603397 -0.596871 -0.516828  ... -0.128368 -0.127677 -0.128242 -0.127867
# 1  -0.746590  0.899454  0.469668  ... -0.128368 -0.127677 -0.128242 -0.127867
# 2  -0.044075 -0.763516  1.056879  ... -0.128368 -0.127677 -0.128242 -0.127867
# 3  -0.339152 -0.735281 -0.529158  ... -0.128368 -0.127677 -0.128242 -0.127867
# 4  -0.905498  0.052478 -0.511066  ... -0.128368 -0.127677 -0.128242 -0.127867
#
#          231       232       233      234       235      236
# id
# 0  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 1  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 2  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 3  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 4  -0.127119 -0.127985 -0.128494 -0.12862  7.821398 -0.12703
#
# [5 rows x 237 columns]

# %%
X1 = X.copy()

# %%
X1.shape
# Out:
# (957919, 237)

# %%
# generate probability predictions for the XGBoost model's folds
for fold in xgboost_models.keys():
#     X1[f"xgboost_fold{fold}_pred"] = xgboost_models[fold].predict(X)
    X1[f"xgboost_fold{fold}_pred"] = xgboost_models[fold].predict_proba(X)[:,1]
#     xgboost_preds[fold] = xgboost_models[fold].predict(X_test_imputed_scaled)
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
X1.head()
# Out:
#            0         1         2         3         4         5         6  \
# id
# 0   0.425545 -2.357891 -0.637206 -0.866657 -0.111568 -4.829243 -1.171229
# 1   0.247600 -0.323982  1.223569  0.361863  1.071182 -0.361140  0.082051
# 2   2.032371 -2.435680 -0.488960  0.341193  1.069656  0.118532  0.537069
# 3   1.438373 -2.337605 -0.508914 -0.829607  1.485682  3.592008 -1.189087
# 4   0.602333  1.076218 -0.648438  0.463365  0.275053 -0.157989  0.727338
#
#            7         8         9  ...       232       233      234       235  \
# id                                ...
# 0  -0.603397 -0.596871 -0.516828  ... -0.127985 -0.128494 -0.12862 -0.127854
# 1  -0.746590  0.899454  0.469668  ... -0.127985 -0.128494 -0.12862 -0.127854
# 2  -0.044075 -0.763516  1.056879  ... -0.127985 -0.128494 -0.12862 -0.127854
# 3  -0.339152 -0.735281 -0.529158  ... -0.127985 -0.128494 -0.12862 -0.127854
# 4  -0.905498  0.052478 -0.511066  ... -0.127985 -0.128494 -0.12862  7.821398
#
#         236  xgboost_fold0_pred  xgboost_fold1_pred  xgboost_fold2_pred  \
# id
# 0  -0.12703            0.582566            0.580950            0.576743
# 1  -0.12703            0.152252            0.150803            0.148316
# 2  -0.12703            0.794083            0.789945            0.788326
# 3  -0.12703            0.774001            0.768510            0.774555
# 4  -0.12703            0.759366            0.755764            0.763769
#
#     xgboost_fold3_pred  xgboost_fold4_pred
# id
# 0             0.569523            0.595877
# 1             0.155218            0.147297
# 2             0.787177            0.797979
# 3             0.782187            0.773245
# 4             0.758034            0.758038
#
# [5 rows x 242 columns]
