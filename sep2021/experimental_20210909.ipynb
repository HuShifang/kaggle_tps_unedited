# %% [markdown]
# # Experiment
# I want to see how a model fit on the full dataset performs relative to models fit on k-folds / their composition

# %% [markdown]
# # Setup

# %%
# two manual flags (ex-config)
colab = False
gpu_available = True
libraries = ['catboost']

# %%
# basic imports
from pathlib import Path
import os
import math
from datetime import datetime

# %%
# %matplotlib inline
# %config Completer.use_jedi = False
os.environ['WANDB_NOTEBOOK_NAME'] = f"experimental_{datetime.now().strftime('%Y%m%d')}.ipynb"

# %%
# handle Google Colab-specific library installation/updating
if colab:
    # much of the below inspired by or cribbed from the May 2021 Kaggle Tabular Playground winner, at 
    # https://colab.research.google.com/gist/academicsuspect/0aac7bd6e506f5f70295bfc9a3dc2250/tabular-may-baseline.ipynb?authuser=1#scrollTo=LJoVKJb5wN0L
    
    # Kaggle API for downloading the datasets
    # !pip install --upgrade -q kaggle

    # weights and biases
    # !pip install -qqqU wandb
    
    # Optuna for parameter search
    # !pip install -q optuna

    # upgrade sklearn
    # !pip install --upgrade scikit-learn

    # !pip install category_encoders
    
    if 'catboost' in libraries:
        # !pip install catboost
    
    if 'xgboost' in libraries:
        if gpu_available: 
            # this part is from https://github.com/rapidsai/gputreeshap/issues/24
            # !pip install cmake --upgrade
            # !pip install sklearn --upgrade
            # !git clone --recursive https://github.com/dmlc/xgboost
            # %cd /content/xgboost
            # !mkdir build
            # %cd build
            # !cmake .. -DUSE_CUDA=ON
            # !make -j4
            # %cd /content/xgboost/python-package
            # !python setup.py install --use-cuda --use-nccl
            # !/opt/bin/nvidia-smi
            # !pip install shap
        else:
            # !pip install --upgrade xgboost
    if 'lightgbm' in libraries:
        if gpu_available:
            # lighgbm gpu compatible
            # !git clone --recursive https://github.com/Microsoft/LightGBM
            ! cd LightGBM && rm -rf build && mkdir build && cd build && cmake -DUSE_GPU=1 ../../LightGBM && make -j4 && cd ../python-package && python3 setup.py install --precompile --gpu;
        else:
            # !pip install --upgrade lightgbm

# %% [markdown]
# Now, non-stdlib imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# general ML tooling
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import log_loss, roc_auc_score
import wandb
from wandb.xgboost import wandb_callback
from wandb.lightgbm import wandb_callback
from sklearn.impute import KNNImputer, SimpleImputer
# import timm

import seaborn as sns

from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
# from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MaxAbsScaler, StandardScaler, MinMaxScaler, RobustScaler, PolynomialFeatures
# from sklearn.feature_selection import SelectKBest, f_regression
from joblib import dump, load
# feature engineering tools
# from sklearn.feature_selection import mutual_info_regression
# import featuretools as ft
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# Now, datapath setup

# %%
# # This is the code for reading the train.csv and converting it to a .feather file
# df = pd.read_csv(datapath/'train.csv', index_col='id', low_memory=False)
# df.index.name = None
# df.to_feather(path='./dataset_df.feather')

# %%
if colab:
    # mount Google Drive
    from google.colab import drive
    drive.mount('/content/drive')
    
    # handling datapath
    datapath = Path('/content/drive/MyDrive/kaggle/tabular_playgrounds/sep2021/')
    
else:
    # if on local machine
    datapath = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/')

# %% [markdown]
# ## Ex-Model Config

# %%
# meta-config for preprocessing and cross-validation, but NOT for model parameters
exmodel_config = {
    # model config
#     "model": XGBClassifier,
#     "n_estimators": 100, 
#     "max_depth": 3,
#     "learning_rate": 0.1,
#     "test_size": 0.2,
#     "reg_lambda": None, 
    "scaler": StandardScaler, # TODO: experiment with others (but imputation may be slow)
    "scale_b4_impute": False,
    "imputer": SimpleImputer(strategy='median', add_indicator=True),
    "knn_imputer_n_neighbors": None, # None if a different imputer is used
#     "feature_selector": SelectKBest,
#     "k_best": 80,
#     "feature_selection_scoring": f_regression,
    'random_state': 42,
#     'subsample': 1,
    'cross_val_strategy': KFold, # None for holdout, or the relevant sklearn class
    'kfolds': 5, # if 1, that means just doing holdout
    'test_size': 0.2,
#     'features_created': False,
#     'feature_creator': None,
}

# %% [markdown]
# ## Data Setup

# %% [markdown]
# **TODO** Write some conditional logic here to automate it -- possibly as part of a sklearn.*pipeline

# %%
# if exmodel_config['scaler']:
#     scaler = exmodel_config['scaler']()
#     scaler.fit_transform()

# %%
# # here's how to load the original, unaltered dataset and separate features from targets
# df = pd.read_feather(path=datapath/'dataset_df.feather') # this is the unaltered original dataset
# features = [x for x in df.columns if x != 'claim']
# X = df[features]
# y = df.claim



# load the version of the dataset with imputations; X and y were stored separately, as feather and joblib respectively
X = pd.read_feather(datapath/'X_NaNcounts_imputed-Median-wIndicators-StandardScaled.feather') 
y = load(datapath/'y.joblib')    
X.index.name = 'id'
y.index.name = 'id'

exmodel_config['feature_count'] = len(X.columns)
exmodel_config['feature_generator'] = None

# %%
# scaler = exmodel_config['scaler']()
# X_scaled = scaler.fit_transform(X)
# X = pd.DataFrame(X_scaled, columns=X.columns)

# %%
X.head()
# Out:
#            0         1         2         3         4         5         6  \
# id
# 0   0.425545 -2.357891 -0.637206 -0.866657 -0.111568 -4.829243 -1.171229
# 1   0.247600 -0.323982  1.223569  0.361863  1.071182 -0.361140  0.082051
# 2   2.032371 -2.435680 -0.488960  0.341193  1.069656  0.118532  0.537069
# 3   1.438373 -2.337605 -0.508914 -0.829607  1.485682  3.592008 -1.189087
# 4   0.602333  1.076218 -0.648438  0.463365  0.275053 -0.157989  0.727338
#
#            7         8         9  ...       227       228       229       230  \
# id                                ...
# 0  -0.603397 -0.596871 -0.516828  ... -0.128368 -0.127677 -0.128242 -0.127867
# 1  -0.746590  0.899454  0.469668  ... -0.128368 -0.127677 -0.128242 -0.127867
# 2  -0.044075 -0.763516  1.056879  ... -0.128368 -0.127677 -0.128242 -0.127867
# 3  -0.339152 -0.735281 -0.529158  ... -0.128368 -0.127677 -0.128242 -0.127867
# 4  -0.905498  0.052478 -0.511066  ... -0.128368 -0.127677 -0.128242 -0.127867
#
#          231       232       233      234       235      236
# id
# 0  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 1  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 2  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 3  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 4  -0.127119 -0.127985 -0.128494 -0.12862  7.821398 -0.12703
#
# [5 rows x 237 columns]

# %%
y.head()
# Out:
# id
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: claim, dtype: int64

# %% [markdown]
# ### Model Config

# %%
def model_configurator(library, gpu_available=True):#, config=universal_config):
    """
    Function that provide task-specific or general preference arguments for the various models. 
    
    At first, will rely largely on defaults for hyperparameters, but later this function 
    can be supplemented later with optimal values, as they're learned in sweeps.
    .
    
    Rationale: creating a helper function will allow more experimentation later, and also
    composite runs that cycle through a series of models.
    
    :param model: A model from [XGBClassifier, LGBMClassifier, CatBoostClassifier]
    :return config: A dict that supplements default hyperparameter values with 1) 
                    task-appropriate ones, and perhaps later 2) optimal hyperparameter values.
    """
    config = {}
    
    # library-specific config
    if library in ['xgboost', 'lightgbm']:
        config['n_jobs'] = -1
        
    # best params per sweep `icac24c5`, generated from notebook `sweep_20210905.ipynb`
    # runtime per fold should be around 12m 38s
    # should get auc of 0.7434 on the random_state=42 holdout
    # haven't yet tried dart
    if library == 'xgboost':
#         config['tree_method'] = 'auto'
#         config['booster'] = 'gbtree' # or 'dart'
#         config['model'] = XGBClassifier
        config['verbosity'] = 1
        config['objective'] = 'binary:logistic'
#         config['eval_metric'] = ['auc', 'logloss', 'aucpr'],
        config['tree_method'] = 'gpu_hist' if (gpu_available and colab) else 'auto' 
        
        # comment out the below to get defaults
        config['n_estimators'] = 902
        config['learning_rate'] = 0.0304
        config['max_depth'] = 3
        config['reg_alpha'] = 0.863
        config['reg_lambda'] = 2.442
        config['subsample'] = 0.8627

    # best params per sweep `sjghewf0`, generated from notebook `sweep_lightgbm_20210907`
    # run name `sweep_lightgbm_20210907_195641`
    # runtime per fold should be around 39s
    # should get an auc of 0.7435 on random_state=42 holdout
    if library == 'lightgbm':
#         config['model'] = LGBMClassifier
        config['objective'] = 'binary'
        config['eval_metric'] = ['auc', 'logloss']
        config['boosting_type'] = 'gbdt' # or 'dart'
        config['device_type'] = 'cuda' if (gpu_available and colab) else 'cpu' # 'gpu' also possible, 'cpu' is default
        
        # comment out the below for defaults
        config['n_estimators'] = 1286
        config['learning_rate'] = 0.03221
        config['max_depth'] = 2
        config['reg_alpha'] = 0.4687
        config['reg_lambda'] = 0.1763
        config['subsample'] = 0.6621
        

#     if config['model'] == CatBoostClassifier:
    if library == 'catboost':
#         config['model'] = CatBoostClassifier
        config['task_type'] = 'GPU' if gpu_available else 'CPU'
        config['custom_metrics'] = ['Logloss', 'AUC'] # objective (loss fn) must be singular, defaults to Logloss
        config['n_estimators'] = 2000 # logged as "iterations" otherwise

    return config

# %% [markdown]
# ## Weights and Biases Run Config

# %% [markdown]
# Below is the configuration for a Weights and Biases (`wandb`) run.

# %%
# wandb config:
config_run = {
    'name': f"{os.environ['WANDB_NOTEBOOK_NAME'][:-6]}_{datetime.now().strftime('%H%M%S')}", # just removes the .ipynb extension, leaving the notebook filename's stem
    'tags': ['experiment'],
    'notes': "I want to see how a model fit on the full dataset performs relative to models fit on k-folds / their composition",
}

# %% [markdown]
# # Preprocessing
# Scaling has already occurred -- used `StandardScaler` as a precursor to using `KNNImputer(n_neighbors=5)`, on the premise that imputation would proceed more quickly if things were already scaled. I may try different permutations of this later: using `IterativeImputer` instead, before or after scaling, potentially with different scalers.

# %% [markdown]
# # Feature Creation and Selection

# %%
# load all the polynomialfeatures generated with `PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)`
# X_np = np.load(datapath/'X_poly_unscaled.npy')
# X = pd.DataFrame(X_np)

# %%
# X.columns

# %%
# generation polynomial features
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_poly = poly.fit_transform(X)

# %%
# X_poly_names = poly.get_feature_names(X.columns)
# # X_poly_names[100:150]
# features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
# checks = [feature in X_poly_names for feature in features]
# checks

# %%
# X = pd.DataFrame(X_poly, columns=X_poly_names)

# %%
# X = X[features[1:]]

# %% [markdown]
# # Training

# %%
def train(X_train, X_valid, y_train, y_valid, model_config, 
                                              random_state=42,
                                              exmodel_config=exmodel_config, 
                                              config_run=config_run):#, scaler): # passed in via config dict for now
    """
    Basic training function. Note that some of the options passed via the argument are
    in fact hard-coded in, to avoid inconveniences.
    :param X_train: the training set features
    :param X_valid: the validation set features
    :param y_train: the training set targets
    :param y_valid: the validation set targets
    :param random_staKFold: for reproducibility
    :param exmodel_config: dict containing configuration details including the library 
                            (thus model) used, preprocessing, and cross-validation
    :param model_config: dict containing hyperparameter specifications for the model
    :param config_run: dict containing wandb run configuration (name, etc)
    """
    
    
    wandb.init(
        project="202109_Kaggle_tabular_playground",
        save_code=True,
        tags=config_run['tags'],
        name=config_run['name'],
        notes=config_run['notes'],
        config=exmodel_config)   
        
    if exmodel_config['library'] == 'xgboost':
        model = XGBClassifier(
            tree_method=model_config['tree_method'],
            random_state=random_state,
            n_jobs=model_config['n_jobs'], 
            verbosity=model_config['verbosity'], 
            objective=model_config['objective'],
            # #             eval_metric=model_config['eval_metric'],

            # comment out the below for a fairly default model
#             booster=model_config['booster'],
            max_depth=model_config['max_depth'],
            learning_rate=model_config['learning_rate'], 
            subsample=model_config['subsample'],
            reg_alpha=model_config['reg_alpha'],
            reg_lambda=model_config['reg_lambda'],
            n_estimators=model_config['n_estimators'],
        )
        
        model.fit(X_train, y_train, callbacks=[wandb.xgboost.wandb_callback()],
#                                     eval_metric=model_config['eval_metric'],
                 )


    elif exmodel_config['library'] == 'lightgbm':
        model = LGBMClassifier(
#             boosting_type=model_config['boosting_type'],
#             max_depth=model_config['max_depth']
            # TODO
            random_state=random_state,
            n_jobs=model_config['n_jobs'],
            objective=model_config['objective'],
#             eval_metric=model_config['eval_metric'],
            boosting_type=model_config['boosting_type'],
            device_type=model_config['device_type'],
            
            # comment out the below for a basically default model
            n_estimators=model_config['n_estimators'],
            learning_rate=model_config['learning_rate'],
            max_depth=model_config['max_depth'],
            reg_alpha=model_config['reg_alpha'],
            reg_lambda=model_config['reg_lambda'],
            subsample=model_config['subsample'],
        )
        
        model.fit(X_train, y_train, callbacks=[wandb.lightgbm.wandb_callback()],
#                                     eval_metric=model_config['eval_metric'],
                 )
        
    elif exmodel_config['library'] == 'catboost':
        print("CatBoost, therefore no WandB callback.")
        model = CatBoostClassifier(
#             n_estimators=config['n_estimators'],
#             learning_rate=config['learning_rate'],
#             max_depth=config['max_depth'],
            task_type=model_config['task_type'],
    #         n_jobs=config['n_jobs'],
    #         verbosity=config['verbosity'],
    #         subsample=config['subsample'],
            n_estimators=model_config['n_estimators'],
            random_state=random_state,
            # objective='Logloss', # default, accepts only one
#             custom_metrics=model_config['custom_metrics'],
    #         bootstrap_type=config['bootstrap_type'],
    #         device:config['device']
        ) 
        model.fit(X_train, y_train)
    y_train_pred = model.predict_proba(X_train)[:,1]
    train_loss = log_loss(y_train, y_train_pred)
    train_auc = roc_auc_score(y_train, y_train_pred)
    wandb.log({'train_loss': train_loss, 'train_auc': train_auc})

    if exmodel_config['library'] == 'catboost':
        print(model.get_all_params())
        wandb.log(model.get_all_params())
    else:
        wandb.log(model.get_params()) # logging model parameters, trying bare-invocation rather than params: model.get_params()
    
    y_pred = model.predict_proba(X_valid)[:,1]
#     mse = mean_squared_error(y_valid, y_pred)
#     rmse = math.sqrt(abs(mse))
    valid_loss = log_loss(y_valid, y_pred)
    valid_auc = roc_auc_score(y_valid, y_pred)
    wandb.log({'valid_loss':valid_loss, 'valid_auc':valid_auc})
    print(f"Valid log-loss is {valid_loss}\nValid AUC is {valid_auc}")   
#     wandb.finish()   
    return model

# %%
def cross_validation(model_config, X=X, y=y, start_fold=0, exmodel_config=exmodel_config, random_state=42):
    """
    Function to handle model training process in the context of cross-validation -- via hold-out or via k-fold.
    If exmodel_config['cross_val_strategy'] == None, then any kfolds= input is ignored; otherwise, the number specified is used.
    
    :param kfolds: int specifying number of k-folds to use in cross-validation
    :param exmodel_config: dict containing general config including for cross-validation -- `kfold=1` implies hold-out
    """
    if exmodel_config['kfolds'] == 1:
        print("Proceeding with holdout")
        X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
                                                      test_size=exmodel_config['test_size'], 
                                                      random_state=random_state,
                                                     )
        model = train(X_train, X_valid, y_train, y_valid, exmodel_config=exmodel_config, 
                                                    model_config=model_config,
                                                    config_run=config_run)
        wandb.finish()
        
    else:
        X, y = X.to_numpy(), y.to_numpy()
        kfold = exmodel_config['cross_val_strategy'](n_splits=exmodel_config['kfolds'], shuffle=True, random_state=random_state)
        models = {}
        model_path = Path(datapath/f"models/{config_run['name']}_{exmodel_config['kfolds']}folds/")
        (model_path).mkdir(exist_ok=True)
        for fold, (train_ids, valid_ids) in enumerate(kfold.split(X,y)):
            if fold < start_fold:
                continue
            else:
                print(f"FOLD {fold}")
                print("---------------------------------------------------")
                X_train, X_valid = X[train_ids], X[valid_ids]
                y_train, y_valid = y[train_ids], y[valid_ids]
                model = train(X_train, X_valid, y_train, y_valid, exmodel_config=exmodel_config, 
                                                    model_config=model_config,
                                                    config_run=config_run)
                wandb.log({'fold': fold})
                models[fold] = model
                dump(model, Path(model_path/f"{exmodel_config['library']}_fold{fold}_model.joblib"))
                wandb.finish()
        return models

# %% [markdown]
# # Interface

# %% [markdown]
# ## Runs

# %%
# library = 'xgboost'
# exmodel_config['library'] = library
# model_config = model_configurator(library)
# xgboost_models = cross_validation(model_config)

# %%
# for scaler in [StandardScaler, MaxAbsScaler, MinMaxScaler, RobustScaler]:
#     exmodel_config['scaler'] = scaler
#     scaler = scaler()
#     X_scaled = scaler.fit_transform(X)
#     X = pd.DataFrame(X_scaled, columns=X.columns)
#     exmodel_config['library'] = 'lightgbm'
#     model_config = model_configurator('lightgbm')
#     cross_validation(model_config)

# %%
# library = 'xgboost'
# exmodel_config['library'] = library
# model_config = model_configurator(library)
# xgboost_models = cross_validation(model_config)

# library = 'lightgbm'
# exmodel_config['library'] = library
# model_config = model_configurator(library)
# lightgbm_models = cross_validation(model_config)

# %%
library = 'catboost'
gpu_available = True
exmodel_config['library'] = library
model_config = model_configurator(library)
catboost_models = cross_validation(model_config)

exmodel_config['kfolds'] = 1
exmodel_config['cross_val_strategy'] = None


catboost_fulldataset_model = train(X_train=X, X_valid=X, y_train=y, y_valid=y, model_config=model_config)
# Out:
# FOLD 0
# ---------------------------------------------------
# wandb: WARNING WANDB_NOTEBOOK_NAME should be a path to a notebook file, couldn't find experimental_20210910.ipynb
# wandb: Currently logged in as: hushifang (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">experimental_20210910_183652</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1chulhx3" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1chulhx3</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210910_183656-1chulhx3</code><br/><br/>
# CatBoost, therefore no WandB callback.
# Learning rate set to 0.012572
# 0:	learn: 0.6881616	total: 12.5ms	remaining: 25.1s
# 1:	learn: 0.6833115	total: 30ms	remaining: 30s
# 2:	learn: 0.6785920	total: 81.6ms	remaining: 54.3s
# 3:	learn: 0.6740076	total: 111ms	remaining: 55.6s
# 4:	learn: 0.6695552	total: 132ms	remaining: 52.7s
# 5:	learn: 0.6652218	total: 147ms	remaining: 49s
# 6:	learn: 0.6610043	total: 163ms	remaining: 46.5s
# 7:	learn: 0.6569107	total: 179ms	remaining: 44.5s
# 8:	learn: 0.6529261	total: 196ms	remaining: 43.5s
# 9:	learn: 0.6490535	total: 214ms	remaining: 42.6s
# 10:	learn: 0.6452922	total: 231ms	remaining: 41.9s
# 11:	learn: 0.6416302	total: 254ms	remaining: 42.1s
# 12:	learn: 0.6380721	total: 270ms	remaining: 41.3s
# 13:	learn: 0.6346165	total: 288ms	remaining: 40.8s
# 14:	learn: 0.6312586	total: 324ms	remaining: 42.9s
# 15:	learn: 0.6279916	total: 363ms	remaining: 45s
# 16:	learn: 0.6248175	total: 390ms	remaining: 45.5s
# 17:	learn: 0.6217344	total: 417ms	remaining: 45.9s
# 18:	learn: 0.6187336	total: 445ms	remaining: 46.4s
# 19:	learn: 0.6158168	total: 461ms	remaining: 45.6s
# 20:	learn: 0.6129796	total: 474ms	remaining: 44.7s
# 21:	learn: 0.6102238	total: 493ms	remaining: 44.4s
# 22:	learn: 0.6075471	total: 508ms	remaining: 43.7s
# 23:	learn: 0.6049443	total: 525ms	remaining: 43.2s
# 24:	learn: 0.6024146	total: 541ms	remaining: 42.8s
# 25:	learn: 0.5999544	total: 556ms	remaining: 42.2s
# 26:	learn: 0.5975652	total: 571ms	remaining: 41.7s
# 27:	learn: 0.5952403	total: 583ms	remaining: 41.1s
# 28:	learn: 0.5929713	total: 600ms	remaining: 40.7s
# 29:	learn: 0.5907725	total: 614ms	remaining: 40.3s
# 30:	learn: 0.5886374	total: 630ms	remaining: 40s
# 31:	learn: 0.5865598	total: 656ms	remaining: 40.3s
# 32:	learn: 0.5845430	total: 669ms	remaining: 39.9s
# 33:	learn: 0.5825799	total: 685ms	remaining: 39.6s
# 34:	learn: 0.5806712	total: 698ms	remaining: 39.2s
# 35:	learn: 0.5788192	total: 709ms	remaining: 38.7s
# 36:	learn: 0.5770169	total: 721ms	remaining: 38.3s
# 37:	learn: 0.5752659	total: 733ms	remaining: 37.9s
# 38:	learn: 0.5735563	total: 745ms	remaining: 37.4s
# 39:	learn: 0.5719005	total: 756ms	remaining: 37.1s
# 40:	learn: 0.5702912	total: 767ms	remaining: 36.7s
# 41:	learn: 0.5687238	total: 783ms	remaining: 36.5s
# 42:	learn: 0.5671983	total: 816ms	remaining: 37.1s
# 43:	learn: 0.5657139	total: 839ms	remaining: 37.3s
# 44:	learn: 0.5642750	total: 851ms	remaining: 37s
# 45:	learn: 0.5628735	total: 864ms	remaining: 36.7s
# 46:	learn: 0.5615088	total: 876ms	remaining: 36.4s
# 47:	learn: 0.5601842	total: 890ms	remaining: 36.2s
# 48:	learn: 0.5588886	total: 903ms	remaining: 35.9s
# 49:	learn: 0.5576372	total: 923ms	remaining: 36s
# 50:	learn: 0.5564180	total: 942ms	remaining: 36s
# 51:	learn: 0.5552343	total: 957ms	remaining: 35.8s
# 52:	learn: 0.5540834	total: 974ms	remaining: 35.8s
# 53:	learn: 0.5529623	total: 988ms	remaining: 35.6s
# 54:	learn: 0.5518709	total: 1.01s	remaining: 35.7s
# 55:	learn: 0.5508091	total: 1.03s	remaining: 35.6s
# 56:	learn: 0.5497816	total: 1.04s	remaining: 35.5s
# 57:	learn: 0.5487825	total: 1.06s	remaining: 35.5s
# 58:	learn: 0.5478052	total: 1.08s	remaining: 35.5s
# 59:	learn: 0.5468546	total: 1.09s	remaining: 35.4s
# 60:	learn: 0.5459327	total: 1.11s	remaining: 35.4s
# 61:	learn: 0.5450365	total: 1.13s	remaining: 35.4s
# 62:	learn: 0.5441636	total: 1.16s	remaining: 35.6s
# 63:	learn: 0.5433138	total: 1.19s	remaining: 36s
# 64:	learn: 0.5424875	total: 1.22s	remaining: 36.4s
# 65:	learn: 0.5416851	total: 1.23s	remaining: 36.1s
# 66:	learn: 0.5408985	total: 1.25s	remaining: 35.9s
# 67:	learn: 0.5401384	total: 1.26s	remaining: 35.7s
# 68:	learn: 0.5394003	total: 1.27s	remaining: 35.5s
# 69:	learn: 0.5386831	total: 1.28s	remaining: 35.3s
# 70:	learn: 0.5379829	total: 1.29s	remaining: 35.1s
# 71:	learn: 0.5373039	total: 1.31s	remaining: 35s
# 72:	learn: 0.5366417	total: 1.32s	remaining: 34.8s
# 73:	learn: 0.5359978	total: 1.33s	remaining: 34.7s
# 74:	learn: 0.5353693	total: 1.35s	remaining: 34.6s
# 75:	learn: 0.5347588	total: 1.37s	remaining: 34.6s
# 76:	learn: 0.5341597	total: 1.39s	remaining: 34.7s
# 77:	learn: 0.5335843	total: 1.41s	remaining: 34.7s
# 78:	learn: 0.5330236	total: 1.43s	remaining: 34.7s
# 79:	learn: 0.5324756	total: 1.44s	remaining: 34.6s
# 80:	learn: 0.5319431	total: 1.48s	remaining: 35s
# 81:	learn: 0.5314277	total: 1.49s	remaining: 34.9s
# 82:	learn: 0.5309188	total: 1.51s	remaining: 34.8s
# 83:	learn: 0.5304283	total: 1.52s	remaining: 34.8s
# 84:	learn: 0.5299521	total: 1.54s	remaining: 34.7s
# 85:	learn: 0.5294857	total: 1.55s	remaining: 34.6s
# 86:	learn: 0.5290366	total: 1.57s	remaining: 34.5s
# 87:	learn: 0.5285994	total: 1.58s	remaining: 34.3s
# 88:	learn: 0.5281698	total: 1.6s	remaining: 34.3s
# 89:	learn: 0.5277526	total: 1.64s	remaining: 34.9s
# 90:	learn: 0.5273420	total: 1.66s	remaining: 34.9s
# 91:	learn: 0.5269456	total: 1.68s	remaining: 34.8s
# 92:	learn: 0.5265606	total: 1.69s	remaining: 34.6s
# 93:	learn: 0.5261845	total: 1.7s	remaining: 34.5s
# 94:	learn: 0.5258186	total: 1.72s	remaining: 34.6s
# 95:	learn: 0.5254621	total: 1.74s	remaining: 34.5s
# 96:	learn: 0.5251161	total: 1.75s	remaining: 34.4s
# 97:	learn: 0.5247749	total: 1.77s	remaining: 34.3s
# 98:	learn: 0.5244499	total: 1.78s	remaining: 34.2s
# 99:	learn: 0.5241286	total: 1.8s	remaining: 34.2s
# 100:	learn: 0.5238106	total: 1.82s	remaining: 34.2s
# 101:	learn: 0.5235093	total: 1.83s	remaining: 34.1s
# 102:	learn: 0.5232154	total: 1.85s	remaining: 34.1s
# 103:	learn: 0.5229231	total: 1.87s	remaining: 34.1s
# 104:	learn: 0.5226415	total: 1.88s	remaining: 34s
# 105:	learn: 0.5223674	total: 1.9s	remaining: 33.9s
# 106:	learn: 0.5220979	total: 1.91s	remaining: 33.8s
# 107:	learn: 0.5218385	total: 1.92s	remaining: 33.7s
# 108:	learn: 0.5215895	total: 1.94s	remaining: 33.6s
# 109:	learn: 0.5213431	total: 1.95s	remaining: 33.5s
# 110:	learn: 0.5210994	total: 1.97s	remaining: 33.4s
# 111:	learn: 0.5208678	total: 1.98s	remaining: 33.4s
# 112:	learn: 0.5206393	total: 1.99s	remaining: 33.3s
# 113:	learn: 0.5204132	total: 2.01s	remaining: 33.2s
# 114:	learn: 0.5201972	total: 2.02s	remaining: 33.1s
# 115:	learn: 0.5199827	total: 2.04s	remaining: 33.1s
# 116:	learn: 0.5197792	total: 2.06s	remaining: 33.1s
# 117:	learn: 0.5195793	total: 2.07s	remaining: 33.1s
# 118:	learn: 0.5193844	total: 2.09s	remaining: 33s
# 119:	learn: 0.5191965	total: 2.1s	remaining: 32.9s
# 120:	learn: 0.5190118	total: 2.11s	remaining: 32.8s
# 121:	learn: 0.5188329	total: 2.13s	remaining: 32.8s
# 122:	learn: 0.5186587	total: 2.14s	remaining: 32.7s
# 123:	learn: 0.5184882	total: 2.15s	remaining: 32.6s
# 124:	learn: 0.5183194	total: 2.17s	remaining: 32.5s
# 125:	learn: 0.5181598	total: 2.18s	remaining: 32.4s
# 126:	learn: 0.5179995	total: 2.19s	remaining: 32.3s
# 127:	learn: 0.5178474	total: 2.21s	remaining: 32.3s
# 128:	learn: 0.5176938	total: 2.23s	remaining: 32.3s
# 129:	learn: 0.5175461	total: 2.24s	remaining: 32.2s
# 130:	learn: 0.5174055	total: 2.25s	remaining: 32.2s
# 131:	learn: 0.5172671	total: 2.27s	remaining: 32.1s
# 132:	learn: 0.5171313	total: 2.28s	remaining: 32.1s
# 133:	learn: 0.5170002	total: 2.3s	remaining: 32s
# 134:	learn: 0.5168715	total: 2.31s	remaining: 31.9s
# 135:	learn: 0.5167477	total: 2.32s	remaining: 31.9s
# 136:	learn: 0.5166233	total: 2.34s	remaining: 31.8s
# 137:	learn: 0.5165055	total: 2.35s	remaining: 31.7s
# 138:	learn: 0.5163928	total: 2.36s	remaining: 31.6s
# 139:	learn: 0.5162805	total: 2.38s	remaining: 31.6s
# 140:	learn: 0.5161675	total: 2.39s	remaining: 31.5s
# 141:	learn: 0.5160571	total: 2.41s	remaining: 31.5s
# 142:	learn: 0.5159503	total: 2.42s	remaining: 31.5s
# 143:	learn: 0.5158483	total: 2.44s	remaining: 31.4s
# 144:	learn: 0.5157483	total: 2.45s	remaining: 31.3s
# 145:	learn: 0.5156509	total: 2.46s	remaining: 31.3s
# 146:	learn: 0.5155555	total: 2.48s	remaining: 31.2s
# 147:	learn: 0.5154609	total: 2.49s	remaining: 31.1s
# 148:	learn: 0.5153686	total: 2.5s	remaining: 31.1s
# 149:	learn: 0.5152769	total: 2.52s	remaining: 31s
# 150:	learn: 0.5151906	total: 2.53s	remaining: 31s
# 151:	learn: 0.5151063	total: 2.54s	remaining: 30.9s
# 152:	learn: 0.5150229	total: 2.56s	remaining: 30.9s
# 153:	learn: 0.5149446	total: 2.57s	remaining: 30.8s
# 154:	learn: 0.5148632	total: 2.58s	remaining: 30.7s
# 155:	learn: 0.5147916	total: 2.59s	remaining: 30.7s
# 156:	learn: 0.5147171	total: 2.61s	remaining: 30.6s
# 157:	learn: 0.5146431	total: 2.63s	remaining: 30.6s
# 158:	learn: 0.5145684	total: 2.65s	remaining: 30.6s
# 159:	learn: 0.5144977	total: 2.66s	remaining: 30.6s
# 160:	learn: 0.5144261	total: 2.68s	remaining: 30.6s
# 161:	learn: 0.5143624	total: 2.69s	remaining: 30.6s
# 162:	learn: 0.5142969	total: 2.71s	remaining: 30.5s
# 163:	learn: 0.5142341	total: 2.72s	remaining: 30.5s
# 164:	learn: 0.5141752	total: 2.73s	remaining: 30.4s
# 165:	learn: 0.5141158	total: 2.75s	remaining: 30.3s
# 166:	learn: 0.5140544	total: 2.76s	remaining: 30.3s
# 167:	learn: 0.5139937	total: 2.77s	remaining: 30.3s
# 168:	learn: 0.5139367	total: 2.79s	remaining: 30.2s
# 169:	learn: 0.5138812	total: 2.81s	remaining: 30.2s
# 170:	learn: 0.5138282	total: 2.82s	remaining: 30.2s
# 171:	learn: 0.5137748	total: 2.84s	remaining: 30.2s
# 172:	learn: 0.5137229	total: 2.86s	remaining: 30.2s
# 173:	learn: 0.5136719	total: 2.88s	remaining: 30.2s
# 174:	learn: 0.5136263	total: 2.9s	remaining: 30.2s
# 175:	learn: 0.5135789	total: 2.92s	remaining: 30.2s
# 176:	learn: 0.5135323	total: 2.94s	remaining: 30.2s
# 177:	learn: 0.5134877	total: 2.96s	remaining: 30.3s
# 178:	learn: 0.5134441	total: 2.98s	remaining: 30.3s
# 179:	learn: 0.5134006	total: 3s	remaining: 30.3s
# 180:	learn: 0.5133603	total: 3.01s	remaining: 30.3s
# 181:	learn: 0.5133208	total: 3.03s	remaining: 30.2s
# 182:	learn: 0.5132809	total: 3.06s	remaining: 30.4s
# 183:	learn: 0.5132438	total: 3.08s	remaining: 30.4s
# 184:	learn: 0.5132024	total: 3.1s	remaining: 30.4s
# 185:	learn: 0.5131652	total: 3.12s	remaining: 30.4s
# 186:	learn: 0.5131297	total: 3.13s	remaining: 30.3s
# 187:	learn: 0.5130918	total: 3.14s	remaining: 30.3s
# 188:	learn: 0.5130542	total: 3.15s	remaining: 30.2s
# 189:	learn: 0.5130186	total: 3.17s	remaining: 30.2s
# 190:	learn: 0.5129857	total: 3.18s	remaining: 30.1s
# 191:	learn: 0.5129523	total: 3.19s	remaining: 30s
# 192:	learn: 0.5129213	total: 3.21s	remaining: 30s
# 193:	learn: 0.5128889	total: 3.22s	remaining: 30s
# 194:	learn: 0.5128607	total: 3.24s	remaining: 30s
# 195:	learn: 0.5128301	total: 3.26s	remaining: 30s
# 196:	learn: 0.5127996	total: 3.29s	remaining: 30.1s
# 197:	learn: 0.5127717	total: 3.31s	remaining: 30.1s
# 198:	learn: 0.5127406	total: 3.33s	remaining: 30.1s
# 199:	learn: 0.5127141	total: 3.35s	remaining: 30.1s
# 200:	learn: 0.5126860	total: 3.37s	remaining: 30.1s
# 201:	learn: 0.5126570	total: 3.39s	remaining: 30.2s
# 202:	learn: 0.5126291	total: 3.41s	remaining: 30.2s
# 203:	learn: 0.5126053	total: 3.44s	remaining: 30.3s
# 204:	learn: 0.5125776	total: 3.45s	remaining: 30.2s
# 205:	learn: 0.5125520	total: 3.47s	remaining: 30.2s
# 206:	learn: 0.5125280	total: 3.49s	remaining: 30.2s
# 207:	learn: 0.5125031	total: 3.51s	remaining: 30.2s
# 208:	learn: 0.5124770	total: 3.53s	remaining: 30.2s
# 209:	learn: 0.5124534	total: 3.55s	remaining: 30.3s
# 210:	learn: 0.5124303	total: 3.57s	remaining: 30.2s
# 211:	learn: 0.5124089	total: 3.59s	remaining: 30.2s
# 212:	learn: 0.5123874	total: 3.6s	remaining: 30.2s
# 213:	learn: 0.5123653	total: 3.62s	remaining: 30.2s
# 214:	learn: 0.5123432	total: 3.64s	remaining: 30.2s
# 215:	learn: 0.5123233	total: 3.66s	remaining: 30.2s
# 216:	learn: 0.5123026	total: 3.67s	remaining: 30.2s
# 217:	learn: 0.5122800	total: 3.7s	remaining: 30.2s
# 218:	learn: 0.5122586	total: 3.71s	remaining: 30.2s
# 219:	learn: 0.5122404	total: 3.73s	remaining: 30.2s
# 220:	learn: 0.5122199	total: 3.75s	remaining: 30.2s
# 221:	learn: 0.5122000	total: 3.77s	remaining: 30.2s
# 222:	learn: 0.5121814	total: 3.78s	remaining: 30.1s
# 223:	learn: 0.5121674	total: 3.8s	remaining: 30.1s
# 224:	learn: 0.5121476	total: 3.82s	remaining: 30.1s
# 225:	learn: 0.5121309	total: 3.84s	remaining: 30.2s
# 226:	learn: 0.5121155	total: 3.86s	remaining: 30.2s
# 227:	learn: 0.5120960	total: 3.88s	remaining: 30.2s
# 228:	learn: 0.5120780	total: 3.9s	remaining: 30.2s
# 229:	learn: 0.5120601	total: 3.91s	remaining: 30.1s
# 230:	learn: 0.5120448	total: 3.93s	remaining: 30.1s
# 231:	learn: 0.5120282	total: 3.95s	remaining: 30.1s
# 232:	learn: 0.5120150	total: 3.96s	remaining: 30.1s
# 233:	learn: 0.5119979	total: 3.99s	remaining: 30.1s
# 234:	learn: 0.5119818	total: 4.02s	remaining: 30.2s
# 235:	learn: 0.5119652	total: 4.04s	remaining: 30.2s
# 236:	learn: 0.5119513	total: 4.06s	remaining: 30.2s
# 237:	learn: 0.5119377	total: 4.08s	remaining: 30.2s
# 238:	learn: 0.5119258	total: 4.09s	remaining: 30.1s
# 239:	learn: 0.5119108	total: 4.1s	remaining: 30.1s
# 240:	learn: 0.5118970	total: 4.12s	remaining: 30.1s
# 241:	learn: 0.5118822	total: 4.14s	remaining: 30.1s
# 242:	learn: 0.5118690	total: 4.16s	remaining: 30.1s
# 243:	learn: 0.5118537	total: 4.18s	remaining: 30.1s
# 244:	learn: 0.5118387	total: 4.2s	remaining: 30.1s
# 245:	learn: 0.5118265	total: 4.21s	remaining: 30s
# 246:	learn: 0.5118133	total: 4.23s	remaining: 30s
# 247:	learn: 0.5118007	total: 4.25s	remaining: 30s
# 248:	learn: 0.5117862	total: 4.26s	remaining: 30s
# 249:	learn: 0.5117723	total: 4.28s	remaining: 29.9s
# 250:	learn: 0.5117625	total: 4.29s	remaining: 29.9s
# 251:	learn: 0.5117503	total: 4.31s	remaining: 29.9s
# 252:	learn: 0.5117381	total: 4.34s	remaining: 30s
# 253:	learn: 0.5117275	total: 4.36s	remaining: 30s
# 254:	learn: 0.5117161	total: 4.38s	remaining: 29.9s
# 255:	learn: 0.5117048	total: 4.39s	remaining: 29.9s
# 256:	learn: 0.5116945	total: 4.4s	remaining: 29.9s
# 257:	learn: 0.5116829	total: 4.42s	remaining: 29.8s
# 258:	learn: 0.5116703	total: 4.43s	remaining: 29.8s
# 259:	learn: 0.5116580	total: 4.45s	remaining: 29.8s
# 260:	learn: 0.5116471	total: 4.47s	remaining: 29.8s
# 261:	learn: 0.5116377	total: 4.48s	remaining: 29.7s
# 262:	learn: 0.5116263	total: 4.5s	remaining: 29.7s
# 263:	learn: 0.5116158	total: 4.52s	remaining: 29.7s
# 264:	learn: 0.5116059	total: 4.54s	remaining: 29.8s
# 265:	learn: 0.5115963	total: 4.56s	remaining: 29.8s
# 266:	learn: 0.5115848	total: 4.58s	remaining: 29.7s
# 267:	learn: 0.5115729	total: 4.59s	remaining: 29.7s
# 268:	learn: 0.5115631	total: 4.6s	remaining: 29.6s
# 269:	learn: 0.5115539	total: 4.62s	remaining: 29.6s
# 270:	learn: 0.5115428	total: 4.63s	remaining: 29.6s
# 271:	learn: 0.5115329	total: 4.65s	remaining: 29.6s
# 272:	learn: 0.5115219	total: 4.67s	remaining: 29.6s
# 273:	learn: 0.5115117	total: 4.69s	remaining: 29.6s
# 274:	learn: 0.5115018	total: 4.71s	remaining: 29.5s
# 275:	learn: 0.5114909	total: 4.72s	remaining: 29.5s
# 276:	learn: 0.5114815	total: 4.73s	remaining: 29.4s
# 277:	learn: 0.5114726	total: 4.75s	remaining: 29.4s
# 278:	learn: 0.5114630	total: 4.76s	remaining: 29.4s
# 279:	learn: 0.5114544	total: 4.77s	remaining: 29.3s
# 280:	learn: 0.5114442	total: 4.79s	remaining: 29.3s
# 281:	learn: 0.5114355	total: 4.81s	remaining: 29.3s
# 282:	learn: 0.5114257	total: 4.82s	remaining: 29.3s
# 283:	learn: 0.5114188	total: 4.84s	remaining: 29.2s
# 284:	learn: 0.5114086	total: 4.86s	remaining: 29.2s
# 285:	learn: 0.5113997	total: 4.87s	remaining: 29.2s
# 286:	learn: 0.5113926	total: 4.89s	remaining: 29.2s
# 287:	learn: 0.5113838	total: 4.91s	remaining: 29.2s
# 288:	learn: 0.5113757	total: 4.93s	remaining: 29.2s
# 289:	learn: 0.5113675	total: 4.95s	remaining: 29.2s
# 290:	learn: 0.5113591	total: 4.97s	remaining: 29.2s
# 291:	learn: 0.5113503	total: 5.02s	remaining: 29.4s
# 292:	learn: 0.5113430	total: 5.04s	remaining: 29.4s
# 293:	learn: 0.5113346	total: 5.05s	remaining: 29.3s
# 294:	learn: 0.5113262	total: 5.08s	remaining: 29.4s
# 295:	learn: 0.5113192	total: 5.1s	remaining: 29.4s
# 296:	learn: 0.5113104	total: 5.12s	remaining: 29.4s
# 297:	learn: 0.5113030	total: 5.14s	remaining: 29.3s
# 298:	learn: 0.5112957	total: 5.16s	remaining: 29.3s
# 299:	learn: 0.5112878	total: 5.17s	remaining: 29.3s
# 300:	learn: 0.5112797	total: 5.19s	remaining: 29.3s
# 301:	learn: 0.5112716	total: 5.21s	remaining: 29.3s
# 302:	learn: 0.5112634	total: 5.23s	remaining: 29.3s
# 303:	learn: 0.5112546	total: 5.25s	remaining: 29.3s
# 304:	learn: 0.5112467	total: 5.26s	remaining: 29.3s
# 305:	learn: 0.5112372	total: 5.29s	remaining: 29.3s
# 306:	learn: 0.5112290	total: 5.3s	remaining: 29.2s
# 307:	learn: 0.5112217	total: 5.32s	remaining: 29.2s
# 308:	learn: 0.5112146	total: 5.33s	remaining: 29.2s
# 309:	learn: 0.5112061	total: 5.34s	remaining: 29.1s
# 310:	learn: 0.5112003	total: 5.36s	remaining: 29.1s
# 311:	learn: 0.5111931	total: 5.37s	remaining: 29s
# 312:	learn: 0.5111851	total: 5.38s	remaining: 29s
# 313:	learn: 0.5111782	total: 5.4s	remaining: 29s
# 314:	learn: 0.5111735	total: 5.42s	remaining: 29s
# 315:	learn: 0.5111661	total: 5.45s	remaining: 29s
# 316:	learn: 0.5111590	total: 5.46s	remaining: 29s
# 317:	learn: 0.5111504	total: 5.48s	remaining: 29s
# 318:	learn: 0.5111427	total: 5.5s	remaining: 29s
# 319:	learn: 0.5111365	total: 5.51s	remaining: 28.9s
# 320:	learn: 0.5111300	total: 5.54s	remaining: 29s
# 321:	learn: 0.5111236	total: 5.56s	remaining: 29s
# 322:	learn: 0.5111174	total: 5.57s	remaining: 28.9s
# 323:	learn: 0.5111122	total: 5.59s	remaining: 28.9s
# 324:	learn: 0.5111069	total: 5.62s	remaining: 28.9s
# 325:	learn: 0.5110993	total: 5.64s	remaining: 28.9s
# 326:	learn: 0.5110929	total: 5.66s	remaining: 29s
# 327:	learn: 0.5110864	total: 5.68s	remaining: 29s
# 328:	learn: 0.5110790	total: 5.7s	remaining: 28.9s
# 329:	learn: 0.5110722	total: 5.71s	remaining: 28.9s
# 330:	learn: 0.5110671	total: 5.73s	remaining: 28.9s
# 331:	learn: 0.5110602	total: 5.75s	remaining: 28.9s
# 332:	learn: 0.5110536	total: 5.76s	remaining: 28.9s
# 333:	learn: 0.5110467	total: 5.78s	remaining: 28.8s
# 334:	learn: 0.5110414	total: 5.79s	remaining: 28.8s
# 335:	learn: 0.5110347	total: 5.81s	remaining: 28.8s
# 336:	learn: 0.5110277	total: 5.83s	remaining: 28.8s
# 337:	learn: 0.5110217	total: 5.84s	remaining: 28.7s
# 338:	learn: 0.5110168	total: 5.86s	remaining: 28.7s
# 339:	learn: 0.5110095	total: 5.87s	remaining: 28.7s
# 340:	learn: 0.5110038	total: 5.9s	remaining: 28.7s
# 341:	learn: 0.5109970	total: 5.92s	remaining: 28.7s
# 342:	learn: 0.5109905	total: 5.94s	remaining: 28.7s
# 343:	learn: 0.5109839	total: 5.96s	remaining: 28.7s
# 344:	learn: 0.5109778	total: 5.97s	remaining: 28.7s
# 345:	learn: 0.5109720	total: 5.99s	remaining: 28.6s
# 346:	learn: 0.5109650	total: 6s	remaining: 28.6s
# 347:	learn: 0.5109584	total: 6.03s	remaining: 28.6s
# 348:	learn: 0.5109516	total: 6.04s	remaining: 28.6s
# 349:	learn: 0.5109457	total: 6.06s	remaining: 28.6s
# 350:	learn: 0.5109392	total: 6.08s	remaining: 28.5s
# 351:	learn: 0.5109335	total: 6.09s	remaining: 28.5s
# 352:	learn: 0.5109261	total: 6.12s	remaining: 28.5s
# 353:	learn: 0.5109196	total: 6.13s	remaining: 28.5s
# 354:	learn: 0.5109144	total: 6.16s	remaining: 28.5s
# 355:	learn: 0.5109084	total: 6.17s	remaining: 28.5s
# 356:	learn: 0.5109027	total: 6.19s	remaining: 28.5s
# 357:	learn: 0.5108957	total: 6.21s	remaining: 28.5s
# 358:	learn: 0.5108896	total: 6.22s	remaining: 28.4s
# 359:	learn: 0.5108827	total: 6.23s	remaining: 28.4s
# 360:	learn: 0.5108770	total: 6.26s	remaining: 28.4s
# 361:	learn: 0.5108720	total: 6.28s	remaining: 28.4s
# 362:	learn: 0.5108678	total: 6.3s	remaining: 28.4s
# 363:	learn: 0.5108625	total: 6.31s	remaining: 28.4s
# 364:	learn: 0.5108583	total: 6.33s	remaining: 28.3s
# 365:	learn: 0.5108515	total: 6.34s	remaining: 28.3s
# 366:	learn: 0.5108459	total: 6.36s	remaining: 28.3s
# 367:	learn: 0.5108403	total: 6.38s	remaining: 28.3s
# 368:	learn: 0.5108340	total: 6.41s	remaining: 28.3s
# 369:	learn: 0.5108289	total: 6.43s	remaining: 28.3s
# 370:	learn: 0.5108236	total: 6.45s	remaining: 28.3s
# 371:	learn: 0.5108187	total: 6.46s	remaining: 28.3s
# 372:	learn: 0.5108126	total: 6.49s	remaining: 28.3s
# 373:	learn: 0.5108089	total: 6.5s	remaining: 28.3s
# 374:	learn: 0.5108032	total: 6.53s	remaining: 28.3s
# 375:	learn: 0.5107975	total: 6.55s	remaining: 28.3s
# 376:	learn: 0.5107924	total: 6.6s	remaining: 28.4s
# 377:	learn: 0.5107886	total: 6.62s	remaining: 28.4s
# 378:	learn: 0.5107825	total: 6.64s	remaining: 28.4s
# 379:	learn: 0.5107771	total: 6.65s	remaining: 28.4s
# 380:	learn: 0.5107704	total: 6.67s	remaining: 28.4s
# 381:	learn: 0.5107659	total: 6.68s	remaining: 28.3s
# 382:	learn: 0.5107600	total: 6.7s	remaining: 28.3s
# 383:	learn: 0.5107557	total: 6.71s	remaining: 28.2s
# 384:	learn: 0.5107519	total: 6.72s	remaining: 28.2s
# 385:	learn: 0.5107464	total: 6.74s	remaining: 28.2s
# 386:	learn: 0.5107406	total: 6.76s	remaining: 28.2s
# 387:	learn: 0.5107339	total: 6.77s	remaining: 28.1s
# 388:	learn: 0.5107304	total: 6.79s	remaining: 28.1s
# 389:	learn: 0.5107248	total: 6.81s	remaining: 28.1s
# 390:	learn: 0.5107189	total: 6.84s	remaining: 28.1s
# 391:	learn: 0.5107127	total: 6.86s	remaining: 28.1s
# 392:	learn: 0.5107065	total: 6.87s	remaining: 28.1s
# 393:	learn: 0.5107011	total: 6.89s	remaining: 28.1s
# 394:	learn: 0.5106958	total: 6.9s	remaining: 28s
# 395:	learn: 0.5106911	total: 6.92s	remaining: 28s
# 396:	learn: 0.5106862	total: 6.93s	remaining: 28s
# 397:	learn: 0.5106819	total: 6.95s	remaining: 28s
# 398:	learn: 0.5106756	total: 6.97s	remaining: 28s
# 399:	learn: 0.5106712	total: 6.98s	remaining: 27.9s
# 400:	learn: 0.5106654	total: 7s	remaining: 27.9s
# 401:	learn: 0.5106600	total: 7.02s	remaining: 27.9s
# 402:	learn: 0.5106552	total: 7.03s	remaining: 27.9s
# 403:	learn: 0.5106511	total: 7.04s	remaining: 27.8s
# 404:	learn: 0.5106474	total: 7.06s	remaining: 27.8s
# 405:	learn: 0.5106424	total: 7.08s	remaining: 27.8s
# 406:	learn: 0.5106373	total: 7.09s	remaining: 27.8s
# 407:	learn: 0.5106320	total: 7.11s	remaining: 27.7s
# 408:	learn: 0.5106246	total: 7.12s	remaining: 27.7s
# 409:	learn: 0.5106184	total: 7.13s	remaining: 27.7s
# 410:	learn: 0.5106131	total: 7.15s	remaining: 27.6s
# 411:	learn: 0.5106065	total: 7.16s	remaining: 27.6s
# 412:	learn: 0.5106015	total: 7.18s	remaining: 27.6s
# 413:	learn: 0.5105964	total: 7.19s	remaining: 27.5s
# 414:	learn: 0.5105903	total: 7.2s	remaining: 27.5s
# 415:	learn: 0.5105857	total: 7.22s	remaining: 27.5s
# 416:	learn: 0.5105804	total: 7.23s	remaining: 27.5s
# 417:	learn: 0.5105756	total: 7.25s	remaining: 27.4s
# 418:	learn: 0.5105702	total: 7.26s	remaining: 27.4s
# 419:	learn: 0.5105666	total: 7.27s	remaining: 27.4s
# 420:	learn: 0.5105611	total: 7.29s	remaining: 27.3s
# 421:	learn: 0.5105565	total: 7.3s	remaining: 27.3s
# 422:	learn: 0.5105531	total: 7.32s	remaining: 27.3s
# 423:	learn: 0.5105464	total: 7.33s	remaining: 27.3s
# 424:	learn: 0.5105408	total: 7.35s	remaining: 27.2s
# 425:	learn: 0.5105348	total: 7.36s	remaining: 27.2s
# 426:	learn: 0.5105299	total: 7.38s	remaining: 27.2s
# 427:	learn: 0.5105252	total: 7.39s	remaining: 27.1s
# 428:	learn: 0.5105203	total: 7.41s	remaining: 27.1s
# 429:	learn: 0.5105150	total: 7.42s	remaining: 27.1s
# 430:	learn: 0.5105097	total: 7.43s	remaining: 27.1s
# 431:	learn: 0.5105047	total: 7.45s	remaining: 27s
# 432:	learn: 0.5105006	total: 7.46s	remaining: 27s
# 433:	learn: 0.5104928	total: 7.48s	remaining: 27s
# 434:	learn: 0.5104893	total: 7.49s	remaining: 26.9s
# 435:	learn: 0.5104834	total: 7.5s	remaining: 26.9s
# 436:	learn: 0.5104784	total: 7.52s	remaining: 26.9s
# 437:	learn: 0.5104730	total: 7.53s	remaining: 26.9s
# 438:	learn: 0.5104694	total: 7.54s	remaining: 26.8s
# 439:	learn: 0.5104641	total: 7.56s	remaining: 26.8s
# 440:	learn: 0.5104601	total: 7.57s	remaining: 26.8s
# 441:	learn: 0.5104528	total: 7.59s	remaining: 26.8s
# 442:	learn: 0.5104481	total: 7.61s	remaining: 26.7s
# 443:	learn: 0.5104416	total: 7.62s	remaining: 26.7s
# 444:	learn: 0.5104355	total: 7.64s	remaining: 26.7s
# 445:	learn: 0.5104314	total: 7.66s	remaining: 26.7s
# 446:	learn: 0.5104261	total: 7.67s	remaining: 26.7s
# 447:	learn: 0.5104218	total: 7.69s	remaining: 26.6s
# 448:	learn: 0.5104171	total: 7.7s	remaining: 26.6s
# 449:	learn: 0.5104126	total: 7.72s	remaining: 26.6s
# 450:	learn: 0.5104076	total: 7.73s	remaining: 26.5s
# 451:	learn: 0.5104029	total: 7.74s	remaining: 26.5s
# 452:	learn: 0.5103980	total: 7.76s	remaining: 26.5s
# 453:	learn: 0.5103917	total: 7.77s	remaining: 26.5s
# 454:	learn: 0.5103858	total: 7.79s	remaining: 26.4s
# 455:	learn: 0.5103798	total: 7.8s	remaining: 26.4s
# 456:	learn: 0.5103745	total: 7.82s	remaining: 26.4s
# 457:	learn: 0.5103702	total: 7.83s	remaining: 26.4s
# 458:	learn: 0.5103644	total: 7.84s	remaining: 26.3s
# 459:	learn: 0.5103600	total: 7.86s	remaining: 26.3s
# 460:	learn: 0.5103559	total: 7.87s	remaining: 26.3s
# 461:	learn: 0.5103511	total: 7.89s	remaining: 26.3s
# 462:	learn: 0.5103459	total: 7.91s	remaining: 26.3s
# 463:	learn: 0.5103415	total: 7.93s	remaining: 26.2s
# 464:	learn: 0.5103365	total: 7.94s	remaining: 26.2s
# 465:	learn: 0.5103308	total: 7.96s	remaining: 26.2s
# 466:	learn: 0.5103266	total: 7.97s	remaining: 26.2s
# 467:	learn: 0.5103213	total: 7.99s	remaining: 26.1s
# 468:	learn: 0.5103171	total: 8s	remaining: 26.1s
# 469:	learn: 0.5103119	total: 8.02s	remaining: 26.1s
# 470:	learn: 0.5103077	total: 8.03s	remaining: 26.1s
# 471:	learn: 0.5103039	total: 8.04s	remaining: 26s
# 472:	learn: 0.5102993	total: 8.06s	remaining: 26s
# 473:	learn: 0.5102940	total: 8.07s	remaining: 26s
# 474:	learn: 0.5102889	total: 8.09s	remaining: 26s
# 475:	learn: 0.5102845	total: 8.1s	remaining: 25.9s
# 476:	learn: 0.5102802	total: 8.11s	remaining: 25.9s
# 477:	learn: 0.5102758	total: 8.13s	remaining: 25.9s
# 478:	learn: 0.5102712	total: 8.14s	remaining: 25.9s
# 479:	learn: 0.5102655	total: 8.16s	remaining: 25.8s
# 480:	learn: 0.5102609	total: 8.18s	remaining: 25.8s
# 481:	learn: 0.5102566	total: 8.2s	remaining: 25.8s
# 482:	learn: 0.5102514	total: 8.21s	remaining: 25.8s
# 483:	learn: 0.5102466	total: 8.22s	remaining: 25.8s
# 484:	learn: 0.5102418	total: 8.24s	remaining: 25.7s
# 485:	learn: 0.5102365	total: 8.25s	remaining: 25.7s
# 486:	learn: 0.5102324	total: 8.26s	remaining: 25.7s
# 487:	learn: 0.5102283	total: 8.28s	remaining: 25.7s
# 488:	learn: 0.5102232	total: 8.29s	remaining: 25.6s
# 489:	learn: 0.5102187	total: 8.31s	remaining: 25.6s
# 490:	learn: 0.5102138	total: 8.32s	remaining: 25.6s
# 491:	learn: 0.5102088	total: 8.34s	remaining: 25.6s
# 492:	learn: 0.5102050	total: 8.35s	remaining: 25.5s
# 493:	learn: 0.5102007	total: 8.37s	remaining: 25.5s
# 494:	learn: 0.5101961	total: 8.38s	remaining: 25.5s
# 495:	learn: 0.5101909	total: 8.4s	remaining: 25.5s
# 496:	learn: 0.5101850	total: 8.42s	remaining: 25.5s
# 497:	learn: 0.5101797	total: 8.43s	remaining: 25.4s
# 498:	learn: 0.5101760	total: 8.45s	remaining: 25.4s
# 499:	learn: 0.5101706	total: 8.46s	remaining: 25.4s
# 500:	learn: 0.5101660	total: 8.48s	remaining: 25.4s
# 501:	learn: 0.5101616	total: 8.49s	remaining: 25.4s
# 502:	learn: 0.5101567	total: 8.51s	remaining: 25.3s
# 503:	learn: 0.5101523	total: 8.53s	remaining: 25.3s
# 504:	learn: 0.5101488	total: 8.54s	remaining: 25.3s
# 505:	learn: 0.5101436	total: 8.55s	remaining: 25.3s
# 506:	learn: 0.5101394	total: 8.57s	remaining: 25.2s
# 507:	learn: 0.5101353	total: 8.58s	remaining: 25.2s
# 508:	learn: 0.5101307	total: 8.6s	remaining: 25.2s
# 509:	learn: 0.5101263	total: 8.62s	remaining: 25.2s
# 510:	learn: 0.5101213	total: 8.63s	remaining: 25.1s
# 511:	learn: 0.5101172	total: 8.64s	remaining: 25.1s
# 512:	learn: 0.5101122	total: 8.66s	remaining: 25.1s
# 513:	learn: 0.5101078	total: 8.68s	remaining: 25.1s
# 514:	learn: 0.5101034	total: 8.69s	remaining: 25.1s
# 515:	learn: 0.5100981	total: 8.7s	remaining: 25s
# 516:	learn: 0.5100941	total: 8.72s	remaining: 25s
# 517:	learn: 0.5100892	total: 8.73s	remaining: 25s
# 518:	learn: 0.5100863	total: 8.76s	remaining: 25s
# 519:	learn: 0.5100833	total: 8.77s	remaining: 25s
# 520:	learn: 0.5100786	total: 8.78s	remaining: 24.9s
# 521:	learn: 0.5100742	total: 8.79s	remaining: 24.9s
# 522:	learn: 0.5100678	total: 8.81s	remaining: 24.9s
# 523:	learn: 0.5100642	total: 8.83s	remaining: 24.9s
# 524:	learn: 0.5100591	total: 8.84s	remaining: 24.8s
# 525:	learn: 0.5100553	total: 8.86s	remaining: 24.8s
# 526:	learn: 0.5100513	total: 8.87s	remaining: 24.8s
# 527:	learn: 0.5100470	total: 8.88s	remaining: 24.8s
# 528:	learn: 0.5100427	total: 8.9s	remaining: 24.7s
# 529:	learn: 0.5100396	total: 8.91s	remaining: 24.7s
# 530:	learn: 0.5100365	total: 8.92s	remaining: 24.7s
# 531:	learn: 0.5100311	total: 8.94s	remaining: 24.7s
# 532:	learn: 0.5100271	total: 8.95s	remaining: 24.6s
# 533:	learn: 0.5100232	total: 8.96s	remaining: 24.6s
# 534:	learn: 0.5100195	total: 8.97s	remaining: 24.6s
# 535:	learn: 0.5100157	total: 8.99s	remaining: 24.6s
# 536:	learn: 0.5100108	total: 9.01s	remaining: 24.5s
# 537:	learn: 0.5100063	total: 9.03s	remaining: 24.5s
# 538:	learn: 0.5100027	total: 9.04s	remaining: 24.5s
# 539:	learn: 0.5099976	total: 9.05s	remaining: 24.5s
# 540:	learn: 0.5099946	total: 9.07s	remaining: 24.5s
# 541:	learn: 0.5099903	total: 9.08s	remaining: 24.4s
# 542:	learn: 0.5099873	total: 9.1s	remaining: 24.4s
# 543:	learn: 0.5099827	total: 9.11s	remaining: 24.4s
# 544:	learn: 0.5099786	total: 9.13s	remaining: 24.4s
# 545:	learn: 0.5099752	total: 9.14s	remaining: 24.3s
# 546:	learn: 0.5099711	total: 9.15s	remaining: 24.3s
# 547:	learn: 0.5099672	total: 9.17s	remaining: 24.3s
# 548:	learn: 0.5099628	total: 9.18s	remaining: 24.3s
# 549:	learn: 0.5099592	total: 9.2s	remaining: 24.3s
# 550:	learn: 0.5099555	total: 9.22s	remaining: 24.2s
# 551:	learn: 0.5099506	total: 9.23s	remaining: 24.2s
# 552:	learn: 0.5099467	total: 9.25s	remaining: 24.2s
# 553:	learn: 0.5099427	total: 9.26s	remaining: 24.2s
# 554:	learn: 0.5099388	total: 9.28s	remaining: 24.1s
# 555:	learn: 0.5099339	total: 9.29s	remaining: 24.1s
# 556:	learn: 0.5099323	total: 9.3s	remaining: 24.1s
# 557:	learn: 0.5099279	total: 9.31s	remaining: 24.1s
# 558:	learn: 0.5099241	total: 9.33s	remaining: 24.1s
# 559:	learn: 0.5099189	total: 9.34s	remaining: 24s
# 560:	learn: 0.5099150	total: 9.36s	remaining: 24s
# 561:	learn: 0.5099108	total: 9.37s	remaining: 24s
# 562:	learn: 0.5099070	total: 9.38s	remaining: 23.9s
# 563:	learn: 0.5099025	total: 9.4s	remaining: 23.9s
# 564:	learn: 0.5098992	total: 9.42s	remaining: 23.9s
# 565:	learn: 0.5098944	total: 9.44s	remaining: 23.9s
# 566:	learn: 0.5098900	total: 9.45s	remaining: 23.9s
# 567:	learn: 0.5098858	total: 9.47s	remaining: 23.9s
# 568:	learn: 0.5098813	total: 9.49s	remaining: 23.9s
# 569:	learn: 0.5098768	total: 9.51s	remaining: 23.9s
# 570:	learn: 0.5098728	total: 9.53s	remaining: 23.8s
# 571:	learn: 0.5098677	total: 9.54s	remaining: 23.8s
# 572:	learn: 0.5098642	total: 9.57s	remaining: 23.8s
# 573:	learn: 0.5098600	total: 9.59s	remaining: 23.8s
# 574:	learn: 0.5098548	total: 9.6s	remaining: 23.8s
# 575:	learn: 0.5098509	total: 9.63s	remaining: 23.8s
# 576:	learn: 0.5098459	total: 9.64s	remaining: 23.8s
# 577:	learn: 0.5098415	total: 9.66s	remaining: 23.8s
# 578:	learn: 0.5098376	total: 9.68s	remaining: 23.8s
# 579:	learn: 0.5098331	total: 9.7s	remaining: 23.7s
# 580:	learn: 0.5098291	total: 9.71s	remaining: 23.7s
# 581:	learn: 0.5098248	total: 9.73s	remaining: 23.7s
# 582:	learn: 0.5098202	total: 9.75s	remaining: 23.7s
# 583:	learn: 0.5098163	total: 9.77s	remaining: 23.7s
# 584:	learn: 0.5098126	total: 9.79s	remaining: 23.7s
# 585:	learn: 0.5098083	total: 9.81s	remaining: 23.7s
# 586:	learn: 0.5098046	total: 9.83s	remaining: 23.7s
# 587:	learn: 0.5098014	total: 9.85s	remaining: 23.6s
# 588:	learn: 0.5097948	total: 9.86s	remaining: 23.6s
# 589:	learn: 0.5097910	total: 9.89s	remaining: 23.6s
# 590:	learn: 0.5097868	total: 9.91s	remaining: 23.6s
# 591:	learn: 0.5097825	total: 9.93s	remaining: 23.6s
# 592:	learn: 0.5097789	total: 9.95s	remaining: 23.6s
# 593:	learn: 0.5097746	total: 9.97s	remaining: 23.6s
# 594:	learn: 0.5097701	total: 9.99s	remaining: 23.6s
# 595:	learn: 0.5097661	total: 10s	remaining: 23.6s
# 596:	learn: 0.5097622	total: 10s	remaining: 23.6s
# 597:	learn: 0.5097581	total: 10s	remaining: 23.5s
# 598:	learn: 0.5097529	total: 10.1s	remaining: 23.5s
# 599:	learn: 0.5097481	total: 10.1s	remaining: 23.5s
# 600:	learn: 0.5097448	total: 10.1s	remaining: 23.5s
# 601:	learn: 0.5097408	total: 10.1s	remaining: 23.5s
# 602:	learn: 0.5097364	total: 10.1s	remaining: 23.5s
# 603:	learn: 0.5097322	total: 10.2s	remaining: 23.5s
# 604:	learn: 0.5097290	total: 10.2s	remaining: 23.5s
# 605:	learn: 0.5097254	total: 10.2s	remaining: 23.5s
# 606:	learn: 0.5097190	total: 10.2s	remaining: 23.4s
# 607:	learn: 0.5097157	total: 10.2s	remaining: 23.4s
# 608:	learn: 0.5097121	total: 10.3s	remaining: 23.4s
# 609:	learn: 0.5097081	total: 10.3s	remaining: 23.4s
# 610:	learn: 0.5097017	total: 10.3s	remaining: 23.4s
# 611:	learn: 0.5096978	total: 10.3s	remaining: 23.4s
# 612:	learn: 0.5096942	total: 10.4s	remaining: 23.4s
# 613:	learn: 0.5096908	total: 10.4s	remaining: 23.4s
# 614:	learn: 0.5096858	total: 10.4s	remaining: 23.4s
# 615:	learn: 0.5096819	total: 10.4s	remaining: 23.4s
# 616:	learn: 0.5096782	total: 10.4s	remaining: 23.4s
# 617:	learn: 0.5096738	total: 10.5s	remaining: 23.4s
# 618:	learn: 0.5096702	total: 10.5s	remaining: 23.4s
# 619:	learn: 0.5096673	total: 10.5s	remaining: 23.3s
# 620:	learn: 0.5096632	total: 10.5s	remaining: 23.3s
# 621:	learn: 0.5096596	total: 10.5s	remaining: 23.3s
# 622:	learn: 0.5096557	total: 10.5s	remaining: 23.3s
# 623:	learn: 0.5096521	total: 10.5s	remaining: 23.2s
# 624:	learn: 0.5096486	total: 10.5s	remaining: 23.2s
# 625:	learn: 0.5096442	total: 10.6s	remaining: 23.2s
# 626:	learn: 0.5096406	total: 10.6s	remaining: 23.2s
# 627:	learn: 0.5096359	total: 10.6s	remaining: 23.1s
# 628:	learn: 0.5096327	total: 10.6s	remaining: 23.1s
# 629:	learn: 0.5096256	total: 10.6s	remaining: 23.1s
# 630:	learn: 0.5096219	total: 10.6s	remaining: 23.1s
# 631:	learn: 0.5096181	total: 10.6s	remaining: 23s
# 632:	learn: 0.5096144	total: 10.7s	remaining: 23s
# 633:	learn: 0.5096108	total: 10.7s	remaining: 23s
# 634:	learn: 0.5096067	total: 10.7s	remaining: 23s
# 635:	learn: 0.5096028	total: 10.7s	remaining: 23s
# 636:	learn: 0.5095997	total: 10.7s	remaining: 23s
# 637:	learn: 0.5095958	total: 10.7s	remaining: 22.9s
# 638:	learn: 0.5095917	total: 10.8s	remaining: 22.9s
# 639:	learn: 0.5095872	total: 10.8s	remaining: 22.9s
# 640:	learn: 0.5095835	total: 10.8s	remaining: 22.9s
# 641:	learn: 0.5095799	total: 10.8s	remaining: 22.9s
# 642:	learn: 0.5095751	total: 10.8s	remaining: 22.8s
# 643:	learn: 0.5095713	total: 10.8s	remaining: 22.8s
# 644:	learn: 0.5095679	total: 10.9s	remaining: 22.8s
# 645:	learn: 0.5095652	total: 10.9s	remaining: 22.8s
# 646:	learn: 0.5095591	total: 10.9s	remaining: 22.8s
# 647:	learn: 0.5095557	total: 10.9s	remaining: 22.7s
# 648:	learn: 0.5095517	total: 10.9s	remaining: 22.7s
# 649:	learn: 0.5095476	total: 10.9s	remaining: 22.7s
# 650:	learn: 0.5095453	total: 10.9s	remaining: 22.7s
# 651:	learn: 0.5095425	total: 11s	remaining: 22.7s
# 652:	learn: 0.5095383	total: 11s	remaining: 22.6s
# 653:	learn: 0.5095334	total: 11s	remaining: 22.6s
# 654:	learn: 0.5095299	total: 11s	remaining: 22.6s
# 655:	learn: 0.5095267	total: 11s	remaining: 22.6s
# 656:	learn: 0.5095231	total: 11s	remaining: 22.5s
# 657:	learn: 0.5095189	total: 11s	remaining: 22.5s
# 658:	learn: 0.5095149	total: 11.1s	remaining: 22.5s
# 659:	learn: 0.5095117	total: 11.1s	remaining: 22.5s
# 660:	learn: 0.5095082	total: 11.1s	remaining: 22.5s
# 661:	learn: 0.5095056	total: 11.1s	remaining: 22.5s
# 662:	learn: 0.5095011	total: 11.1s	remaining: 22.5s
# 663:	learn: 0.5094972	total: 11.2s	remaining: 22.5s
# 664:	learn: 0.5094934	total: 11.2s	remaining: 22.5s
# 665:	learn: 0.5094888	total: 11.2s	remaining: 22.4s
# 666:	learn: 0.5094837	total: 11.2s	remaining: 22.4s
# 667:	learn: 0.5094800	total: 11.2s	remaining: 22.4s
# 668:	learn: 0.5094751	total: 11.2s	remaining: 22.4s
# 669:	learn: 0.5094720	total: 11.3s	remaining: 22.4s
# 670:	learn: 0.5094680	total: 11.3s	remaining: 22.3s
# 671:	learn: 0.5094638	total: 11.3s	remaining: 22.3s
# 672:	learn: 0.5094605	total: 11.3s	remaining: 22.3s
# 673:	learn: 0.5094567	total: 11.3s	remaining: 22.3s
# 674:	learn: 0.5094525	total: 11.3s	remaining: 22.3s
# 675:	learn: 0.5094487	total: 11.4s	remaining: 22.3s
# 676:	learn: 0.5094451	total: 11.4s	remaining: 22.2s
# 677:	learn: 0.5094416	total: 11.4s	remaining: 22.2s
# 678:	learn: 0.5094380	total: 11.4s	remaining: 22.2s
# 679:	learn: 0.5094341	total: 11.4s	remaining: 22.2s
# 680:	learn: 0.5094299	total: 11.4s	remaining: 22.2s
# 681:	learn: 0.5094265	total: 11.5s	remaining: 22.2s
# 682:	learn: 0.5094223	total: 11.5s	remaining: 22.1s
# 683:	learn: 0.5094192	total: 11.5s	remaining: 22.1s
# 684:	learn: 0.5094131	total: 11.5s	remaining: 22.1s
# 685:	learn: 0.5094097	total: 11.5s	remaining: 22.1s
# 686:	learn: 0.5094052	total: 11.5s	remaining: 22.1s
# 687:	learn: 0.5094019	total: 11.6s	remaining: 22s
# 688:	learn: 0.5093994	total: 11.6s	remaining: 22s
# 689:	learn: 0.5093952	total: 11.6s	remaining: 22s
# 690:	learn: 0.5093922	total: 11.6s	remaining: 22s
# 691:	learn: 0.5093875	total: 11.6s	remaining: 22s
# 692:	learn: 0.5093842	total: 11.6s	remaining: 21.9s
# 693:	learn: 0.5093799	total: 11.6s	remaining: 21.9s
# 694:	learn: 0.5093776	total: 11.7s	remaining: 21.9s
# 695:	learn: 0.5093736	total: 11.7s	remaining: 21.9s
# 696:	learn: 0.5093696	total: 11.7s	remaining: 21.9s
# 697:	learn: 0.5093657	total: 11.7s	remaining: 21.8s
# 698:	learn: 0.5093629	total: 11.7s	remaining: 21.8s
# 699:	learn: 0.5093590	total: 11.7s	remaining: 21.8s
# 700:	learn: 0.5093554	total: 11.7s	remaining: 21.8s
# 701:	learn: 0.5093516	total: 11.8s	remaining: 21.7s
# 702:	learn: 0.5093482	total: 11.8s	remaining: 21.7s
# 703:	learn: 0.5093440	total: 11.8s	remaining: 21.7s
# 704:	learn: 0.5093413	total: 11.8s	remaining: 21.7s
# 705:	learn: 0.5093367	total: 11.8s	remaining: 21.7s
# 706:	learn: 0.5093334	total: 11.8s	remaining: 21.7s
# 707:	learn: 0.5093307	total: 11.9s	remaining: 21.6s
# 708:	learn: 0.5093278	total: 11.9s	remaining: 21.6s
# 709:	learn: 0.5093234	total: 11.9s	remaining: 21.6s
# 710:	learn: 0.5093196	total: 11.9s	remaining: 21.6s
# 711:	learn: 0.5093164	total: 11.9s	remaining: 21.6s
# 712:	learn: 0.5093141	total: 11.9s	remaining: 21.6s
# 713:	learn: 0.5093093	total: 12s	remaining: 21.5s
# 714:	learn: 0.5093056	total: 12s	remaining: 21.5s
# 715:	learn: 0.5093019	total: 12s	remaining: 21.5s
# 716:	learn: 0.5092985	total: 12s	remaining: 21.5s
# 717:	learn: 0.5092947	total: 12s	remaining: 21.5s
# 718:	learn: 0.5092911	total: 12.1s	remaining: 21.5s
# 719:	learn: 0.5092872	total: 12.1s	remaining: 21.5s
# 720:	learn: 0.5092838	total: 12.1s	remaining: 21.4s
# 721:	learn: 0.5092786	total: 12.1s	remaining: 21.4s
# 722:	learn: 0.5092754	total: 12.1s	remaining: 21.4s
# 723:	learn: 0.5092723	total: 12.1s	remaining: 21.4s
# 724:	learn: 0.5092681	total: 12.1s	remaining: 21.4s
# 725:	learn: 0.5092650	total: 12.2s	remaining: 21.3s
# 726:	learn: 0.5092611	total: 12.2s	remaining: 21.3s
# 727:	learn: 0.5092575	total: 12.2s	remaining: 21.3s
# 728:	learn: 0.5092538	total: 12.2s	remaining: 21.3s
# 729:	learn: 0.5092502	total: 12.2s	remaining: 21.3s
# 730:	learn: 0.5092477	total: 12.2s	remaining: 21.2s
# 731:	learn: 0.5092436	total: 12.3s	remaining: 21.2s
# 732:	learn: 0.5092397	total: 12.3s	remaining: 21.2s
# 733:	learn: 0.5092356	total: 12.3s	remaining: 21.2s
# 734:	learn: 0.5092330	total: 12.3s	remaining: 21.2s
# 735:	learn: 0.5092295	total: 12.3s	remaining: 21.1s
# 736:	learn: 0.5092266	total: 12.3s	remaining: 21.1s
# 737:	learn: 0.5092227	total: 12.3s	remaining: 21.1s
# 738:	learn: 0.5092188	total: 12.4s	remaining: 21.1s
# 739:	learn: 0.5092150	total: 12.4s	remaining: 21.1s
# 740:	learn: 0.5092117	total: 12.4s	remaining: 21s
# 741:	learn: 0.5092086	total: 12.4s	remaining: 21s
# 742:	learn: 0.5092056	total: 12.4s	remaining: 21s
# 743:	learn: 0.5092015	total: 12.4s	remaining: 21s
# 744:	learn: 0.5091985	total: 12.4s	remaining: 20.9s
# 745:	learn: 0.5091955	total: 12.4s	remaining: 20.9s
# 746:	learn: 0.5091918	total: 12.5s	remaining: 20.9s
# 747:	learn: 0.5091863	total: 12.5s	remaining: 20.9s
# 748:	learn: 0.5091818	total: 12.5s	remaining: 20.9s
# 749:	learn: 0.5091787	total: 12.5s	remaining: 20.8s
# 750:	learn: 0.5091762	total: 12.5s	remaining: 20.8s
# 751:	learn: 0.5091722	total: 12.5s	remaining: 20.8s
# 752:	learn: 0.5091691	total: 12.5s	remaining: 20.8s
# 753:	learn: 0.5091655	total: 12.6s	remaining: 20.7s
# 754:	learn: 0.5091624	total: 12.6s	remaining: 20.7s
# 755:	learn: 0.5091596	total: 12.6s	remaining: 20.7s
# 756:	learn: 0.5091570	total: 12.6s	remaining: 20.7s
# 757:	learn: 0.5091518	total: 12.6s	remaining: 20.7s
# 758:	learn: 0.5091492	total: 12.6s	remaining: 20.7s
# 759:	learn: 0.5091466	total: 12.6s	remaining: 20.6s
# 760:	learn: 0.5091429	total: 12.7s	remaining: 20.6s
# 761:	learn: 0.5091395	total: 12.7s	remaining: 20.6s
# 762:	learn: 0.5091365	total: 12.7s	remaining: 20.6s
# 763:	learn: 0.5091326	total: 12.7s	remaining: 20.6s
# 764:	learn: 0.5091288	total: 12.7s	remaining: 20.6s
# 765:	learn: 0.5091255	total: 12.8s	remaining: 20.6s
# 766:	learn: 0.5091227	total: 12.8s	remaining: 20.5s
# 767:	learn: 0.5091190	total: 12.8s	remaining: 20.5s
# 768:	learn: 0.5091158	total: 12.8s	remaining: 20.5s
# 769:	learn: 0.5091111	total: 12.8s	remaining: 20.5s
# 770:	learn: 0.5091074	total: 12.8s	remaining: 20.5s
# 771:	learn: 0.5091040	total: 12.9s	remaining: 20.4s
# 772:	learn: 0.5090997	total: 12.9s	remaining: 20.4s
# 773:	learn: 0.5090961	total: 12.9s	remaining: 20.4s
# 774:	learn: 0.5090920	total: 12.9s	remaining: 20.4s
# 775:	learn: 0.5090888	total: 12.9s	remaining: 20.4s
# 776:	learn: 0.5090854	total: 13s	remaining: 20.4s
# 777:	learn: 0.5090821	total: 13s	remaining: 20.4s
# 778:	learn: 0.5090777	total: 13s	remaining: 20.4s
# 779:	learn: 0.5090742	total: 13s	remaining: 20.4s
# 780:	learn: 0.5090711	total: 13.1s	remaining: 20.4s
# 781:	learn: 0.5090684	total: 13.1s	remaining: 20.4s
# 782:	learn: 0.5090642	total: 13.1s	remaining: 20.3s
# 783:	learn: 0.5090617	total: 13.1s	remaining: 20.3s
# 784:	learn: 0.5090592	total: 13.1s	remaining: 20.3s
# 785:	learn: 0.5090551	total: 13.1s	remaining: 20.3s
# 786:	learn: 0.5090518	total: 13.1s	remaining: 20.2s
# 787:	learn: 0.5090489	total: 13.2s	remaining: 20.2s
# 788:	learn: 0.5090453	total: 13.2s	remaining: 20.2s
# 789:	learn: 0.5090415	total: 13.2s	remaining: 20.2s
# 790:	learn: 0.5090384	total: 13.2s	remaining: 20.2s
# 791:	learn: 0.5090355	total: 13.2s	remaining: 20.2s
# 792:	learn: 0.5090302	total: 13.2s	remaining: 20.1s
# 793:	learn: 0.5090260	total: 13.3s	remaining: 20.2s
# 794:	learn: 0.5090224	total: 13.3s	remaining: 20.2s
# 795:	learn: 0.5090194	total: 13.4s	remaining: 20.2s
# 796:	learn: 0.5090153	total: 13.4s	remaining: 20.3s
# 797:	learn: 0.5090104	total: 13.5s	remaining: 20.3s
# 798:	learn: 0.5090068	total: 13.5s	remaining: 20.3s
# 799:	learn: 0.5090033	total: 13.5s	remaining: 20.3s
# 800:	learn: 0.5090009	total: 13.5s	remaining: 20.2s
# 801:	learn: 0.5089984	total: 13.5s	remaining: 20.2s
# 802:	learn: 0.5089964	total: 13.6s	remaining: 20.2s
# 803:	learn: 0.5089917	total: 13.6s	remaining: 20.2s
# 804:	learn: 0.5089882	total: 13.6s	remaining: 20.2s
# 805:	learn: 0.5089844	total: 13.6s	remaining: 20.1s
# 806:	learn: 0.5089802	total: 13.6s	remaining: 20.1s
# 807:	learn: 0.5089767	total: 13.6s	remaining: 20.1s
# 808:	learn: 0.5089744	total: 13.6s	remaining: 20.1s
# 809:	learn: 0.5089703	total: 13.7s	remaining: 20.1s
# 810:	learn: 0.5089677	total: 13.7s	remaining: 20.1s
# 811:	learn: 0.5089644	total: 13.7s	remaining: 20s
# 812:	learn: 0.5089605	total: 13.7s	remaining: 20s
# 813:	learn: 0.5089569	total: 13.7s	remaining: 20s
# 814:	learn: 0.5089535	total: 13.8s	remaining: 20s
# 815:	learn: 0.5089505	total: 13.8s	remaining: 20s
# 816:	learn: 0.5089478	total: 13.8s	remaining: 20s
# 817:	learn: 0.5089445	total: 13.8s	remaining: 20s
# 818:	learn: 0.5089422	total: 13.8s	remaining: 19.9s
# 819:	learn: 0.5089388	total: 13.8s	remaining: 19.9s
# 820:	learn: 0.5089347	total: 13.9s	remaining: 19.9s
# 821:	learn: 0.5089321	total: 13.9s	remaining: 19.9s
# 822:	learn: 0.5089259	total: 13.9s	remaining: 19.9s
# 823:	learn: 0.5089222	total: 13.9s	remaining: 19.8s
# 824:	learn: 0.5089190	total: 13.9s	remaining: 19.8s
# 825:	learn: 0.5089145	total: 13.9s	remaining: 19.8s
# 826:	learn: 0.5089109	total: 13.9s	remaining: 19.8s
# 827:	learn: 0.5089072	total: 14s	remaining: 19.8s
# 828:	learn: 0.5089036	total: 14s	remaining: 19.8s
# 829:	learn: 0.5089012	total: 14s	remaining: 19.7s
# 830:	learn: 0.5088982	total: 14s	remaining: 19.7s
# 831:	learn: 0.5088960	total: 14s	remaining: 19.7s
# 832:	learn: 0.5088930	total: 14s	remaining: 19.7s
# 833:	learn: 0.5088898	total: 14.1s	remaining: 19.7s
# 834:	learn: 0.5088860	total: 14.1s	remaining: 19.6s
# 835:	learn: 0.5088827	total: 14.1s	remaining: 19.6s
# 836:	learn: 0.5088784	total: 14.1s	remaining: 19.6s
# 837:	learn: 0.5088750	total: 14.1s	remaining: 19.6s
# 838:	learn: 0.5088719	total: 14.1s	remaining: 19.6s
# 839:	learn: 0.5088684	total: 14.1s	remaining: 19.5s
# 840:	learn: 0.5088656	total: 14.2s	remaining: 19.5s
# 841:	learn: 0.5088626	total: 14.2s	remaining: 19.5s
# 842:	learn: 0.5088599	total: 14.2s	remaining: 19.5s
# 843:	learn: 0.5088568	total: 14.2s	remaining: 19.5s
# 844:	learn: 0.5088540	total: 14.2s	remaining: 19.4s
# 845:	learn: 0.5088505	total: 14.3s	remaining: 19.4s
# 846:	learn: 0.5088474	total: 14.3s	remaining: 19.4s
# 847:	learn: 0.5088440	total: 14.3s	remaining: 19.4s
# 848:	learn: 0.5088393	total: 14.3s	remaining: 19.4s
# 849:	learn: 0.5088366	total: 14.3s	remaining: 19.4s
# 850:	learn: 0.5088334	total: 14.3s	remaining: 19.3s
# 851:	learn: 0.5088308	total: 14.3s	remaining: 19.3s
# 852:	learn: 0.5088279	total: 14.4s	remaining: 19.3s
# 853:	learn: 0.5088247	total: 14.4s	remaining: 19.3s
# 854:	learn: 0.5088210	total: 14.4s	remaining: 19.3s
# 855:	learn: 0.5088179	total: 14.4s	remaining: 19.2s
# 856:	learn: 0.5088157	total: 14.4s	remaining: 19.2s
# 857:	learn: 0.5088115	total: 14.4s	remaining: 19.2s
# 858:	learn: 0.5088089	total: 14.5s	remaining: 19.2s
# 859:	learn: 0.5088066	total: 14.5s	remaining: 19.2s
# 860:	learn: 0.5088023	total: 14.5s	remaining: 19.2s
# 861:	learn: 0.5087990	total: 14.5s	remaining: 19.2s
# 862:	learn: 0.5087967	total: 14.5s	remaining: 19.1s
# 863:	learn: 0.5087927	total: 14.5s	remaining: 19.1s
# 864:	learn: 0.5087890	total: 14.6s	remaining: 19.1s
# 865:	learn: 0.5087845	total: 14.6s	remaining: 19.1s
# 866:	learn: 0.5087814	total: 14.6s	remaining: 19.1s
# 867:	learn: 0.5087777	total: 14.6s	remaining: 19s
# 868:	learn: 0.5087735	total: 14.6s	remaining: 19s
# 869:	learn: 0.5087702	total: 14.6s	remaining: 19s
# 870:	learn: 0.5087672	total: 14.7s	remaining: 19s
# 871:	learn: 0.5087637	total: 14.7s	remaining: 19s
# 872:	learn: 0.5087609	total: 14.7s	remaining: 19s
# 873:	learn: 0.5087583	total: 14.7s	remaining: 19s
# 874:	learn: 0.5087555	total: 14.8s	remaining: 19s
# 875:	learn: 0.5087518	total: 14.8s	remaining: 19s
# 876:	learn: 0.5087486	total: 14.9s	remaining: 19s
# 877:	learn: 0.5087454	total: 14.9s	remaining: 19s
# 878:	learn: 0.5087426	total: 14.9s	remaining: 19s
# 879:	learn: 0.5087385	total: 14.9s	remaining: 19s
# 880:	learn: 0.5087355	total: 14.9s	remaining: 19s
# 881:	learn: 0.5087315	total: 14.9s	remaining: 18.9s
# 882:	learn: 0.5087291	total: 15s	remaining: 18.9s
# 883:	learn: 0.5087262	total: 15s	remaining: 18.9s
# 884:	learn: 0.5087230	total: 15s	remaining: 18.9s
# 885:	learn: 0.5087197	total: 15s	remaining: 18.9s
# 886:	learn: 0.5087162	total: 15s	remaining: 18.8s
# 887:	learn: 0.5087129	total: 15s	remaining: 18.8s
# 888:	learn: 0.5087105	total: 15.1s	remaining: 18.8s
# 889:	learn: 0.5087078	total: 15.1s	remaining: 18.8s
# 890:	learn: 0.5087049	total: 15.1s	remaining: 18.8s
# 891:	learn: 0.5087021	total: 15.1s	remaining: 18.8s
# 892:	learn: 0.5086986	total: 15.1s	remaining: 18.8s
# 893:	learn: 0.5086959	total: 15.1s	remaining: 18.7s
# 894:	learn: 0.5086902	total: 15.2s	remaining: 18.7s
# 895:	learn: 0.5086871	total: 15.2s	remaining: 18.7s
# 896:	learn: 0.5086833	total: 15.2s	remaining: 18.7s
# 897:	learn: 0.5086802	total: 15.2s	remaining: 18.7s
# 898:	learn: 0.5086770	total: 15.2s	remaining: 18.7s
# 899:	learn: 0.5086738	total: 15.2s	remaining: 18.6s
# 900:	learn: 0.5086702	total: 15.3s	remaining: 18.6s
# 901:	learn: 0.5086675	total: 15.3s	remaining: 18.6s
# 902:	learn: 0.5086626	total: 15.3s	remaining: 18.6s
# 903:	learn: 0.5086601	total: 15.3s	remaining: 18.6s
# 904:	learn: 0.5086564	total: 15.3s	remaining: 18.6s
# 905:	learn: 0.5086536	total: 15.3s	remaining: 18.5s
# 906:	learn: 0.5086504	total: 15.4s	remaining: 18.5s
# ...
# 1721:	learn: 0.5072000	total: 33.5s	remaining: 5.41s
# 1722:	learn: 0.5071976	total: 33.6s	remaining: 5.39s
# 1723:	learn: 0.5071953	total: 33.6s	remaining: 5.38s
# 1724:	learn: 0.5071930	total: 33.6s	remaining: 5.36s
# 1725:	learn: 0.5071907	total: 33.6s	remaining: 5.33s
# 1726:	learn: 0.5071885	total: 33.6s	remaining: 5.32s
# 1727:	learn: 0.5071863	total: 33.6s	remaining: 5.29s
# 1728:	learn: 0.5071841	total: 33.7s	remaining: 5.28s
# 1729:	learn: 0.5071813	total: 33.7s	remaining: 5.26s
# 1730:	learn: 0.5071790	total: 33.7s	remaining: 5.24s
# 1731:	learn: 0.5071760	total: 33.7s	remaining: 5.22s
# 1732:	learn: 0.5071741	total: 33.7s	remaining: 5.2s
# 1733:	learn: 0.5071715	total: 33.8s	remaining: 5.18s
# 1734:	learn: 0.5071695	total: 33.8s	remaining: 5.16s
# 1735:	learn: 0.5071673	total: 33.8s	remaining: 5.14s
# 1736:	learn: 0.5071650	total: 33.9s	remaining: 5.13s
# 1737:	learn: 0.5071630	total: 33.9s	remaining: 5.11s
# 1738:	learn: 0.5071603	total: 33.9s	remaining: 5.09s
# 1739:	learn: 0.5071582	total: 33.9s	remaining: 5.07s
# 1740:	learn: 0.5071566	total: 34s	remaining: 5.05s
# 1741:	learn: 0.5071544	total: 34s	remaining: 5.04s
# 1742:	learn: 0.5071519	total: 34s	remaining: 5.02s
# 1743:	learn: 0.5071497	total: 34.1s	remaining: 5s
# 1744:	learn: 0.5071471	total: 34.1s	remaining: 4.98s
# 1745:	learn: 0.5071451	total: 34.1s	remaining: 4.96s
# 1746:	learn: 0.5071431	total: 34.2s	remaining: 4.95s
# 1747:	learn: 0.5071406	total: 34.2s	remaining: 4.93s
# 1748:	learn: 0.5071384	total: 34.2s	remaining: 4.91s
# 1749:	learn: 0.5071361	total: 34.3s	remaining: 4.89s
# 1750:	learn: 0.5071343	total: 34.3s	remaining: 4.88s
# 1751:	learn: 0.5071315	total: 34.3s	remaining: 4.86s
# 1752:	learn: 0.5071297	total: 34.3s	remaining: 4.83s
# 1753:	learn: 0.5071276	total: 34.3s	remaining: 4.82s
# 1754:	learn: 0.5071254	total: 34.4s	remaining: 4.8s
# 1755:	learn: 0.5071232	total: 34.4s	remaining: 4.78s
# 1756:	learn: 0.5071217	total: 34.4s	remaining: 4.76s
# 1757:	learn: 0.5071183	total: 34.4s	remaining: 4.74s
# 1758:	learn: 0.5071164	total: 34.4s	remaining: 4.72s
# 1759:	learn: 0.5071142	total: 34.4s	remaining: 4.7s
# 1760:	learn: 0.5071121	total: 34.5s	remaining: 4.68s
# 1761:	learn: 0.5071105	total: 34.5s	remaining: 4.66s
# 1762:	learn: 0.5071083	total: 34.5s	remaining: 4.64s
# 1763:	learn: 0.5071063	total: 34.5s	remaining: 4.62s
# 1764:	learn: 0.5071043	total: 34.5s	remaining: 4.6s
# 1765:	learn: 0.5071021	total: 34.6s	remaining: 4.58s
# 1766:	learn: 0.5070995	total: 34.6s	remaining: 4.56s
# 1767:	learn: 0.5070974	total: 34.6s	remaining: 4.54s
# 1768:	learn: 0.5070943	total: 34.6s	remaining: 4.52s
# 1769:	learn: 0.5070915	total: 34.6s	remaining: 4.5s
# 1770:	learn: 0.5070889	total: 34.7s	remaining: 4.48s
# 1771:	learn: 0.5070867	total: 34.7s	remaining: 4.46s
# 1772:	learn: 0.5070846	total: 34.7s	remaining: 4.45s
# 1773:	learn: 0.5070832	total: 34.8s	remaining: 4.43s
# 1774:	learn: 0.5070811	total: 34.8s	remaining: 4.41s
# 1775:	learn: 0.5070786	total: 34.8s	remaining: 4.39s
# 1776:	learn: 0.5070764	total: 34.8s	remaining: 4.37s
# 1777:	learn: 0.5070744	total: 34.8s	remaining: 4.35s
# 1778:	learn: 0.5070724	total: 34.9s	remaining: 4.33s
# 1779:	learn: 0.5070700	total: 34.9s	remaining: 4.31s
# 1780:	learn: 0.5070683	total: 34.9s	remaining: 4.29s
# 1781:	learn: 0.5070658	total: 34.9s	remaining: 4.27s
# 1782:	learn: 0.5070636	total: 34.9s	remaining: 4.25s
# 1783:	learn: 0.5070608	total: 35s	remaining: 4.23s
# 1784:	learn: 0.5070588	total: 35s	remaining: 4.21s
# 1785:	learn: 0.5070567	total: 35s	remaining: 4.19s
# 1786:	learn: 0.5070543	total: 35s	remaining: 4.17s
# 1787:	learn: 0.5070524	total: 35s	remaining: 4.15s
# 1788:	learn: 0.5070500	total: 35.1s	remaining: 4.13s
# 1789:	learn: 0.5070484	total: 35.1s	remaining: 4.12s
# 1790:	learn: 0.5070460	total: 35.1s	remaining: 4.09s
# 1791:	learn: 0.5070442	total: 35.1s	remaining: 4.08s
# 1792:	learn: 0.5070408	total: 35.1s	remaining: 4.05s
# 1793:	learn: 0.5070385	total: 35.1s	remaining: 4.04s
# 1794:	learn: 0.5070363	total: 35.2s	remaining: 4.01s
# 1795:	learn: 0.5070344	total: 35.2s	remaining: 4s
# 1796:	learn: 0.5070323	total: 35.2s	remaining: 3.98s
# 1797:	learn: 0.5070305	total: 35.2s	remaining: 3.96s
# 1798:	learn: 0.5070284	total: 35.2s	remaining: 3.94s
# 1799:	learn: 0.5070263	total: 35.2s	remaining: 3.92s
# 1800:	learn: 0.5070243	total: 35.3s	remaining: 3.9s
# 1801:	learn: 0.5070212	total: 35.3s	remaining: 3.88s
# 1802:	learn: 0.5070192	total: 35.3s	remaining: 3.86s
# 1803:	learn: 0.5070168	total: 35.3s	remaining: 3.84s
# 1804:	learn: 0.5070143	total: 35.3s	remaining: 3.82s
# 1805:	learn: 0.5070124	total: 35.4s	remaining: 3.8s
# 1806:	learn: 0.5070102	total: 35.4s	remaining: 3.78s
# 1807:	learn: 0.5070082	total: 35.4s	remaining: 3.76s
# 1808:	learn: 0.5070063	total: 35.4s	remaining: 3.74s
# 1809:	learn: 0.5070046	total: 35.4s	remaining: 3.72s
# 1810:	learn: 0.5070021	total: 35.4s	remaining: 3.7s
# 1811:	learn: 0.5069995	total: 35.5s	remaining: 3.68s
# 1812:	learn: 0.5069973	total: 35.5s	remaining: 3.66s
# 1813:	learn: 0.5069949	total: 35.5s	remaining: 3.64s
# 1814:	learn: 0.5069927	total: 35.5s	remaining: 3.62s
# 1815:	learn: 0.5069904	total: 35.5s	remaining: 3.6s
# 1816:	learn: 0.5069881	total: 35.5s	remaining: 3.58s
# 1817:	learn: 0.5069856	total: 35.6s	remaining: 3.56s
# 1818:	learn: 0.5069829	total: 35.6s	remaining: 3.54s
# 1819:	learn: 0.5069809	total: 35.6s	remaining: 3.52s
# 1820:	learn: 0.5069788	total: 35.6s	remaining: 3.5s
# 1821:	learn: 0.5069768	total: 35.6s	remaining: 3.48s
# 1822:	learn: 0.5069748	total: 35.6s	remaining: 3.46s
# 1823:	learn: 0.5069719	total: 35.7s	remaining: 3.44s
# 1824:	learn: 0.5069699	total: 35.7s	remaining: 3.42s
# 1825:	learn: 0.5069671	total: 35.7s	remaining: 3.4s
# 1826:	learn: 0.5069646	total: 35.7s	remaining: 3.38s
# 1827:	learn: 0.5069621	total: 35.8s	remaining: 3.36s
# 1828:	learn: 0.5069601	total: 35.8s	remaining: 3.35s
# 1829:	learn: 0.5069581	total: 35.8s	remaining: 3.33s
# 1830:	learn: 0.5069556	total: 35.9s	remaining: 3.31s
# 1831:	learn: 0.5069540	total: 35.9s	remaining: 3.29s
# 1832:	learn: 0.5069515	total: 35.9s	remaining: 3.27s
# 1833:	learn: 0.5069499	total: 35.9s	remaining: 3.25s
# 1834:	learn: 0.5069471	total: 35.9s	remaining: 3.23s
# 1835:	learn: 0.5069447	total: 35.9s	remaining: 3.21s
# 1836:	learn: 0.5069432	total: 35.9s	remaining: 3.19s
# 1837:	learn: 0.5069416	total: 36s	remaining: 3.17s
# 1838:	learn: 0.5069395	total: 36s	remaining: 3.15s
# 1839:	learn: 0.5069370	total: 36s	remaining: 3.13s
# 1840:	learn: 0.5069344	total: 36s	remaining: 3.11s
# 1841:	learn: 0.5069326	total: 36s	remaining: 3.09s
# 1842:	learn: 0.5069304	total: 36s	remaining: 3.07s
# 1843:	learn: 0.5069283	total: 36.1s	remaining: 3.05s
# 1844:	learn: 0.5069257	total: 36.1s	remaining: 3.03s
# 1845:	learn: 0.5069242	total: 36.1s	remaining: 3.01s
# 1846:	learn: 0.5069221	total: 36.1s	remaining: 2.99s
# 1847:	learn: 0.5069205	total: 36.2s	remaining: 2.97s
# 1848:	learn: 0.5069183	total: 36.2s	remaining: 2.95s
# 1849:	learn: 0.5069166	total: 36.2s	remaining: 2.94s
# 1850:	learn: 0.5069147	total: 36.2s	remaining: 2.92s
# 1851:	learn: 0.5069121	total: 36.2s	remaining: 2.9s
# 1852:	learn: 0.5069098	total: 36.3s	remaining: 2.88s
# 1853:	learn: 0.5069076	total: 36.3s	remaining: 2.86s
# 1854:	learn: 0.5069052	total: 36.3s	remaining: 2.84s
# 1855:	learn: 0.5069032	total: 36.3s	remaining: 2.82s
# 1856:	learn: 0.5069009	total: 36.4s	remaining: 2.8s
# 1857:	learn: 0.5068988	total: 36.4s	remaining: 2.78s
# 1858:	learn: 0.5068964	total: 36.4s	remaining: 2.76s
# 1859:	learn: 0.5068945	total: 36.4s	remaining: 2.74s
# 1860:	learn: 0.5068918	total: 36.5s	remaining: 2.72s
# 1861:	learn: 0.5068896	total: 36.5s	remaining: 2.7s
# 1862:	learn: 0.5068875	total: 36.5s	remaining: 2.69s
# 1863:	learn: 0.5068851	total: 36.5s	remaining: 2.67s
# 1864:	learn: 0.5068828	total: 36.6s	remaining: 2.65s
# 1865:	learn: 0.5068803	total: 36.6s	remaining: 2.63s
# 1866:	learn: 0.5068787	total: 36.6s	remaining: 2.61s
# 1867:	learn: 0.5068765	total: 36.6s	remaining: 2.59s
# 1868:	learn: 0.5068744	total: 36.7s	remaining: 2.57s
# 1869:	learn: 0.5068721	total: 36.7s	remaining: 2.55s
# 1870:	learn: 0.5068701	total: 36.7s	remaining: 2.53s
# 1871:	learn: 0.5068678	total: 36.8s	remaining: 2.51s
# 1872:	learn: 0.5068654	total: 36.8s	remaining: 2.49s
# 1873:	learn: 0.5068625	total: 36.8s	remaining: 2.48s
# 1874:	learn: 0.5068605	total: 36.8s	remaining: 2.46s
# 1875:	learn: 0.5068585	total: 36.9s	remaining: 2.44s
# 1876:	learn: 0.5068565	total: 36.9s	remaining: 2.42s
# 1877:	learn: 0.5068547	total: 36.9s	remaining: 2.4s
# 1878:	learn: 0.5068519	total: 37s	remaining: 2.38s
# 1879:	learn: 0.5068488	total: 37s	remaining: 2.36s
# 1880:	learn: 0.5068467	total: 37s	remaining: 2.34s
# 1881:	learn: 0.5068445	total: 37s	remaining: 2.32s
# 1882:	learn: 0.5068426	total: 37s	remaining: 2.3s
# 1883:	learn: 0.5068405	total: 37.1s	remaining: 2.28s
# 1884:	learn: 0.5068382	total: 37.1s	remaining: 2.26s
# 1885:	learn: 0.5068369	total: 37.1s	remaining: 2.24s
# 1886:	learn: 0.5068347	total: 37.1s	remaining: 2.22s
# 1887:	learn: 0.5068326	total: 37.1s	remaining: 2.2s
# 1888:	learn: 0.5068307	total: 37.1s	remaining: 2.18s
# 1889:	learn: 0.5068280	total: 37.2s	remaining: 2.16s
# 1890:	learn: 0.5068259	total: 37.2s	remaining: 2.14s
# 1891:	learn: 0.5068239	total: 37.2s	remaining: 2.12s
# 1892:	learn: 0.5068213	total: 37.2s	remaining: 2.1s
# 1893:	learn: 0.5068195	total: 37.2s	remaining: 2.08s
# 1894:	learn: 0.5068173	total: 37.2s	remaining: 2.06s
# 1895:	learn: 0.5068156	total: 37.3s	remaining: 2.04s
# 1896:	learn: 0.5068140	total: 37.3s	remaining: 2.02s
# 1897:	learn: 0.5068121	total: 37.3s	remaining: 2s
# 1898:	learn: 0.5068099	total: 37.3s	remaining: 1.99s
# 1899:	learn: 0.5068074	total: 37.3s	remaining: 1.97s
# 1900:	learn: 0.5068056	total: 37.4s	remaining: 1.95s
# 1901:	learn: 0.5068036	total: 37.4s	remaining: 1.93s
# 1902:	learn: 0.5068014	total: 37.4s	remaining: 1.91s
# 1903:	learn: 0.5068003	total: 37.4s	remaining: 1.89s
# 1904:	learn: 0.5067981	total: 37.4s	remaining: 1.87s
# 1905:	learn: 0.5067960	total: 37.4s	remaining: 1.85s
# 1906:	learn: 0.5067940	total: 37.5s	remaining: 1.83s
# 1907:	learn: 0.5067915	total: 37.5s	remaining: 1.81s
# 1908:	learn: 0.5067898	total: 37.5s	remaining: 1.79s
# 1909:	learn: 0.5067875	total: 37.5s	remaining: 1.77s
# 1910:	learn: 0.5067859	total: 37.5s	remaining: 1.75s
# 1911:	learn: 0.5067833	total: 37.5s	remaining: 1.73s
# 1912:	learn: 0.5067813	total: 37.6s	remaining: 1.71s
# 1913:	learn: 0.5067791	total: 37.6s	remaining: 1.69s
# 1914:	learn: 0.5067774	total: 37.6s	remaining: 1.67s
# 1915:	learn: 0.5067753	total: 37.6s	remaining: 1.65s
# 1916:	learn: 0.5067734	total: 37.6s	remaining: 1.63s
# 1917:	learn: 0.5067703	total: 37.7s	remaining: 1.61s
# 1918:	learn: 0.5067684	total: 37.7s	remaining: 1.59s
# 1919:	learn: 0.5067663	total: 37.7s	remaining: 1.57s
# 1920:	learn: 0.5067647	total: 37.7s	remaining: 1.55s
# 1921:	learn: 0.5067626	total: 37.7s	remaining: 1.53s
# 1922:	learn: 0.5067602	total: 37.7s	remaining: 1.51s
# 1923:	learn: 0.5067584	total: 37.8s	remaining: 1.49s
# 1924:	learn: 0.5067562	total: 37.8s	remaining: 1.47s
# 1925:	learn: 0.5067540	total: 37.8s	remaining: 1.45s
# 1926:	learn: 0.5067517	total: 37.8s	remaining: 1.43s
# 1927:	learn: 0.5067500	total: 37.8s	remaining: 1.41s
# 1928:	learn: 0.5067480	total: 37.9s	remaining: 1.39s
# 1929:	learn: 0.5067459	total: 37.9s	remaining: 1.37s
# 1930:	learn: 0.5067441	total: 37.9s	remaining: 1.35s
# 1931:	learn: 0.5067419	total: 37.9s	remaining: 1.33s
# 1932:	learn: 0.5067401	total: 37.9s	remaining: 1.31s
# 1933:	learn: 0.5067378	total: 38s	remaining: 1.29s
# 1934:	learn: 0.5067356	total: 38s	remaining: 1.27s
# 1935:	learn: 0.5067333	total: 38s	remaining: 1.26s
# 1936:	learn: 0.5067313	total: 38s	remaining: 1.24s
# 1937:	learn: 0.5067292	total: 38s	remaining: 1.22s
# 1938:	learn: 0.5067277	total: 38.1s	remaining: 1.2s
# 1939:	learn: 0.5067262	total: 38.1s	remaining: 1.18s
# 1940:	learn: 0.5067238	total: 38.1s	remaining: 1.16s
# 1941:	learn: 0.5067211	total: 38.1s	remaining: 1.14s
# 1942:	learn: 0.5067191	total: 38.1s	remaining: 1.12s
# 1943:	learn: 0.5067163	total: 38.1s	remaining: 1.1s
# 1944:	learn: 0.5067146	total: 38.2s	remaining: 1.08s
# 1945:	learn: 0.5067124	total: 38.2s	remaining: 1.06s
# 1946:	learn: 0.5067106	total: 38.2s	remaining: 1.04s
# 1947:	learn: 0.5067081	total: 38.2s	remaining: 1.02s
# 1948:	learn: 0.5067062	total: 38.2s	remaining: 1s
# 1949:	learn: 0.5067039	total: 38.3s	remaining: 982ms
# 1950:	learn: 0.5067012	total: 38.3s	remaining: 962ms
# 1951:	learn: 0.5066994	total: 38.3s	remaining: 943ms
# 1952:	learn: 0.5066976	total: 38.3s	remaining: 923ms
# 1953:	learn: 0.5066945	total: 38.4s	remaining: 903ms
# 1954:	learn: 0.5066928	total: 38.4s	remaining: 883ms
# 1955:	learn: 0.5066903	total: 38.4s	remaining: 864ms
# 1956:	learn: 0.5066877	total: 38.4s	remaining: 844ms
# 1957:	learn: 0.5066855	total: 38.5s	remaining: 825ms
# 1958:	learn: 0.5066842	total: 38.5s	remaining: 805ms
# 1959:	learn: 0.5066820	total: 38.5s	remaining: 785ms
# 1960:	learn: 0.5066791	total: 38.5s	remaining: 766ms
# 1961:	learn: 0.5066772	total: 38.5s	remaining: 746ms
# 1962:	learn: 0.5066753	total: 38.5s	remaining: 726ms
# 1963:	learn: 0.5066733	total: 38.5s	remaining: 706ms
# 1964:	learn: 0.5066710	total: 38.5s	remaining: 687ms
# 1965:	learn: 0.5066693	total: 38.6s	remaining: 667ms
# 1966:	learn: 0.5066674	total: 38.6s	remaining: 647ms
# 1967:	learn: 0.5066651	total: 38.6s	remaining: 628ms
# 1968:	learn: 0.5066632	total: 38.6s	remaining: 608ms
# 1969:	learn: 0.5066609	total: 38.6s	remaining: 588ms
# 1970:	learn: 0.5066589	total: 38.6s	remaining: 569ms
# 1971:	learn: 0.5066569	total: 38.7s	remaining: 549ms
# 1972:	learn: 0.5066543	total: 38.7s	remaining: 530ms
# 1973:	learn: 0.5066519	total: 38.7s	remaining: 510ms
# 1974:	learn: 0.5066500	total: 38.8s	remaining: 491ms
# 1975:	learn: 0.5066482	total: 38.8s	remaining: 471ms
# 1976:	learn: 0.5066460	total: 38.8s	remaining: 451ms
# 1977:	learn: 0.5066441	total: 38.8s	remaining: 432ms
# 1978:	learn: 0.5066424	total: 38.8s	remaining: 412ms
# 1979:	learn: 0.5066400	total: 38.8s	remaining: 392ms
# 1980:	learn: 0.5066379	total: 38.8s	remaining: 373ms
# 1981:	learn: 0.5066359	total: 38.9s	remaining: 353ms
# 1982:	learn: 0.5066343	total: 38.9s	remaining: 333ms
# 1983:	learn: 0.5066321	total: 38.9s	remaining: 314ms
# 1984:	learn: 0.5066307	total: 38.9s	remaining: 294ms
# 1985:	learn: 0.5066284	total: 38.9s	remaining: 274ms
# 1986:	learn: 0.5066269	total: 38.9s	remaining: 255ms
# 1987:	learn: 0.5066245	total: 38.9s	remaining: 235ms
# 1988:	learn: 0.5066225	total: 39s	remaining: 215ms
# 1989:	learn: 0.5066206	total: 39s	remaining: 196ms
# 1990:	learn: 0.5066182	total: 39s	remaining: 176ms
# 1991:	learn: 0.5066165	total: 39s	remaining: 157ms
# 1992:	learn: 0.5066142	total: 39s	remaining: 137ms
# 1993:	learn: 0.5066119	total: 39s	remaining: 117ms
# 1994:	learn: 0.5066100	total: 39.1s	remaining: 97.9ms
# 1995:	learn: 0.5066078	total: 39.1s	remaining: 78.3ms
# 1996:	learn: 0.5066062	total: 39.1s	remaining: 58.7ms
# 1997:	learn: 0.5066042	total: 39.1s	remaining: 39.1ms
# 1998:	learn: 0.5066019	total: 39.1s	remaining: 19.6ms
# 1999:	learn: 0.5065997	total: 39.1s	remaining: 0us
# {'nan_mode': 'Min', 'gpu_ram_part': 0.95, 'eval_metric': 'Logloss', 'iterations': 2000, 'leaf_estimation_method': 'Newton', 'observations_to_bootstrap': 'TestOnly', 'grow_policy': 'SymmetricTree', 'boosting_type': 'Plain', 'feature_border_type': 'GreedyLogSum', 'bayesian_matrix_reg': 0.10000000149011612, 'devices': '-1', 'pinned_memory_bytes': '104857600', 'l2_leaf_reg': 3, 'random_strength': 1, 'rsm': 1, 'boost_from_average': False, 'gpu_cat_features_storage': 'GpuRam', 'fold_size_loss_normalization': False, 'model_size_reg': 0.5, 'pool_metainfo_options': {'tags': {}}, 'use_best_model': False, 'meta_l2_frequency': 0, 'class_names': [0, 1], 'random_seed': 42, 'depth': 6, 'border_count': 128, 'min_fold_size': 100, 'data_partition': 'DocParallel', 'bagging_temperature': 1, 'classes_count': 0, 'auto_class_weights': 'None', 'leaf_estimation_backtracking': 'AnyImprovement', 'best_model_min_trees': 1, 'min_data_in_leaf': 1, 'add_ridge_penalty_to_loss_function': False, 'loss_function': 'Logloss', 'learning_rate': 0.012419000267982485, 'meta_l2_exponent': 1, 'score_function': 'Cosine', 'task_type': 'GPU', 'leaf_estimation_iterations': 10, 'bootstrap_type': 'Bayesian', 'max_leaves': 64}
# Valid log-loss is 0.5065998690021452
# Valid AUC is 0.8198526711852614

# %%
# # this loads models if you need to (or forgot to save them on training above)
# xgboost_models = {}
# xgboost_models_path = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/models/baseline_20210905a_152521_5folds/xgboost/')
# for fold in range(5):
#     xgboost_models[fold] = load(xgboost_models_path/f'xgboost_fold{fold}_model.joblib')

# %% [markdown]
# # Inference

# %%
test_df = pd.read_csv(datapath/'test.csv', index_col='id', low_memory=False)
# test_df.to_feather(datapath/'test.feather') # issue with index being non-default; fix later
# test_df = pd.read_feather(datapath/'test.feather')

# %%
test_df.head()
# Out:
#               f1        f2        f3       f4       f5       f6       f7  \
# id
# 957919  0.165850  0.487050   1295.00  0.02310  0.31900  0.90188   573.29
# 957920  0.129650  0.373480   1763.00  0.72884  0.33247 -1.26310   875.55
# 957921  0.120190  0.445210    736.26  0.04615  0.29605  0.31665  2659.50
# 957922  0.054008  0.395960    996.14  0.85934  0.36678 -0.17060   386.56
# 957923  0.079947 -0.006919  10574.00  0.34845  0.45008 -1.84200  3027.00
#
#               f8            f9       f10  ...     f109     f110    f111  \
# id                                        ...
# 957919    3743.7  2.705700e+12  6221.000  ...  0.16253 -22.1890  2.0655
# 957920  554370.0  5.955700e+14   934.430  ...  0.81528  -1.6342  1.5736
# 957921  317140.0  3.977800e+14   131.810  ...  0.81831 -32.7800  2.1364
# 957922  325680.0 -3.432200e+13   -26.473  ...  0.86559  -2.4162  1.5199
# 957923  428150.0  9.291500e+11  5999.400  ...  0.25190 -18.6300  3.7387
#
#             f112     f113     f114    f115          f116    f117     f118
# id
# 957919  0.430880 -10.7410  81606.0  1.1940  1.980400e+14  2017.1  0.46357
# 957920 -1.071200  11.8320  90114.0  1.1507  4.388000e+16  6638.9  0.28125
# 957921 -1.931200  -3.2804  37739.0  1.1548  1.718100e+14  5844.0  0.13797
# 957922 -0.011633   1.3840  26849.0  1.1490  2.138800e+17  6173.3  0.32910
# 957923  0.757080  -4.9405  50336.0  1.2488  2.151300e+17  2250.1  0.33796
#
# [5 rows x 118 columns]

# %% [markdown]
# (Here's where encapsulating the transformations in a pipeline would come in handy. But I'll do it manually for now.)

# %%
features = [x for x in test_df.columns if x != 'claim']
X_test = test_df[features] # this is just for naming consistency

# %% [markdown]
# Now, let's get the features the model was trained on and subset the test set's features accordingly

# %%
# generation polynomial features
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_test_poly = poly.fit_transform(X_test)

# %%
# X_test_poly_names = poly.get_feature_names(X_test.columns)
# X_poly_names[100:150]
# features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
# checks = [feature in X_test_poly_names for feature in features]
# checks

# %%
# X_test_final = pd.DataFrame(X_test_poly, columns=X_test_poly_names)

# %%
# X_test_final = X_test_final[features[1:]]
# X_test_final = X_test

# %% [markdown]
# # Test set preprocessing

# %%
X_test['nan_count'] = X_test.isnull().sum(axis=1)

# %%
imputer = SimpleImputer(strategy='median', add_indicator=True)
X_test_imputed_np = imputer.fit_transform(X_test)

# %%
X_test_imputed = pd.DataFrame(X_test_imputed, columns=[str(x) for x in range(X_test_imputed.shape[1])])
X_test_imputed.to_feather(path=datapath/'X_test_NaNcounts_imputed-Median-wIndicators.feather')

# %%
scaler = exmodel_config['scaler']()
X_test_imputed_scaled_np = scaler.fit_transform(X_test_imputed)
X_test_imputed_scaled = pd.DataFrame(X_test_imputed_scaled_np, columns=X_test_imputed.columns)
X_test_imputed_scaled.to_feather(path=datapath/'X_test_NaNcounts_imputed-Median-wIndicators_StandardScaled.feather')
# X_scaled_df = pd.DataFrame(X_scaled, columns=X_poly_names)

# %%
xgboost_preds = {}
for fold in xgboost_models.keys():
    xgboost_preds[fold] = xgboost_models[fold].predict(X_test_imputed_scaled)
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
lightgbm_preds = {}
for fold in lightgbm_models.keys():
    lightgbm_preds[fold] = lightgbm_models[fold].predict(X_test_imputed_scaled)

# %%
catboost_preds = {}
for fold in catboost_models.keys():
    catboost_preds[fold] = catboost_models[fold].predict(X_test_imputed_scaled)

# %%
preds_path = Path(datapath/f"preds/{config_run['name']}_{exmodel_config['kfolds']}folds/")
preds_path.mkdir(exist_ok=True)

for library in ['xgboost', 'lightgbm', 'catboost']:
    (preds_path/library).mkdir(exist_ok=True)

# %%
dump(xgboost_preds, Path(preds_path/'xgboost/xgboost_preds_dict.joblib'))
# Out:
# ['/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/preds/baseline_20210909_114059_5folds/xgboost/xgboost_preds_dict.joblib']

# %%
dump(lightgbm_preds, Path(preds_path/'lightgbm/lightgbm_preds_dict.joblib'))
# Out:
# ['/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/preds/baseline_20210909_114059_5folds/lightgbm/lightgbm_preds_dict.joblib']

# %%
dump(catboost_preds, Path(preds_path/'catboost/catboost_preds_dict.joblib'))
# Out:
# ['/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/preds/baseline_20210909_114059_5folds/catboost/catboost_preds_dict.joblib']

# %%
sample_df = pd.read_csv(datapath/'sample_solution.csv')

# %%
final_xgboost_preds = (xgboost_preds[0] + xgboost_preds[1] + xgboost_preds[2] + xgboost_preds[3] + xgboost_preds[4]) / 5
final_lightgbm_preds = (lightgbm_preds[0] + lightgbm_preds[1] + lightgbm_preds[2] + lightgbm_preds[3] + lightgbm_preds[4]) / 5
final_catboost_preds = (catboost_preds[0] + catboost_preds[1] + catboost_preds[2] + catboost_preds[3] + catboost_preds[4]) / 5

# %%
print(final_xgboost_preds[:10])
print(final_lightgbm_preds[:10])
print(final_catboost_preds[:10])

# %%
sample_df.loc[:, 'claim'] = final_xgboost_preds

# %%
sample_df.head()
# Out:
#        id  claim
# 0  957919    1.0
# 1  957920    0.0
# 2  957921    1.0
# 3  957922    0.0
# 4  957923    0.0

# %%
submission_path = datapath/'submissions'
submission_path.mkdir(exist_ok=True)

# %%
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_xgboost-mean.csv", index=False)

# %%
sample_df.loc[:, 'claim'] = final_lightgbm_preds
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_lightgbm-mean.csv", index=False)

# %%
sample_df.loc[:, 'claim'] = final_catboost_preds
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_catboost-mean.csv", index=False)

# %%
ensemble_preds = (final_xgboost_preds + final_lightgbm_preds + final_catboost_preds) / 3

# %%
sample_df.loc[:, 'claim'] = ensemble_preds
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_ensemble-equal_model_and_fold_weight_mean.csv", index=False)

# %%
ensemble_preds = 0.4*final_xgboost_preds + 0.3*final_lightgbm_preds + 0.3*final_catboost_preds

# %%
sample_df.loc[:, 'claim'] = ensemble_preds
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_ensemble-0.4xgboost_0.3lightgbm_0.3catboost-equal_fold_weight_mean.csv", index=False)

# %% [markdown]
# # Ensembling with CatBoost

# %%
catboost_models = {}
saved_models_path = Path('/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/models/CatBoost_ensemble_20210831_144245_5folds/')
for fold in range(5):
    catboost_models[fold] = load(filename=Path(saved_models_path/f'catboost_fold{fold}_model.joblib'))

# %%
catboost_models
# Out:
# {0: <catboost.core.CatBoostRegressor at 0x7f1b154ecfa0>,
#  1: <catboost.core.CatBoostRegressor at 0x7f1b1548a880>,
#  2: <catboost.core.CatBoostRegressor at 0x7f1b154ec0a0>,
#  3: <catboost.core.CatBoostRegressor at 0x7f1b1548ac40>,
#  4: <catboost.core.CatBoostRegressor at 0x7f1b154ecdf0>}

# %%
catboost_preds = {}
for fold in catboost_models.keys():
    catboost_preds[fold] = catboost_models[fold].predict(X_test_scaled)

# %%
final_catboost_preds = (catboost_preds[0] + catboost_preds[1] + catboost_preds[2] + catboost_preds[3] + catboost_preds[4]) / 5

# %%
ensemble_preds = 0.6 * final_catboost_preds + 0.4 * final_preds

# %%
ensemble_preds[:10], final_catboost_preds[:10], final_preds[:10]
# Out:
# (array([8.40583658, 4.58774964, 8.32465697, 7.18375788, 7.13135284,
#         9.67367649, 9.96252577, 5.89393404, 7.22270917, 7.53612671]),
#  array([8.67110053, 4.62450053, 8.6372614 , 7.22330665, 6.92239076,
#         9.70097104, 9.97590847, 5.72130089, 7.33351626, 7.44252341]),
#  array([8.00794  , 4.5326233, 7.85575  , 7.1244345, 7.444796 , 9.632734 ,
#         9.9424515, 6.1528835, 7.0564985, 7.6765313], dtype=float32))

# %%
final_ensemble_preds = 0.65 * final_catboost_preds + 0.35 * final_preds

# %%
final_ensemble_preds[:10], final_catboost_preds[:10], final_preds[:10]
# Out:
# (array([8.4389943 , 4.5923435 , 8.36373235, 7.18870129, 7.10523255,
#         9.67708804, 9.96419843, 5.87235472, 7.23656006, 7.52442615]),
#  array([8.67110053, 4.62450053, 8.6372614 , 7.22330665, 6.92239076,
#         9.70097104, 9.97590847, 5.72130089, 7.33351626, 7.44252341]),
#  array([8.00794  , 4.5326233, 7.85575  , 7.1244345, 7.444796 , 9.632734 ,
#         9.9424515, 6.1528835, 7.0564985, 7.6765313], dtype=float32))

# %%
sample_df.loc[:, 'loss'] = final_ensemble_preds

# %%
sample_df.head()
# Out:
#        id      loss
# 0  250000  8.438994
# 1  250001  4.592343
# 2  250002  8.363732
# 3  250003  7.188701
# 4  250004  7.105233

# %%
sample_df.to_csv('XGBoost0.35-Catboost0.65_ensemble_20210831_no_feature_gen.csv', index=False)

# %% [markdown]
# # Experiment - fitting model on full training set

# %%
# applying hold-out before scaling
# X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
#                                                       test_size=config['test_size'], 
#                                                       random_state=config['random_state']
#                                                      )
# scaling (i.e. normalizing)
scaler = config['scaler']()
X_s = scaler.fit_transform(X)
X_test_s = scaler.fit_transform(X_test)

# selecting features
selector = config['feature_selector'](score_func=config["feature_selection_scoring"], 
                                      k=config['k_best'])
X_fs = selector.fit_transform(X_s, y)
X_test_fs = X_test_s[:, selector.get_support()]

model = XGBRegressor(
    tree_method=config['tree_method'],
    booster=config['booster'],
    n_estimators=config['n_estimators'], 
    max_depth=config['max_depth'],
    learning_rate=config['learning_rate'], 
    test_size=config['test_size'],
    subsample=config['subsample'],
    random_state=config['random_state'],
    n_jobs=config['n_jobs'], 
    verbosity=config['verbosity'], 
)
#     wandb.log({'params': model.get_params()}) # logging model parameters
model.fit(X_fs, y)#, callbacks=[wandb.xgboost.wandb_callback()])
# Out:
# [12:11:15] WARNING: ../src/learner.cc:573:
# Parameters: { "test_size" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRegressor(base_score=0.5, booster='dart', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1522, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=400, n_jobs=-1, num_parallel_tree=1, random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              test_size=0.2, tree_method='auto', validate_parameters=1,
#              verbosity=1)

# %%
y_test_preds = model.predict(X_test_fs)
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
sample_df = pd.read_csv(datapath/'sample_submission.csv')

# %%
sample_df.loc[:, 'loss'] = y_test_preds

# %%
sample_df.head()
# Out:
#        id      loss
# 0  250000  8.027956
# 1  250001  4.305676
# 2  250002  7.300106
# 3  250003  6.988875
# 4  250004  7.316631

# %%
sample_df.to_csv('202108241211_XGBoost_fullset.csv', index=False)
