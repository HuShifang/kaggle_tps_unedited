# %% [markdown]
# # Super-Learner Manual Implementation
# Since `mlens.ensemble.SuperLearner` does not appear to be capable of correctly outputting probabilities in binary classification tasks, I'm going to roll my own implementation of the underlying algorithm.

# %% [markdown]
# # Setup

# %%
# two manual flags (ex-config)
colab = False
gpu_available = False
libraries = ['xgboost', 'lightgbm', 'catboost']

# %%
# basic imports
from pathlib import Path
import os
import math
from datetime import datetime

# %%
# %matplotlib inline
# %config Completer.use_jedi = False
os.environ['WANDB_NOTEBOOK_NAME'] = f"super-learner_manual_{datetime.now().strftime('%Y%m%d')}.ipynb"

# %%
# handle Google Colab-specific library installation/updating
if colab:
    # much of the below inspired by or cribbed from the May 2021 Kaggle Tabular Playground winner, at 
    # https://colab.research.google.com/gist/academicsuspect/0aac7bd6e506f5f70295bfc9a3dc2250/tabular-may-baseline.ipynb?authuser=1#scrollTo=LJoVKJb5wN0L
    
    # Kaggle API for downloading the datasets
    # !pip install --upgrade -q kaggle

    # weights and biases
    # !pip install -qqqU wandb
    
    # Optuna for parameter search
    # !pip install -q optuna

    # upgrade sklearn
    # !pip install --upgrade scikit-learn

    # !pip install category_encoders
    
    if 'catboost' in libraries:
        # !pip install catboost
    
    if 'xgboost' in libraries:
        if gpu_available: 
            # this part is from https://github.com/rapidsai/gputreeshap/issues/24
            # !pip install cmake --upgrade
            # !pip install sklearn --upgrade
            # !git clone --recursive https://github.com/dmlc/xgboost
            # %cd /content/xgboost
            # !mkdir build
            # %cd build
            # !cmake .. -DUSE_CUDA=ON
            # !make -j4
            # %cd /content/xgboost/python-package
            # !python setup.py install --use-cuda --use-nccl
            # !/opt/bin/nvidia-smi
            # !pip install shap
        else:
            # !pip install --upgrade xgboost
    if 'lightgbm' in libraries:
        if gpu_available:
            # lighgbm gpu compatible
            # !git clone --recursive https://github.com/Microsoft/LightGBM
            ! cd LightGBM && rm -rf build && mkdir build && cd build && cmake -DUSE_GPU=1 ../../LightGBM && make -j4 && cd ../python-package && python3 setup.py install --precompile --gpu;
        else:
            # !pip install --upgrade lightgbm

# %% [markdown]
# Now, non-stdlib imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# general ML tooling
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import log_loss, roc_auc_score
import wandb
from wandb.xgboost import wandb_callback
from wandb.lightgbm import wandb_callback
from sklearn.impute import SimpleImputer #, KNNImputer
# import timm
import seaborn as sns

from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import StackingClassifier, RandomForestClassifier
# from mlens.ensemble import SuperLearner
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler #, MinMaxScaler, MaxAbsScaler, RobustScaler, PolynomialFeatures
# from sklearn.feature_selection import SelectKBest, f_regression
from joblib import dump, load
# feature engineering tools
# from sklearn.feature_selection import mutual_info_regression
# import featuretools as ft
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# Now, datapath setup

# %%
# # This is the code for reading the train.csv and converting it to a .feather file
# df = pd.read_csv(datapath/'train.csv', index_col='id', low_memory=False)
# df.index.name = None
# df.to_feather(path='./dataset_df.feather')

# %%
if colab:
    # mount Google Drive
    from google.colab import drive
    drive.mount('/content/drive')
    
    # handling datapath
    datapath = Path('/content/drive/MyDrive/kaggle/tabular_playgrounds/sep2021/')
    
else:
    # if on local machine
    datapath = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/')

# %% [markdown]
# ## Ex-Model Config

# %%
# meta-config for preprocessing and cross-validation, but NOT for model parameters
exmodel_config = {
    # model config
#     "model": XGBClassifier,
#     "n_estimators": 100, 
#     "max_depth": 3,
#     "learning_rate": 0.1,
#     "test_size": 0.2,
#     "reg_lambda": None, 
    "library": libraries,
    "scaler": StandardScaler, # TODO: experiment with others (but imputation may be slow)
    "scale_b4_impute": False,
    "imputer": SimpleImputer(strategy='median', add_indicator=True),
#     "knn_imputer_n_neighbors": None, # None if a different imputer is used
#     "feature_selector": SelectKBest,
#     "k_best": 80,
#     "feature_selection_scoring": f_regression,
    'random_state': 42,
#     'subsample': 1,
#     'cross_val_strategy': KFold, # None for holdout, or the relevant sklearn class
#     'kfolds': 5, # if 1, that means just doing holdout
#     'test_size': 0.2,
#     'features_created': False,
#     'feature_creator': None,
}

# %% [markdown]
# ## Data Setup

# %% [markdown]
# **TODO** Write some conditional logic here to automate it -- possibly as part of a sklearn.*pipeline

# %%
# if exmodel_config['scaler']:
#     scaler = exmodel_config['scaler']()
#     scaler.fit_transform()

# %%
# # here's how to load the original, unaltered dataset and separate features from targets
# df = pd.read_feather(path=datapath/'dataset_df.feather') # this is the unaltered original dataset
# features = [x for x in df.columns if x != 'claim']
# X = df[features]
# y = df.claim



# load the version of the dataset with imputations; X and y were stored separately, as feather and joblib respectively
X = pd.read_feather(datapath/'X_NaNcounts_imputed-Median-wIndicators-StandardScaled.feather') 
y = load(datapath/'y.joblib')    
X.index.name = 'id'
y.index.name = 'id'

exmodel_config['feature_count'] = len(X.columns)
exmodel_config['feature_generator'] = None

# %%
# scaler = exmodel_config['scaler']()
# X_scaled = scaler.fit_transform(X)
# X = pd.DataFrame(X_scaled, columns=X.columns)

# %%
X.head()
# Out:
#            0         1         2         3         4         5         6  \
# id
# 0   0.425545 -2.357891 -0.637206 -0.866657 -0.111568 -4.829243 -1.171229
# 1   0.247600 -0.323982  1.223569  0.361863  1.071182 -0.361140  0.082051
# 2   2.032371 -2.435680 -0.488960  0.341193  1.069656  0.118532  0.537069
# 3   1.438373 -2.337605 -0.508914 -0.829607  1.485682  3.592008 -1.189087
# 4   0.602333  1.076218 -0.648438  0.463365  0.275053 -0.157989  0.727338
#
#            7         8         9  ...       227       228       229       230  \
# id                                ...
# 0  -0.603397 -0.596871 -0.516828  ... -0.128368 -0.127677 -0.128242 -0.127867
# 1  -0.746590  0.899454  0.469668  ... -0.128368 -0.127677 -0.128242 -0.127867
# 2  -0.044075 -0.763516  1.056879  ... -0.128368 -0.127677 -0.128242 -0.127867
# 3  -0.339152 -0.735281 -0.529158  ... -0.128368 -0.127677 -0.128242 -0.127867
# 4  -0.905498  0.052478 -0.511066  ... -0.128368 -0.127677 -0.128242 -0.127867
#
#          231       232       233      234       235      236
# id
# 0  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 1  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 2  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 3  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 4  -0.127119 -0.127985 -0.128494 -0.12862  7.821398 -0.12703
#
# [5 rows x 237 columns]

# %%
y.head()
# Out:
# id
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: claim, dtype: int64

# %% [markdown]
# ### Model Config

# %%
def model_configurator(library, gpu_available=True):#, config=universal_config):
    """
    Function that provide task-specific or general preference arguments for the various models. 
    
    At first, will rely largely on defaults for hyperparameters, but later this function 
    can be supplemented later with optimal values, as they're learned in sweeps.
    .
    
    Rationale: creating a helper function will allow more experimentation later, and also
    composite runs that cycle through a series of models.
    
    :param model: A model from [XGBClassifier, LGBMClassifier, CatBoostClassifier]
    :return config: A dict that supplements default hyperparameter values with 1) 
                    task-appropriate ones, and perhaps later 2) optimal hyperparameter values.
    """
    config = {}
    
    # library-specific config
    if library in ['xgboost', 'lightgbm']:
        config['n_jobs'] = -1
        
    # best params per sweep `icac24c5`, generated from notebook `sweep_20210905.ipynb`
    # runtime per fold should be around 12m 38s
    # should get auc of 0.7434 on the random_state=42 holdout
    # haven't yet tried dart
    if library == 'xgboost':
#         config['tree_method'] = 'auto'
#         config['booster'] = 'gbtree' # or 'dart'
#         config['model'] = XGBClassifier
        config['verbosity'] = 1
        config['objective'] = 'binary:logistic'
#         config['eval_metric'] = ['auc', 'logloss', 'aucpr'],
        config['tree_method'] = 'gpu_hist' if (gpu_available and colab) else 'auto' 
        
        # comment out the below to get defaults
        config['n_estimators'] = 902
        config['learning_rate'] = 0.0304
        config['max_depth'] = 3
        config['reg_alpha'] = 0.863
        config['reg_lambda'] = 2.442
        config['subsample'] = 0.8627

    # best params per sweep `sjghewf0`, generated from notebook `sweep_lightgbm_20210907`
    # run name `sweep_lightgbm_20210907_195641`
    # runtime per fold should be around 39s
    # should get an auc of 0.7435 on random_state=42 holdout
    if library == 'lightgbm':
#         config['model'] = LGBMClassifier
        config['objective'] = 'binary'
        config['eval_metric'] = ['auc', 'logloss']
        config['boosting_type'] = 'gbdt' # or 'dart'
        config['device_type'] = 'cuda' if (gpu_available and colab) else 'cpu' # 'gpu' also possible, 'cpu' is default
        
        # comment out the below for defaults
        config['n_estimators'] = 1286
        config['learning_rate'] = 0.03221
        config['max_depth'] = 2
        config['reg_alpha'] = 0.4687
        config['reg_lambda'] = 0.1763
        config['subsample'] = 0.6621
        

#     if config['model'] == CatBoostClassifier:
    if library == 'catboost':
#         config['model'] = CatBoostClassifier
        config['task_type'] = 'GPU' if gpu_available else 'CPU'
        config['custom_metrics'] = ['Logloss', 'AUC'] # objective (loss fn) must be singular, defaults to Logloss
        config['n_estimators'] = 2000 # logged as "iterations" otherwise

    return config

# %% [markdown]
# ## Weights and Biases Run Config

# %% [markdown]
# Below is the configuration for a Weights and Biases (`wandb`) run.

# %%
# wandb config:
config_run = {
    'name': f"{os.environ['WANDB_NOTEBOOK_NAME'][:-6]}_{datetime.now().strftime('%H%M%S')}", # just removes the .ipynb extension, leaving the notebook filename's stem
    'tags': ['super-learner', 'experiment', 'attempt'],
    'notes': "Since `mlens.ensemble.SuperLearner` does not appear to be capable of correctly outputting probabilities in binary classification tasks, I'm going to roll my own implementation of the underlying algorithm.",
}

# %% [markdown]
# # Preprocessing
# Scaling has already occurred -- used `StandardScaler` as a precursor to using `KNNImputer(n_neighbors=5)`, on the premise that imputation would proceed more quickly if things were already scaled. I may try different permutations of this later: using `IterativeImputer` instead, before or after scaling, potentially with different scalers.

# %% [markdown]
# # Feature Creation and Selection

# %%
# load all the polynomialfeatures generated with `PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)`
# X_np = np.load(datapath/'X_poly_unscaled.npy')
# X = pd.DataFrame(X_np)

# %%
# X.columns

# %%
# generation polynomial features
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_poly = poly.fit_transform(X)

# %%
# X_poly_names = poly.get_feature_names(X.columns)
# # X_poly_names[100:150]
# features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
# checks = [feature in X_poly_names for feature in features]
# checks

# %%
# X = pd.DataFrame(X_poly, columns=X_poly_names)

# %%
# X = X[features[1:]]

# %% [markdown]
# # Training

# %%
def super_train(X_train, X_valid, y_train, y_valid, model_config, 
                                              random_state=42,
                                              exmodel_config=exmodel_config, 
                                              config_run=config_run):#, scaler): # passed in via config dict for now
    """
    Basic training function. Note that some of the options passed via the argument are
    in fact hard-coded in, to avoid inconveniences.
    :param X_train: the training set features
    :param X_valid: the validation set features
    :param y_train: the training set targets
    :param y_valid: the validation set targets
    :param random_staKFold: for reproducibility
    :param exmodel_config: dict containing configuration details including the library 
                            (thus model) used, preprocessing, and cross-validation
    :param model_config: dict containing hyperparameter specifications for the model
    :param config_run: dict containing wandb run configuration (name, etc)
    """
    
    
    wandb.init(
        project="202109_Kaggle_tabular_playground",
        save_code=True,
        tags=config_run['tags'],
        name=config_run['name'],
        notes=config_run['notes'],
        config=exmodel_config)   
        
    if exmodel_config['library'] == 'xgboost':
        model = XGBClassifier(
            tree_method=model_config['tree_method'],
            random_state=random_state,
            n_jobs=model_config['n_jobs'], 
            verbosity=model_config['verbosity'], 
            objective=model_config['objective'],
            # #             eval_metric=model_config['eval_metric'],

            # comment out the below for a fairly default model
#             booster=model_config['booster'],
            max_depth=model_config['max_depth'],
            learning_rate=model_config['learning_rate'], 
            subsample=model_config['subsample'],
            reg_alpha=model_config['reg_alpha'],
            reg_lambda=model_config['reg_lambda'],
            n_estimators=model_config['n_estimators'],
        )
        
        model.fit(X_train, y_train, callbacks=[wandb.xgboost.wandb_callback()],
#                                     eval_metric=model_config['eval_metric'],
                 )


    elif exmodel_config['library'] == 'lightgbm':
        model = LGBMClassifier(
#             boosting_type=model_config['boosting_type'],
#             max_depth=model_config['max_depth']
            # TODO
            random_state=random_state,
            n_jobs=model_config['n_jobs'],
            objective=model_config['objective'],
#             eval_metric=model_config['eval_metric'],
            boosting_type=model_config['boosting_type'],
            device_type=model_config['device_type'],
            
            # comment out the below for a basically default model
            n_estimators=model_config['n_estimators'],
            learning_rate=model_config['learning_rate'],
            max_depth=model_config['max_depth'],
            reg_alpha=model_config['reg_alpha'],
            reg_lambda=model_config['reg_lambda'],
            subsample=model_config['subsample'],
        )
        
        model.fit(X_train, y_train, callbacks=[wandb.lightgbm.wandb_callback()],
#                                     eval_metric=model_config['eval_metric'],
                 )
        
    elif exmodel_config['library'] == 'catboost':
        print("CatBoost, therefore no WandB callback.")
        model = CatBoostClassifier(
#             n_estimators=config['n_estimators'],
#             learning_rate=config['learning_rate'],
#             max_depth=config['max_depth'],
            task_type=model_config['task_type'],
    #         n_jobs=config['n_jobs'],
    #         verbosity=config['verbosity'],
    #         subsample=config['subsample'],
            n_estimators=model_config['n_estimators'],
            random_state=random_state,
            # objective='Logloss', # default, accepts only one
#             custom_metrics=model_config['custom_metrics'],
    #         bootstrap_type=config['bootstrap_type'],
    #         device:config['device']
        ) 
        model.fit(X_train, y_train)
        
#     y_train_pred = model.predict(X_train)
    y_train_pred = model.predict_proba(X_train)[:,1]

    train_loss = log_loss(y_train, y_train_pred)
    train_auc = roc_auc_score(y_train, y_train_pred)
    wandb.log({'train_loss': train_loss, 'train_auc': train_auc})

    if exmodel_config['library'] == 'catboost':
        print(model.get_all_params())
        wandb.log(model.get_all_params())
    else:
        wandb.log(model.get_params()) # logging model parameters, trying bare-invocation rather than params: model.get_params()
    
    # trying with predict_proba
    y_pred = model.predict_proba(X_valid)[:,1]
#     y_pred = model.predict(X_valid)

    valid_loss = log_loss(y_valid, y_pred)
    valid_auc = roc_auc_score(y_valid, y_pred)
    wandb.log({'valid_loss':valid_loss, 'valid_auc':valid_auc})
    print(f"Valid log-loss is {valid_loss}\nValid AUC is {valid_auc}")   
#     wandb.finish()   
    return model, y_pred

# %%
random_state = 42
model_list = []
#     XGBClassifer(
#         verbosity=1,
#         n_jobs=-1,
#         objective='binary:logistic',
#         tree_method= 'gpu_hist' if (gpu_available and colab) else 'auto',
#         n_estimators=902,
#         learning_rate=0.0304,
#         max_depth=3,
#         reg_alpha = 0.863,
#         reg_lambda = 2.442,
#         subsample= 0.8627,
#         random_state=exmodel_config['random_state'],
#     ),
model_config = model_configurator('xgboost')
model_list.append(
    ('xgboost', XGBClassifier(
        tree_method=model_config['tree_method'],
        random_state=random_state,
        n_jobs=model_config['n_jobs'], 
        verbosity=model_config['verbosity'], 
        objective=model_config['objective'],
        # #             eval_metric=model_config['eval_metric'],

        # comment out the below for a fairly default model
#             booster=model_config['booster'],
        max_depth=model_config['max_depth'],
        learning_rate=model_config['learning_rate'], 
        subsample=model_config['subsample'],
        reg_alpha=model_config['reg_alpha'],
        reg_lambda=model_config['reg_lambda'],
        n_estimators=model_config['n_estimators'],
    ))
)

model_config = model_configurator('lightgbm')
model_list.append(
    ('lightgbm', LGBMClassifier(
#         verbose=model_config['verbosity'], 
        random_state=random_state,
        n_jobs=model_config['n_jobs'],
        objective=model_config['objective'],
#             eval_metric=model_config['eval_metric'],
        boosting_type=model_config['boosting_type'],
        device_type=model_config['device_type'],

        # comment out the below for a basically default model
        n_estimators=model_config['n_estimators'],
        learning_rate=model_config['learning_rate'],
        max_depth=model_config['max_depth'],
        reg_alpha=model_config['reg_alpha'],
        reg_lambda=model_config['reg_lambda'],
        subsample=model_config['subsample'],
    ))
)

model_config = model_configurator('catboost', gpu_available=False)
model_list.append(
    ('catboost', CatBoostClassifier(
#             n_estimators=config['n_estimators'],
#             learning_rate=config['learning_rate'],
#             max_depth=config['max_depth'],
        task_type=model_config['task_type'],
#         n_jobs=config['n_jobs'],
#         verbosity=config['verbosity'],
#         subsample=config['subsample'],
        n_estimators=model_config['n_estimators'],
        random_state=random_state,
                # objective='Logloss', # default, accepts only one
    #             custom_metrics=model_config['custom_metrics'],
        #         bootstrap_type=config['bootstrap_type'],
        #         device:config['device']
            ))
)

# %%
test_list = model_list[1:]

# %%
test_list
# Out:
# [('lightgbm',
#   LGBMClassifier(device_type='cpu', learning_rate=0.03221, max_depth=2,
#                  n_estimators=1286, objective='binary', random_state=42,
#                  reg_alpha=0.4687, reg_lambda=0.1763, subsample=0.6621)),
#  ('catboost', <catboost.core.CatBoostClassifier at 0x7f336c156640>)]

# %%
def super_train(model_list=model_list, 
                           X=X, 
                           y=y, 
                           start_fold=0, 
                           exmodel_config=exmodel_config, 
                           random_state=42, 
                           wandb_run=True, 
                           passthrough=False):
    """
    Function to handle model training process in the context of cross-validation -- via hold-out or via k-fold.
    If exmodel_config['cross_val_strategy'] == None, then any kfolds= input is ignored; otherwise, the number specified is used.
    
    :param kfolds: int specifying number of k-folds to use in cross-validation
    :param exmodel_config: dict containing general config including for cross-validation -- `kfold=1` implies hold-out
    """
#     if exmodel_config['kfolds'] == 1:
#         print("Proceeding with holdout")
#         X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
#                                                       test_size=exmodel_config['test_size'], 
#                                                       random_state=random_state,
#                                                      )
#         model = train(X_train, X_valid, y_train, y_valid, exmodel_config=exmodel_config, 
#                                                     model_config=model_config,
#                                                     config_run=config_run)
#         wandb.finish()
        
#     else:

    if wandb_run:
        wandb.init(
            project="202109_Kaggle_tabular_playground",
            save_code=True,
            tags=config_run['tags'],
            name=config_run['name'],
            notes=config_run['notes'],
            config=exmodel_config)  
    
    X_np, y_np = X.to_numpy(), y.to_numpy()
    # from https://machinelearningmastery.com/super-learner-ensemble-in-python/ # Super Learner for Classification
#     X_meta, y_meta = X, y # for the meta-learner; might concat the X with the data later for a passthrough=True run
#     X_baseline_preds = 
    X_meta, y_meta = [], []
    exmodel_config['kfolds'] = 5
    exmodel_config['cross_val_strategy'] = 'KFold'
    kfold = KFold(n_splits=exmodel_config['kfolds'], shuffle=True, random_state=random_state)
#     trained_models = {}
#         oof_preds = {}
#     model_path = Path(datapath/f"models/{config_run['name']}_{exmodel_config['kfolds']}folds/")
#     (model_path).mkdir(exist_ok=True)
    preds_path = Path(datapath/f"preds/{config_run['name']}_{exmodel_config['kfolds']}folds/")
    (preds_path).mkdir(exist_ok=True)
    for fold, (train_ids, valid_ids) in enumerate(kfold.split(X,y)):
        if fold < start_fold:
            continue
        else:
            fold_preds = [] # initializing the list of predictions for the fold
            print(f"FOLD {fold}")
            print("---------------------------------------------------")
            X_np, y_np = X.to_numpy(), y.to_numpy()
            
#             fold_preds = []
            # proeeding with `pd.DataFrame`s rather than `np.ndarray`s
#             X_train, X_valid = X.loc[train_ids], X.loc[valid_ids]
#             y_train, y_valid = y.loc[train_ids], y.loc[valid_ids]
            X_train, X_valid = X_np[train_ids], X_np[valid_ids]
            y_train, y_valid = y_np[train_ids], y_np[valid_ids]
            print(f"type(X_train) = {type(X_train)}")
            print(f"type(y_trian) = {type(y_train)}")
            # append the y_valid to y_meta
#             pd.concat(y_meta, y_valid, axis=0) # building this "meta" y as we go - the valid for each fold go at the bottom of the col/pd.Series
            y_meta.append(y_valid) # assumes y_meta is a list
#             y_meta = pd.concat(y_meta, pd.Series(y_valid))
            for model in model_list: # presumes tuples of the form (str, model)
                model[1].fit(X_train, y_train)
                y_train_pred = model[1].predict_proba(X_train)[:,1]

                train_loss = log_loss(y_train, y_train_pred)
                train_auc = roc_auc_score(y_train, y_train_pred)
                if wandb_run:
                    wandb.log({'train_loss': train_loss, 'train_auc': train_auc})
                    if model[0] == 'catboost':
    #                         print(model[1].get_all_params())
                        wandb.log({'catboost_params': str(model[1].get_all_params())})                        
                    else:
                        wandb.log({f'{model[0]}_params': str(model[1].get_params())}) 
                y_pred = model[1].predict_proba(X_valid)[:,1]
                fold_preds.append(y_pred.reshape(len(y_pred), 1))
                
                valid_loss = log_loss(y_valid, y_pred)
                valid_auc = roc_auc_score(y_valid, y_pred)
                
                print(f"Valid log-loss is {valid_loss}\nValid AUC is {valid_auc}")   
#                     oof_preds = super_train(X_train, X_valid, y_train, y_valid, exmodel_config=exmodel_config, 
# #                                                     model_config=model_config,
#                                                     config_run=config_run)
                
                if wandb_run:
                    wandb.log({'valid_loss':valid_loss, 'valid_auc':valid_auc})
                    wandb.log({'fold': fold})
                dump(y_pred, Path(preds_path/f"{model[0]}_fold{fold}_oof-preds.joblib"))
                
#                     models[fold] = model
#           y      preds[fold] = oof_preds
            X_meta.append(np.hstack(fold_preds))
            dump(fold_preds, Path(preds_path/f"all_fold{fold}_oof-preds.joblib"))
#                     dump(model, Path(model_path/f"{exmodel_config['library']}_fold{fold}_model.joblib"))

#                 wandb.finish()
#     return np.vstack(X_meta), np.asarray(y_meta)
    # at this point, X_meta is a length-5 list of np.ndarrays; each array has as many columns as estimators. The number of rows across folds sum to the number in the dataset.
    # meanwhile, y_meta is a length-5 list of np.ndarrays containing the labels for each fold.
    # on the way out, let's get them into the proper format
#     return X_meta, y_meta 
    return np.vstack(X_meta), np.hstack(np.asarray(y_meta))

# %%
# this will define the features and labels for the meta-learner
X_meta, y_meta = super_train(model_list, wandb_run=True)
# Out:
# wandb: Currently logged in as: hushifang (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">super-learner_manual_20210914_094720</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3kxydjbt" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3kxydjbt</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210914_094721-3kxydjbt</code><br/><br/>
# FOLD 0
# ---------------------------------------------------
# type(X_train) = <class 'numpy.ndarray'>
# type(y_trian) = <class 'numpy.ndarray'>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [09:47:30] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Valid log-loss is 0.5109356389636417
# Valid AUC is 0.8122584973566012
# Valid log-loss is 0.5113911181729013
# Valid AUC is 0.8114826365905788
# Learning rate set to 0.093011
# 0:	learn: 0.6580718	total: 138ms	remaining: 4m 35s
# 1:	learn: 0.6298703	total: 230ms	remaining: 3m 49s
# 2:	learn: 0.6072111	total: 322ms	remaining: 3m 34s
# 3:	learn: 0.5889982	total: 414ms	remaining: 3m 26s
# 4:	learn: 0.5743639	total: 513ms	remaining: 3m 24s
# 5:	learn: 0.5625637	total: 603ms	remaining: 3m 20s
# 6:	learn: 0.5530566	total: 689ms	remaining: 3m 16s
# 7:	learn: 0.5454104	total: 784ms	remaining: 3m 15s
# 8:	learn: 0.5392238	total: 882ms	remaining: 3m 15s
# 9:	learn: 0.5342211	total: 972ms	remaining: 3m 13s
# 10:	learn: 0.5301457	total: 1.06s	remaining: 3m 12s
# 11:	learn: 0.5268757	total: 1.15s	remaining: 3m 11s
# 12:	learn: 0.5242039	total: 1.24s	remaining: 3m 9s
# 13:	learn: 0.5220363	total: 1.33s	remaining: 3m 8s
# 14:	learn: 0.5202507	total: 1.42s	remaining: 3m 7s
# 15:	learn: 0.5188851	total: 1.5s	remaining: 3m 6s
# 16:	learn: 0.5176763	total: 1.59s	remaining: 3m 5s
# 17:	learn: 0.5167425	total: 1.68s	remaining: 3m 5s
# 18:	learn: 0.5159180	total: 1.78s	remaining: 3m 5s
# 19:	learn: 0.5152346	total: 1.87s	remaining: 3m 4s
# 20:	learn: 0.5146921	total: 1.96s	remaining: 3m 4s
# 21:	learn: 0.5142470	total: 2.05s	remaining: 3m 3s
# 22:	learn: 0.5138785	total: 2.13s	remaining: 3m 3s
# 23:	learn: 0.5135251	total: 2.21s	remaining: 3m 2s
# 24:	learn: 0.5132441	total: 2.3s	remaining: 3m 1s
# 25:	learn: 0.5130166	total: 2.39s	remaining: 3m 1s
# 26:	learn: 0.5128093	total: 2.48s	remaining: 3m 1s
# 27:	learn: 0.5126455	total: 2.57s	remaining: 3m
# 28:	learn: 0.5124710	total: 2.66s	remaining: 3m
# 29:	learn: 0.5123086	total: 2.75s	remaining: 3m
# 30:	learn: 0.5121819	total: 2.84s	remaining: 3m
# 31:	learn: 0.5120554	total: 2.93s	remaining: 3m
# 32:	learn: 0.5119419	total: 3.01s	remaining: 2m 59s
# 33:	learn: 0.5118495	total: 3.09s	remaining: 2m 58s
# 34:	learn: 0.5117441	total: 3.18s	remaining: 2m 58s
# 35:	learn: 0.5116619	total: 3.27s	remaining: 2m 58s
# 36:	learn: 0.5115803	total: 3.35s	remaining: 2m 57s
# 37:	learn: 0.5115052	total: 3.45s	remaining: 2m 57s
# 38:	learn: 0.5114414	total: 3.53s	remaining: 2m 57s
# 39:	learn: 0.5113737	total: 3.62s	remaining: 2m 57s
# 40:	learn: 0.5113226	total: 3.71s	remaining: 2m 57s
# 41:	learn: 0.5112584	total: 3.79s	remaining: 2m 56s
# 42:	learn: 0.5112094	total: 3.88s	remaining: 2m 56s
# 43:	learn: 0.5111644	total: 3.97s	remaining: 2m 56s
# 44:	learn: 0.5111160	total: 4.05s	remaining: 2m 56s
# 45:	learn: 0.5110580	total: 4.14s	remaining: 2m 55s
# 46:	learn: 0.5110091	total: 4.23s	remaining: 2m 55s
# 47:	learn: 0.5109592	total: 4.32s	remaining: 2m 55s
# 48:	learn: 0.5109098	total: 4.42s	remaining: 2m 55s
# 49:	learn: 0.5108653	total: 4.51s	remaining: 2m 56s
# 50:	learn: 0.5108186	total: 4.61s	remaining: 2m 56s
# 51:	learn: 0.5107718	total: 4.71s	remaining: 2m 56s
# 52:	learn: 0.5107374	total: 4.8s	remaining: 2m 56s
# 53:	learn: 0.5106943	total: 4.91s	remaining: 2m 56s
# 54:	learn: 0.5106512	total: 5s	remaining: 2m 56s
# 55:	learn: 0.5106198	total: 5.08s	remaining: 2m 56s
# 56:	learn: 0.5105798	total: 5.17s	remaining: 2m 56s
# 57:	learn: 0.5105370	total: 5.26s	remaining: 2m 56s
# 58:	learn: 0.5105046	total: 5.35s	remaining: 2m 55s
# 59:	learn: 0.5104673	total: 5.44s	remaining: 2m 56s
# 60:	learn: 0.5104315	total: 5.52s	remaining: 2m 55s
# 61:	learn: 0.5103915	total: 5.61s	remaining: 2m 55s
# 62:	learn: 0.5103493	total: 5.69s	remaining: 2m 54s
# 63:	learn: 0.5103083	total: 5.78s	remaining: 2m 54s
# 64:	learn: 0.5102768	total: 5.87s	remaining: 2m 54s
# 65:	learn: 0.5102416	total: 5.95s	remaining: 2m 54s
# 66:	learn: 0.5102068	total: 6.04s	remaining: 2m 54s
# 67:	learn: 0.5101693	total: 6.12s	remaining: 2m 53s
# 68:	learn: 0.5101361	total: 6.21s	remaining: 2m 53s
# 69:	learn: 0.5101040	total: 6.3s	remaining: 2m 53s
# 70:	learn: 0.5100726	total: 6.39s	remaining: 2m 53s
# 71:	learn: 0.5100347	total: 6.48s	remaining: 2m 53s
# 72:	learn: 0.5100024	total: 6.56s	remaining: 2m 53s
# 73:	learn: 0.5099751	total: 6.65s	remaining: 2m 53s
# 74:	learn: 0.5099435	total: 6.74s	remaining: 2m 52s
# 75:	learn: 0.5099129	total: 6.84s	remaining: 2m 53s
# 76:	learn: 0.5098832	total: 6.92s	remaining: 2m 52s
# 77:	learn: 0.5098497	total: 7.01s	remaining: 2m 52s
# 78:	learn: 0.5098175	total: 7.1s	remaining: 2m 52s
# 79:	learn: 0.5097855	total: 7.18s	remaining: 2m 52s
# 80:	learn: 0.5097554	total: 7.27s	remaining: 2m 52s
# 81:	learn: 0.5097264	total: 7.35s	remaining: 2m 51s
# 82:	learn: 0.5096965	total: 7.44s	remaining: 2m 51s
# 83:	learn: 0.5096669	total: 7.53s	remaining: 2m 51s
# 84:	learn: 0.5096372	total: 7.62s	remaining: 2m 51s
# 85:	learn: 0.5096041	total: 7.7s	remaining: 2m 51s
# 86:	learn: 0.5095754	total: 7.79s	remaining: 2m 51s
# 87:	learn: 0.5095412	total: 7.89s	remaining: 2m 51s
# 88:	learn: 0.5095108	total: 7.98s	remaining: 2m 51s
# 89:	learn: 0.5094720	total: 8.07s	remaining: 2m 51s
# 90:	learn: 0.5094467	total: 8.16s	remaining: 2m 51s
# 91:	learn: 0.5094223	total: 8.24s	remaining: 2m 50s
# 92:	learn: 0.5093921	total: 8.33s	remaining: 2m 50s
# 93:	learn: 0.5093638	total: 8.42s	remaining: 2m 50s
# 94:	learn: 0.5093372	total: 8.51s	remaining: 2m 50s
# 95:	learn: 0.5093101	total: 8.6s	remaining: 2m 50s
# 96:	learn: 0.5092839	total: 8.69s	remaining: 2m 50s
# 97:	learn: 0.5092577	total: 8.79s	remaining: 2m 50s
# 98:	learn: 0.5092339	total: 8.89s	remaining: 2m 50s
# 99:	learn: 0.5092133	total: 8.97s	remaining: 2m 50s
# 100:	learn: 0.5091843	total: 9.05s	remaining: 2m 50s
# 101:	learn: 0.5091576	total: 9.13s	remaining: 2m 49s
# 102:	learn: 0.5091308	total: 9.22s	remaining: 2m 49s
# 103:	learn: 0.5090967	total: 9.3s	remaining: 2m 49s
# 104:	learn: 0.5090700	total: 9.39s	remaining: 2m 49s
# 105:	learn: 0.5090417	total: 9.48s	remaining: 2m 49s
# 106:	learn: 0.5090174	total: 9.57s	remaining: 2m 49s
# 107:	learn: 0.5089946	total: 9.66s	remaining: 2m 49s
# 108:	learn: 0.5089712	total: 9.75s	remaining: 2m 49s
# 109:	learn: 0.5089326	total: 9.83s	remaining: 2m 48s
# 110:	learn: 0.5089072	total: 9.93s	remaining: 2m 48s
# 111:	learn: 0.5088812	total: 10s	remaining: 2m 48s
# 112:	learn: 0.5088516	total: 10.1s	remaining: 2m 48s
# 113:	learn: 0.5088283	total: 10.2s	remaining: 2m 48s
# 114:	learn: 0.5088022	total: 10.3s	remaining: 2m 48s
# 115:	learn: 0.5087754	total: 10.4s	remaining: 2m 48s
# 116:	learn: 0.5087504	total: 10.5s	remaining: 2m 48s
# 117:	learn: 0.5087275	total: 10.5s	remaining: 2m 48s
# 118:	learn: 0.5087025	total: 10.6s	remaining: 2m 48s
# 119:	learn: 0.5086789	total: 10.7s	remaining: 2m 48s
# 120:	learn: 0.5086579	total: 10.8s	remaining: 2m 47s
# 121:	learn: 0.5086347	total: 10.9s	remaining: 2m 48s
# 122:	learn: 0.5086151	total: 11s	remaining: 2m 47s
# 123:	learn: 0.5085935	total: 11.1s	remaining: 2m 47s
# 124:	learn: 0.5085704	total: 11.2s	remaining: 2m 47s
# 125:	learn: 0.5085403	total: 11.3s	remaining: 2m 47s
# 126:	learn: 0.5085187	total: 11.4s	remaining: 2m 47s
# 127:	learn: 0.5084947	total: 11.5s	remaining: 2m 47s
# 128:	learn: 0.5084647	total: 11.5s	remaining: 2m 47s
# 129:	learn: 0.5084420	total: 11.6s	remaining: 2m 47s
# 130:	learn: 0.5084205	total: 11.7s	remaining: 2m 47s
# 131:	learn: 0.5083981	total: 11.8s	remaining: 2m 47s
# 132:	learn: 0.5083727	total: 11.9s	remaining: 2m 47s
# 133:	learn: 0.5083504	total: 12s	remaining: 2m 46s
# 134:	learn: 0.5083262	total: 12.1s	remaining: 2m 46s
# 135:	learn: 0.5083002	total: 12.2s	remaining: 2m 46s
# 136:	learn: 0.5082773	total: 12.2s	remaining: 2m 46s
# 137:	learn: 0.5082519	total: 12.3s	remaining: 2m 46s
# 138:	learn: 0.5082289	total: 12.4s	remaining: 2m 46s
# 139:	learn: 0.5082058	total: 12.5s	remaining: 2m 46s
# 140:	learn: 0.5081843	total: 12.6s	remaining: 2m 45s
# 141:	learn: 0.5081613	total: 12.7s	remaining: 2m 45s
# 142:	learn: 0.5081431	total: 12.8s	remaining: 2m 45s
# 143:	learn: 0.5081184	total: 12.8s	remaining: 2m 45s
# 144:	learn: 0.5080952	total: 12.9s	remaining: 2m 45s
# 145:	learn: 0.5080702	total: 13s	remaining: 2m 45s
# 146:	learn: 0.5080470	total: 13.1s	remaining: 2m 45s
# 147:	learn: 0.5080245	total: 13.2s	remaining: 2m 45s
# 148:	learn: 0.5079829	total: 13.3s	remaining: 2m 44s
# 149:	learn: 0.5079578	total: 13.4s	remaining: 2m 44s
# 150:	learn: 0.5079328	total: 13.5s	remaining: 2m 44s
# 151:	learn: 0.5079087	total: 13.5s	remaining: 2m 44s
# 152:	learn: 0.5078805	total: 13.6s	remaining: 2m 44s
# 153:	learn: 0.5078562	total: 13.7s	remaining: 2m 44s
# 154:	learn: 0.5078246	total: 13.8s	remaining: 2m 44s
# 155:	learn: 0.5077970	total: 13.9s	remaining: 2m 44s
# 156:	learn: 0.5077646	total: 14s	remaining: 2m 44s
# 157:	learn: 0.5077371	total: 14.1s	remaining: 2m 44s
# 158:	learn: 0.5077080	total: 14.2s	remaining: 2m 44s
# 159:	learn: 0.5076820	total: 14.3s	remaining: 2m 44s
# 160:	learn: 0.5076568	total: 14.3s	remaining: 2m 43s
# 161:	learn: 0.5076306	total: 14.4s	remaining: 2m 43s
# 162:	learn: 0.5076051	total: 14.5s	remaining: 2m 43s
# 163:	learn: 0.5075802	total: 14.6s	remaining: 2m 43s
# 164:	learn: 0.5075363	total: 14.7s	remaining: 2m 43s
# 165:	learn: 0.5075076	total: 14.8s	remaining: 2m 43s
# 166:	learn: 0.5074838	total: 14.9s	remaining: 2m 43s
# 167:	learn: 0.5074553	total: 15s	remaining: 2m 43s
# 168:	learn: 0.5074278	total: 15.1s	remaining: 2m 43s
# 169:	learn: 0.5074017	total: 15.1s	remaining: 2m 42s
# 170:	learn: 0.5073699	total: 15.2s	remaining: 2m 42s
# 171:	learn: 0.5073416	total: 15.3s	remaining: 2m 42s
# 172:	learn: 0.5073149	total: 15.4s	remaining: 2m 42s
# 173:	learn: 0.5072891	total: 15.5s	remaining: 2m 42s
# 174:	learn: 0.5072598	total: 15.6s	remaining: 2m 42s
# 175:	learn: 0.5072337	total: 15.7s	remaining: 2m 42s
# 176:	learn: 0.5072062	total: 15.8s	remaining: 2m 42s
# 177:	learn: 0.5071801	total: 15.9s	remaining: 2m 42s
# 178:	learn: 0.5071554	total: 15.9s	remaining: 2m 42s
# 179:	learn: 0.5071263	total: 16s	remaining: 2m 42s
# 180:	learn: 0.5070958	total: 16.1s	remaining: 2m 41s
# 181:	learn: 0.5070692	total: 16.2s	remaining: 2m 41s
# 182:	learn: 0.5070392	total: 16.3s	remaining: 2m 41s
# 183:	learn: 0.5070130	total: 16.4s	remaining: 2m 41s
# 184:	learn: 0.5069870	total: 16.5s	remaining: 2m 41s
# 185:	learn: 0.5069630	total: 16.6s	remaining: 2m 41s
# 186:	learn: 0.5069393	total: 16.7s	remaining: 2m 41s
# 187:	learn: 0.5069142	total: 16.7s	remaining: 2m 41s
# 188:	learn: 0.5068898	total: 16.8s	remaining: 2m 41s
# 189:	learn: 0.5068619	total: 16.9s	remaining: 2m 41s
# 190:	learn: 0.5068376	total: 17s	remaining: 2m 41s
# 191:	learn: 0.5068129	total: 17.1s	remaining: 2m 40s
# 192:	learn: 0.5067874	total: 17.2s	remaining: 2m 40s
# 193:	learn: 0.5067629	total: 17.3s	remaining: 2m 40s
# 194:	learn: 0.5067339	total: 17.4s	remaining: 2m 40s
# 195:	learn: 0.5067051	total: 17.4s	remaining: 2m 40s
# 196:	learn: 0.5066769	total: 17.5s	remaining: 2m 40s
# 197:	learn: 0.5066496	total: 17.6s	remaining: 2m 40s
# 198:	learn: 0.5066240	total: 17.7s	remaining: 2m 40s
# 199:	learn: 0.5065996	total: 17.8s	remaining: 2m 40s
# 200:	learn: 0.5065662	total: 17.9s	remaining: 2m 39s
# 201:	learn: 0.5065404	total: 18s	remaining: 2m 39s
# 202:	learn: 0.5065125	total: 18.1s	remaining: 2m 39s
# 203:	learn: 0.5064871	total: 18.1s	remaining: 2m 39s
# 204:	learn: 0.5064606	total: 18.2s	remaining: 2m 39s
# 205:	learn: 0.5064368	total: 18.3s	remaining: 2m 39s
# 206:	learn: 0.5064109	total: 18.4s	remaining: 2m 39s
# 207:	learn: 0.5063835	total: 18.5s	remaining: 2m 39s
# 208:	learn: 0.5063604	total: 18.6s	remaining: 2m 39s
# 209:	learn: 0.5063356	total: 18.6s	remaining: 2m 38s
# 210:	learn: 0.5063114	total: 18.7s	remaining: 2m 38s
# 211:	learn: 0.5062829	total: 18.8s	remaining: 2m 38s
# 212:	learn: 0.5062574	total: 18.9s	remaining: 2m 38s
# 213:	learn: 0.5062347	total: 19s	remaining: 2m 38s
# 214:	learn: 0.5062105	total: 19.1s	remaining: 2m 38s
# 215:	learn: 0.5061837	total: 19.2s	remaining: 2m 38s
# 216:	learn: 0.5061600	total: 19.3s	remaining: 2m 38s
# 217:	learn: 0.5061373	total: 19.4s	remaining: 2m 38s
# 218:	learn: 0.5061143	total: 19.5s	remaining: 2m 38s
# 219:	learn: 0.5060912	total: 19.5s	remaining: 2m 38s
# 220:	learn: 0.5060678	total: 19.6s	remaining: 2m 37s
# 221:	learn: 0.5060435	total: 19.7s	remaining: 2m 37s
# 222:	learn: 0.5060161	total: 19.8s	remaining: 2m 37s
# 223:	learn: 0.5059916	total: 19.9s	remaining: 2m 37s
# 224:	learn: 0.5059689	total: 20s	remaining: 2m 37s
# 225:	learn: 0.5059462	total: 20.1s	remaining: 2m 37s
# 226:	learn: 0.5059209	total: 20.2s	remaining: 2m 37s
# 227:	learn: 0.5058960	total: 20.2s	remaining: 2m 37s
# 228:	learn: 0.5058712	total: 20.3s	remaining: 2m 37s
# 229:	learn: 0.5058469	total: 20.4s	remaining: 2m 37s
# 230:	learn: 0.5058210	total: 20.5s	remaining: 2m 37s
# 231:	learn: 0.5057993	total: 20.6s	remaining: 2m 36s
# 232:	learn: 0.5057724	total: 20.7s	remaining: 2m 36s
# 233:	learn: 0.5057489	total: 20.8s	remaining: 2m 36s
# 234:	learn: 0.5057258	total: 20.9s	remaining: 2m 36s
# 235:	learn: 0.5057052	total: 21s	remaining: 2m 36s
# 236:	learn: 0.5056787	total: 21s	remaining: 2m 36s
# 237:	learn: 0.5056548	total: 21.1s	remaining: 2m 36s
# 238:	learn: 0.5056302	total: 21.2s	remaining: 2m 36s
# 239:	learn: 0.5056031	total: 21.3s	remaining: 2m 36s
# 240:	learn: 0.5055808	total: 21.4s	remaining: 2m 36s
# 241:	learn: 0.5055608	total: 21.5s	remaining: 2m 36s
# 242:	learn: 0.5055371	total: 21.6s	remaining: 2m 35s
# 243:	learn: 0.5055139	total: 21.7s	remaining: 2m 35s
# 244:	learn: 0.5054895	total: 21.7s	remaining: 2m 35s
# 245:	learn: 0.5054677	total: 21.8s	remaining: 2m 35s
# 246:	learn: 0.5054436	total: 21.9s	remaining: 2m 35s
# 247:	learn: 0.5054190	total: 22s	remaining: 2m 35s
# 248:	learn: 0.5053951	total: 22.1s	remaining: 2m 35s
# 249:	learn: 0.5053721	total: 22.2s	remaining: 2m 35s
# 250:	learn: 0.5053537	total: 22.3s	remaining: 2m 35s
# 251:	learn: 0.5053319	total: 22.4s	remaining: 2m 35s
# 252:	learn: 0.5053104	total: 22.4s	remaining: 2m 34s
# 253:	learn: 0.5052885	total: 22.5s	remaining: 2m 34s
# 254:	learn: 0.5052627	total: 22.6s	remaining: 2m 34s
# 255:	learn: 0.5052407	total: 22.7s	remaining: 2m 34s
# 256:	learn: 0.5052162	total: 22.8s	remaining: 2m 34s
# 257:	learn: 0.5051953	total: 22.9s	remaining: 2m 34s
# 258:	learn: 0.5051702	total: 23s	remaining: 2m 34s
# 259:	learn: 0.5051470	total: 23.1s	remaining: 2m 34s
# 260:	learn: 0.5051254	total: 23.2s	remaining: 2m 34s
# 261:	learn: 0.5051006	total: 23.3s	remaining: 2m 34s
# 262:	learn: 0.5050757	total: 23.4s	remaining: 2m 34s
# 263:	learn: 0.5050522	total: 23.4s	remaining: 2m 34s
# 264:	learn: 0.5050292	total: 23.5s	remaining: 2m 34s
# 265:	learn: 0.5050071	total: 23.6s	remaining: 2m 33s
# 266:	learn: 0.5049829	total: 23.7s	remaining: 2m 33s
# 267:	learn: 0.5049643	total: 23.8s	remaining: 2m 33s
# 268:	learn: 0.5049390	total: 23.9s	remaining: 2m 33s
# 269:	learn: 0.5049182	total: 24s	remaining: 2m 33s
# 270:	learn: 0.5048972	total: 24s	remaining: 2m 33s
# 271:	learn: 0.5048753	total: 24.1s	remaining: 2m 33s
# 272:	learn: 0.5048508	total: 24.2s	remaining: 2m 33s
# 273:	learn: 0.5048270	total: 24.3s	remaining: 2m 33s
# 274:	learn: 0.5048056	total: 24.4s	remaining: 2m 33s
# 275:	learn: 0.5047815	total: 24.5s	remaining: 2m 33s
# 276:	learn: 0.5047554	total: 24.6s	remaining: 2m 32s
# 277:	learn: 0.5047310	total: 24.7s	remaining: 2m 32s
# 278:	learn: 0.5047099	total: 24.8s	remaining: 2m 32s
# 279:	learn: 0.5046866	total: 24.8s	remaining: 2m 32s
# 280:	learn: 0.5046647	total: 24.9s	remaining: 2m 32s
# 281:	learn: 0.5046433	total: 25s	remaining: 2m 32s
# 282:	learn: 0.5046208	total: 25.1s	remaining: 2m 32s
# 283:	learn: 0.5045996	total: 25.2s	remaining: 2m 32s
# 284:	learn: 0.5045790	total: 25.3s	remaining: 2m 32s
# 285:	learn: 0.5045591	total: 25.4s	remaining: 2m 32s
# 286:	learn: 0.5045381	total: 25.5s	remaining: 2m 31s
# 287:	learn: 0.5045201	total: 25.5s	remaining: 2m 31s
# 288:	learn: 0.5044975	total: 25.6s	remaining: 2m 31s
# 289:	learn: 0.5044751	total: 25.7s	remaining: 2m 31s
# 290:	learn: 0.5044523	total: 25.8s	remaining: 2m 31s
# 291:	learn: 0.5044280	total: 25.9s	remaining: 2m 31s
# 292:	learn: 0.5044051	total: 26s	remaining: 2m 31s
# 293:	learn: 0.5043850	total: 26.1s	remaining: 2m 31s
# 294:	learn: 0.5043656	total: 26.2s	remaining: 2m 31s
# 295:	learn: 0.5043419	total: 26.3s	remaining: 2m 31s
# 296:	learn: 0.5043183	total: 26.3s	remaining: 2m 31s
# 297:	learn: 0.5042986	total: 26.4s	remaining: 2m 30s
# 298:	learn: 0.5042763	total: 26.5s	remaining: 2m 30s
# 299:	learn: 0.5042533	total: 26.6s	remaining: 2m 30s
# 300:	learn: 0.5042336	total: 26.7s	remaining: 2m 30s
# 301:	learn: 0.5042141	total: 26.8s	remaining: 2m 30s
# 302:	learn: 0.5041955	total: 26.9s	remaining: 2m 30s
# 303:	learn: 0.5041732	total: 26.9s	remaining: 2m 30s
# 304:	learn: 0.5041523	total: 27s	remaining: 2m 30s
# 305:	learn: 0.5041301	total: 27.1s	remaining: 2m 30s
# 306:	learn: 0.5041115	total: 27.2s	remaining: 2m 30s
# 307:	learn: 0.5040881	total: 27.3s	remaining: 2m 30s
# 308:	learn: 0.5040678	total: 27.4s	remaining: 2m 29s
# 309:	learn: 0.5040450	total: 27.5s	remaining: 2m 29s
# 310:	learn: 0.5040225	total: 27.6s	remaining: 2m 29s
# 311:	learn: 0.5039971	total: 27.7s	remaining: 2m 29s
# 312:	learn: 0.5039753	total: 27.8s	remaining: 2m 29s
# 313:	learn: 0.5039513	total: 27.9s	remaining: 2m 29s
# 314:	learn: 0.5039336	total: 27.9s	remaining: 2m 29s
# 315:	learn: 0.5039127	total: 28s	remaining: 2m 29s
# 316:	learn: 0.5038944	total: 28.1s	remaining: 2m 29s
# 317:	learn: 0.5038718	total: 28.2s	remaining: 2m 29s
# 318:	learn: 0.5038508	total: 28.3s	remaining: 2m 29s
# 319:	learn: 0.5038286	total: 28.4s	remaining: 2m 29s
# 320:	learn: 0.5038072	total: 28.5s	remaining: 2m 28s
# 321:	learn: 0.5037862	total: 28.6s	remaining: 2m 28s
# 322:	learn: 0.5037649	total: 28.6s	remaining: 2m 28s
# 323:	learn: 0.5037439	total: 28.7s	remaining: 2m 28s
# 324:	learn: 0.5037217	total: 28.8s	remaining: 2m 28s
# 325:	learn: 0.5036991	total: 28.9s	remaining: 2m 28s
# 326:	learn: 0.5036750	total: 29s	remaining: 2m 28s
# 327:	learn: 0.5036551	total: 29.1s	remaining: 2m 28s
# 328:	learn: 0.5036307	total: 29.2s	remaining: 2m 28s
# 329:	learn: 0.5036083	total: 29.3s	remaining: 2m 28s
# 330:	learn: 0.5035852	total: 29.4s	remaining: 2m 28s
# 331:	learn: 0.5035606	total: 29.5s	remaining: 2m 27s
# 332:	learn: 0.5035374	total: 29.5s	remaining: 2m 27s
# 333:	learn: 0.5035151	total: 29.6s	remaining: 2m 27s
# 334:	learn: 0.5034941	total: 29.7s	remaining: 2m 27s
# 335:	learn: 0.5034699	total: 29.8s	remaining: 2m 27s
# 336:	learn: 0.5034457	total: 29.9s	remaining: 2m 27s
# 337:	learn: 0.5034259	total: 30s	remaining: 2m 27s
# 338:	learn: 0.5034052	total: 30.1s	remaining: 2m 27s
# 339:	learn: 0.5033864	total: 30.2s	remaining: 2m 27s
# 340:	learn: 0.5033667	total: 30.3s	remaining: 2m 27s
# 341:	learn: 0.5033440	total: 30.4s	remaining: 2m 27s
# 342:	learn: 0.5033241	total: 30.4s	remaining: 2m 27s
# 343:	learn: 0.5033025	total: 30.5s	remaining: 2m 27s
# 344:	learn: 0.5032809	total: 30.6s	remaining: 2m 26s
# 345:	learn: 0.5032586	total: 30.7s	remaining: 2m 26s
# 346:	learn: 0.5032391	total: 30.8s	remaining: 2m 26s
# 347:	learn: 0.5032144	total: 30.9s	remaining: 2m 26s
# 348:	learn: 0.5031970	total: 31s	remaining: 2m 26s
# 349:	learn: 0.5031744	total: 31.1s	remaining: 2m 26s
# 350:	learn: 0.5031514	total: 31.2s	remaining: 2m 26s
# 351:	learn: 0.5031289	total: 31.3s	remaining: 2m 26s
# 352:	learn: 0.5031075	total: 31.4s	remaining: 2m 26s
# 353:	learn: 0.5030882	total: 31.4s	remaining: 2m 26s
# 354:	learn: 0.5030698	total: 31.5s	remaining: 2m 26s
# 355:	learn: 0.5030516	total: 31.6s	remaining: 2m 25s
# 356:	learn: 0.5030338	total: 31.7s	remaining: 2m 25s
# 357:	learn: 0.5030118	total: 31.8s	remaining: 2m 25s
# 358:	learn: 0.5029897	total: 31.9s	remaining: 2m 25s
# 359:	learn: 0.5029680	total: 32s	remaining: 2m 25s
# 360:	learn: 0.5029501	total: 32s	remaining: 2m 25s
# 361:	learn: 0.5029309	total: 32.1s	remaining: 2m 25s
# 362:	learn: 0.5029106	total: 32.2s	remaining: 2m 25s
# 363:	learn: 0.5028917	total: 32.3s	remaining: 2m 25s
# 364:	learn: 0.5028730	total: 32.4s	remaining: 2m 25s
# 365:	learn: 0.5028565	total: 32.5s	remaining: 2m 24s
# 366:	learn: 0.5028349	total: 32.5s	remaining: 2m 24s
# 367:	learn: 0.5028161	total: 32.6s	remaining: 2m 24s
# 368:	learn: 0.5027953	total: 32.7s	remaining: 2m 24s
# 369:	learn: 0.5027770	total: 32.8s	remaining: 2m 24s
# 370:	learn: 0.5027575	total: 32.9s	remaining: 2m 24s
# 371:	learn: 0.5027368	total: 33s	remaining: 2m 24s
# 372:	learn: 0.5027149	total: 33.1s	remaining: 2m 24s
# 373:	learn: 0.5026932	total: 33.2s	remaining: 2m 24s
# 374:	learn: 0.5026734	total: 33.3s	remaining: 2m 24s
# 375:	learn: 0.5026515	total: 33.3s	remaining: 2m 24s
# 376:	learn: 0.5026309	total: 33.4s	remaining: 2m 23s
# 377:	learn: 0.5026111	total: 33.5s	remaining: 2m 23s
# 378:	learn: 0.5025903	total: 33.6s	remaining: 2m 23s
# 379:	learn: 0.5025687	total: 33.7s	remaining: 2m 23s
# 380:	learn: 0.5025482	total: 33.8s	remaining: 2m 23s
# 381:	learn: 0.5025243	total: 33.9s	remaining: 2m 23s
# 382:	learn: 0.5025029	total: 34s	remaining: 2m 23s
# 383:	learn: 0.5024825	total: 34.1s	remaining: 2m 23s
# 384:	learn: 0.5024648	total: 34.1s	remaining: 2m 23s
# 385:	learn: 0.5024437	total: 34.2s	remaining: 2m 23s
# 386:	learn: 0.5024237	total: 34.3s	remaining: 2m 23s
# 387:	learn: 0.5024050	total: 34.4s	remaining: 2m 22s
# 388:	learn: 0.5023868	total: 34.5s	remaining: 2m 22s
# 389:	learn: 0.5023683	total: 34.6s	remaining: 2m 22s
# 390:	learn: 0.5023496	total: 34.7s	remaining: 2m 22s
# 391:	learn: 0.5023285	total: 34.8s	remaining: 2m 22s
# 392:	learn: 0.5023133	total: 34.9s	remaining: 2m 22s
# 393:	learn: 0.5022950	total: 34.9s	remaining: 2m 22s
# 394:	learn: 0.5022742	total: 35s	remaining: 2m 22s
# 395:	learn: 0.5022540	total: 35.1s	remaining: 2m 22s
# 396:	learn: 0.5022343	total: 35.2s	remaining: 2m 22s
# 397:	learn: 0.5022138	total: 35.3s	remaining: 2m 21s
# 398:	learn: 0.5021925	total: 35.4s	remaining: 2m 21s
# 399:	learn: 0.5021708	total: 35.5s	remaining: 2m 21s
# 400:	learn: 0.5021490	total: 35.6s	remaining: 2m 21s
# 401:	learn: 0.5021267	total: 35.7s	remaining: 2m 21s
# 402:	learn: 0.5021072	total: 35.8s	remaining: 2m 21s
# 403:	learn: 0.5020856	total: 35.9s	remaining: 2m 21s
# 404:	learn: 0.5020660	total: 36s	remaining: 2m 21s
# 405:	learn: 0.5020462	total: 36.1s	remaining: 2m 21s
# 406:	learn: 0.5020263	total: 36.1s	remaining: 2m 21s
# 407:	learn: 0.5020046	total: 36.2s	remaining: 2m 21s
# 408:	learn: 0.5019823	total: 36.3s	remaining: 2m 21s
# 409:	learn: 0.5019619	total: 36.4s	remaining: 2m 21s
# 410:	learn: 0.5019419	total: 36.5s	remaining: 2m 21s
# 411:	learn: 0.5019258	total: 36.6s	remaining: 2m 20s
# 412:	learn: 0.5019059	total: 36.7s	remaining: 2m 20s
# 413:	learn: 0.5018867	total: 36.7s	remaining: 2m 20s
# 414:	learn: 0.5018654	total: 36.8s	remaining: 2m 20s
# 415:	learn: 0.5018481	total: 36.9s	remaining: 2m 20s
# 416:	learn: 0.5018286	total: 37s	remaining: 2m 20s
# 417:	learn: 0.5018054	total: 37.1s	remaining: 2m 20s
# 418:	learn: 0.5017843	total: 37.2s	remaining: 2m 20s
# 419:	learn: 0.5017668	total: 37.3s	remaining: 2m 20s
# 420:	learn: 0.5017477	total: 37.3s	remaining: 2m 20s
# 421:	learn: 0.5017250	total: 37.4s	remaining: 2m 19s
# 422:	learn: 0.5017029	total: 37.5s	remaining: 2m 19s
# 423:	learn: 0.5016844	total: 37.6s	remaining: 2m 19s
# 424:	learn: 0.5016654	total: 37.7s	remaining: 2m 19s
# 425:	learn: 0.5016454	total: 37.8s	remaining: 2m 19s
# 426:	learn: 0.5016268	total: 37.9s	remaining: 2m 19s
# 427:	learn: 0.5016060	total: 38s	remaining: 2m 19s
# 428:	learn: 0.5015852	total: 38.1s	remaining: 2m 19s
# 429:	learn: 0.5015645	total: 38.1s	remaining: 2m 19s
# 430:	learn: 0.5015457	total: 38.2s	remaining: 2m 19s
# 431:	learn: 0.5015252	total: 38.3s	remaining: 2m 19s
# 432:	learn: 0.5015039	total: 38.4s	remaining: 2m 19s
# 433:	learn: 0.5014842	total: 38.5s	remaining: 2m 18s
# 434:	learn: 0.5014626	total: 38.6s	remaining: 2m 18s
# 435:	learn: 0.5014430	total: 38.7s	remaining: 2m 18s
# 436:	learn: 0.5014209	total: 38.8s	remaining: 2m 18s
# 437:	learn: 0.5014024	total: 38.8s	remaining: 2m 18s
# 438:	learn: 0.5013821	total: 38.9s	remaining: 2m 18s
# 439:	learn: 0.5013598	total: 39s	remaining: 2m 18s
# 440:	learn: 0.5013380	total: 39.1s	remaining: 2m 18s
# 441:	learn: 0.5013153	total: 39.2s	remaining: 2m 18s
# 442:	learn: 0.5012933	total: 39.3s	remaining: 2m 18s
# 443:	learn: 0.5012767	total: 39.4s	remaining: 2m 18s
# 444:	learn: 0.5012586	total: 39.5s	remaining: 2m 17s
# 445:	learn: 0.5012374	total: 39.6s	remaining: 2m 17s
# 446:	learn: 0.5012173	total: 39.6s	remaining: 2m 17s
# 447:	learn: 0.5011974	total: 39.7s	remaining: 2m 17s
# 448:	learn: 0.5011798	total: 39.8s	remaining: 2m 17s
# 449:	learn: 0.5011592	total: 39.9s	remaining: 2m 17s
# 450:	learn: 0.5011398	total: 40s	remaining: 2m 17s
# 451:	learn: 0.5011193	total: 40.1s	remaining: 2m 17s
# 452:	learn: 0.5011043	total: 40.2s	remaining: 2m 17s
# 453:	learn: 0.5010829	total: 40.3s	remaining: 2m 17s
# 454:	learn: 0.5010621	total: 40.4s	remaining: 2m 17s
# 455:	learn: 0.5010427	total: 40.4s	remaining: 2m 16s
# 456:	learn: 0.5010252	total: 40.5s	remaining: 2m 16s
# 457:	learn: 0.5010050	total: 40.6s	remaining: 2m 16s
# 458:	learn: 0.5009844	total: 40.7s	remaining: 2m 16s
# 459:	learn: 0.5009638	total: 40.8s	remaining: 2m 16s
# 460:	learn: 0.5009435	total: 40.9s	remaining: 2m 16s
# 461:	learn: 0.5009243	total: 41s	remaining: 2m 16s
# 462:	learn: 0.5009042	total: 41.1s	remaining: 2m 16s
# 463:	learn: 0.5008878	total: 41.2s	remaining: 2m 16s
# 464:	learn: 0.5008647	total: 41.3s	remaining: 2m 16s
# 465:	learn: 0.5008466	total: 41.3s	remaining: 2m 16s
# 466:	learn: 0.5008298	total: 41.4s	remaining: 2m 16s
# 467:	learn: 0.5008124	total: 41.5s	remaining: 2m 15s
# 468:	learn: 0.5007961	total: 41.6s	remaining: 2m 15s
# 469:	learn: 0.5007760	total: 41.7s	remaining: 2m 15s
# 470:	learn: 0.5007558	total: 41.8s	remaining: 2m 15s
# 471:	learn: 0.5007323	total: 41.9s	remaining: 2m 15s
# 472:	learn: 0.5007118	total: 42s	remaining: 2m 15s
# 473:	learn: 0.5006924	total: 42.1s	remaining: 2m 15s
# 474:	learn: 0.5006698	total: 42.2s	remaining: 2m 15s
# 475:	learn: 0.5006503	total: 42.2s	remaining: 2m 15s
# 476:	learn: 0.5006289	total: 42.3s	remaining: 2m 15s
# 477:	learn: 0.5006109	total: 42.4s	remaining: 2m 15s
# 478:	learn: 0.5005878	total: 42.5s	remaining: 2m 14s
# 479:	learn: 0.5005730	total: 42.6s	remaining: 2m 14s
# 480:	learn: 0.5005564	total: 42.7s	remaining: 2m 14s
# 481:	learn: 0.5005382	total: 42.8s	remaining: 2m 14s
# 482:	learn: 0.5005185	total: 42.9s	remaining: 2m 14s
# 483:	learn: 0.5004967	total: 43s	remaining: 2m 14s
# 484:	learn: 0.5004830	total: 43s	remaining: 2m 14s
# 485:	learn: 0.5004650	total: 43.1s	remaining: 2m 14s
# 486:	learn: 0.5004454	total: 43.2s	remaining: 2m 14s
# 487:	learn: 0.5004271	total: 43.3s	remaining: 2m 14s
# 488:	learn: 0.5004076	total: 43.4s	remaining: 2m 14s
# 489:	learn: 0.5003899	total: 43.5s	remaining: 2m 13s
# 490:	learn: 0.5003690	total: 43.5s	remaining: 2m 13s
# 491:	learn: 0.5003488	total: 43.6s	remaining: 2m 13s
# 492:	learn: 0.5003276	total: 43.7s	remaining: 2m 13s
# 493:	learn: 0.5003057	total: 43.8s	remaining: 2m 13s
# 494:	learn: 0.5002840	total: 43.9s	remaining: 2m 13s
# 495:	learn: 0.5002663	total: 44s	remaining: 2m 13s
# 496:	learn: 0.5002455	total: 44.1s	remaining: 2m 13s
# 497:	learn: 0.5002264	total: 44.2s	remaining: 2m 13s
# 498:	learn: 0.5002086	total: 44.3s	remaining: 2m 13s
# 499:	learn: 0.5001915	total: 44.4s	remaining: 2m 13s
# 500:	learn: 0.5001698	total: 44.5s	remaining: 2m 13s
# 501:	learn: 0.5001496	total: 44.5s	remaining: 2m 12s
# 502:	learn: 0.5001296	total: 44.6s	remaining: 2m 12s
# 503:	learn: 0.5001093	total: 44.7s	remaining: 2m 12s
# 504:	learn: 0.5000884	total: 44.8s	remaining: 2m 12s
# 505:	learn: 0.5000722	total: 44.9s	remaining: 2m 12s
# 506:	learn: 0.5000548	total: 45s	remaining: 2m 12s
# 507:	learn: 0.5000364	total: 45.1s	remaining: 2m 12s
# 508:	learn: 0.5000175	total: 45.2s	remaining: 2m 12s
# 509:	learn: 0.4999997	total: 45.3s	remaining: 2m 12s
# 510:	learn: 0.4999802	total: 45.3s	remaining: 2m 12s
# 511:	learn: 0.4999646	total: 45.4s	remaining: 2m 12s
# 512:	learn: 0.4999467	total: 45.5s	remaining: 2m 11s
# 513:	learn: 0.4999268	total: 45.6s	remaining: 2m 11s
# 514:	learn: 0.4999079	total: 45.7s	remaining: 2m 11s
# 515:	learn: 0.4998899	total: 45.8s	remaining: 2m 11s
# 516:	learn: 0.4998684	total: 45.9s	remaining: 2m 11s
# 517:	learn: 0.4998453	total: 46s	remaining: 2m 11s
# 518:	learn: 0.4998265	total: 46.1s	remaining: 2m 11s
# 519:	learn: 0.4998077	total: 46.1s	remaining: 2m 11s
# 520:	learn: 0.4997899	total: 46.2s	remaining: 2m 11s
# 521:	learn: 0.4997724	total: 46.3s	remaining: 2m 11s
# 522:	learn: 0.4997530	total: 46.4s	remaining: 2m 11s
# 523:	learn: 0.4997325	total: 46.5s	remaining: 2m 10s
# 524:	learn: 0.4997129	total: 46.6s	remaining: 2m 10s
# 525:	learn: 0.4996953	total: 46.7s	remaining: 2m 10s
# 526:	learn: 0.4996750	total: 46.8s	remaining: 2m 10s
# 527:	learn: 0.4996549	total: 46.9s	remaining: 2m 10s
# 528:	learn: 0.4996339	total: 46.9s	remaining: 2m 10s
# 529:	learn: 0.4996149	total: 47s	remaining: 2m 10s
# 530:	learn: 0.4995935	total: 47.1s	remaining: 2m 10s
# 531:	learn: 0.4995736	total: 47.2s	remaining: 2m 10s
# 532:	learn: 0.4995556	total: 47.3s	remaining: 2m 10s
# 533:	learn: 0.4995362	total: 47.4s	remaining: 2m 10s
# 534:	learn: 0.4995195	total: 47.5s	remaining: 2m 10s
# 535:	learn: 0.4995004	total: 47.6s	remaining: 2m 9s
# 536:	learn: 0.4994784	total: 47.7s	remaining: 2m 9s
# 537:	learn: 0.4994615	total: 47.7s	remaining: 2m 9s
# 538:	learn: 0.4994416	total: 47.8s	remaining: 2m 9s
# 539:	learn: 0.4994237	total: 47.9s	remaining: 2m 9s
# 540:	learn: 0.4994022	total: 48s	remaining: 2m 9s
# 541:	learn: 0.4993837	total: 48.1s	remaining: 2m 9s
# 542:	learn: 0.4993653	total: 48.2s	remaining: 2m 9s
# 543:	learn: 0.4993497	total: 48.3s	remaining: 2m 9s
# 544:	learn: 0.4993299	total: 48.4s	remaining: 2m 9s
# 545:	learn: 0.4993100	total: 48.5s	remaining: 2m 9s
# 546:	learn: 0.4992901	total: 48.5s	remaining: 2m 8s
# 547:	learn: 0.4992703	total: 48.6s	remaining: 2m 8s
# 548:	learn: 0.4992545	total: 48.7s	remaining: 2m 8s
# 549:	learn: 0.4992362	total: 48.8s	remaining: 2m 8s
# 550:	learn: 0.4992154	total: 48.9s	remaining: 2m 8s
# 551:	learn: 0.4991927	total: 49s	remaining: 2m 8s
# 552:	learn: 0.4991751	total: 49.1s	remaining: 2m 8s
# 553:	learn: 0.4991574	total: 49.2s	remaining: 2m 8s
# 554:	learn: 0.4991370	total: 49.3s	remaining: 2m 8s
# 555:	learn: 0.4991170	total: 49.4s	remaining: 2m 8s
# 556:	learn: 0.4990983	total: 49.4s	remaining: 2m 8s
# 557:	learn: 0.4990791	total: 49.5s	remaining: 2m 8s
# 558:	learn: 0.4990592	total: 49.6s	remaining: 2m 7s
# 559:	learn: 0.4990414	total: 49.7s	remaining: 2m 7s
# 560:	learn: 0.4990251	total: 49.8s	remaining: 2m 7s
# 561:	learn: 0.4990061	total: 49.9s	remaining: 2m 7s
# 562:	learn: 0.4989878	total: 50s	remaining: 2m 7s
# 563:	learn: 0.4989660	total: 50.1s	remaining: 2m 7s
# 564:	learn: 0.4989472	total: 50.1s	remaining: 2m 7s
# 565:	learn: 0.4989291	total: 50.2s	remaining: 2m 7s
# 566:	learn: 0.4989091	total: 50.3s	remaining: 2m 7s
# 567:	learn: 0.4988899	total: 50.4s	remaining: 2m 7s
# 568:	learn: 0.4988699	total: 50.5s	remaining: 2m 6s
# 569:	learn: 0.4988494	total: 50.6s	remaining: 2m 6s
# 570:	learn: 0.4988280	total: 50.7s	remaining: 2m 6s
# 571:	learn: 0.4988083	total: 50.8s	remaining: 2m 6s
# 572:	learn: 0.4987918	total: 50.9s	remaining: 2m 6s
# 573:	learn: 0.4987760	total: 51s	remaining: 2m 6s
# 574:	learn: 0.4987560	total: 51s	remaining: 2m 6s
# 575:	learn: 0.4987379	total: 51.1s	remaining: 2m 6s
# 576:	learn: 0.4987197	total: 51.2s	remaining: 2m 6s
# 577:	learn: 0.4986987	total: 51.3s	remaining: 2m 6s
# 578:	learn: 0.4986798	total: 51.4s	remaining: 2m 6s
# 579:	learn: 0.4986581	total: 51.5s	remaining: 2m 6s
# 580:	learn: 0.4986404	total: 51.6s	remaining: 2m 5s
# 581:	learn: 0.4986242	total: 51.7s	remaining: 2m 5s
# 582:	learn: 0.4986042	total: 51.8s	remaining: 2m 5s
# 583:	learn: 0.4985852	total: 51.8s	remaining: 2m 5s
# 584:	learn: 0.4985703	total: 51.9s	remaining: 2m 5s
# 585:	learn: 0.4985512	total: 52s	remaining: 2m 5s
# 586:	learn: 0.4985311	total: 52.1s	remaining: 2m 5s
# 587:	learn: 0.4985123	total: 52.2s	remaining: 2m 5s
# 588:	learn: 0.4984932	total: 52.3s	remaining: 2m 5s
# 589:	learn: 0.4984745	total: 52.4s	remaining: 2m 5s
# 590:	learn: 0.4984548	total: 52.5s	remaining: 2m 5s
# 591:	learn: 0.4984346	total: 52.6s	remaining: 2m 5s
# 592:	learn: 0.4984179	total: 52.7s	remaining: 2m 4s
# 593:	learn: 0.4983994	total: 52.7s	remaining: 2m 4s
# 594:	learn: 0.4983789	total: 52.8s	remaining: 2m 4s
# 595:	learn: 0.4983622	total: 52.9s	remaining: 2m 4s
# 596:	learn: 0.4983436	total: 53s	remaining: 2m 4s
# 597:	learn: 0.4983235	total: 53.1s	remaining: 2m 4s
# 598:	learn: 0.4983029	total: 53.2s	remaining: 2m 4s
# 599:	learn: 0.4982865	total: 53.3s	remaining: 2m 4s
# 600:	learn: 0.4982681	total: 53.4s	remaining: 2m 4s
# 601:	learn: 0.4982471	total: 53.4s	remaining: 2m 4s
# 602:	learn: 0.4982302	total: 53.5s	remaining: 2m 4s
# 603:	learn: 0.4982117	total: 53.6s	remaining: 2m 3s
# 604:	learn: 0.4981944	total: 53.7s	remaining: 2m 3s
# 605:	learn: 0.4981754	total: 53.8s	remaining: 2m 3s
# 606:	learn: 0.4981573	total: 53.9s	remaining: 2m 3s
# 607:	learn: 0.4981395	total: 54s	remaining: 2m 3s
# 608:	learn: 0.4981186	total: 54.1s	remaining: 2m 3s
# 609:	learn: 0.4980992	total: 54.1s	remaining: 2m 3s
# 610:	learn: 0.4980771	total: 54.2s	remaining: 2m 3s
# 611:	learn: 0.4980598	total: 54.3s	remaining: 2m 3s
# 612:	learn: 0.4980393	total: 54.4s	remaining: 2m 3s
# 613:	learn: 0.4980204	total: 54.5s	remaining: 2m 3s
# 614:	learn: 0.4980003	total: 54.6s	remaining: 2m 2s
# 615:	learn: 0.4979831	total: 54.7s	remaining: 2m 2s
# 616:	learn: 0.4979633	total: 54.8s	remaining: 2m 2s
# 617:	learn: 0.4979451	total: 54.9s	remaining: 2m 2s
# 618:	learn: 0.4979303	total: 55s	remaining: 2m 2s
# 619:	learn: 0.4979137	total: 55s	remaining: 2m 2s
# 620:	learn: 0.4978922	total: 55.1s	remaining: 2m 2s
# 621:	learn: 0.4978763	total: 55.2s	remaining: 2m 2s
# 622:	learn: 0.4978591	total: 55.3s	remaining: 2m 2s
# 623:	learn: 0.4978380	total: 55.4s	remaining: 2m 2s
# 624:	learn: 0.4978211	total: 55.5s	remaining: 2m 2s
# 625:	learn: 0.4978025	total: 55.6s	remaining: 2m 1s
# 626:	learn: 0.4977848	total: 55.7s	remaining: 2m 1s
# 627:	learn: 0.4977642	total: 55.7s	remaining: 2m 1s
# 628:	learn: 0.4977463	total: 55.8s	remaining: 2m 1s
# 629:	learn: 0.4977260	total: 55.9s	remaining: 2m 1s
# 630:	learn: 0.4977057	total: 56s	remaining: 2m 1s
# 631:	learn: 0.4976850	total: 56.1s	remaining: 2m 1s
# 632:	learn: 0.4976693	total: 56.2s	remaining: 2m 1s
# 633:	learn: 0.4976501	total: 56.3s	remaining: 2m 1s
# 634:	learn: 0.4976318	total: 56.4s	remaining: 2m 1s
# 635:	learn: 0.4976165	total: 56.5s	remaining: 2m 1s
# 636:	learn: 0.4975961	total: 56.6s	remaining: 2m 1s
# 637:	learn: 0.4975746	total: 56.7s	remaining: 2m
# 638:	learn: 0.4975590	total: 56.8s	remaining: 2m
# 639:	learn: 0.4975443	total: 56.8s	remaining: 2m
# 640:	learn: 0.4975231	total: 56.9s	remaining: 2m
# 641:	learn: 0.4975046	total: 57s	remaining: 2m
# 642:	learn: 0.4974849	total: 57.1s	remaining: 2m
# 643:	learn: 0.4974669	total: 57.2s	remaining: 2m
# 644:	learn: 0.4974483	total: 57.3s	remaining: 2m
# 645:	learn: 0.4974273	total: 57.4s	remaining: 2m
# 646:	learn: 0.4974088	total: 57.4s	remaining: 2m
# 647:	learn: 0.4973882	total: 57.5s	remaining: 2m
# 648:	learn: 0.4973716	total: 57.6s	remaining: 1m 59s
# 649:	learn: 0.4973529	total: 57.7s	remaining: 1m 59s
# 650:	learn: 0.4973361	total: 57.8s	remaining: 1m 59s
# 651:	learn: 0.4973162	total: 57.9s	remaining: 1m 59s
# 652:	learn: 0.4972995	total: 58s	remaining: 1m 59s
# 653:	learn: 0.4972812	total: 58.1s	remaining: 1m 59s
# 654:	learn: 0.4972667	total: 58.2s	remaining: 1m 59s
# 655:	learn: 0.4972450	total: 58.2s	remaining: 1m 59s
# 656:	learn: 0.4972266	total: 58.3s	remaining: 1m 59s
# 657:	learn: 0.4972070	total: 58.4s	remaining: 1m 59s
# 658:	learn: 0.4971872	total: 58.5s	remaining: 1m 59s
# 659:	learn: 0.4971680	total: 58.6s	remaining: 1m 58s
# 660:	learn: 0.4971489	total: 58.7s	remaining: 1m 58s
# 661:	learn: 0.4971309	total: 58.8s	remaining: 1m 58s
# 662:	learn: 0.4971123	total: 58.9s	remaining: 1m 58s
# 663:	learn: 0.4970941	total: 59s	remaining: 1m 58s
# 664:	learn: 0.4970744	total: 59.1s	remaining: 1m 58s
# 665:	learn: 0.4970574	total: 59.2s	remaining: 1m 58s
# 666:	learn: 0.4970398	total: 59.2s	remaining: 1m 58s
# 667:	learn: 0.4970190	total: 59.3s	remaining: 1m 58s
# 668:	learn: 0.4970001	total: 59.4s	remaining: 1m 58s
# 669:	learn: 0.4969817	total: 59.5s	remaining: 1m 58s
# 670:	learn: 0.4969648	total: 59.6s	remaining: 1m 58s
# 671:	learn: 0.4969434	total: 59.7s	remaining: 1m 57s
# 672:	learn: 0.4969265	total: 59.8s	remaining: 1m 57s
# 673:	learn: 0.4969092	total: 59.9s	remaining: 1m 57s
# 674:	learn: 0.4968903	total: 60s	remaining: 1m 57s
# 675:	learn: 0.4968707	total: 1m	remaining: 1m 57s
# 676:	learn: 0.4968529	total: 1m	remaining: 1m 57s
# 677:	learn: 0.4968370	total: 1m	remaining: 1m 57s
# 678:	learn: 0.4968179	total: 1m	remaining: 1m 57s
# 679:	learn: 0.4967962	total: 1m	remaining: 1m 57s
# 680:	learn: 0.4967785	total: 1m	remaining: 1m 57s
# 681:	learn: 0.4967604	total: 1m	remaining: 1m 57s
# 682:	learn: 0.4967402	total: 1m	remaining: 1m 56s
# 683:	learn: 0.4967209	total: 1m	remaining: 1m 56s
# 684:	learn: 0.4967015	total: 1m	remaining: 1m 56s
# 685:	learn: 0.4966838	total: 1m	remaining: 1m 56s
# 686:	learn: 0.4966646	total: 1m 1s	remaining: 1m 56s
# 687:	learn: 0.4966477	total: 1m 1s	remaining: 1m 56s
# 688:	learn: 0.4966309	total: 1m 1s	remaining: 1m 56s
# 689:	learn: 0.4966107	total: 1m 1s	remaining: 1m 56s
# 690:	learn: 0.4965904	total: 1m 1s	remaining: 1m 56s
# 691:	learn: 0.4965722	total: 1m 1s	remaining: 1m 56s
# 692:	learn: 0.4965518	total: 1m 1s	remaining: 1m 56s
# 693:	learn: 0.4965355	total: 1m 1s	remaining: 1m 56s
# 694:	learn: 0.4965155	total: 1m 1s	remaining: 1m 55s
# 695:	learn: 0.4964959	total: 1m 1s	remaining: 1m 55s
# 696:	learn: 0.4964769	total: 1m 1s	remaining: 1m 55s
# 697:	learn: 0.4964576	total: 1m 2s	remaining: 1m 55s
# 698:	learn: 0.4964424	total: 1m 2s	remaining: 1m 55s
# 699:	learn: 0.4964235	total: 1m 2s	remaining: 1m 55s
# 700:	learn: 0.4964042	total: 1m 2s	remaining: 1m 55s
# 701:	learn: 0.4963849	total: 1m 2s	remaining: 1m 55s
# 702:	learn: 0.4963667	total: 1m 2s	remaining: 1m 55s
# 703:	learn: 0.4963489	total: 1m 2s	remaining: 1m 55s
# 704:	learn: 0.4963310	total: 1m 2s	remaining: 1m 55s
# 705:	learn: 0.4963117	total: 1m 2s	remaining: 1m 54s
# 706:	learn: 0.4962913	total: 1m 2s	remaining: 1m 54s
# 707:	learn: 0.4962781	total: 1m 2s	remaining: 1m 54s
# 708:	learn: 0.4962567	total: 1m 2s	remaining: 1m 54s
# 709:	learn: 0.4962369	total: 1m 3s	remaining: 1m 54s
# 710:	learn: 0.4962172	total: 1m 3s	remaining: 1m 54s
# 711:	learn: 0.4961993	total: 1m 3s	remaining: 1m 54s
# 712:	learn: 0.4961818	total: 1m 3s	remaining: 1m 54s
# 713:	learn: 0.4961632	total: 1m 3s	remaining: 1m 54s
# 714:	learn: 0.4961440	total: 1m 3s	remaining: 1m 54s
# 715:	learn: 0.4961254	total: 1m 3s	remaining: 1m 54s
# 716:	learn: 0.4961077	total: 1m 3s	remaining: 1m 53s
# 717:	learn: 0.4960893	total: 1m 3s	remaining: 1m 53s
# 718:	learn: 0.4960713	total: 1m 3s	remaining: 1m 53s
# 719:	learn: 0.4960513	total: 1m 3s	remaining: 1m 53s
# 720:	learn: 0.4960317	total: 1m 4s	remaining: 1m 53s
# 721:	learn: 0.4960116	total: 1m 4s	remaining: 1m 53s
# 722:	learn: 0.4959909	total: 1m 4s	remaining: 1m 53s
# 723:	learn: 0.4959695	total: 1m 4s	remaining: 1m 53s
# 724:	learn: 0.4959515	total: 1m 4s	remaining: 1m 53s
# 725:	learn: 0.4959324	total: 1m 4s	remaining: 1m 53s
# 726:	learn: 0.4959121	total: 1m 4s	remaining: 1m 53s
# 727:	learn: 0.4958921	total: 1m 4s	remaining: 1m 53s
# 728:	learn: 0.4958731	total: 1m 4s	remaining: 1m 52s
# 729:	learn: 0.4958522	total: 1m 4s	remaining: 1m 52s
# 730:	learn: 0.4958328	total: 1m 4s	remaining: 1m 52s
# 731:	learn: 0.4958159	total: 1m 5s	remaining: 1m 52s
# 732:	learn: 0.4957940	total: 1m 5s	remaining: 1m 52s
# 733:	learn: 0.4957782	total: 1m 5s	remaining: 1m 52s
# 734:	learn: 0.4957612	total: 1m 5s	remaining: 1m 52s
# 735:	learn: 0.4957435	total: 1m 5s	remaining: 1m 52s
# 736:	learn: 0.4957264	total: 1m 5s	remaining: 1m 52s
# 737:	learn: 0.4957067	total: 1m 5s	remaining: 1m 52s
# 738:	learn: 0.4956903	total: 1m 5s	remaining: 1m 52s
# 739:	learn: 0.4956732	total: 1m 5s	remaining: 1m 51s
# 740:	learn: 0.4956522	total: 1m 5s	remaining: 1m 51s
# 741:	learn: 0.4956357	total: 1m 5s	remaining: 1m 51s
# 742:	learn: 0.4956180	total: 1m 6s	remaining: 1m 51s
# 743:	learn: 0.4956004	total: 1m 6s	remaining: 1m 51s
# 744:	learn: 0.4955808	total: 1m 6s	remaining: 1m 51s
# 745:	learn: 0.4955639	total: 1m 6s	remaining: 1m 51s
# 746:	learn: 0.4955473	total: 1m 6s	remaining: 1m 51s
# 747:	learn: 0.4955293	total: 1m 6s	remaining: 1m 51s
# 748:	learn: 0.4955114	total: 1m 6s	remaining: 1m 51s
# 749:	learn: 0.4954917	total: 1m 6s	remaining: 1m 51s
# 750:	learn: 0.4954743	total: 1m 6s	remaining: 1m 51s
# 751:	learn: 0.4954566	total: 1m 6s	remaining: 1m 50s
# 752:	learn: 0.4954388	total: 1m 6s	remaining: 1m 50s
# 753:	learn: 0.4954213	total: 1m 7s	remaining: 1m 50s
# 754:	learn: 0.4954064	total: 1m 7s	remaining: 1m 50s
# 755:	learn: 0.4953874	total: 1m 7s	remaining: 1m 50s
# 756:	learn: 0.4953684	total: 1m 7s	remaining: 1m 50s
# 757:	learn: 0.4953499	total: 1m 7s	remaining: 1m 50s
# 758:	learn: 0.4953307	total: 1m 7s	remaining: 1m 50s
# 759:	learn: 0.4953136	total: 1m 7s	remaining: 1m 50s
# 760:	learn: 0.4952958	total: 1m 7s	remaining: 1m 50s
# 761:	learn: 0.4952767	total: 1m 7s	remaining: 1m 50s
# 762:	learn: 0.4952575	total: 1m 7s	remaining: 1m 50s
# 763:	learn: 0.4952385	total: 1m 7s	remaining: 1m 49s
# 764:	learn: 0.4952170	total: 1m 8s	remaining: 1m 49s
# 765:	learn: 0.4951987	total: 1m 8s	remaining: 1m 49s
# 766:	learn: 0.4951811	total: 1m 8s	remaining: 1m 49s
# 767:	learn: 0.4951610	total: 1m 8s	remaining: 1m 49s
# 768:	learn: 0.4951452	total: 1m 8s	remaining: 1m 49s
# 769:	learn: 0.4951292	total: 1m 8s	remaining: 1m 49s
# 770:	learn: 0.4951107	total: 1m 8s	remaining: 1m 49s
# 771:	learn: 0.4950912	total: 1m 8s	remaining: 1m 49s
# 772:	learn: 0.4950729	total: 1m 8s	remaining: 1m 49s
# 773:	learn: 0.4950558	total: 1m 8s	remaining: 1m 49s
# 774:	learn: 0.4950376	total: 1m 8s	remaining: 1m 48s
# 775:	learn: 0.4950204	total: 1m 9s	remaining: 1m 48s
# 776:	learn: 0.4950005	total: 1m 9s	remaining: 1m 48s
# 777:	learn: 0.4949848	total: 1m 9s	remaining: 1m 48s
# 778:	learn: 0.4949694	total: 1m 9s	remaining: 1m 48s
# 779:	learn: 0.4949499	total: 1m 9s	remaining: 1m 48s
# 780:	learn: 0.4949331	total: 1m 9s	remaining: 1m 48s
# 781:	learn: 0.4949150	total: 1m 9s	remaining: 1m 48s
# 782:	learn: 0.4948976	total: 1m 9s	remaining: 1m 48s
# 783:	learn: 0.4948777	total: 1m 9s	remaining: 1m 48s
# 784:	learn: 0.4948585	total: 1m 9s	remaining: 1m 48s
# 785:	learn: 0.4948401	total: 1m 9s	remaining: 1m 47s
# 786:	learn: 0.4948223	total: 1m 9s	remaining: 1m 47s
# 787:	learn: 0.4948058	total: 1m 10s	remaining: 1m 47s
# 788:	learn: 0.4947876	total: 1m 10s	remaining: 1m 47s
# 789:	learn: 0.4947695	total: 1m 10s	remaining: 1m 47s
# 790:	learn: 0.4947507	total: 1m 10s	remaining: 1m 47s
# 791:	learn: 0.4947315	total: 1m 10s	remaining: 1m 47s
# 792:	learn: 0.4947143	total: 1m 10s	remaining: 1m 47s
# 793:	learn: 0.4946932	total: 1m 10s	remaining: 1m 47s
# 794:	learn: 0.4946767	total: 1m 10s	remaining: 1m 47s
# 795:	learn: 0.4946598	total: 1m 10s	remaining: 1m 47s
# 796:	learn: 0.4946413	total: 1m 10s	remaining: 1m 46s
# 797:	learn: 0.4946195	total: 1m 10s	remaining: 1m 46s
# 798:	learn: 0.4946019	total: 1m 11s	remaining: 1m 46s
# 799:	learn: 0.4945827	total: 1m 11s	remaining: 1m 46s
# 800:	learn: 0.4945634	total: 1m 11s	remaining: 1m 46s
# 801:	learn: 0.4945442	total: 1m 11s	remaining: 1m 46s
# 802:	learn: 0.4945254	total: 1m 11s	remaining: 1m 46s
# 803:	learn: 0.4945084	total: 1m 11s	remaining: 1m 46s
# 804:	learn: 0.4944910	total: 1m 11s	remaining: 1m 46s
# 805:	learn: 0.4944734	total: 1m 11s	remaining: 1m 46s
# 806:	learn: 0.4944539	total: 1m 11s	remaining: 1m 46s
# 807:	learn: 0.4944333	total: 1m 11s	remaining: 1m 46s
# 808:	learn: 0.4944133	total: 1m 11s	remaining: 1m 45s
# 809:	learn: 0.4943933	total: 1m 12s	remaining: 1m 45s
# 810:	learn: 0.4943745	total: 1m 12s	remaining: 1m 45s
# 811:	learn: 0.4943553	total: 1m 12s	remaining: 1m 45s
# 812:	learn: 0.4943361	total: 1m 12s	remaining: 1m 45s
# 813:	learn: 0.4943187	total: 1m 12s	remaining: 1m 45s
# 814:	learn: 0.4942968	total: 1m 12s	remaining: 1m 45s
# 815:	learn: 0.4942800	total: 1m 12s	remaining: 1m 45s
# 816:	learn: 0.4942604	total: 1m 12s	remaining: 1m 45s
# 817:	learn: 0.4942416	total: 1m 12s	remaining: 1m 45s
# 818:	learn: 0.4942249	total: 1m 12s	remaining: 1m 45s
# 819:	learn: 0.4942062	total: 1m 12s	remaining: 1m 44s
# 820:	learn: 0.4941861	total: 1m 13s	remaining: 1m 44s
# 821:	learn: 0.4941681	total: 1m 13s	remaining: 1m 44s
# 822:	learn: 0.4941488	total: 1m 13s	remaining: 1m 44s
# 823:	learn: 0.4941283	total: 1m 13s	remaining: 1m 44s
# 824:	learn: 0.4941077	total: 1m 13s	remaining: 1m 44s
# 825:	learn: 0.4940923	total: 1m 13s	remaining: 1m 44s
# 826:	learn: 0.4940744	total: 1m 13s	remaining: 1m 44s
# 827:	learn: 0.4940602	total: 1m 13s	remaining: 1m 44s
# 828:	learn: 0.4940411	total: 1m 13s	remaining: 1m 44s
# 829:	learn: 0.4940240	total: 1m 13s	remaining: 1m 44s
# 830:	learn: 0.4940070	total: 1m 13s	remaining: 1m 44s
# 831:	learn: 0.4939901	total: 1m 14s	remaining: 1m 43s
# 832:	learn: 0.4939716	total: 1m 14s	remaining: 1m 43s
# 833:	learn: 0.4939532	total: 1m 14s	remaining: 1m 43s
# 834:	learn: 0.4939370	total: 1m 14s	remaining: 1m 43s
# 835:	learn: 0.4939236	total: 1m 14s	remaining: 1m 43s
# 836:	learn: 0.4939036	total: 1m 14s	remaining: 1m 43s
# 837:	learn: 0.4938860	total: 1m 14s	remaining: 1m 43s
# 838:	learn: 0.4938685	total: 1m 14s	remaining: 1m 43s
# 839:	learn: 0.4938503	total: 1m 14s	remaining: 1m 43s
# 840:	learn: 0.4938314	total: 1m 14s	remaining: 1m 43s
# 841:	learn: 0.4938114	total: 1m 14s	remaining: 1m 43s
# 842:	learn: 0.4937909	total: 1m 15s	remaining: 1m 43s
# 843:	learn: 0.4937731	total: 1m 15s	remaining: 1m 42s
# 844:	learn: 0.4937575	total: 1m 15s	remaining: 1m 42s
# 845:	learn: 0.4937406	total: 1m 15s	remaining: 1m 42s
# 846:	learn: 0.4937238	total: 1m 15s	remaining: 1m 42s
# 847:	learn: 0.4937043	total: 1m 15s	remaining: 1m 42s
# 848:	learn: 0.4936832	total: 1m 15s	remaining: 1m 42s
# 849:	learn: 0.4936662	total: 1m 15s	remaining: 1m 42s
# 850:	learn: 0.4936478	total: 1m 15s	remaining: 1m 42s
# 851:	learn: 0.4936303	total: 1m 15s	remaining: 1m 42s
# 852:	learn: 0.4936110	total: 1m 15s	remaining: 1m 42s
# 853:	learn: 0.4935962	total: 1m 16s	remaining: 1m 42s
# 854:	learn: 0.4935758	total: 1m 16s	remaining: 1m 41s
# 855:	learn: 0.4935599	total: 1m 16s	remaining: 1m 41s
# 856:	learn: 0.4935364	total: 1m 16s	remaining: 1m 41s
# 857:	learn: 0.4935204	total: 1m 16s	remaining: 1m 41s
# 858:	learn: 0.4935018	total: 1m 16s	remaining: 1m 41s
# 859:	learn: 0.4934841	total: 1m 16s	remaining: 1m 41s
# 860:	learn: 0.4934637	total: 1m 16s	remaining: 1m 41s
# 861:	learn: 0.4934430	total: 1m 16s	remaining: 1m 41s
# 862:	learn: 0.4934226	total: 1m 16s	remaining: 1m 41s
# 863:	learn: 0.4934051	total: 1m 16s	remaining: 1m 41s
# 864:	learn: 0.4933830	total: 1m 17s	remaining: 1m 41s
# 865:	learn: 0.4933656	total: 1m 17s	remaining: 1m 40s
# 866:	learn: 0.4933459	total: 1m 17s	remaining: 1m 40s
# 867:	learn: 0.4933261	total: 1m 17s	remaining: 1m 40s
# 868:	learn: 0.4933054	total: 1m 17s	remaining: 1m 40s
# 869:	learn: 0.4932854	total: 1m 17s	remaining: 1m 40s
# 870:	learn: 0.4932672	total: 1m 17s	remaining: 1m 40s
# 871:	learn: 0.4932461	total: 1m 17s	remaining: 1m 40s
# 872:	learn: 0.4932319	total: 1m 17s	remaining: 1m 40s
# 873:	learn: 0.4932133	total: 1m 17s	remaining: 1m 40s
# ...
# 1712:	learn: 0.4792930	total: 2m 34s	remaining: 25.8s
# 1713:	learn: 0.4792790	total: 2m 34s	remaining: 25.7s
# 1714:	learn: 0.4792618	total: 2m 34s	remaining: 25.6s
# 1715:	learn: 0.4792465	total: 2m 34s	remaining: 25.6s
# 1716:	learn: 0.4792300	total: 2m 34s	remaining: 25.5s
# 1717:	learn: 0.4792146	total: 2m 34s	remaining: 25.4s
# 1718:	learn: 0.4791973	total: 2m 34s	remaining: 25.3s
# 1719:	learn: 0.4791786	total: 2m 34s	remaining: 25.2s
# 1720:	learn: 0.4791605	total: 2m 34s	remaining: 25.1s
# 1721:	learn: 0.4791442	total: 2m 34s	remaining: 25s
# 1722:	learn: 0.4791261	total: 2m 35s	remaining: 24.9s
# 1723:	learn: 0.4791081	total: 2m 35s	remaining: 24.8s
# 1724:	learn: 0.4790899	total: 2m 35s	remaining: 24.7s
# 1725:	learn: 0.4790715	total: 2m 35s	remaining: 24.7s
# 1726:	learn: 0.4790495	total: 2m 35s	remaining: 24.6s
# 1727:	learn: 0.4790326	total: 2m 35s	remaining: 24.5s
# 1728:	learn: 0.4790190	total: 2m 35s	remaining: 24.4s
# 1729:	learn: 0.4790008	total: 2m 35s	remaining: 24.3s
# 1730:	learn: 0.4789852	total: 2m 35s	remaining: 24.2s
# 1731:	learn: 0.4789673	total: 2m 35s	remaining: 24.1s
# 1732:	learn: 0.4789491	total: 2m 35s	remaining: 24s
# 1733:	learn: 0.4789331	total: 2m 36s	remaining: 23.9s
# 1734:	learn: 0.4789154	total: 2m 36s	remaining: 23.8s
# 1735:	learn: 0.4788967	total: 2m 36s	remaining: 23.7s
# 1736:	learn: 0.4788787	total: 2m 36s	remaining: 23.7s
# 1737:	learn: 0.4788639	total: 2m 36s	remaining: 23.6s
# 1738:	learn: 0.4788450	total: 2m 36s	remaining: 23.5s
# 1739:	learn: 0.4788315	total: 2m 36s	remaining: 23.4s
# 1740:	learn: 0.4788136	total: 2m 36s	remaining: 23.3s
# 1741:	learn: 0.4787944	total: 2m 36s	remaining: 23.2s
# 1742:	learn: 0.4787773	total: 2m 36s	remaining: 23.1s
# 1743:	learn: 0.4787600	total: 2m 36s	remaining: 23s
# 1744:	learn: 0.4787430	total: 2m 36s	remaining: 22.9s
# 1745:	learn: 0.4787267	total: 2m 37s	remaining: 22.8s
# 1746:	learn: 0.4787104	total: 2m 37s	remaining: 22.8s
# 1747:	learn: 0.4786928	total: 2m 37s	remaining: 22.7s
# 1748:	learn: 0.4786763	total: 2m 37s	remaining: 22.6s
# 1749:	learn: 0.4786589	total: 2m 37s	remaining: 22.5s
# 1750:	learn: 0.4786423	total: 2m 37s	remaining: 22.4s
# 1751:	learn: 0.4786250	total: 2m 37s	remaining: 22.3s
# 1752:	learn: 0.4786072	total: 2m 37s	remaining: 22.2s
# 1753:	learn: 0.4785901	total: 2m 37s	remaining: 22.1s
# 1754:	learn: 0.4785747	total: 2m 37s	remaining: 22s
# 1755:	learn: 0.4785581	total: 2m 37s	remaining: 21.9s
# 1756:	learn: 0.4785406	total: 2m 38s	remaining: 21.9s
# 1757:	learn: 0.4785268	total: 2m 38s	remaining: 21.8s
# 1758:	learn: 0.4785079	total: 2m 38s	remaining: 21.7s
# 1759:	learn: 0.4784910	total: 2m 38s	remaining: 21.6s
# 1760:	learn: 0.4784770	total: 2m 38s	remaining: 21.5s
# 1761:	learn: 0.4784591	total: 2m 38s	remaining: 21.4s
# 1762:	learn: 0.4784405	total: 2m 38s	remaining: 21.3s
# 1763:	learn: 0.4784218	total: 2m 38s	remaining: 21.2s
# 1764:	learn: 0.4784040	total: 2m 38s	remaining: 21.1s
# 1765:	learn: 0.4783896	total: 2m 38s	remaining: 21s
# 1766:	learn: 0.4783735	total: 2m 38s	remaining: 21s
# 1767:	learn: 0.4783575	total: 2m 39s	remaining: 20.9s
# 1768:	learn: 0.4783407	total: 2m 39s	remaining: 20.8s
# 1769:	learn: 0.4783233	total: 2m 39s	remaining: 20.7s
# 1770:	learn: 0.4783080	total: 2m 39s	remaining: 20.6s
# 1771:	learn: 0.4782905	total: 2m 39s	remaining: 20.5s
# 1772:	learn: 0.4782756	total: 2m 39s	remaining: 20.4s
# 1773:	learn: 0.4782618	total: 2m 39s	remaining: 20.3s
# 1774:	learn: 0.4782423	total: 2m 39s	remaining: 20.2s
# 1775:	learn: 0.4782260	total: 2m 39s	remaining: 20.1s
# 1776:	learn: 0.4782118	total: 2m 39s	remaining: 20.1s
# 1777:	learn: 0.4781956	total: 2m 39s	remaining: 20s
# 1778:	learn: 0.4781782	total: 2m 39s	remaining: 19.9s
# 1779:	learn: 0.4781648	total: 2m 40s	remaining: 19.8s
# 1780:	learn: 0.4781492	total: 2m 40s	remaining: 19.7s
# 1781:	learn: 0.4781317	total: 2m 40s	remaining: 19.6s
# 1782:	learn: 0.4781151	total: 2m 40s	remaining: 19.5s
# 1783:	learn: 0.4780986	total: 2m 40s	remaining: 19.4s
# 1784:	learn: 0.4780824	total: 2m 40s	remaining: 19.3s
# 1785:	learn: 0.4780641	total: 2m 40s	remaining: 19.2s
# 1786:	learn: 0.4780470	total: 2m 40s	remaining: 19.1s
# 1787:	learn: 0.4780310	total: 2m 40s	remaining: 19.1s
# 1788:	learn: 0.4780139	total: 2m 40s	remaining: 19s
# 1789:	learn: 0.4779987	total: 2m 40s	remaining: 18.9s
# 1790:	learn: 0.4779811	total: 2m 40s	remaining: 18.8s
# 1791:	learn: 0.4779631	total: 2m 41s	remaining: 18.7s
# 1792:	learn: 0.4779482	total: 2m 41s	remaining: 18.6s
# 1793:	learn: 0.4779303	total: 2m 41s	remaining: 18.5s
# 1794:	learn: 0.4779130	total: 2m 41s	remaining: 18.4s
# 1795:	learn: 0.4778949	total: 2m 41s	remaining: 18.3s
# 1796:	learn: 0.4778772	total: 2m 41s	remaining: 18.2s
# 1797:	learn: 0.4778619	total: 2m 41s	remaining: 18.2s
# 1798:	learn: 0.4778456	total: 2m 41s	remaining: 18.1s
# 1799:	learn: 0.4778350	total: 2m 41s	remaining: 18s
# 1800:	learn: 0.4778171	total: 2m 41s	remaining: 17.9s
# 1801:	learn: 0.4778001	total: 2m 41s	remaining: 17.8s
# 1802:	learn: 0.4777849	total: 2m 42s	remaining: 17.7s
# 1803:	learn: 0.4777660	total: 2m 42s	remaining: 17.6s
# 1804:	learn: 0.4777511	total: 2m 42s	remaining: 17.5s
# 1805:	learn: 0.4777336	total: 2m 42s	remaining: 17.4s
# 1806:	learn: 0.4777159	total: 2m 42s	remaining: 17.3s
# 1807:	learn: 0.4776994	total: 2m 42s	remaining: 17.3s
# 1808:	learn: 0.4776856	total: 2m 42s	remaining: 17.2s
# 1809:	learn: 0.4776678	total: 2m 42s	remaining: 17.1s
# 1810:	learn: 0.4776517	total: 2m 42s	remaining: 17s
# 1811:	learn: 0.4776335	total: 2m 42s	remaining: 16.9s
# 1812:	learn: 0.4776162	total: 2m 43s	remaining: 16.8s
# 1813:	learn: 0.4775977	total: 2m 43s	remaining: 16.7s
# 1814:	learn: 0.4775801	total: 2m 43s	remaining: 16.6s
# 1815:	learn: 0.4775631	total: 2m 43s	remaining: 16.5s
# 1816:	learn: 0.4775480	total: 2m 43s	remaining: 16.5s
# 1817:	learn: 0.4775284	total: 2m 43s	remaining: 16.4s
# 1818:	learn: 0.4775124	total: 2m 43s	remaining: 16.3s
# 1819:	learn: 0.4774935	total: 2m 43s	remaining: 16.2s
# 1820:	learn: 0.4774807	total: 2m 43s	remaining: 16.1s
# 1821:	learn: 0.4774652	total: 2m 43s	remaining: 16s
# 1822:	learn: 0.4774482	total: 2m 43s	remaining: 15.9s
# 1823:	learn: 0.4774306	total: 2m 43s	remaining: 15.8s
# 1824:	learn: 0.4774135	total: 2m 44s	remaining: 15.7s
# 1825:	learn: 0.4774001	total: 2m 44s	remaining: 15.6s
# 1826:	learn: 0.4773838	total: 2m 44s	remaining: 15.6s
# 1827:	learn: 0.4773671	total: 2m 44s	remaining: 15.5s
# 1828:	learn: 0.4773516	total: 2m 44s	remaining: 15.4s
# 1829:	learn: 0.4773344	total: 2m 44s	remaining: 15.3s
# 1830:	learn: 0.4773173	total: 2m 44s	remaining: 15.2s
# 1831:	learn: 0.4773001	total: 2m 44s	remaining: 15.1s
# 1832:	learn: 0.4772805	total: 2m 44s	remaining: 15s
# 1833:	learn: 0.4772643	total: 2m 44s	remaining: 14.9s
# 1834:	learn: 0.4772469	total: 2m 44s	remaining: 14.8s
# 1835:	learn: 0.4772323	total: 2m 45s	remaining: 14.7s
# 1836:	learn: 0.4772138	total: 2m 45s	remaining: 14.6s
# 1837:	learn: 0.4771978	total: 2m 45s	remaining: 14.6s
# 1838:	learn: 0.4771817	total: 2m 45s	remaining: 14.5s
# 1839:	learn: 0.4771649	total: 2m 45s	remaining: 14.4s
# 1840:	learn: 0.4771492	total: 2m 45s	remaining: 14.3s
# 1841:	learn: 0.4771334	total: 2m 45s	remaining: 14.2s
# 1842:	learn: 0.4771177	total: 2m 45s	remaining: 14.1s
# 1843:	learn: 0.4771016	total: 2m 45s	remaining: 14s
# 1844:	learn: 0.4770827	total: 2m 45s	remaining: 13.9s
# 1845:	learn: 0.4770670	total: 2m 45s	remaining: 13.8s
# 1846:	learn: 0.4770509	total: 2m 45s	remaining: 13.7s
# 1847:	learn: 0.4770346	total: 2m 46s	remaining: 13.7s
# 1848:	learn: 0.4770168	total: 2m 46s	remaining: 13.6s
# 1849:	learn: 0.4769964	total: 2m 46s	remaining: 13.5s
# 1850:	learn: 0.4769806	total: 2m 46s	remaining: 13.4s
# 1851:	learn: 0.4769653	total: 2m 46s	remaining: 13.3s
# 1852:	learn: 0.4769493	total: 2m 46s	remaining: 13.2s
# 1853:	learn: 0.4769331	total: 2m 46s	remaining: 13.1s
# 1854:	learn: 0.4769163	total: 2m 46s	remaining: 13s
# 1855:	learn: 0.4768977	total: 2m 46s	remaining: 12.9s
# 1856:	learn: 0.4768813	total: 2m 46s	remaining: 12.8s
# 1857:	learn: 0.4768650	total: 2m 46s	remaining: 12.8s
# 1858:	learn: 0.4768488	total: 2m 46s	remaining: 12.7s
# 1859:	learn: 0.4768314	total: 2m 47s	remaining: 12.6s
# 1860:	learn: 0.4768132	total: 2m 47s	remaining: 12.5s
# 1861:	learn: 0.4767940	total: 2m 47s	remaining: 12.4s
# 1862:	learn: 0.4767763	total: 2m 47s	remaining: 12.3s
# 1863:	learn: 0.4767589	total: 2m 47s	remaining: 12.2s
# 1864:	learn: 0.4767405	total: 2m 47s	remaining: 12.1s
# 1865:	learn: 0.4767238	total: 2m 47s	remaining: 12s
# 1866:	learn: 0.4767048	total: 2m 47s	remaining: 11.9s
# 1867:	learn: 0.4766873	total: 2m 47s	remaining: 11.9s
# 1868:	learn: 0.4766697	total: 2m 47s	remaining: 11.8s
# 1869:	learn: 0.4766518	total: 2m 47s	remaining: 11.7s
# 1870:	learn: 0.4766389	total: 2m 48s	remaining: 11.6s
# 1871:	learn: 0.4766212	total: 2m 48s	remaining: 11.5s
# 1872:	learn: 0.4766081	total: 2m 48s	remaining: 11.4s
# 1873:	learn: 0.4765913	total: 2m 48s	remaining: 11.3s
# 1874:	learn: 0.4765729	total: 2m 48s	remaining: 11.2s
# 1875:	learn: 0.4765590	total: 2m 48s	remaining: 11.1s
# 1876:	learn: 0.4765416	total: 2m 48s	remaining: 11s
# 1877:	learn: 0.4765264	total: 2m 48s	remaining: 11s
# 1878:	learn: 0.4765081	total: 2m 48s	remaining: 10.9s
# 1879:	learn: 0.4764916	total: 2m 48s	remaining: 10.8s
# 1880:	learn: 0.4764752	total: 2m 48s	remaining: 10.7s
# 1881:	learn: 0.4764571	total: 2m 48s	remaining: 10.6s
# 1882:	learn: 0.4764411	total: 2m 49s	remaining: 10.5s
# 1883:	learn: 0.4764251	total: 2m 49s	remaining: 10.4s
# 1884:	learn: 0.4764103	total: 2m 49s	remaining: 10.3s
# 1885:	learn: 0.4763952	total: 2m 49s	remaining: 10.2s
# 1886:	learn: 0.4763778	total: 2m 49s	remaining: 10.1s
# 1887:	learn: 0.4763602	total: 2m 49s	remaining: 10.1s
# 1888:	learn: 0.4763424	total: 2m 49s	remaining: 9.97s
# 1889:	learn: 0.4763271	total: 2m 49s	remaining: 9.88s
# 1890:	learn: 0.4763085	total: 2m 49s	remaining: 9.79s
# 1891:	learn: 0.4762922	total: 2m 49s	remaining: 9.7s
# 1892:	learn: 0.4762778	total: 2m 49s	remaining: 9.61s
# 1893:	learn: 0.4762610	total: 2m 50s	remaining: 9.52s
# 1894:	learn: 0.4762420	total: 2m 50s	remaining: 9.43s
# 1895:	learn: 0.4762241	total: 2m 50s	remaining: 9.34s
# 1896:	learn: 0.4762086	total: 2m 50s	remaining: 9.25s
# 1897:	learn: 0.4761913	total: 2m 50s	remaining: 9.16s
# 1898:	learn: 0.4761754	total: 2m 50s	remaining: 9.07s
# 1899:	learn: 0.4761581	total: 2m 50s	remaining: 8.98s
# 1900:	learn: 0.4761409	total: 2m 50s	remaining: 8.89s
# 1901:	learn: 0.4761224	total: 2m 50s	remaining: 8.8s
# 1902:	learn: 0.4761059	total: 2m 50s	remaining: 8.71s
# 1903:	learn: 0.4760893	total: 2m 50s	remaining: 8.62s
# 1904:	learn: 0.4760745	total: 2m 50s	remaining: 8.53s
# 1905:	learn: 0.4760576	total: 2m 51s	remaining: 8.44s
# 1906:	learn: 0.4760415	total: 2m 51s	remaining: 8.35s
# 1907:	learn: 0.4760247	total: 2m 51s	remaining: 8.26s
# 1908:	learn: 0.4760095	total: 2m 51s	remaining: 8.17s
# 1909:	learn: 0.4759930	total: 2m 51s	remaining: 8.08s
# 1910:	learn: 0.4759757	total: 2m 51s	remaining: 7.99s
# 1911:	learn: 0.4759584	total: 2m 51s	remaining: 7.9s
# 1912:	learn: 0.4759434	total: 2m 51s	remaining: 7.81s
# 1913:	learn: 0.4759267	total: 2m 51s	remaining: 7.72s
# 1914:	learn: 0.4759111	total: 2m 51s	remaining: 7.63s
# 1915:	learn: 0.4758955	total: 2m 51s	remaining: 7.54s
# 1916:	learn: 0.4758783	total: 2m 52s	remaining: 7.45s
# 1917:	learn: 0.4758618	total: 2m 52s	remaining: 7.36s
# 1918:	learn: 0.4758456	total: 2m 52s	remaining: 7.27s
# 1919:	learn: 0.4758263	total: 2m 52s	remaining: 7.18s
# 1920:	learn: 0.4758104	total: 2m 52s	remaining: 7.09s
# 1921:	learn: 0.4757940	total: 2m 52s	remaining: 7s
# 1922:	learn: 0.4757775	total: 2m 52s	remaining: 6.91s
# 1923:	learn: 0.4757616	total: 2m 52s	remaining: 6.82s
# 1924:	learn: 0.4757450	total: 2m 52s	remaining: 6.73s
# 1925:	learn: 0.4757307	total: 2m 52s	remaining: 6.64s
# 1926:	learn: 0.4757145	total: 2m 52s	remaining: 6.55s
# 1927:	learn: 0.4756976	total: 2m 52s	remaining: 6.46s
# 1928:	learn: 0.4756806	total: 2m 53s	remaining: 6.37s
# 1929:	learn: 0.4756606	total: 2m 53s	remaining: 6.28s
# 1930:	learn: 0.4756423	total: 2m 53s	remaining: 6.19s
# 1931:	learn: 0.4756249	total: 2m 53s	remaining: 6.1s
# 1932:	learn: 0.4756056	total: 2m 53s	remaining: 6.01s
# 1933:	learn: 0.4755906	total: 2m 53s	remaining: 5.92s
# 1934:	learn: 0.4755732	total: 2m 53s	remaining: 5.83s
# 1935:	learn: 0.4755582	total: 2m 53s	remaining: 5.74s
# 1936:	learn: 0.4755414	total: 2m 53s	remaining: 5.65s
# 1937:	learn: 0.4755266	total: 2m 53s	remaining: 5.56s
# 1938:	learn: 0.4755102	total: 2m 53s	remaining: 5.47s
# 1939:	learn: 0.4754939	total: 2m 54s	remaining: 5.38s
# 1940:	learn: 0.4754804	total: 2m 54s	remaining: 5.29s
# 1941:	learn: 0.4754640	total: 2m 54s	remaining: 5.2s
# 1942:	learn: 0.4754440	total: 2m 54s	remaining: 5.11s
# 1943:	learn: 0.4754299	total: 2m 54s	remaining: 5.02s
# 1944:	learn: 0.4754119	total: 2m 54s	remaining: 4.93s
# 1945:	learn: 0.4753971	total: 2m 54s	remaining: 4.84s
# 1946:	learn: 0.4753806	total: 2m 54s	remaining: 4.75s
# 1947:	learn: 0.4753633	total: 2m 54s	remaining: 4.66s
# 1948:	learn: 0.4753452	total: 2m 54s	remaining: 4.57s
# 1949:	learn: 0.4753295	total: 2m 54s	remaining: 4.48s
# 1950:	learn: 0.4753128	total: 2m 54s	remaining: 4.39s
# 1951:	learn: 0.4752951	total: 2m 55s	remaining: 4.3s
# 1952:	learn: 0.4752794	total: 2m 55s	remaining: 4.21s
# 1953:	learn: 0.4752635	total: 2m 55s	remaining: 4.12s
# 1954:	learn: 0.4752448	total: 2m 55s	remaining: 4.03s
# 1955:	learn: 0.4752259	total: 2m 55s	remaining: 3.94s
# 1956:	learn: 0.4752077	total: 2m 55s	remaining: 3.85s
# 1957:	learn: 0.4751914	total: 2m 55s	remaining: 3.77s
# 1958:	learn: 0.4751756	total: 2m 55s	remaining: 3.67s
# 1959:	learn: 0.4751585	total: 2m 55s	remaining: 3.59s
# 1960:	learn: 0.4751414	total: 2m 55s	remaining: 3.5s
# 1961:	learn: 0.4751239	total: 2m 55s	remaining: 3.41s
# 1962:	learn: 0.4751068	total: 2m 55s	remaining: 3.32s
# 1963:	learn: 0.4750876	total: 2m 56s	remaining: 3.23s
# 1964:	learn: 0.4750724	total: 2m 56s	remaining: 3.14s
# 1965:	learn: 0.4750556	total: 2m 56s	remaining: 3.05s
# 1966:	learn: 0.4750374	total: 2m 56s	remaining: 2.96s
# 1967:	learn: 0.4750222	total: 2m 56s	remaining: 2.87s
# 1968:	learn: 0.4750057	total: 2m 56s	remaining: 2.78s
# 1969:	learn: 0.4749883	total: 2m 56s	remaining: 2.69s
# 1970:	learn: 0.4749730	total: 2m 56s	remaining: 2.6s
# 1971:	learn: 0.4749580	total: 2m 56s	remaining: 2.51s
# 1972:	learn: 0.4749413	total: 2m 56s	remaining: 2.42s
# 1973:	learn: 0.4749272	total: 2m 56s	remaining: 2.33s
# 1974:	learn: 0.4749090	total: 2m 57s	remaining: 2.24s
# 1975:	learn: 0.4748928	total: 2m 57s	remaining: 2.15s
# 1976:	learn: 0.4748778	total: 2m 57s	remaining: 2.06s
# 1977:	learn: 0.4748609	total: 2m 57s	remaining: 1.97s
# 1978:	learn: 0.4748441	total: 2m 57s	remaining: 1.88s
# 1979:	learn: 0.4748269	total: 2m 57s	remaining: 1.79s
# 1980:	learn: 0.4748093	total: 2m 57s	remaining: 1.7s
# 1981:	learn: 0.4747911	total: 2m 57s	remaining: 1.61s
# 1982:	learn: 0.4747721	total: 2m 57s	remaining: 1.52s
# 1983:	learn: 0.4747567	total: 2m 57s	remaining: 1.43s
# 1984:	learn: 0.4747388	total: 2m 57s	remaining: 1.34s
# 1985:	learn: 0.4747200	total: 2m 58s	remaining: 1.25s
# 1986:	learn: 0.4747028	total: 2m 58s	remaining: 1.17s
# 1987:	learn: 0.4746860	total: 2m 58s	remaining: 1.07s
# 1988:	learn: 0.4746682	total: 2m 58s	remaining: 986ms
# 1989:	learn: 0.4746501	total: 2m 58s	remaining: 896ms
# 1990:	learn: 0.4746337	total: 2m 58s	remaining: 807ms
# 1991:	learn: 0.4746165	total: 2m 58s	remaining: 717ms
# 1992:	learn: 0.4745993	total: 2m 58s	remaining: 627ms
# 1993:	learn: 0.4745822	total: 2m 58s	remaining: 538ms
# 1994:	learn: 0.4745644	total: 2m 58s	remaining: 448ms
# 1995:	learn: 0.4745484	total: 2m 58s	remaining: 358ms
# 1996:	learn: 0.4745325	total: 2m 58s	remaining: 269ms
# 1997:	learn: 0.4745156	total: 2m 59s	remaining: 179ms
# 1998:	learn: 0.4745003	total: 2m 59s	remaining: 89.6ms
# 1999:	learn: 0.4744827	total: 2m 59s	remaining: 0us
# Valid log-loss is 0.5071090517540354
# Valid AUC is 0.8149091535817894
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)

# %%
meta_learner = LogisticRegression(n_jobs=-1)

# %%
meta_learner.fit(X_meta, y_meta)
# Out:
# LogisticRegression(n_jobs=-1)

# %%
X_preds = meta_learner.predict_proba(X_meta)[:,1]

# %%
full_dataset_auc = roc_auc_score(y_meta, X_preds)

# %%
wandb.log({'blender-stack_mdethod': 'predict_proba', 
           'blender-final_estimator': str(meta_learner),
           'blender-final_estimator_params': meta_learner.get_params(),
           'ensemble_full-dataset_auc': full_dataset_auc,
           'blender-cv': None
          })

# %%
Path(datapath/f"models/{config_run['name']}_{exmodel_config['kfolds']}folds").mkdir(exist_ok=True)
dump(meta_learner, Path(datapath/f"models/{config_run['name']}_{exmodel_config['kfolds']}folds/meta-model_LogisticRegression_fit-on-full-dataset.joblib"))
# Out:
# ['/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/models/super-learner_manual_20210914_094720_5folds/meta-model_LogisticRegression_fit-on-full-dataset.joblib']

# %% [markdown]
# # Test set preprocessing

# %% [markdown]
# (Here's where encapsulating the transformations in a pipeline would come in handy. But I'll do it manually for now.)

# %%
# features = [x for x in test_df.columns if x != 'claim']
# X_test = test_df[features] # this is just for naming consistency

# %% [markdown]
# Now, let's get the features the model was trained on and subset the test set's features accordingly

# %%
# generation polynomial features
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_test_poly = poly.fit_transform(X_test)

# %%
# X_test_poly_names = poly.get_feature_names(X_test.columns)
# X_poly_names[100:150]
# features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
# checks = [feature in X_test_poly_names for feature in features]
# checks

# %%
# X_test_final = pd.DataFrame(X_test_poly, columns=X_test_poly_names)

# %%
# X_test_final = X_test_final[features[1:]]
# X_test_final = X_test

# %%
# X_test['nan_count'] = X_test.isnull().sum(axis=1)

# %%
# imputer = SimpleImputer(strategy='median', add_indicator=True)
# X_test_imputed_np = imputer.fit_transform(X_test)

# %%
# X_test_imputed = pd.DataFrame(X_test_imputed, columns=[str(x) for x in range(X_test_imputed.shape[1])])
# X_test_imputed.to_feather(path=datapath/'X_test_NaNcounts_imputed-Median-wIndicators.feather')

# %%
# scaler = exmodel_config['scaler']()
# X_test_imputed_scaled_np = scaler.fit_transform(X_test_imputed)
# X_test_imputed_scaled = pd.DataFrame(X_test_imputed_scaled_np, columns=X_test_imputed.columns)
# X_test_imputed_scaled.to_feather(path=datapath/'X_test_NaNcounts_imputed-Median-wIndicators_StandardScaled.feather')
# X_scaled_df = pd.DataFrame(X_scaled, columns=X_poly_names)

# %%
X_test = pd.read_feather(path=datapath/'X_test_NaNcounts_imputed-Median-wIndicators_StandardScaled.feather')

# %% [markdown]
# Now, you have to generate predictions for the test set using the constituent estimators, and then blend them together for the final prediction.

# %%
X_test_meta = [] 
# y_test_meta = [], []
X_test_np = X_test.to_numpy()
#         X_train, X_valid = X_np[train_ids], X_np[valid_ids]
#         y_train, y_valid = y_np[train_ids], y_np[valid_ids]
#         print(f"type(X_train) = {type(X_train)}")
#         print(f"type(y_trian) = {type(y_train)}")
#         # append the y_valid to y_meta
# #             pd.concat(y_meta, y_valid, axis=0) # building this "meta" y as we go - the valid for each fold go at the bottom of the col/pd.Series
#         y_meta.append(y_valid) # assumes y_meta is a list
# #             y_meta = pd.concat(y_meta, pd.Series(y_valid))

base_preds = [] # serving the same purpose as the `fold_preds` in the super_train func
for model in model_list: # presumes tuples of the form (str, model)
#     model[1].fit(X_train, y_train)
    y_pred = model[1].predict_proba(X_test_np)[:,1]
    base_preds.append(y_pred.reshape(len(y_pred), 1))

X_test_meta.append(np.hstack(base_preds))
#         dump(fold_preds, Path(preds_path/f"all_fold{fold}_oof-preds.joblib"))
#                     dump(model, Path(model_path/f"{exmodel_config['library']}_fold{fold}_model.joblib"))

#                 wandb.finish()
#     return np.vstack(X_meta), np.asarray(y_meta)
# at this point, X_meta is a length-5 list of np.ndarrays; each array has as many columns as estimators. The number of rows across folds sum to the number in the dataset.
# meanwhile, y_meta is a length-5 list of np.ndarrays containing the labels for each fold.
# on the way out, let's get them into the proper format
#     return X_meta, y_meta 

X_test_base = np.vstack(X_test_meta)
# np.vstack(X_meta), np.hstack(np.asarray(y_meta))
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %% [markdown]
# ## Prediction Generation

# %%
meta_preds = meta_learner.predict_proba(X_test_base)

# %%
meta_preds
# Out:
# array([[0.37975558, 0.62024442],
#        [0.86840193, 0.13159807],
#        [0.38051642, 0.61948358],
#        ...,
#        [0.24316148, 0.75683852],
#        [0.87790954, 0.12209046],
#        [0.19314858, 0.80685142]])

# %%
# preds_path = Path(datapath/"preds/")

# blender_preds = blender.predict_proba(X_test_imputed_scaled)#[:,1]
# dump(blender_preds, preds_path/f"{config_run['name']}_stack.joblib")

# %% [markdown]
# # Submission

# %%
sample_df = pd.read_csv(datapath/'sample_solution.csv')

# %%
sample_df.loc[:, 'claim'] = meta_preds[:,1]

# %%
sample_df.head()
# Out:
#        id     claim
# 0  957919  0.620244
# 1  957920  0.131598
# 2  957921  0.619484
# 3  957922  0.127216
# 4  957923  0.142606

# %%
submission_path = datapath/'submissions'
submission_path.mkdir(exist_ok=True)

# %%
sample_df.to_csv(submission_path/f"{config_run['name']}_super-learner_LogisticRegression_full-dataset.csv", index=False)

# %%
wandb.log({'leaderboard_auc': 0.81560 })

# %%
wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 1595973<br/>Program ended successfully.
# VBox(children=(Label(value=' 2.24MB of 2.24MB uploaded (0.73MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210914_094721-3kxydjbt/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210914_094721-3kxydjbt/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>0.47448</td></tr><tr><td>train_auc</td><td>0.86535</td></tr><tr><td>_runtime</td><td>4173</td></tr><tr><td>_timestamp</td><td>1631642214</td></tr><tr><td>_step</td><td>61</td></tr><tr><td>xgboost_params</td><td>{'objective': 'binar...</td></tr><tr><td>valid_loss</td><td>0.50711</td></tr><tr><td>valid_auc</td><td>0.81491</td></tr><tr><td>fold</td><td>4</td></tr><tr><td>lightgbm_params</td><td>{'boosting_type': 'g...</td></tr><tr><td>catboost_params</td><td>{'nan_mode': 'Min', ...</td></tr><tr><td>blender-stack_mdethod</td><td>predict_proba</td></tr><tr><td>blender-final_estimator</td><td>LogisticRegression(n...</td></tr><tr><td>ensemble_full-dataset_auc</td><td>0.81472</td></tr><tr><td>leaderboard_auc</td><td>0.8156</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▇█▁██▁██▁██▁██▁</td></tr><tr><td>train_auc</td><td>▂▁█▂▁█▂▁█▂▁█▂▁█</td></tr><tr><td>_runtime</td><td>▁▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▆▆▇▇▇▇▇▇▇▇█</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▆▆▇▇▇▇▇▇▇▇█</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>▇█▆▃▄▂▅▆▄▃▄▃▂▃▁</td></tr><tr><td>valid_auc</td><td>▃▁▄▆▅█▄▂▅▅▄▆▆▄█</td></tr><tr><td>fold</td><td>▁▁▁▃▃▃▅▅▅▆▆▆███</td></tr><tr><td>ensemble_full-dataset_auc</td><td>▁</td></tr><tr><td>leaderboard_auc</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 4 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">super-learner_manual_20210914_094720</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3kxydjbt" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3kxydjbt</a><br/>

# %% [markdown]
# ## Manual Stacking

# %%
X.head()
# Out:
#            0         1         2         3         4         5         6  \
# id
# 0   0.425545 -2.357891 -0.637206 -0.866657 -0.111568 -4.829243 -1.171229
# 1   0.247600 -0.323982  1.223569  0.361863  1.071182 -0.361140  0.082051
# 2   2.032371 -2.435680 -0.488960  0.341193  1.069656  0.118532  0.537069
# 3   1.438373 -2.337605 -0.508914 -0.829607  1.485682  3.592008 -1.189087
# 4   0.602333  1.076218 -0.648438  0.463365  0.275053 -0.157989  0.727338
#
#            7         8         9  ...       227       228       229       230  \
# id                                ...
# 0  -0.603397 -0.596871 -0.516828  ... -0.128368 -0.127677 -0.128242 -0.127867
# 1  -0.746590  0.899454  0.469668  ... -0.128368 -0.127677 -0.128242 -0.127867
# 2  -0.044075 -0.763516  1.056879  ... -0.128368 -0.127677 -0.128242 -0.127867
# 3  -0.339152 -0.735281 -0.529158  ... -0.128368 -0.127677 -0.128242 -0.127867
# 4  -0.905498  0.052478 -0.511066  ... -0.128368 -0.127677 -0.128242 -0.127867
#
#          231       232       233      234       235      236
# id
# 0  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 1  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 2  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 3  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 4  -0.127119 -0.127985 -0.128494 -0.12862  7.821398 -0.12703
#
# [5 rows x 237 columns]

# %%
X1 = X.copy()

# %%
X1.shape
# Out:
# (957919, 237)

# %%
# generate probability predictions for the XGBoost model's folds
for fold in xgboost_models.keys():
#     X1[f"xgboost_fold{fold}_pred"] = xgboost_models[fold].predict(X)
    X1[f"xgboost_fold{fold}_pred"] = xgboost_models[fold].predict_proba(X)[:,1]
#     xgboost_preds[fold] = xgboost_models[fold].predict(X_test_imputed_scaled)
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
X1.head()
# Out:
#            0         1         2         3         4         5         6  \
# id
# 0   0.425545 -2.357891 -0.637206 -0.866657 -0.111568 -4.829243 -1.171229
# 1   0.247600 -0.323982  1.223569  0.361863  1.071182 -0.361140  0.082051
# 2   2.032371 -2.435680 -0.488960  0.341193  1.069656  0.118532  0.537069
# 3   1.438373 -2.337605 -0.508914 -0.829607  1.485682  3.592008 -1.189087
# 4   0.602333  1.076218 -0.648438  0.463365  0.275053 -0.157989  0.727338
#
#            7         8         9  ...       232       233      234       235  \
# id                                ...
# 0  -0.603397 -0.596871 -0.516828  ... -0.127985 -0.128494 -0.12862 -0.127854
# 1  -0.746590  0.899454  0.469668  ... -0.127985 -0.128494 -0.12862 -0.127854
# 2  -0.044075 -0.763516  1.056879  ... -0.127985 -0.128494 -0.12862 -0.127854
# 3  -0.339152 -0.735281 -0.529158  ... -0.127985 -0.128494 -0.12862 -0.127854
# 4  -0.905498  0.052478 -0.511066  ... -0.127985 -0.128494 -0.12862  7.821398
#
#         236  xgboost_fold0_pred  xgboost_fold1_pred  xgboost_fold2_pred  \
# id
# 0  -0.12703            0.582566            0.580950            0.576743
# 1  -0.12703            0.152252            0.150803            0.148316
# 2  -0.12703            0.794083            0.789945            0.788326
# 3  -0.12703            0.774001            0.768510            0.774555
# 4  -0.12703            0.759366            0.755764            0.763769
#
#     xgboost_fold3_pred  xgboost_fold4_pred
# id
# 0             0.569523            0.595877
# 1             0.155218            0.147297
# 2             0.787177            0.797979
# 3             0.782187            0.773245
# 4             0.758034            0.758038
#
# [5 rows x 242 columns]
