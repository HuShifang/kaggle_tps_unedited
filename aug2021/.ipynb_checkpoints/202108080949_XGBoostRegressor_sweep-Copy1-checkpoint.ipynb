# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# general ML tooling
from sklearn.model_selection import train_test_split, StratifiedKFold#, KFold
from sklearn.metrics import mean_squared_error
import wandb
from wandb.xgboost import wandb_callback
# import timm

# %%
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
# from torchinfo import summary
# # from fastai.callback.wandb import *
# from torch.cuda.amp import autocast, GradScaler

# %%
# from fastai.vision.all import *
from fastai.tabular.all import *
# from fastai.callback.wandb import WandbCallback

# %%
# import xgboost as xgb
from xgboost import XGBRegressor, XGBRFRegressor
# from xgboost import XGBClassifier
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.tree import DecisionTreeClassifier

# %%
# %config Completer.use_jedi = False

# %%
set_seed(42, reproducible=True)

# %%
datapath = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/202108_august/')

# %%
df = pd.read_csv(datapath/'train.csv', index_col='id', low_memory=False)

# %%
# df.isnull().sum().any() # False

# %%
# df.info(verbose=True, null_counts=True)

# %% [markdown]
# So no NaNs.

# %%
# df.describe()

# %%
y = df.loss

# %%
features = [x for x in df.columns if x != 'loss']

# %%
X = df[features]

# %%
len(X)
# Out:
# 250000

# %%
df.head()
# Out:
#           f0   f1        f2        f3          f4        f5        f6  \
# id
# 0  -0.002350   59  0.766739 -1.350460     42.2727  16.68570   30.3599
# 1   0.784462  145 -0.463845 -0.530421  27324.9000   3.47545  160.4980
# 2   0.317816   19 -0.432571 -0.382644   1383.2600  19.71290   31.1026
# 3   0.210753   17 -0.616454  0.946362   -119.2530   4.08235  185.2570
# 4   0.439671   20  0.968126 -0.092546     74.3020  12.30650   72.1860
#
#           f7         f8       f9  ...        f91        f92      f93  \
# id                                ...
# 0   1.267300   0.392007  1.09101  ...  -42.43990  26.854000  1.45751
# 1   0.828007   3.735860  1.28138  ... -184.13200   7.901370  1.70644
# 2  -0.515354  34.430800  1.24210  ...    7.43721  37.218100  3.25339
# 3   1.383310 -47.521400  1.09130  ...    9.66778   0.626942  1.49425
# 4  -0.233964  24.399100  1.10151  ...  290.65700  15.604300  1.73557
#
#          f94        f95       f96       f97      f98       f99  loss
# id
# 0   0.696161   0.941764  1.828470  0.924090  2.29658  10.48980    15
# 1  -0.494699  -2.058300  0.819184  0.439152  2.36470   1.14383     3
# 2   0.337934   0.615037  2.216760  0.745268  1.69679  12.30550     6
# 3   0.517513 -10.222100  2.627310  0.617270  1.45645  10.02880     2
# 4  -0.476668   1.390190  2.195740  0.826987  1.78485   7.07197     1
#
# [5 rows x 101 columns]

# %%
len(y), len(y.value_counts())
# Out:
# (250000, 43)

# %% [markdown]
# So, it seems that we're actually looking at a classification problem here -- not a regression one.

# %% [markdown]
# # XGBRegressor

# %% [markdown]
# For the Sweep, you have to encapsulate your configs, your `wandb.init`, and everything else into a single function that will be called on each sweep iteration.

# %%
sweep_config = {
    "method": "grid", # try grid or random
    "metric": {
      "name": "rmse",
      "goal": "minimize"   
    },
    "parameters": {
        "booster": {
            "values": ["gbtree","gblinear"]
        },
        "max_depth": {
            "values": [20, 40, 60, 80]
        },
        "learning_rate": {
            "values": [0.1, 0.05, 0.2]
        },
        "subsample": {
            "values": [1, 0.5, 0.3]
        },
        "n_estimators": {
            "values": [50, 100, 150]
        }
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, project="202108_Kaggle_tabular_playground")
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Create sweep with ID: 4abje3y9
# Sweep URL: https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9

# %%
def train():
    config_defaults = {
        "library": "xgboost",
        "booster": "gbtree",
        "max_depth": 10,
        "learning_rate": 0.1,
        "subsample": 1,
        "seed": 42,
        "test_size": 0.2,
    }

    wandb.init(
        project="202108_Kaggle_tabular_playground",
        save_code=True,
        tags=['XGBoost'],
        name='202108080949_XGBRegressor_sweep',
        notes='Trying a Weights & Biases sweep on the XGBRegressor',
        config=config_defaults)
    
    config = wandb.config
        
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=config.test_size, random_state=config.seed)
    
    model = XGBRegressor(
        n_estimators=config.n_estimators, 
        max_depth=config.max_depth,
        booster=config.booster,
        learning_rate=config.learning_rate, 
        n_jobs=-1, 
        verbosity=1, 
        random_state=config.seed,
        subsample=config.subsample,
    )
    wandb.log({'params': model.get_params()})
    model.fit(X_train, y_train, callbacks=[wandb.xgboost.wandb_callback()])
    y_preds = model.predict(X_valid)
    mse = mean_squared_error(y_valid, y_preds)
    rmse = math.sqrt(abs(mse))
    wandb.log({'mse':mse, 'rmse':rmse})
    print(f"MSE is {mse}\nRMSE is {rmse}")

# %%
wandb.agent(sweep_id, train)
# Out:
# wandb: Agent Starting Run: xais54h8 with config:
# wandb: 	booster: gbtree
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 20
# wandb: 	n_estimators: 50
# wandb: 	subsample: 1
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: hushifang (use `wandb login --relogin` to force relogin)
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/xais54h8" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/xais54h8</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_095457-xais54h8</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# MSE is 64.14559821863554
# RMSE is 8.009094719045065
# <br/>Waiting for W&B process to finish, PID 304256<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_095457-xais54h8/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_095457-xais54h8/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>80</td></tr><tr><td>_timestamp</td><td>1628441778</td></tr><tr><td>_step</td><td>51</td></tr><tr><td>mse</td><td>64.1456</td></tr><tr><td>rmse</td><td>8.00909</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/xais54h8" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/xais54h8</a><br/>
# wandb: Agent Starting Run: x99mmhj2 with config:
# wandb: 	booster: gbtree
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 20
# wandb: 	n_estimators: 50
# wandb: 	subsample: 0.5
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/x99mmhj2" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/x99mmhj2</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_095622-x99mmhj2</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# MSE is 65.64768631626372
# RMSE is 8.102325981856303
# <br/>Waiting for W&B process to finish, PID 304445<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_095622-x99mmhj2/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_095622-x99mmhj2/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>61</td></tr><tr><td>_timestamp</td><td>1628441843</td></tr><tr><td>_step</td><td>51</td></tr><tr><td>mse</td><td>65.64769</td></tr><tr><td>rmse</td><td>8.10233</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/x99mmhj2" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/x99mmhj2</a><br/>
# wandb: Agent Starting Run: f24g4luv with config:
# wandb: 	booster: gbtree
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 20
# wandb: 	n_estimators: 50
# wandb: 	subsample: 0.3
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/f24g4luv" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/f24g4luv</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_095727-f24g4luv</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# MSE is 67.66510193405456
# RMSE is 8.225880009704406
# <br/>Waiting for W&B process to finish, PID 304527<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_095727-f24g4luv/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_095727-f24g4luv/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>47</td></tr><tr><td>_timestamp</td><td>1628441894</td></tr><tr><td>_step</td><td>51</td></tr><tr><td>mse</td><td>67.6651</td></tr><tr><td>rmse</td><td>8.22588</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/f24g4luv" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/f24g4luv</a><br/>
# wandb: Agent Starting Run: 34y1yooa with config:
# wandb: 	booster: gbtree
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 20
# wandb: 	n_estimators: 100
# wandb: 	subsample: 1
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/34y1yooa" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/34y1yooa</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_095817-34y1yooa</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# MSE is 64.44586140308544
# RMSE is 8.02781797271746
# <br/>Waiting for W&B process to finish, PID 304594<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_095817-34y1yooa/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_095817-34y1yooa/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>144</td></tr><tr><td>_timestamp</td><td>1628442042</td></tr><tr><td>_step</td><td>101</td></tr><tr><td>mse</td><td>64.44586</td></tr><tr><td>rmse</td><td>8.02782</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/34y1yooa" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/34y1yooa</a><br/>
# wandb: Agent Starting Run: y862eruq with config:
# wandb: 	booster: gbtree
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 20
# wandb: 	n_estimators: 100
# wandb: 	subsample: 0.5
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/y862eruq" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/y862eruq</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_100046-y862eruq</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# MSE is 66.69824134589031
# RMSE is 8.166899126712066
# <br/>Waiting for W&B process to finish, PID 304717<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_100046-y862eruq/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_100046-y862eruq/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>111</td></tr><tr><td>_timestamp</td><td>1628442157</td></tr><tr><td>_step</td><td>101</td></tr><tr><td>mse</td><td>66.69824</td></tr><tr><td>rmse</td><td>8.1669</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/y862eruq" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/y862eruq</a><br/>
# wandb: Agent Starting Run: p4fnjr9g with config:
# wandb: 	booster: gbtree
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 20
# wandb: 	n_estimators: 100
# wandb: 	subsample: 0.3
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/p4fnjr9g" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/p4fnjr9g</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_100240-p4fnjr9g</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# MSE is 69.59239211515525
# RMSE is 8.342205470686709
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# <br/>Waiting for W&B process to finish, PID 304817<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_100240-p4fnjr9g/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_100240-p4fnjr9g/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>87</td></tr><tr><td>_timestamp</td><td>1628442247</td></tr><tr><td>_step</td><td>101</td></tr><tr><td>mse</td><td>69.59239</td></tr><tr><td>rmse</td><td>8.34221</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/p4fnjr9g" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/p4fnjr9g</a><br/>
# wandb: Agent Starting Run: qzd0iuzx with config:
# wandb: 	booster: gbtree
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 20
# wandb: 	n_estimators: 150
# wandb: 	subsample: 1
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/qzd0iuzx" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/qzd0iuzx</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_100411-qzd0iuzx</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# MSE is 64.54827418086303
# RMSE is 8.03419405919866
# <br/>Waiting for W&B process to finish, PID 304921<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_100411-qzd0iuzx/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_100411-qzd0iuzx/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>216</td></tr><tr><td>_timestamp</td><td>1628442467</td></tr><tr><td>_step</td><td>151</td></tr><tr><td>mse</td><td>64.54827</td></tr><tr><td>rmse</td><td>8.03419</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/qzd0iuzx" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/qzd0iuzx</a><br/>
# wandb: Agent Starting Run: ck5zguwi with config:
# wandb: 	booster: gbtree
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 20
# wandb: 	n_estimators: 150
# wandb: 	subsample: 0.5
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ck5zguwi" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ck5zguwi</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_100750-ck5zguwi</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# MSE is 67.22931870437542
# RMSE is 8.199348675619023
# <br/>Waiting for W&B process to finish, PID 305101<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_100750-ck5zguwi/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_100750-ck5zguwi/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>184</td></tr><tr><td>_timestamp</td><td>1628442654</td></tr><tr><td>_step</td><td>151</td></tr><tr><td>mse</td><td>67.22932</td></tr><tr><td>rmse</td><td>8.19935</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ck5zguwi" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ck5zguwi</a><br/>
# wandb: Agent Starting Run: ipjluucm with config:
# wandb: 	booster: gbtree
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 20
# wandb: 	n_estimators: 150
# wandb: 	subsample: 0.3
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ipjluucm" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ipjluucm</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101057-ipjluucm</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# MSE is 70.95652687251325
# RMSE is 8.42356972265994
# <br/>Waiting for W&B process to finish, PID 305383<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101057-ipjluucm/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101057-ipjluucm/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>141</td></tr><tr><td>_timestamp</td><td>1628442798</td></tr><tr><td>_step</td><td>151</td></tr><tr><td>mse</td><td>70.95653</td></tr><tr><td>rmse</td><td>8.42357</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ipjluucm" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ipjluucm</a><br/>
# wandb: Agent Starting Run: rublhrxb with config:
# wandb: 	booster: gbtree
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 40
# wandb: 	n_estimators: 50
# wandb: 	subsample: 1
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/rublhrxb" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/rublhrxb</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101322-rublhrxb</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# MSE is 65.74321399024493
# RMSE is 8.108218916028656
# <br/>Waiting for W&B process to finish, PID 305668<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101322-rublhrxb/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101322-rublhrxb/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>151</td></tr><tr><td>_timestamp</td><td>1628442953</td></tr><tr><td>_step</td><td>51</td></tr><tr><td>mse</td><td>65.74321</td></tr><tr><td>rmse</td><td>8.10822</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/rublhrxb" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/rublhrxb</a><br/>
# wandb: Agent Starting Run: fff1r2w5 with config:
# wandb: 	booster: gbtree
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 40
# wandb: 	n_estimators: 50
# wandb: 	subsample: 0.5
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/fff1r2w5" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/fff1r2w5</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101557-fff1r2w5</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# MSE is 67.4938107990294
# RMSE is 8.215461691166809
# <br/>Waiting for W&B process to finish, PID 305774<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101557-fff1r2w5/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101557-fff1r2w5/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>126</td></tr><tr><td>_timestamp</td><td>1628443083</td></tr><tr><td>_step</td><td>51</td></tr><tr><td>mse</td><td>67.49381</td></tr><tr><td>rmse</td><td>8.21546</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/fff1r2w5" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/fff1r2w5</a><br/>
# wandb: Agent Starting Run: djausrfb with config:
# wandb: 	booster: gbtree
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 40
# wandb: 	n_estimators: 50
# wandb: 	subsample: 0.3
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/djausrfb" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/djausrfb</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101805-djausrfb</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# MSE is 70.54700267740863
# RMSE is 8.399226314215413
# <br/>Waiting for W&B process to finish, PID 305850<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101805-djausrfb/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101805-djausrfb/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>98</td></tr><tr><td>_timestamp</td><td>1628443184</td></tr><tr><td>_step</td><td>51</td></tr><tr><td>mse</td><td>70.547</td></tr><tr><td>rmse</td><td>8.39923</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/djausrfb" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/djausrfb</a><br/>
# wandb: Agent Starting Run: yyvq98fl with config:
# wandb: 	booster: gbtree
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 40
# wandb: 	n_estimators: 100
# wandb: 	subsample: 1
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/yyvq98fl" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/yyvq98fl</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101948-yyvq98fl</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(
# MSE is 65.78001474796618
# RMSE is 8.110487947587751
# <br/>Waiting for W&B process to finish, PID 305939<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101948-yyvq98fl/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_101948-yyvq98fl/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# ...
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# MSE is 62.09764970974484
# RMSE is 7.88020619715911
# <br/>Waiting for W&B process to finish, PID 330201<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181120-cy0hxx9s/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181120-cy0hxx9s/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>10</td></tr><tr><td>_timestamp</td><td>1628471490</td></tr><tr><td>_step</td><td>101</td></tr><tr><td>mse</td><td>62.09765</td></tr><tr><td>rmse</td><td>7.88021</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/cy0hxx9s" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/cy0hxx9s</a><br/>
# wandb: Agent Starting Run: of2833s4 with config:
# wandb: 	booster: gblinear
# wandb: 	learning_rate: 0.2
# wandb: 	max_depth: 80
# wandb: 	n_estimators: 100
# wandb: 	subsample: 0.3
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/of2833s4" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/of2833s4</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181136-of2833s4</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# MSE is 62.09666464326495
# RMSE is 7.880143694328483
# <br/>Waiting for W&B process to finish, PID 330268<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181136-of2833s4/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181136-of2833s4/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>10</td></tr><tr><td>_timestamp</td><td>1628471506</td></tr><tr><td>_step</td><td>101</td></tr><tr><td>mse</td><td>62.09666</td></tr><tr><td>rmse</td><td>7.88014</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/of2833s4" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/of2833s4</a><br/>
# wandb: Agent Starting Run: lb7hf51g with config:
# wandb: 	booster: gblinear
# wandb: 	learning_rate: 0.2
# wandb: 	max_depth: 80
# wandb: 	n_estimators: 150
# wandb: 	subsample: 1
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/lb7hf51g" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/lb7hf51g</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181151-lb7hf51g</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# MSE is 62.05976665239637
# RMSE is 7.877802146055482
# <br/>Waiting for W&B process to finish, PID 330314<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181151-lb7hf51g/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181151-lb7hf51g/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>12</td></tr><tr><td>_timestamp</td><td>1628471523</td></tr><tr><td>_step</td><td>151</td></tr><tr><td>mse</td><td>62.05977</td></tr><tr><td>rmse</td><td>7.8778</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/lb7hf51g" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/lb7hf51g</a><br/>
# wandb: Agent Starting Run: buhpjusx with config:
# wandb: 	booster: gblinear
# wandb: 	learning_rate: 0.2
# wandb: 	max_depth: 80
# wandb: 	n_estimators: 150
# wandb: 	subsample: 0.5
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/buhpjusx" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/buhpjusx</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181208-buhpjusx</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# MSE is 62.06348010845762
# RMSE is 7.878037833652337
# <br/>Waiting for W&B process to finish, PID 330358<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181208-buhpjusx/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181208-buhpjusx/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>12</td></tr><tr><td>_timestamp</td><td>1628471540</td></tr><tr><td>_step</td><td>151</td></tr><tr><td>mse</td><td>62.06348</td></tr><tr><td>rmse</td><td>7.87804</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/buhpjusx" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/buhpjusx</a><br/>
# wandb: Agent Starting Run: 3yyp9m64 with config:
# wandb: 	booster: gblinear
# wandb: 	learning_rate: 0.2
# wandb: 	max_depth: 80
# wandb: 	n_estimators: 150
# wandb: 	subsample: 0.3
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# wandb: wandb version 0.11.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/4abje3y9</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/3yyp9m64" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/3yyp9m64</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181231-3yyp9m64</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# MSE is 62.06108591323603
# RMSE is 7.877885878409005
# <br/>Waiting for W&B process to finish, PID 330421<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181231-3yyp9m64/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210808_181231-3yyp9m64/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>12</td></tr><tr><td>_timestamp</td><td>1628471563</td></tr><tr><td>_step</td><td>151</td></tr><tr><td>mse</td><td>62.06109</td></tr><tr><td>rmse</td><td>7.87789</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁█</td></tr><tr><td>_timestamp</td><td>▁█</td></tr><tr><td>_step</td><td>▁█</td></tr><tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108080949_XGBRegressor_sweep</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/3yyp9m64" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/3yyp9m64</a><br/>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.

# %% [markdown]
# # Old:

# %%
model.fit(X_train, y_train, callbacks=[wandb.xgboost.wandb_callback()])
# model.fit(X, y)
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=200, n_jobs=-1, num_parallel_tree=1, random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=1)

# %%
# wandb.sklearn.plot_regressor(model, X_train, X_valid, y_train, y_valid,  model_name='RandomForestRegressor', )

# %%
# y_pred = model.predict(X_valid)

# %%
# from sklearn.model_selection import cross_val_score

# %%
# scores = cross_val_score(model, X, y, cv=5, n_jobs=-1)

# %%
# model.get_depth()

# %%
y_valid_preds = model.predict(X_valid)
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
mse = mean_squared_error(y_valid, y_valid_preds)

# %%
mse
# Out:
# 61.500556614829804

# %%
rmse = math.sqrt(mse)
rmse
# Out:
# 7.842229059064126

# %%
wandb.log({'rmse': rmse, 'mse': mse, 'y_valid_preds': y_valid_preds})

# %%
# rmses = [math.sqrt(abs(score)) for score in scores]
# rmses

# %% [markdown]
# Let's give that a submit...

# %%
test_df = pd.read_csv(datapath/'test.csv', index_col='id', low_memory=False)

# %%
test_df.head()
# Out:
#               f0   f1        f2        f3          f4        f5         f6  \
# id
# 250000  0.812665   15 -1.239120 -0.893251    295.5770  15.87120   23.04360
# 250001  0.190344  131 -0.501361  0.801921     64.8866   3.09703  344.80500
# 250002  0.919671   19 -0.057382  0.901419  11961.2000  16.39650  273.24000
# 250003  0.860985   19 -0.549509  0.471799   7501.6000   2.80698   71.08170
# 250004  0.313229   89  0.588509  0.167705   2931.2600   4.34986    1.57187
#
#               f7         f8       f9  ...       f90        f91       f92  \
# id                                    ...
# 250000  0.942256  29.898000  1.11394  ...  0.446389   -422.332  -1.44630
# 250001  0.807194  38.421900  1.09695  ...  0.377179  10352.200  21.06270
# 250002 -0.003300  37.940000  1.15222  ...  0.990140   3224.020  -2.25287
# 250003  0.792136   0.395235  1.20157  ...  1.396880   9689.760  14.77150
# 250004  1.118300   7.754630  1.16807  ...  0.862502   2693.350  44.18050
#
#             f93       f94        f95      f96       f97       f98       f99
# id
# 250000  1.69075  1.059300  -3.010570  1.94664  0.529470  1.386950   8.78767
# 250001  1.84351  0.251895   4.440570  1.90309  0.248534  0.863881  11.79390
# 250002  1.55100 -0.559157  17.838600  1.83385  0.931796  2.336870   9.05400
# 250003  1.41390  0.329272   0.802437  2.23251  0.893348  1.359470   4.84833
# 250004  1.58020 -0.191021  26.253000  2.68238  0.361923  1.532800   3.70660
#
# [5 rows x 100 columns]

# %%
X_test = test_df[features] # this is just for naming consistency

# %%
y_test_preds = model.predict(X_test)
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
sample_df = pd.read_csv(datapath/'sample_submission.csv')

# %%
sample_df.loc[:, 'loss'] = y_test_preds

# %%
sample_df.head()
# Out:
#        id      loss
# 0  250000  7.328520
# 1  250001  4.610067
# 2  250002  7.277142
# 3  250003  7.030011
# 4  250004  7.187167

# %%
sample_df.to_csv('202108062038_XGBoost.csv', index=False)

# %%
wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 250093<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210806_204810-1oaq8jy8/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/202108_august/wandb/run-20210806_204810-1oaq8jy8/logs/debug-internal.log</code>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">202108062041_RandomForestRegressor</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/1oaq8jy8" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/1oaq8jy8</a><br/>
