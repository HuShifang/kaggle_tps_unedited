# %% [markdown]
# Notebook for doing inference only with an ensemble -- experiments are conducted elsewhere. Model is as stated; `MaxAbsScaler` and `SelectKBest(k=80)` seem to be the best options as of 20210824. (Though model hyperparams haven't been fine-tuned with the scaler and the feature selector as of yet.) **And they should be, since performance is down!**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# general ML tooling
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
import wandb
from wandb.xgboost import wandb_callback
# import timm
from pathlib import Path
import os
import math
import seaborn as sns
from datetime import datetime

from xgboost import XGBRegressor
# from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MaxAbsScaler, StandardScaler, MinMaxScaler, RobustScaler, PolynomialFeatures
from sklearn.feature_selection import SelectKBest, f_regression
from joblib import dump, load
# feature engineering tools
# from sklearn.feature_selection import mutual_info_regression
# import featuretools as ft

# %%
# %matplotlib inline
# %config Completer.use_jedi = False
os.environ['WANDB_NOTEBOOK_NAME'] = 'XGBoost_hyperparameter_sweep_20210827.ipynb'

# defining default config here; n_estimators, learning_rate, scaler, reg_alpha, and reg_lambda will be the variables
config_defaults = {
    # model config
    "wandb": True,
    "model":XGBRegressor,
    "tree_method": "auto", # set to 'gpu_hist' to try GPU if available
    "booster": 'gbtree', # dart may be marginally better, but will opt for this quicker approach as a default
    "n_estimators": 50, 
    "max_depth": 3,
    "learning_rate": 0.1522,
    "test_size": 0.2,
    "scaler": MaxAbsScaler,
#     "feature_selector": SelectKBest,
#     "k_best": 80,
#     "feature_selection_scoring": f_regression,
    'random_state': 42,
    'subsample': 1,
    'n_jobs': -1,
    'verbosity': 1,
    'k_folds': 1,
    'feature_creator': PolynomialFeatures,
    'features_selection': 'manual_by_importance',
}

config_run = {
    # wandb config:
    'name': f"{os.environ['WANDB_NOTEBOOK_NAME'][:-6]}_{datetime.now().strftime('%H%M%S')}", # just removes the .ipynb extension, leaving the notebook filename's stem
    'tags': ['XGBoost', 'kfold', 'scaling', 'baseline'],
    'notes': "Control run for 50-estimator run with features created with PolynomialFeatures",
}

# %%
# second tree sweep
sweep_config = {
    "method": "bayes", # try grid or random
    "metric": {
      "name": "rmse",
      "goal": "minimize"   
    },
    "parameters": {
        "max_depth": {
            "distribution": "int_uniform", 
            "min": 2,
            "max": 5,
        },
        "learning_rate": {
            "distribution": "uniform", 
            "min": 0.001,
            "max": 0.3
            #             "values": [0.1, 0.2, 0.3]
        },
        "n_estimators": {
            "distribution": "int_uniform",
            "min": 300,
            "max": 5000,
#             "values": [50, 125, 200]
        },
#         "scaler": {
#             "distribution": "constant",
#             "values": [MaxAbsScaler, StandardScaler, MinMaxScaler, RobustScaler],
#         },
        "reg_alpha": {
            "distribution": "uniform",
            "min": 0,
            "max": 3,
        },
        "reg_lambda": {
            "distribution": "uniform",
            "min": 1,
            "max": 5,
        },
        "subsample": {
            "distribution": "uniform",
            "min": 0.5,
            "max": 1,
        }
    }
}

# %%
# datapath = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/202108_august/')

# %%
# df = pd.read_csv(datapath/'train.csv', index_col='id', low_memory=False)
# df.index.name = None
# df.to_feather(path='./dataset_df.feather')

# load unaltered dataset
# df = pd.read_feather(path='dataset_df.feather')
# df.index.name = 'id'

# %%
# y = df.loss

# %%
# load all the polynomialfeatures generated with `PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)`
# X_np = np.load(datapath/'X_poly_unscaled.npy')
# X = pd.DataFrame(X_np)

# %%
# X.columns

# %%
# # prep features from unaltered dataset
# features = [x for x in df.columns if x != 'loss']
# X = df[features]

# %% [markdown]
# # Feature Creation

# %%
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_poly = poly.fit_transform(X)

# %%
# X_poly_names = poly.get_feature_names(X.columns)

# %%
# X = pd.DataFrame(X_poly, columns=X_poly_names)

# %% [markdown]
# # Scaling
# Now, going to scale using `MaxAbsScaler`

# %%
# scaler = config['scaler']()
# X = scaler.fit_transform(X)

# %% [markdown]
# # Training Function

# %%
# datapath = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/202108_august/')
# df = pd.read_feather(path='dataset_df.feather')
# df.index.name = 'id'
# y = df.loss
# features = [x for x in df.columns if x != 'loss']
# X = df[features]
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_poly = poly.fit_transform(X)
# X_poly_names = poly.get_feature_names(X.columns)
# X = pd.DataFrame(X_poly, columns=X_poly_names)
# scaler = MaxAbsScaler()
# X_scaled = scaler.fit_transform(X)
# features = pd.read_csv('X_candidates_20210827.csv').columns
# print(len(features))
# X_scaled_df = pd.DataFrame(X_scaled, columns=X_poly_names)

# %%
# features[1:]

# %%
# X_final = X_scaled_df[features[1:]]

# %%
# X_final.head()

# %%
# X_scaled_df.loc[:, 'f25'].head()

# %%
# X.columns

# %%
def train_sweep(): #X_train, X_valid, y_train, y_valid, config):#, scaler): # passed in via config dict for now
    """
    Basic training function. Note that some of the options passed via the argument are
    in fact hard-coded in, to avoid inconveniences.
    :param config: dict with things to be logged in WandB, some to be used in function
    """
    
    
#     if config['wandb']:
    wandb.init(config=config_defaults)   
    config = wandb.config
    datapath = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/202108_august/')
    df = pd.read_feather(path='dataset_df.feather')
    df.index.name = 'id'
    y = df.loss
    features = [x for x in df.columns if x != 'loss']
    X = df[features]
    poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
    X_poly = poly.fit_transform(X)
    X_poly_names = poly.get_feature_names(X.columns)
    X = pd.DataFrame(X_poly, columns=X_poly_names)
    scaler = MaxAbsScaler()
    X_scaled = scaler.fit_transform(X)
    X_scaled_df = pd.DataFrame(X_scaled, columns=X_poly_names)
    features = pd.read_csv('X_candidates_20210827.csv').columns
    X = X_scaled_df[features[1:]]
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
                                                          test_size=config['test_size'], 
                                                          random_state=config['random_state']
                                                         )
    
    
    # selecting features
#     selector = config['feature_selector'](score_func=config["feature_selection_scoring"], 
#                                           k=config['k_best'])
#     X_train_fs = selector.fit_transform(X_train_s, y_train)
#     X_valid_fs = X_valid_s[:, selector.get_support()] # ensures same features are used in validation

    # split the dataset
    model = XGBRegressor(
        tree_method=config['tree_method'],
        booster=config['booster'],
        n_estimators=config['n_estimators'], 
        max_depth=config['max_depth'],
        learning_rate=config['learning_rate'], 
        reg_alpha=config['reg_alpha'],
        reg_lambda=config['reg_lambda'],
#         test_size=config['test_size'],
        subsample=config['subsample'],
        random_state=config['random_state'],
        n_jobs=config['n_jobs'], 
        verbosity=config['verbosity'], 
    )
#     wandb.log({'params': model.get_params()}) # logging model parameters
#     if config['wandb']:
    model.fit(X_train, y_train, callbacks=[wandb.xgboost.wandb_callback()])
    y_preds = model.predict(X_valid)
    mse = mean_squared_error(y_valid, y_preds)
    rmse = math.sqrt(abs(mse))
#     print(f"MSE is {mse}\nRMSE is {rmse}")   
#     if config['wandb']:
    wandb.log({'mse':mse, 'rmse':rmse})
#     wandb.finish()   
#     return model

# %% [markdown]
# # Hyperparameter Sweep

# %%
sweep_id = wandb.sweep(sweep_config, project="202108_Kaggle_tabular_playground")
# Out:
# Create sweep with ID: e9uzmfqp
# Sweep URL: https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp

# %%
wandb.agent(sweep_id, train_sweep)
# Out:
# wandb: Agent Starting Run: 4iqp392v with config:
# wandb: 	learning_rate: 0.24315213346025308
# wandb: 	max_depth: 2
# wandb: 	n_estimators: 1624
# wandb: 	reg_alpha: 1.6676014177903533
# wandb: 	reg_lambda: 3.776474007640686
# wandb: 	subsample: 0.9066273919369642
# wandb: Currently logged in as: hushifang (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">clear-sweep-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/4iqp392v" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/4iqp392v</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_212304-4iqp392v</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 392904<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_212304-4iqp392v/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_212304-4iqp392v/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>62.23047</td></tr><tr><td>rmse</td><td>7.88863</td></tr><tr><td>_runtime</td><td>480</td></tr><tr><td>_timestamp</td><td>1630125064</td></tr><tr><td>_step</td><td>1624</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">clear-sweep-1</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/4iqp392v" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/4iqp392v</a><br/>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: cagdkkft with config:
# wandb: 	learning_rate: 0.09183493419166489
# wandb: 	max_depth: 3
# wandb: 	n_estimators: 3373
# wandb: 	reg_alpha: 2.8553087490567552
# wandb: 	reg_lambda: 1.806837450845915
# wandb: 	subsample: 0.9672187042459595
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">wild-sweep-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/cagdkkft" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/cagdkkft</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_213138-cagdkkft</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 393080<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_213138-cagdkkft/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_213138-cagdkkft/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>62.11176</td></tr><tr><td>rmse</td><td>7.8811</td></tr><tr><td>_runtime</td><td>1441</td></tr><tr><td>_timestamp</td><td>1630126539</td></tr><tr><td>_step</td><td>3373</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">wild-sweep-2</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/cagdkkft" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/cagdkkft</a><br/>
# wandb: Agent Starting Run: giwarqau with config:
# wandb: 	learning_rate: 0.11666580390152395
# wandb: 	max_depth: 3
# wandb: 	n_estimators: 2719
# wandb: 	reg_alpha: 1.2085944196595286
# wandb: 	reg_lambda: 4.82160880197978
# wandb: 	subsample: 0.723530838922178
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">distinctive-sweep-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/giwarqau" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/giwarqau</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_215543-giwarqau</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 393293<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_215543-giwarqau/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_215543-giwarqau/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>62.59399</td></tr><tr><td>rmse</td><td>7.91164</td></tr><tr><td>_runtime</td><td>1019</td></tr><tr><td>_timestamp</td><td>1630127562</td></tr><tr><td>_step</td><td>2719</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">distinctive-sweep-3</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/giwarqau" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/giwarqau</a><br/>
# wandb: Agent Starting Run: ss8mibp5 with config:
# wandb: 	learning_rate: 0.23418667333483345
# wandb: 	max_depth: 3
# wandb: 	n_estimators: 1646
# wandb: 	reg_alpha: 2.729344115177481
# wandb: 	reg_lambda: 4.025240426089821
# wandb: 	subsample: 0.9479074463179945
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">pious-sweep-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ss8mibp5" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ss8mibp5</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_221246-ss8mibp5</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 393444<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_221246-ss8mibp5/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_221246-ss8mibp5/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>63.14473</td></tr><tr><td>rmse</td><td>7.94637</td></tr><tr><td>_runtime</td><td>711</td></tr><tr><td>_timestamp</td><td>1630128277</td></tr><tr><td>_step</td><td>1646</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">pious-sweep-4</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ss8mibp5" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ss8mibp5</a><br/>
# wandb: Agent Starting Run: x7pbp60z with config:
# wandb: 	learning_rate: 0.18348960158813316
# wandb: 	max_depth: 3
# wandb: 	n_estimators: 2719
# wandb: 	reg_alpha: 1.004666687609094
# wandb: 	reg_lambda: 2.865677536928833
# wandb: 	subsample: 0.9843546507091991
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">brisk-sweep-5</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/x7pbp60z" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/x7pbp60z</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_222441-x7pbp60z</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 393580<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_222441-x7pbp60z/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_222441-x7pbp60z/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>63.01451</td></tr><tr><td>rmse</td><td>7.93817</td></tr><tr><td>_runtime</td><td>1179</td></tr><tr><td>_timestamp</td><td>1630129460</td></tr><tr><td>_step</td><td>2719</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">brisk-sweep-5</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/x7pbp60z" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/x7pbp60z</a><br/>
# wandb: Agent Starting Run: axl50145 with config:
# wandb: 	learning_rate: 0.20370556518372673
# wandb: 	max_depth: 4
# wandb: 	n_estimators: 1251
# wandb: 	reg_alpha: 2.8275771048482587
# wandb: 	reg_lambda: 4.887504241211965
# wandb: 	subsample: 0.9118960873425952
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">glamorous-sweep-6</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/axl50145" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/axl50145</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_224423-axl50145</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 396021<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_224423-axl50145/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_224423-axl50145/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>63.50695</td></tr><tr><td>rmse</td><td>7.96913</td></tr><tr><td>_runtime</td><td>705</td></tr><tr><td>_timestamp</td><td>1630130168</td></tr><tr><td>_step</td><td>1251</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">glamorous-sweep-6</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/axl50145" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/axl50145</a><br/>
# wandb: Agent Starting Run: hpcfefdn with config:
# wandb: 	learning_rate: 0.2530770053436926
# wandb: 	max_depth: 3
# wandb: 	n_estimators: 1947
# wandb: 	reg_alpha: 1.742538826030308
# wandb: 	reg_lambda: 3.397542085828421
# wandb: 	subsample: 0.8337671326171443
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">eternal-sweep-7</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/hpcfefdn" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/hpcfefdn</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_225612-hpcfefdn</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 396144<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_225612-hpcfefdn/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_225612-hpcfefdn/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>64.17844</td></tr><tr><td>rmse</td><td>8.01114</td></tr><tr><td>_runtime</td><td>783</td></tr><tr><td>_timestamp</td><td>1630130955</td></tr><tr><td>_step</td><td>1947</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">eternal-sweep-7</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/hpcfefdn" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/hpcfefdn</a><br/>
# wandb: Agent Starting Run: tte73rin with config:
# wandb: 	learning_rate: 0.2704201611378869
# wandb: 	max_depth: 2
# wandb: 	n_estimators: 4391
# wandb: 	reg_alpha: 0.20602149825652494
# wandb: 	reg_lambda: 1.9184786912398177
# wandb: 	subsample: 0.981789400241704
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">balmy-sweep-8</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/tte73rin" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/tte73rin</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_230919-tte73rin</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 396293<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_230919-tte73rin/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_230919-tte73rin/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>63.781</td></tr><tr><td>rmse</td><td>7.9863</td></tr><tr><td>_runtime</td><td>1293</td></tr><tr><td>_timestamp</td><td>1630132252</td></tr><tr><td>_step</td><td>4391</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">balmy-sweep-8</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/tte73rin" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/tte73rin</a><br/>
# wandb: Agent Starting Run: hzyo9c40 with config:
# wandb: 	learning_rate: 0.20248492070952057
# wandb: 	max_depth: 4
# wandb: 	n_estimators: 2679
# wandb: 	reg_alpha: 0.2437358197037952
# wandb: 	reg_lambda: 2.222299438913913
# wandb: 	subsample: 0.7172385603971918
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">soft-sweep-9</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/hzyo9c40" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/hzyo9c40</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_233057-hzyo9c40</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 396444<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_233057-hzyo9c40/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_233057-hzyo9c40/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>66.75301</td></tr><tr><td>rmse</td><td>8.17025</td></tr><tr><td>_runtime</td><td>1320</td></tr><tr><td>_timestamp</td><td>1630133577</td></tr><tr><td>_step</td><td>2679</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">soft-sweep-9</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/hzyo9c40" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/hzyo9c40</a><br/>
# wandb: Agent Starting Run: p21ibvv4 with config:
# wandb: 	learning_rate: 0.09678056498193528
# wandb: 	max_depth: 4
# wandb: 	n_estimators: 2610
# wandb: 	reg_alpha: 0.2585034959562287
# wandb: 	reg_lambda: 3.5604472349257725
# wandb: 	subsample: 0.8510709034335878
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">sparkling-sweep-10</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/p21ibvv4" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/p21ibvv4</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_235301-p21ibvv4</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 396628<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_235301-p21ibvv4/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210827_235301-p21ibvv4/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>62.70675</td></tr><tr><td>rmse</td><td>7.91876</td></tr><tr><td>_runtime</td><td>1383</td></tr><tr><td>_timestamp</td><td>1630134964</td></tr><tr><td>_step</td><td>2610</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">sparkling-sweep-10</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/p21ibvv4" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/p21ibvv4</a><br/>
# wandb: Agent Starting Run: edyvdwro with config:
# wandb: 	learning_rate: 0.1307865175644529
# wandb: 	max_depth: 4
# wandb: 	n_estimators: 4020
# wandb: 	reg_alpha: 0.32976989187174743
# wandb: 	reg_lambda: 2.232415821623973
# wandb: 	subsample: 0.5572255221717876
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">giddy-sweep-11</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/edyvdwro" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/edyvdwro</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_001607-edyvdwro</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 396842<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_001607-edyvdwro/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_001607-edyvdwro/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>66.2449</td></tr><tr><td>rmse</td><td>8.1391</td></tr><tr><td>_runtime</td><td>1789</td></tr><tr><td>_timestamp</td><td>1630136756</td></tr><tr><td>_step</td><td>4020</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">giddy-sweep-11</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/edyvdwro" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/edyvdwro</a><br/>
# wandb: Agent Starting Run: pfog71wc with config:
# wandb: 	learning_rate: 0.09295634389692974
# wandb: 	max_depth: 3
# wandb: 	n_estimators: 2737
# wandb: 	reg_alpha: 1.779036802817918
# wandb: 	reg_lambda: 4.481750604690807
# wandb: 	subsample: 0.9315255188623558
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">clear-sweep-12</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/pfog71wc" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/pfog71wc</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_004559-pfog71wc</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 397011<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_004559-pfog71wc/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_004559-pfog71wc/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>61.93963</td></tr><tr><td>rmse</td><td>7.87017</td></tr><tr><td>_runtime</td><td>1152</td></tr><tr><td>_timestamp</td><td>1630137911</td></tr><tr><td>_step</td><td>2737</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">clear-sweep-12</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/pfog71wc" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/pfog71wc</a><br/>
# wandb: Agent Starting Run: ybutjcyg with config:
# wandb: 	learning_rate: 0.10723963941997171
# wandb: 	max_depth: 2
# wandb: 	n_estimators: 1224
# wandb: 	reg_alpha: 1.3995578269078734
# wandb: 	reg_lambda: 4.6973303662767325
# wandb: 	subsample: 0.922490510077348
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">hearty-sweep-13</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ybutjcyg" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ybutjcyg</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_010516-ybutjcyg</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 397146<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_010516-ybutjcyg/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_010516-ybutjcyg/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>61.476</td></tr><tr><td>rmse</td><td>7.84066</td></tr><tr><td>_runtime</td><td>368</td></tr><tr><td>_timestamp</td><td>1630138284</td></tr><tr><td>_step</td><td>1224</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">hearty-sweep-13</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ybutjcyg" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/ybutjcyg</a><br/>
# wandb: Agent Starting Run: nckm55e3 with config:
# wandb: 	learning_rate: 0.034657985893215296
# wandb: 	max_depth: 2
# wandb: 	n_estimators: 2246
# wandb: 	reg_alpha: 1.425984860160536
# wandb: 	reg_lambda: 4.5138523098914325
# wandb: 	subsample: 0.9008872456854127
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">golden-sweep-14</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/nckm55e3" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/nckm55e3</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_011128-nckm55e3</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 397266<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_011128-nckm55e3/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_011128-nckm55e3/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>61.42455</td></tr><tr><td>rmse</td><td>7.83738</td></tr><tr><td>_runtime</td><td>647</td></tr><tr><td>_timestamp</td><td>1630138935</td></tr><tr><td>_step</td><td>2246</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">golden-sweep-14</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/nckm55e3" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/nckm55e3</a><br/>
# wandb: Agent Starting Run: paucsvqw with config:
# wandb: 	learning_rate: 0.0442154903454062
# wandb: 	max_depth: 2
# wandb: 	n_estimators: 2997
# wandb: 	reg_alpha: 2.042274483893973
# wandb: 	reg_lambda: 3.4135041189604047
# wandb: 	subsample: 0.9868821086047208
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">royal-sweep-15</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/paucsvqw" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/paucsvqw</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_012218-paucsvqw</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 397384<br/>Program ended successfully.
# ...
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">stellar-sweep-209</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/q07bqfx7" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/q07bqfx7</a><br/>
# wandb: Agent Starting Run: oteqqzju with config:
# wandb: 	learning_rate: 0.15635014154160884
# wandb: 	max_depth: 2
# wandb: 	n_estimators: 983
# wandb: 	reg_alpha: 1.6540724830960003
# wandb: 	reg_lambda: 2.515482814629549
# wandb: 	subsample: 0.9375582287267563
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">jumping-sweep-210</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/oteqqzju" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/oteqqzju</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_211537-oteqqzju</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 429367<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_211537-oteqqzju/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_211537-oteqqzju/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>61.51636</td></tr><tr><td>rmse</td><td>7.84324</td></tr><tr><td>_runtime</td><td>303</td></tr><tr><td>_timestamp</td><td>1630210840</td></tr><tr><td>_step</td><td>983</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">jumping-sweep-210</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/oteqqzju" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/oteqqzju</a><br/>
# wandb: Agent Starting Run: wcib1jd9 with config:
# wandb: 	learning_rate: 0.11114807279664506
# wandb: 	max_depth: 2
# wandb: 	n_estimators: 1337
# wandb: 	reg_alpha: 2.417597320724621
# wandb: 	reg_lambda: 3.7725410617467863
# wandb: 	subsample: 0.9185258937146813
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">trim-sweep-211</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/wcib1jd9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/wcib1jd9</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_212044-wcib1jd9</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 429502<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_212044-wcib1jd9/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_212044-wcib1jd9/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>61.50142</td></tr><tr><td>rmse</td><td>7.84228</td></tr><tr><td>_runtime</td><td>398</td></tr><tr><td>_timestamp</td><td>1630211243</td></tr><tr><td>_step</td><td>1337</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">trim-sweep-211</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/wcib1jd9" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/wcib1jd9</a><br/>
# wandb: Agent Starting Run: 6x41tksl with config:
# wandb: 	learning_rate: 0.16120238915389365
# wandb: 	max_depth: 2
# wandb: 	n_estimators: 373
# wandb: 	reg_alpha: 1.9069804842036011
# wandb: 	reg_lambda: 3.8917425350002293
# wandb: 	subsample: 0.8242203248047268
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">silvery-sweep-212</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/6x41tksl" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/6x41tksl</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_212726-6x41tksl</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 429676<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_212726-6x41tksl/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_212726-6x41tksl/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>61.50232</td></tr><tr><td>rmse</td><td>7.84234</td></tr><tr><td>_runtime</td><td>126</td></tr><tr><td>_timestamp</td><td>1630211372</td></tr><tr><td>_step</td><td>373</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">silvery-sweep-212</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/6x41tksl" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/6x41tksl</a><br/>
# wandb: Agent Starting Run: cijzmhwh with config:
# wandb: 	learning_rate: 0.12342537117716633
# wandb: 	max_depth: 2
# wandb: 	n_estimators: 422
# wandb: 	reg_alpha: 2.0361960251758626
# wandb: 	reg_lambda: 2.7350850026327156
# wandb: 	subsample: 0.8017725117036976
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">super-sweep-213</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/cijzmhwh" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/cijzmhwh</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_212936-cijzmhwh</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# <br/>Waiting for W&B process to finish, PID 429782<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_212936-cijzmhwh/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_212936-cijzmhwh/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>61.48504</td></tr><tr><td>rmse</td><td>7.84124</td></tr><tr><td>_runtime</td><td>142</td></tr><tr><td>_timestamp</td><td>1630211518</td></tr><tr><td>_step</td><td>422</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>mse</td><td>▁</td></tr><tr><td>rmse</td><td>▁</td></tr><tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">super-sweep-213</strong>: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/cijzmhwh" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/cijzmhwh</a><br/>
# wandb: Agent Starting Run: 9wu1x5uf with config:
# wandb: 	learning_rate: 0.14736046933685948
# wandb: 	max_depth: 2
# wandb: 	n_estimators: 905
# wandb: 	reg_alpha: 1.472455466378075
# wandb: 	reg_lambda: 4.158540427967519
# wandb: 	subsample: 0.8948090304836148
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">polar-sweep-214</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground</a><br/>
#                 Sweep page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/sweeps/e9uzmfqp</a><br/>
# Run page: <a href="https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/9wu1x5uf" target="_blank">https://wandb.ai/hushifang/202108_Kaggle_tabular_playground/runs/9wu1x5uf</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/wandb/run-20210828_213202-9wu1x5uf</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# wandb: Ctrl + C detected. Stopping sweep.
# <br/>Waiting for W&B process to finish, PID 429858<br/>Program failed with code 1.  Press ctrl-c to abort syncing.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
