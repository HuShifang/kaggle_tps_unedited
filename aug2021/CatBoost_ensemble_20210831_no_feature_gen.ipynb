# %% [markdown]
# Notebook for doing inference only with an ensemble -- experiments are conducted elsewhere. Model is as stated; `MaxAbsScaler` and `SelectKBest(k=80)` seem to be the best options as of 20210824. (Though model hyperparams haven't been fine-tuned with the scaler and the feature selector as of yet.) **And they should be, since performance is down!**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# general ML tooling
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
import wandb
from wandb.xgboost import wandb_callback
# import timm
from pathlib import Path
import os
import math
import seaborn as sns
from datetime import datetime

from catboost import CatBoostRegressor
from xgboost import XGBRegressor
# from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MaxAbsScaler, StandardScaler, MinMaxScaler, PolynomialFeatures
from sklearn.feature_selection import SelectKBest, f_regression
from joblib import dump, load
# feature engineering tools
# from sklearn.feature_selection import mutual_info_regression
# import featuretools as ft

# %%
# %matplotlib inline
# %config Completer.use_jedi = False
os.environ['WANDB_NOTEBOOK_NAME'] = 'XGBoost_ensemble_20210830.ipynb'
config = {
    # model config
    "model":XGBRegressor,
    "tree_method": "auto", # set to 'gpu_hist' to try GPU if available
    "booster": 'dart', # dart may be marginally better, but will opt for this quicker approach as a default
    "n_estimators": 3000, 
    "max_depth": 3,
    "learning_rate": 0.1522,
    "test_size": 0.2,
    "scaler": MaxAbsScaler,
    "task_type": "GPU", # for CatBoost only
#     "reg_alpha": 2.8,
#     "reg_lambda": 3.987,
#     "feature_selector": SelectKBest,
#     "k_best": 80,
#     "feature_selection_scoring": f_regression,
    'random_state': 42,
    'subsample': 1,
    'n_jobs': -1,
    'verbosity': 1,
    'k_folds': 5,
    'features_created': False,
    'feature_creator': None,
}

config_run = {
    # wandb config:
    'name': f"{os.environ['WANDB_NOTEBOOK_NAME'][:-6]}_{datetime.now().strftime('%H%M%S')}", # just removes the .ipynb extension, leaving the notebook filename's stem
    'tags': ['XGBoost', 'kfold', 'scaling', 'feature-creation', 'feature-selection'],
    'notes': "Running most of the parameters from the run j7tlo010 from the sweep b2zv3fsy, the most successful yet; just increasing n_estimators from 400 to 1000 and adding k-fold, feature generation/selection, etc",
}

# %%
datapath = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/202108_august/')

# %%
# df = pd.read_csv(datapath/'train.csv', index_col='id', low_memory=False)
# df.index.name = None
# df.to_feather(path='./dataset_df.feather')

# load unaltered dataset
df = pd.read_feather(path='dataset_df.feather')
df.index.name = 'id'

# %%
y = df.loss

# %% [markdown]
# # Feature Creation and Selection

# %%
# load all the polynomialfeatures generated with `PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)`
# X_np = np.load(datapath/'X_poly_unscaled.npy')
# X = pd.DataFrame(X_np)

# %%
# X.columns

# %%
# prep features from unaltered dataset
features = [x for x in df.columns if x != 'loss']
X = df[features]

# %%
# generation polynomial features
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_poly = poly.fit_transform(X)

# %%
# X_poly_names = poly.get_feature_names(X.columns)
# # X_poly_names[100:150]
# features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
# checks = [feature in X_poly_names for feature in features]
# checks

# %%
# X = pd.DataFrame(X_poly, columns=X_poly_names)

# %%
# X = X[features[1:]]

# %% [markdown]
# # Scaling
# Now, going to scale using `MaxAbsScaler`

# %%
scaler = config['scaler']()
X_scaled = scaler.fit_transform(X)
# X_scaled_df = pd.DataFrame(X_scaled, columns=X_poly_names)

# %% [markdown]
# # K-fold Cross-validation

# %%
# ACTUALLY probably better to save those as pickles or .npy files; I'll generate them later, regardless
# results = {} # for storing k-fold models' predictions

# %%
kfold = KFold(n_splits=config['k_folds'], shuffle=True, random_state=config['random_state'])

# %%
def train(X_train, X_valid, y_train, y_valid, config):#, scaler): # passed in via config dict for now
    """
    Basic training function. Note that some of the options passed via the argument are
    in fact hard-coded in, to avoid inconveniences.
    :param config: dict with things to be logged in WandB, some to be used in function
    """
    
    
#     wandb.init(
#         project="202108_Kaggle_tabular_playground",
#         save_code=True,
#         tags=config_run['tags'],
#         name=config_run['name'],
#         notes=config_run['notes'],
#         config=config)   
        
    # applying hold-out before scaling
#     X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
#                                                           test_size=config['test_size'], 
#                                                           random_state=config['random_state']
#                                                          )
    
    # strictly speaking should do the below, but doing beforehand faster and fine in this context
    # scaling (i.e. normalizing)
#     scaler = config['scaler']()
#     X_train_s = scaler.fit_transform(X_train)
#     X_valid_s = scaler.fit_transform(X_valid)
    
    # selecting features
#     selector = config['feature_selector'](score_func=config["feature_selection_scoring"], 
#                                           k=config['k_best'])
#     X_train_fs = selector.fit_transform(X_train_s, y_train)
#     X_valid_fs = X_valid_s[:, selector.get_support()] # ensures same features are used in validation

    # split the dataset
    model = CatBoostRegressor(
        n_estimators=config['n_estimators'],
        learning_rate=config['learning_rate'],
        max_depth=config['max_depth'],
        task_type=config['task_type'],
#         n_jobs=config['n_jobs'],
#         verbosity=config['verbosity'],
#         subsample=config['subsample'],
        random_state=config['random_state'],
#         bootstrap_type=config['bootstrap_type'],
#         device:config['device']
    ) 

#     model = XGBRegressor(
#         tree_method=config['tree_method'],
#         booster=config['booster'],
#         n_estimators=config['n_estimators'], 
#         max_depth=config['max_depth'],
#         learning_rate=config['learning_rate'], 
# #         test_size=config['test_size'],
#         subsample=config['subsample'],
#         reg_alpha=config['reg_alpha'],
#         reg_lambda=config['reg_lambda'],
#         random_state=config['random_state'],
#         n_jobs=config['n_jobs'], 
#         verbosity=config['verbosity'], 
#     )
#     wandb.log({'params': model.get_params()}) # logging model parameters
    model.fit(X_train, y_train)#, callbacks=[wandb.xgboost.wandb_callback()])
    y_preds = model.predict(X_valid)
    mse = mean_squared_error(y_valid, y_preds)
    rmse = math.sqrt(abs(mse))
#     wandb.log({'mse':mse, 'rmse':rmse})
    print(f"MSE is {mse}\nRMSE is {rmse}")   
#     wandb.finish()   
    return model

# %%
models = {}

# %%
model_path = Path(f"./models/{config_run['name']}_{config['k_folds']}folds/")
(model_path).mkdir(exist_ok=True)

# %%
for fold, (train_ids, valid_ids) in enumerate(kfold.split(X,y)):
#     if fold == 0:
#         continue
#     else:
    print(f"FOLD {fold}")
    print("-----------------------------------------")
    X_train, X_valid = X_scaled[train_ids], X_scaled[valid_ids] # requires X to be a numpy.ndarray
    y_train, y_valid = y[train_ids], y[valid_ids]
    model = train(X_train, X_valid, y_train, y_valid, config)
#     wandb.log({'fold': fold})
    models[fold] = model
    dump(model, Path(model_path/f"catboost_fold{fold}_model.joblib"))
#     wandb.finish()
# Out:
# FOLD 0
# -----------------------------------------
# 0:	learn: 7.9418049	total: 8.18ms	remaining: 24.5s
# 1:	learn: 7.9386857	total: 10.4ms	remaining: 15.6s
# 2:	learn: 7.9364381	total: 12.9ms	remaining: 12.8s
# 3:	learn: 7.9343308	total: 20.3ms	remaining: 15.2s
# 4:	learn: 7.9327322	total: 24.3ms	remaining: 14.5s
# 5:	learn: 7.9309148	total: 27.3ms	remaining: 13.6s
# 6:	learn: 7.9294186	total: 30ms	remaining: 12.8s
# 7:	learn: 7.9284283	total: 32.3ms	remaining: 12.1s
# 8:	learn: 7.9271795	total: 34.3ms	remaining: 11.4s
# 9:	learn: 7.9257485	total: 37.4ms	remaining: 11.2s
# 10:	learn: 7.9246691	total: 39.7ms	remaining: 10.8s
# 11:	learn: 7.9237980	total: 44.5ms	remaining: 11.1s
# 12:	learn: 7.9227729	total: 51.8ms	remaining: 11.9s
# 13:	learn: 7.9217160	total: 60.4ms	remaining: 12.9s
# 14:	learn: 7.9207026	total: 67.6ms	remaining: 13.5s
# 15:	learn: 7.9198879	total: 74.9ms	remaining: 14s
# 16:	learn: 7.9187613	total: 82.1ms	remaining: 14.4s
# 17:	learn: 7.9177017	total: 89.7ms	remaining: 14.9s
# 18:	learn: 7.9167916	total: 96.6ms	remaining: 15.2s
# 19:	learn: 7.9158104	total: 103ms	remaining: 15.3s
# 20:	learn: 7.9149523	total: 109ms	remaining: 15.5s
# 21:	learn: 7.9140634	total: 116ms	remaining: 15.7s
# 22:	learn: 7.9132841	total: 122ms	remaining: 15.8s
# 23:	learn: 7.9125479	total: 128ms	remaining: 15.8s
# 24:	learn: 7.9118342	total: 134ms	remaining: 15.9s
# 25:	learn: 7.9111965	total: 140ms	remaining: 16s
# 26:	learn: 7.9105379	total: 146ms	remaining: 16.1s
# 27:	learn: 7.9097623	total: 149ms	remaining: 15.8s
# 28:	learn: 7.9090891	total: 151ms	remaining: 15.5s
# 29:	learn: 7.9083304	total: 157ms	remaining: 15.5s
# 30:	learn: 7.9075758	total: 163ms	remaining: 15.6s
# 31:	learn: 7.9069432	total: 169ms	remaining: 15.7s
# 32:	learn: 7.9064268	total: 175ms	remaining: 15.8s
# 33:	learn: 7.9058225	total: 182ms	remaining: 15.9s
# 34:	learn: 7.9049927	total: 188ms	remaining: 16s
# 35:	learn: 7.9043880	total: 195ms	remaining: 16s
# 36:	learn: 7.9038475	total: 197ms	remaining: 15.7s
# 37:	learn: 7.9033199	total: 199ms	remaining: 15.5s
# 38:	learn: 7.9025787	total: 201ms	remaining: 15.3s
# 39:	learn: 7.9021693	total: 203ms	remaining: 15s
# 40:	learn: 7.9015783	total: 205ms	remaining: 14.8s
# 41:	learn: 7.9009037	total: 207ms	remaining: 14.6s
# 42:	learn: 7.9004655	total: 209ms	remaining: 14.4s
# 43:	learn: 7.8998509	total: 211ms	remaining: 14.2s
# 44:	learn: 7.8993987	total: 213ms	remaining: 14s
# 45:	learn: 7.8988170	total: 215ms	remaining: 13.8s
# 46:	learn: 7.8982637	total: 218ms	remaining: 13.7s
# 47:	learn: 7.8977522	total: 220ms	remaining: 13.5s
# 48:	learn: 7.8972587	total: 225ms	remaining: 13.6s
# 49:	learn: 7.8968161	total: 232ms	remaining: 13.7s
# 50:	learn: 7.8962472	total: 236ms	remaining: 13.7s
# 51:	learn: 7.8957251	total: 239ms	remaining: 13.5s
# 52:	learn: 7.8952128	total: 241ms	remaining: 13.4s
# 53:	learn: 7.8946868	total: 243ms	remaining: 13.3s
# 54:	learn: 7.8941491	total: 245ms	remaining: 13.1s
# 55:	learn: 7.8937041	total: 248ms	remaining: 13s
# 56:	learn: 7.8933269	total: 250ms	remaining: 12.9s
# 57:	learn: 7.8928829	total: 252ms	remaining: 12.8s
# 58:	learn: 7.8924410	total: 254ms	remaining: 12.6s
# 59:	learn: 7.8920216	total: 256ms	remaining: 12.5s
# 60:	learn: 7.8915537	total: 258ms	remaining: 12.4s
# 61:	learn: 7.8910098	total: 263ms	remaining: 12.5s
# 62:	learn: 7.8905602	total: 269ms	remaining: 12.6s
# 63:	learn: 7.8900786	total: 275ms	remaining: 12.6s
# 64:	learn: 7.8896613	total: 277ms	remaining: 12.5s
# 65:	learn: 7.8892696	total: 280ms	remaining: 12.4s
# 66:	learn: 7.8888348	total: 282ms	remaining: 12.3s
# 67:	learn: 7.8883335	total: 284ms	remaining: 12.2s
# 68:	learn: 7.8879500	total: 286ms	remaining: 12.1s
# 69:	learn: 7.8875522	total: 287ms	remaining: 12s
# 70:	learn: 7.8871354	total: 289ms	remaining: 11.9s
# 71:	learn: 7.8867138	total: 291ms	remaining: 11.8s
# 72:	learn: 7.8861939	total: 294ms	remaining: 11.8s
# 73:	learn: 7.8857755	total: 295ms	remaining: 11.7s
# 74:	learn: 7.8853878	total: 297ms	remaining: 11.6s
# 75:	learn: 7.8849575	total: 299ms	remaining: 11.5s
# 76:	learn: 7.8845187	total: 301ms	remaining: 11.4s
# 77:	learn: 7.8841122	total: 303ms	remaining: 11.3s
# 78:	learn: 7.8836768	total: 305ms	remaining: 11.3s
# 79:	learn: 7.8832823	total: 307ms	remaining: 11.2s
# 80:	learn: 7.8829959	total: 309ms	remaining: 11.1s
# 81:	learn: 7.8826312	total: 311ms	remaining: 11.1s
# 82:	learn: 7.8822839	total: 313ms	remaining: 11s
# 83:	learn: 7.8819366	total: 315ms	remaining: 10.9s
# 84:	learn: 7.8815382	total: 316ms	remaining: 10.9s
# 85:	learn: 7.8811979	total: 318ms	remaining: 10.8s
# 86:	learn: 7.8807741	total: 320ms	remaining: 10.7s
# 87:	learn: 7.8803658	total: 323ms	remaining: 10.7s
# 88:	learn: 7.8800219	total: 324ms	remaining: 10.6s
# 89:	learn: 7.8797332	total: 326ms	remaining: 10.5s
# 90:	learn: 7.8793280	total: 328ms	remaining: 10.5s
# 91:	learn: 7.8790758	total: 330ms	remaining: 10.4s
# 92:	learn: 7.8787562	total: 332ms	remaining: 10.4s
# 93:	learn: 7.8783713	total: 333ms	remaining: 10.3s
# 94:	learn: 7.8780397	total: 335ms	remaining: 10.2s
# 95:	learn: 7.8776332	total: 337ms	remaining: 10.2s
# 96:	learn: 7.8772711	total: 339ms	remaining: 10.2s
# 97:	learn: 7.8770331	total: 341ms	remaining: 10.1s
# 98:	learn: 7.8766405	total: 343ms	remaining: 10s
# 99:	learn: 7.8763878	total: 344ms	remaining: 9.99s
# 100:	learn: 7.8761088	total: 346ms	remaining: 9.94s
# 101:	learn: 7.8756562	total: 348ms	remaining: 9.89s
# 102:	learn: 7.8753797	total: 350ms	remaining: 9.84s
# 103:	learn: 7.8750527	total: 353ms	remaining: 9.82s
# 104:	learn: 7.8747936	total: 355ms	remaining: 9.78s
# 105:	learn: 7.8744343	total: 356ms	remaining: 9.73s
# 106:	learn: 7.8740726	total: 358ms	remaining: 9.69s
# 107:	learn: 7.8737726	total: 360ms	remaining: 9.64s
# 108:	learn: 7.8734532	total: 362ms	remaining: 9.6s
# 109:	learn: 7.8731595	total: 364ms	remaining: 9.56s
# 110:	learn: 7.8728422	total: 366ms	remaining: 9.52s
# 111:	learn: 7.8724907	total: 368ms	remaining: 9.5s
# 112:	learn: 7.8722919	total: 370ms	remaining: 9.46s
# 113:	learn: 7.8719997	total: 372ms	remaining: 9.42s
# 114:	learn: 7.8715786	total: 374ms	remaining: 9.38s
# 115:	learn: 7.8713064	total: 376ms	remaining: 9.35s
# 116:	learn: 7.8710460	total: 378ms	remaining: 9.31s
# 117:	learn: 7.8707944	total: 380ms	remaining: 9.28s
# 118:	learn: 7.8703936	total: 382ms	remaining: 9.24s
# 119:	learn: 7.8700708	total: 384ms	remaining: 9.22s
# 120:	learn: 7.8697980	total: 386ms	remaining: 9.19s
# 121:	learn: 7.8694822	total: 388ms	remaining: 9.16s
# 122:	learn: 7.8692328	total: 390ms	remaining: 9.13s
# 123:	learn: 7.8688840	total: 392ms	remaining: 9.09s
# 124:	learn: 7.8686482	total: 394ms	remaining: 9.06s
# 125:	learn: 7.8683575	total: 396ms	remaining: 9.03s
# 126:	learn: 7.8678104	total: 399ms	remaining: 9.02s
# 127:	learn: 7.8675784	total: 400ms	remaining: 8.98s
# 128:	learn: 7.8672641	total: 402ms	remaining: 8.94s
# 129:	learn: 7.8671148	total: 404ms	remaining: 8.91s
# 130:	learn: 7.8668618	total: 406ms	remaining: 8.88s
# 131:	learn: 7.8665869	total: 407ms	remaining: 8.85s
# 132:	learn: 7.8663486	total: 409ms	remaining: 8.82s
# 133:	learn: 7.8661156	total: 411ms	remaining: 8.79s
# 134:	learn: 7.8658188	total: 414ms	remaining: 8.78s
# 135:	learn: 7.8654968	total: 416ms	remaining: 8.75s
# 136:	learn: 7.8652711	total: 417ms	remaining: 8.72s
# 137:	learn: 7.8649905	total: 419ms	remaining: 8.69s
# 138:	learn: 7.8647908	total: 421ms	remaining: 8.66s
# 139:	learn: 7.8645200	total: 423ms	remaining: 8.64s
# 140:	learn: 7.8642174	total: 425ms	remaining: 8.61s
# 141:	learn: 7.8639996	total: 427ms	remaining: 8.59s
# 142:	learn: 7.8637405	total: 428ms	remaining: 8.56s
# 143:	learn: 7.8634023	total: 430ms	remaining: 8.53s
# 144:	learn: 7.8631288	total: 432ms	remaining: 8.51s
# 145:	learn: 7.8628300	total: 434ms	remaining: 8.48s
# 146:	learn: 7.8625136	total: 436ms	remaining: 8.46s
# 147:	learn: 7.8622742	total: 438ms	remaining: 8.43s
# 148:	learn: 7.8619896	total: 440ms	remaining: 8.41s
# 149:	learn: 7.8616493	total: 441ms	remaining: 8.39s
# 150:	learn: 7.8612820	total: 443ms	remaining: 8.36s
# 151:	learn: 7.8610667	total: 445ms	remaining: 8.34s
# 152:	learn: 7.8607188	total: 447ms	remaining: 8.31s
# 153:	learn: 7.8604599	total: 449ms	remaining: 8.29s
# 154:	learn: 7.8600932	total: 450ms	remaining: 8.27s
# 155:	learn: 7.8598480	total: 452ms	remaining: 8.24s
# 156:	learn: 7.8596263	total: 454ms	remaining: 8.22s
# 157:	learn: 7.8593762	total: 456ms	remaining: 8.2s
# 158:	learn: 7.8591011	total: 458ms	remaining: 8.18s
# 159:	learn: 7.8588425	total: 460ms	remaining: 8.16s
# 160:	learn: 7.8585692	total: 462ms	remaining: 8.14s
# 161:	learn: 7.8582794	total: 463ms	remaining: 8.12s
# 162:	learn: 7.8580548	total: 465ms	remaining: 8.09s
# 163:	learn: 7.8578416	total: 467ms	remaining: 8.07s
# 164:	learn: 7.8575874	total: 469ms	remaining: 8.05s
# 165:	learn: 7.8573844	total: 471ms	remaining: 8.03s
# 166:	learn: 7.8571251	total: 473ms	remaining: 8.02s
# 167:	learn: 7.8568362	total: 474ms	remaining: 8s
# 168:	learn: 7.8565953	total: 479ms	remaining: 8.02s
# 169:	learn: 7.8563688	total: 485ms	remaining: 8.07s
# 170:	learn: 7.8561387	total: 491ms	remaining: 8.12s
# 171:	learn: 7.8558345	total: 493ms	remaining: 8.1s
# 172:	learn: 7.8556206	total: 495ms	remaining: 8.08s
# 173:	learn: 7.8553746	total: 497ms	remaining: 8.06s
# 174:	learn: 7.8551735	total: 498ms	remaining: 8.04s
# 175:	learn: 7.8549118	total: 500ms	remaining: 8.03s
# 176:	learn: 7.8546633	total: 503ms	remaining: 8.02s
# 177:	learn: 7.8544707	total: 504ms	remaining: 8s
# 178:	learn: 7.8542921	total: 506ms	remaining: 7.97s
# 179:	learn: 7.8540623	total: 508ms	remaining: 7.96s
# 180:	learn: 7.8537469	total: 510ms	remaining: 7.94s
# 181:	learn: 7.8535301	total: 512ms	remaining: 7.92s
# 182:	learn: 7.8531790	total: 513ms	remaining: 7.9s
# 183:	learn: 7.8529520	total: 515ms	remaining: 7.88s
# 184:	learn: 7.8526814	total: 517ms	remaining: 7.87s
# 185:	learn: 7.8524280	total: 519ms	remaining: 7.85s
# 186:	learn: 7.8521430	total: 521ms	remaining: 7.83s
# 187:	learn: 7.8518581	total: 523ms	remaining: 7.82s
# 188:	learn: 7.8516533	total: 524ms	remaining: 7.8s
# 189:	learn: 7.8514706	total: 526ms	remaining: 7.78s
# 190:	learn: 7.8512445	total: 528ms	remaining: 7.76s
# 191:	learn: 7.8510241	total: 530ms	remaining: 7.75s
# 192:	learn: 7.8508019	total: 532ms	remaining: 7.73s
# 193:	learn: 7.8505981	total: 533ms	remaining: 7.71s
# 194:	learn: 7.8504165	total: 535ms	remaining: 7.7s
# 195:	learn: 7.8502096	total: 537ms	remaining: 7.68s
# 196:	learn: 7.8499694	total: 539ms	remaining: 7.67s
# 197:	learn: 7.8498032	total: 541ms	remaining: 7.65s
# 198:	learn: 7.8496223	total: 542ms	remaining: 7.63s
# 199:	learn: 7.8493232	total: 544ms	remaining: 7.62s
# 200:	learn: 7.8491152	total: 546ms	remaining: 7.6s
# 201:	learn: 7.8488993	total: 548ms	remaining: 7.59s
# 202:	learn: 7.8487075	total: 550ms	remaining: 7.58s
# 203:	learn: 7.8485285	total: 552ms	remaining: 7.56s
# 204:	learn: 7.8483132	total: 554ms	remaining: 7.55s
# 205:	learn: 7.8481434	total: 556ms	remaining: 7.54s
# 206:	learn: 7.8478258	total: 557ms	remaining: 7.52s
# 207:	learn: 7.8476611	total: 559ms	remaining: 7.5s
# 208:	learn: 7.8474120	total: 561ms	remaining: 7.49s
# 209:	learn: 7.8472642	total: 563ms	remaining: 7.47s
# 210:	learn: 7.8471033	total: 565ms	remaining: 7.46s
# 211:	learn: 7.8469341	total: 566ms	remaining: 7.45s
# 212:	learn: 7.8466308	total: 568ms	remaining: 7.43s
# 213:	learn: 7.8465215	total: 570ms	remaining: 7.42s
# 214:	learn: 7.8462991	total: 572ms	remaining: 7.41s
# 215:	learn: 7.8460321	total: 573ms	remaining: 7.39s
# 216:	learn: 7.8458186	total: 575ms	remaining: 7.38s
# 217:	learn: 7.8455519	total: 577ms	remaining: 7.37s
# 218:	learn: 7.8452635	total: 579ms	remaining: 7.35s
# 219:	learn: 7.8450621	total: 581ms	remaining: 7.34s
# 220:	learn: 7.8448199	total: 583ms	remaining: 7.33s
# 221:	learn: 7.8446393	total: 585ms	remaining: 7.32s
# 222:	learn: 7.8444337	total: 586ms	remaining: 7.3s
# 223:	learn: 7.8442533	total: 588ms	remaining: 7.29s
# 224:	learn: 7.8440748	total: 590ms	remaining: 7.28s
# 225:	learn: 7.8436949	total: 592ms	remaining: 7.27s
# 226:	learn: 7.8435027	total: 594ms	remaining: 7.25s
# 227:	learn: 7.8432681	total: 596ms	remaining: 7.24s
# 228:	learn: 7.8431365	total: 598ms	remaining: 7.23s
# 229:	learn: 7.8428968	total: 599ms	remaining: 7.22s
# 230:	learn: 7.8426928	total: 601ms	remaining: 7.21s
# 231:	learn: 7.8425420	total: 603ms	remaining: 7.19s
# 232:	learn: 7.8423667	total: 606ms	remaining: 7.19s
# 233:	learn: 7.8421094	total: 607ms	remaining: 7.18s
# 234:	learn: 7.8419459	total: 609ms	remaining: 7.17s
# 235:	learn: 7.8417874	total: 611ms	remaining: 7.15s
# 236:	learn: 7.8415824	total: 613ms	remaining: 7.14s
# 237:	learn: 7.8413816	total: 615ms	remaining: 7.13s
# 238:	learn: 7.8408947	total: 616ms	remaining: 7.12s
# 239:	learn: 7.8407445	total: 618ms	remaining: 7.11s
# 240:	learn: 7.8405743	total: 623ms	remaining: 7.13s
# 241:	learn: 7.8403122	total: 629ms	remaining: 7.17s
# 242:	learn: 7.8400823	total: 634ms	remaining: 7.2s
# 243:	learn: 7.8399786	total: 637ms	remaining: 7.19s
# 244:	learn: 7.8397915	total: 639ms	remaining: 7.18s
# 245:	learn: 7.8396228	total: 641ms	remaining: 7.18s
# 246:	learn: 7.8394745	total: 643ms	remaining: 7.17s
# 247:	learn: 7.8392713	total: 645ms	remaining: 7.16s
# 248:	learn: 7.8391301	total: 647ms	remaining: 7.14s
# 249:	learn: 7.8389074	total: 649ms	remaining: 7.14s
# 250:	learn: 7.8387113	total: 651ms	remaining: 7.13s
# 251:	learn: 7.8385825	total: 652ms	remaining: 7.11s
# 252:	learn: 7.8383803	total: 654ms	remaining: 7.1s
# 253:	learn: 7.8382237	total: 656ms	remaining: 7.1s
# 254:	learn: 7.8380833	total: 658ms	remaining: 7.09s
# 255:	learn: 7.8378546	total: 660ms	remaining: 7.07s
# 256:	learn: 7.8376977	total: 662ms	remaining: 7.06s
# 257:	learn: 7.8375644	total: 664ms	remaining: 7.05s
# 258:	learn: 7.8374540	total: 665ms	remaining: 7.04s
# 259:	learn: 7.8372986	total: 667ms	remaining: 7.03s
# 260:	learn: 7.8371120	total: 669ms	remaining: 7.03s
# 261:	learn: 7.8369334	total: 672ms	remaining: 7.02s
# 262:	learn: 7.8367327	total: 674ms	remaining: 7.01s
# 263:	learn: 7.8365598	total: 676ms	remaining: 7s
# 264:	learn: 7.8363754	total: 678ms	remaining: 6.99s
# 265:	learn: 7.8361997	total: 679ms	remaining: 6.98s
# 266:	learn: 7.8359550	total: 681ms	remaining: 6.97s
# 267:	learn: 7.8358493	total: 683ms	remaining: 6.96s
# 268:	learn: 7.8356349	total: 685ms	remaining: 6.95s
# 269:	learn: 7.8354544	total: 687ms	remaining: 6.95s
# 270:	learn: 7.8352387	total: 689ms	remaining: 6.94s
# 271:	learn: 7.8349882	total: 691ms	remaining: 6.93s
# 272:	learn: 7.8347272	total: 693ms	remaining: 6.92s
# 273:	learn: 7.8345581	total: 694ms	remaining: 6.91s
# 274:	learn: 7.8343717	total: 696ms	remaining: 6.9s
# 275:	learn: 7.8342412	total: 698ms	remaining: 6.89s
# 276:	learn: 7.8341158	total: 699ms	remaining: 6.88s
# 277:	learn: 7.8339990	total: 702ms	remaining: 6.87s
# 278:	learn: 7.8338436	total: 704ms	remaining: 6.86s
# 279:	learn: 7.8337067	total: 705ms	remaining: 6.85s
# 280:	learn: 7.8335710	total: 707ms	remaining: 6.84s
# 281:	learn: 7.8334060	total: 709ms	remaining: 6.83s
# 282:	learn: 7.8332046	total: 711ms	remaining: 6.82s
# 283:	learn: 7.8329790	total: 712ms	remaining: 6.81s
# 284:	learn: 7.8328127	total: 714ms	remaining: 6.8s
# 285:	learn: 7.8326432	total: 717ms	remaining: 6.8s
# 286:	learn: 7.8324629	total: 719ms	remaining: 6.79s
# 287:	learn: 7.8323193	total: 720ms	remaining: 6.78s
# 288:	learn: 7.8321479	total: 722ms	remaining: 6.77s
# 289:	learn: 7.8319978	total: 724ms	remaining: 6.76s
# 290:	learn: 7.8319158	total: 726ms	remaining: 6.75s
# 291:	learn: 7.8317243	total: 727ms	remaining: 6.75s
# 292:	learn: 7.8315404	total: 729ms	remaining: 6.74s
# 293:	learn: 7.8313160	total: 745ms	remaining: 6.86s
# 294:	learn: 7.8311535	total: 748ms	remaining: 6.86s
# 295:	learn: 7.8309712	total: 750ms	remaining: 6.85s
# 296:	learn: 7.8308215	total: 751ms	remaining: 6.84s
# 297:	learn: 7.8306197	total: 753ms	remaining: 6.83s
# 298:	learn: 7.8304677	total: 755ms	remaining: 6.82s
# 299:	learn: 7.8302905	total: 757ms	remaining: 6.81s
# 300:	learn: 7.8301038	total: 758ms	remaining: 6.8s
# 301:	learn: 7.8299234	total: 760ms	remaining: 6.79s
# 302:	learn: 7.8297854	total: 762ms	remaining: 6.78s
# 303:	learn: 7.8296191	total: 764ms	remaining: 6.78s
# 304:	learn: 7.8294348	total: 766ms	remaining: 6.77s
# 305:	learn: 7.8292429	total: 768ms	remaining: 6.76s
# 306:	learn: 7.8291356	total: 770ms	remaining: 6.75s
# 307:	learn: 7.8289428	total: 771ms	remaining: 6.74s
# 308:	learn: 7.8288032	total: 773ms	remaining: 6.73s
# 309:	learn: 7.8286142	total: 775ms	remaining: 6.72s
# 310:	learn: 7.8285190	total: 778ms	remaining: 6.72s
# 311:	learn: 7.8283993	total: 779ms	remaining: 6.71s
# 312:	learn: 7.8282319	total: 781ms	remaining: 6.7s
# 313:	learn: 7.8280716	total: 783ms	remaining: 6.7s
# 314:	learn: 7.8279052	total: 785ms	remaining: 6.69s
# 315:	learn: 7.8277481	total: 786ms	remaining: 6.68s
# 316:	learn: 7.8275798	total: 788ms	remaining: 6.67s
# 317:	learn: 7.8274015	total: 790ms	remaining: 6.66s
# 318:	learn: 7.8272530	total: 793ms	remaining: 6.66s
# 319:	learn: 7.8271371	total: 795ms	remaining: 6.66s
# 320:	learn: 7.8270087	total: 796ms	remaining: 6.64s
# 321:	learn: 7.8268796	total: 798ms	remaining: 6.64s
# 322:	learn: 7.8267027	total: 800ms	remaining: 6.63s
# 323:	learn: 7.8265114	total: 802ms	remaining: 6.62s
# 324:	learn: 7.8263801	total: 803ms	remaining: 6.61s
# 325:	learn: 7.8261363	total: 805ms	remaining: 6.61s
# 326:	learn: 7.8259840	total: 807ms	remaining: 6.6s
# 327:	learn: 7.8257980	total: 810ms	remaining: 6.6s
# 328:	learn: 7.8257211	total: 814ms	remaining: 6.61s
# 329:	learn: 7.8256281	total: 820ms	remaining: 6.64s
# 330:	learn: 7.8254712	total: 825ms	remaining: 6.66s
# 331:	learn: 7.8253067	total: 828ms	remaining: 6.65s
# 332:	learn: 7.8251559	total: 830ms	remaining: 6.65s
# 333:	learn: 7.8249869	total: 832ms	remaining: 6.64s
# 334:	learn: 7.8247540	total: 834ms	remaining: 6.63s
# 335:	learn: 7.8245850	total: 835ms	remaining: 6.62s
# 336:	learn: 7.8244326	total: 837ms	remaining: 6.62s
# 337:	learn: 7.8241693	total: 840ms	remaining: 6.61s
# 338:	learn: 7.8239443	total: 842ms	remaining: 6.61s
# 339:	learn: 7.8237871	total: 843ms	remaining: 6.6s
# 340:	learn: 7.8236398	total: 845ms	remaining: 6.59s
# 341:	learn: 7.8234915	total: 847ms	remaining: 6.58s
# 342:	learn: 7.8233251	total: 849ms	remaining: 6.57s
# 343:	learn: 7.8231736	total: 850ms	remaining: 6.56s
# 344:	learn: 7.8229358	total: 852ms	remaining: 6.56s
# 345:	learn: 7.8227738	total: 854ms	remaining: 6.55s
# 346:	learn: 7.8226163	total: 856ms	remaining: 6.54s
# 347:	learn: 7.8224459	total: 857ms	remaining: 6.53s
# 348:	learn: 7.8222439	total: 859ms	remaining: 6.53s
# 349:	learn: 7.8220937	total: 861ms	remaining: 6.52s
# 350:	learn: 7.8219547	total: 863ms	remaining: 6.51s
# 351:	learn: 7.8218204	total: 865ms	remaining: 6.5s
# 352:	learn: 7.8217140	total: 866ms	remaining: 6.5s
# 353:	learn: 7.8215459	total: 868ms	remaining: 6.49s
# 354:	learn: 7.8214033	total: 870ms	remaining: 6.48s
# 355:	learn: 7.8212710	total: 872ms	remaining: 6.47s
# 356:	learn: 7.8210463	total: 873ms	remaining: 6.47s
# 357:	learn: 7.8208817	total: 875ms	remaining: 6.46s
# 358:	learn: 7.8206777	total: 877ms	remaining: 6.45s
# 359:	learn: 7.8205118	total: 879ms	remaining: 6.45s
# 360:	learn: 7.8203750	total: 881ms	remaining: 6.44s
# 361:	learn: 7.8202666	total: 883ms	remaining: 6.43s
# 362:	learn: 7.8201627	total: 884ms	remaining: 6.42s
# 363:	learn: 7.8199891	total: 886ms	remaining: 6.42s
# 364:	learn: 7.8198967	total: 888ms	remaining: 6.41s
# 365:	learn: 7.8197922	total: 890ms	remaining: 6.4s
# 366:	learn: 7.8197110	total: 892ms	remaining: 6.4s
# 367:	learn: 7.8195550	total: 893ms	remaining: 6.39s
# 368:	learn: 7.8193663	total: 895ms	remaining: 6.38s
# 369:	learn: 7.8191915	total: 897ms	remaining: 6.38s
# 370:	learn: 7.8190089	total: 899ms	remaining: 6.37s
# 371:	learn: 7.8188922	total: 901ms	remaining: 6.36s
# 372:	learn: 7.8187800	total: 902ms	remaining: 6.36s
# 373:	learn: 7.8185996	total: 904ms	remaining: 6.35s
# 374:	learn: 7.8183812	total: 906ms	remaining: 6.34s
# 375:	learn: 7.8181884	total: 908ms	remaining: 6.33s
# 376:	learn: 7.8180151	total: 909ms	remaining: 6.33s
# 377:	learn: 7.8179137	total: 911ms	remaining: 6.32s
# 378:	learn: 7.8177983	total: 913ms	remaining: 6.31s
# 379:	learn: 7.8176224	total: 915ms	remaining: 6.31s
# 380:	learn: 7.8174695	total: 917ms	remaining: 6.3s
# 381:	learn: 7.8173403	total: 919ms	remaining: 6.3s
# 382:	learn: 7.8171577	total: 920ms	remaining: 6.29s
# 383:	learn: 7.8170020	total: 922ms	remaining: 6.28s
# 384:	learn: 7.8167986	total: 924ms	remaining: 6.28s
# 385:	learn: 7.8166208	total: 926ms	remaining: 6.27s
# 386:	learn: 7.8164899	total: 928ms	remaining: 6.27s
# 387:	learn: 7.8163578	total: 930ms	remaining: 6.26s
# 388:	learn: 7.8161720	total: 932ms	remaining: 6.25s
# 389:	learn: 7.8160812	total: 933ms	remaining: 6.25s
# 390:	learn: 7.8159843	total: 935ms	remaining: 6.24s
# 391:	learn: 7.8158061	total: 937ms	remaining: 6.23s
# 392:	learn: 7.8157034	total: 938ms	remaining: 6.22s
# 393:	learn: 7.8155361	total: 940ms	remaining: 6.22s
# 394:	learn: 7.8153484	total: 942ms	remaining: 6.21s
# 395:	learn: 7.8151977	total: 944ms	remaining: 6.21s
# 396:	learn: 7.8150419	total: 946ms	remaining: 6.2s
# 397:	learn: 7.8148954	total: 948ms	remaining: 6.19s
# 398:	learn: 7.8147598	total: 950ms	remaining: 6.19s
# 399:	learn: 7.8145652	total: 952ms	remaining: 6.18s
# 400:	learn: 7.8143631	total: 954ms	remaining: 6.18s
# 401:	learn: 7.8141973	total: 956ms	remaining: 6.17s
# 402:	learn: 7.8138934	total: 957ms	remaining: 6.17s
# 403:	learn: 7.8137238	total: 959ms	remaining: 6.16s
# 404:	learn: 7.8135507	total: 961ms	remaining: 6.16s
# 405:	learn: 7.8134426	total: 963ms	remaining: 6.15s
# 406:	learn: 7.8133226	total: 965ms	remaining: 6.14s
# 407:	learn: 7.8131223	total: 966ms	remaining: 6.14s
# 408:	learn: 7.8130554	total: 968ms	remaining: 6.13s
# 409:	learn: 7.8129578	total: 970ms	remaining: 6.13s
# 410:	learn: 7.8127774	total: 972ms	remaining: 6.12s
# 411:	learn: 7.8126484	total: 974ms	remaining: 6.12s
# 412:	learn: 7.8124167	total: 976ms	remaining: 6.11s
# 413:	learn: 7.8122730	total: 977ms	remaining: 6.11s
# 414:	learn: 7.8121348	total: 979ms	remaining: 6.1s
# 415:	learn: 7.8119882	total: 981ms	remaining: 6.09s
# 416:	learn: 7.8118621	total: 983ms	remaining: 6.09s
# 417:	learn: 7.8117220	total: 985ms	remaining: 6.08s
# 418:	learn: 7.8115290	total: 986ms	remaining: 6.08s
# 419:	learn: 7.8114192	total: 988ms	remaining: 6.07s
# 420:	learn: 7.8113101	total: 990ms	remaining: 6.06s
# 421:	learn: 7.8110550	total: 992ms	remaining: 6.06s
# 422:	learn: 7.8109279	total: 994ms	remaining: 6.05s
# 423:	learn: 7.8107576	total: 996ms	remaining: 6.05s
# 424:	learn: 7.8106533	total: 997ms	remaining: 6.04s
# 425:	learn: 7.8105189	total: 1s	remaining: 6.05s
# 426:	learn: 7.8103627	total: 1.01s	remaining: 6.07s
# 427:	learn: 7.8101405	total: 1.01s	remaining: 6.09s
# 428:	learn: 7.8099587	total: 1.01s	remaining: 6.08s
# 429:	learn: 7.8098761	total: 1.02s	remaining: 6.08s
# 430:	learn: 7.8097519	total: 1.02s	remaining: 6.07s
# 431:	learn: 7.8096328	total: 1.02s	remaining: 6.07s
# 432:	learn: 7.8095029	total: 1.02s	remaining: 6.06s
# 433:	learn: 7.8094152	total: 1.02s	remaining: 6.06s
# 434:	learn: 7.8093124	total: 1.03s	remaining: 6.05s
# 435:	learn: 7.8091539	total: 1.03s	remaining: 6.04s
# 436:	learn: 7.8089615	total: 1.03s	remaining: 6.04s
# 437:	learn: 7.8088341	total: 1.03s	remaining: 6.03s
# 438:	learn: 7.8086122	total: 1.03s	remaining: 6.03s
# 439:	learn: 7.8084285	total: 1.03s	remaining: 6.03s
# 440:	learn: 7.8082344	total: 1.04s	remaining: 6.02s
# 441:	learn: 7.8081701	total: 1.04s	remaining: 6.01s
# 442:	learn: 7.8080065	total: 1.04s	remaining: 6.01s
# 443:	learn: 7.8078166	total: 1.04s	remaining: 6s
# 444:	learn: 7.8076306	total: 1.04s	remaining: 6s
# 445:	learn: 7.8074797	total: 1.05s	remaining: 5.99s
# 446:	learn: 7.8072745	total: 1.05s	remaining: 5.99s
# 447:	learn: 7.8071778	total: 1.05s	remaining: 5.98s
# 448:	learn: 7.8070471	total: 1.05s	remaining: 5.98s
# 449:	learn: 7.8069450	total: 1.05s	remaining: 5.97s
# 450:	learn: 7.8067586	total: 1.05s	remaining: 5.96s
# 451:	learn: 7.8066324	total: 1.06s	remaining: 5.96s
# 452:	learn: 7.8065886	total: 1.06s	remaining: 5.96s
# 453:	learn: 7.8064765	total: 1.06s	remaining: 5.95s
# 454:	learn: 7.8063417	total: 1.06s	remaining: 5.95s
# 455:	learn: 7.8061822	total: 1.06s	remaining: 5.95s
# 456:	learn: 7.8060614	total: 1.07s	remaining: 5.94s
# 457:	learn: 7.8058894	total: 1.07s	remaining: 5.93s
# 458:	learn: 7.8057799	total: 1.07s	remaining: 5.93s
# 459:	learn: 7.8056415	total: 1.07s	remaining: 5.92s
# 460:	learn: 7.8055224	total: 1.07s	remaining: 5.92s
# 461:	learn: 7.8053744	total: 1.08s	remaining: 5.91s
# 462:	learn: 7.8052642	total: 1.08s	remaining: 5.91s
# 463:	learn: 7.8051406	total: 1.08s	remaining: 5.9s
# 464:	learn: 7.8049295	total: 1.08s	remaining: 5.9s
# 465:	learn: 7.8048222	total: 1.08s	remaining: 5.9s
# 466:	learn: 7.8046320	total: 1.09s	remaining: 5.89s
# 467:	learn: 7.8045173	total: 1.09s	remaining: 5.89s
# 468:	learn: 7.8042652	total: 1.09s	remaining: 5.88s
# 469:	learn: 7.8041479	total: 1.09s	remaining: 5.88s
# 470:	learn: 7.8040236	total: 1.09s	remaining: 5.87s
# 471:	learn: 7.8038795	total: 1.1s	remaining: 5.87s
# 472:	learn: 7.8037167	total: 1.1s	remaining: 5.87s
# 473:	learn: 7.8035793	total: 1.1s	remaining: 5.87s
# 474:	learn: 7.8034326	total: 1.1s	remaining: 5.86s
# 475:	learn: 7.8032637	total: 1.1s	remaining: 5.86s
# 476:	learn: 7.8030299	total: 1.11s	remaining: 5.85s
# 477:	learn: 7.8028511	total: 1.11s	remaining: 5.85s
# 478:	learn: 7.8027367	total: 1.11s	remaining: 5.84s
# 479:	learn: 7.8025980	total: 1.11s	remaining: 5.84s
# 480:	learn: 7.8025502	total: 1.11s	remaining: 5.84s
# 481:	learn: 7.8024602	total: 1.12s	remaining: 5.83s
# 482:	learn: 7.8022670	total: 1.12s	remaining: 5.83s
# 483:	learn: 7.8020927	total: 1.12s	remaining: 5.82s
# 484:	learn: 7.8018978	total: 1.12s	remaining: 5.82s
# 485:	learn: 7.8017296	total: 1.12s	remaining: 5.81s
# 486:	learn: 7.8015537	total: 1.13s	remaining: 5.81s
# 487:	learn: 7.8014540	total: 1.13s	remaining: 5.81s
# 488:	learn: 7.8013678	total: 1.13s	remaining: 5.8s
# 489:	learn: 7.8012159	total: 1.13s	remaining: 5.8s
# 490:	learn: 7.8010656	total: 1.13s	remaining: 5.79s
# 491:	learn: 7.8009894	total: 1.14s	remaining: 5.79s
# 492:	learn: 7.8008403	total: 1.14s	remaining: 5.78s
# 493:	learn: 7.8006577	total: 1.14s	remaining: 5.78s
# 494:	learn: 7.8004157	total: 1.14s	remaining: 5.77s
# 495:	learn: 7.8003279	total: 1.14s	remaining: 5.77s
# 496:	learn: 7.8002064	total: 1.15s	remaining: 5.77s
# 497:	learn: 7.8000821	total: 1.15s	remaining: 5.76s
# 498:	learn: 7.7999481	total: 1.15s	remaining: 5.76s
# 499:	learn: 7.7997478	total: 1.15s	remaining: 5.75s
# 500:	learn: 7.7996465	total: 1.15s	remaining: 5.75s
# 501:	learn: 7.7995535	total: 1.15s	remaining: 5.74s
# 502:	learn: 7.7994051	total: 1.16s	remaining: 5.74s
# 503:	learn: 7.7992695	total: 1.16s	remaining: 5.74s
# 504:	learn: 7.7990974	total: 1.16s	remaining: 5.73s
# 505:	learn: 7.7990205	total: 1.16s	remaining: 5.72s
# 506:	learn: 7.7988980	total: 1.16s	remaining: 5.72s
# 507:	learn: 7.7987278	total: 1.16s	remaining: 5.71s
# 508:	learn: 7.7984691	total: 1.17s	remaining: 5.71s
# 509:	learn: 7.7984021	total: 1.17s	remaining: 5.71s
# 510:	learn: 7.7983001	total: 1.17s	remaining: 5.7s
# 511:	learn: 7.7982370	total: 1.17s	remaining: 5.7s
# 512:	learn: 7.7981081	total: 1.18s	remaining: 5.7s
# 513:	learn: 7.7979751	total: 1.18s	remaining: 5.69s
# 514:	learn: 7.7978167	total: 1.18s	remaining: 5.69s
# 515:	learn: 7.7976420	total: 1.18s	remaining: 5.68s
# 516:	learn: 7.7974746	total: 1.18s	remaining: 5.68s
# 517:	learn: 7.7973345	total: 1.18s	remaining: 5.67s
# 518:	learn: 7.7972062	total: 1.19s	remaining: 5.67s
# 519:	learn: 7.7970860	total: 1.19s	remaining: 5.67s
# 520:	learn: 7.7969500	total: 1.19s	remaining: 5.66s
# 521:	learn: 7.7967702	total: 1.19s	remaining: 5.66s
# 522:	learn: 7.7966839	total: 1.19s	remaining: 5.65s
# 523:	learn: 7.7965582	total: 1.2s	remaining: 5.65s
# 524:	learn: 7.7964755	total: 1.2s	remaining: 5.64s
# 525:	learn: 7.7963398	total: 1.2s	remaining: 5.64s
# 526:	learn: 7.7961872	total: 1.2s	remaining: 5.63s
# 527:	learn: 7.7960673	total: 1.2s	remaining: 5.63s
# 528:	learn: 7.7959538	total: 1.21s	remaining: 5.63s
# 529:	learn: 7.7957870	total: 1.21s	remaining: 5.63s
# 530:	learn: 7.7956344	total: 1.21s	remaining: 5.62s
# 531:	learn: 7.7955058	total: 1.21s	remaining: 5.62s
# 532:	learn: 7.7953624	total: 1.21s	remaining: 5.61s
# 533:	learn: 7.7951988	total: 1.22s	remaining: 5.61s
# 534:	learn: 7.7950064	total: 1.22s	remaining: 5.61s
# 535:	learn: 7.7949173	total: 1.22s	remaining: 5.61s
# 536:	learn: 7.7947393	total: 1.22s	remaining: 5.6s
# 537:	learn: 7.7946264	total: 1.22s	remaining: 5.6s
# 538:	learn: 7.7945420	total: 1.22s	remaining: 5.59s
# 539:	learn: 7.7943605	total: 1.23s	remaining: 5.59s
# 540:	learn: 7.7942010	total: 1.23s	remaining: 5.58s
# 541:	learn: 7.7940275	total: 1.23s	remaining: 5.58s
# 542:	learn: 7.7939345	total: 1.23s	remaining: 5.58s
# 543:	learn: 7.7936843	total: 1.23s	remaining: 5.57s
# 544:	learn: 7.7935746	total: 1.24s	remaining: 5.57s
# 545:	learn: 7.7934585	total: 1.24s	remaining: 5.57s
# 546:	learn: 7.7933494	total: 1.24s	remaining: 5.56s
# 547:	learn: 7.7932086	total: 1.24s	remaining: 5.56s
# 548:	learn: 7.7931130	total: 1.24s	remaining: 5.55s
# 549:	learn: 7.7930123	total: 1.25s	remaining: 5.55s
# 550:	learn: 7.7928926	total: 1.25s	remaining: 5.55s
# 551:	learn: 7.7927052	total: 1.25s	remaining: 5.54s
# 552:	learn: 7.7925253	total: 1.25s	remaining: 5.54s
# 553:	learn: 7.7924069	total: 1.25s	remaining: 5.53s
# 554:	learn: 7.7923215	total: 1.25s	remaining: 5.53s
# 555:	learn: 7.7921634	total: 1.26s	remaining: 5.52s
# 556:	learn: 7.7920822	total: 1.26s	remaining: 5.52s
# 557:	learn: 7.7918833	total: 1.26s	remaining: 5.51s
# 558:	learn: 7.7917527	total: 1.26s	remaining: 5.51s
# 559:	learn: 7.7916542	total: 1.26s	remaining: 5.51s
# 560:	learn: 7.7915204	total: 1.27s	remaining: 5.51s
# 561:	learn: 7.7913994	total: 1.27s	remaining: 5.5s
# 562:	learn: 7.7912727	total: 1.27s	remaining: 5.5s
# 563:	learn: 7.7911097	total: 1.28s	remaining: 5.51s
# 564:	learn: 7.7909935	total: 1.28s	remaining: 5.53s
# 565:	learn: 7.7908764	total: 1.29s	remaining: 5.53s
# 566:	learn: 7.7907776	total: 1.29s	remaining: 5.53s
# 567:	learn: 7.7906502	total: 1.29s	remaining: 5.52s
# 568:	learn: 7.7905125	total: 1.29s	remaining: 5.52s
# 569:	learn: 7.7904037	total: 1.29s	remaining: 5.52s
# 570:	learn: 7.7903171	total: 1.29s	remaining: 5.51s
# 571:	learn: 7.7901768	total: 1.3s	remaining: 5.51s
# 572:	learn: 7.7900822	total: 1.3s	remaining: 5.5s
# 573:	learn: 7.7899788	total: 1.3s	remaining: 5.5s
# 574:	learn: 7.7898681	total: 1.3s	remaining: 5.49s
# 575:	learn: 7.7897452	total: 1.3s	remaining: 5.49s
# 576:	learn: 7.7895622	total: 1.31s	remaining: 5.48s
# 577:	learn: 7.7893501	total: 1.31s	remaining: 5.48s
# 578:	learn: 7.7891848	total: 1.31s	remaining: 5.48s
# 579:	learn: 7.7890022	total: 1.31s	remaining: 5.47s
# 580:	learn: 7.7888208	total: 1.31s	remaining: 5.47s
# 581:	learn: 7.7886636	total: 1.31s	remaining: 5.46s
# 582:	learn: 7.7885387	total: 1.32s	remaining: 5.46s
# 583:	learn: 7.7884068	total: 1.32s	remaining: 5.46s
# 584:	learn: 7.7883169	total: 1.32s	remaining: 5.45s
# 585:	learn: 7.7881371	total: 1.32s	remaining: 5.45s
# 586:	learn: 7.7879622	total: 1.32s	remaining: 5.44s
# 587:	learn: 7.7878630	total: 1.32s	remaining: 5.44s
# 588:	learn: 7.7877291	total: 1.33s	remaining: 5.43s
# 589:	learn: 7.7874932	total: 1.33s	remaining: 5.43s
# 590:	learn: 7.7873927	total: 1.33s	remaining: 5.43s
# 591:	learn: 7.7872938	total: 1.33s	remaining: 5.42s
# 592:	learn: 7.7872155	total: 1.33s	remaining: 5.42s
# 593:	learn: 7.7870421	total: 1.34s	remaining: 5.42s
# 594:	learn: 7.7868745	total: 1.34s	remaining: 5.41s
# 595:	learn: 7.7867984	total: 1.34s	remaining: 5.41s
# 596:	learn: 7.7867224	total: 1.34s	remaining: 5.4s
# 597:	learn: 7.7865628	total: 1.34s	remaining: 5.4s
# 598:	learn: 7.7863679	total: 1.34s	remaining: 5.39s
# 599:	learn: 7.7862106	total: 1.35s	remaining: 5.39s
# 600:	learn: 7.7860369	total: 1.35s	remaining: 5.39s
# 601:	learn: 7.7859556	total: 1.35s	remaining: 5.38s
# 602:	learn: 7.7857973	total: 1.35s	remaining: 5.38s
# 603:	learn: 7.7856506	total: 1.35s	remaining: 5.38s
# 604:	learn: 7.7855703	total: 1.36s	remaining: 5.37s
# 605:	learn: 7.7854740	total: 1.36s	remaining: 5.37s
# 606:	learn: 7.7853796	total: 1.36s	remaining: 5.36s
# 607:	learn: 7.7852778	total: 1.36s	remaining: 5.36s
# 608:	learn: 7.7852206	total: 1.36s	remaining: 5.36s
# 609:	learn: 7.7851435	total: 1.37s	remaining: 5.35s
# 610:	learn: 7.7849364	total: 1.37s	remaining: 5.35s
# 611:	learn: 7.7848250	total: 1.37s	remaining: 5.34s
# 612:	learn: 7.7847145	total: 1.37s	remaining: 5.34s
# 613:	learn: 7.7846519	total: 1.37s	remaining: 5.34s
# 614:	learn: 7.7845013	total: 1.38s	remaining: 5.33s
# 615:	learn: 7.7843503	total: 1.38s	remaining: 5.33s
# 616:	learn: 7.7842328	total: 1.38s	remaining: 5.33s
# 617:	learn: 7.7840632	total: 1.38s	remaining: 5.33s
# 618:	learn: 7.7839797	total: 1.38s	remaining: 5.32s
# 619:	learn: 7.7838239	total: 1.39s	remaining: 5.32s
# 620:	learn: 7.7837269	total: 1.39s	remaining: 5.32s
# 621:	learn: 7.7836075	total: 1.39s	remaining: 5.31s
# 622:	learn: 7.7834472	total: 1.39s	remaining: 5.31s
# 623:	learn: 7.7832724	total: 1.4s	remaining: 5.32s
# 624:	learn: 7.7831594	total: 1.4s	remaining: 5.33s
# 625:	learn: 7.7830258	total: 1.41s	remaining: 5.33s
# 626:	learn: 7.7829121	total: 1.41s	remaining: 5.33s
# 627:	learn: 7.7827762	total: 1.41s	remaining: 5.33s
# 628:	learn: 7.7826438	total: 1.41s	remaining: 5.32s
# 629:	learn: 7.7825626	total: 1.41s	remaining: 5.32s
# 630:	learn: 7.7824148	total: 1.42s	remaining: 5.32s
# 631:	learn: 7.7822799	total: 1.42s	remaining: 5.31s
# 632:	learn: 7.7820865	total: 1.42s	remaining: 5.31s
# 633:	learn: 7.7819628	total: 1.42s	remaining: 5.3s
# 634:	learn: 7.7818616	total: 1.42s	remaining: 5.3s
# 635:	learn: 7.7817325	total: 1.43s	remaining: 5.3s
# 636:	learn: 7.7816460	total: 1.43s	remaining: 5.29s
# 637:	learn: 7.7815458	total: 1.43s	remaining: 5.29s
# 638:	learn: 7.7814385	total: 1.43s	remaining: 5.29s
# 639:	learn: 7.7812779	total: 1.43s	remaining: 5.28s
# 640:	learn: 7.7811548	total: 1.43s	remaining: 5.28s
# 641:	learn: 7.7810359	total: 1.44s	remaining: 5.28s
# 642:	learn: 7.7809556	total: 1.44s	remaining: 5.27s
# 643:	learn: 7.7808052	total: 1.44s	remaining: 5.27s
# 644:	learn: 7.7805697	total: 1.44s	remaining: 5.27s
# 645:	learn: 7.7804614	total: 1.44s	remaining: 5.26s
# 646:	learn: 7.7803387	total: 1.45s	remaining: 5.26s
# 647:	learn: 7.7801616	total: 1.45s	remaining: 5.26s
# 648:	learn: 7.7800575	total: 1.45s	remaining: 5.25s
# 649:	learn: 7.7799335	total: 1.45s	remaining: 5.25s
# 650:	learn: 7.7797815	total: 1.45s	remaining: 5.24s
# 651:	learn: 7.7797577	total: 1.46s	remaining: 5.24s
# 652:	learn: 7.7796574	total: 1.46s	remaining: 5.24s
# 653:	learn: 7.7795932	total: 1.46s	remaining: 5.24s
# 654:	learn: 7.7795183	total: 1.46s	remaining: 5.23s
# 655:	learn: 7.7793567	total: 1.46s	remaining: 5.23s
# 656:	learn: 7.7792326	total: 1.47s	remaining: 5.22s
# 657:	learn: 7.7790764	total: 1.47s	remaining: 5.22s
# 658:	learn: 7.7788129	total: 1.47s	remaining: 5.22s
# 659:	learn: 7.7787538	total: 1.47s	remaining: 5.21s
# 660:	learn: 7.7786683	total: 1.47s	remaining: 5.21s
# 661:	learn: 7.7786095	total: 1.47s	remaining: 5.21s
# 662:	learn: 7.7785108	total: 1.48s	remaining: 5.2s
# 663:	learn: 7.7783813	total: 1.48s	remaining: 5.2s
# 664:	learn: 7.7781865	total: 1.48s	remaining: 5.2s
# 665:	learn: 7.7780444	total: 1.48s	remaining: 5.19s
# 666:	learn: 7.7779329	total: 1.48s	remaining: 5.19s
# 667:	learn: 7.7777494	total: 1.49s	remaining: 5.19s
# 668:	learn: 7.7776047	total: 1.49s	remaining: 5.18s
# 669:	learn: 7.7774784	total: 1.49s	remaining: 5.18s
# 670:	learn: 7.7773765	total: 1.49s	remaining: 5.17s
# 671:	learn: 7.7772219	total: 1.49s	remaining: 5.17s
# 672:	learn: 7.7771026	total: 1.49s	remaining: 5.17s
# 673:	learn: 7.7770280	total: 1.5s	remaining: 5.16s
# 674:	learn: 7.7769445	total: 1.5s	remaining: 5.16s
# 675:	learn: 7.7767795	total: 1.5s	remaining: 5.16s
# 676:	learn: 7.7766693	total: 1.5s	remaining: 5.16s
# 677:	learn: 7.7765542	total: 1.5s	remaining: 5.15s
# 678:	learn: 7.7764648	total: 1.51s	remaining: 5.15s
# 679:	learn: 7.7761993	total: 1.51s	remaining: 5.15s
# 680:	learn: 7.7761128	total: 1.51s	remaining: 5.14s
# 681:	learn: 7.7759048	total: 1.51s	remaining: 5.14s
# 682:	learn: 7.7757643	total: 1.51s	remaining: 5.14s
# 683:	learn: 7.7757016	total: 1.52s	remaining: 5.13s
# 684:	learn: 7.7755749	total: 1.52s	remaining: 5.13s
# 685:	learn: 7.7754598	total: 1.52s	remaining: 5.13s
# 686:	learn: 7.7753717	total: 1.52s	remaining: 5.12s
# 687:	learn: 7.7753103	total: 1.52s	remaining: 5.12s
# 688:	learn: 7.7751424	total: 1.52s	remaining: 5.12s
# 689:	learn: 7.7750740	total: 1.53s	remaining: 5.12s
# 690:	learn: 7.7749646	total: 1.53s	remaining: 5.11s
# 691:	learn: 7.7748418	total: 1.53s	remaining: 5.11s
# 692:	learn: 7.7747006	total: 1.53s	remaining: 5.11s
# 693:	learn: 7.7745797	total: 1.54s	remaining: 5.11s
# 694:	learn: 7.7744926	total: 1.54s	remaining: 5.1s
# 695:	learn: 7.7743955	total: 1.54s	remaining: 5.1s
# 696:	learn: 7.7742279	total: 1.54s	remaining: 5.1s
# 697:	learn: 7.7741189	total: 1.54s	remaining: 5.09s
# 698:	learn: 7.7740861	total: 1.55s	remaining: 5.09s
# 699:	learn: 7.7739903	total: 1.55s	remaining: 5.09s
# 700:	learn: 7.7738999	total: 1.55s	remaining: 5.08s
# 701:	learn: 7.7737832	total: 1.55s	remaining: 5.08s
# 702:	learn: 7.7736938	total: 1.55s	remaining: 5.08s
# 703:	learn: 7.7735523	total: 1.56s	remaining: 5.08s
# 704:	learn: 7.7734667	total: 1.56s	remaining: 5.07s
# 705:	learn: 7.7733702	total: 1.56s	remaining: 5.07s
# 706:	learn: 7.7732448	total: 1.56s	remaining: 5.07s
# 707:	learn: 7.7730972	total: 1.56s	remaining: 5.06s
# 708:	learn: 7.7729923	total: 1.57s	remaining: 5.06s
# 709:	learn: 7.7729409	total: 1.57s	remaining: 5.06s
# 710:	learn: 7.7728048	total: 1.57s	remaining: 5.06s
# 711:	learn: 7.7726588	total: 1.57s	remaining: 5.05s
# 712:	learn: 7.7725166	total: 1.57s	remaining: 5.05s
# 713:	learn: 7.7724604	total: 1.58s	remaining: 5.05s
# 714:	learn: 7.7723365	total: 1.58s	remaining: 5.05s
# 715:	learn: 7.7722326	total: 1.58s	remaining: 5.04s
# 716:	learn: 7.7721265	total: 1.58s	remaining: 5.04s
# 717:	learn: 7.7720300	total: 1.58s	remaining: 5.04s
# 718:	learn: 7.7718926	total: 1.59s	remaining: 5.04s
# 719:	learn: 7.7717450	total: 1.59s	remaining: 5.04s
# 720:	learn: 7.7716507	total: 1.6s	remaining: 5.05s
# 721:	learn: 7.7715629	total: 1.6s	remaining: 5.06s
# 722:	learn: 7.7714593	total: 1.61s	remaining: 5.06s
# 723:	learn: 7.7713792	total: 1.61s	remaining: 5.05s
# 724:	learn: 7.7712933	total: 1.61s	remaining: 5.05s
# 725:	learn: 7.7711244	total: 1.61s	remaining: 5.05s
# 726:	learn: 7.7710157	total: 1.61s	remaining: 5.04s
# 727:	learn: 7.7708986	total: 1.61s	remaining: 5.04s
# 728:	learn: 7.7707136	total: 1.62s	remaining: 5.04s
# 729:	learn: 7.7705544	total: 1.62s	remaining: 5.03s
# 730:	learn: 7.7704630	total: 1.62s	remaining: 5.03s
# 731:	learn: 7.7703690	total: 1.62s	remaining: 5.03s
# 732:	learn: 7.7702506	total: 1.62s	remaining: 5.02s
# 733:	learn: 7.7701493	total: 1.63s	remaining: 5.02s
# 734:	learn: 7.7700717	total: 1.63s	remaining: 5.02s
# 735:	learn: 7.7699440	total: 1.63s	remaining: 5.01s
# 736:	learn: 7.7698137	total: 1.63s	remaining: 5.01s
# 737:	learn: 7.7695824	total: 1.63s	remaining: 5.01s
# 738:	learn: 7.7695077	total: 1.64s	remaining: 5s
# 739:	learn: 7.7693471	total: 1.64s	remaining: 5s
# 740:	learn: 7.7692673	total: 1.64s	remaining: 5s
# 741:	learn: 7.7691872	total: 1.64s	remaining: 5s
# 742:	learn: 7.7690562	total: 1.64s	remaining: 4.99s
# 743:	learn: 7.7689262	total: 1.65s	remaining: 4.99s
# 744:	learn: 7.7687843	total: 1.65s	remaining: 4.99s
# 745:	learn: 7.7686891	total: 1.65s	remaining: 4.98s
# 746:	learn: 7.7685739	total: 1.65s	remaining: 4.98s
# 747:	learn: 7.7684870	total: 1.65s	remaining: 4.98s
# 748:	learn: 7.7683367	total: 1.65s	remaining: 4.97s
# 749:	learn: 7.7681587	total: 1.66s	remaining: 4.97s
# 750:	learn: 7.7680808	total: 1.66s	remaining: 4.97s
# 751:	learn: 7.7679692	total: 1.66s	remaining: 4.96s
# 752:	learn: 7.7677922	total: 1.66s	remaining: 4.96s
# 753:	learn: 7.7677484	total: 1.66s	remaining: 4.96s
# 754:	learn: 7.7676451	total: 1.67s	remaining: 4.96s
# 755:	learn: 7.7675820	total: 1.67s	remaining: 4.95s
# 756:	learn: 7.7674899	total: 1.67s	remaining: 4.95s
# 757:	learn: 7.7673593	total: 1.67s	remaining: 4.94s
# 758:	learn: 7.7672440	total: 1.67s	remaining: 4.94s
# 759:	learn: 7.7670429	total: 1.68s	remaining: 4.94s
# 760:	learn: 7.7669199	total: 1.68s	remaining: 4.94s
# 761:	learn: 7.7668446	total: 1.68s	remaining: 4.93s
# 762:	learn: 7.7667773	total: 1.68s	remaining: 4.93s
# 763:	learn: 7.7666418	total: 1.68s	remaining: 4.93s
# 764:	learn: 7.7665221	total: 1.68s	remaining: 4.92s
# 765:	learn: 7.7664461	total: 1.69s	remaining: 4.92s
# 766:	learn: 7.7661928	total: 1.69s	remaining: 4.92s
# 767:	learn: 7.7661380	total: 1.69s	remaining: 4.91s
# 768:	learn: 7.7660199	total: 1.69s	remaining: 4.91s
# 769:	learn: 7.7658898	total: 1.69s	remaining: 4.91s
# 770:	learn: 7.7658248	total: 1.7s	remaining: 4.9s
# 771:	learn: 7.7656809	total: 1.7s	remaining: 4.9s
# 772:	learn: 7.7655583	total: 1.7s	remaining: 4.9s
# 773:	learn: 7.7654069	total: 1.7s	remaining: 4.89s
# 774:	learn: 7.7653464	total: 1.7s	remaining: 4.89s
# 775:	learn: 7.7652753	total: 1.71s	remaining: 4.89s
# 776:	learn: 7.7651446	total: 1.71s	remaining: 4.88s
# 777:	learn: 7.7650815	total: 1.71s	remaining: 4.88s
# 778:	learn: 7.7649285	total: 1.71s	remaining: 4.88s
# 779:	learn: 7.7648525	total: 1.71s	remaining: 4.87s
# 780:	learn: 7.7646774	total: 1.71s	remaining: 4.87s
# 781:	learn: 7.7645563	total: 1.72s	remaining: 4.87s
# 782:	learn: 7.7644237	total: 1.72s	remaining: 4.87s
# 783:	learn: 7.7643020	total: 1.72s	remaining: 4.86s
# 784:	learn: 7.7641976	total: 1.72s	remaining: 4.86s
# 785:	learn: 7.7640225	total: 1.72s	remaining: 4.86s
# 786:	learn: 7.7638843	total: 1.73s	remaining: 4.85s
# 787:	learn: 7.7637800	total: 1.73s	remaining: 4.85s
# 788:	learn: 7.7636180	total: 1.73s	remaining: 4.85s
# 789:	learn: 7.7635514	total: 1.73s	remaining: 4.84s
# 790:	learn: 7.7634470	total: 1.73s	remaining: 4.84s
# 791:	learn: 7.7633260	total: 1.74s	remaining: 4.84s
# 792:	learn: 7.7632023	total: 1.74s	remaining: 4.84s
# 793:	learn: 7.7630902	total: 1.74s	remaining: 4.83s
# 794:	learn: 7.7629183	total: 1.74s	remaining: 4.83s
# 795:	learn: 7.7628326	total: 1.74s	remaining: 4.83s
# 796:	learn: 7.7627279	total: 1.74s	remaining: 4.82s
# 797:	learn: 7.7625914	total: 1.75s	remaining: 4.82s
# 798:	learn: 7.7624519	total: 1.75s	remaining: 4.82s
# 799:	learn: 7.7623337	total: 1.75s	remaining: 4.81s
# 800:	learn: 7.7622072	total: 1.75s	remaining: 4.81s
# 801:	learn: 7.7621485	total: 1.75s	remaining: 4.81s
# 802:	learn: 7.7620542	total: 1.76s	remaining: 4.81s
# 803:	learn: 7.7619057	total: 1.76s	remaining: 4.8s
# 804:	learn: 7.7616970	total: 1.76s	remaining: 4.8s
# 805:	learn: 7.7616516	total: 1.76s	remaining: 4.8s
# 806:	learn: 7.7615723	total: 1.76s	remaining: 4.8s
# 807:	learn: 7.7614158	total: 1.77s	remaining: 4.79s
# 808:	learn: 7.7613449	total: 1.77s	remaining: 4.79s
# 809:	learn: 7.7612338	total: 1.77s	remaining: 4.8s
# 810:	learn: 7.7611069	total: 1.78s	remaining: 4.8s
# 811:	learn: 7.7610138	total: 1.79s	remaining: 4.81s
# 812:	learn: 7.7608418	total: 1.79s	remaining: 4.82s
# 813:	learn: 7.7607496	total: 1.8s	remaining: 4.82s
# 814:	learn: 7.7606643	total: 1.8s	remaining: 4.82s
# 815:	learn: 7.7605486	total: 1.8s	remaining: 4.82s
# 816:	learn: 7.7604198	total: 1.8s	remaining: 4.82s
# 817:	learn: 7.7603064	total: 1.8s	remaining: 4.82s
# 818:	learn: 7.7601794	total: 1.81s	remaining: 4.81s
# 819:	learn: 7.7600412	total: 1.81s	remaining: 4.81s
# 820:	learn: 7.7599314	total: 1.81s	remaining: 4.81s
# 821:	learn: 7.7597065	total: 1.81s	remaining: 4.81s
# 822:	learn: 7.7595709	total: 1.81s	remaining: 4.8s
# 823:	learn: 7.7595113	total: 1.82s	remaining: 4.8s
# 824:	learn: 7.7594185	total: 1.82s	remaining: 4.8s
# 825:	learn: 7.7593173	total: 1.82s	remaining: 4.79s
# 826:	learn: 7.7592310	total: 1.82s	remaining: 4.79s
# 827:	learn: 7.7591527	total: 1.82s	remaining: 4.79s
# 828:	learn: 7.7590670	total: 1.83s	remaining: 4.78s
# 829:	learn: 7.7588894	total: 1.83s	remaining: 4.78s
# 830:	learn: 7.7587193	total: 1.83s	remaining: 4.78s
# 831:	learn: 7.7586220	total: 1.83s	remaining: 4.78s
# 832:	learn: 7.7584957	total: 1.83s	remaining: 4.77s
# 833:	learn: 7.7584122	total: 1.84s	remaining: 4.77s
# 834:	learn: 7.7583117	total: 1.84s	remaining: 4.77s
# 835:	learn: 7.7582140	total: 1.84s	remaining: 4.76s
# 836:	learn: 7.7581467	total: 1.84s	remaining: 4.76s
# 837:	learn: 7.7580442	total: 1.84s	remaining: 4.76s
# 838:	learn: 7.7579156	total: 1.85s	remaining: 4.75s
# 839:	learn: 7.7578028	total: 1.85s	remaining: 4.75s
# 840:	learn: 7.7576913	total: 1.85s	remaining: 4.75s
# 841:	learn: 7.7576433	total: 1.85s	remaining: 4.75s
# 842:	learn: 7.7575502	total: 1.85s	remaining: 4.74s
# 843:	learn: 7.7573849	total: 1.86s	remaining: 4.74s
# 844:	learn: 7.7573307	total: 1.86s	remaining: 4.74s
# 845:	learn: 7.7572601	total: 1.86s	remaining: 4.74s
# 846:	learn: 7.7571441	total: 1.86s	remaining: 4.73s
# 847:	learn: 7.7570162	total: 1.86s	remaining: 4.73s
# 848:	learn: 7.7568608	total: 1.86s	remaining: 4.73s
# 849:	learn: 7.7567367	total: 1.87s	remaining: 4.72s
# 850:	learn: 7.7566194	total: 1.87s	remaining: 4.72s
# 851:	learn: 7.7565269	total: 1.87s	remaining: 4.71s
# 852:	learn: 7.7564338	total: 1.87s	remaining: 4.71s
# 853:	learn: 7.7562994	total: 1.87s	remaining: 4.71s
# 854:	learn: 7.7561411	total: 1.88s	remaining: 4.71s
# 855:	learn: 7.7560409	total: 1.88s	remaining: 4.71s
# 856:	learn: 7.7559216	total: 1.88s	remaining: 4.7s
# 857:	learn: 7.7558297	total: 1.88s	remaining: 4.7s
# 858:	learn: 7.7556989	total: 1.88s	remaining: 4.7s
# 859:	learn: 7.7555332	total: 1.89s	remaining: 4.7s
# 860:	learn: 7.7553594	total: 1.89s	remaining: 4.69s
# 861:	learn: 7.7552353	total: 1.89s	remaining: 4.69s
# 862:	learn: 7.7551435	total: 1.89s	remaining: 4.69s
# 863:	learn: 7.7550106	total: 1.89s	remaining: 4.68s
# 864:	learn: 7.7549497	total: 1.9s	remaining: 4.68s
# 865:	learn: 7.7548088	total: 1.9s	remaining: 4.68s
# 866:	learn: 7.7547144	total: 1.9s	remaining: 4.68s
# 867:	learn: 7.7545964	total: 1.9s	remaining: 4.67s
# 868:	learn: 7.7544632	total: 1.91s	remaining: 4.67s
# 869:	learn: 7.7543439	total: 1.91s	remaining: 4.67s
# 870:	learn: 7.7542156	total: 1.91s	remaining: 4.66s
# 871:	learn: 7.7541299	total: 1.91s	remaining: 4.66s
# 872:	learn: 7.7540041	total: 1.91s	remaining: 4.66s
# 873:	learn: 7.7539003	total: 1.91s	remaining: 4.66s
# 874:	learn: 7.7537736	total: 1.92s	remaining: 4.65s
# 875:	learn: 7.7536411	total: 1.92s	remaining: 4.65s
# 876:	learn: 7.7535602	total: 1.92s	remaining: 4.65s
# 877:	learn: 7.7534044	total: 1.92s	remaining: 4.64s
# 878:	learn: 7.7532816	total: 1.92s	remaining: 4.64s
# 879:	learn: 7.7531584	total: 1.93s	remaining: 4.64s
# 880:	learn: 7.7530339	total: 1.93s	remaining: 4.63s
# 881:	learn: 7.7529211	total: 1.93s	remaining: 4.63s
# 882:	learn: 7.7528182	total: 1.93s	remaining: 4.63s
# 883:	learn: 7.7526705	total: 1.93s	remaining: 4.63s
# 884:	learn: 7.7525202	total: 1.94s	remaining: 4.63s
# 885:	learn: 7.7523638	total: 1.94s	remaining: 4.62s
# 886:	learn: 7.7522303	total: 1.94s	remaining: 4.62s
# 887:	learn: 7.7520965	total: 1.94s	remaining: 4.62s
# 888:	learn: 7.7519720	total: 1.94s	remaining: 4.61s
# 889:	learn: 7.7518595	total: 1.95s	remaining: 4.61s
# 890:	learn: 7.7516898	total: 1.95s	remaining: 4.61s
# 891:	learn: 7.7516182	total: 1.95s	remaining: 4.61s
# 892:	learn: 7.7514641	total: 1.95s	remaining: 4.6s
# 893:	learn: 7.7513302	total: 1.95s	remaining: 4.6s
# 894:	learn: 7.7512141	total: 1.95s	remaining: 4.6s
# 895:	learn: 7.7510880	total: 1.96s	remaining: 4.59s
# 896:	learn: 7.7509986	total: 1.96s	remaining: 4.59s
# 897:	learn: 7.7509158	total: 1.96s	remaining: 4.59s
# 898:	learn: 7.7508045	total: 1.96s	remaining: 4.59s
# 899:	learn: 7.7507467	total: 1.97s	remaining: 4.58s
# 900:	learn: 7.7506858	total: 1.97s	remaining: 4.58s
# 901:	learn: 7.7505797	total: 1.97s	remaining: 4.59s
# 902:	learn: 7.7505277	total: 1.98s	remaining: 4.59s
# 903:	learn: 7.7504077	total: 1.98s	remaining: 4.6s
# 904:	learn: 7.7503377	total: 1.99s	remaining: 4.59s
# 905:	learn: 7.7502003	total: 1.99s	remaining: 4.59s
# 906:	learn: 7.7500745	total: 1.99s	remaining: 4.59s
# 907:	learn: 7.7499268	total: 1.99s	remaining: 4.59s
# 908:	learn: 7.7497713	total: 1.99s	remaining: 4.58s
# 909:	learn: 7.7496661	total: 1.99s	remaining: 4.58s
# 910:	learn: 7.7495451	total: 2s	remaining: 4.58s
# 911:	learn: 7.7493267	total: 2s	remaining: 4.57s
# 912:	learn: 7.7492287	total: 2s	remaining: 4.57s
# 913:	learn: 7.7490864	total: 2s	remaining: 4.57s
# 914:	learn: 7.7490006	total: 2s	remaining: 4.57s
# 915:	learn: 7.7488886	total: 2.01s	remaining: 4.56s
# 916:	learn: 7.7487238	total: 2.01s	remaining: 4.56s
# 917:	learn: 7.7486373	total: 2.01s	remaining: 4.56s
# 918:	learn: 7.7485441	total: 2.01s	remaining: 4.55s
# 919:	learn: 7.7484156	total: 2.01s	remaining: 4.55s
# 920:	learn: 7.7482417	total: 2.02s	remaining: 4.55s
# 921:	learn: 7.7480304	total: 2.02s	remaining: 4.54s
# 922:	learn: 7.7479591	total: 2.02s	remaining: 4.54s
# 923:	learn: 7.7478300	total: 2.02s	remaining: 4.54s
# 924:	learn: 7.7477168	total: 2.02s	remaining: 4.54s
# 925:	learn: 7.7476074	total: 2.02s	remaining: 4.54s
# 926:	learn: 7.7474990	total: 2.03s	remaining: 4.53s
# ...
# 2700:	learn: 7.5610948	total: 6.01s	remaining: 665ms
# 2701:	learn: 7.5610158	total: 6.01s	remaining: 663ms
# 2702:	learn: 7.5609398	total: 6.01s	remaining: 660ms
# 2703:	learn: 7.5608822	total: 6.01s	remaining: 658ms
# 2704:	learn: 7.5607929	total: 6.01s	remaining: 656ms
# 2705:	learn: 7.5606660	total: 6.02s	remaining: 654ms
# 2706:	learn: 7.5605347	total: 6.02s	remaining: 651ms
# 2707:	learn: 7.5604448	total: 6.02s	remaining: 649ms
# 2708:	learn: 7.5603733	total: 6.02s	remaining: 647ms
# 2709:	learn: 7.5602900	total: 6.02s	remaining: 645ms
# 2710:	learn: 7.5602202	total: 6.03s	remaining: 642ms
# 2711:	learn: 7.5601508	total: 6.03s	remaining: 640ms
# 2712:	learn: 7.5600274	total: 6.03s	remaining: 638ms
# 2713:	learn: 7.5599808	total: 6.03s	remaining: 636ms
# 2714:	learn: 7.5599306	total: 6.03s	remaining: 633ms
# 2715:	learn: 7.5598419	total: 6.04s	remaining: 631ms
# 2716:	learn: 7.5597249	total: 6.04s	remaining: 629ms
# 2717:	learn: 7.5595665	total: 6.04s	remaining: 627ms
# 2718:	learn: 7.5594917	total: 6.04s	remaining: 624ms
# 2719:	learn: 7.5593515	total: 6.04s	remaining: 622ms
# 2720:	learn: 7.5592351	total: 6.04s	remaining: 620ms
# 2721:	learn: 7.5591891	total: 6.04s	remaining: 617ms
# 2722:	learn: 7.5591061	total: 6.05s	remaining: 615ms
# 2723:	learn: 7.5589831	total: 6.05s	remaining: 613ms
# 2724:	learn: 7.5588733	total: 6.05s	remaining: 611ms
# 2725:	learn: 7.5588041	total: 6.05s	remaining: 608ms
# 2726:	learn: 7.5587066	total: 6.05s	remaining: 606ms
# 2727:	learn: 7.5586715	total: 6.06s	remaining: 604ms
# 2728:	learn: 7.5585630	total: 6.06s	remaining: 602ms
# 2729:	learn: 7.5584932	total: 6.06s	remaining: 599ms
# 2730:	learn: 7.5583920	total: 6.06s	remaining: 597ms
# 2731:	learn: 7.5583646	total: 6.06s	remaining: 595ms
# 2732:	learn: 7.5582921	total: 6.07s	remaining: 593ms
# 2733:	learn: 7.5582091	total: 6.07s	remaining: 590ms
# 2734:	learn: 7.5581274	total: 6.07s	remaining: 588ms
# 2735:	learn: 7.5580841	total: 6.07s	remaining: 586ms
# 2736:	learn: 7.5580021	total: 6.07s	remaining: 584ms
# 2737:	learn: 7.5579041	total: 6.07s	remaining: 581ms
# 2738:	learn: 7.5577404	total: 6.08s	remaining: 579ms
# 2739:	learn: 7.5576590	total: 6.08s	remaining: 577ms
# 2740:	learn: 7.5574976	total: 6.08s	remaining: 574ms
# 2741:	learn: 7.5574281	total: 6.08s	remaining: 572ms
# 2742:	learn: 7.5573200	total: 6.08s	remaining: 570ms
# 2743:	learn: 7.5572224	total: 6.08s	remaining: 568ms
# 2744:	learn: 7.5570679	total: 6.09s	remaining: 565ms
# 2745:	learn: 7.5569746	total: 6.09s	remaining: 563ms
# 2746:	learn: 7.5568714	total: 6.09s	remaining: 561ms
# 2747:	learn: 7.5567384	total: 6.09s	remaining: 559ms
# 2748:	learn: 7.5566190	total: 6.09s	remaining: 556ms
# 2749:	learn: 7.5565088	total: 6.1s	remaining: 554ms
# 2750:	learn: 7.5564208	total: 6.1s	remaining: 552ms
# 2751:	learn: 7.5564029	total: 6.1s	remaining: 550ms
# 2752:	learn: 7.5563434	total: 6.1s	remaining: 547ms
# 2753:	learn: 7.5562659	total: 6.1s	remaining: 545ms
# 2754:	learn: 7.5561306	total: 6.11s	remaining: 543ms
# 2755:	learn: 7.5560267	total: 6.11s	remaining: 541ms
# 2756:	learn: 7.5559563	total: 6.11s	remaining: 538ms
# 2757:	learn: 7.5558051	total: 6.11s	remaining: 536ms
# 2758:	learn: 7.5557425	total: 6.11s	remaining: 534ms
# 2759:	learn: 7.5556515	total: 6.12s	remaining: 532ms
# 2760:	learn: 7.5555708	total: 6.12s	remaining: 530ms
# 2761:	learn: 7.5554924	total: 6.12s	remaining: 527ms
# 2762:	learn: 7.5553759	total: 6.12s	remaining: 525ms
# 2763:	learn: 7.5552932	total: 6.13s	remaining: 523ms
# 2764:	learn: 7.5551774	total: 6.13s	remaining: 521ms
# 2765:	learn: 7.5550407	total: 6.13s	remaining: 519ms
# 2766:	learn: 7.5548799	total: 6.14s	remaining: 517ms
# 2767:	learn: 7.5547876	total: 6.14s	remaining: 515ms
# 2768:	learn: 7.5547382	total: 6.14s	remaining: 512ms
# 2769:	learn: 7.5546876	total: 6.14s	remaining: 510ms
# 2770:	learn: 7.5546420	total: 6.14s	remaining: 508ms
# 2771:	learn: 7.5545324	total: 6.15s	remaining: 506ms
# 2772:	learn: 7.5544828	total: 6.15s	remaining: 503ms
# 2773:	learn: 7.5543574	total: 6.15s	remaining: 501ms
# 2774:	learn: 7.5542908	total: 6.15s	remaining: 499ms
# 2775:	learn: 7.5541919	total: 6.15s	remaining: 497ms
# 2776:	learn: 7.5541409	total: 6.16s	remaining: 494ms
# 2777:	learn: 7.5540294	total: 6.16s	remaining: 492ms
# 2778:	learn: 7.5539672	total: 6.16s	remaining: 490ms
# 2779:	learn: 7.5539112	total: 6.16s	remaining: 488ms
# 2780:	learn: 7.5538798	total: 6.16s	remaining: 485ms
# 2781:	learn: 7.5537997	total: 6.17s	remaining: 483ms
# 2782:	learn: 7.5536878	total: 6.17s	remaining: 481ms
# 2783:	learn: 7.5535935	total: 6.17s	remaining: 479ms
# 2784:	learn: 7.5534962	total: 6.17s	remaining: 476ms
# 2785:	learn: 7.5534016	total: 6.17s	remaining: 474ms
# 2786:	learn: 7.5533370	total: 6.17s	remaining: 472ms
# 2787:	learn: 7.5532685	total: 6.18s	remaining: 470ms
# 2788:	learn: 7.5531987	total: 6.18s	remaining: 468ms
# 2789:	learn: 7.5531080	total: 6.18s	remaining: 465ms
# 2790:	learn: 7.5530236	total: 6.18s	remaining: 463ms
# 2791:	learn: 7.5529163	total: 6.18s	remaining: 461ms
# 2792:	learn: 7.5527836	total: 6.19s	remaining: 459ms
# 2793:	learn: 7.5526022	total: 6.19s	remaining: 456ms
# 2794:	learn: 7.5524820	total: 6.19s	remaining: 454ms
# 2795:	learn: 7.5523983	total: 6.19s	remaining: 452ms
# 2796:	learn: 7.5522649	total: 6.19s	remaining: 450ms
# 2797:	learn: 7.5521815	total: 6.2s	remaining: 447ms
# 2798:	learn: 7.5520732	total: 6.2s	remaining: 445ms
# 2799:	learn: 7.5519944	total: 6.2s	remaining: 443ms
# 2800:	learn: 7.5518620	total: 6.2s	remaining: 441ms
# 2801:	learn: 7.5517458	total: 6.2s	remaining: 438ms
# 2802:	learn: 7.5517074	total: 6.21s	remaining: 436ms
# 2803:	learn: 7.5515694	total: 6.21s	remaining: 434ms
# 2804:	learn: 7.5513992	total: 6.21s	remaining: 432ms
# 2805:	learn: 7.5512870	total: 6.21s	remaining: 429ms
# 2806:	learn: 7.5512208	total: 6.21s	remaining: 427ms
# 2807:	learn: 7.5511072	total: 6.21s	remaining: 425ms
# 2808:	learn: 7.5510423	total: 6.21s	remaining: 423ms
# 2809:	learn: 7.5509850	total: 6.22s	remaining: 420ms
# 2810:	learn: 7.5508850	total: 6.22s	remaining: 418ms
# 2811:	learn: 7.5507635	total: 6.22s	remaining: 416ms
# 2812:	learn: 7.5506851	total: 6.22s	remaining: 414ms
# 2813:	learn: 7.5505791	total: 6.22s	remaining: 412ms
# 2814:	learn: 7.5504655	total: 6.23s	remaining: 409ms
# 2815:	learn: 7.5503679	total: 6.23s	remaining: 407ms
# 2816:	learn: 7.5502215	total: 6.23s	remaining: 405ms
# 2817:	learn: 7.5501136	total: 6.23s	remaining: 403ms
# 2818:	learn: 7.5499215	total: 6.23s	remaining: 400ms
# 2819:	learn: 7.5498156	total: 6.24s	remaining: 398ms
# 2820:	learn: 7.5497649	total: 6.24s	remaining: 396ms
# 2821:	learn: 7.5496861	total: 6.24s	remaining: 394ms
# 2822:	learn: 7.5496179	total: 6.24s	remaining: 391ms
# 2823:	learn: 7.5495384	total: 6.25s	remaining: 389ms
# 2824:	learn: 7.5495089	total: 6.25s	remaining: 387ms
# 2825:	learn: 7.5494205	total: 6.25s	remaining: 385ms
# 2826:	learn: 7.5492976	total: 6.26s	remaining: 383ms
# 2827:	learn: 7.5492294	total: 6.26s	remaining: 381ms
# 2828:	learn: 7.5491546	total: 6.27s	remaining: 379ms
# 2829:	learn: 7.5490708	total: 6.28s	remaining: 377ms
# 2830:	learn: 7.5489953	total: 6.28s	remaining: 375ms
# 2831:	learn: 7.5489145	total: 6.28s	remaining: 373ms
# 2832:	learn: 7.5488062	total: 6.29s	remaining: 371ms
# 2833:	learn: 7.5487406	total: 6.29s	remaining: 368ms
# 2834:	learn: 7.5486270	total: 6.29s	remaining: 366ms
# 2835:	learn: 7.5485588	total: 6.29s	remaining: 364ms
# 2836:	learn: 7.5483452	total: 6.3s	remaining: 362ms
# 2837:	learn: 7.5482528	total: 6.31s	remaining: 360ms
# 2838:	learn: 7.5481726	total: 6.31s	remaining: 358ms
# 2839:	learn: 7.5481001	total: 6.32s	remaining: 356ms
# 2840:	learn: 7.5480365	total: 6.33s	remaining: 354ms
# 2841:	learn: 7.5479732	total: 6.33s	remaining: 352ms
# 2842:	learn: 7.5478967	total: 6.34s	remaining: 350ms
# 2843:	learn: 7.5477838	total: 6.34s	remaining: 348ms
# 2844:	learn: 7.5476996	total: 6.35s	remaining: 346ms
# 2845:	learn: 7.5476606	total: 6.35s	remaining: 344ms
# 2846:	learn: 7.5475715	total: 6.35s	remaining: 342ms
# 2847:	learn: 7.5474433	total: 6.36s	remaining: 339ms
# 2848:	learn: 7.5473750	total: 6.36s	remaining: 337ms
# 2849:	learn: 7.5472078	total: 6.36s	remaining: 335ms
# 2850:	learn: 7.5471004	total: 6.36s	remaining: 333ms
# 2851:	learn: 7.5470358	total: 6.36s	remaining: 330ms
# 2852:	learn: 7.5469279	total: 6.37s	remaining: 328ms
# 2853:	learn: 7.5468457	total: 6.37s	remaining: 326ms
# 2854:	learn: 7.5467559	total: 6.37s	remaining: 324ms
# 2855:	learn: 7.5466771	total: 6.38s	remaining: 322ms
# 2856:	learn: 7.5466400	total: 6.38s	remaining: 319ms
# 2857:	learn: 7.5465568	total: 6.38s	remaining: 317ms
# 2858:	learn: 7.5464247	total: 6.39s	remaining: 315ms
# 2859:	learn: 7.5462666	total: 6.39s	remaining: 313ms
# 2860:	learn: 7.5461447	total: 6.4s	remaining: 311ms
# 2861:	learn: 7.5460748	total: 6.4s	remaining: 309ms
# 2862:	learn: 7.5459270	total: 6.41s	remaining: 307ms
# 2863:	learn: 7.5458306	total: 6.41s	remaining: 305ms
# 2864:	learn: 7.5457028	total: 6.42s	remaining: 302ms
# 2865:	learn: 7.5455749	total: 6.42s	remaining: 300ms
# 2866:	learn: 7.5455179	total: 6.42s	remaining: 298ms
# 2867:	learn: 7.5454228	total: 6.43s	remaining: 296ms
# 2868:	learn: 7.5453194	total: 6.43s	remaining: 293ms
# 2869:	learn: 7.5452193	total: 6.43s	remaining: 291ms
# 2870:	learn: 7.5451620	total: 6.43s	remaining: 289ms
# 2871:	learn: 7.5450706	total: 6.44s	remaining: 287ms
# 2872:	learn: 7.5450245	total: 6.44s	remaining: 285ms
# 2873:	learn: 7.5449225	total: 6.44s	remaining: 282ms
# 2874:	learn: 7.5447969	total: 6.44s	remaining: 280ms
# 2875:	learn: 7.5447124	total: 6.45s	remaining: 278ms
# 2876:	learn: 7.5445586	total: 6.45s	remaining: 276ms
# 2877:	learn: 7.5444871	total: 6.45s	remaining: 274ms
# 2878:	learn: 7.5443492	total: 6.46s	remaining: 271ms
# 2879:	learn: 7.5442372	total: 6.46s	remaining: 269ms
# 2880:	learn: 7.5441315	total: 6.46s	remaining: 267ms
# 2881:	learn: 7.5440791	total: 6.46s	remaining: 265ms
# 2882:	learn: 7.5440139	total: 6.47s	remaining: 263ms
# 2883:	learn: 7.5439002	total: 6.47s	remaining: 260ms
# 2884:	learn: 7.5438435	total: 6.47s	remaining: 258ms
# 2885:	learn: 7.5437895	total: 6.47s	remaining: 256ms
# 2886:	learn: 7.5436768	total: 6.48s	remaining: 254ms
# 2887:	learn: 7.5435088	total: 6.48s	remaining: 251ms
# 2888:	learn: 7.5434018	total: 6.48s	remaining: 249ms
# 2889:	learn: 7.5433464	total: 6.49s	remaining: 247ms
# 2890:	learn: 7.5432500	total: 6.49s	remaining: 245ms
# 2891:	learn: 7.5431300	total: 6.49s	remaining: 242ms
# 2892:	learn: 7.5430591	total: 6.49s	remaining: 240ms
# 2893:	learn: 7.5429245	total: 6.5s	remaining: 238ms
# 2894:	learn: 7.5427959	total: 6.5s	remaining: 236ms
# 2895:	learn: 7.5426825	total: 6.51s	remaining: 234ms
# 2896:	learn: 7.5426090	total: 6.52s	remaining: 232ms
# 2897:	learn: 7.5425046	total: 6.52s	remaining: 229ms
# 2898:	learn: 7.5424399	total: 6.52s	remaining: 227ms
# 2899:	learn: 7.5423988	total: 6.52s	remaining: 225ms
# 2900:	learn: 7.5423037	total: 6.53s	remaining: 223ms
# 2901:	learn: 7.5422308	total: 6.53s	remaining: 221ms
# 2902:	learn: 7.5421701	total: 6.54s	remaining: 218ms
# 2903:	learn: 7.5421134	total: 6.54s	remaining: 216ms
# 2904:	learn: 7.5419779	total: 6.54s	remaining: 214ms
# 2905:	learn: 7.5419106	total: 6.54s	remaining: 212ms
# 2906:	learn: 7.5418085	total: 6.54s	remaining: 209ms
# 2907:	learn: 7.5417196	total: 6.55s	remaining: 207ms
# 2908:	learn: 7.5416295	total: 6.55s	remaining: 205ms
# 2909:	learn: 7.5415267	total: 6.55s	remaining: 203ms
# 2910:	learn: 7.5414418	total: 6.55s	remaining: 200ms
# 2911:	learn: 7.5413742	total: 6.56s	remaining: 198ms
# 2912:	learn: 7.5412751	total: 6.56s	remaining: 196ms
# 2913:	learn: 7.5412068	total: 6.57s	remaining: 194ms
# 2914:	learn: 7.5410865	total: 6.57s	remaining: 192ms
# 2915:	learn: 7.5410221	total: 6.57s	remaining: 189ms
# 2916:	learn: 7.5409598	total: 6.57s	remaining: 187ms
# 2917:	learn: 7.5408322	total: 6.57s	remaining: 185ms
# 2918:	learn: 7.5407055	total: 6.58s	remaining: 183ms
# 2919:	learn: 7.5406167	total: 6.58s	remaining: 180ms
# 2920:	learn: 7.5405530	total: 6.58s	remaining: 178ms
# 2921:	learn: 7.5404300	total: 6.58s	remaining: 176ms
# 2922:	learn: 7.5403720	total: 6.59s	remaining: 174ms
# 2923:	learn: 7.5402851	total: 6.59s	remaining: 171ms
# 2924:	learn: 7.5402082	total: 6.59s	remaining: 169ms
# 2925:	learn: 7.5401160	total: 6.6s	remaining: 167ms
# 2926:	learn: 7.5400186	total: 6.6s	remaining: 165ms
# 2927:	learn: 7.5399446	total: 6.6s	remaining: 162ms
# 2928:	learn: 7.5398402	total: 6.6s	remaining: 160ms
# 2929:	learn: 7.5397513	total: 6.6s	remaining: 158ms
# 2930:	learn: 7.5396717	total: 6.61s	remaining: 156ms
# 2931:	learn: 7.5395501	total: 6.61s	remaining: 153ms
# 2932:	learn: 7.5394297	total: 6.61s	remaining: 151ms
# 2933:	learn: 7.5393591	total: 6.62s	remaining: 149ms
# 2934:	learn: 7.5392327	total: 6.62s	remaining: 147ms
# 2935:	learn: 7.5391700	total: 6.62s	remaining: 144ms
# 2936:	learn: 7.5390759	total: 6.63s	remaining: 142ms
# 2937:	learn: 7.5390556	total: 6.63s	remaining: 140ms
# 2938:	learn: 7.5389489	total: 6.63s	remaining: 138ms
# 2939:	learn: 7.5388670	total: 6.63s	remaining: 135ms
# 2940:	learn: 7.5388139	total: 6.63s	remaining: 133ms
# 2941:	learn: 7.5387177	total: 6.63s	remaining: 131ms
# 2942:	learn: 7.5386451	total: 6.64s	remaining: 129ms
# 2943:	learn: 7.5385851	total: 6.64s	remaining: 126ms
# 2944:	learn: 7.5385085	total: 6.65s	remaining: 124ms
# 2945:	learn: 7.5384511	total: 6.65s	remaining: 122ms
# 2946:	learn: 7.5383715	total: 6.65s	remaining: 120ms
# 2947:	learn: 7.5382959	total: 6.65s	remaining: 117ms
# 2948:	learn: 7.5382312	total: 6.66s	remaining: 115ms
# 2949:	learn: 7.5381709	total: 6.66s	remaining: 113ms
# 2950:	learn: 7.5380906	total: 6.66s	remaining: 111ms
# 2951:	learn: 7.5379851	total: 6.66s	remaining: 108ms
# 2952:	learn: 7.5379029	total: 6.67s	remaining: 106ms
# 2953:	learn: 7.5377636	total: 6.67s	remaining: 104ms
# 2954:	learn: 7.5376913	total: 6.67s	remaining: 102ms
# 2955:	learn: 7.5375404	total: 6.68s	remaining: 99.4ms
# 2956:	learn: 7.5374415	total: 6.68s	remaining: 97.1ms
# 2957:	learn: 7.5373503	total: 6.68s	remaining: 94.9ms
# 2958:	learn: 7.5372366	total: 6.68s	remaining: 92.6ms
# 2959:	learn: 7.5371357	total: 6.68s	remaining: 90.3ms
# 2960:	learn: 7.5370528	total: 6.69s	remaining: 88.1ms
# 2961:	learn: 7.5369831	total: 6.69s	remaining: 85.9ms
# 2962:	learn: 7.5369006	total: 6.69s	remaining: 83.6ms
# 2963:	learn: 7.5368223	total: 6.7s	remaining: 81.3ms
# 2964:	learn: 7.5366780	total: 6.7s	remaining: 79.1ms
# 2965:	learn: 7.5365718	total: 6.7s	remaining: 76.8ms
# 2966:	learn: 7.5364309	total: 6.7s	remaining: 74.5ms
# 2967:	learn: 7.5363091	total: 6.7s	remaining: 72.3ms
# 2968:	learn: 7.5362567	total: 6.71s	remaining: 70ms
# 2969:	learn: 7.5361870	total: 6.71s	remaining: 67.8ms
# 2970:	learn: 7.5360898	total: 6.72s	remaining: 65.6ms
# 2971:	learn: 7.5360033	total: 6.72s	remaining: 63.3ms
# 2972:	learn: 7.5359406	total: 6.73s	remaining: 61.1ms
# 2973:	learn: 7.5358341	total: 6.74s	remaining: 58.9ms
# 2974:	learn: 7.5357495	total: 6.74s	remaining: 56.6ms
# 2975:	learn: 7.5357266	total: 6.74s	remaining: 54.4ms
# 2976:	learn: 7.5356307	total: 6.74s	remaining: 52.1ms
# 2977:	learn: 7.5355381	total: 6.75s	remaining: 49.8ms
# 2978:	learn: 7.5354695	total: 6.75s	remaining: 47.6ms
# 2979:	learn: 7.5354131	total: 6.75s	remaining: 45.3ms
# 2980:	learn: 7.5353212	total: 6.75s	remaining: 43ms
# 2981:	learn: 7.5352306	total: 6.75s	remaining: 40.8ms
# 2982:	learn: 7.5351725	total: 6.76s	remaining: 38.5ms
# 2983:	learn: 7.5350760	total: 6.76s	remaining: 36.2ms
# 2984:	learn: 7.5350192	total: 6.76s	remaining: 34ms
# 2985:	learn: 7.5349625	total: 6.76s	remaining: 31.7ms
# 2986:	learn: 7.5349041	total: 6.76s	remaining: 29.4ms
# 2987:	learn: 7.5347850	total: 6.77s	remaining: 27.2ms
# 2988:	learn: 7.5347037	total: 6.77s	remaining: 24.9ms
# 2989:	learn: 7.5345989	total: 6.77s	remaining: 22.6ms
# 2990:	learn: 7.5344847	total: 6.77s	remaining: 20.4ms
# 2991:	learn: 7.5344018	total: 6.77s	remaining: 18.1ms
# 2992:	learn: 7.5342966	total: 6.78s	remaining: 15.8ms
# 2993:	learn: 7.5342332	total: 6.78s	remaining: 13.6ms
# 2994:	learn: 7.5341629	total: 6.78s	remaining: 11.3ms
# 2995:	learn: 7.5340245	total: 6.78s	remaining: 9.05ms
# 2996:	learn: 7.5339472	total: 6.78s	remaining: 6.79ms
# 2997:	learn: 7.5338755	total: 6.79s	remaining: 4.53ms
# 2998:	learn: 7.5338105	total: 6.79s	remaining: 2.26ms
# 2999:	learn: 7.5337394	total: 6.79s	remaining: 0us
# MSE is 61.62658039789295
# RMSE is 7.850259893652754

# %%
#     dump(preds, f"./preds/{config_rn['name']}/xgboost_fold{fold}_preds.joblib")

# %% [markdown]
# # Inference

# %%
test_df = pd.read_csv(datapath/'test.csv', index_col='id', low_memory=False)

# %%
test_df.head()
# Out:
#               f0   f1        f2        f3          f4        f5         f6  \
# id
# 250000  0.812665   15 -1.239120 -0.893251    295.5770  15.87120   23.04360
# 250001  0.190344  131 -0.501361  0.801921     64.8866   3.09703  344.80500
# 250002  0.919671   19 -0.057382  0.901419  11961.2000  16.39650  273.24000
# 250003  0.860985   19 -0.549509  0.471799   7501.6000   2.80698   71.08170
# 250004  0.313229   89  0.588509  0.167705   2931.2600   4.34986    1.57187
#
#               f7         f8       f9  ...       f90        f91       f92  \
# id                                    ...
# 250000  0.942256  29.898000  1.11394  ...  0.446389   -422.332  -1.44630
# 250001  0.807194  38.421900  1.09695  ...  0.377179  10352.200  21.06270
# 250002 -0.003300  37.940000  1.15222  ...  0.990140   3224.020  -2.25287
# 250003  0.792136   0.395235  1.20157  ...  1.396880   9689.760  14.77150
# 250004  1.118300   7.754630  1.16807  ...  0.862502   2693.350  44.18050
#
#             f93       f94        f95      f96       f97       f98       f99
# id
# 250000  1.69075  1.059300  -3.010570  1.94664  0.529470  1.386950   8.78767
# 250001  1.84351  0.251895   4.440570  1.90309  0.248534  0.863881  11.79390
# 250002  1.55100 -0.559157  17.838600  1.83385  0.931796  2.336870   9.05400
# 250003  1.41390  0.329272   0.802437  2.23251  0.893348  1.359470   4.84833
# 250004  1.58020 -0.191021  26.253000  2.68238  0.361923  1.532800   3.70660
#
# [5 rows x 100 columns]

# %% [markdown]
# (Here's where encapsulating the transformations in a pipeline would come in handy. But I'll do it manually for now.)

# %%
features = [x for x in test_df.columns if x != 'loss']
X_test = test_df[features] # this is just for naming consistency

# %% [markdown]
# Now, let's get the features the model was trained on and subset the test set's features accordingly

# %%
# generation polynomial features
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_test_poly = poly.fit_transform(X_test)

# %%
# X_test_poly_names = poly.get_feature_names(X_test.columns)
# # X_poly_names[100:150]
# features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
# checks = [feature in X_test_poly_names for feature in features]
# checks

# %%
# X_test_final = pd.DataFrame(X_test_poly, columns=X_test_poly_names)

# %%
# X_test_final = X_test_final[features[1:]]

# %% [markdown]
# # Scaling
# Now, going to scale using `MaxAbsScaler`

# %%
X_test_final = X_test

# %%
scaler = config['scaler']()
X_test_scaled = scaler.fit_transform(X_test_final)
# X_scaled_df = pd.DataFrame(X_scaled, columns=X_poly_names)

# %%
# applying hold-out before scaling
# X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
#                                                       test_size=config['test_size'], 
#                                                       random_state=config['random_state']
#                                                      )
# # scaling (i.e. normalizing)
# scaler = config['scaler']()
# X_train_s = scaler.fit_transform(X_train)
# X_test_s = scaler.fit_transform(X_test)

# # selecting features
# selector = config['feature_selector'](score_func=config["feature_selection_scoring"], 
#                                       k=config['k_best'])
# X_train_fs = selector.fit_transform(X_train_s, y_train)
# X_test_fs = X_test_s[:, selector.get_support()]

# model = XGBRegressor(
#     tree_method=config['tree_method'],
#     booster=config['booster'],
#     n_estimators=config['n_estimators'], 
#     max_depth=config['max_depth'],
#     learning_rate=config['learning_rate'], 
#     test_size=config['test_size'],
#     subsample=config['subsample'],
#     random_state=config['random_state'],
#     n_jobs=config['n_jobs'], 
#     verbosity=config['verbosity'], 
# )
# #     wandb.log({'params': model.get_params()}) # logging model parameters
# model.fit(X_train_fs, y_train)#, callbacks=[wandb.xgboost.wandb_callback()])

# %%
models
# Out:
# {0: <catboost.core.CatBoostRegressor at 0x7fa47854b940>,
#  1: <catboost.core.CatBoostRegressor at 0x7fa47854b7f0>,
#  2: <catboost.core.CatBoostRegressor at 0x7fa47854bb80>,
#  3: <catboost.core.CatBoostRegressor at 0x7fa47854b970>,
#  4: <catboost.core.CatBoostRegressor at 0x7fa47856ee80>}

# %% [markdown]
# Now, iterate over the dict containing the models trained on the 5 folds, and store the predictions in a new dict `preds`
# **OR**
# load from a directory.

# %%
# loaded_models = {}
# saved_models_path = Path('/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/models/inference_ensemble_20210828_204126_5folds/')
# for fold in range(5):
#     loaded_models[fold] = load(filename=Path(saved_models_path/f'xgboost_fold{fold}_model.joblib'))

# %%
# models = loaded_models

# %%
preds = {}
for fold in models.keys():
    preds[fold] = models[fold].predict(X_test_scaled)

# %%
sample_df = pd.read_csv(datapath/'sample_submission.csv')

# %%
type(preds[0])
# Out:
# numpy.ndarray

# %%
final_preds = (preds[0] + preds[1] + preds[2] + preds[3] + preds[4]) / 5

# %%
dump(final_preds, '/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/preds/catboost_5fold_no_feature_gen.joblib')
# Out:
# ['/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/preds/catboost_5fold_no_feature_gen.joblib']

# %%
final_preds[:10]
# Out:
# array([8.67110053, 4.62450053, 8.6372614 , 7.22330665, 6.92239076,
#        9.70097104, 9.97590847, 5.72130089, 7.33351626, 7.44252341])

# %%
sample_df.loc[:, 'loss'] = final_preds

# %%
sample_df.head()
# Out:
#        id      loss
# 0  250000  8.671101
# 1  250001  4.624501
# 2  250002  8.637261
# 3  250003  7.223307
# 4  250004  6.922391

# %%
sample_df.to_csv('202108311445_CatBoost_n-est1000per_no-feature-gen.csv', index=False)

# %% [markdown]
# # Experiment - fitting model on full training set

# %%
# applying hold-out before scaling
# X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
#                                                       test_size=config['test_size'], 
#                                                       random_state=config['random_state']
#                                                      )
# scaling (i.e. normalizing)
scaler = config['scaler']()
X_s = scaler.fit_transform(X)
X_test_s = scaler.fit_transform(X_test)

# selecting features
selector = config['feature_selector'](score_func=config["feature_selection_scoring"], 
                                      k=config['k_best'])
X_fs = selector.fit_transform(X_s, y)
X_test_fs = X_test_s[:, selector.get_support()]

model = XGBRegressor(
    tree_method=config['tree_method'],
    booster=config['booster'],
    n_estimators=config['n_estimators'], 
    max_depth=config['max_depth'],
    learning_rate=config['learning_rate'], 
    test_size=config['test_size'],
    subsample=config['subsample'],
    random_state=config['random_state'],
    n_jobs=config['n_jobs'], 
    verbosity=config['verbosity'], 
)
#     wandb.log({'params': model.get_params()}) # logging model parameters
model.fit(X_fs, y)#, callbacks=[wandb.xgboost.wandb_callback()])
# Out:
# [12:11:15] WARNING: ../src/learner.cc:573:
# Parameters: { "test_size" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRegressor(base_score=0.5, booster='dart', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1522, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=400, n_jobs=-1, num_parallel_tree=1, random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              test_size=0.2, tree_method='auto', validate_parameters=1,
#              verbosity=1)

# %%
y_test_preds = model.predict(X_test_fs)
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
sample_df = pd.read_csv(datapath/'sample_submission.csv')

# %%
sample_df.loc[:, 'loss'] = y_test_preds

# %%
sample_df.head()
# Out:
#        id      loss
# 0  250000  8.027956
# 1  250001  4.305676
# 2  250002  7.300106
# 3  250003  6.988875
# 4  250004  7.316631

# %%
sample_df.to_csv('202108241211_XGBoost_fullset.csv', index=False)
