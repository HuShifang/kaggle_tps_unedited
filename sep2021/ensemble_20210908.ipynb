# %% [markdown]
# # Baseline
# Setting up a more robust baseline notebook, suitable for use with all of the "Big Three" (XGBoost, CatBoost, LightGBM) libraries and on either Google Colab or the local machine.

# %% [markdown]
# # Setup

# %%
# two manual flags (ex-config)
colab = False
gpu_available = False
libraries = ['xgboost', 'lightgbm', 'catboost']

# %%
# basic imports
from pathlib import Path
import os
import math
from datetime import datetime

# %%
# %matplotlib inline
# %config Completer.use_jedi = False
os.environ['WANDB_NOTEBOOK_NAME'] = f"ensemble_{datetime.now().strftime('%Y%m%d')}.ipynb"

# %%
# handle Google Colab-specific library installation/updating
if colab:
    # much of the below inspired by or cribbed from the May 2021 Kaggle Tabular Playground winner, at 
    # https://colab.research.google.com/gist/academicsuspect/0aac7bd6e506f5f70295bfc9a3dc2250/tabular-may-baseline.ipynb?authuser=1#scrollTo=LJoVKJb5wN0L
    
    # Kaggle API for downloading the datasets
    # !pip install --upgrade -q kaggle

    # weights and biases
    # !pip install -qqqU wandb
    
    # Optuna for parameter search
    # !pip install -q optuna

    # upgrade sklearn
    # !pip install --upgrade scikit-learn

    # !pip install category_encoders
    
    if 'catboost' in libraries:
        # !pip install catboost
    
    if 'xgboost' in libraries:
        if gpu_available: 
            # this part is from https://github.com/rapidsai/gputreeshap/issues/24
            # !pip install cmake --upgrade
            # !pip install sklearn --upgrade
            # !git clone --recursive https://github.com/dmlc/xgboost
            # %cd /content/xgboost
            # !mkdir build
            # %cd build
            # !cmake .. -DUSE_CUDA=ON
            # !make -j4
            # %cd /content/xgboost/python-package
            # !python setup.py install --use-cuda --use-nccl
            # !/opt/bin/nvidia-smi
            # !pip install shap
        else:
            # !pip install --upgrade xgboost
    if 'lightgbm' in libraries:
        if gpu_available:
            # lighgbm gpu compatible
            # !git clone --recursive https://github.com/Microsoft/LightGBM
            ! cd LightGBM && rm -rf build && mkdir build && cd build && cmake -DUSE_GPU=1 ../../LightGBM && make -j4 && cd ../python-package && python3 setup.py install --precompile --gpu;
        else:
            # !pip install --upgrade lightgbm

# %% [markdown]
# Now, non-stdlib imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# general ML tooling
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import log_loss, roc_auc_score
import wandb
from wandb.xgboost import wandb_callback
from wandb.lightgbm import wandb_callback
from sklearn.impute import KNNImputer
# import timm

import seaborn as sns

from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
# from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MaxAbsScaler, StandardScaler, MinMaxScaler, RobustScaler, PolynomialFeatures
# from sklearn.feature_selection import SelectKBest, f_regression
from joblib import dump, load
# feature engineering tools
# from sklearn.feature_selection import mutual_info_regression
# import featuretools as ft
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# Now, datapath setup

# %%
# # This is the code for reading the train.csv and converting it to a .feather file
# df = pd.read_csv(datapath/'train.csv', index_col='id', low_memory=False)
# df.index.name = None
# df.to_feather(path='./dataset_df.feather')

# %%
if colab:
    # mount Google Drive
    from google.colab import drive
    drive.mount('/content/drive')
    
    # handling datapath
    datapath = Path('/content/drive/MyDrive/kaggle/tabular_playgrounds/sep2021/')
    
else:
    # if on local machine
    datapath = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/')

# %% [markdown]
# ## Ex-Model Config

# %%
# meta-config for preprocessing and cross-validation, but NOT for model parameters
exmodel_config = {
    # model config
#     "model": XGBClassifier,
#     "n_estimators": 100, 
#     "max_depth": 3,
#     "learning_rate": 0.1,
#     "test_size": 0.2,
#     "reg_lambda": None, 
    "scaler": MinMaxScaler, # TODO: experiment with others (but imputation may be slow)
    "scale_b4_impute": None,
    "imputer": None,
    "knn_imputer_n_neighbors": None, # None if a different imputer is used
#     "feature_selector": SelectKBest,
#     "k_best": 80,
#     "feature_selection_scoring": f_regression,
    'random_state': 42,
#     'subsample': 1,
    'cross_val_strategy': KFold, # None for holdout, or the relevant sklearn class
    'kfolds': 5, # if 1, that means just doing holdout
    'test_size': 0.2,
#     'features_created': False,
#     'feature_creator': None,
}

# %% [markdown]
# ## Data Setup

# %% [markdown]
# **TODO** Write some conditional logic here to automate it -- possibly as part of a sklearn.*pipeline

# %%
# if exmodel_config['scaler']:
#     scaler = exmodel_config['scaler']()
#     scaler.fit_transform()

# %%
# # here's how to load the original, unaltered dataset and separate features from targets
df = pd.read_feather(path=datapath/'dataset_df.feather') # this is the unaltered original dataset
features = [x for x in df.columns if x != 'claim']
X = df[features]
y = df.claim

exmodel_config['feature_count'] = len(features)
exmodel_config['feature_generator'] = None

# load the version of the dataset with imputations; X and y were stored separately, as feather and joblib respectively
# X = pd.read_feather(datapath/'X_StandardScaled_KNNImputed_5NN.feather') 
# y = load(datapath/'y.joblib')    
# X.index.name = 'id'
# y.index.name = 'id'

# %%
scaler = exmodel_config['scaler']()
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(X_scaled, columns=X.columns)

# %%
X.head()
# Out:
#          f1        f2        f3        f4        f5        f6        f7  \
# 0  0.457457  0.043413  0.191647  0.070959  0.527183  0.105864  0.063687
# 1  0.443849  0.592256  0.433849  0.255789  0.830794  0.498215  0.344463
# 2  0.580343  0.022422  0.210943  0.252679  0.830402  0.540336  0.446403
# 3  0.534915  0.048887  0.208346  0.076533  0.937195  0.845347  0.059686
# 4  0.470978  0.970095  0.190185  0.271060  0.626428  0.516054  0.489029
#
#          f8        f9       f10  ...      f109      f110      f111      f112  \
# 0  0.102258  0.134102  0.236467  ...  0.131467  0.871211  0.343019  0.120557
# 1  0.077000  0.434246  0.324546  ...  0.874035  0.456876  0.907318  0.114198
# 2  0.200918  0.100675  0.376975  ...  0.208734  0.931311  0.216179  0.113851
# 3  0.148869  0.106339  0.235366  ...  0.026189  0.660647  0.417911  0.116023
# 4  0.048970  0.264354  0.236982  ...  0.831717  0.858063  0.292096  0.117449
#
#        f113      f114      f115      f116      f117      f118
# 0  0.261928  0.142026  0.310088  0.029364  0.040935  0.403801
# 1  0.413351  0.136327  0.347585  0.049469  0.167787  0.150209
# 2  0.467008  0.209030  0.276260  0.027749  0.313531  0.192805
# 3  0.137909  0.142970  0.278298  0.026798  0.390996  0.230099
# 4  0.351838  0.141167  0.588661  0.026758       NaN  0.131866
#
# [5 rows x 118 columns]

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: claim, dtype: int64

# %% [markdown]
# ### Model Config

# %%
def model_configurator(library, gpu_available=True):#, config=universal_config):
    """
    Function that provide task-specific or general preference arguments for the various models. 
    
    At first, will rely largely on defaults for hyperparameters, but later this function 
    can be supplemented later with optimal values, as they're learned in sweeps.
    .
    
    Rationale: creating a helper function will allow more experimentation later, and also
    composite runs that cycle through a series of models.
    
    :param model: A model from [XGBClassifier, LGBMClassifier, CatBoostClassifier]
    :return config: A dict that supplements default hyperparameter values with 1) 
                    task-appropriate ones, and perhaps later 2) optimal hyperparameter values.
    """
    config = {}
    
    # library-specific config
    if library in ['xgboost', 'lightgbm']:
        config['n_jobs'] = -1
        
    # best params per sweep `icac24c5`, generated from notebook `sweep_20210905.ipynb`
    # runtime per fold should be around 12m 38s
    # should get auc of 0.7434 on the random_state=42 holdout
    # haven't yet tried dart
    if library == 'xgboost':
        config['tree_method'] = 'auto'
#         config['booster'] = 'gbtree' # or 'dart'
#         config['model'] = XGBClassifier
        config['verbosity'] = 1
        config['objective'] = 'binary:logistic'
#         config['eval_metric'] = ['auc', 'logloss', 'aucpr'],
        config['tree_method'] = 'gpu_hist' if (gpu_available and colab) else 'auto' 
        config['n_estimators'] = 902
        config['learning_rate'] = 0.0304
        config['max_depth'] = 3
        config['reg_alpha'] = 0.863
        config['reg_lambda'] = 2.442
        config['subsample'] = 0.8627

    # best params per sweep `sjghewf0`, generated from notebook `sweep_lightgbm_20210907`
    # run name `sweep_lightgbm_20210907_195641`
    # runtime per fold should be around 39s
    # should get an auc of 0.7435 on random_state=42 holdout
    if library == 'lightgbm':
#         config['model'] = LGBMClassifier
        config['objective'] = 'binary'
        config['eval_metric'] = ['auc', 'logloss']
        config['boosting_type'] = 'gbdt' # or 'dart'
        config['device_type'] = 'cuda' if (gpu_available and colab) else 'cpu' # 'gpu' also possible, 'cpu' is default
        config['n_estimators'] = 1286
        config['learning_rate'] = 0.03221
        config['max_depth'] = 2
        config['reg_alpha'] = 0.4687
        config['reg_lambda'] = 0.1763
        config['subsample'] = 0.6621
        

#     if config['model'] == CatBoostClassifier:
    if library == 'catboost':
#         config['model'] = CatBoostClassifier
        config['task_type'] = 'GPU' if gpu_available else 'CPU'
        config['custom_metrics'] = ['Logloss', 'AUC'] # objective (loss fn) must be singular, defaults to Logloss
        config['n_estimators'] = 2000 # logged as "iterations" otherwise

    return config

# %% [markdown]
# ## Weights and Biases Run Config

# %% [markdown]
# Below is the configuration for a Weights and Biases (`wandb`) run.

# %%
# wandb config:
config_run = {
    'name': f"{os.environ['WANDB_NOTEBOOK_NAME'][:-6]}_{datetime.now().strftime('%H%M%S')}", # just removes the .ipynb extension, leaving the notebook filename's stem
    'tags': ['baseline'],
    'notes': "Initial runs of each model-type, with sane defaults.",
}

# %% [markdown]
# # Preprocessing
# Scaling has already occurred -- used `StandardScaler` as a precursor to using `KNNImputer(n_neighbors=5)`, on the premise that imputation would proceed more quickly if things were already scaled. I may try different permutations of this later: using `IterativeImputer` instead, before or after scaling, potentially with different scalers.

# %% [markdown]
# # Feature Creation and Selection

# %%
# load all the polynomialfeatures generated with `PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)`
# X_np = np.load(datapath/'X_poly_unscaled.npy')
# X = pd.DataFrame(X_np)

# %%
# X.columns

# %%
# generation polynomial features
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_poly = poly.fit_transform(X)

# %%
# X_poly_names = poly.get_feature_names(X.columns)
# # X_poly_names[100:150]
# features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
# checks = [feature in X_poly_names for feature in features]
# checks

# %%
# X = pd.DataFrame(X_poly, columns=X_poly_names)

# %%
# X = X[features[1:]]

# %% [markdown]
# # Training

# %%
def train(X_train, X_valid, y_train, y_valid, model_config, 
                                              random_state=42,
                                              exmodel_config=exmodel_config, 
                                              config_run=config_run):#, scaler): # passed in via config dict for now
    """
    Basic training function. Note that some of the options passed via the argument are
    in fact hard-coded in, to avoid inconveniences.
    :param X_train: the training set features
    :param X_valid: the validation set features
    :param y_train: the training set targets
    :param y_valid: the validation set targets
    :param random_staKFold: for reproducibility
    :param exmodel_config: dict containing configuration details including the library 
                            (thus model) used, preprocessing, and cross-validation
    :param model_config: dict containing hyperparameter specifications for the model
    :param config_run: dict containing wandb run configuration (name, etc)
    """
    
    
    wandb.init(
        project="202109_Kaggle_tabular_playground",
        save_code=True,
        tags=config_run['tags'],
        name=config_run['name'],
        notes=config_run['notes'],
        config=exmodel_config)   
        
    if exmodel_config['library'] == 'xgboost':
        model = XGBClassifier(
#             tree_method=config['tree_method'],
#             booster=config['booster'],
            max_depth=model_config['max_depth'],
            learning_rate=model_config['learning_rate'], 
            subsample=model_config['subsample'],
            reg_alpha=model_config['reg_alpha'],
            reg_lambda=model_config['reg_lambda'],
            random_state=random_state,
            n_jobs=model_config['n_jobs'], 
            verbosity=model_config['verbosity'], 
            objective=model_config['objective'],
#             eval_metric=model_config['eval_metric'],
            tree_method=model_config['tree_method'],
            n_estimators=model_config['n_estimators'],
        )
        
        model.fit(X_train, y_train, callbacks=[wandb.xgboost.wandb_callback()],
#                                     eval_metric=model_config['eval_metric'],
                 )


    elif exmodel_config['library'] == 'lightgbm':
        model = LGBMClassifier(
#             boosting_type=model_config['boosting_type'],
#             max_depth=model_config['max_depth']
            # TODO
            random_state=random_state,
            n_jobs=model_config['n_jobs'],
            objective=model_config['objective'],
            eval_metric=model_config['eval_metric'],
            boosting_type=model_config['boosting_type'],
            device_type=model_config['device_type'],
            n_estimators=model_config['n_estimators'],
            learning_rate=model_config['learning_rate'],
            max_depth=model_config['max_depth'],
            reg_alpha=model_config['reg_alpha'],
            reg_lambda=model_config['reg_lambda'],
            subsample=model_config['subsample'],
        )
        
        model.fit(X_train, y_train, callbacks=[wandb.lightgbm.wandb_callback()],
#                                     eval_metric=model_config['eval_metric'],
                 )
        
    elif exmodel_config['library'] == 'catboost':
        print("CatBoost, therefore no WandB callback.")
        model = CatBoostClassifier(
#             n_estimators=config['n_estimators'],
#             learning_rate=config['learning_rate'],
#             max_depth=config['max_depth'],
            task_type=model_config['task_type'],
    #         n_jobs=config['n_jobs'],
    #         verbosity=config['verbosity'],
    #         subsample=config['subsample'],
            n_estimators=model_config['n_estimators'],
            random_state=random_state,
            # objective='Logloss', # default, accepts only one
#             custom_metrics=model_config['custom_metrics'],
    #         bootstrap_type=config['bootstrap_type'],
    #         device:config['device']
        ) 
        model.fit(X_train, y_train)
    y_train_pred = model.predict(X_train)
    train_loss = log_loss(y_train, y_train_pred)
    train_auc = roc_auc_score(y_train, y_train_pred)
    wandb.log({'train_loss': train_loss, 'train_auc': train_auc})

    if exmodel_config['library'] == 'catboost':
        print(model.get_all_params())
        wandb.log(model.get_all_params())
    else:
        wandb.log(model.get_params()) # logging model parameters, trying bare-invocation rather than params: model.get_params()
    
    y_pred = model.predict(X_valid)
#     mse = mean_squared_error(y_valid, y_pred)
#     rmse = math.sqrt(abs(mse))
    valid_loss = log_loss(y_valid, y_pred)
    valid_auc = roc_auc_score(y_valid, y_pred)
    wandb.log({'valid_loss':valid_loss, 'valid_auc':valid_auc})
    print(f"Valid log-loss is {valid_loss}\nValid AUC is {valid_auc}")   
#     wandb.finish()   
    return model

# %%
def cross_validation(model_config, X=X, y=y, start_fold=0, exmodel_config=exmodel_config, random_state=42):
    """
    Function to handle model training process in the context of cross-validation -- via hold-out or via k-fold.
    If exmodel_config['cross_val_strategy'] == None, then any kfolds= input is ignored; otherwise, the number specified is used.
    
    :param kfolds: int specifying number of k-folds to use in cross-validation
    :param exmodel_config: dict containing general config including for cross-validation -- `kfold=1` implies hold-out
    """
    if exmodel_config['kfolds'] == 1:
        print("Proceeding with holdout")
        X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
                                                      test_size=exmodel_config['test_size'], 
                                                      random_state=random_state,
                                                     )
        model = train(X_train, X_valid, y_train, y_valid, exmodel_config=exmodel_config, 
                                                    model_config=model_config,
                                                    config_run=config_run)
        wandb.finish()
        
    else:
        X, y = X.to_numpy(), y.to_numpy()
        kfold = exmodel_config['cross_val_strategy'](n_splits=exmodel_config['kfolds'], shuffle=True, random_state=random_state)
        models = {}
        model_path = Path(datapath/f"models/{config_run['name']}_{exmodel_config['kfolds']}folds/")
        (model_path).mkdir(exist_ok=True)
        for fold, (train_ids, valid_ids) in enumerate(kfold.split(X,y)):
            if fold < start_fold:
                continue
            else:
                print(f"FOLD {fold}")
                print("---------------------------------------------------")
                X_train, X_valid = X[train_ids], X[valid_ids]
                y_train, y_valid = y[train_ids], y[valid_ids]
                model = train(X_train, X_valid, y_train, y_valid, exmodel_config=exmodel_config, 
                                                    model_config=model_config,
                                                    config_run=config_run)
                wandb.log({'fold': fold})
                models[fold] = model
                dump(model, Path(model_path/f"{exmodel_config['library']}_fold{fold}_model.joblib"))
                wandb.finish()
        return models

# %% [markdown]
# # Interface

# %% [markdown]
# ## Runs

# %%
library = 'xgboost'
exmodel_config['library'] = library
model_config = model_configurator(library)
xgboost_models = cross_validation(model_config)
# Out:
# FOLD 0
# ---------------------------------------------------
# Finishing last run (ID:hx8lwq7p) before initializing another...
# <br/>Waiting for W&B process to finish, PID 1210295<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.16MB of 0.16MB uploaded (0.06MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_213319-hx8lwq7p/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_213319-hx8lwq7p/logs/debug-internal.log</code>
# Synced 6 W&B file(s), 0 media file(s), 3 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ensemble_20210908_213242</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/hx8lwq7p" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/hx8lwq7p</a><br/>
# ...Successfully finished last run (ID:hx8lwq7p). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">ensemble_20210908_213242</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/fgnodi8b" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/fgnodi8b</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_213546-fgnodi8b</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# Valid log-loss is 8.859236129418058
# Valid AUC is 0.7434111729872946
# <br/>Waiting for W&B process to finish, PID 1210606<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_213546-fgnodi8b/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_213546-fgnodi8b/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>8.74211</td></tr><tr><td>train_auc</td><td>0.74682</td></tr><tr><td>_runtime</td><td>606</td></tr><tr><td>_timestamp</td><td>1631162757</td></tr><tr><td>_step</td><td>905</td></tr><tr><td>objective</td><td>binary:logistic</td></tr><tr><td>use_label_encoder</td><td>True</td></tr><tr><td>base_score</td><td>0.5</td></tr><tr><td>booster</td><td>gbtree</td></tr><tr><td>colsample_bylevel</td><td>1</td></tr><tr><td>colsample_bynode</td><td>1</td></tr><tr><td>colsample_bytree</td><td>1</td></tr><tr><td>gamma</td><td>0</td></tr><tr><td>gpu_id</td><td>-1</td></tr><tr><td>importance_type</td><td>gain</td></tr><tr><td>learning_rate</td><td>0.0304</td></tr><tr><td>max_delta_step</td><td>0</td></tr><tr><td>max_depth</td><td>3</td></tr><tr><td>min_child_weight</td><td>1</td></tr><tr><td>missing</td><td>nan</td></tr><tr><td>monotone_constraints</td><td>()</td></tr><tr><td>n_estimators</td><td>902</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_parallel_tree</td><td>1</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.863</td></tr><tr><td>reg_lambda</td><td>2.442</td></tr><tr><td>scale_pos_weight</td><td>1</td></tr><tr><td>subsample</td><td>0.8627</td></tr><tr><td>tree_method</td><td>auto</td></tr><tr><td>validate_parameters</td><td>1</td></tr><tr><td>verbosity</td><td>1</td></tr><tr><td>valid_loss</td><td>8.85924</td></tr><tr><td>valid_auc</td><td>0.74341</td></tr><tr><td>fold</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁</td></tr><tr><td>_timestamp</td><td>▁▁▁▁</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>use_label_encoder</td><td>▁</td></tr><tr><td>base_score</td><td>▁</td></tr><tr><td>colsample_bylevel</td><td>▁</td></tr><tr><td>colsample_bynode</td><td>▁</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>gamma</td><td>▁</td></tr><tr><td>gpu_id</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_delta_step</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>missing</td><td></td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_parallel_tree</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>scale_pos_weight</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>validate_parameters</td><td>▁</td></tr><tr><td>verbosity</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ensemble_20210908_213242</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/fgnodi8b" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/fgnodi8b</a><br/>
# FOLD 1
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">ensemble_20210908_213242</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/389gyu8y" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/389gyu8y</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_214602-389gyu8y</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# Valid log-loss is 8.784419229577395
# Valid AUC is 0.745533410290788
# <br/>Waiting for W&B process to finish, PID 1211720<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.11MB of 0.11MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_214602-389gyu8y/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_214602-389gyu8y/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>8.75721</td></tr><tr><td>train_auc</td><td>0.7464</td></tr><tr><td>_runtime</td><td>613</td></tr><tr><td>_timestamp</td><td>1631163375</td></tr><tr><td>_step</td><td>905</td></tr><tr><td>objective</td><td>binary:logistic</td></tr><tr><td>use_label_encoder</td><td>True</td></tr><tr><td>base_score</td><td>0.5</td></tr><tr><td>booster</td><td>gbtree</td></tr><tr><td>colsample_bylevel</td><td>1</td></tr><tr><td>colsample_bynode</td><td>1</td></tr><tr><td>colsample_bytree</td><td>1</td></tr><tr><td>gamma</td><td>0</td></tr><tr><td>gpu_id</td><td>-1</td></tr><tr><td>importance_type</td><td>gain</td></tr><tr><td>learning_rate</td><td>0.0304</td></tr><tr><td>max_delta_step</td><td>0</td></tr><tr><td>max_depth</td><td>3</td></tr><tr><td>min_child_weight</td><td>1</td></tr><tr><td>missing</td><td>nan</td></tr><tr><td>monotone_constraints</td><td>()</td></tr><tr><td>n_estimators</td><td>902</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_parallel_tree</td><td>1</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.863</td></tr><tr><td>reg_lambda</td><td>2.442</td></tr><tr><td>scale_pos_weight</td><td>1</td></tr><tr><td>subsample</td><td>0.8627</td></tr><tr><td>tree_method</td><td>auto</td></tr><tr><td>validate_parameters</td><td>1</td></tr><tr><td>verbosity</td><td>1</td></tr><tr><td>valid_loss</td><td>8.78442</td></tr><tr><td>valid_auc</td><td>0.74553</td></tr><tr><td>fold</td><td>1</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁</td></tr><tr><td>_timestamp</td><td>▁▁▁▁</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>use_label_encoder</td><td>▁</td></tr><tr><td>base_score</td><td>▁</td></tr><tr><td>colsample_bylevel</td><td>▁</td></tr><tr><td>colsample_bynode</td><td>▁</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>gamma</td><td>▁</td></tr><tr><td>gpu_id</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_delta_step</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>missing</td><td></td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_parallel_tree</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>scale_pos_weight</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>validate_parameters</td><td>▁</td></tr><tr><td>verbosity</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ensemble_20210908_213242</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/389gyu8y" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/389gyu8y</a><br/>
# FOLD 2
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">ensemble_20210908_213242</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/11ocp4lq" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/11ocp4lq</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_215622-11ocp4lq</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# Valid log-loss is 8.856892242301274
# Valid AUC is 0.7435404923663352
# <br/>Waiting for W&B process to finish, PID 1212867<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.12MB of 0.12MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_215622-11ocp4lq/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_215622-11ocp4lq/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>8.74333</td></tr><tr><td>train_auc</td><td>0.74677</td></tr><tr><td>_runtime</td><td>593</td></tr><tr><td>_timestamp</td><td>1631163976</td></tr><tr><td>_step</td><td>905</td></tr><tr><td>objective</td><td>binary:logistic</td></tr><tr><td>use_label_encoder</td><td>True</td></tr><tr><td>base_score</td><td>0.5</td></tr><tr><td>booster</td><td>gbtree</td></tr><tr><td>colsample_bylevel</td><td>1</td></tr><tr><td>colsample_bynode</td><td>1</td></tr><tr><td>colsample_bytree</td><td>1</td></tr><tr><td>gamma</td><td>0</td></tr><tr><td>gpu_id</td><td>-1</td></tr><tr><td>importance_type</td><td>gain</td></tr><tr><td>learning_rate</td><td>0.0304</td></tr><tr><td>max_delta_step</td><td>0</td></tr><tr><td>max_depth</td><td>3</td></tr><tr><td>min_child_weight</td><td>1</td></tr><tr><td>missing</td><td>nan</td></tr><tr><td>monotone_constraints</td><td>()</td></tr><tr><td>n_estimators</td><td>902</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_parallel_tree</td><td>1</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.863</td></tr><tr><td>reg_lambda</td><td>2.442</td></tr><tr><td>scale_pos_weight</td><td>1</td></tr><tr><td>subsample</td><td>0.8627</td></tr><tr><td>tree_method</td><td>auto</td></tr><tr><td>validate_parameters</td><td>1</td></tr><tr><td>verbosity</td><td>1</td></tr><tr><td>valid_loss</td><td>8.85689</td></tr><tr><td>valid_auc</td><td>0.74354</td></tr><tr><td>fold</td><td>2</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁██</td></tr><tr><td>_timestamp</td><td>▁▁██</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>use_label_encoder</td><td>▁</td></tr><tr><td>base_score</td><td>▁</td></tr><tr><td>colsample_bylevel</td><td>▁</td></tr><tr><td>colsample_bynode</td><td>▁</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>gamma</td><td>▁</td></tr><tr><td>gpu_id</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_delta_step</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>missing</td><td></td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_parallel_tree</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>scale_pos_weight</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>validate_parameters</td><td>▁</td></tr><tr><td>verbosity</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ensemble_20210908_213242</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/11ocp4lq" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/11ocp4lq</a><br/>
# FOLD 3
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">ensemble_20210908_213242</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3bhwnbxb" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3bhwnbxb</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_220621-3bhwnbxb</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# Valid log-loss is 8.822457793708285
# Valid AUC is 0.7445301392006682
# <br/>Waiting for W&B process to finish, PID 1214009<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.13MB of 0.13MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_220621-3bhwnbxb/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_220621-3bhwnbxb/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>8.7427</td></tr><tr><td>train_auc</td><td>0.7468</td></tr><tr><td>_runtime</td><td>693</td></tr><tr><td>_timestamp</td><td>1631164674</td></tr><tr><td>_step</td><td>905</td></tr><tr><td>objective</td><td>binary:logistic</td></tr><tr><td>use_label_encoder</td><td>True</td></tr><tr><td>base_score</td><td>0.5</td></tr><tr><td>booster</td><td>gbtree</td></tr><tr><td>colsample_bylevel</td><td>1</td></tr><tr><td>colsample_bynode</td><td>1</td></tr><tr><td>colsample_bytree</td><td>1</td></tr><tr><td>gamma</td><td>0</td></tr><tr><td>gpu_id</td><td>-1</td></tr><tr><td>importance_type</td><td>gain</td></tr><tr><td>learning_rate</td><td>0.0304</td></tr><tr><td>max_delta_step</td><td>0</td></tr><tr><td>max_depth</td><td>3</td></tr><tr><td>min_child_weight</td><td>1</td></tr><tr><td>missing</td><td>nan</td></tr><tr><td>monotone_constraints</td><td>()</td></tr><tr><td>n_estimators</td><td>902</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_parallel_tree</td><td>1</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.863</td></tr><tr><td>reg_lambda</td><td>2.442</td></tr><tr><td>scale_pos_weight</td><td>1</td></tr><tr><td>subsample</td><td>0.8627</td></tr><tr><td>tree_method</td><td>auto</td></tr><tr><td>validate_parameters</td><td>1</td></tr><tr><td>verbosity</td><td>1</td></tr><tr><td>valid_loss</td><td>8.82246</td></tr><tr><td>valid_auc</td><td>0.74453</td></tr><tr><td>fold</td><td>3</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁</td></tr><tr><td>_timestamp</td><td>▁▁▁▁</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>use_label_encoder</td><td>▁</td></tr><tr><td>base_score</td><td>▁</td></tr><tr><td>colsample_bylevel</td><td>▁</td></tr><tr><td>colsample_bynode</td><td>▁</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>gamma</td><td>▁</td></tr><tr><td>gpu_id</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_delta_step</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>missing</td><td></td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_parallel_tree</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>scale_pos_weight</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>validate_parameters</td><td>▁</td></tr><tr><td>verbosity</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ensemble_20210908_213242</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3bhwnbxb" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3bhwnbxb</a><br/>
# FOLD 4
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">ensemble_20210908_213242</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/2t7h3bpi" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/2t7h3bpi</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_221800-2t7h3bpi</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# Valid log-loss is 8.772566171697461
# Valid AUC is 0.7459377301842103
# <br/>Waiting for W&B process to finish, PID 1215407<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.14MB of 0.14MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_221800-2t7h3bpi/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_221800-2t7h3bpi/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>8.75138</td></tr><tr><td>train_auc</td><td>0.74655</td></tr><tr><td>_runtime</td><td>653</td></tr><tr><td>_timestamp</td><td>1631165333</td></tr><tr><td>_step</td><td>905</td></tr><tr><td>objective</td><td>binary:logistic</td></tr><tr><td>use_label_encoder</td><td>True</td></tr><tr><td>base_score</td><td>0.5</td></tr><tr><td>booster</td><td>gbtree</td></tr><tr><td>colsample_bylevel</td><td>1</td></tr><tr><td>colsample_bynode</td><td>1</td></tr><tr><td>colsample_bytree</td><td>1</td></tr><tr><td>gamma</td><td>0</td></tr><tr><td>gpu_id</td><td>-1</td></tr><tr><td>importance_type</td><td>gain</td></tr><tr><td>learning_rate</td><td>0.0304</td></tr><tr><td>max_delta_step</td><td>0</td></tr><tr><td>max_depth</td><td>3</td></tr><tr><td>min_child_weight</td><td>1</td></tr><tr><td>missing</td><td>nan</td></tr><tr><td>monotone_constraints</td><td>()</td></tr><tr><td>n_estimators</td><td>902</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_parallel_tree</td><td>1</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.863</td></tr><tr><td>reg_lambda</td><td>2.442</td></tr><tr><td>scale_pos_weight</td><td>1</td></tr><tr><td>subsample</td><td>0.8627</td></tr><tr><td>tree_method</td><td>auto</td></tr><tr><td>validate_parameters</td><td>1</td></tr><tr><td>verbosity</td><td>1</td></tr><tr><td>valid_loss</td><td>8.77257</td></tr><tr><td>valid_auc</td><td>0.74594</td></tr><tr><td>fold</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁</td></tr><tr><td>_timestamp</td><td>▁▁▁▁</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>use_label_encoder</td><td>▁</td></tr><tr><td>base_score</td><td>▁</td></tr><tr><td>colsample_bylevel</td><td>▁</td></tr><tr><td>colsample_bynode</td><td>▁</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>gamma</td><td>▁</td></tr><tr><td>gpu_id</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_delta_step</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>missing</td><td></td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_parallel_tree</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>scale_pos_weight</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>validate_parameters</td><td>▁</td></tr><tr><td>verbosity</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ensemble_20210908_213242</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/2t7h3bpi" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/2t7h3bpi</a><br/>

# %%
# for scaler in [StandardScaler, MaxAbsScaler, MinMaxScaler, RobustScaler]:
#     exmodel_config['scaler'] = scaler
#     scaler = scaler()
#     X_scaled = scaler.fit_transform(X)
#     X = pd.DataFrame(X_scaled, columns=X.columns)
#     exmodel_config['library'] = 'lightgbm'
#     model_config = model_configurator('lightgbm')
#     cross_validation(model_config)

# %%
# library = 'xgboost'
# exmodel_config['library'] = library
# model_config = model_configurator(library)
# xgboost_models = cross_validation(model_config)

library = 'lightgbm'
exmodel_config['library'] = library
model_config = model_configurator(library)
lightgbm_models = cross_validation(model_config)

library = 'catboost'
gpu_available = True
exmodel_config['library'] = library
model_config = model_configurator(library)
catboost_models = cross_validation(model_config)
# Out:
# FOLD 0
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">ensemble_20210908_213242</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/19ppdg0h" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/19ppdg0h</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_222858-19ppdg0h</code><br/><br/>
# [LightGBM] [Warning] Unknown parameter: eval_metric
# Valid log-loss is 8.857793630116449
# Valid AUC is 0.7434506488929393
# <br/>Waiting for W&B process to finish, PID 1216780<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.14MB of 0.14MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_222858-19ppdg0h/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_222858-19ppdg0h/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>8.78105</td></tr><tr><td>train_auc</td><td>0.7457</td></tr><tr><td>_runtime</td><td>39</td></tr><tr><td>_timestamp</td><td>1631165377</td></tr><tr><td>_step</td><td>1289</td></tr><tr><td>boosting_type</td><td>gbdt</td></tr><tr><td>colsample_bytree</td><td>1.0</td></tr><tr><td>importance_type</td><td>split</td></tr><tr><td>learning_rate</td><td>0.03221</td></tr><tr><td>max_depth</td><td>2</td></tr><tr><td>min_child_samples</td><td>20</td></tr><tr><td>min_child_weight</td><td>0.001</td></tr><tr><td>min_split_gain</td><td>0.0</td></tr><tr><td>n_estimators</td><td>1286</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_leaves</td><td>31</td></tr><tr><td>objective</td><td>binary</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.4687</td></tr><tr><td>reg_lambda</td><td>0.1763</td></tr><tr><td>silent</td><td>True</td></tr><tr><td>subsample</td><td>0.6621</td></tr><tr><td>subsample_for_bin</td><td>200000</td></tr><tr><td>subsample_freq</td><td>0</td></tr><tr><td>device_type</td><td>cpu</td></tr><tr><td>valid_loss</td><td>8.85779</td></tr><tr><td>valid_auc</td><td>0.74345</td></tr><tr><td>fold</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁██</td></tr><tr><td>_timestamp</td><td>▁▁██</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_samples</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>min_split_gain</td><td>▁</td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_leaves</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>silent</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>subsample_for_bin</td><td>▁</td></tr><tr><td>subsample_freq</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ensemble_20210908_213242</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/19ppdg0h" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/19ppdg0h</a><br/>
# FOLD 1
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">ensemble_20210908_213242</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/2334lqti" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/2334lqti</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_222942-2334lqti</code><br/><br/>
# [LightGBM] [Warning] Unknown parameter: eval_metric
# Valid log-loss is 8.794695072373163
# Valid AUC is 0.7452325162200142
# <br/>Waiting for W&B process to finish, PID 1216901<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.15MB of 0.15MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_222942-2334lqti/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_222942-2334lqti/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>8.79921</td></tr><tr><td>train_auc</td><td>0.74518</td></tr><tr><td>_runtime</td><td>46</td></tr><tr><td>_timestamp</td><td>1631165428</td></tr><tr><td>_step</td><td>1289</td></tr><tr><td>boosting_type</td><td>gbdt</td></tr><tr><td>colsample_bytree</td><td>1.0</td></tr><tr><td>importance_type</td><td>split</td></tr><tr><td>learning_rate</td><td>0.03221</td></tr><tr><td>max_depth</td><td>2</td></tr><tr><td>min_child_samples</td><td>20</td></tr><tr><td>min_child_weight</td><td>0.001</td></tr><tr><td>min_split_gain</td><td>0.0</td></tr><tr><td>n_estimators</td><td>1286</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_leaves</td><td>31</td></tr><tr><td>objective</td><td>binary</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.4687</td></tr><tr><td>reg_lambda</td><td>0.1763</td></tr><tr><td>silent</td><td>True</td></tr><tr><td>subsample</td><td>0.6621</td></tr><tr><td>subsample_for_bin</td><td>200000</td></tr><tr><td>subsample_freq</td><td>0</td></tr><tr><td>device_type</td><td>cpu</td></tr><tr><td>valid_loss</td><td>8.7947</td></tr><tr><td>valid_auc</td><td>0.74523</td></tr><tr><td>fold</td><td>1</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁██</td></tr><tr><td>_timestamp</td><td>▁▁██</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_samples</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>min_split_gain</td><td>▁</td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_leaves</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>silent</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>subsample_for_bin</td><td>▁</td></tr><tr><td>subsample_freq</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ensemble_20210908_213242</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/2334lqti" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/2334lqti</a><br/>
# FOLD 2
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">ensemble_20210908_213242</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1nt76wu2" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1nt76wu2</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_223040-1nt76wu2</code><br/><br/>
# [LightGBM] [Warning] Unknown parameter: eval_metric
# Valid log-loss is 8.870052432616673
# Valid AUC is 0.743158225350174
# <br/>Waiting for W&B process to finish, PID 1217104<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.15MB of 0.15MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_223040-1nt76wu2/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_223040-1nt76wu2/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>8.79331</td></tr><tr><td>train_auc</td><td>0.74532</td></tr><tr><td>_runtime</td><td>39</td></tr><tr><td>_timestamp</td><td>1631165479</td></tr><tr><td>_step</td><td>1289</td></tr><tr><td>boosting_type</td><td>gbdt</td></tr><tr><td>colsample_bytree</td><td>1.0</td></tr><tr><td>importance_type</td><td>split</td></tr><tr><td>learning_rate</td><td>0.03221</td></tr><tr><td>max_depth</td><td>2</td></tr><tr><td>min_child_samples</td><td>20</td></tr><tr><td>min_child_weight</td><td>0.001</td></tr><tr><td>min_split_gain</td><td>0.0</td></tr><tr><td>n_estimators</td><td>1286</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_leaves</td><td>31</td></tr><tr><td>objective</td><td>binary</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.4687</td></tr><tr><td>reg_lambda</td><td>0.1763</td></tr><tr><td>silent</td><td>True</td></tr><tr><td>subsample</td><td>0.6621</td></tr><tr><td>subsample_for_bin</td><td>200000</td></tr><tr><td>subsample_freq</td><td>0</td></tr><tr><td>device_type</td><td>cpu</td></tr><tr><td>valid_loss</td><td>8.87005</td></tr><tr><td>valid_auc</td><td>0.74316</td></tr><tr><td>fold</td><td>2</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁██</td></tr><tr><td>_timestamp</td><td>▁▁██</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_samples</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>min_split_gain</td><td>▁</td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_leaves</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>silent</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>subsample_for_bin</td><td>▁</td></tr><tr><td>subsample_freq</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ensemble_20210908_213242</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1nt76wu2" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1nt76wu2</a><br/>
# FOLD 3
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">ensemble_20210908_213242</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3acdyetq" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3acdyetq</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_223124-3acdyetq</code><br/><br/>
# [LightGBM] [Warning] Unknown parameter: eval_metric
# Valid log-loss is 8.82444078680164
# Valid AUC is 0.7444723273671959
# <br/>Waiting for W&B process to finish, PID 1217225<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.15MB of 0.15MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_223124-3acdyetq/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_223124-3acdyetq/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>8.78281</td></tr><tr><td>train_auc</td><td>0.74563</td></tr><tr><td>_runtime</td><td>39</td></tr><tr><td>_timestamp</td><td>1631165523</td></tr><tr><td>_step</td><td>1289</td></tr><tr><td>boosting_type</td><td>gbdt</td></tr><tr><td>colsample_bytree</td><td>1.0</td></tr><tr><td>importance_type</td><td>split</td></tr><tr><td>learning_rate</td><td>0.03221</td></tr><tr><td>max_depth</td><td>2</td></tr><tr><td>min_child_samples</td><td>20</td></tr><tr><td>min_child_weight</td><td>0.001</td></tr><tr><td>min_split_gain</td><td>0.0</td></tr><tr><td>n_estimators</td><td>1286</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_leaves</td><td>31</td></tr><tr><td>objective</td><td>binary</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.4687</td></tr><tr><td>reg_lambda</td><td>0.1763</td></tr><tr><td>silent</td><td>True</td></tr><tr><td>subsample</td><td>0.6621</td></tr><tr><td>subsample_for_bin</td><td>200000</td></tr><tr><td>subsample_freq</td><td>0</td></tr><tr><td>device_type</td><td>cpu</td></tr><tr><td>valid_loss</td><td>8.82444</td></tr><tr><td>valid_auc</td><td>0.74447</td></tr><tr><td>fold</td><td>3</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁██</td></tr><tr><td>_timestamp</td><td>▁▁██</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_samples</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>min_split_gain</td><td>▁</td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_leaves</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>silent</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>subsample_for_bin</td><td>▁</td></tr><tr><td>subsample_freq</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ensemble_20210908_213242</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3acdyetq" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3acdyetq</a><br/>
# FOLD 4
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">ensemble_20210908_213242</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/2v0kbz61" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/2v0kbz61</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_223210-2v0kbz61</code><br/><br/>
# [LightGBM] [Warning] Unknown parameter: eval_metric
# Valid log-loss is 8.767698580302296
# Valid AUC is 0.7460790624153869
# <br/>Waiting for W&B process to finish, PID 1217348<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.17MB of 0.17MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_223210-2v0kbz61/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_223210-2v0kbz61/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>8.7809</td></tr><tr><td>train_auc</td><td>0.7457</td></tr><tr><td>_runtime</td><td>39</td></tr><tr><td>_timestamp</td><td>1631165569</td></tr><tr><td>_step</td><td>1289</td></tr><tr><td>boosting_type</td><td>gbdt</td></tr><tr><td>colsample_bytree</td><td>1.0</td></tr><tr><td>importance_type</td><td>split</td></tr><tr><td>learning_rate</td><td>0.03221</td></tr><tr><td>max_depth</td><td>2</td></tr><tr><td>min_child_samples</td><td>20</td></tr><tr><td>min_child_weight</td><td>0.001</td></tr><tr><td>min_split_gain</td><td>0.0</td></tr><tr><td>n_estimators</td><td>1286</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_leaves</td><td>31</td></tr><tr><td>objective</td><td>binary</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.4687</td></tr><tr><td>reg_lambda</td><td>0.1763</td></tr><tr><td>silent</td><td>True</td></tr><tr><td>subsample</td><td>0.6621</td></tr><tr><td>subsample_for_bin</td><td>200000</td></tr><tr><td>subsample_freq</td><td>0</td></tr><tr><td>device_type</td><td>cpu</td></tr><tr><td>valid_loss</td><td>8.7677</td></tr><tr><td>valid_auc</td><td>0.74608</td></tr><tr><td>fold</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁</td></tr><tr><td>_timestamp</td><td>▁▁▁▁</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_samples</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>min_split_gain</td><td>▁</td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_leaves</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>silent</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>subsample_for_bin</td><td>▁</td></tr><tr><td>subsample_freq</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ensemble_20210908_213242</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/2v0kbz61" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/2v0kbz61</a><br/>
# FOLD 0
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">ensemble_20210908_213242</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1y862yno" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1y862yno</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_223255-1y862yno</code><br/><br/>
# CatBoost, therefore no WandB callback.
# Learning rate set to 0.012572
# 0:	learn: 0.6928148	total: 11.1ms	remaining: 22.2s
# 1:	learn: 0.6924862	total: 20.7ms	remaining: 20.7s
# 2:	learn: 0.6921546	total: 30.3ms	remaining: 20.2s
# 3:	learn: 0.6918300	total: 39.9ms	remaining: 19.9s
# 4:	learn: 0.6915176	total: 49.6ms	remaining: 19.8s
# 5:	learn: 0.6912018	total: 59.3ms	remaining: 19.7s
# 6:	learn: 0.6908800	total: 69.1ms	remaining: 19.7s
# 7:	learn: 0.6905571	total: 78.8ms	remaining: 19.6s
# 8:	learn: 0.6902453	total: 88.3ms	remaining: 19.5s
# 9:	learn: 0.6899317	total: 98ms	remaining: 19.5s
# 10:	learn: 0.6896186	total: 108ms	remaining: 19.5s
# 11:	learn: 0.6893082	total: 117ms	remaining: 19.4s
# 12:	learn: 0.6889978	total: 127ms	remaining: 19.4s
# 13:	learn: 0.6886846	total: 137ms	remaining: 19.4s
# 14:	learn: 0.6883737	total: 146ms	remaining: 19.3s
# 15:	learn: 0.6880665	total: 156ms	remaining: 19.3s
# 16:	learn: 0.6877605	total: 165ms	remaining: 19.2s
# 17:	learn: 0.6874562	total: 173ms	remaining: 19.1s
# 18:	learn: 0.6871491	total: 182ms	remaining: 19s
# 19:	learn: 0.6868453	total: 191ms	remaining: 18.9s
# 20:	learn: 0.6865437	total: 199ms	remaining: 18.8s
# 21:	learn: 0.6862402	total: 208ms	remaining: 18.7s
# 22:	learn: 0.6859361	total: 216ms	remaining: 18.6s
# 23:	learn: 0.6856351	total: 225ms	remaining: 18.5s
# 24:	learn: 0.6853342	total: 233ms	remaining: 18.4s
# 25:	learn: 0.6850353	total: 249ms	remaining: 18.9s
# 26:	learn: 0.6847384	total: 260ms	remaining: 19s
# 27:	learn: 0.6844410	total: 269ms	remaining: 18.9s
# 28:	learn: 0.6841435	total: 277ms	remaining: 18.8s
# 29:	learn: 0.6838497	total: 286ms	remaining: 18.8s
# 30:	learn: 0.6835571	total: 294ms	remaining: 18.7s
# 31:	learn: 0.6832672	total: 303ms	remaining: 18.6s
# 32:	learn: 0.6829761	total: 312ms	remaining: 18.6s
# 33:	learn: 0.6826843	total: 320ms	remaining: 18.5s
# 34:	learn: 0.6823971	total: 329ms	remaining: 18.5s
# 35:	learn: 0.6821070	total: 337ms	remaining: 18.4s
# 36:	learn: 0.6818201	total: 346ms	remaining: 18.4s
# 37:	learn: 0.6815332	total: 354ms	remaining: 18.3s
# 38:	learn: 0.6812464	total: 363ms	remaining: 18.3s
# 39:	learn: 0.6809617	total: 372ms	remaining: 18.2s
# 40:	learn: 0.6806800	total: 380ms	remaining: 18.2s
# 41:	learn: 0.6803926	total: 389ms	remaining: 18.1s
# 42:	learn: 0.6801109	total: 398ms	remaining: 18.1s
# 43:	learn: 0.6798283	total: 406ms	remaining: 18.1s
# 44:	learn: 0.6795470	total: 415ms	remaining: 18s
# 45:	learn: 0.6792697	total: 423ms	remaining: 18s
# 46:	learn: 0.6789918	total: 432ms	remaining: 17.9s
# 47:	learn: 0.6787098	total: 442ms	remaining: 18s
# 48:	learn: 0.6784309	total: 459ms	remaining: 18.3s
# 49:	learn: 0.6781545	total: 468ms	remaining: 18.2s
# 50:	learn: 0.6778776	total: 476ms	remaining: 18.2s
# 51:	learn: 0.6776006	total: 485ms	remaining: 18.2s
# 52:	learn: 0.6773247	total: 493ms	remaining: 18.1s
# 53:	learn: 0.6770497	total: 502ms	remaining: 18.1s
# 54:	learn: 0.6767754	total: 510ms	remaining: 18s
# 55:	learn: 0.6765022	total: 519ms	remaining: 18s
# 56:	learn: 0.6762304	total: 527ms	remaining: 18s
# 57:	learn: 0.6759556	total: 536ms	remaining: 17.9s
# 58:	learn: 0.6756827	total: 544ms	remaining: 17.9s
# 59:	learn: 0.6754150	total: 553ms	remaining: 17.9s
# 60:	learn: 0.6751454	total: 562ms	remaining: 17.9s
# 61:	learn: 0.6748810	total: 570ms	remaining: 17.8s
# 62:	learn: 0.6746120	total: 579ms	remaining: 17.8s
# 63:	learn: 0.6743468	total: 588ms	remaining: 17.8s
# 64:	learn: 0.6740809	total: 596ms	remaining: 17.8s
# 65:	learn: 0.6738125	total: 605ms	remaining: 17.7s
# 66:	learn: 0.6735474	total: 614ms	remaining: 17.7s
# 67:	learn: 0.6732861	total: 622ms	remaining: 17.7s
# 68:	learn: 0.6730259	total: 632ms	remaining: 17.7s
# 69:	learn: 0.6727634	total: 640ms	remaining: 17.7s
# 70:	learn: 0.6725029	total: 649ms	remaining: 17.6s
# 71:	learn: 0.6722422	total: 665ms	remaining: 17.8s
# 72:	learn: 0.6719766	total: 677ms	remaining: 17.9s
# 73:	learn: 0.6717150	total: 685ms	remaining: 17.8s
# 74:	learn: 0.6714564	total: 694ms	remaining: 17.8s
# 75:	learn: 0.6711991	total: 702ms	remaining: 17.8s
# 76:	learn: 0.6709371	total: 711ms	remaining: 17.8s
# 77:	learn: 0.6706823	total: 719ms	remaining: 17.7s
# 78:	learn: 0.6704240	total: 728ms	remaining: 17.7s
# 79:	learn: 0.6701716	total: 737ms	remaining: 17.7s
# 80:	learn: 0.6699177	total: 745ms	remaining: 17.7s
# 81:	learn: 0.6696629	total: 754ms	remaining: 17.6s
# 82:	learn: 0.6694106	total: 763ms	remaining: 17.6s
# 83:	learn: 0.6691572	total: 771ms	remaining: 17.6s
# 84:	learn: 0.6689084	total: 780ms	remaining: 17.6s
# 85:	learn: 0.6686594	total: 788ms	remaining: 17.5s
# 86:	learn: 0.6684072	total: 797ms	remaining: 17.5s
# 87:	learn: 0.6681594	total: 806ms	remaining: 17.5s
# 88:	learn: 0.6679099	total: 814ms	remaining: 17.5s
# 89:	learn: 0.6676591	total: 823ms	remaining: 17.5s
# 90:	learn: 0.6674104	total: 831ms	remaining: 17.4s
# 91:	learn: 0.6671620	total: 840ms	remaining: 17.4s
# 92:	learn: 0.6669115	total: 853ms	remaining: 17.5s
# 93:	learn: 0.6666687	total: 867ms	remaining: 17.6s
# 94:	learn: 0.6664219	total: 876ms	remaining: 17.6s
# 95:	learn: 0.6661748	total: 884ms	remaining: 17.5s
# 96:	learn: 0.6659320	total: 893ms	remaining: 17.5s
# 97:	learn: 0.6656899	total: 901ms	remaining: 17.5s
# 98:	learn: 0.6654499	total: 910ms	remaining: 17.5s
# 99:	learn: 0.6652067	total: 919ms	remaining: 17.5s
# 100:	learn: 0.6649613	total: 927ms	remaining: 17.4s
# 101:	learn: 0.6647191	total: 936ms	remaining: 17.4s
# 102:	learn: 0.6644804	total: 944ms	remaining: 17.4s
# 103:	learn: 0.6642407	total: 953ms	remaining: 17.4s
# 104:	learn: 0.6640053	total: 962ms	remaining: 17.4s
# 105:	learn: 0.6637658	total: 970ms	remaining: 17.3s
# 106:	learn: 0.6635290	total: 979ms	remaining: 17.3s
# 107:	learn: 0.6632933	total: 987ms	remaining: 17.3s
# 108:	learn: 0.6630558	total: 996ms	remaining: 17.3s
# 109:	learn: 0.6628194	total: 1s	remaining: 17.3s
# 110:	learn: 0.6625818	total: 1.01s	remaining: 17.2s
# 111:	learn: 0.6623469	total: 1.02s	remaining: 17.2s
# 112:	learn: 0.6621146	total: 1.03s	remaining: 17.2s
# 113:	learn: 0.6618822	total: 1.04s	remaining: 17.3s
# 114:	learn: 0.6616504	total: 1.06s	remaining: 17.3s
# 115:	learn: 0.6614197	total: 1.07s	remaining: 17.3s
# 116:	learn: 0.6611858	total: 1.07s	remaining: 17.3s
# 117:	learn: 0.6609543	total: 1.08s	remaining: 17.3s
# 118:	learn: 0.6607262	total: 1.09s	remaining: 17.3s
# 119:	learn: 0.6604958	total: 1.1s	remaining: 17.2s
# 120:	learn: 0.6602683	total: 1.11s	remaining: 17.2s
# 121:	learn: 0.6600363	total: 1.12s	remaining: 17.2s
# 122:	learn: 0.6598084	total: 1.13s	remaining: 17.2s
# 123:	learn: 0.6595820	total: 1.14s	remaining: 17.2s
# 124:	learn: 0.6593561	total: 1.14s	remaining: 17.2s
# 125:	learn: 0.6591309	total: 1.15s	remaining: 17.1s
# 126:	learn: 0.6589053	total: 1.16s	remaining: 17.1s
# 127:	learn: 0.6586807	total: 1.17s	remaining: 17.1s
# 128:	learn: 0.6584570	total: 1.18s	remaining: 17.1s
# 129:	learn: 0.6582326	total: 1.19s	remaining: 17.1s
# 130:	learn: 0.6580091	total: 1.2s	remaining: 17.1s
# 131:	learn: 0.6577859	total: 1.2s	remaining: 17s
# 132:	learn: 0.6575658	total: 1.21s	remaining: 17s
# 133:	learn: 0.6573449	total: 1.22s	remaining: 17s
# 134:	learn: 0.6571280	total: 1.23s	remaining: 17s
# 135:	learn: 0.6569092	total: 1.25s	remaining: 17.1s
# 136:	learn: 0.6566905	total: 1.26s	remaining: 17.1s
# 137:	learn: 0.6564715	total: 1.26s	remaining: 17.1s
# 138:	learn: 0.6562538	total: 1.27s	remaining: 17.1s
# 139:	learn: 0.6560372	total: 1.28s	remaining: 17s
# 140:	learn: 0.6558198	total: 1.29s	remaining: 17s
# 141:	learn: 0.6556020	total: 1.3s	remaining: 17s
# 142:	learn: 0.6553853	total: 1.31s	remaining: 17s
# 143:	learn: 0.6551734	total: 1.32s	remaining: 17s
# 144:	learn: 0.6549562	total: 1.32s	remaining: 17s
# 145:	learn: 0.6547410	total: 1.33s	remaining: 16.9s
# 146:	learn: 0.6545286	total: 1.34s	remaining: 16.9s
# 147:	learn: 0.6543169	total: 1.35s	remaining: 16.9s
# 148:	learn: 0.6541039	total: 1.36s	remaining: 16.9s
# 149:	learn: 0.6538912	total: 1.37s	remaining: 16.9s
# 150:	learn: 0.6536828	total: 1.38s	remaining: 16.9s
# 151:	learn: 0.6534726	total: 1.39s	remaining: 16.9s
# 152:	learn: 0.6532617	total: 1.4s	remaining: 16.8s
# 153:	learn: 0.6530510	total: 1.4s	remaining: 16.8s
# 154:	learn: 0.6528427	total: 1.41s	remaining: 16.8s
# 155:	learn: 0.6526327	total: 1.42s	remaining: 16.8s
# 156:	learn: 0.6524252	total: 1.43s	remaining: 16.8s
# 157:	learn: 0.6522183	total: 1.45s	remaining: 16.9s
# 158:	learn: 0.6520130	total: 1.46s	remaining: 16.9s
# 159:	learn: 0.6518067	total: 1.47s	remaining: 16.9s
# 160:	learn: 0.6515984	total: 1.47s	remaining: 16.8s
# 161:	learn: 0.6513941	total: 1.48s	remaining: 16.8s
# 162:	learn: 0.6511895	total: 1.49s	remaining: 16.8s
# 163:	learn: 0.6509877	total: 1.5s	remaining: 16.8s
# 164:	learn: 0.6507829	total: 1.51s	remaining: 16.8s
# 165:	learn: 0.6505811	total: 1.52s	remaining: 16.8s
# 166:	learn: 0.6503833	total: 1.52s	remaining: 16.7s
# 167:	learn: 0.6501808	total: 1.53s	remaining: 16.7s
# 168:	learn: 0.6499770	total: 1.54s	remaining: 16.7s
# 169:	learn: 0.6497780	total: 1.55s	remaining: 16.7s
# 170:	learn: 0.6495760	total: 1.56s	remaining: 16.7s
# 171:	learn: 0.6493765	total: 1.57s	remaining: 16.7s
# 172:	learn: 0.6491796	total: 1.58s	remaining: 16.7s
# 173:	learn: 0.6489823	total: 1.58s	remaining: 16.6s
# 174:	learn: 0.6487833	total: 1.59s	remaining: 16.6s
# 175:	learn: 0.6485870	total: 1.6s	remaining: 16.6s
# 176:	learn: 0.6483879	total: 1.61s	remaining: 16.6s
# 177:	learn: 0.6481925	total: 1.62s	remaining: 16.6s
# 178:	learn: 0.6479947	total: 1.63s	remaining: 16.6s
# 179:	learn: 0.6477989	total: 1.64s	remaining: 16.6s
# 180:	learn: 0.6476064	total: 1.66s	remaining: 16.6s
# 181:	learn: 0.6474122	total: 1.67s	remaining: 16.6s
# 182:	learn: 0.6472201	total: 1.67s	remaining: 16.6s
# 183:	learn: 0.6470263	total: 1.68s	remaining: 16.6s
# 184:	learn: 0.6468349	total: 1.69s	remaining: 16.6s
# 185:	learn: 0.6466453	total: 1.7s	remaining: 16.6s
# 186:	learn: 0.6464552	total: 1.71s	remaining: 16.6s
# 187:	learn: 0.6462661	total: 1.72s	remaining: 16.5s
# 188:	learn: 0.6460741	total: 1.73s	remaining: 16.5s
# 189:	learn: 0.6458830	total: 1.73s	remaining: 16.5s
# 190:	learn: 0.6456935	total: 1.74s	remaining: 16.5s
# 191:	learn: 0.6455047	total: 1.75s	remaining: 16.5s
# 192:	learn: 0.6453141	total: 1.76s	remaining: 16.5s
# 193:	learn: 0.6451237	total: 1.77s	remaining: 16.5s
# 194:	learn: 0.6449338	total: 1.78s	remaining: 16.4s
# 195:	learn: 0.6447455	total: 1.78s	remaining: 16.4s
# 196:	learn: 0.6445595	total: 1.79s	remaining: 16.4s
# 197:	learn: 0.6443752	total: 1.8s	remaining: 16.4s
# 198:	learn: 0.6441871	total: 1.81s	remaining: 16.4s
# 199:	learn: 0.6439994	total: 1.82s	remaining: 16.4s
# 200:	learn: 0.6438161	total: 1.83s	remaining: 16.4s
# 201:	learn: 0.6436298	total: 1.84s	remaining: 16.4s
# 202:	learn: 0.6434446	total: 1.85s	remaining: 16.4s
# 203:	learn: 0.6432618	total: 1.86s	remaining: 16.4s
# 204:	learn: 0.6430789	total: 1.87s	remaining: 16.4s
# 205:	learn: 0.6428972	total: 1.88s	remaining: 16.4s
# 206:	learn: 0.6427176	total: 1.89s	remaining: 16.4s
# 207:	learn: 0.6425368	total: 1.9s	remaining: 16.4s
# 208:	learn: 0.6423560	total: 1.91s	remaining: 16.4s
# 209:	learn: 0.6421753	total: 1.92s	remaining: 16.3s
# 210:	learn: 0.6419932	total: 1.93s	remaining: 16.3s
# 211:	learn: 0.6418126	total: 1.93s	remaining: 16.3s
# 212:	learn: 0.6416342	total: 1.94s	remaining: 16.3s
# 213:	learn: 0.6414561	total: 1.95s	remaining: 16.3s
# 214:	learn: 0.6412768	total: 1.96s	remaining: 16.3s
# 215:	learn: 0.6410997	total: 1.97s	remaining: 16.3s
# 216:	learn: 0.6409233	total: 1.98s	remaining: 16.2s
# 217:	learn: 0.6407449	total: 1.99s	remaining: 16.2s
# 218:	learn: 0.6405700	total: 1.99s	remaining: 16.2s
# 219:	learn: 0.6403941	total: 2s	remaining: 16.2s
# 220:	learn: 0.6402203	total: 2.01s	remaining: 16.2s
# 221:	learn: 0.6400456	total: 2.02s	remaining: 16.2s
# 222:	learn: 0.6398700	total: 2.03s	remaining: 16.2s
# 223:	learn: 0.6396968	total: 2.05s	remaining: 16.2s
# 224:	learn: 0.6395236	total: 2.05s	remaining: 16.2s
# 225:	learn: 0.6393471	total: 2.06s	remaining: 16.2s
# 226:	learn: 0.6391775	total: 2.07s	remaining: 16.2s
# 227:	learn: 0.6390045	total: 2.08s	remaining: 16.2s
# 228:	learn: 0.6388351	total: 2.09s	remaining: 16.2s
# 229:	learn: 0.6386660	total: 2.1s	remaining: 16.1s
# 230:	learn: 0.6384940	total: 2.11s	remaining: 16.1s
# 231:	learn: 0.6383231	total: 2.12s	remaining: 16.1s
# 232:	learn: 0.6381528	total: 2.12s	remaining: 16.1s
# 233:	learn: 0.6379833	total: 2.13s	remaining: 16.1s
# 234:	learn: 0.6378152	total: 2.14s	remaining: 16.1s
# 235:	learn: 0.6376469	total: 2.15s	remaining: 16.1s
# 236:	learn: 0.6374806	total: 2.16s	remaining: 16.1s
# 237:	learn: 0.6373134	total: 2.17s	remaining: 16s
# 238:	learn: 0.6371471	total: 2.17s	remaining: 16s
# 239:	learn: 0.6369773	total: 2.18s	remaining: 16s
# 240:	learn: 0.6368101	total: 2.19s	remaining: 16s
# 241:	learn: 0.6366431	total: 2.2s	remaining: 16s
# 242:	learn: 0.6364781	total: 2.21s	remaining: 16s
# 243:	learn: 0.6363119	total: 2.22s	remaining: 16s
# 244:	learn: 0.6361489	total: 2.23s	remaining: 16s
# 245:	learn: 0.6359860	total: 2.24s	remaining: 16s
# 246:	learn: 0.6358215	total: 2.25s	remaining: 16s
# 247:	learn: 0.6356579	total: 2.26s	remaining: 16s
# 248:	learn: 0.6354969	total: 2.27s	remaining: 16s
# 249:	learn: 0.6353366	total: 2.28s	remaining: 16s
# 250:	learn: 0.6351769	total: 2.29s	remaining: 15.9s
# 251:	learn: 0.6350176	total: 2.3s	remaining: 15.9s
# 252:	learn: 0.6348559	total: 2.31s	remaining: 15.9s
# 253:	learn: 0.6346956	total: 2.31s	remaining: 15.9s
# 254:	learn: 0.6345347	total: 2.32s	remaining: 15.9s
# 255:	learn: 0.6343746	total: 2.33s	remaining: 15.9s
# 256:	learn: 0.6342132	total: 2.34s	remaining: 15.9s
# 257:	learn: 0.6340516	total: 2.35s	remaining: 15.9s
# 258:	learn: 0.6338934	total: 2.36s	remaining: 15.9s
# 259:	learn: 0.6337323	total: 2.37s	remaining: 15.8s
# 260:	learn: 0.6335756	total: 2.38s	remaining: 15.8s
# 261:	learn: 0.6334182	total: 2.38s	remaining: 15.8s
# 262:	learn: 0.6332609	total: 2.39s	remaining: 15.8s
# 263:	learn: 0.6331031	total: 2.4s	remaining: 15.8s
# 264:	learn: 0.6329462	total: 2.41s	remaining: 15.8s
# 265:	learn: 0.6327920	total: 2.42s	remaining: 15.8s
# 266:	learn: 0.6326348	total: 2.43s	remaining: 15.8s
# 267:	learn: 0.6324804	total: 2.44s	remaining: 15.8s
# 268:	learn: 0.6323250	total: 2.45s	remaining: 15.8s
# 269:	learn: 0.6321705	total: 2.46s	remaining: 15.8s
# 270:	learn: 0.6320161	total: 2.47s	remaining: 15.8s
# 271:	learn: 0.6318607	total: 2.48s	remaining: 15.8s
# 272:	learn: 0.6317081	total: 2.49s	remaining: 15.7s
# 273:	learn: 0.6315554	total: 2.5s	remaining: 15.7s
# 274:	learn: 0.6314028	total: 2.51s	remaining: 15.7s
# 275:	learn: 0.6312504	total: 2.52s	remaining: 15.7s
# 276:	learn: 0.6310984	total: 2.52s	remaining: 15.7s
# 277:	learn: 0.6309466	total: 2.53s	remaining: 15.7s
# 278:	learn: 0.6307953	total: 2.54s	remaining: 15.7s
# 279:	learn: 0.6306455	total: 2.55s	remaining: 15.7s
# 280:	learn: 0.6304975	total: 2.56s	remaining: 15.7s
# 281:	learn: 0.6303486	total: 2.57s	remaining: 15.6s
# 282:	learn: 0.6302003	total: 2.58s	remaining: 15.6s
# 283:	learn: 0.6300534	total: 2.58s	remaining: 15.6s
# 284:	learn: 0.6299047	total: 2.59s	remaining: 15.6s
# 285:	learn: 0.6297599	total: 2.6s	remaining: 15.6s
# 286:	learn: 0.6296142	total: 2.61s	remaining: 15.6s
# 287:	learn: 0.6294643	total: 2.62s	remaining: 15.6s
# 288:	learn: 0.6293202	total: 2.63s	remaining: 15.6s
# 289:	learn: 0.6291733	total: 2.65s	remaining: 15.6s
# 290:	learn: 0.6290263	total: 2.65s	remaining: 15.6s
# 291:	learn: 0.6288814	total: 2.66s	remaining: 15.6s
# 292:	learn: 0.6287375	total: 2.67s	remaining: 15.6s
# 293:	learn: 0.6285916	total: 2.68s	remaining: 15.5s
# 294:	learn: 0.6284447	total: 2.69s	remaining: 15.5s
# 295:	learn: 0.6282995	total: 2.7s	remaining: 15.5s
# 296:	learn: 0.6281539	total: 2.71s	remaining: 15.5s
# 297:	learn: 0.6280104	total: 2.71s	remaining: 15.5s
# 298:	learn: 0.6278661	total: 2.72s	remaining: 15.5s
# 299:	learn: 0.6277236	total: 2.73s	remaining: 15.5s
# 300:	learn: 0.6275816	total: 2.74s	remaining: 15.5s
# 301:	learn: 0.6274399	total: 2.75s	remaining: 15.5s
# 302:	learn: 0.6272987	total: 2.76s	remaining: 15.4s
# 303:	learn: 0.6271596	total: 2.77s	remaining: 15.4s
# 304:	learn: 0.6270183	total: 2.77s	remaining: 15.4s
# 305:	learn: 0.6268765	total: 2.78s	remaining: 15.4s
# 306:	learn: 0.6267363	total: 2.79s	remaining: 15.4s
# 307:	learn: 0.6265967	total: 2.8s	remaining: 15.4s
# 308:	learn: 0.6264588	total: 2.81s	remaining: 15.4s
# 309:	learn: 0.6263161	total: 2.82s	remaining: 15.4s
# 310:	learn: 0.6261793	total: 2.83s	remaining: 15.4s
# 311:	learn: 0.6260384	total: 2.84s	remaining: 15.4s
# 312:	learn: 0.6259030	total: 2.85s	remaining: 15.4s
# 313:	learn: 0.6257674	total: 2.86s	remaining: 15.4s
# 314:	learn: 0.6256316	total: 2.87s	remaining: 15.4s
# 315:	learn: 0.6254954	total: 2.88s	remaining: 15.3s
# 316:	learn: 0.6253580	total: 2.89s	remaining: 15.3s
# 317:	learn: 0.6252236	total: 2.9s	remaining: 15.3s
# 318:	learn: 0.6250880	total: 2.9s	remaining: 15.3s
# 319:	learn: 0.6249553	total: 2.91s	remaining: 15.3s
# 320:	learn: 0.6248200	total: 2.92s	remaining: 15.3s
# 321:	learn: 0.6246845	total: 2.93s	remaining: 15.3s
# 322:	learn: 0.6245485	total: 2.94s	remaining: 15.3s
# 323:	learn: 0.6244142	total: 2.95s	remaining: 15.2s
# 324:	learn: 0.6242836	total: 2.96s	remaining: 15.2s
# 325:	learn: 0.6241503	total: 2.96s	remaining: 15.2s
# 326:	learn: 0.6240165	total: 2.97s	remaining: 15.2s
# 327:	learn: 0.6238818	total: 2.98s	remaining: 15.2s
# 328:	learn: 0.6237490	total: 2.99s	remaining: 15.2s
# 329:	learn: 0.6236161	total: 3s	remaining: 15.2s
# 330:	learn: 0.6234865	total: 3.02s	remaining: 15.2s
# 331:	learn: 0.6233528	total: 3.03s	remaining: 15.2s
# 332:	learn: 0.6232217	total: 3.03s	remaining: 15.2s
# 333:	learn: 0.6230905	total: 3.04s	remaining: 15.2s
# 334:	learn: 0.6229594	total: 3.05s	remaining: 15.2s
# 335:	learn: 0.6228327	total: 3.06s	remaining: 15.2s
# 336:	learn: 0.6227029	total: 3.07s	remaining: 15.1s
# 337:	learn: 0.6225729	total: 3.08s	remaining: 15.1s
# 338:	learn: 0.6224449	total: 3.09s	remaining: 15.1s
# 339:	learn: 0.6223175	total: 3.09s	remaining: 15.1s
# 340:	learn: 0.6221881	total: 3.1s	remaining: 15.1s
# 341:	learn: 0.6220565	total: 3.11s	remaining: 15.1s
# 342:	learn: 0.6219316	total: 3.12s	remaining: 15.1s
# 343:	learn: 0.6218030	total: 3.13s	remaining: 15.1s
# 344:	learn: 0.6216768	total: 3.14s	remaining: 15.1s
# 345:	learn: 0.6215514	total: 3.15s	remaining: 15s
# 346:	learn: 0.6214229	total: 3.15s	remaining: 15s
# 347:	learn: 0.6212940	total: 3.16s	remaining: 15s
# 348:	learn: 0.6211677	total: 3.17s	remaining: 15s
# 349:	learn: 0.6210410	total: 3.18s	remaining: 15s
# 350:	learn: 0.6209162	total: 3.19s	remaining: 15s
# 351:	learn: 0.6207928	total: 3.2s	remaining: 15s
# 352:	learn: 0.6206686	total: 3.21s	remaining: 15s
# 353:	learn: 0.6205458	total: 3.22s	remaining: 15s
# 354:	learn: 0.6204208	total: 3.23s	remaining: 15s
# 355:	learn: 0.6202927	total: 3.24s	remaining: 15s
# 356:	learn: 0.6201691	total: 3.25s	remaining: 15s
# 357:	learn: 0.6200455	total: 3.26s	remaining: 14.9s
# 358:	learn: 0.6199200	total: 3.27s	remaining: 14.9s
# 359:	learn: 0.6197978	total: 3.27s	remaining: 14.9s
# 360:	learn: 0.6196738	total: 3.28s	remaining: 14.9s
# 361:	learn: 0.6195509	total: 3.29s	remaining: 14.9s
# 362:	learn: 0.6194281	total: 3.3s	remaining: 14.9s
# 363:	learn: 0.6193077	total: 3.31s	remaining: 14.9s
# 364:	learn: 0.6191845	total: 3.32s	remaining: 14.9s
# 365:	learn: 0.6190642	total: 3.33s	remaining: 14.9s
# 366:	learn: 0.6189425	total: 3.34s	remaining: 14.8s
# 367:	learn: 0.6188243	total: 3.34s	remaining: 14.8s
# 368:	learn: 0.6187040	total: 3.35s	remaining: 14.8s
# 369:	learn: 0.6185863	total: 3.36s	remaining: 14.8s
# 370:	learn: 0.6184686	total: 3.37s	remaining: 14.8s
# 371:	learn: 0.6183485	total: 3.38s	remaining: 14.8s
# 372:	learn: 0.6182300	total: 3.39s	remaining: 14.8s
# 373:	learn: 0.6181125	total: 3.4s	remaining: 14.8s
# 374:	learn: 0.6179936	total: 3.42s	remaining: 14.8s
# 375:	learn: 0.6178755	total: 3.42s	remaining: 14.8s
# 376:	learn: 0.6177558	total: 3.43s	remaining: 14.8s
# 377:	learn: 0.6176402	total: 3.44s	remaining: 14.8s
# 378:	learn: 0.6175231	total: 3.45s	remaining: 14.8s
# 379:	learn: 0.6174054	total: 3.46s	remaining: 14.7s
# 380:	learn: 0.6172915	total: 3.47s	remaining: 14.7s
# 381:	learn: 0.6171749	total: 3.47s	remaining: 14.7s
# 382:	learn: 0.6170595	total: 3.48s	remaining: 14.7s
# 383:	learn: 0.6169447	total: 3.49s	remaining: 14.7s
# 384:	learn: 0.6168286	total: 3.5s	remaining: 14.7s
# 385:	learn: 0.6167139	total: 3.51s	remaining: 14.7s
# 386:	learn: 0.6165997	total: 3.52s	remaining: 14.7s
# 387:	learn: 0.6164843	total: 3.53s	remaining: 14.7s
# 388:	learn: 0.6163718	total: 3.54s	remaining: 14.6s
# 389:	learn: 0.6162573	total: 3.54s	remaining: 14.6s
# 390:	learn: 0.6161435	total: 3.55s	remaining: 14.6s
# 391:	learn: 0.6160301	total: 3.56s	remaining: 14.6s
# 392:	learn: 0.6159171	total: 3.57s	remaining: 14.6s
# 393:	learn: 0.6158043	total: 3.58s	remaining: 14.6s
# 394:	learn: 0.6156913	total: 3.59s	remaining: 14.6s
# 395:	learn: 0.6155774	total: 3.61s	remaining: 14.6s
# 396:	learn: 0.6154661	total: 3.61s	remaining: 14.6s
# 397:	learn: 0.6153548	total: 3.62s	remaining: 14.6s
# 398:	learn: 0.6152450	total: 3.63s	remaining: 14.6s
# 399:	learn: 0.6151341	total: 3.64s	remaining: 14.6s
# 400:	learn: 0.6150253	total: 3.65s	remaining: 14.5s
# 401:	learn: 0.6149140	total: 3.66s	remaining: 14.5s
# 402:	learn: 0.6148060	total: 3.67s	remaining: 14.5s
# 403:	learn: 0.6146956	total: 3.67s	remaining: 14.5s
# 404:	learn: 0.6145866	total: 3.68s	remaining: 14.5s
# 405:	learn: 0.6144781	total: 3.69s	remaining: 14.5s
# 406:	learn: 0.6143692	total: 3.7s	remaining: 14.5s
# 407:	learn: 0.6142589	total: 3.71s	remaining: 14.5s
# 408:	learn: 0.6141496	total: 3.72s	remaining: 14.5s
# 409:	learn: 0.6140416	total: 3.73s	remaining: 14.4s
# 410:	learn: 0.6139322	total: 3.73s	remaining: 14.4s
# 411:	learn: 0.6138238	total: 3.74s	remaining: 14.4s
# 412:	learn: 0.6137155	total: 3.75s	remaining: 14.4s
# 413:	learn: 0.6136098	total: 3.76s	remaining: 14.4s
# 414:	learn: 0.6135020	total: 3.77s	remaining: 14.4s
# 415:	learn: 0.6133936	total: 3.78s	remaining: 14.4s
# 416:	learn: 0.6132873	total: 3.79s	remaining: 14.4s
# 417:	learn: 0.6131831	total: 3.8s	remaining: 14.4s
# 418:	learn: 0.6130769	total: 3.81s	remaining: 14.4s
# 419:	learn: 0.6129713	total: 3.82s	remaining: 14.4s
# 420:	learn: 0.6128662	total: 3.83s	remaining: 14.4s
# 421:	learn: 0.6127612	total: 3.84s	remaining: 14.4s
# 422:	learn: 0.6126557	total: 3.85s	remaining: 14.3s
# 423:	learn: 0.6125502	total: 3.86s	remaining: 14.3s
# 424:	learn: 0.6124453	total: 3.87s	remaining: 14.3s
# 425:	learn: 0.6123417	total: 3.87s	remaining: 14.3s
# 426:	learn: 0.6122373	total: 3.88s	remaining: 14.3s
# 427:	learn: 0.6121347	total: 3.89s	remaining: 14.3s
# 428:	learn: 0.6120318	total: 3.9s	remaining: 14.3s
# 429:	learn: 0.6119296	total: 3.91s	remaining: 14.3s
# 430:	learn: 0.6118266	total: 3.92s	remaining: 14.3s
# 431:	learn: 0.6117247	total: 3.92s	remaining: 14.2s
# 432:	learn: 0.6116224	total: 3.93s	remaining: 14.2s
# 433:	learn: 0.6115210	total: 3.94s	remaining: 14.2s
# 434:	learn: 0.6114189	total: 3.95s	remaining: 14.2s
# 435:	learn: 0.6113183	total: 3.96s	remaining: 14.2s
# 436:	learn: 0.6112163	total: 3.97s	remaining: 14.2s
# 437:	learn: 0.6111129	total: 3.98s	remaining: 14.2s
# 438:	learn: 0.6110111	total: 3.99s	remaining: 14.2s
# 439:	learn: 0.6109098	total: 4s	remaining: 14.2s
# 440:	learn: 0.6108114	total: 4.01s	remaining: 14.2s
# 441:	learn: 0.6107095	total: 4.02s	remaining: 14.2s
# 442:	learn: 0.6106117	total: 4.03s	remaining: 14.2s
# 443:	learn: 0.6105111	total: 4.04s	remaining: 14.2s
# 444:	learn: 0.6104128	total: 4.05s	remaining: 14.1s
# 445:	learn: 0.6103127	total: 4.06s	remaining: 14.1s
# 446:	learn: 0.6102121	total: 4.07s	remaining: 14.1s
# 447:	learn: 0.6101129	total: 4.07s	remaining: 14.1s
# 448:	learn: 0.6100121	total: 4.08s	remaining: 14.1s
# 449:	learn: 0.6099135	total: 4.09s	remaining: 14.1s
# 450:	learn: 0.6098149	total: 4.1s	remaining: 14.1s
# 451:	learn: 0.6097190	total: 4.11s	remaining: 14.1s
# 452:	learn: 0.6096199	total: 4.12s	remaining: 14.1s
# 453:	learn: 0.6095230	total: 4.13s	remaining: 14s
# 454:	learn: 0.6094267	total: 4.13s	remaining: 14s
# 455:	learn: 0.6093316	total: 4.14s	remaining: 14s
# 456:	learn: 0.6092354	total: 4.15s	remaining: 14s
# 457:	learn: 0.6091374	total: 4.16s	remaining: 14s
# 458:	learn: 0.6090404	total: 4.17s	remaining: 14s
# 459:	learn: 0.6089428	total: 4.18s	remaining: 14s
# 460:	learn: 0.6088473	total: 4.2s	remaining: 14s
# 461:	learn: 0.6087531	total: 4.2s	remaining: 14s
# 462:	learn: 0.6086575	total: 4.21s	remaining: 14s
# 463:	learn: 0.6085624	total: 4.22s	remaining: 14s
# 464:	learn: 0.6084670	total: 4.23s	remaining: 14s
# 465:	learn: 0.6083718	total: 4.24s	remaining: 14s
# 466:	learn: 0.6082782	total: 4.25s	remaining: 13.9s
# 467:	learn: 0.6081840	total: 4.26s	remaining: 13.9s
# 468:	learn: 0.6080893	total: 4.26s	remaining: 13.9s
# 469:	learn: 0.6079961	total: 4.27s	remaining: 13.9s
# 470:	learn: 0.6079034	total: 4.28s	remaining: 13.9s
# 471:	learn: 0.6078106	total: 4.29s	remaining: 13.9s
# 472:	learn: 0.6077178	total: 4.3s	remaining: 13.9s
# 473:	learn: 0.6076247	total: 4.31s	remaining: 13.9s
# 474:	learn: 0.6075338	total: 4.32s	remaining: 13.9s
# 475:	learn: 0.6074418	total: 4.33s	remaining: 13.8s
# 476:	learn: 0.6073494	total: 4.33s	remaining: 13.8s
# 477:	learn: 0.6072570	total: 4.34s	remaining: 13.8s
# 478:	learn: 0.6071655	total: 4.35s	remaining: 13.8s
# 479:	learn: 0.6070737	total: 4.36s	remaining: 13.8s
# 480:	learn: 0.6069820	total: 4.37s	remaining: 13.8s
# 481:	learn: 0.6068918	total: 4.38s	remaining: 13.8s
# 482:	learn: 0.6068012	total: 4.4s	remaining: 13.8s
# 483:	learn: 0.6067108	total: 4.41s	remaining: 13.8s
# 484:	learn: 0.6066199	total: 4.41s	remaining: 13.8s
# ...
# 1813:	learn: 0.5670634	total: 17.1s	remaining: 1.75s
# 1814:	learn: 0.5670567	total: 17.1s	remaining: 1.74s
# 1815:	learn: 0.5670465	total: 17.1s	remaining: 1.73s
# 1816:	learn: 0.5670406	total: 17.1s	remaining: 1.72s
# 1817:	learn: 0.5670309	total: 17.1s	remaining: 1.71s
# 1818:	learn: 0.5670236	total: 17.1s	remaining: 1.7s
# 1819:	learn: 0.5670153	total: 17.1s	remaining: 1.69s
# 1820:	learn: 0.5670072	total: 17.1s	remaining: 1.68s
# 1821:	learn: 0.5669992	total: 17.1s	remaining: 1.67s
# 1822:	learn: 0.5669904	total: 17.1s	remaining: 1.66s
# 1823:	learn: 0.5669834	total: 17.1s	remaining: 1.65s
# 1824:	learn: 0.5669758	total: 17.2s	remaining: 1.65s
# 1825:	learn: 0.5669701	total: 17.2s	remaining: 1.64s
# 1826:	learn: 0.5669628	total: 17.2s	remaining: 1.63s
# 1827:	learn: 0.5669516	total: 17.2s	remaining: 1.62s
# 1828:	learn: 0.5669431	total: 17.2s	remaining: 1.61s
# 1829:	learn: 0.5669344	total: 17.2s	remaining: 1.6s
# 1830:	learn: 0.5669230	total: 17.2s	remaining: 1.59s
# 1831:	learn: 0.5669135	total: 17.2s	remaining: 1.58s
# 1832:	learn: 0.5669034	total: 17.2s	remaining: 1.57s
# 1833:	learn: 0.5668936	total: 17.3s	remaining: 1.56s
# 1834:	learn: 0.5668868	total: 17.3s	remaining: 1.55s
# 1835:	learn: 0.5668788	total: 17.3s	remaining: 1.54s
# 1836:	learn: 0.5668705	total: 17.3s	remaining: 1.53s
# 1837:	learn: 0.5668611	total: 17.3s	remaining: 1.52s
# 1838:	learn: 0.5668491	total: 17.3s	remaining: 1.51s
# 1839:	learn: 0.5668402	total: 17.3s	remaining: 1.5s
# 1840:	learn: 0.5668298	total: 17.3s	remaining: 1.5s
# 1841:	learn: 0.5668196	total: 17.3s	remaining: 1.49s
# 1842:	learn: 0.5668124	total: 17.3s	remaining: 1.48s
# 1843:	learn: 0.5668014	total: 17.3s	remaining: 1.47s
# 1844:	learn: 0.5667951	total: 17.4s	remaining: 1.46s
# 1845:	learn: 0.5667852	total: 17.4s	remaining: 1.45s
# 1846:	learn: 0.5667758	total: 17.4s	remaining: 1.44s
# 1847:	learn: 0.5667671	total: 17.4s	remaining: 1.43s
# 1848:	learn: 0.5667556	total: 17.4s	remaining: 1.42s
# 1849:	learn: 0.5667468	total: 17.4s	remaining: 1.41s
# 1850:	learn: 0.5667374	total: 17.4s	remaining: 1.4s
# 1851:	learn: 0.5667299	total: 17.4s	remaining: 1.39s
# 1852:	learn: 0.5667241	total: 17.4s	remaining: 1.38s
# 1853:	learn: 0.5667181	total: 17.4s	remaining: 1.37s
# 1854:	learn: 0.5667095	total: 17.5s	remaining: 1.36s
# 1855:	learn: 0.5667014	total: 17.5s	remaining: 1.35s
# 1856:	learn: 0.5666943	total: 17.5s	remaining: 1.34s
# 1857:	learn: 0.5666867	total: 17.5s	remaining: 1.34s
# 1858:	learn: 0.5666775	total: 17.5s	remaining: 1.33s
# 1859:	learn: 0.5666707	total: 17.5s	remaining: 1.32s
# 1860:	learn: 0.5666613	total: 17.5s	remaining: 1.31s
# 1861:	learn: 0.5666515	total: 17.5s	remaining: 1.3s
# 1862:	learn: 0.5666433	total: 17.5s	remaining: 1.29s
# 1863:	learn: 0.5666377	total: 17.5s	remaining: 1.28s
# 1864:	learn: 0.5666322	total: 17.6s	remaining: 1.27s
# 1865:	learn: 0.5666257	total: 17.6s	remaining: 1.26s
# 1866:	learn: 0.5666166	total: 17.6s	remaining: 1.25s
# 1867:	learn: 0.5666055	total: 17.6s	remaining: 1.24s
# 1868:	learn: 0.5665964	total: 17.6s	remaining: 1.23s
# 1869:	learn: 0.5665892	total: 17.6s	remaining: 1.22s
# 1870:	learn: 0.5665819	total: 17.6s	remaining: 1.21s
# 1871:	learn: 0.5665715	total: 17.6s	remaining: 1.2s
# 1872:	learn: 0.5665658	total: 17.6s	remaining: 1.2s
# 1873:	learn: 0.5665586	total: 17.6s	remaining: 1.19s
# 1874:	learn: 0.5665511	total: 17.7s	remaining: 1.18s
# 1875:	learn: 0.5665431	total: 17.7s	remaining: 1.17s
# 1876:	learn: 0.5665369	total: 17.7s	remaining: 1.16s
# 1877:	learn: 0.5665289	total: 17.7s	remaining: 1.15s
# 1878:	learn: 0.5665232	total: 17.7s	remaining: 1.14s
# 1879:	learn: 0.5665150	total: 17.7s	remaining: 1.13s
# 1880:	learn: 0.5665095	total: 17.7s	remaining: 1.12s
# 1881:	learn: 0.5664999	total: 17.7s	remaining: 1.11s
# 1882:	learn: 0.5664924	total: 17.7s	remaining: 1.1s
# 1883:	learn: 0.5664865	total: 17.8s	remaining: 1.09s
# 1884:	learn: 0.5664799	total: 17.8s	remaining: 1.08s
# 1885:	learn: 0.5664729	total: 17.8s	remaining: 1.07s
# 1886:	learn: 0.5664642	total: 17.8s	remaining: 1.06s
# 1887:	learn: 0.5664566	total: 17.8s	remaining: 1.05s
# 1888:	learn: 0.5664509	total: 17.8s	remaining: 1.05s
# 1889:	learn: 0.5664451	total: 17.8s	remaining: 1.04s
# 1890:	learn: 0.5664347	total: 17.8s	remaining: 1.03s
# 1891:	learn: 0.5664278	total: 17.8s	remaining: 1.02s
# 1892:	learn: 0.5664207	total: 17.8s	remaining: 1.01s
# 1893:	learn: 0.5664149	total: 17.9s	remaining: 1000ms
# 1894:	learn: 0.5664074	total: 17.9s	remaining: 990ms
# 1895:	learn: 0.5663981	total: 17.9s	remaining: 981ms
# 1896:	learn: 0.5663914	total: 17.9s	remaining: 971ms
# 1897:	learn: 0.5663839	total: 17.9s	remaining: 962ms
# 1898:	learn: 0.5663724	total: 17.9s	remaining: 952ms
# 1899:	learn: 0.5663672	total: 17.9s	remaining: 943ms
# 1900:	learn: 0.5663603	total: 17.9s	remaining: 934ms
# 1901:	learn: 0.5663514	total: 17.9s	remaining: 924ms
# 1902:	learn: 0.5663435	total: 17.9s	remaining: 915ms
# 1903:	learn: 0.5663363	total: 18s	remaining: 905ms
# 1904:	learn: 0.5663277	total: 18s	remaining: 896ms
# 1905:	learn: 0.5663212	total: 18s	remaining: 886ms
# 1906:	learn: 0.5663139	total: 18s	remaining: 877ms
# 1907:	learn: 0.5663040	total: 18s	remaining: 868ms
# 1908:	learn: 0.5662930	total: 18s	remaining: 858ms
# 1909:	learn: 0.5662884	total: 18s	remaining: 849ms
# 1910:	learn: 0.5662796	total: 18s	remaining: 839ms
# 1911:	learn: 0.5662697	total: 18s	remaining: 830ms
# 1912:	learn: 0.5662615	total: 18s	remaining: 821ms
# 1913:	learn: 0.5662537	total: 18.1s	remaining: 811ms
# 1914:	learn: 0.5662458	total: 18.1s	remaining: 802ms
# 1915:	learn: 0.5662376	total: 18.1s	remaining: 793ms
# 1916:	learn: 0.5662313	total: 18.1s	remaining: 783ms
# 1917:	learn: 0.5662216	total: 18.1s	remaining: 774ms
# 1918:	learn: 0.5662126	total: 18.1s	remaining: 764ms
# 1919:	learn: 0.5662047	total: 18.1s	remaining: 755ms
# 1920:	learn: 0.5661946	total: 18.1s	remaining: 745ms
# 1921:	learn: 0.5661886	total: 18.1s	remaining: 736ms
# 1922:	learn: 0.5661813	total: 18.1s	remaining: 727ms
# 1923:	learn: 0.5661754	total: 18.2s	remaining: 717ms
# 1924:	learn: 0.5661699	total: 18.2s	remaining: 708ms
# 1925:	learn: 0.5661617	total: 18.2s	remaining: 698ms
# 1926:	learn: 0.5661557	total: 18.2s	remaining: 689ms
# 1927:	learn: 0.5661458	total: 18.2s	remaining: 680ms
# 1928:	learn: 0.5661409	total: 18.2s	remaining: 670ms
# 1929:	learn: 0.5661343	total: 18.2s	remaining: 661ms
# 1930:	learn: 0.5661263	total: 18.2s	remaining: 651ms
# 1931:	learn: 0.5661192	total: 18.2s	remaining: 642ms
# 1932:	learn: 0.5661132	total: 18.2s	remaining: 632ms
# 1933:	learn: 0.5661033	total: 18.3s	remaining: 623ms
# 1934:	learn: 0.5660965	total: 18.3s	remaining: 613ms
# 1935:	learn: 0.5660877	total: 18.3s	remaining: 604ms
# 1936:	learn: 0.5660819	total: 18.3s	remaining: 595ms
# 1937:	learn: 0.5660768	total: 18.3s	remaining: 585ms
# 1938:	learn: 0.5660663	total: 18.3s	remaining: 576ms
# 1939:	learn: 0.5660605	total: 18.3s	remaining: 566ms
# 1940:	learn: 0.5660554	total: 18.3s	remaining: 557ms
# 1941:	learn: 0.5660480	total: 18.3s	remaining: 548ms
# 1942:	learn: 0.5660377	total: 18.4s	remaining: 538ms
# 1943:	learn: 0.5660307	total: 18.4s	remaining: 529ms
# 1944:	learn: 0.5660233	total: 18.4s	remaining: 520ms
# 1945:	learn: 0.5660171	total: 18.4s	remaining: 510ms
# 1946:	learn: 0.5660103	total: 18.4s	remaining: 501ms
# 1947:	learn: 0.5659995	total: 18.4s	remaining: 491ms
# 1948:	learn: 0.5659950	total: 18.4s	remaining: 482ms
# 1949:	learn: 0.5659896	total: 18.4s	remaining: 473ms
# 1950:	learn: 0.5659834	total: 18.4s	remaining: 463ms
# 1951:	learn: 0.5659763	total: 18.5s	remaining: 454ms
# 1952:	learn: 0.5659700	total: 18.5s	remaining: 445ms
# 1953:	learn: 0.5659643	total: 18.5s	remaining: 435ms
# 1954:	learn: 0.5659570	total: 18.5s	remaining: 426ms
# 1955:	learn: 0.5659504	total: 18.5s	remaining: 416ms
# 1956:	learn: 0.5659423	total: 18.5s	remaining: 407ms
# 1957:	learn: 0.5659373	total: 18.5s	remaining: 397ms
# 1958:	learn: 0.5659322	total: 18.5s	remaining: 388ms
# 1959:	learn: 0.5659225	total: 18.5s	remaining: 378ms
# 1960:	learn: 0.5659167	total: 18.6s	remaining: 369ms
# 1961:	learn: 0.5659093	total: 18.6s	remaining: 359ms
# 1962:	learn: 0.5659005	total: 18.6s	remaining: 350ms
# 1963:	learn: 0.5658919	total: 18.6s	remaining: 341ms
# 1964:	learn: 0.5658827	total: 18.6s	remaining: 331ms
# 1965:	learn: 0.5658769	total: 18.6s	remaining: 322ms
# 1966:	learn: 0.5658701	total: 18.6s	remaining: 312ms
# 1967:	learn: 0.5658641	total: 18.6s	remaining: 303ms
# 1968:	learn: 0.5658563	total: 18.6s	remaining: 293ms
# 1969:	learn: 0.5658514	total: 18.6s	remaining: 284ms
# 1970:	learn: 0.5658463	total: 18.6s	remaining: 274ms
# 1971:	learn: 0.5658382	total: 18.7s	remaining: 265ms
# 1972:	learn: 0.5658309	total: 18.7s	remaining: 255ms
# 1973:	learn: 0.5658263	total: 18.7s	remaining: 246ms
# 1974:	learn: 0.5658201	total: 18.7s	remaining: 237ms
# 1975:	learn: 0.5658148	total: 18.7s	remaining: 227ms
# 1976:	learn: 0.5658096	total: 18.7s	remaining: 218ms
# 1977:	learn: 0.5658001	total: 18.7s	remaining: 208ms
# 1978:	learn: 0.5657946	total: 18.7s	remaining: 199ms
# 1979:	learn: 0.5657849	total: 18.7s	remaining: 189ms
# 1980:	learn: 0.5657744	total: 18.7s	remaining: 180ms
# 1981:	learn: 0.5657689	total: 18.8s	remaining: 170ms
# 1982:	learn: 0.5657597	total: 18.8s	remaining: 161ms
# 1983:	learn: 0.5657521	total: 18.8s	remaining: 151ms
# 1984:	learn: 0.5657437	total: 18.8s	remaining: 142ms
# 1985:	learn: 0.5657385	total: 18.8s	remaining: 133ms
# 1986:	learn: 0.5657298	total: 18.8s	remaining: 123ms
# 1987:	learn: 0.5657215	total: 18.8s	remaining: 114ms
# 1988:	learn: 0.5657122	total: 18.8s	remaining: 104ms
# 1989:	learn: 0.5657036	total: 18.8s	remaining: 94.6ms
# 1990:	learn: 0.5656970	total: 18.8s	remaining: 85.2ms
# 1991:	learn: 0.5656916	total: 18.9s	remaining: 75.7ms
# 1992:	learn: 0.5656836	total: 18.9s	remaining: 66.3ms
# 1993:	learn: 0.5656771	total: 18.9s	remaining: 56.8ms
# 1994:	learn: 0.5656701	total: 18.9s	remaining: 47.3ms
# 1995:	learn: 0.5656625	total: 18.9s	remaining: 37.9ms
# 1996:	learn: 0.5656571	total: 18.9s	remaining: 28.4ms
# 1997:	learn: 0.5656492	total: 18.9s	remaining: 18.9ms
# 1998:	learn: 0.5656416	total: 18.9s	remaining: 9.47ms
# 1999:	learn: 0.5656331	total: 18.9s	remaining: 0us
# {'nan_mode': 'Min', 'gpu_ram_part': 0.95, 'eval_metric': 'Logloss', 'iterations': 2000, 'leaf_estimation_method': 'Newton', 'observations_to_bootstrap': 'TestOnly', 'grow_policy': 'SymmetricTree', 'boosting_type': 'Plain', 'feature_border_type': 'GreedyLogSum', 'bayesian_matrix_reg': 0.10000000149011612, 'devices': '-1', 'pinned_memory_bytes': '104857600', 'l2_leaf_reg': 3, 'random_strength': 1, 'rsm': 1, 'boost_from_average': False, 'gpu_cat_features_storage': 'GpuRam', 'fold_size_loss_normalization': False, 'model_size_reg': 0.5, 'pool_metainfo_options': {'tags': {}}, 'use_best_model': False, 'meta_l2_frequency': 0, 'class_names': [0, 1], 'random_seed': 42, 'depth': 6, 'border_count': 128, 'min_fold_size': 100, 'data_partition': 'DocParallel', 'bagging_temperature': 1, 'classes_count': 0, 'auto_class_weights': 'None', 'leaf_estimation_backtracking': 'AnyImprovement', 'best_model_min_trees': 1, 'min_data_in_leaf': 1, 'add_ridge_penalty_to_loss_function': False, 'loss_function': 'Logloss', 'learning_rate': 0.012571999803185465, 'meta_l2_exponent': 1, 'score_function': 'Cosine', 'task_type': 'GPU', 'leaf_estimation_iterations': 10, 'bootstrap_type': 'Bayesian', 'max_leaves': 64}
# Valid log-loss is 8.713975161227108
# Valid AUC is 0.7476417674270677
# <br/>Waiting for W&B process to finish, PID 1218542<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.84MB of 0.84MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_223738-15xmjyuv/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210908_223738-15xmjyuv/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>8.73556</td></tr><tr><td>train_auc</td><td>0.74702</td></tr><tr><td>_runtime</td><td>61</td></tr><tr><td>_timestamp</td><td>1631165919</td></tr><tr><td>_step</td><td>3</td></tr><tr><td>nan_mode</td><td>Min</td></tr><tr><td>gpu_ram_part</td><td>0.95</td></tr><tr><td>eval_metric</td><td>Logloss</td></tr><tr><td>iterations</td><td>2000</td></tr><tr><td>leaf_estimation_method</td><td>Newton</td></tr><tr><td>observations_to_bootstrap</td><td>TestOnly</td></tr><tr><td>grow_policy</td><td>SymmetricTree</td></tr><tr><td>boosting_type</td><td>Plain</td></tr><tr><td>feature_border_type</td><td>GreedyLogSum</td></tr><tr><td>bayesian_matrix_reg</td><td>0.1</td></tr><tr><td>devices</td><td>-1</td></tr><tr><td>pinned_memory_bytes</td><td>104857600</td></tr><tr><td>l2_leaf_reg</td><td>3</td></tr><tr><td>random_strength</td><td>1</td></tr><tr><td>rsm</td><td>1</td></tr><tr><td>boost_from_average</td><td>False</td></tr><tr><td>gpu_cat_features_storage</td><td>GpuRam</td></tr><tr><td>fold_size_loss_normalization</td><td>False</td></tr><tr><td>model_size_reg</td><td>0.5</td></tr><tr><td>use_best_model</td><td>False</td></tr><tr><td>meta_l2_frequency</td><td>0</td></tr><tr><td>random_seed</td><td>42</td></tr><tr><td>depth</td><td>6</td></tr><tr><td>border_count</td><td>128</td></tr><tr><td>min_fold_size</td><td>100</td></tr><tr><td>data_partition</td><td>DocParallel</td></tr><tr><td>bagging_temperature</td><td>1</td></tr><tr><td>classes_count</td><td>0</td></tr><tr><td>auto_class_weights</td><td>None</td></tr><tr><td>leaf_estimation_backtracking</td><td>AnyImprovement</td></tr><tr><td>best_model_min_trees</td><td>1</td></tr><tr><td>min_data_in_leaf</td><td>1</td></tr><tr><td>add_ridge_penalty_to_loss_function</td><td>False</td></tr><tr><td>loss_function</td><td>Logloss</td></tr><tr><td>learning_rate</td><td>0.01257</td></tr><tr><td>meta_l2_exponent</td><td>1</td></tr><tr><td>score_function</td><td>Cosine</td></tr><tr><td>task_type</td><td>GPU</td></tr><tr><td>leaf_estimation_iterations</td><td>10</td></tr><tr><td>bootstrap_type</td><td>Bayesian</td></tr><tr><td>max_leaves</td><td>64</td></tr><tr><td>valid_loss</td><td>8.71398</td></tr><tr><td>valid_auc</td><td>0.74764</td></tr><tr><td>fold</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁██</td></tr><tr><td>_timestamp</td><td>▁▁██</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>gpu_ram_part</td><td>▁</td></tr><tr><td>iterations</td><td>▁</td></tr><tr><td>bayesian_matrix_reg</td><td>▁</td></tr><tr><td>l2_leaf_reg</td><td>▁</td></tr><tr><td>random_strength</td><td>▁</td></tr><tr><td>rsm</td><td>▁</td></tr><tr><td>boost_from_average</td><td>▁</td></tr><tr><td>fold_size_loss_normalization</td><td>▁</td></tr><tr><td>model_size_reg</td><td>▁</td></tr><tr><td>use_best_model</td><td>▁</td></tr><tr><td>meta_l2_frequency</td><td>▁</td></tr><tr><td>random_seed</td><td>▁</td></tr><tr><td>depth</td><td>▁</td></tr><tr><td>border_count</td><td>▁</td></tr><tr><td>min_fold_size</td><td>▁</td></tr><tr><td>bagging_temperature</td><td>▁</td></tr><tr><td>classes_count</td><td>▁</td></tr><tr><td>best_model_min_trees</td><td>▁</td></tr><tr><td>min_data_in_leaf</td><td>▁</td></tr><tr><td>add_ridge_penalty_to_loss_function</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>meta_l2_exponent</td><td>▁</td></tr><tr><td>leaf_estimation_iterations</td><td>▁</td></tr><tr><td>max_leaves</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">ensemble_20210908_213242</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/15xmjyuv" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/15xmjyuv</a><br/>

# %%
# # this loads models if you need to (or forgot to save them on training above)
# xgboost_models = {}
# xgboost_models_path = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/models/baseline_20210905a_152521_5folds/xgboost/')
# for fold in range(5):
#     xgboost_models[fold] = load(xgboost_models_path/f'xgboost_fold{fold}_model.joblib')

# %% [markdown]
# # Inference

# %%
test_df = pd.read_csv(datapath/'test.csv', index_col='id', low_memory=False)
# test_df.to_feather(datapath/'test.feather') # issue with index being non-default; fix later
# test_df = pd.read_feather(datapath/'test.feather')

# %%
test_df.head()
# Out:
#               f1        f2        f3       f4       f5       f6       f7  \
# id
# 957919  0.165850  0.487050   1295.00  0.02310  0.31900  0.90188   573.29
# 957920  0.129650  0.373480   1763.00  0.72884  0.33247 -1.26310   875.55
# 957921  0.120190  0.445210    736.26  0.04615  0.29605  0.31665  2659.50
# 957922  0.054008  0.395960    996.14  0.85934  0.36678 -0.17060   386.56
# 957923  0.079947 -0.006919  10574.00  0.34845  0.45008 -1.84200  3027.00
#
#               f8            f9       f10  ...     f109     f110    f111  \
# id                                        ...
# 957919    3743.7  2.705700e+12  6221.000  ...  0.16253 -22.1890  2.0655
# 957920  554370.0  5.955700e+14   934.430  ...  0.81528  -1.6342  1.5736
# 957921  317140.0  3.977800e+14   131.810  ...  0.81831 -32.7800  2.1364
# 957922  325680.0 -3.432200e+13   -26.473  ...  0.86559  -2.4162  1.5199
# 957923  428150.0  9.291500e+11  5999.400  ...  0.25190 -18.6300  3.7387
#
#             f112     f113     f114    f115          f116    f117     f118
# id
# 957919  0.430880 -10.7410  81606.0  1.1940  1.980400e+14  2017.1  0.46357
# 957920 -1.071200  11.8320  90114.0  1.1507  4.388000e+16  6638.9  0.28125
# 957921 -1.931200  -3.2804  37739.0  1.1548  1.718100e+14  5844.0  0.13797
# 957922 -0.011633   1.3840  26849.0  1.1490  2.138800e+17  6173.3  0.32910
# 957923  0.757080  -4.9405  50336.0  1.2488  2.151300e+17  2250.1  0.33796
#
# [5 rows x 118 columns]

# %% [markdown]
# (Here's where encapsulating the transformations in a pipeline would come in handy. But I'll do it manually for now.)

# %%
features = [x for x in test_df.columns if x != 'claim']
X_test = test_df[features] # this is just for naming consistency

# %% [markdown]
# Now, let's get the features the model was trained on and subset the test set's features accordingly

# %%
# generation polynomial features
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_test_poly = poly.fit_transform(X_test)

# %%
# X_test_poly_names = poly.get_feature_names(X_test.columns)
# X_poly_names[100:150]
# features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
# checks = [feature in X_test_poly_names for feature in features]
# checks

# %%
# X_test_final = pd.DataFrame(X_test_poly, columns=X_test_poly_names)

# %%
# X_test_final = X_test_final[features[1:]]
# X_test_final = X_test

# %% [markdown]
# # Scaling
# Now, going to scale using `MaxAbsScaler`

# %%
scaler = exmodel_config['scaler']()
X_test_scaled = scaler.fit_transform(X_test)
# X_scaled_df = pd.DataFrame(X_scaled, columns=X_poly_names)

# %%
xgboost_preds = {}
for fold in xgboost_models.keys():
    xgboost_preds[fold] = xgboost_models[fold].predict(X_test_scaled)
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
lightgbm_preds = {}
for fold in lightgbm_models.keys():
    lightgbm_preds[fold] = lightgbm_models[fold].predict(X_test_scaled)

# %%
catboost_preds = {}
for fold in catboost_models.keys():
    catboost_preds[fold] = catboost_models[fold].predict(X_test_scaled)

# %%
preds_path = Path(datapath/f"preds/{config_run['name']}_{exmodel_config['kfolds']}folds/")
preds_path.mkdir(exist_ok=True)

for library in ['xgboost', 'lightgbm', 'catboost']:
    (preds_path/library).mkdir(exist_ok=True)

# %%
dump(xgboost_preds, Path(preds_path/'xgboost/xgboost_preds_dict.joblib'))
# Out:
# ['/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/preds/ensemble_20210908_213242_5folds/xgboost/xgboost_preds_dict.joblib']

# %%
dump(lightgbm_preds, Path(preds_path/'lightgbm/lightgbm_preds_dict.joblib'))
# Out:
# ['/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/preds/ensemble_20210908_213242_5folds/lightgbm/lightgbm_preds_dict.joblib']

# %%
dump(catboost_preds, Path(preds_path/'catboost/catboost_preds_dict.joblib'))
# Out:
# ['/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/preds/ensemble_20210908_213242_5folds/catboost/catboost_preds_dict.joblib']

# %%
sample_df = pd.read_csv(datapath/'sample_solution.csv')

# %%
final_xgboost_preds = (xgboost_preds[0] + xgboost_preds[1] + xgboost_preds[2] + xgboost_preds[3] + xgboost_preds[4]) / 5
final_lightgbm_preds = (lightgbm_preds[0] + lightgbm_preds[1] + lightgbm_preds[2] + lightgbm_preds[3] + lightgbm_preds[4]) / 5
final_catboost_preds = (catboost_preds[0] + catboost_preds[1] + catboost_preds[2] + catboost_preds[3] + catboost_preds[4]) / 5

# %%
# print(final_xgboost_preds[:10])
# print(final_lightgbm_preds[:10])
# print(final_catboost_preds[:10])

# %%
sample_df.loc[:, 'claim'] = final_xgboost_preds

# %%
# sample_df.head()

# %%
submission_path = datapath/'submissions'
submission_path.mkdir(exist_ok=True)

# %%
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_xgboost-mean.csv", index=False)

# %%
sample_df.loc[:, 'claim'] = final_lightgbm_preds
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_lightgbm-mean.csv", index=False)

# %%
sample_df.loc[:, 'claim'] = final_catboost_preds
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_catboost-mean.csv", index=False)

# %%
ensemble_preds = (final_xgboost_preds + final_lightgbm_preds + final_catboost_preds) / 3

# %%
sample_df.loc[:, 'claim'] = ensemble_preds
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_ensemble-equal_model_and_fold_weight_mean.csv", index=False)

# %%
ensemble_preds = 0.4*final_xgboost_preds + 0.3*final_lightgbm_preds + 0.3*final_catboost_preds

# %%
sample_df.loc[:, 'claim'] = ensemble_preds
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_ensemble-0.4xgboost_0.3lightgbm_0.3catboost-equal_fold_weight_mean.csv", index=False)

# %% [markdown]
# # Ensembling with CatBoost

# %%
catboost_models = {}
saved_models_path = Path('/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/models/CatBoost_ensemble_20210831_144245_5folds/')
for fold in range(5):
    catboost_models[fold] = load(filename=Path(saved_models_path/f'catboost_fold{fold}_model.joblib'))

# %%
catboost_models
# Out:
# {0: <catboost.core.CatBoostRegressor at 0x7f1b154ecfa0>,
#  1: <catboost.core.CatBoostRegressor at 0x7f1b1548a880>,
#  2: <catboost.core.CatBoostRegressor at 0x7f1b154ec0a0>,
#  3: <catboost.core.CatBoostRegressor at 0x7f1b1548ac40>,
#  4: <catboost.core.CatBoostRegressor at 0x7f1b154ecdf0>}

# %%
catboost_preds = {}
for fold in catboost_models.keys():
    catboost_preds[fold] = catboost_models[fold].predict(X_test_scaled)

# %%
final_catboost_preds = (catboost_preds[0] + catboost_preds[1] + catboost_preds[2] + catboost_preds[3] + catboost_preds[4]) / 5

# %%
ensemble_preds = 0.6 * final_catboost_preds + 0.4 * final_preds

# %%
ensemble_preds[:10], final_catboost_preds[:10], final_preds[:10]
# Out:
# (array([8.40583658, 4.58774964, 8.32465697, 7.18375788, 7.13135284,
#         9.67367649, 9.96252577, 5.89393404, 7.22270917, 7.53612671]),
#  array([8.67110053, 4.62450053, 8.6372614 , 7.22330665, 6.92239076,
#         9.70097104, 9.97590847, 5.72130089, 7.33351626, 7.44252341]),
#  array([8.00794  , 4.5326233, 7.85575  , 7.1244345, 7.444796 , 9.632734 ,
#         9.9424515, 6.1528835, 7.0564985, 7.6765313], dtype=float32))

# %%
final_ensemble_preds = 0.65 * final_catboost_preds + 0.35 * final_preds

# %%
final_ensemble_preds[:10], final_catboost_preds[:10], final_preds[:10]
# Out:
# (array([8.4389943 , 4.5923435 , 8.36373235, 7.18870129, 7.10523255,
#         9.67708804, 9.96419843, 5.87235472, 7.23656006, 7.52442615]),
#  array([8.67110053, 4.62450053, 8.6372614 , 7.22330665, 6.92239076,
#         9.70097104, 9.97590847, 5.72130089, 7.33351626, 7.44252341]),
#  array([8.00794  , 4.5326233, 7.85575  , 7.1244345, 7.444796 , 9.632734 ,
#         9.9424515, 6.1528835, 7.0564985, 7.6765313], dtype=float32))

# %%
sample_df.loc[:, 'loss'] = final_ensemble_preds

# %%
sample_df.head()
# Out:
#        id      loss
# 0  250000  8.438994
# 1  250001  4.592343
# 2  250002  8.363732
# 3  250003  7.188701
# 4  250004  7.105233

# %%
sample_df.to_csv('XGBoost0.35-Catboost0.65_ensemble_20210831_no_feature_gen.csv', index=False)

# %% [markdown]
# # Experiment - fitting model on full training set

# %%
# applying hold-out before scaling
# X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
#                                                       test_size=config['test_size'], 
#                                                       random_state=config['random_state']
#                                                      )
# scaling (i.e. normalizing)
scaler = config['scaler']()
X_s = scaler.fit_transform(X)
X_test_s = scaler.fit_transform(X_test)

# selecting features
selector = config['feature_selector'](score_func=config["feature_selection_scoring"], 
                                      k=config['k_best'])
X_fs = selector.fit_transform(X_s, y)
X_test_fs = X_test_s[:, selector.get_support()]

model = XGBRegressor(
    tree_method=config['tree_method'],
    booster=config['booster'],
    n_estimators=config['n_estimators'], 
    max_depth=config['max_depth'],
    learning_rate=config['learning_rate'], 
    test_size=config['test_size'],
    subsample=config['subsample'],
    random_state=config['random_state'],
    n_jobs=config['n_jobs'], 
    verbosity=config['verbosity'], 
)
#     wandb.log({'params': model.get_params()}) # logging model parameters
model.fit(X_fs, y)#, callbacks=[wandb.xgboost.wandb_callback()])
# Out:
# [12:11:15] WARNING: ../src/learner.cc:573:
# Parameters: { "test_size" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRegressor(base_score=0.5, booster='dart', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1522, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=400, n_jobs=-1, num_parallel_tree=1, random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              test_size=0.2, tree_method='auto', validate_parameters=1,
#              verbosity=1)

# %%
y_test_preds = model.predict(X_test_fs)
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
sample_df = pd.read_csv(datapath/'sample_submission.csv')

# %%
sample_df.loc[:, 'loss'] = y_test_preds

# %%
sample_df.head()
# Out:
#        id      loss
# 0  250000  8.027956
# 1  250001  4.305676
# 2  250002  7.300106
# 3  250003  6.988875
# 4  250004  7.316631

# %%
sample_df.to_csv('202108241211_XGBoost_fullset.csv', index=False)
