# %% [markdown]
# # Baseline
# Setting up a more robust baseline notebook, suitable for use with all of the "Big Three" (XGBoost, CatBoost, LightGBM) libraries and on either Google Colab or the local machine.

# %% [markdown]
# # Setup

# %%
# two manual flags (ex-config)
colab = False
gpu_available = False
libraries = ['xgboost', 'lightgbm', 'catboost']

# %%
# basic imports
from pathlib import Path
import os
import math
from datetime import datetime

# %%
# %matplotlib inline
# %config Completer.use_jedi = False
os.environ['WANDB_NOTEBOOK_NAME'] = f"baseline_{datetime.now().strftime('%Y%m%d')}.ipynb"

# %%
# handle Google Colab-specific library installation/updating
if colab:
    # much of the below inspired by or cribbed from the May 2021 Kaggle Tabular Playground winner, at 
    # https://colab.research.google.com/gist/academicsuspect/0aac7bd6e506f5f70295bfc9a3dc2250/tabular-may-baseline.ipynb?authuser=1#scrollTo=LJoVKJb5wN0L
    
    # Kaggle API for downloading the datasets
    # !pip install --upgrade -q kaggle

    # weights and biases
    # !pip install -qqqU wandb
    
    # Optuna for parameter search
    # !pip install -q optuna

    # upgrade sklearn
    # !pip install --upgrade scikit-learn

    # !pip install category_encoders
    
    if 'catboost' in libraries:
        # !pip install catboost
    
    if 'xgboost' in libraries:
        if gpu_available: 
            # this part is from https://github.com/rapidsai/gputreeshap/issues/24
            # !pip install cmake --upgrade
            # !pip install sklearn --upgrade
            # !git clone --recursive https://github.com/dmlc/xgboost
            # %cd /content/xgboost
            # !mkdir build
            # %cd build
            # !cmake .. -DUSE_CUDA=ON
            # !make -j4
            # %cd /content/xgboost/python-package
            # !python setup.py install --use-cuda --use-nccl
            # !/opt/bin/nvidia-smi
            # !pip install shap
        else:
            # !pip install --upgrade xgboost
    if 'lightgbm' in libraries:
        if gpu_available:
            # lighgbm gpu compatible
            # !git clone --recursive https://github.com/Microsoft/LightGBM
            ! cd LightGBM && rm -rf build && mkdir build && cd build && cmake -DUSE_GPU=1 ../../LightGBM && make -j4 && cd ../python-package && python3 setup.py install --precompile --gpu;
        else:
            # !pip install --upgrade lightgbm

# %% [markdown]
# Now, non-stdlib imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# general ML tooling
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import log_loss, roc_auc_score
import wandb
from wandb.xgboost import wandb_callback
from wandb.lightgbm import wandb_callback
from sklearn.impute import KNNImputer, SimpleImputer
# import timm

import seaborn as sns

from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
# from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MaxAbsScaler, StandardScaler, MinMaxScaler, RobustScaler, PolynomialFeatures
# from sklearn.feature_selection import SelectKBest, f_regression
from joblib import dump, load
# feature engineering tools
# from sklearn.feature_selection import mutual_info_regression
# import featuretools as ft
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# Now, datapath setup

# %%
# # This is the code for reading the train.csv and converting it to a .feather file
# df = pd.read_csv(datapath/'train.csv', index_col='id', low_memory=False)
# df.index.name = None
# df.to_feather(path='./dataset_df.feather')

# %%
if colab:
    # mount Google Drive
    from google.colab import drive
    drive.mount('/content/drive')
    
    # handling datapath
    datapath = Path('/content/drive/MyDrive/kaggle/tabular_playgrounds/sep2021/')
    
else:
    # if on local machine
    datapath = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/')

# %% [markdown]
# ## Ex-Model Config

# %%
# meta-config for preprocessing and cross-validation, but NOT for model parameters
exmodel_config = {
    # model config
#     "model": XGBClassifier,
#     "n_estimators": 100, 
#     "max_depth": 3,
#     "learning_rate": 0.1,
#     "test_size": 0.2,
#     "reg_lambda": None, 
    "scaler": StandardScaler, # TODO: experiment with others (but imputation may be slow)
    "scale_b4_impute": False,
    "imputer": SimpleImputer(strategy='median', add_indicator=True),
    "knn_imputer_n_neighbors": None, # None if a different imputer is used
#     "feature_selector": SelectKBest,
#     "k_best": 80,
#     "feature_selection_scoring": f_regression,
    'random_state': 42,
#     'subsample': 1,
    'cross_val_strategy': KFold, # None for holdout, or the relevant sklearn class
    'kfolds': 5, # if 1, that means just doing holdout
    'test_size': 0.2,
#     'features_created': False,
#     'feature_creator': None,
}

# %% [markdown]
# ## Data Setup

# %% [markdown]
# **TODO** Write some conditional logic here to automate it -- possibly as part of a sklearn.*pipeline

# %%
# if exmodel_config['scaler']:
#     scaler = exmodel_config['scaler']()
#     scaler.fit_transform()

# %%
# # here's how to load the original, unaltered dataset and separate features from targets
# df = pd.read_feather(path=datapath/'dataset_df.feather') # this is the unaltered original dataset
# features = [x for x in df.columns if x != 'claim']
# X = df[features]
# y = df.claim



# load the version of the dataset with imputations; X and y were stored separately, as feather and joblib respectively
X = pd.read_feather(datapath/'X_NaNcounts_imputed-Median-wIndicators-StandardScaled.feather') 
y = load(datapath/'y.joblib')    
X.index.name = 'id'
y.index.name = 'id'

exmodel_config['feature_count'] = len(X.columns)
exmodel_config['feature_generator'] = None

# %%
# scaler = exmodel_config['scaler']()
# X_scaled = scaler.fit_transform(X)
# X = pd.DataFrame(X_scaled, columns=X.columns)

# %%
X.head()
# Out:
#            0         1         2         3         4         5         6  \
# id
# 0   0.425545 -2.357891 -0.637206 -0.866657 -0.111568 -4.829243 -1.171229
# 1   0.247600 -0.323982  1.223569  0.361863  1.071182 -0.361140  0.082051
# 2   2.032371 -2.435680 -0.488960  0.341193  1.069656  0.118532  0.537069
# 3   1.438373 -2.337605 -0.508914 -0.829607  1.485682  3.592008 -1.189087
# 4   0.602333  1.076218 -0.648438  0.463365  0.275053 -0.157989  0.727338
#
#            7         8         9  ...       227       228       229       230  \
# id                                ...
# 0  -0.603397 -0.596871 -0.516828  ... -0.128368 -0.127677 -0.128242 -0.127867
# 1  -0.746590  0.899454  0.469668  ... -0.128368 -0.127677 -0.128242 -0.127867
# 2  -0.044075 -0.763516  1.056879  ... -0.128368 -0.127677 -0.128242 -0.127867
# 3  -0.339152 -0.735281 -0.529158  ... -0.128368 -0.127677 -0.128242 -0.127867
# 4  -0.905498  0.052478 -0.511066  ... -0.128368 -0.127677 -0.128242 -0.127867
#
#          231       232       233      234       235      236
# id
# 0  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 1  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 2  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 3  -0.127119 -0.127985 -0.128494 -0.12862 -0.127854 -0.12703
# 4  -0.127119 -0.127985 -0.128494 -0.12862  7.821398 -0.12703
#
# [5 rows x 237 columns]

# %%
y.head()
# Out:
# id
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: claim, dtype: int64

# %% [markdown]
# ### Model Config

# %%
def model_configurator(library, gpu_available=True):#, config=universal_config):
    """
    Function that provide task-specific or general preference arguments for the various models. 
    
    At first, will rely largely on defaults for hyperparameters, but later this function 
    can be supplemented later with optimal values, as they're learned in sweeps.
    .
    
    Rationale: creating a helper function will allow more experimentation later, and also
    composite runs that cycle through a series of models.
    
    :param model: A model from [XGBClassifier, LGBMClassifier, CatBoostClassifier]
    :return config: A dict that supplements default hyperparameter values with 1) 
                    task-appropriate ones, and perhaps later 2) optimal hyperparameter values.
    """
    config = {}
    
    # library-specific config
    if library in ['xgboost', 'lightgbm']:
        config['n_jobs'] = -1
        
    # best params per sweep `icac24c5`, generated from notebook `sweep_20210905.ipynb`
    # runtime per fold should be around 12m 38s
    # should get auc of 0.7434 on the random_state=42 holdout
    # haven't yet tried dart
    if library == 'xgboost':
#         config['tree_method'] = 'auto'
#         config['booster'] = 'gbtree' # or 'dart'
#         config['model'] = XGBClassifier
        config['verbosity'] = 1
        config['objective'] = 'binary:logistic'
#         config['eval_metric'] = ['auc', 'logloss', 'aucpr'],
        config['tree_method'] = 'gpu_hist' if (gpu_available and colab) else 'auto' 
        
        # comment out the below to get defaults
        config['n_estimators'] = 902
        config['learning_rate'] = 0.0304
        config['max_depth'] = 3
        config['reg_alpha'] = 0.863
        config['reg_lambda'] = 2.442
        config['subsample'] = 0.8627

    # best params per sweep `sjghewf0`, generated from notebook `sweep_lightgbm_20210907`
    # run name `sweep_lightgbm_20210907_195641`
    # runtime per fold should be around 39s
    # should get an auc of 0.7435 on random_state=42 holdout
    if library == 'lightgbm':
#         config['model'] = LGBMClassifier
        config['objective'] = 'binary'
        config['eval_metric'] = ['auc', 'logloss']
        config['boosting_type'] = 'gbdt' # or 'dart'
        config['device_type'] = 'cuda' if (gpu_available and colab) else 'cpu' # 'gpu' also possible, 'cpu' is default
        
        # comment out the below for defaults
        config['n_estimators'] = 1286
        config['learning_rate'] = 0.03221
        config['max_depth'] = 2
        config['reg_alpha'] = 0.4687
        config['reg_lambda'] = 0.1763
        config['subsample'] = 0.6621
        

#     if config['model'] == CatBoostClassifier:
    if library == 'catboost':
#         config['model'] = CatBoostClassifier
        config['task_type'] = 'GPU' if gpu_available else 'CPU'
        config['custom_metrics'] = ['Logloss', 'AUC'] # objective (loss fn) must be singular, defaults to Logloss
        config['n_estimators'] = 2000 # logged as "iterations" otherwise

    return config

# %% [markdown]
# ## Weights and Biases Run Config

# %% [markdown]
# Below is the configuration for a Weights and Biases (`wandb`) run.

# %%
# wandb config:
config_run = {
    'name': f"{os.environ['WANDB_NOTEBOOK_NAME'][:-6]}_{datetime.now().strftime('%H%M%S')}", # just removes the .ipynb extension, leaving the notebook filename's stem
    'tags': ['attempt'],
    'notes': "Attempting sweep-best XGBoost and LightGBM plus defaultish CatBoost on newly preprocessed data (with a column containing NaN counts, median imputation w/indicators, and standard scaling)",
}

# %% [markdown]
# # Preprocessing
# Scaling has already occurred -- used `StandardScaler` as a precursor to using `KNNImputer(n_neighbors=5)`, on the premise that imputation would proceed more quickly if things were already scaled. I may try different permutations of this later: using `IterativeImputer` instead, before or after scaling, potentially with different scalers.

# %% [markdown]
# # Feature Creation and Selection

# %%
# load all the polynomialfeatures generated with `PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)`
# X_np = np.load(datapath/'X_poly_unscaled.npy')
# X = pd.DataFrame(X_np)

# %%
# X.columns

# %%
# generation polynomial features
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_poly = poly.fit_transform(X)

# %%
# X_poly_names = poly.get_feature_names(X.columns)
# # X_poly_names[100:150]
# features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
# checks = [feature in X_poly_names for feature in features]
# checks

# %%
# X = pd.DataFrame(X_poly, columns=X_poly_names)

# %%
# X = X[features[1:]]

# %% [markdown]
# # Training

# %%
def train(X_train, X_valid, y_train, y_valid, model_config, 
                                              random_state=42,
                                              exmodel_config=exmodel_config, 
                                              config_run=config_run):#, scaler): # passed in via config dict for now
    """
    Basic training function. Note that some of the options passed via the argument are
    in fact hard-coded in, to avoid inconveniences.
    :param X_train: the training set features
    :param X_valid: the validation set features
    :param y_train: the training set targets
    :param y_valid: the validation set targets
    :param random_staKFold: for reproducibility
    :param exmodel_config: dict containing configuration details including the library 
                            (thus model) used, preprocessing, and cross-validation
    :param model_config: dict containing hyperparameter specifications for the model
    :param config_run: dict containing wandb run configuration (name, etc)
    """
    
    
    wandb.init(
        project="202109_Kaggle_tabular_playground",
        save_code=True,
        tags=config_run['tags'],
        name=config_run['name'],
        notes=config_run['notes'],
        config=exmodel_config)   
        
    if exmodel_config['library'] == 'xgboost':
        model = XGBClassifier(
            tree_method=model_config['tree_method'],
            random_state=random_state,
            n_jobs=model_config['n_jobs'], 
            verbosity=model_config['verbosity'], 
            objective=model_config['objective'],
            # #             eval_metric=model_config['eval_metric'],

            # comment out the below for a fairly default model
#             booster=model_config['booster'],
            max_depth=model_config['max_depth'],
            learning_rate=model_config['learning_rate'], 
            subsample=model_config['subsample'],
            reg_alpha=model_config['reg_alpha'],
            reg_lambda=model_config['reg_lambda'],
            n_estimators=model_config['n_estimators'],
        )
        
        model.fit(X_train, y_train, callbacks=[wandb.xgboost.wandb_callback()],
#                                     eval_metric=model_config['eval_metric'],
                 )


    elif exmodel_config['library'] == 'lightgbm':
        model = LGBMClassifier(
#             boosting_type=model_config['boosting_type'],
#             max_depth=model_config['max_depth']
            # TODO
            random_state=random_state,
            n_jobs=model_config['n_jobs'],
            objective=model_config['objective'],
#             eval_metric=model_config['eval_metric'],
            boosting_type=model_config['boosting_type'],
            device_type=model_config['device_type'],
            
            # comment out the below for a basically default model
            n_estimators=model_config['n_estimators'],
            learning_rate=model_config['learning_rate'],
            max_depth=model_config['max_depth'],
            reg_alpha=model_config['reg_alpha'],
            reg_lambda=model_config['reg_lambda'],
            subsample=model_config['subsample'],
        )
        
        model.fit(X_train, y_train, callbacks=[wandb.lightgbm.wandb_callback()],
#                                     eval_metric=model_config['eval_metric'],
                 )
        
    elif exmodel_config['library'] == 'catboost':
        print("CatBoost, therefore no WandB callback.")
        model = CatBoostClassifier(
#             n_estimators=config['n_estimators'],
#             learning_rate=config['learning_rate'],
#             max_depth=config['max_depth'],
            task_type=model_config['task_type'],
    #         n_jobs=config['n_jobs'],
    #         verbosity=config['verbosity'],
    #         subsample=config['subsample'],
            n_estimators=model_config['n_estimators'],
            random_state=random_state,
            # objective='Logloss', # default, accepts only one
#             custom_metrics=model_config['custom_metrics'],
    #         bootstrap_type=config['bootstrap_type'],
    #         device:config['device']
        ) 
        model.fit(X_train, y_train)
    y_train_pred = model.predict(X_train)
    train_loss = log_loss(y_train, y_train_pred)
    train_auc = roc_auc_score(y_train, y_train_pred)
    wandb.log({'train_loss': train_loss, 'train_auc': train_auc})

    if exmodel_config['library'] == 'catboost':
        print(model.get_all_params())
        wandb.log(model.get_all_params())
    else:
        wandb.log(model.get_params()) # logging model parameters, trying bare-invocation rather than params: model.get_params()
    
    y_pred = model.predict(X_valid)
#     mse = mean_squared_error(y_valid, y_pred)
#     rmse = math.sqrt(abs(mse))
    valid_loss = log_loss(y_valid, y_pred)
    valid_auc = roc_auc_score(y_valid, y_pred)
    wandb.log({'valid_loss':valid_loss, 'valid_auc':valid_auc})
    print(f"Valid log-loss is {valid_loss}\nValid AUC is {valid_auc}")   
#     wandb.finish()   
    return model

# %%
def cross_validation(model_config, X=X, y=y, start_fold=0, exmodel_config=exmodel_config, random_state=42):
    """
    Function to handle model training process in the context of cross-validation -- via hold-out or via k-fold.
    If exmodel_config['cross_val_strategy'] == None, then any kfolds= input is ignored; otherwise, the number specified is used.
    
    :param kfolds: int specifying number of k-folds to use in cross-validation
    :param exmodel_config: dict containing general config including for cross-validation -- `kfold=1` implies hold-out
    """
    if exmodel_config['kfolds'] == 1:
        print("Proceeding with holdout")
        X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
                                                      test_size=exmodel_config['test_size'], 
                                                      random_state=random_state,
                                                     )
        model = train(X_train, X_valid, y_train, y_valid, exmodel_config=exmodel_config, 
                                                    model_config=model_config,
                                                    config_run=config_run)
        wandb.finish()
        
    else:
        X, y = X.to_numpy(), y.to_numpy()
        kfold = exmodel_config['cross_val_strategy'](n_splits=exmodel_config['kfolds'], shuffle=True, random_state=random_state)
        models = {}
        model_path = Path(datapath/f"models/{config_run['name']}_{exmodel_config['kfolds']}folds/")
        (model_path).mkdir(exist_ok=True)
        for fold, (train_ids, valid_ids) in enumerate(kfold.split(X,y)):
            if fold < start_fold:
                continue
            else:
                print(f"FOLD {fold}")
                print("---------------------------------------------------")
                X_train, X_valid = X[train_ids], X[valid_ids]
                y_train, y_valid = y[train_ids], y[valid_ids]
                model = train(X_train, X_valid, y_train, y_valid, exmodel_config=exmodel_config, 
                                                    model_config=model_config,
                                                    config_run=config_run)
                wandb.log({'fold': fold})
                models[fold] = model
                dump(model, Path(model_path/f"{exmodel_config['library']}_fold{fold}_model.joblib"))
                wandb.finish()
        return models

# %% [markdown]
# # Interface

# %% [markdown]
# ## Runs

# %%
library = 'xgboost'
exmodel_config['library'] = library
model_config = model_configurator(library)
xgboost_models = cross_validation(model_config)
# Out:
# FOLD 0
# ---------------------------------------------------
# wandb: Currently logged in as: hushifang (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">baseline_20210909_114059</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1kwg14p8" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1kwg14p8</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_114100-1kwg14p8</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# Valid log-loss is 7.892441549599787
# Valid AUC is 0.7719570110083699
# <br/>Waiting for W&B process to finish, PID 1308572<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.09MB of 0.09MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_114100-1kwg14p8/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_114100-1kwg14p8/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>7.81863</td></tr><tr><td>train_auc</td><td>0.77398</td></tr><tr><td>_runtime</td><td>511</td></tr><tr><td>_timestamp</td><td>1631213371</td></tr><tr><td>_step</td><td>905</td></tr><tr><td>objective</td><td>binary:logistic</td></tr><tr><td>use_label_encoder</td><td>True</td></tr><tr><td>base_score</td><td>0.5</td></tr><tr><td>booster</td><td>gbtree</td></tr><tr><td>colsample_bylevel</td><td>1</td></tr><tr><td>colsample_bynode</td><td>1</td></tr><tr><td>colsample_bytree</td><td>1</td></tr><tr><td>gamma</td><td>0</td></tr><tr><td>gpu_id</td><td>-1</td></tr><tr><td>importance_type</td><td>gain</td></tr><tr><td>learning_rate</td><td>0.0304</td></tr><tr><td>max_delta_step</td><td>0</td></tr><tr><td>max_depth</td><td>3</td></tr><tr><td>min_child_weight</td><td>1</td></tr><tr><td>missing</td><td>nan</td></tr><tr><td>monotone_constraints</td><td>()</td></tr><tr><td>n_estimators</td><td>902</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_parallel_tree</td><td>1</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.863</td></tr><tr><td>reg_lambda</td><td>2.442</td></tr><tr><td>scale_pos_weight</td><td>1</td></tr><tr><td>subsample</td><td>0.8627</td></tr><tr><td>tree_method</td><td>auto</td></tr><tr><td>validate_parameters</td><td>1</td></tr><tr><td>verbosity</td><td>1</td></tr><tr><td>valid_loss</td><td>7.89244</td></tr><tr><td>valid_auc</td><td>0.77196</td></tr><tr><td>fold</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁</td></tr><tr><td>_timestamp</td><td>▁▁▁▁</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>use_label_encoder</td><td>▁</td></tr><tr><td>base_score</td><td>▁</td></tr><tr><td>colsample_bylevel</td><td>▁</td></tr><tr><td>colsample_bynode</td><td>▁</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>gamma</td><td>▁</td></tr><tr><td>gpu_id</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_delta_step</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>missing</td><td></td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_parallel_tree</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>scale_pos_weight</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>validate_parameters</td><td>▁</td></tr><tr><td>verbosity</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">baseline_20210909_114059</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1kwg14p8" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1kwg14p8</a><br/>
# FOLD 1
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">baseline_20210909_114059</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/ooen6s3f" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/ooen6s3f</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_114939-ooen6s3f</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# Valid log-loss is 7.84881346031584
# Valid AUC is 0.7734460504519363
# <br/>Waiting for W&B process to finish, PID 1309556<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.10MB of 0.10MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_114939-ooen6s3f/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_114939-ooen6s3f/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>7.82823</td></tr><tr><td>train_auc</td><td>0.77364</td></tr><tr><td>_runtime</td><td>499</td></tr><tr><td>_timestamp</td><td>1631213878</td></tr><tr><td>_step</td><td>905</td></tr><tr><td>objective</td><td>binary:logistic</td></tr><tr><td>use_label_encoder</td><td>True</td></tr><tr><td>base_score</td><td>0.5</td></tr><tr><td>booster</td><td>gbtree</td></tr><tr><td>colsample_bylevel</td><td>1</td></tr><tr><td>colsample_bynode</td><td>1</td></tr><tr><td>colsample_bytree</td><td>1</td></tr><tr><td>gamma</td><td>0</td></tr><tr><td>gpu_id</td><td>-1</td></tr><tr><td>importance_type</td><td>gain</td></tr><tr><td>learning_rate</td><td>0.0304</td></tr><tr><td>max_delta_step</td><td>0</td></tr><tr><td>max_depth</td><td>3</td></tr><tr><td>min_child_weight</td><td>1</td></tr><tr><td>missing</td><td>nan</td></tr><tr><td>monotone_constraints</td><td>()</td></tr><tr><td>n_estimators</td><td>902</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_parallel_tree</td><td>1</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.863</td></tr><tr><td>reg_lambda</td><td>2.442</td></tr><tr><td>scale_pos_weight</td><td>1</td></tr><tr><td>subsample</td><td>0.8627</td></tr><tr><td>tree_method</td><td>auto</td></tr><tr><td>validate_parameters</td><td>1</td></tr><tr><td>verbosity</td><td>1</td></tr><tr><td>valid_loss</td><td>7.84881</td></tr><tr><td>valid_auc</td><td>0.77345</td></tr><tr><td>fold</td><td>1</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁██</td></tr><tr><td>_timestamp</td><td>▁▁██</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>use_label_encoder</td><td>▁</td></tr><tr><td>base_score</td><td>▁</td></tr><tr><td>colsample_bylevel</td><td>▁</td></tr><tr><td>colsample_bynode</td><td>▁</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>gamma</td><td>▁</td></tr><tr><td>gpu_id</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_delta_step</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>missing</td><td></td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_parallel_tree</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>scale_pos_weight</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>validate_parameters</td><td>▁</td></tr><tr><td>verbosity</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">baseline_20210909_114059</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/ooen6s3f" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/ooen6s3f</a><br/>
# FOLD 2
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">baseline_20210909_114059</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/10l1db7u" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/10l1db7u</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_115805-10l1db7u</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# Valid log-loss is 7.847370497743209
# Valid AUC is 0.7729471738635041
# <br/>Waiting for W&B process to finish, PID 1310540<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.11MB of 0.11MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_115805-10l1db7u/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_115805-10l1db7u/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>7.82624</td></tr><tr><td>train_auc</td><td>0.77384</td></tr><tr><td>_runtime</td><td>511</td></tr><tr><td>_timestamp</td><td>1631214396</td></tr><tr><td>_step</td><td>905</td></tr><tr><td>objective</td><td>binary:logistic</td></tr><tr><td>use_label_encoder</td><td>True</td></tr><tr><td>base_score</td><td>0.5</td></tr><tr><td>booster</td><td>gbtree</td></tr><tr><td>colsample_bylevel</td><td>1</td></tr><tr><td>colsample_bynode</td><td>1</td></tr><tr><td>colsample_bytree</td><td>1</td></tr><tr><td>gamma</td><td>0</td></tr><tr><td>gpu_id</td><td>-1</td></tr><tr><td>importance_type</td><td>gain</td></tr><tr><td>learning_rate</td><td>0.0304</td></tr><tr><td>max_delta_step</td><td>0</td></tr><tr><td>max_depth</td><td>3</td></tr><tr><td>min_child_weight</td><td>1</td></tr><tr><td>missing</td><td>nan</td></tr><tr><td>monotone_constraints</td><td>()</td></tr><tr><td>n_estimators</td><td>902</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_parallel_tree</td><td>1</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.863</td></tr><tr><td>reg_lambda</td><td>2.442</td></tr><tr><td>scale_pos_weight</td><td>1</td></tr><tr><td>subsample</td><td>0.8627</td></tr><tr><td>tree_method</td><td>auto</td></tr><tr><td>validate_parameters</td><td>1</td></tr><tr><td>verbosity</td><td>1</td></tr><tr><td>valid_loss</td><td>7.84737</td></tr><tr><td>valid_auc</td><td>0.77295</td></tr><tr><td>fold</td><td>2</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁</td></tr><tr><td>_timestamp</td><td>▁▁▁▁</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>use_label_encoder</td><td>▁</td></tr><tr><td>base_score</td><td>▁</td></tr><tr><td>colsample_bylevel</td><td>▁</td></tr><tr><td>colsample_bynode</td><td>▁</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>gamma</td><td>▁</td></tr><tr><td>gpu_id</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_delta_step</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>missing</td><td></td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_parallel_tree</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>scale_pos_weight</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>validate_parameters</td><td>▁</td></tr><tr><td>verbosity</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">baseline_20210909_114059</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/10l1db7u" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/10l1db7u</a><br/>
# FOLD 3
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">baseline_20210909_114059</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3tc5dp9k" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3tc5dp9k</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_120643-3tc5dp9k</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# Valid log-loss is 7.821770148068287
# Valid AUC is 0.7737140306426393
# <br/>Waiting for W&B process to finish, PID 1311570<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.11MB of 0.11MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_120643-3tc5dp9k/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_120643-3tc5dp9k/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>7.83314</td></tr><tr><td>train_auc</td><td>0.77363</td></tr><tr><td>_runtime</td><td>506</td></tr><tr><td>_timestamp</td><td>1631214909</td></tr><tr><td>_step</td><td>905</td></tr><tr><td>objective</td><td>binary:logistic</td></tr><tr><td>use_label_encoder</td><td>True</td></tr><tr><td>base_score</td><td>0.5</td></tr><tr><td>booster</td><td>gbtree</td></tr><tr><td>colsample_bylevel</td><td>1</td></tr><tr><td>colsample_bynode</td><td>1</td></tr><tr><td>colsample_bytree</td><td>1</td></tr><tr><td>gamma</td><td>0</td></tr><tr><td>gpu_id</td><td>-1</td></tr><tr><td>importance_type</td><td>gain</td></tr><tr><td>learning_rate</td><td>0.0304</td></tr><tr><td>max_delta_step</td><td>0</td></tr><tr><td>max_depth</td><td>3</td></tr><tr><td>min_child_weight</td><td>1</td></tr><tr><td>missing</td><td>nan</td></tr><tr><td>monotone_constraints</td><td>()</td></tr><tr><td>n_estimators</td><td>902</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_parallel_tree</td><td>1</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.863</td></tr><tr><td>reg_lambda</td><td>2.442</td></tr><tr><td>scale_pos_weight</td><td>1</td></tr><tr><td>subsample</td><td>0.8627</td></tr><tr><td>tree_method</td><td>auto</td></tr><tr><td>validate_parameters</td><td>1</td></tr><tr><td>verbosity</td><td>1</td></tr><tr><td>valid_loss</td><td>7.82177</td></tr><tr><td>valid_auc</td><td>0.77371</td></tr><tr><td>fold</td><td>3</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁</td></tr><tr><td>_timestamp</td><td>▁▁▁▁</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>use_label_encoder</td><td>▁</td></tr><tr><td>base_score</td><td>▁</td></tr><tr><td>colsample_bylevel</td><td>▁</td></tr><tr><td>colsample_bynode</td><td>▁</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>gamma</td><td>▁</td></tr><tr><td>gpu_id</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_delta_step</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>missing</td><td></td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_parallel_tree</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>scale_pos_weight</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>validate_parameters</td><td>▁</td></tr><tr><td>verbosity</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">baseline_20210909_114059</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3tc5dp9k" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3tc5dp9k</a><br/>
# FOLD 4
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">baseline_20210909_114059</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/11s05l5z" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/11s05l5z</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_121515-11s05l5z</code><br/><br/>
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/training.py:17: UserWarning: Old style callback is deprecated.  See: https://xgboost.readthedocs.io/en/latest/python/callbacks.html
#   warnings.warn(f'Old style callback is deprecated.  See: {link}', UserWarning)
# Valid log-loss is 7.8133382685762625
# Valid AUC is 0.7741597681462388
# <br/>Waiting for W&B process to finish, PID 1312597<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.12MB of 0.12MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_121515-11s05l5z/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_121515-11s05l5z/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>7.83489</td></tr><tr><td>train_auc</td><td>0.77353</td></tr><tr><td>_runtime</td><td>550</td></tr><tr><td>_timestamp</td><td>1631215465</td></tr><tr><td>_step</td><td>905</td></tr><tr><td>objective</td><td>binary:logistic</td></tr><tr><td>use_label_encoder</td><td>True</td></tr><tr><td>base_score</td><td>0.5</td></tr><tr><td>booster</td><td>gbtree</td></tr><tr><td>colsample_bylevel</td><td>1</td></tr><tr><td>colsample_bynode</td><td>1</td></tr><tr><td>colsample_bytree</td><td>1</td></tr><tr><td>gamma</td><td>0</td></tr><tr><td>gpu_id</td><td>-1</td></tr><tr><td>importance_type</td><td>gain</td></tr><tr><td>learning_rate</td><td>0.0304</td></tr><tr><td>max_delta_step</td><td>0</td></tr><tr><td>max_depth</td><td>3</td></tr><tr><td>min_child_weight</td><td>1</td></tr><tr><td>missing</td><td>nan</td></tr><tr><td>monotone_constraints</td><td>()</td></tr><tr><td>n_estimators</td><td>902</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_parallel_tree</td><td>1</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.863</td></tr><tr><td>reg_lambda</td><td>2.442</td></tr><tr><td>scale_pos_weight</td><td>1</td></tr><tr><td>subsample</td><td>0.8627</td></tr><tr><td>tree_method</td><td>auto</td></tr><tr><td>validate_parameters</td><td>1</td></tr><tr><td>verbosity</td><td>1</td></tr><tr><td>valid_loss</td><td>7.81334</td></tr><tr><td>valid_auc</td><td>0.77416</td></tr><tr><td>fold</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁██</td></tr><tr><td>_timestamp</td><td>▁▁██</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>use_label_encoder</td><td>▁</td></tr><tr><td>base_score</td><td>▁</td></tr><tr><td>colsample_bylevel</td><td>▁</td></tr><tr><td>colsample_bynode</td><td>▁</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>gamma</td><td>▁</td></tr><tr><td>gpu_id</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_delta_step</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>missing</td><td></td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_parallel_tree</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>scale_pos_weight</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>validate_parameters</td><td>▁</td></tr><tr><td>verbosity</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">baseline_20210909_114059</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/11s05l5z" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/11s05l5z</a><br/>

# %%
# for scaler in [StandardScaler, MaxAbsScaler, MinMaxScaler, RobustScaler]:
#     exmodel_config['scaler'] = scaler
#     scaler = scaler()
#     X_scaled = scaler.fit_transform(X)
#     X = pd.DataFrame(X_scaled, columns=X.columns)
#     exmodel_config['library'] = 'lightgbm'
#     model_config = model_configurator('lightgbm')
#     cross_validation(model_config)

# %%
# library = 'xgboost'
# exmodel_config['library'] = library
# model_config = model_configurator(library)
# xgboost_models = cross_validation(model_config)

library = 'lightgbm'
exmodel_config['library'] = library
model_config = model_configurator(library)
lightgbm_models = cross_validation(model_config)
# Out:
# FOLD 0
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">baseline_20210909_114059</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3bqejkc2" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3bqejkc2</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122437-3bqejkc2</code><br/><br/>
# Valid log-loss is 7.895687212677736
# Valid AUC is 0.7718685639683389
# <br/>Waiting for W&B process to finish, PID 1313691<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.12MB of 0.12MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122437-3bqejkc2/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122437-3bqejkc2/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>7.83224</td></tr><tr><td>train_auc</td><td>0.77359</td></tr><tr><td>_runtime</td><td>48</td></tr><tr><td>_timestamp</td><td>1631215525</td></tr><tr><td>_step</td><td>1289</td></tr><tr><td>boosting_type</td><td>gbdt</td></tr><tr><td>colsample_bytree</td><td>1.0</td></tr><tr><td>importance_type</td><td>split</td></tr><tr><td>learning_rate</td><td>0.03221</td></tr><tr><td>max_depth</td><td>2</td></tr><tr><td>min_child_samples</td><td>20</td></tr><tr><td>min_child_weight</td><td>0.001</td></tr><tr><td>min_split_gain</td><td>0.0</td></tr><tr><td>n_estimators</td><td>1286</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_leaves</td><td>31</td></tr><tr><td>objective</td><td>binary</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.4687</td></tr><tr><td>reg_lambda</td><td>0.1763</td></tr><tr><td>silent</td><td>True</td></tr><tr><td>subsample</td><td>0.6621</td></tr><tr><td>subsample_for_bin</td><td>200000</td></tr><tr><td>subsample_freq</td><td>0</td></tr><tr><td>device_type</td><td>cpu</td></tr><tr><td>valid_loss</td><td>7.89569</td></tr><tr><td>valid_auc</td><td>0.77187</td></tr><tr><td>fold</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁██</td></tr><tr><td>_timestamp</td><td>▁▁██</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_samples</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>min_split_gain</td><td>▁</td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_leaves</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>silent</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>subsample_for_bin</td><td>▁</td></tr><tr><td>subsample_freq</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">baseline_20210909_114059</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3bqejkc2" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/3bqejkc2</a><br/>
# FOLD 1
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">baseline_20210909_114059</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/cb8k4jyq" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/cb8k4jyq</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122538-cb8k4jyq</code><br/><br/>
# Valid log-loss is 7.859270380338852
# Valid AUC is 0.7731510852797842
# <br/>Waiting for W&B process to finish, PID 1313885<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.13MB of 0.13MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.99549287160…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122538-cb8k4jyq/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122538-cb8k4jyq/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>7.84387</td></tr><tr><td>train_auc</td><td>0.77319</td></tr><tr><td>_runtime</td><td>45</td></tr><tr><td>_timestamp</td><td>1631215583</td></tr><tr><td>_step</td><td>1289</td></tr><tr><td>boosting_type</td><td>gbdt</td></tr><tr><td>colsample_bytree</td><td>1.0</td></tr><tr><td>importance_type</td><td>split</td></tr><tr><td>learning_rate</td><td>0.03221</td></tr><tr><td>max_depth</td><td>2</td></tr><tr><td>min_child_samples</td><td>20</td></tr><tr><td>min_child_weight</td><td>0.001</td></tr><tr><td>min_split_gain</td><td>0.0</td></tr><tr><td>n_estimators</td><td>1286</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_leaves</td><td>31</td></tr><tr><td>objective</td><td>binary</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.4687</td></tr><tr><td>reg_lambda</td><td>0.1763</td></tr><tr><td>silent</td><td>True</td></tr><tr><td>subsample</td><td>0.6621</td></tr><tr><td>subsample_for_bin</td><td>200000</td></tr><tr><td>subsample_freq</td><td>0</td></tr><tr><td>device_type</td><td>cpu</td></tr><tr><td>valid_loss</td><td>7.85927</td></tr><tr><td>valid_auc</td><td>0.77315</td></tr><tr><td>fold</td><td>1</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁</td></tr><tr><td>_timestamp</td><td>▁▁▁▁</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_samples</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>min_split_gain</td><td>▁</td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_leaves</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>silent</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>subsample_for_bin</td><td>▁</td></tr><tr><td>subsample_freq</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">baseline_20210909_114059</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/cb8k4jyq" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/cb8k4jyq</a><br/>
# FOLD 2
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">baseline_20210909_114059</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1oipnjrq" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1oipnjrq</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122758-1oipnjrq</code><br/><br/>
# Valid log-loss is 7.853861151947448
# Valid AUC is 0.7727607707996527
# <br/>Waiting for W&B process to finish, PID 1314173<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.14MB of 0.14MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122758-1oipnjrq/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122758-1oipnjrq/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>7.84283</td></tr><tr><td>train_auc</td><td>0.77336</td></tr><tr><td>_runtime</td><td>46</td></tr><tr><td>_timestamp</td><td>1631215724</td></tr><tr><td>_step</td><td>1289</td></tr><tr><td>boosting_type</td><td>gbdt</td></tr><tr><td>colsample_bytree</td><td>1.0</td></tr><tr><td>importance_type</td><td>split</td></tr><tr><td>learning_rate</td><td>0.03221</td></tr><tr><td>max_depth</td><td>2</td></tr><tr><td>min_child_samples</td><td>20</td></tr><tr><td>min_child_weight</td><td>0.001</td></tr><tr><td>min_split_gain</td><td>0.0</td></tr><tr><td>n_estimators</td><td>1286</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_leaves</td><td>31</td></tr><tr><td>objective</td><td>binary</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.4687</td></tr><tr><td>reg_lambda</td><td>0.1763</td></tr><tr><td>silent</td><td>True</td></tr><tr><td>subsample</td><td>0.6621</td></tr><tr><td>subsample_for_bin</td><td>200000</td></tr><tr><td>subsample_freq</td><td>0</td></tr><tr><td>device_type</td><td>cpu</td></tr><tr><td>valid_loss</td><td>7.85386</td></tr><tr><td>valid_auc</td><td>0.77276</td></tr><tr><td>fold</td><td>2</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁██</td></tr><tr><td>_timestamp</td><td>▁▁██</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_samples</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>min_split_gain</td><td>▁</td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_leaves</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>silent</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>subsample_for_bin</td><td>▁</td></tr><tr><td>subsample_freq</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">baseline_20210909_114059</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1oipnjrq" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1oipnjrq</a><br/>
# FOLD 3
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">baseline_20210909_114059</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/gsgcija7" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/gsgcija7</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122850-gsgcija7</code><br/><br/>
# Valid log-loss is 7.820689031102799
# Valid AUC is 0.7737474089170715
# <br/>Waiting for W&B process to finish, PID 1314304<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.14MB of 0.14MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122850-gsgcija7/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122850-gsgcija7/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>7.85121</td></tr><tr><td>train_auc</td><td>0.77311</td></tr><tr><td>_runtime</td><td>45</td></tr><tr><td>_timestamp</td><td>1631215776</td></tr><tr><td>_step</td><td>1289</td></tr><tr><td>boosting_type</td><td>gbdt</td></tr><tr><td>colsample_bytree</td><td>1.0</td></tr><tr><td>importance_type</td><td>split</td></tr><tr><td>learning_rate</td><td>0.03221</td></tr><tr><td>max_depth</td><td>2</td></tr><tr><td>min_child_samples</td><td>20</td></tr><tr><td>min_child_weight</td><td>0.001</td></tr><tr><td>min_split_gain</td><td>0.0</td></tr><tr><td>n_estimators</td><td>1286</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_leaves</td><td>31</td></tr><tr><td>objective</td><td>binary</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.4687</td></tr><tr><td>reg_lambda</td><td>0.1763</td></tr><tr><td>silent</td><td>True</td></tr><tr><td>subsample</td><td>0.6621</td></tr><tr><td>subsample_for_bin</td><td>200000</td></tr><tr><td>subsample_freq</td><td>0</td></tr><tr><td>device_type</td><td>cpu</td></tr><tr><td>valid_loss</td><td>7.82069</td></tr><tr><td>valid_auc</td><td>0.77375</td></tr><tr><td>fold</td><td>3</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁</td></tr><tr><td>_timestamp</td><td>▁▁▁▁</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_samples</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>min_split_gain</td><td>▁</td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_leaves</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>silent</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>subsample_for_bin</td><td>▁</td></tr><tr><td>subsample_freq</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">baseline_20210909_114059</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/gsgcija7" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/gsgcija7</a><br/>
# FOLD 4
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">baseline_20210909_114059</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/mbc0qnit" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/mbc0qnit</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122942-mbc0qnit</code><br/><br/>
# Valid log-loss is 7.81712476240467
# Valid AUC is 0.7740543601938836
# <br/>Waiting for W&B process to finish, PID 1314435<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.15MB of 0.15MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122942-mbc0qnit/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_122942-mbc0qnit/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>7.85233</td></tr><tr><td>train_auc</td><td>0.77303</td></tr><tr><td>_runtime</td><td>50</td></tr><tr><td>_timestamp</td><td>1631215832</td></tr><tr><td>_step</td><td>1289</td></tr><tr><td>boosting_type</td><td>gbdt</td></tr><tr><td>colsample_bytree</td><td>1.0</td></tr><tr><td>importance_type</td><td>split</td></tr><tr><td>learning_rate</td><td>0.03221</td></tr><tr><td>max_depth</td><td>2</td></tr><tr><td>min_child_samples</td><td>20</td></tr><tr><td>min_child_weight</td><td>0.001</td></tr><tr><td>min_split_gain</td><td>0.0</td></tr><tr><td>n_estimators</td><td>1286</td></tr><tr><td>n_jobs</td><td>-1</td></tr><tr><td>num_leaves</td><td>31</td></tr><tr><td>objective</td><td>binary</td></tr><tr><td>random_state</td><td>42</td></tr><tr><td>reg_alpha</td><td>0.4687</td></tr><tr><td>reg_lambda</td><td>0.1763</td></tr><tr><td>silent</td><td>True</td></tr><tr><td>subsample</td><td>0.6621</td></tr><tr><td>subsample_for_bin</td><td>200000</td></tr><tr><td>subsample_freq</td><td>0</td></tr><tr><td>device_type</td><td>cpu</td></tr><tr><td>valid_loss</td><td>7.81712</td></tr><tr><td>valid_auc</td><td>0.77405</td></tr><tr><td>fold</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁██</td></tr><tr><td>_timestamp</td><td>▁▁██</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>colsample_bytree</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>max_depth</td><td>▁</td></tr><tr><td>min_child_samples</td><td>▁</td></tr><tr><td>min_child_weight</td><td>▁</td></tr><tr><td>min_split_gain</td><td>▁</td></tr><tr><td>n_estimators</td><td>▁</td></tr><tr><td>n_jobs</td><td>▁</td></tr><tr><td>num_leaves</td><td>▁</td></tr><tr><td>random_state</td><td>▁</td></tr><tr><td>reg_alpha</td><td>▁</td></tr><tr><td>reg_lambda</td><td>▁</td></tr><tr><td>silent</td><td>▁</td></tr><tr><td>subsample</td><td>▁</td></tr><tr><td>subsample_for_bin</td><td>▁</td></tr><tr><td>subsample_freq</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">baseline_20210909_114059</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/mbc0qnit" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/mbc0qnit</a><br/>

# %%
library = 'catboost'
gpu_available = True
exmodel_config['library'] = library
model_config = model_configurator(library)
catboost_models = cross_validation(model_config)
# Out:
# FOLD 0
# ---------------------------------------------------
#                 Tracking run with wandb version 0.12.1<br/>
#                 Syncing run <strong style="color:#cdcd00">baseline_20210909_114059</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground</a><br/>
#                 Run page: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1w4xt0db" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/1w4xt0db</a><br/>
#                 Run data is saved locally in <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_123038-1w4xt0db</code><br/><br/>
# CatBoost, therefore no WandB callback.
# Learning rate set to 0.012572
# 0:	learn: 0.6881629	total: 13.4ms	remaining: 26.9s
# 1:	learn: 0.6833127	total: 25.1ms	remaining: 25.1s
# 2:	learn: 0.6785933	total: 38ms	remaining: 25.3s
# 3:	learn: 0.6740085	total: 50.5ms	remaining: 25.2s
# 4:	learn: 0.6695562	total: 62.3ms	remaining: 24.9s
# 5:	learn: 0.6652229	total: 74ms	remaining: 24.6s
# 6:	learn: 0.6610054	total: 86.4ms	remaining: 24.6s
# 7:	learn: 0.6569118	total: 98.1ms	remaining: 24.4s
# 8:	learn: 0.6529269	total: 111ms	remaining: 24.5s
# 9:	learn: 0.6490544	total: 122ms	remaining: 24.2s
# 10:	learn: 0.6452932	total: 134ms	remaining: 24.2s
# 11:	learn: 0.6416313	total: 145ms	remaining: 24.1s
# 12:	learn: 0.6380730	total: 157ms	remaining: 24s
# 13:	learn: 0.6346169	total: 168ms	remaining: 23.8s
# 14:	learn: 0.6312591	total: 179ms	remaining: 23.7s
# 15:	learn: 0.6279930	total: 191ms	remaining: 23.7s
# 16:	learn: 0.6248191	total: 201ms	remaining: 23.5s
# 17:	learn: 0.6217357	total: 213ms	remaining: 23.4s
# 18:	learn: 0.6187358	total: 223ms	remaining: 23.3s
# 19:	learn: 0.6158182	total: 234ms	remaining: 23.2s
# 20:	learn: 0.6129810	total: 246ms	remaining: 23.2s
# 21:	learn: 0.6102252	total: 257ms	remaining: 23.1s
# 22:	learn: 0.6075490	total: 268ms	remaining: 23s
# 23:	learn: 0.6049455	total: 279ms	remaining: 23s
# 24:	learn: 0.6024163	total: 289ms	remaining: 22.8s
# 25:	learn: 0.5999560	total: 299ms	remaining: 22.7s
# 26:	learn: 0.5975668	total: 309ms	remaining: 22.6s
# 27:	learn: 0.5952415	total: 320ms	remaining: 22.6s
# 28:	learn: 0.5929730	total: 331ms	remaining: 22.5s
# 29:	learn: 0.5907740	total: 341ms	remaining: 22.4s
# 30:	learn: 0.5886388	total: 352ms	remaining: 22.4s
# 31:	learn: 0.5865611	total: 363ms	remaining: 22.3s
# 32:	learn: 0.5845439	total: 374ms	remaining: 22.3s
# 33:	learn: 0.5825808	total: 384ms	remaining: 22.2s
# 34:	learn: 0.5806723	total: 395ms	remaining: 22.2s
# 35:	learn: 0.5788200	total: 406ms	remaining: 22.1s
# 36:	learn: 0.5770179	total: 416ms	remaining: 22s
# 37:	learn: 0.5752667	total: 426ms	remaining: 22s
# 38:	learn: 0.5735574	total: 437ms	remaining: 22s
# 39:	learn: 0.5719013	total: 448ms	remaining: 21.9s
# 40:	learn: 0.5702919	total: 458ms	remaining: 21.9s
# 41:	learn: 0.5687245	total: 470ms	remaining: 21.9s
# 42:	learn: 0.5671990	total: 482ms	remaining: 21.9s
# 43:	learn: 0.5657146	total: 493ms	remaining: 21.9s
# 44:	learn: 0.5642761	total: 503ms	remaining: 21.9s
# 45:	learn: 0.5628744	total: 514ms	remaining: 21.8s
# 46:	learn: 0.5615095	total: 524ms	remaining: 21.8s
# 47:	learn: 0.5601850	total: 536ms	remaining: 21.8s
# 48:	learn: 0.5588892	total: 547ms	remaining: 21.8s
# 49:	learn: 0.5576377	total: 558ms	remaining: 21.8s
# 50:	learn: 0.5564185	total: 570ms	remaining: 21.8s
# 51:	learn: 0.5552347	total: 581ms	remaining: 21.8s
# 52:	learn: 0.5540841	total: 590ms	remaining: 21.7s
# 53:	learn: 0.5529629	total: 601ms	remaining: 21.7s
# 54:	learn: 0.5518716	total: 612ms	remaining: 21.6s
# 55:	learn: 0.5508098	total: 623ms	remaining: 21.6s
# 56:	learn: 0.5497824	total: 633ms	remaining: 21.6s
# 57:	learn: 0.5487831	total: 643ms	remaining: 21.5s
# 58:	learn: 0.5478059	total: 657ms	remaining: 21.6s
# 59:	learn: 0.5468553	total: 669ms	remaining: 21.6s
# 60:	learn: 0.5459334	total: 679ms	remaining: 21.6s
# 61:	learn: 0.5450370	total: 689ms	remaining: 21.5s
# 62:	learn: 0.5441641	total: 699ms	remaining: 21.5s
# 63:	learn: 0.5433143	total: 711ms	remaining: 21.5s
# 64:	learn: 0.5424879	total: 721ms	remaining: 21.5s
# 65:	learn: 0.5416855	total: 731ms	remaining: 21.4s
# 66:	learn: 0.5408987	total: 742ms	remaining: 21.4s
# 67:	learn: 0.5401388	total: 753ms	remaining: 21.4s
# 68:	learn: 0.5394006	total: 763ms	remaining: 21.3s
# 69:	learn: 0.5386835	total: 773ms	remaining: 21.3s
# 70:	learn: 0.5379831	total: 783ms	remaining: 21.3s
# 71:	learn: 0.5373041	total: 793ms	remaining: 21.2s
# 72:	learn: 0.5366421	total: 803ms	remaining: 21.2s
# 73:	learn: 0.5359981	total: 814ms	remaining: 21.2s
# 74:	learn: 0.5353696	total: 824ms	remaining: 21.2s
# 75:	learn: 0.5347592	total: 835ms	remaining: 21.1s
# 76:	learn: 0.5341599	total: 847ms	remaining: 21.2s
# 77:	learn: 0.5335845	total: 858ms	remaining: 21.1s
# 78:	learn: 0.5330237	total: 869ms	remaining: 21.1s
# 79:	learn: 0.5324760	total: 880ms	remaining: 21.1s
# 80:	learn: 0.5319434	total: 890ms	remaining: 21.1s
# 81:	learn: 0.5314279	total: 902ms	remaining: 21.1s
# 82:	learn: 0.5309190	total: 912ms	remaining: 21.1s
# 83:	learn: 0.5304286	total: 923ms	remaining: 21s
# 84:	learn: 0.5299523	total: 934ms	remaining: 21s
# 85:	learn: 0.5294859	total: 944ms	remaining: 21s
# 86:	learn: 0.5290368	total: 956ms	remaining: 21s
# 87:	learn: 0.5285996	total: 968ms	remaining: 21s
# 88:	learn: 0.5281699	total: 979ms	remaining: 21s
# 89:	learn: 0.5277528	total: 989ms	remaining: 21s
# 90:	learn: 0.5273420	total: 1000ms	remaining: 21s
# 91:	learn: 0.5269457	total: 1.01s	remaining: 21s
# 92:	learn: 0.5265608	total: 1.02s	remaining: 20.9s
# 93:	learn: 0.5261849	total: 1.03s	remaining: 20.9s
# 94:	learn: 0.5258188	total: 1.04s	remaining: 20.9s
# 95:	learn: 0.5254621	total: 1.05s	remaining: 20.9s
# 96:	learn: 0.5251162	total: 1.06s	remaining: 20.9s
# 97:	learn: 0.5247751	total: 1.07s	remaining: 20.9s
# 98:	learn: 0.5244499	total: 1.08s	remaining: 20.8s
# 99:	learn: 0.5241286	total: 1.09s	remaining: 20.8s
# 100:	learn: 0.5238106	total: 1.1s	remaining: 20.8s
# 101:	learn: 0.5235095	total: 1.12s	remaining: 20.8s
# 102:	learn: 0.5232155	total: 1.13s	remaining: 20.8s
# 103:	learn: 0.5229230	total: 1.14s	remaining: 20.7s
# 104:	learn: 0.5226416	total: 1.15s	remaining: 20.7s
# 105:	learn: 0.5223676	total: 1.16s	remaining: 20.7s
# 106:	learn: 0.5220980	total: 1.17s	remaining: 20.7s
# 107:	learn: 0.5218384	total: 1.18s	remaining: 20.7s
# 108:	learn: 0.5215894	total: 1.19s	remaining: 20.6s
# 109:	learn: 0.5213433	total: 1.2s	remaining: 20.6s
# 110:	learn: 0.5210995	total: 1.21s	remaining: 20.6s
# 111:	learn: 0.5208678	total: 1.22s	remaining: 20.6s
# 112:	learn: 0.5206394	total: 1.23s	remaining: 20.6s
# 113:	learn: 0.5204134	total: 1.24s	remaining: 20.6s
# 114:	learn: 0.5201974	total: 1.25s	remaining: 20.5s
# 115:	learn: 0.5199828	total: 1.26s	remaining: 20.5s
# 116:	learn: 0.5197792	total: 1.27s	remaining: 20.5s
# 117:	learn: 0.5195794	total: 1.28s	remaining: 20.5s
# 118:	learn: 0.5193846	total: 1.3s	remaining: 20.5s
# 119:	learn: 0.5191966	total: 1.31s	remaining: 20.5s
# 120:	learn: 0.5190118	total: 1.32s	remaining: 20.5s
# 121:	learn: 0.5188328	total: 1.33s	remaining: 20.4s
# 122:	learn: 0.5186587	total: 1.34s	remaining: 20.4s
# 123:	learn: 0.5184882	total: 1.35s	remaining: 20.4s
# 124:	learn: 0.5183195	total: 1.36s	remaining: 20.4s
# 125:	learn: 0.5181595	total: 1.37s	remaining: 20.4s
# 126:	learn: 0.5179994	total: 1.38s	remaining: 20.4s
# 127:	learn: 0.5178472	total: 1.39s	remaining: 20.4s
# 128:	learn: 0.5176937	total: 1.41s	remaining: 20.4s
# 129:	learn: 0.5175461	total: 1.42s	remaining: 20.4s
# 130:	learn: 0.5174054	total: 1.43s	remaining: 20.4s
# 131:	learn: 0.5172668	total: 1.44s	remaining: 20.4s
# 132:	learn: 0.5171308	total: 1.45s	remaining: 20.3s
# 133:	learn: 0.5170001	total: 1.46s	remaining: 20.3s
# 134:	learn: 0.5168712	total: 1.47s	remaining: 20.3s
# 135:	learn: 0.5167474	total: 1.48s	remaining: 20.3s
# 136:	learn: 0.5166230	total: 1.49s	remaining: 20.3s
# 137:	learn: 0.5165051	total: 1.5s	remaining: 20.3s
# 138:	learn: 0.5163927	total: 1.52s	remaining: 20.3s
# 139:	learn: 0.5162805	total: 1.53s	remaining: 20.3s
# 140:	learn: 0.5161673	total: 1.54s	remaining: 20.3s
# 141:	learn: 0.5160569	total: 1.55s	remaining: 20.3s
# 142:	learn: 0.5159500	total: 1.56s	remaining: 20.3s
# 143:	learn: 0.5158481	total: 1.57s	remaining: 20.3s
# 144:	learn: 0.5157480	total: 1.59s	remaining: 20.3s
# 145:	learn: 0.5156506	total: 1.6s	remaining: 20.3s
# 146:	learn: 0.5155553	total: 1.61s	remaining: 20.3s
# 147:	learn: 0.5154607	total: 1.62s	remaining: 20.3s
# 148:	learn: 0.5153684	total: 1.63s	remaining: 20.2s
# 149:	learn: 0.5152765	total: 1.64s	remaining: 20.2s
# 150:	learn: 0.5151905	total: 1.65s	remaining: 20.2s
# 151:	learn: 0.5151063	total: 1.66s	remaining: 20.2s
# 152:	learn: 0.5150226	total: 1.67s	remaining: 20.2s
# 153:	learn: 0.5149445	total: 1.68s	remaining: 20.2s
# 154:	learn: 0.5148630	total: 1.69s	remaining: 20.2s
# 155:	learn: 0.5147915	total: 1.7s	remaining: 20.1s
# 156:	learn: 0.5147171	total: 1.71s	remaining: 20.1s
# 157:	learn: 0.5146430	total: 1.73s	remaining: 20.1s
# 158:	learn: 0.5145682	total: 1.74s	remaining: 20.1s
# 159:	learn: 0.5144975	total: 1.75s	remaining: 20.1s
# 160:	learn: 0.5144258	total: 1.76s	remaining: 20.1s
# 161:	learn: 0.5143623	total: 1.77s	remaining: 20.1s
# 162:	learn: 0.5142967	total: 1.78s	remaining: 20.1s
# 163:	learn: 0.5142339	total: 1.79s	remaining: 20.1s
# 164:	learn: 0.5141751	total: 1.8s	remaining: 20s
# 165:	learn: 0.5141157	total: 1.81s	remaining: 20s
# 166:	learn: 0.5140542	total: 1.82s	remaining: 20s
# 167:	learn: 0.5139935	total: 1.83s	remaining: 20s
# 168:	learn: 0.5139364	total: 1.85s	remaining: 20s
# 169:	learn: 0.5138811	total: 1.86s	remaining: 20s
# 170:	learn: 0.5138281	total: 1.87s	remaining: 20s
# 171:	learn: 0.5137747	total: 1.88s	remaining: 20s
# 172:	learn: 0.5137228	total: 1.89s	remaining: 20s
# 173:	learn: 0.5136718	total: 1.91s	remaining: 20s
# 174:	learn: 0.5136262	total: 1.92s	remaining: 20s
# 175:	learn: 0.5135790	total: 1.93s	remaining: 20s
# 176:	learn: 0.5135319	total: 1.94s	remaining: 20s
# 177:	learn: 0.5134874	total: 1.95s	remaining: 20s
# 178:	learn: 0.5134440	total: 1.96s	remaining: 20s
# 179:	learn: 0.5134005	total: 1.97s	remaining: 20s
# 180:	learn: 0.5133600	total: 1.99s	remaining: 20s
# 181:	learn: 0.5133208	total: 2s	remaining: 19.9s
# 182:	learn: 0.5132808	total: 2.01s	remaining: 19.9s
# 183:	learn: 0.5132438	total: 2.02s	remaining: 19.9s
# 184:	learn: 0.5132024	total: 2.03s	remaining: 19.9s
# 185:	learn: 0.5131651	total: 2.04s	remaining: 19.9s
# 186:	learn: 0.5131297	total: 2.05s	remaining: 19.9s
# 187:	learn: 0.5130914	total: 2.06s	remaining: 19.9s
# 188:	learn: 0.5130542	total: 2.08s	remaining: 19.9s
# 189:	learn: 0.5130183	total: 2.09s	remaining: 19.9s
# 190:	learn: 0.5129857	total: 2.1s	remaining: 19.9s
# 191:	learn: 0.5129524	total: 2.11s	remaining: 19.8s
# 192:	learn: 0.5129212	total: 2.12s	remaining: 19.8s
# 193:	learn: 0.5128887	total: 2.13s	remaining: 19.8s
# 194:	learn: 0.5128607	total: 2.14s	remaining: 19.8s
# 195:	learn: 0.5128299	total: 2.15s	remaining: 19.8s
# 196:	learn: 0.5127996	total: 2.16s	remaining: 19.8s
# 197:	learn: 0.5127715	total: 2.17s	remaining: 19.7s
# 198:	learn: 0.5127405	total: 2.18s	remaining: 19.7s
# 199:	learn: 0.5127139	total: 2.19s	remaining: 19.7s
# 200:	learn: 0.5126859	total: 2.21s	remaining: 19.8s
# 201:	learn: 0.5126567	total: 2.22s	remaining: 19.8s
# 202:	learn: 0.5126289	total: 2.23s	remaining: 19.7s
# 203:	learn: 0.5126052	total: 2.24s	remaining: 19.7s
# 204:	learn: 0.5125774	total: 2.25s	remaining: 19.7s
# 205:	learn: 0.5125518	total: 2.26s	remaining: 19.7s
# 206:	learn: 0.5125280	total: 2.27s	remaining: 19.7s
# 207:	learn: 0.5125031	total: 2.28s	remaining: 19.7s
# 208:	learn: 0.5124768	total: 2.3s	remaining: 19.7s
# 209:	learn: 0.5124531	total: 2.31s	remaining: 19.7s
# 210:	learn: 0.5124303	total: 2.32s	remaining: 19.7s
# 211:	learn: 0.5124087	total: 2.33s	remaining: 19.7s
# 212:	learn: 0.5123872	total: 2.34s	remaining: 19.6s
# 213:	learn: 0.5123653	total: 2.35s	remaining: 19.6s
# 214:	learn: 0.5123433	total: 2.37s	remaining: 19.6s
# 215:	learn: 0.5123233	total: 2.38s	remaining: 19.6s
# 216:	learn: 0.5123024	total: 2.39s	remaining: 19.6s
# 217:	learn: 0.5122798	total: 2.4s	remaining: 19.6s
# 218:	learn: 0.5122586	total: 2.41s	remaining: 19.6s
# 219:	learn: 0.5122404	total: 2.42s	remaining: 19.6s
# 220:	learn: 0.5122198	total: 2.44s	remaining: 19.6s
# 221:	learn: 0.5122000	total: 2.45s	remaining: 19.6s
# 222:	learn: 0.5121815	total: 2.46s	remaining: 19.6s
# 223:	learn: 0.5121672	total: 2.47s	remaining: 19.6s
# 224:	learn: 0.5121476	total: 2.48s	remaining: 19.6s
# 225:	learn: 0.5121308	total: 2.49s	remaining: 19.6s
# 226:	learn: 0.5121154	total: 2.5s	remaining: 19.6s
# 227:	learn: 0.5120962	total: 2.52s	remaining: 19.6s
# 228:	learn: 0.5120780	total: 2.53s	remaining: 19.6s
# 229:	learn: 0.5120600	total: 2.54s	remaining: 19.5s
# 230:	learn: 0.5120448	total: 2.55s	remaining: 19.5s
# 231:	learn: 0.5120283	total: 2.56s	remaining: 19.5s
# 232:	learn: 0.5120149	total: 2.57s	remaining: 19.5s
# 233:	learn: 0.5119979	total: 2.58s	remaining: 19.5s
# 234:	learn: 0.5119817	total: 2.6s	remaining: 19.5s
# 235:	learn: 0.5119652	total: 2.61s	remaining: 19.5s
# 236:	learn: 0.5119511	total: 2.62s	remaining: 19.5s
# 237:	learn: 0.5119377	total: 2.63s	remaining: 19.5s
# 238:	learn: 0.5119255	total: 2.64s	remaining: 19.5s
# 239:	learn: 0.5119106	total: 2.65s	remaining: 19.5s
# 240:	learn: 0.5118971	total: 2.66s	remaining: 19.4s
# 241:	learn: 0.5118822	total: 2.68s	remaining: 19.4s
# 242:	learn: 0.5118688	total: 2.69s	remaining: 19.4s
# 243:	learn: 0.5118537	total: 2.7s	remaining: 19.4s
# 244:	learn: 0.5118387	total: 2.71s	remaining: 19.4s
# 245:	learn: 0.5118264	total: 2.72s	remaining: 19.4s
# 246:	learn: 0.5118131	total: 2.73s	remaining: 19.4s
# 247:	learn: 0.5118005	total: 2.75s	remaining: 19.4s
# 248:	learn: 0.5117862	total: 2.76s	remaining: 19.4s
# 249:	learn: 0.5117725	total: 2.77s	remaining: 19.4s
# 250:	learn: 0.5117624	total: 2.78s	remaining: 19.4s
# 251:	learn: 0.5117503	total: 2.79s	remaining: 19.4s
# 252:	learn: 0.5117381	total: 2.8s	remaining: 19.4s
# 253:	learn: 0.5117272	total: 2.82s	remaining: 19.4s
# 254:	learn: 0.5117162	total: 2.83s	remaining: 19.4s
# 255:	learn: 0.5117047	total: 2.84s	remaining: 19.3s
# 256:	learn: 0.5116945	total: 2.85s	remaining: 19.3s
# 257:	learn: 0.5116830	total: 2.87s	remaining: 19.3s
# 258:	learn: 0.5116703	total: 2.88s	remaining: 19.3s
# 259:	learn: 0.5116580	total: 2.89s	remaining: 19.3s
# 260:	learn: 0.5116472	total: 2.9s	remaining: 19.3s
# 261:	learn: 0.5116377	total: 2.91s	remaining: 19.3s
# 262:	learn: 0.5116261	total: 2.92s	remaining: 19.3s
# 263:	learn: 0.5116159	total: 2.93s	remaining: 19.3s
# 264:	learn: 0.5116059	total: 2.94s	remaining: 19.3s
# 265:	learn: 0.5115961	total: 2.96s	remaining: 19.3s
# 266:	learn: 0.5115842	total: 2.97s	remaining: 19.3s
# 267:	learn: 0.5115729	total: 2.98s	remaining: 19.3s
# 268:	learn: 0.5115631	total: 2.99s	remaining: 19.3s
# 269:	learn: 0.5115539	total: 3s	remaining: 19.2s
# 270:	learn: 0.5115428	total: 3.01s	remaining: 19.2s
# 271:	learn: 0.5115326	total: 3.02s	remaining: 19.2s
# 272:	learn: 0.5115220	total: 3.04s	remaining: 19.2s
# 273:	learn: 0.5115115	total: 3.05s	remaining: 19.2s
# 274:	learn: 0.5115017	total: 3.06s	remaining: 19.2s
# 275:	learn: 0.5114908	total: 3.07s	remaining: 19.2s
# 276:	learn: 0.5114814	total: 3.08s	remaining: 19.2s
# 277:	learn: 0.5114725	total: 3.09s	remaining: 19.2s
# 278:	learn: 0.5114631	total: 3.1s	remaining: 19.1s
# 279:	learn: 0.5114543	total: 3.11s	remaining: 19.1s
# 280:	learn: 0.5114442	total: 3.13s	remaining: 19.1s
# 281:	learn: 0.5114354	total: 3.14s	remaining: 19.1s
# 282:	learn: 0.5114258	total: 3.15s	remaining: 19.1s
# 283:	learn: 0.5114188	total: 3.16s	remaining: 19.1s
# 284:	learn: 0.5114082	total: 3.17s	remaining: 19.1s
# 285:	learn: 0.5113996	total: 3.18s	remaining: 19.1s
# 286:	learn: 0.5113925	total: 3.19s	remaining: 19.1s
# 287:	learn: 0.5113837	total: 3.2s	remaining: 19s
# 288:	learn: 0.5113757	total: 3.21s	remaining: 19s
# 289:	learn: 0.5113673	total: 3.23s	remaining: 19s
# 290:	learn: 0.5113588	total: 3.24s	remaining: 19s
# 291:	learn: 0.5113500	total: 3.25s	remaining: 19s
# 292:	learn: 0.5113431	total: 3.26s	remaining: 19s
# 293:	learn: 0.5113344	total: 3.27s	remaining: 19s
# 294:	learn: 0.5113262	total: 3.29s	remaining: 19s
# 295:	learn: 0.5113189	total: 3.3s	remaining: 19s
# 296:	learn: 0.5113103	total: 3.31s	remaining: 19s
# 297:	learn: 0.5113026	total: 3.32s	remaining: 19s
# 298:	learn: 0.5112958	total: 3.33s	remaining: 19s
# 299:	learn: 0.5112876	total: 3.35s	remaining: 19s
# 300:	learn: 0.5112795	total: 3.36s	remaining: 19s
# 301:	learn: 0.5112715	total: 3.37s	remaining: 19s
# 302:	learn: 0.5112632	total: 3.38s	remaining: 18.9s
# 303:	learn: 0.5112544	total: 3.39s	remaining: 18.9s
# 304:	learn: 0.5112465	total: 3.41s	remaining: 18.9s
# 305:	learn: 0.5112372	total: 3.42s	remaining: 18.9s
# 306:	learn: 0.5112289	total: 3.43s	remaining: 18.9s
# 307:	learn: 0.5112216	total: 3.44s	remaining: 18.9s
# 308:	learn: 0.5112145	total: 3.45s	remaining: 18.9s
# 309:	learn: 0.5112062	total: 3.46s	remaining: 18.9s
# 310:	learn: 0.5112002	total: 3.48s	remaining: 18.9s
# 311:	learn: 0.5111930	total: 3.49s	remaining: 18.9s
# 312:	learn: 0.5111851	total: 3.5s	remaining: 18.9s
# 313:	learn: 0.5111782	total: 3.51s	remaining: 18.9s
# 314:	learn: 0.5111733	total: 3.52s	remaining: 18.9s
# 315:	learn: 0.5111659	total: 3.53s	remaining: 18.8s
# 316:	learn: 0.5111590	total: 3.55s	remaining: 18.8s
# 317:	learn: 0.5111502	total: 3.56s	remaining: 18.8s
# 318:	learn: 0.5111428	total: 3.57s	remaining: 18.8s
# 319:	learn: 0.5111362	total: 3.58s	remaining: 18.8s
# 320:	learn: 0.5111299	total: 3.59s	remaining: 18.8s
# 321:	learn: 0.5111235	total: 3.6s	remaining: 18.8s
# 322:	learn: 0.5111172	total: 3.61s	remaining: 18.8s
# 323:	learn: 0.5111121	total: 3.63s	remaining: 18.8s
# 324:	learn: 0.5111070	total: 3.64s	remaining: 18.7s
# 325:	learn: 0.5110991	total: 3.65s	remaining: 18.7s
# 326:	learn: 0.5110929	total: 3.66s	remaining: 18.7s
# 327:	learn: 0.5110863	total: 3.67s	remaining: 18.7s
# 328:	learn: 0.5110789	total: 3.68s	remaining: 18.7s
# 329:	learn: 0.5110722	total: 3.69s	remaining: 18.7s
# 330:	learn: 0.5110670	total: 3.71s	remaining: 18.7s
# 331:	learn: 0.5110600	total: 3.72s	remaining: 18.7s
# 332:	learn: 0.5110535	total: 3.73s	remaining: 18.7s
# 333:	learn: 0.5110465	total: 3.74s	remaining: 18.7s
# 334:	learn: 0.5110413	total: 3.75s	remaining: 18.6s
# 335:	learn: 0.5110347	total: 3.76s	remaining: 18.6s
# 336:	learn: 0.5110277	total: 3.77s	remaining: 18.6s
# 337:	learn: 0.5110217	total: 3.79s	remaining: 18.6s
# 338:	learn: 0.5110167	total: 3.8s	remaining: 18.6s
# 339:	learn: 0.5110092	total: 3.81s	remaining: 18.6s
# 340:	learn: 0.5110038	total: 3.82s	remaining: 18.6s
# 341:	learn: 0.5109970	total: 3.83s	remaining: 18.6s
# 342:	learn: 0.5109905	total: 3.84s	remaining: 18.6s
# 343:	learn: 0.5109838	total: 3.86s	remaining: 18.6s
# 344:	learn: 0.5109779	total: 3.87s	remaining: 18.6s
# 345:	learn: 0.5109719	total: 3.88s	remaining: 18.5s
# 346:	learn: 0.5109651	total: 3.89s	remaining: 18.5s
# 347:	learn: 0.5109584	total: 3.9s	remaining: 18.5s
# 348:	learn: 0.5109516	total: 3.91s	remaining: 18.5s
# 349:	learn: 0.5109456	total: 3.92s	remaining: 18.5s
# 350:	learn: 0.5109390	total: 3.94s	remaining: 18.5s
# 351:	learn: 0.5109334	total: 3.95s	remaining: 18.5s
# 352:	learn: 0.5109262	total: 3.96s	remaining: 18.5s
# 353:	learn: 0.5109193	total: 3.97s	remaining: 18.5s
# 354:	learn: 0.5109144	total: 3.98s	remaining: 18.4s
# 355:	learn: 0.5109082	total: 3.99s	remaining: 18.4s
# 356:	learn: 0.5109025	total: 4s	remaining: 18.4s
# 357:	learn: 0.5108959	total: 4.01s	remaining: 18.4s
# 358:	learn: 0.5108895	total: 4.02s	remaining: 18.4s
# 359:	learn: 0.5108830	total: 4.04s	remaining: 18.4s
# 360:	learn: 0.5108771	total: 4.04s	remaining: 18.4s
# 361:	learn: 0.5108718	total: 4.06s	remaining: 18.4s
# 362:	learn: 0.5108677	total: 4.07s	remaining: 18.3s
# 363:	learn: 0.5108624	total: 4.08s	remaining: 18.3s
# 364:	learn: 0.5108583	total: 4.09s	remaining: 18.3s
# 365:	learn: 0.5108515	total: 4.1s	remaining: 18.3s
# 366:	learn: 0.5108459	total: 4.11s	remaining: 18.3s
# 367:	learn: 0.5108401	total: 4.12s	remaining: 18.3s
# 368:	learn: 0.5108341	total: 4.13s	remaining: 18.3s
# 369:	learn: 0.5108288	total: 4.14s	remaining: 18.3s
# 370:	learn: 0.5108235	total: 4.16s	remaining: 18.2s
# 371:	learn: 0.5108186	total: 4.17s	remaining: 18.2s
# 372:	learn: 0.5108128	total: 4.18s	remaining: 18.2s
# 373:	learn: 0.5108090	total: 4.19s	remaining: 18.2s
# 374:	learn: 0.5108031	total: 4.2s	remaining: 18.2s
# 375:	learn: 0.5107975	total: 4.21s	remaining: 18.2s
# 376:	learn: 0.5107925	total: 4.22s	remaining: 18.2s
# 377:	learn: 0.5107884	total: 4.23s	remaining: 18.2s
# 378:	learn: 0.5107827	total: 4.24s	remaining: 18.1s
# 379:	learn: 0.5107770	total: 4.25s	remaining: 18.1s
# 380:	learn: 0.5107704	total: 4.27s	remaining: 18.1s
# 381:	learn: 0.5107656	total: 4.28s	remaining: 18.1s
# 382:	learn: 0.5107598	total: 4.29s	remaining: 18.1s
# 383:	learn: 0.5107557	total: 4.3s	remaining: 18.1s
# 384:	learn: 0.5107519	total: 4.31s	remaining: 18.1s
# 385:	learn: 0.5107464	total: 4.32s	remaining: 18.1s
# 386:	learn: 0.5107404	total: 4.33s	remaining: 18.1s
# 387:	learn: 0.5107339	total: 4.34s	remaining: 18.1s
# 388:	learn: 0.5107301	total: 4.36s	remaining: 18s
# 389:	learn: 0.5107247	total: 4.37s	remaining: 18s
# 390:	learn: 0.5107186	total: 4.38s	remaining: 18s
# 391:	learn: 0.5107128	total: 4.39s	remaining: 18s
# 392:	learn: 0.5107064	total: 4.4s	remaining: 18s
# 393:	learn: 0.5107010	total: 4.42s	remaining: 18s
# 394:	learn: 0.5106959	total: 4.43s	remaining: 18s
# 395:	learn: 0.5106911	total: 4.44s	remaining: 18s
# 396:	learn: 0.5106862	total: 4.45s	remaining: 18s
# 397:	learn: 0.5106817	total: 4.46s	remaining: 18s
# 398:	learn: 0.5106755	total: 4.47s	remaining: 17.9s
# 399:	learn: 0.5106711	total: 4.48s	remaining: 17.9s
# 400:	learn: 0.5106652	total: 4.5s	remaining: 17.9s
# 401:	learn: 0.5106599	total: 4.5s	remaining: 17.9s
# 402:	learn: 0.5106551	total: 4.52s	remaining: 17.9s
# 403:	learn: 0.5106509	total: 4.53s	remaining: 17.9s
# 404:	learn: 0.5106472	total: 4.54s	remaining: 17.9s
# 405:	learn: 0.5106422	total: 4.55s	remaining: 17.9s
# 406:	learn: 0.5106374	total: 4.56s	remaining: 17.9s
# 407:	learn: 0.5106321	total: 4.57s	remaining: 17.8s
# 408:	learn: 0.5106247	total: 4.58s	remaining: 17.8s
# 409:	learn: 0.5106184	total: 4.59s	remaining: 17.8s
# 410:	learn: 0.5106129	total: 4.6s	remaining: 17.8s
# 411:	learn: 0.5106066	total: 4.62s	remaining: 17.8s
# 412:	learn: 0.5106013	total: 4.63s	remaining: 17.8s
# 413:	learn: 0.5105962	total: 4.64s	remaining: 17.8s
# 414:	learn: 0.5105903	total: 4.65s	remaining: 17.8s
# 415:	learn: 0.5105857	total: 4.66s	remaining: 17.7s
# 416:	learn: 0.5105804	total: 4.67s	remaining: 17.7s
# 417:	learn: 0.5105755	total: 4.68s	remaining: 17.7s
# 418:	learn: 0.5105702	total: 4.69s	remaining: 17.7s
# 419:	learn: 0.5105665	total: 4.7s	remaining: 17.7s
# 420:	learn: 0.5105611	total: 4.71s	remaining: 17.7s
# 421:	learn: 0.5105564	total: 4.72s	remaining: 17.7s
# 422:	learn: 0.5105531	total: 4.73s	remaining: 17.6s
# 423:	learn: 0.5105464	total: 4.75s	remaining: 17.6s
# 424:	learn: 0.5105406	total: 4.76s	remaining: 17.6s
# 425:	learn: 0.5105347	total: 4.77s	remaining: 17.6s
# 426:	learn: 0.5105297	total: 4.78s	remaining: 17.6s
# 427:	learn: 0.5105252	total: 4.79s	remaining: 17.6s
# 428:	learn: 0.5105203	total: 4.8s	remaining: 17.6s
# 429:	learn: 0.5105147	total: 4.81s	remaining: 17.6s
# 430:	learn: 0.5105096	total: 4.82s	remaining: 17.6s
# 431:	learn: 0.5105046	total: 4.84s	remaining: 17.6s
# 432:	learn: 0.5105006	total: 4.85s	remaining: 17.5s
# 433:	learn: 0.5104927	total: 4.86s	remaining: 17.5s
# 434:	learn: 0.5104891	total: 4.87s	remaining: 17.5s
# 435:	learn: 0.5104832	total: 4.88s	remaining: 17.5s
# 436:	learn: 0.5104783	total: 4.89s	remaining: 17.5s
# 437:	learn: 0.5104729	total: 4.9s	remaining: 17.5s
# 438:	learn: 0.5104694	total: 4.91s	remaining: 17.5s
# 439:	learn: 0.5104641	total: 4.92s	remaining: 17.5s
# 440:	learn: 0.5104600	total: 4.93s	remaining: 17.4s
# 441:	learn: 0.5104528	total: 4.95s	remaining: 17.4s
# 442:	learn: 0.5104478	total: 4.96s	remaining: 17.4s
# 443:	learn: 0.5104417	total: 4.97s	remaining: 17.4s
# 444:	learn: 0.5104353	total: 4.98s	remaining: 17.4s
# 445:	learn: 0.5104315	total: 4.99s	remaining: 17.4s
# 446:	learn: 0.5104260	total: 5s	remaining: 17.4s
# 447:	learn: 0.5104216	total: 5.01s	remaining: 17.4s
# 448:	learn: 0.5104170	total: 5.02s	remaining: 17.4s
# 449:	learn: 0.5104125	total: 5.04s	remaining: 17.3s
# 450:	learn: 0.5104075	total: 5.05s	remaining: 17.3s
# 451:	learn: 0.5104027	total: 5.06s	remaining: 17.3s
# 452:	learn: 0.5103981	total: 5.07s	remaining: 17.3s
# 453:	learn: 0.5103915	total: 5.08s	remaining: 17.3s
# 454:	learn: 0.5103857	total: 5.09s	remaining: 17.3s
# 455:	learn: 0.5103795	total: 5.1s	remaining: 17.3s
# 456:	learn: 0.5103743	total: 5.11s	remaining: 17.3s
# 457:	learn: 0.5103700	total: 5.12s	remaining: 17.3s
# 458:	learn: 0.5103639	total: 5.13s	remaining: 17.2s
# 459:	learn: 0.5103598	total: 5.15s	remaining: 17.2s
# 460:	learn: 0.5103556	total: 5.16s	remaining: 17.2s
# 461:	learn: 0.5103510	total: 5.17s	remaining: 17.2s
# 462:	learn: 0.5103458	total: 5.18s	remaining: 17.2s
# 463:	learn: 0.5103413	total: 5.19s	remaining: 17.2s
# 464:	learn: 0.5103362	total: 5.2s	remaining: 17.2s
# 465:	learn: 0.5103307	total: 5.22s	remaining: 17.2s
# 466:	learn: 0.5103267	total: 5.23s	remaining: 17.2s
# 467:	learn: 0.5103212	total: 5.24s	remaining: 17.1s
# 468:	learn: 0.5103171	total: 5.25s	remaining: 17.1s
# 469:	learn: 0.5103119	total: 5.26s	remaining: 17.1s
# 470:	learn: 0.5103074	total: 5.27s	remaining: 17.1s
# 471:	learn: 0.5103035	total: 5.28s	remaining: 17.1s
# 472:	learn: 0.5102992	total: 5.29s	remaining: 17.1s
# 473:	learn: 0.5102939	total: 5.3s	remaining: 17.1s
# 474:	learn: 0.5102887	total: 5.31s	remaining: 17.1s
# 475:	learn: 0.5102843	total: 5.33s	remaining: 17.1s
# 476:	learn: 0.5102801	total: 5.33s	remaining: 17s
# 477:	learn: 0.5102757	total: 5.35s	remaining: 17s
# 478:	learn: 0.5102710	total: 5.36s	remaining: 17s
# 479:	learn: 0.5102655	total: 5.37s	remaining: 17s
# 480:	learn: 0.5102607	total: 5.38s	remaining: 17s
# 481:	learn: 0.5102564	total: 5.39s	remaining: 17s
# 482:	learn: 0.5102513	total: 5.41s	remaining: 17s
# 483:	learn: 0.5102464	total: 5.42s	remaining: 17s
# 484:	learn: 0.5102418	total: 5.43s	remaining: 17s
# 485:	learn: 0.5102364	total: 5.44s	remaining: 16.9s
# 486:	learn: 0.5102321	total: 5.45s	remaining: 16.9s
# 487:	learn: 0.5102281	total: 5.46s	remaining: 16.9s
# 488:	learn: 0.5102233	total: 5.47s	remaining: 16.9s
# 489:	learn: 0.5102185	total: 5.48s	remaining: 16.9s
# 490:	learn: 0.5102138	total: 5.49s	remaining: 16.9s
# 491:	learn: 0.5102085	total: 5.5s	remaining: 16.9s
# 492:	learn: 0.5102049	total: 5.51s	remaining: 16.9s
# 493:	learn: 0.5102006	total: 5.53s	remaining: 16.8s
# 494:	learn: 0.5101959	total: 5.54s	remaining: 16.8s
# 495:	learn: 0.5101908	total: 5.55s	remaining: 16.8s
# 496:	learn: 0.5101848	total: 5.56s	remaining: 16.8s
# 497:	learn: 0.5101797	total: 5.57s	remaining: 16.8s
# 498:	learn: 0.5101758	total: 5.58s	remaining: 16.8s
# 499:	learn: 0.5101706	total: 5.6s	remaining: 16.8s
# 500:	learn: 0.5101662	total: 5.61s	remaining: 16.8s
# 501:	learn: 0.5101615	total: 5.62s	remaining: 16.8s
# 502:	learn: 0.5101567	total: 5.63s	remaining: 16.8s
# 503:	learn: 0.5101523	total: 5.64s	remaining: 16.7s
# 504:	learn: 0.5101489	total: 5.65s	remaining: 16.7s
# 505:	learn: 0.5101437	total: 5.66s	remaining: 16.7s
# 506:	learn: 0.5101392	total: 5.67s	remaining: 16.7s
# 507:	learn: 0.5101353	total: 5.68s	remaining: 16.7s
# 508:	learn: 0.5101305	total: 5.69s	remaining: 16.7s
# 509:	learn: 0.5101261	total: 5.71s	remaining: 16.7s
# 510:	learn: 0.5101213	total: 5.71s	remaining: 16.7s
# 511:	learn: 0.5101171	total: 5.72s	remaining: 16.6s
# 512:	learn: 0.5101121	total: 5.74s	remaining: 16.6s
# 513:	learn: 0.5101077	total: 5.75s	remaining: 16.6s
# 514:	learn: 0.5101034	total: 5.76s	remaining: 16.6s
# 515:	learn: 0.5100980	total: 5.77s	remaining: 16.6s
# 516:	learn: 0.5100939	total: 5.78s	remaining: 16.6s
# 517:	learn: 0.5100891	total: 5.79s	remaining: 16.6s
# 518:	learn: 0.5100863	total: 5.8s	remaining: 16.6s
# 519:	learn: 0.5100831	total: 5.81s	remaining: 16.6s
# 520:	learn: 0.5100785	total: 5.83s	remaining: 16.5s
# 521:	learn: 0.5100744	total: 5.84s	remaining: 16.5s
# 522:	learn: 0.5100680	total: 5.85s	remaining: 16.5s
# 523:	learn: 0.5100642	total: 5.86s	remaining: 16.5s
# 524:	learn: 0.5100590	total: 5.87s	remaining: 16.5s
# 525:	learn: 0.5100553	total: 5.88s	remaining: 16.5s
# 526:	learn: 0.5100513	total: 5.89s	remaining: 16.5s
# 527:	learn: 0.5100470	total: 5.9s	remaining: 16.5s
# 528:	learn: 0.5100427	total: 5.91s	remaining: 16.4s
# 529:	learn: 0.5100394	total: 5.92s	remaining: 16.4s
# 530:	learn: 0.5100364	total: 5.93s	remaining: 16.4s
# 531:	learn: 0.5100311	total: 5.95s	remaining: 16.4s
# 532:	learn: 0.5100269	total: 5.96s	remaining: 16.4s
# 533:	learn: 0.5100230	total: 5.97s	remaining: 16.4s
# 534:	learn: 0.5100193	total: 5.97s	remaining: 16.4s
# 535:	learn: 0.5100158	total: 5.99s	remaining: 16.4s
# 536:	learn: 0.5100108	total: 6s	remaining: 16.3s
# 537:	learn: 0.5100061	total: 6.01s	remaining: 16.3s
# 538:	learn: 0.5100024	total: 6.02s	remaining: 16.3s
# 539:	learn: 0.5099975	total: 6.03s	remaining: 16.3s
# 540:	learn: 0.5099946	total: 6.04s	remaining: 16.3s
# 541:	learn: 0.5099902	total: 6.05s	remaining: 16.3s
# 542:	learn: 0.5099872	total: 6.07s	remaining: 16.3s
# 543:	learn: 0.5099827	total: 6.08s	remaining: 16.3s
# 544:	learn: 0.5099785	total: 6.08s	remaining: 16.2s
# 545:	learn: 0.5099750	total: 6.1s	remaining: 16.2s
# 546:	learn: 0.5099710	total: 6.11s	remaining: 16.2s
# 547:	learn: 0.5099671	total: 6.12s	remaining: 16.2s
# 548:	learn: 0.5099627	total: 6.13s	remaining: 16.2s
# 549:	learn: 0.5099591	total: 6.14s	remaining: 16.2s
# 550:	learn: 0.5099555	total: 6.15s	remaining: 16.2s
# 551:	learn: 0.5099504	total: 6.16s	remaining: 16.2s
# 552:	learn: 0.5099464	total: 6.17s	remaining: 16.2s
# 553:	learn: 0.5099426	total: 6.19s	remaining: 16.1s
# 554:	learn: 0.5099385	total: 6.2s	remaining: 16.1s
# 555:	learn: 0.5099338	total: 6.21s	remaining: 16.1s
# 556:	learn: 0.5099320	total: 6.22s	remaining: 16.1s
# 557:	learn: 0.5099280	total: 6.23s	remaining: 16.1s
# 558:	learn: 0.5099242	total: 6.24s	remaining: 16.1s
# 559:	learn: 0.5099188	total: 6.25s	remaining: 16.1s
# 560:	learn: 0.5099148	total: 6.26s	remaining: 16.1s
# 561:	learn: 0.5099105	total: 6.27s	remaining: 16s
# 562:	learn: 0.5099069	total: 6.28s	remaining: 16s
# 563:	learn: 0.5099026	total: 6.3s	remaining: 16s
# 564:	learn: 0.5098989	total: 6.31s	remaining: 16s
# 565:	learn: 0.5098941	total: 6.32s	remaining: 16s
# 566:	learn: 0.5098898	total: 6.33s	remaining: 16s
# 567:	learn: 0.5098855	total: 6.34s	remaining: 16s
# 568:	learn: 0.5098814	total: 6.35s	remaining: 16s
# 569:	learn: 0.5098766	total: 6.36s	remaining: 16s
# 570:	learn: 0.5098725	total: 6.38s	remaining: 16s
# 571:	learn: 0.5098677	total: 6.38s	remaining: 15.9s
# 572:	learn: 0.5098640	total: 6.4s	remaining: 15.9s
# 573:	learn: 0.5098598	total: 6.41s	remaining: 15.9s
# 574:	learn: 0.5098548	total: 6.42s	remaining: 15.9s
# 575:	learn: 0.5098510	total: 6.43s	remaining: 15.9s
# 576:	learn: 0.5098456	total: 6.44s	remaining: 15.9s
# 577:	learn: 0.5098412	total: 6.45s	remaining: 15.9s
# 578:	learn: 0.5098374	total: 6.46s	remaining: 15.9s
# 579:	learn: 0.5098331	total: 6.47s	remaining: 15.8s
# 580:	learn: 0.5098288	total: 6.48s	remaining: 15.8s
# 581:	learn: 0.5098246	total: 6.49s	remaining: 15.8s
# 582:	learn: 0.5098200	total: 6.5s	remaining: 15.8s
# 583:	learn: 0.5098161	total: 6.52s	remaining: 15.8s
# 584:	learn: 0.5098125	total: 6.53s	remaining: 15.8s
# 585:	learn: 0.5098083	total: 6.54s	remaining: 15.8s
# 586:	learn: 0.5098047	total: 6.55s	remaining: 15.8s
# 587:	learn: 0.5098011	total: 6.56s	remaining: 15.7s
# 588:	learn: 0.5097948	total: 6.57s	remaining: 15.7s
# 589:	learn: 0.5097908	total: 6.58s	remaining: 15.7s
# 590:	learn: 0.5097867	total: 6.59s	remaining: 15.7s
# 591:	learn: 0.5097822	total: 6.6s	remaining: 15.7s
# 592:	learn: 0.5097786	total: 6.61s	remaining: 15.7s
# 593:	learn: 0.5097744	total: 6.62s	remaining: 15.7s
# 594:	learn: 0.5097697	total: 6.64s	remaining: 15.7s
# 595:	learn: 0.5097658	total: 6.65s	remaining: 15.7s
# 596:	learn: 0.5097620	total: 6.66s	remaining: 15.6s
# 597:	learn: 0.5097581	total: 6.67s	remaining: 15.6s
# 598:	learn: 0.5097527	total: 6.68s	remaining: 15.6s
# 599:	learn: 0.5097479	total: 6.69s	remaining: 15.6s
# 600:	learn: 0.5097446	total: 6.7s	remaining: 15.6s
# 601:	learn: 0.5097406	total: 6.71s	remaining: 15.6s
# 602:	learn: 0.5097361	total: 6.72s	remaining: 15.6s
# 603:	learn: 0.5097318	total: 6.74s	remaining: 15.6s
# 604:	learn: 0.5097289	total: 6.75s	remaining: 15.6s
# 605:	learn: 0.5097251	total: 6.76s	remaining: 15.5s
# 606:	learn: 0.5097188	total: 6.77s	remaining: 15.5s
# 607:	learn: 0.5097159	total: 6.78s	remaining: 15.5s
# 608:	learn: 0.5097118	total: 6.79s	remaining: 15.5s
# 609:	learn: 0.5097077	total: 6.8s	remaining: 15.5s
# 610:	learn: 0.5097016	total: 6.81s	remaining: 15.5s
# 611:	learn: 0.5096978	total: 6.82s	remaining: 15.5s
# 612:	learn: 0.5096942	total: 6.83s	remaining: 15.5s
# 613:	learn: 0.5096908	total: 6.84s	remaining: 15.4s
# 614:	learn: 0.5096858	total: 6.86s	remaining: 15.4s
# 615:	learn: 0.5096816	total: 6.87s	remaining: 15.4s
# 616:	learn: 0.5096780	total: 6.88s	remaining: 15.4s
# 617:	learn: 0.5096737	total: 6.89s	remaining: 15.4s
# 618:	learn: 0.5096702	total: 6.9s	remaining: 15.4s
# 619:	learn: 0.5096672	total: 6.91s	remaining: 15.4s
# 620:	learn: 0.5096630	total: 6.92s	remaining: 15.4s
# 621:	learn: 0.5096592	total: 6.93s	remaining: 15.3s
# 622:	learn: 0.5096554	total: 6.94s	remaining: 15.3s
# 623:	learn: 0.5096518	total: 6.95s	remaining: 15.3s
# 624:	learn: 0.5096485	total: 6.96s	remaining: 15.3s
# 625:	learn: 0.5096442	total: 6.97s	remaining: 15.3s
# 626:	learn: 0.5096405	total: 6.98s	remaining: 15.3s
# 627:	learn: 0.5096358	total: 6.99s	remaining: 15.3s
# 628:	learn: 0.5096325	total: 7s	remaining: 15.3s
# 629:	learn: 0.5096255	total: 7.01s	remaining: 15.2s
# 630:	learn: 0.5096217	total: 7.02s	remaining: 15.2s
# 631:	learn: 0.5096179	total: 7.03s	remaining: 15.2s
# 632:	learn: 0.5096143	total: 7.04s	remaining: 15.2s
# 633:	learn: 0.5096104	total: 7.05s	remaining: 15.2s
# 634:	learn: 0.5096066	total: 7.07s	remaining: 15.2s
# 635:	learn: 0.5096026	total: 7.08s	remaining: 15.2s
# 636:	learn: 0.5095995	total: 7.09s	remaining: 15.2s
# 637:	learn: 0.5095955	total: 7.1s	remaining: 15.2s
# 638:	learn: 0.5095916	total: 7.11s	remaining: 15.1s
# 639:	learn: 0.5095872	total: 7.12s	remaining: 15.1s
# 640:	learn: 0.5095832	total: 7.13s	remaining: 15.1s
# 641:	learn: 0.5095800	total: 7.14s	remaining: 15.1s
# 642:	learn: 0.5095751	total: 7.15s	remaining: 15.1s
# 643:	learn: 0.5095712	total: 7.16s	remaining: 15.1s
# 644:	learn: 0.5095677	total: 7.17s	remaining: 15.1s
# 645:	learn: 0.5095649	total: 7.18s	remaining: 15.1s
# 646:	learn: 0.5095588	total: 7.2s	remaining: 15s
# 647:	learn: 0.5095555	total: 7.21s	remaining: 15s
# 648:	learn: 0.5095515	total: 7.22s	remaining: 15s
# 649:	learn: 0.5095477	total: 7.23s	remaining: 15s
# 650:	learn: 0.5095453	total: 7.24s	remaining: 15s
# 651:	learn: 0.5095421	total: 7.25s	remaining: 15s
# 652:	learn: 0.5095380	total: 7.26s	remaining: 15s
# 653:	learn: 0.5095336	total: 7.28s	remaining: 15s
# 654:	learn: 0.5095297	total: 7.29s	remaining: 15s
# 655:	learn: 0.5095267	total: 7.3s	remaining: 14.9s
# 656:	learn: 0.5095229	total: 7.31s	remaining: 14.9s
# 657:	learn: 0.5095187	total: 7.32s	remaining: 14.9s
# 658:	learn: 0.5095148	total: 7.33s	remaining: 14.9s
# 659:	learn: 0.5095118	total: 7.34s	remaining: 14.9s
# 660:	learn: 0.5095080	total: 7.35s	remaining: 14.9s
# 661:	learn: 0.5095054	total: 7.36s	remaining: 14.9s
# 662:	learn: 0.5095009	total: 7.37s	remaining: 14.9s
# 663:	learn: 0.5094968	total: 7.38s	remaining: 14.9s
# 664:	learn: 0.5094931	total: 7.39s	remaining: 14.8s
# 665:	learn: 0.5094887	total: 7.4s	remaining: 14.8s
# 666:	learn: 0.5094833	total: 7.42s	remaining: 14.8s
# 667:	learn: 0.5094799	total: 7.42s	remaining: 14.8s
# 668:	learn: 0.5094750	total: 7.44s	remaining: 14.8s
# 669:	learn: 0.5094716	total: 7.45s	remaining: 14.8s
# 670:	learn: 0.5094677	total: 7.46s	remaining: 14.8s
# 671:	learn: 0.5094638	total: 7.47s	remaining: 14.8s
# 672:	learn: 0.5094602	total: 7.48s	remaining: 14.7s
# 673:	learn: 0.5094564	total: 7.49s	remaining: 14.7s
# 674:	learn: 0.5094524	total: 7.5s	remaining: 14.7s
# 675:	learn: 0.5094485	total: 7.51s	remaining: 14.7s
# 676:	learn: 0.5094450	total: 7.52s	remaining: 14.7s
# 677:	learn: 0.5094414	total: 7.53s	remaining: 14.7s
# 678:	learn: 0.5094377	total: 7.54s	remaining: 14.7s
# 679:	learn: 0.5094339	total: 7.55s	remaining: 14.7s
# 680:	learn: 0.5094297	total: 7.56s	remaining: 14.6s
# 681:	learn: 0.5094265	total: 7.57s	remaining: 14.6s
# 682:	learn: 0.5094219	total: 7.59s	remaining: 14.6s
# 683:	learn: 0.5094192	total: 7.6s	remaining: 14.6s
# 684:	learn: 0.5094129	total: 7.61s	remaining: 14.6s
# 685:	learn: 0.5094095	total: 7.62s	remaining: 14.6s
# 686:	learn: 0.5094052	total: 7.63s	remaining: 14.6s
# 687:	learn: 0.5094018	total: 7.64s	remaining: 14.6s
# 688:	learn: 0.5093994	total: 7.65s	remaining: 14.6s
# 689:	learn: 0.5093950	total: 7.66s	remaining: 14.5s
# 690:	learn: 0.5093922	total: 7.67s	remaining: 14.5s
# 691:	learn: 0.5093873	total: 7.68s	remaining: 14.5s
# 692:	learn: 0.5093839	total: 7.7s	remaining: 14.5s
# 693:	learn: 0.5093796	total: 7.71s	remaining: 14.5s
# 694:	learn: 0.5093773	total: 7.72s	remaining: 14.5s
# 695:	learn: 0.5093736	total: 7.73s	remaining: 14.5s
# 696:	learn: 0.5093695	total: 7.74s	remaining: 14.5s
# 697:	learn: 0.5093656	total: 7.75s	remaining: 14.5s
# 698:	learn: 0.5093627	total: 7.76s	remaining: 14.5s
# 699:	learn: 0.5093587	total: 7.78s	remaining: 14.4s
# 700:	learn: 0.5093553	total: 7.79s	remaining: 14.4s
# 701:	learn: 0.5093513	total: 7.8s	remaining: 14.4s
# 702:	learn: 0.5093479	total: 7.81s	remaining: 14.4s
# 703:	learn: 0.5093439	total: 7.82s	remaining: 14.4s
# 704:	learn: 0.5093410	total: 7.83s	remaining: 14.4s
# 705:	learn: 0.5093363	total: 7.84s	remaining: 14.4s
# 706:	learn: 0.5093331	total: 7.86s	remaining: 14.4s
# 707:	learn: 0.5093306	total: 7.87s	remaining: 14.4s
# 708:	learn: 0.5093276	total: 7.88s	remaining: 14.3s
# 709:	learn: 0.5093231	total: 7.89s	remaining: 14.3s
# 710:	learn: 0.5093195	total: 7.9s	remaining: 14.3s
# 711:	learn: 0.5093162	total: 7.91s	remaining: 14.3s
# 712:	learn: 0.5093140	total: 7.92s	remaining: 14.3s
# 713:	learn: 0.5093092	total: 7.93s	remaining: 14.3s
# 714:	learn: 0.5093055	total: 7.94s	remaining: 14.3s
# 715:	learn: 0.5093018	total: 7.95s	remaining: 14.3s
# 716:	learn: 0.5092984	total: 7.96s	remaining: 14.3s
# 717:	learn: 0.5092945	total: 7.97s	remaining: 14.2s
# 718:	learn: 0.5092910	total: 7.99s	remaining: 14.2s
# 719:	learn: 0.5092871	total: 8s	remaining: 14.2s
# 720:	learn: 0.5092834	total: 8.01s	remaining: 14.2s
# 721:	learn: 0.5092784	total: 8.02s	remaining: 14.2s
# 722:	learn: 0.5092750	total: 8.03s	remaining: 14.2s
# 723:	learn: 0.5092722	total: 8.04s	remaining: 14.2s
# 724:	learn: 0.5092677	total: 8.05s	remaining: 14.2s
# 725:	learn: 0.5092647	total: 8.06s	remaining: 14.1s
# 726:	learn: 0.5092608	total: 8.07s	remaining: 14.1s
# 727:	learn: 0.5092571	total: 8.08s	remaining: 14.1s
# 728:	learn: 0.5092535	total: 8.09s	remaining: 14.1s
# 729:	learn: 0.5092503	total: 8.1s	remaining: 14.1s
# 730:	learn: 0.5092473	total: 8.11s	remaining: 14.1s
# 731:	learn: 0.5092434	total: 8.12s	remaining: 14.1s
# 732:	learn: 0.5092396	total: 8.13s	remaining: 14.1s
# 733:	learn: 0.5092355	total: 8.14s	remaining: 14s
# 734:	learn: 0.5092328	total: 8.15s	remaining: 14s
# 735:	learn: 0.5092293	total: 8.16s	remaining: 14s
# 736:	learn: 0.5092265	total: 8.17s	remaining: 14s
# 737:	learn: 0.5092227	total: 8.19s	remaining: 14s
# 738:	learn: 0.5092187	total: 8.2s	remaining: 14s
# 739:	learn: 0.5092149	total: 8.21s	remaining: 14s
# 740:	learn: 0.5092114	total: 8.22s	remaining: 14s
# 741:	learn: 0.5092084	total: 8.23s	remaining: 14s
# 742:	learn: 0.5092053	total: 8.24s	remaining: 13.9s
# 743:	learn: 0.5092013	total: 8.25s	remaining: 13.9s
# 744:	learn: 0.5091982	total: 8.26s	remaining: 13.9s
# 745:	learn: 0.5091953	total: 8.27s	remaining: 13.9s
# 746:	learn: 0.5091914	total: 8.28s	remaining: 13.9s
# 747:	learn: 0.5091861	total: 8.29s	remaining: 13.9s
# 748:	learn: 0.5091815	total: 8.3s	remaining: 13.9s
# 749:	learn: 0.5091784	total: 8.31s	remaining: 13.9s
# 750:	learn: 0.5091761	total: 8.32s	remaining: 13.8s
# 751:	learn: 0.5091720	total: 8.34s	remaining: 13.8s
# 752:	learn: 0.5091688	total: 8.35s	remaining: 13.8s
# 753:	learn: 0.5091655	total: 8.36s	remaining: 13.8s
# 754:	learn: 0.5091622	total: 8.37s	remaining: 13.8s
# 755:	learn: 0.5091592	total: 8.38s	remaining: 13.8s
# 756:	learn: 0.5091568	total: 8.39s	remaining: 13.8s
# 757:	learn: 0.5091515	total: 8.4s	remaining: 13.8s
# 758:	learn: 0.5091489	total: 8.41s	remaining: 13.7s
# 759:	learn: 0.5091462	total: 8.42s	remaining: 13.7s
# 760:	learn: 0.5091423	total: 8.43s	remaining: 13.7s
# 761:	learn: 0.5091394	total: 8.44s	remaining: 13.7s
# 762:	learn: 0.5091362	total: 8.45s	remaining: 13.7s
# 763:	learn: 0.5091323	total: 8.46s	remaining: 13.7s
# 764:	learn: 0.5091284	total: 8.48s	remaining: 13.7s
# 765:	learn: 0.5091253	total: 8.48s	remaining: 13.7s
# 766:	learn: 0.5091225	total: 8.49s	remaining: 13.7s
# 767:	learn: 0.5091189	total: 8.51s	remaining: 13.6s
# 768:	learn: 0.5091152	total: 8.52s	remaining: 13.6s
# 769:	learn: 0.5091109	total: 8.53s	remaining: 13.6s
# 770:	learn: 0.5091074	total: 8.54s	remaining: 13.6s
# 771:	learn: 0.5091037	total: 8.54s	remaining: 13.6s
# 772:	learn: 0.5090995	total: 8.56s	remaining: 13.6s
# 773:	learn: 0.5090959	total: 8.57s	remaining: 13.6s
# 774:	learn: 0.5090917	total: 8.58s	remaining: 13.6s
# 775:	learn: 0.5090888	total: 8.59s	remaining: 13.6s
# 776:	learn: 0.5090855	total: 8.6s	remaining: 13.5s
# 777:	learn: 0.5090821	total: 8.61s	remaining: 13.5s
# 778:	learn: 0.5090775	total: 8.62s	remaining: 13.5s
# 779:	learn: 0.5090744	total: 8.63s	remaining: 13.5s
# 780:	learn: 0.5090709	total: 8.65s	remaining: 13.5s
# 781:	learn: 0.5090680	total: 8.66s	remaining: 13.5s
# 782:	learn: 0.5090642	total: 8.67s	remaining: 13.5s
# 783:	learn: 0.5090615	total: 8.68s	remaining: 13.5s
# 784:	learn: 0.5090590	total: 8.69s	remaining: 13.5s
# 785:	learn: 0.5090548	total: 8.7s	remaining: 13.4s
# 786:	learn: 0.5090516	total: 8.71s	remaining: 13.4s
# 787:	learn: 0.5090490	total: 8.73s	remaining: 13.4s
# 788:	learn: 0.5090453	total: 8.74s	remaining: 13.4s
# 789:	learn: 0.5090414	total: 8.75s	remaining: 13.4s
# 790:	learn: 0.5090381	total: 8.76s	remaining: 13.4s
# 791:	learn: 0.5090355	total: 8.77s	remaining: 13.4s
# 792:	learn: 0.5090300	total: 8.78s	remaining: 13.4s
# 793:	learn: 0.5090257	total: 8.79s	remaining: 13.4s
# 794:	learn: 0.5090223	total: 8.8s	remaining: 13.3s
# 795:	learn: 0.5090194	total: 8.81s	remaining: 13.3s
# 796:	learn: 0.5090151	total: 8.82s	remaining: 13.3s
# 797:	learn: 0.5090101	total: 8.83s	remaining: 13.3s
# 798:	learn: 0.5090066	total: 8.85s	remaining: 13.3s
# 799:	learn: 0.5090031	total: 8.86s	remaining: 13.3s
# 800:	learn: 0.5090007	total: 8.87s	remaining: 13.3s
# 801:	learn: 0.5089983	total: 8.88s	remaining: 13.3s
# 802:	learn: 0.5089964	total: 8.89s	remaining: 13.3s
# 803:	learn: 0.5089917	total: 8.9s	remaining: 13.2s
# 804:	learn: 0.5089880	total: 8.91s	remaining: 13.2s
# 805:	learn: 0.5089842	total: 8.92s	remaining: 13.2s
# 806:	learn: 0.5089802	total: 8.93s	remaining: 13.2s
# 807:	learn: 0.5089765	total: 8.95s	remaining: 13.2s
# 808:	learn: 0.5089740	total: 8.95s	remaining: 13.2s
# 809:	learn: 0.5089700	total: 8.96s	remaining: 13.2s
# 810:	learn: 0.5089674	total: 8.98s	remaining: 13.2s
# 811:	learn: 0.5089643	total: 8.99s	remaining: 13.1s
# 812:	learn: 0.5089603	total: 9s	remaining: 13.1s
# 813:	learn: 0.5089568	total: 9.01s	remaining: 13.1s
# 814:	learn: 0.5089534	total: 9.02s	remaining: 13.1s
# 815:	learn: 0.5089502	total: 9.03s	remaining: 13.1s
# 816:	learn: 0.5089475	total: 9.04s	remaining: 13.1s
# 817:	learn: 0.5089442	total: 9.05s	remaining: 13.1s
# 818:	learn: 0.5089419	total: 9.06s	remaining: 13.1s
# 819:	learn: 0.5089391	total: 9.07s	remaining: 13.1s
# 820:	learn: 0.5089345	total: 9.09s	remaining: 13s
# 821:	learn: 0.5089322	total: 9.1s	remaining: 13s
# 822:	learn: 0.5089258	total: 9.11s	remaining: 13s
# 823:	learn: 0.5089221	total: 9.12s	remaining: 13s
# 824:	learn: 0.5089187	total: 9.13s	remaining: 13s
# 825:	learn: 0.5089145	total: 9.14s	remaining: 13s
# 826:	learn: 0.5089106	total: 9.15s	remaining: 13s
# 827:	learn: 0.5089070	total: 9.16s	remaining: 13s
# 828:	learn: 0.5089035	total: 9.18s	remaining: 13s
# 829:	learn: 0.5089008	total: 9.19s	remaining: 12.9s
# 830:	learn: 0.5088980	total: 9.2s	remaining: 12.9s
# 831:	learn: 0.5088958	total: 9.21s	remaining: 12.9s
# 832:	learn: 0.5088927	total: 9.22s	remaining: 12.9s
# 833:	learn: 0.5088897	total: 9.23s	remaining: 12.9s
# 834:	learn: 0.5088859	total: 9.24s	remaining: 12.9s
# 835:	learn: 0.5088825	total: 9.25s	remaining: 12.9s
# 836:	learn: 0.5088785	total: 9.26s	remaining: 12.9s
# 837:	learn: 0.5088746	total: 9.28s	remaining: 12.9s
# 838:	learn: 0.5088717	total: 9.29s	remaining: 12.9s
# 839:	learn: 0.5088683	total: 9.3s	remaining: 12.8s
# 840:	learn: 0.5088653	total: 9.31s	remaining: 12.8s
# 841:	learn: 0.5088623	total: 9.32s	remaining: 12.8s
# 842:	learn: 0.5088597	total: 9.33s	remaining: 12.8s
# 843:	learn: 0.5088564	total: 9.34s	remaining: 12.8s
# 844:	learn: 0.5088537	total: 9.35s	remaining: 12.8s
# 845:	learn: 0.5088503	total: 9.36s	remaining: 12.8s
# 846:	learn: 0.5088472	total: 9.37s	remaining: 12.8s
# 847:	learn: 0.5088439	total: 9.38s	remaining: 12.7s
# 848:	learn: 0.5088392	total: 9.39s	remaining: 12.7s
# 849:	learn: 0.5088367	total: 9.4s	remaining: 12.7s
# 850:	learn: 0.5088332	total: 9.41s	remaining: 12.7s
# 851:	learn: 0.5088305	total: 9.43s	remaining: 12.7s
# 852:	learn: 0.5088277	total: 9.44s	remaining: 12.7s
# 853:	learn: 0.5088246	total: 9.45s	remaining: 12.7s
# 854:	learn: 0.5088210	total: 9.46s	remaining: 12.7s
# 855:	learn: 0.5088180	total: 9.47s	remaining: 12.7s
# 856:	learn: 0.5088155	total: 9.48s	remaining: 12.6s
# 857:	learn: 0.5088115	total: 9.49s	remaining: 12.6s
# 858:	learn: 0.5088089	total: 9.5s	remaining: 12.6s
# 859:	learn: 0.5088065	total: 9.51s	remaining: 12.6s
# 860:	learn: 0.5088022	total: 9.52s	remaining: 12.6s
# 861:	learn: 0.5087989	total: 9.54s	remaining: 12.6s
# 862:	learn: 0.5087965	total: 9.55s	remaining: 12.6s
# 863:	learn: 0.5087927	total: 9.56s	remaining: 12.6s
# 864:	learn: 0.5087889	total: 9.57s	remaining: 12.6s
# 865:	learn: 0.5087845	total: 9.58s	remaining: 12.5s
# 866:	learn: 0.5087813	total: 9.59s	remaining: 12.5s
# 867:	learn: 0.5087775	total: 9.61s	remaining: 12.5s
# 868:	learn: 0.5087734	total: 9.62s	remaining: 12.5s
# 869:	learn: 0.5087700	total: 9.63s	remaining: 12.5s
# 870:	learn: 0.5087673	total: 9.64s	remaining: 12.5s
# 871:	learn: 0.5087635	total: 9.65s	remaining: 12.5s
# 872:	learn: 0.5087608	total: 9.66s	remaining: 12.5s
# 873:	learn: 0.5087582	total: 9.68s	remaining: 12.5s
# 874:	learn: 0.5087554	total: 9.69s	remaining: 12.5s
# 875:	learn: 0.5087517	total: 9.7s	remaining: 12.4s
# 876:	learn: 0.5087485	total: 9.71s	remaining: 12.4s
# 877:	learn: 0.5087455	total: 9.72s	remaining: 12.4s
# 878:	learn: 0.5087425	total: 9.73s	remaining: 12.4s
# 879:	learn: 0.5087384	total: 9.74s	remaining: 12.4s
# 880:	learn: 0.5087351	total: 9.75s	remaining: 12.4s
# 881:	learn: 0.5087313	total: 9.77s	remaining: 12.4s
# 882:	learn: 0.5087288	total: 9.78s	remaining: 12.4s
# 883:	learn: 0.5087261	total: 9.79s	remaining: 12.4s
# 884:	learn: 0.5087229	total: 9.8s	remaining: 12.3s
# 885:	learn: 0.5087192	total: 9.81s	remaining: 12.3s
# 886:	learn: 0.5087162	total: 9.82s	remaining: 12.3s
# 887:	learn: 0.5087127	total: 9.83s	remaining: 12.3s
# 888:	learn: 0.5087102	total: 9.84s	remaining: 12.3s
# 889:	learn: 0.5087078	total: 9.85s	remaining: 12.3s
# 890:	learn: 0.5087047	total: 9.86s	remaining: 12.3s
# 891:	learn: 0.5087022	total: 9.87s	remaining: 12.3s
# 892:	learn: 0.5086984	total: 9.88s	remaining: 12.3s
# 893:	learn: 0.5086956	total: 9.89s	remaining: 12.2s
# 894:	learn: 0.5086898	total: 9.9s	remaining: 12.2s
# 895:	learn: 0.5086868	total: 9.91s	remaining: 12.2s
# 896:	learn: 0.5086833	total: 9.93s	remaining: 12.2s
# 897:	learn: 0.5086800	total: 9.94s	remaining: 12.2s
# 898:	learn: 0.5086768	total: 9.95s	remaining: 12.2s
# 899:	learn: 0.5086740	total: 9.96s	remaining: 12.2s
# 900:	learn: 0.5086702	total: 9.97s	remaining: 12.2s
# 901:	learn: 0.5086677	total: 9.98s	remaining: 12.1s
# 902:	learn: 0.5086626	total: 9.99s	remaining: 12.1s
# 903:	learn: 0.5086596	total: 10s	remaining: 12.1s
# 904:	learn: 0.5086562	total: 10s	remaining: 12.1s
# 905:	learn: 0.5086538	total: 10s	remaining: 12.1s
# 906:	learn: 0.5086505	total: 10s	remaining: 12.1s
# 907:	learn: 0.5086477	total: 10s	remaining: 12.1s
# 908:	learn: 0.5086447	total: 10.1s	remaining: 12.1s
# 909:	learn: 0.5086424	total: 10.1s	remaining: 12.1s
# 910:	learn: 0.5086382	total: 10.1s	remaining: 12s
# ...
# 1812:	learn: 0.5067216	total: 20.2s	remaining: 2.08s
# 1813:	learn: 0.5067194	total: 20.2s	remaining: 2.07s
# 1814:	learn: 0.5067174	total: 20.2s	remaining: 2.06s
# 1815:	learn: 0.5067145	total: 20.2s	remaining: 2.05s
# 1816:	learn: 0.5067118	total: 20.2s	remaining: 2.04s
# 1817:	learn: 0.5067090	total: 20.2s	remaining: 2.02s
# 1818:	learn: 0.5067066	total: 20.2s	remaining: 2.01s
# 1819:	learn: 0.5067050	total: 20.3s	remaining: 2s
# 1820:	learn: 0.5067023	total: 20.3s	remaining: 1.99s
# 1821:	learn: 0.5067005	total: 20.3s	remaining: 1.98s
# 1822:	learn: 0.5066979	total: 20.3s	remaining: 1.97s
# 1823:	learn: 0.5066952	total: 20.3s	remaining: 1.96s
# 1824:	learn: 0.5066935	total: 20.3s	remaining: 1.95s
# 1825:	learn: 0.5066913	total: 20.3s	remaining: 1.94s
# 1826:	learn: 0.5066891	total: 20.3s	remaining: 1.93s
# 1827:	learn: 0.5066862	total: 20.3s	remaining: 1.91s
# 1828:	learn: 0.5066836	total: 20.4s	remaining: 1.9s
# 1829:	learn: 0.5066814	total: 20.4s	remaining: 1.89s
# 1830:	learn: 0.5066785	total: 20.4s	remaining: 1.88s
# 1831:	learn: 0.5066760	total: 20.4s	remaining: 1.87s
# 1832:	learn: 0.5066735	total: 20.4s	remaining: 1.86s
# 1833:	learn: 0.5066707	total: 20.4s	remaining: 1.85s
# 1834:	learn: 0.5066679	total: 20.4s	remaining: 1.84s
# 1835:	learn: 0.5066648	total: 20.4s	remaining: 1.82s
# 1836:	learn: 0.5066618	total: 20.4s	remaining: 1.81s
# 1837:	learn: 0.5066592	total: 20.5s	remaining: 1.8s
# 1838:	learn: 0.5066568	total: 20.5s	remaining: 1.79s
# 1839:	learn: 0.5066542	total: 20.5s	remaining: 1.78s
# 1840:	learn: 0.5066519	total: 20.5s	remaining: 1.77s
# 1841:	learn: 0.5066488	total: 20.5s	remaining: 1.76s
# 1842:	learn: 0.5066465	total: 20.5s	remaining: 1.75s
# 1843:	learn: 0.5066444	total: 20.5s	remaining: 1.74s
# 1844:	learn: 0.5066422	total: 20.5s	remaining: 1.73s
# 1845:	learn: 0.5066397	total: 20.5s	remaining: 1.71s
# 1846:	learn: 0.5066364	total: 20.6s	remaining: 1.7s
# 1847:	learn: 0.5066338	total: 20.6s	remaining: 1.69s
# 1848:	learn: 0.5066318	total: 20.6s	remaining: 1.68s
# 1849:	learn: 0.5066293	total: 20.6s	remaining: 1.67s
# 1850:	learn: 0.5066269	total: 20.6s	remaining: 1.66s
# 1851:	learn: 0.5066238	total: 20.6s	remaining: 1.65s
# 1852:	learn: 0.5066215	total: 20.6s	remaining: 1.64s
# 1853:	learn: 0.5066191	total: 20.6s	remaining: 1.62s
# 1854:	learn: 0.5066173	total: 20.6s	remaining: 1.61s
# 1855:	learn: 0.5066146	total: 20.7s	remaining: 1.6s
# 1856:	learn: 0.5066122	total: 20.7s	remaining: 1.59s
# 1857:	learn: 0.5066102	total: 20.7s	remaining: 1.58s
# 1858:	learn: 0.5066085	total: 20.7s	remaining: 1.57s
# 1859:	learn: 0.5066064	total: 20.7s	remaining: 1.56s
# 1860:	learn: 0.5066036	total: 20.7s	remaining: 1.55s
# 1861:	learn: 0.5066010	total: 20.7s	remaining: 1.53s
# 1862:	learn: 0.5065978	total: 20.7s	remaining: 1.52s
# 1863:	learn: 0.5065953	total: 20.7s	remaining: 1.51s
# 1864:	learn: 0.5065929	total: 20.8s	remaining: 1.5s
# 1865:	learn: 0.5065906	total: 20.8s	remaining: 1.49s
# 1866:	learn: 0.5065881	total: 20.8s	remaining: 1.48s
# 1867:	learn: 0.5065860	total: 20.8s	remaining: 1.47s
# 1868:	learn: 0.5065833	total: 20.8s	remaining: 1.46s
# 1869:	learn: 0.5065810	total: 20.8s	remaining: 1.45s
# 1870:	learn: 0.5065791	total: 20.8s	remaining: 1.44s
# 1871:	learn: 0.5065764	total: 20.8s	remaining: 1.42s
# 1872:	learn: 0.5065740	total: 20.8s	remaining: 1.41s
# 1873:	learn: 0.5065711	total: 20.9s	remaining: 1.4s
# 1874:	learn: 0.5065684	total: 20.9s	remaining: 1.39s
# 1875:	learn: 0.5065658	total: 20.9s	remaining: 1.38s
# 1876:	learn: 0.5065638	total: 20.9s	remaining: 1.37s
# 1877:	learn: 0.5065613	total: 20.9s	remaining: 1.36s
# 1878:	learn: 0.5065589	total: 20.9s	remaining: 1.35s
# 1879:	learn: 0.5065559	total: 20.9s	remaining: 1.33s
# 1880:	learn: 0.5065533	total: 20.9s	remaining: 1.32s
# 1881:	learn: 0.5065512	total: 20.9s	remaining: 1.31s
# 1882:	learn: 0.5065484	total: 21s	remaining: 1.3s
# 1883:	learn: 0.5065455	total: 21s	remaining: 1.29s
# 1884:	learn: 0.5065427	total: 21s	remaining: 1.28s
# 1885:	learn: 0.5065391	total: 21s	remaining: 1.27s
# 1886:	learn: 0.5065373	total: 21s	remaining: 1.26s
# 1887:	learn: 0.5065354	total: 21s	remaining: 1.25s
# 1888:	learn: 0.5065327	total: 21s	remaining: 1.24s
# 1889:	learn: 0.5065305	total: 21s	remaining: 1.22s
# 1890:	learn: 0.5065281	total: 21s	remaining: 1.21s
# 1891:	learn: 0.5065257	total: 21.1s	remaining: 1.2s
# 1892:	learn: 0.5065224	total: 21.1s	remaining: 1.19s
# 1893:	learn: 0.5065205	total: 21.1s	remaining: 1.18s
# 1894:	learn: 0.5065177	total: 21.1s	remaining: 1.17s
# 1895:	learn: 0.5065157	total: 21.1s	remaining: 1.16s
# 1896:	learn: 0.5065130	total: 21.1s	remaining: 1.15s
# 1897:	learn: 0.5065104	total: 21.1s	remaining: 1.13s
# 1898:	learn: 0.5065076	total: 21.1s	remaining: 1.12s
# 1899:	learn: 0.5065048	total: 21.1s	remaining: 1.11s
# 1900:	learn: 0.5065019	total: 21.1s	remaining: 1.1s
# 1901:	learn: 0.5064998	total: 21.2s	remaining: 1.09s
# 1902:	learn: 0.5064974	total: 21.2s	remaining: 1.08s
# 1903:	learn: 0.5064939	total: 21.2s	remaining: 1.07s
# 1904:	learn: 0.5064915	total: 21.2s	remaining: 1.06s
# 1905:	learn: 0.5064892	total: 21.2s	remaining: 1.04s
# 1906:	learn: 0.5064874	total: 21.2s	remaining: 1.03s
# 1907:	learn: 0.5064850	total: 21.2s	remaining: 1.02s
# 1908:	learn: 0.5064821	total: 21.2s	remaining: 1.01s
# 1909:	learn: 0.5064794	total: 21.3s	remaining: 1s
# 1910:	learn: 0.5064770	total: 21.3s	remaining: 990ms
# 1911:	learn: 0.5064743	total: 21.3s	remaining: 979ms
# 1912:	learn: 0.5064723	total: 21.3s	remaining: 968ms
# 1913:	learn: 0.5064697	total: 21.3s	remaining: 957ms
# 1914:	learn: 0.5064671	total: 21.3s	remaining: 946ms
# 1915:	learn: 0.5064644	total: 21.3s	remaining: 935ms
# 1916:	learn: 0.5064617	total: 21.3s	remaining: 924ms
# 1917:	learn: 0.5064591	total: 21.3s	remaining: 912ms
# 1918:	learn: 0.5064567	total: 21.4s	remaining: 901ms
# 1919:	learn: 0.5064545	total: 21.4s	remaining: 890ms
# 1920:	learn: 0.5064517	total: 21.4s	remaining: 879ms
# 1921:	learn: 0.5064490	total: 21.4s	remaining: 868ms
# 1922:	learn: 0.5064474	total: 21.4s	remaining: 857ms
# 1923:	learn: 0.5064447	total: 21.4s	remaining: 846ms
# 1924:	learn: 0.5064427	total: 21.4s	remaining: 834ms
# 1925:	learn: 0.5064402	total: 21.4s	remaining: 823ms
# 1926:	learn: 0.5064376	total: 21.4s	remaining: 812ms
# 1927:	learn: 0.5064348	total: 21.4s	remaining: 801ms
# 1928:	learn: 0.5064326	total: 21.5s	remaining: 790ms
# 1929:	learn: 0.5064301	total: 21.5s	remaining: 779ms
# 1930:	learn: 0.5064281	total: 21.5s	remaining: 768ms
# 1931:	learn: 0.5064255	total: 21.5s	remaining: 757ms
# 1932:	learn: 0.5064232	total: 21.5s	remaining: 745ms
# 1933:	learn: 0.5064202	total: 21.5s	remaining: 734ms
# 1934:	learn: 0.5064177	total: 21.5s	remaining: 723ms
# 1935:	learn: 0.5064150	total: 21.5s	remaining: 712ms
# 1936:	learn: 0.5064116	total: 21.5s	remaining: 701ms
# 1937:	learn: 0.5064090	total: 21.6s	remaining: 690ms
# 1938:	learn: 0.5064067	total: 21.6s	remaining: 679ms
# 1939:	learn: 0.5064044	total: 21.6s	remaining: 668ms
# 1940:	learn: 0.5064016	total: 21.6s	remaining: 656ms
# 1941:	learn: 0.5063987	total: 21.6s	remaining: 645ms
# 1942:	learn: 0.5063962	total: 21.6s	remaining: 634ms
# 1943:	learn: 0.5063934	total: 21.6s	remaining: 623ms
# 1944:	learn: 0.5063912	total: 21.6s	remaining: 612ms
# 1945:	learn: 0.5063888	total: 21.7s	remaining: 601ms
# 1946:	learn: 0.5063867	total: 21.7s	remaining: 590ms
# 1947:	learn: 0.5063839	total: 21.7s	remaining: 579ms
# 1948:	learn: 0.5063812	total: 21.7s	remaining: 567ms
# 1949:	learn: 0.5063786	total: 21.7s	remaining: 556ms
# 1950:	learn: 0.5063761	total: 21.7s	remaining: 545ms
# 1951:	learn: 0.5063734	total: 21.7s	remaining: 534ms
# 1952:	learn: 0.5063712	total: 21.7s	remaining: 523ms
# 1953:	learn: 0.5063683	total: 21.7s	remaining: 512ms
# 1954:	learn: 0.5063658	total: 21.8s	remaining: 501ms
# 1955:	learn: 0.5063632	total: 21.8s	remaining: 490ms
# 1956:	learn: 0.5063605	total: 21.8s	remaining: 479ms
# 1957:	learn: 0.5063583	total: 21.8s	remaining: 467ms
# 1958:	learn: 0.5063562	total: 21.8s	remaining: 456ms
# 1959:	learn: 0.5063530	total: 21.8s	remaining: 445ms
# 1960:	learn: 0.5063506	total: 21.8s	remaining: 434ms
# 1961:	learn: 0.5063486	total: 21.8s	remaining: 423ms
# 1962:	learn: 0.5063455	total: 21.8s	remaining: 412ms
# 1963:	learn: 0.5063429	total: 21.9s	remaining: 401ms
# 1964:	learn: 0.5063408	total: 21.9s	remaining: 389ms
# 1965:	learn: 0.5063379	total: 21.9s	remaining: 378ms
# 1966:	learn: 0.5063355	total: 21.9s	remaining: 367ms
# 1967:	learn: 0.5063332	total: 21.9s	remaining: 356ms
# 1968:	learn: 0.5063306	total: 21.9s	remaining: 345ms
# 1969:	learn: 0.5063282	total: 21.9s	remaining: 334ms
# 1970:	learn: 0.5063262	total: 21.9s	remaining: 323ms
# 1971:	learn: 0.5063234	total: 21.9s	remaining: 312ms
# 1972:	learn: 0.5063212	total: 21.9s	remaining: 300ms
# 1973:	learn: 0.5063184	total: 22s	remaining: 289ms
# 1974:	learn: 0.5063164	total: 22s	remaining: 278ms
# 1975:	learn: 0.5063143	total: 22s	remaining: 267ms
# 1976:	learn: 0.5063125	total: 22s	remaining: 256ms
# 1977:	learn: 0.5063093	total: 22s	remaining: 245ms
# 1978:	learn: 0.5063073	total: 22s	remaining: 234ms
# 1979:	learn: 0.5063048	total: 22s	remaining: 222ms
# 1980:	learn: 0.5063025	total: 22s	remaining: 211ms
# 1981:	learn: 0.5062996	total: 22s	remaining: 200ms
# 1982:	learn: 0.5062977	total: 22.1s	remaining: 189ms
# 1983:	learn: 0.5062955	total: 22.1s	remaining: 178ms
# 1984:	learn: 0.5062930	total: 22.1s	remaining: 167ms
# 1985:	learn: 0.5062905	total: 22.1s	remaining: 156ms
# 1986:	learn: 0.5062875	total: 22.1s	remaining: 145ms
# 1987:	learn: 0.5062850	total: 22.1s	remaining: 133ms
# 1988:	learn: 0.5062822	total: 22.1s	remaining: 122ms
# 1989:	learn: 0.5062798	total: 22.1s	remaining: 111ms
# 1990:	learn: 0.5062776	total: 22.1s	remaining: 100ms
# 1991:	learn: 0.5062754	total: 22.2s	remaining: 89ms
# 1992:	learn: 0.5062732	total: 22.2s	remaining: 77.9ms
# 1993:	learn: 0.5062707	total: 22.2s	remaining: 66.7ms
# 1994:	learn: 0.5062682	total: 22.2s	remaining: 55.6ms
# 1995:	learn: 0.5062657	total: 22.2s	remaining: 44.5ms
# 1996:	learn: 0.5062634	total: 22.2s	remaining: 33.4ms
# 1997:	learn: 0.5062603	total: 22.2s	remaining: 22.2ms
# 1998:	learn: 0.5062579	total: 22.2s	remaining: 11.1ms
# 1999:	learn: 0.5062550	total: 22.2s	remaining: 0us
# {'nan_mode': 'Min', 'gpu_ram_part': 0.95, 'eval_metric': 'Logloss', 'iterations': 2000, 'leaf_estimation_method': 'Newton', 'observations_to_bootstrap': 'TestOnly', 'grow_policy': 'SymmetricTree', 'boosting_type': 'Plain', 'feature_border_type': 'GreedyLogSum', 'bayesian_matrix_reg': 0.10000000149011612, 'devices': '-1', 'pinned_memory_bytes': '104857600', 'l2_leaf_reg': 3, 'random_strength': 1, 'rsm': 1, 'boost_from_average': False, 'gpu_cat_features_storage': 'GpuRam', 'fold_size_loss_normalization': False, 'model_size_reg': 0.5, 'pool_metainfo_options': {'tags': {}}, 'use_best_model': False, 'meta_l2_frequency': 0, 'class_names': [0, 1], 'random_seed': 42, 'depth': 6, 'border_count': 128, 'min_fold_size': 100, 'data_partition': 'DocParallel', 'bagging_temperature': 1, 'classes_count': 0, 'auto_class_weights': 'None', 'leaf_estimation_backtracking': 'AnyImprovement', 'best_model_min_trees': 1, 'min_data_in_leaf': 1, 'add_ridge_penalty_to_loss_function': False, 'loss_function': 'Logloss', 'learning_rate': 0.012571999803185465, 'meta_l2_exponent': 1, 'score_function': 'Cosine', 'task_type': 'GPU', 'leaf_estimation_iterations': 10, 'bootstrap_type': 'Bayesian', 'max_leaves': 64}
# Valid log-loss is 7.820008862040665
# Valid AUC is 0.7739675501478824
# <br/>Waiting for W&B process to finish, PID 1315963<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.83MB of 0.83MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_123806-146d4d9r/logs/debug.log</code>
# Find internal logs for this run at: <code>/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/sep2021/wandb/run-20210909_123806-146d4d9r/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>7.8338</td></tr><tr><td>train_auc</td><td>0.77356</td></tr><tr><td>_runtime</td><td>102</td></tr><tr><td>_timestamp</td><td>1631216388</td></tr><tr><td>_step</td><td>3</td></tr><tr><td>nan_mode</td><td>Min</td></tr><tr><td>gpu_ram_part</td><td>0.95</td></tr><tr><td>eval_metric</td><td>Logloss</td></tr><tr><td>iterations</td><td>2000</td></tr><tr><td>leaf_estimation_method</td><td>Newton</td></tr><tr><td>observations_to_bootstrap</td><td>TestOnly</td></tr><tr><td>grow_policy</td><td>SymmetricTree</td></tr><tr><td>boosting_type</td><td>Plain</td></tr><tr><td>feature_border_type</td><td>GreedyLogSum</td></tr><tr><td>bayesian_matrix_reg</td><td>0.1</td></tr><tr><td>devices</td><td>-1</td></tr><tr><td>pinned_memory_bytes</td><td>104857600</td></tr><tr><td>l2_leaf_reg</td><td>3</td></tr><tr><td>random_strength</td><td>1</td></tr><tr><td>rsm</td><td>1</td></tr><tr><td>boost_from_average</td><td>False</td></tr><tr><td>gpu_cat_features_storage</td><td>GpuRam</td></tr><tr><td>fold_size_loss_normalization</td><td>False</td></tr><tr><td>model_size_reg</td><td>0.5</td></tr><tr><td>use_best_model</td><td>False</td></tr><tr><td>meta_l2_frequency</td><td>0</td></tr><tr><td>random_seed</td><td>42</td></tr><tr><td>depth</td><td>6</td></tr><tr><td>border_count</td><td>128</td></tr><tr><td>min_fold_size</td><td>100</td></tr><tr><td>data_partition</td><td>DocParallel</td></tr><tr><td>bagging_temperature</td><td>1</td></tr><tr><td>classes_count</td><td>0</td></tr><tr><td>auto_class_weights</td><td>None</td></tr><tr><td>leaf_estimation_backtracking</td><td>AnyImprovement</td></tr><tr><td>best_model_min_trees</td><td>1</td></tr><tr><td>min_data_in_leaf</td><td>1</td></tr><tr><td>add_ridge_penalty_to_loss_function</td><td>False</td></tr><tr><td>loss_function</td><td>Logloss</td></tr><tr><td>learning_rate</td><td>0.01257</td></tr><tr><td>meta_l2_exponent</td><td>1</td></tr><tr><td>score_function</td><td>Cosine</td></tr><tr><td>task_type</td><td>GPU</td></tr><tr><td>leaf_estimation_iterations</td><td>10</td></tr><tr><td>bootstrap_type</td><td>Bayesian</td></tr><tr><td>max_leaves</td><td>64</td></tr><tr><td>valid_loss</td><td>7.82001</td></tr><tr><td>valid_auc</td><td>0.77397</td></tr><tr><td>fold</td><td>4</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>_runtime</td><td>▁▁██</td></tr><tr><td>_timestamp</td><td>▁▁██</td></tr><tr><td>_step</td><td>▁▃▆█</td></tr><tr><td>gpu_ram_part</td><td>▁</td></tr><tr><td>iterations</td><td>▁</td></tr><tr><td>bayesian_matrix_reg</td><td>▁</td></tr><tr><td>l2_leaf_reg</td><td>▁</td></tr><tr><td>random_strength</td><td>▁</td></tr><tr><td>rsm</td><td>▁</td></tr><tr><td>boost_from_average</td><td>▁</td></tr><tr><td>fold_size_loss_normalization</td><td>▁</td></tr><tr><td>model_size_reg</td><td>▁</td></tr><tr><td>use_best_model</td><td>▁</td></tr><tr><td>meta_l2_frequency</td><td>▁</td></tr><tr><td>random_seed</td><td>▁</td></tr><tr><td>depth</td><td>▁</td></tr><tr><td>border_count</td><td>▁</td></tr><tr><td>min_fold_size</td><td>▁</td></tr><tr><td>bagging_temperature</td><td>▁</td></tr><tr><td>classes_count</td><td>▁</td></tr><tr><td>best_model_min_trees</td><td>▁</td></tr><tr><td>min_data_in_leaf</td><td>▁</td></tr><tr><td>add_ridge_penalty_to_loss_function</td><td>▁</td></tr><tr><td>learning_rate</td><td>▁</td></tr><tr><td>meta_l2_exponent</td><td>▁</td></tr><tr><td>leaf_estimation_iterations</td><td>▁</td></tr><tr><td>max_leaves</td><td>▁</td></tr><tr><td>valid_loss</td><td>▁</td></tr><tr><td>valid_auc</td><td>▁</td></tr><tr><td>fold</td><td>▁</td></tr></table><br/>
# Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">baseline_20210909_114059</strong>: <a href="https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/146d4d9r" target="_blank">https://wandb.ai/hushifang/202109_Kaggle_tabular_playground/runs/146d4d9r</a><br/>

# %%
# # this loads models if you need to (or forgot to save them on training above)
# xgboost_models = {}
# xgboost_models_path = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/sep2021/models/baseline_20210905a_152521_5folds/xgboost/')
# for fold in range(5):
#     xgboost_models[fold] = load(xgboost_models_path/f'xgboost_fold{fold}_model.joblib')

# %% [markdown]
# # Inference

# %%
test_df = pd.read_csv(datapath/'test.csv', index_col='id', low_memory=False)
# test_df.to_feather(datapath/'test.feather') # issue with index being non-default; fix later
# test_df = pd.read_feather(datapath/'test.feather')

# %%
test_df.head()
# Out:
#               f1        f2        f3       f4       f5       f6       f7  \
# id
# 957919  0.165850  0.487050   1295.00  0.02310  0.31900  0.90188   573.29
# 957920  0.129650  0.373480   1763.00  0.72884  0.33247 -1.26310   875.55
# 957921  0.120190  0.445210    736.26  0.04615  0.29605  0.31665  2659.50
# 957922  0.054008  0.395960    996.14  0.85934  0.36678 -0.17060   386.56
# 957923  0.079947 -0.006919  10574.00  0.34845  0.45008 -1.84200  3027.00
#
#               f8            f9       f10  ...     f109     f110    f111  \
# id                                        ...
# 957919    3743.7  2.705700e+12  6221.000  ...  0.16253 -22.1890  2.0655
# 957920  554370.0  5.955700e+14   934.430  ...  0.81528  -1.6342  1.5736
# 957921  317140.0  3.977800e+14   131.810  ...  0.81831 -32.7800  2.1364
# 957922  325680.0 -3.432200e+13   -26.473  ...  0.86559  -2.4162  1.5199
# 957923  428150.0  9.291500e+11  5999.400  ...  0.25190 -18.6300  3.7387
#
#             f112     f113     f114    f115          f116    f117     f118
# id
# 957919  0.430880 -10.7410  81606.0  1.1940  1.980400e+14  2017.1  0.46357
# 957920 -1.071200  11.8320  90114.0  1.1507  4.388000e+16  6638.9  0.28125
# 957921 -1.931200  -3.2804  37739.0  1.1548  1.718100e+14  5844.0  0.13797
# 957922 -0.011633   1.3840  26849.0  1.1490  2.138800e+17  6173.3  0.32910
# 957923  0.757080  -4.9405  50336.0  1.2488  2.151300e+17  2250.1  0.33796
#
# [5 rows x 118 columns]

# %% [markdown]
# (Here's where encapsulating the transformations in a pipeline would come in handy. But I'll do it manually for now.)

# %%
features = [x for x in test_df.columns if x != 'claim']
X_test = test_df[features] # this is just for naming consistency

# %% [markdown]
# Now, let's get the features the model was trained on and subset the test set's features accordingly

# %%
# generation polynomial features
# poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
# X_test_poly = poly.fit_transform(X_test)

# %%
# X_test_poly_names = poly.get_feature_names(X_test.columns)
# X_poly_names[100:150]
# features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
# checks = [feature in X_test_poly_names for feature in features]
# checks

# %%
# X_test_final = pd.DataFrame(X_test_poly, columns=X_test_poly_names)

# %%
# X_test_final = X_test_final[features[1:]]
# X_test_final = X_test

# %% [markdown]
# # Scaling
# Now, going to scale using `MaxAbsScaler`

# %%
scaler = exmodel_config['scaler']()
X_test_scaled = scaler.fit_transform(X_test)
# X_scaled_df = pd.DataFrame(X_scaled, columns=X_poly_names)

# %%
xgboost_preds = {}
for fold in xgboost_models.keys():
    xgboost_preds[fold] = xgboost_models[fold].predict(X_test_scaled)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-0fbb9e76b22e> in <module>
#       1 xgboost_preds = {}
#       2 for fold in xgboost_models.keys():
# ----> 3     xgboost_preds[fold] = xgboost_models[fold].predict(X_test_scaled)
#
# ~/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1207         iteration_range: Optional[Tuple[int, int]] = None,
#    1208     ):
# -> 1209         class_probs = super().predict(
#    1210             X=X,
#    1211             output_margin=output_margin,
#
# ~/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#     818         if self._can_use_inplace_predict():
#     819             try:
# --> 820                 predts = self.get_booster().inplace_predict(
#     821                     data=X,
#     822                     iteration_range=iteration_range,
#
# ~/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/core.py in inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    1836         if validate_features:
#    1837             if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# -> 1838                 raise ValueError(
#    1839                     f"Feature shape mismatch, expected: {self.num_features()}, "
#    1840                     f"got {data.shape[0]}"
#
# ValueError: Feature shape mismatch, expected: 237, got 493474

# %%
lightgbm_preds = {}
for fold in lightgbm_models.keys():
    lightgbm_preds[fold] = lightgbm_models[fold].predict(X_test_scaled)

# %%
catboost_preds = {}
for fold in catboost_models.keys():
    catboost_preds[fold] = catboost_models[fold].predict(X_test_scaled)

# %%
preds_path = Path(datapath/f"preds/{config_run['name']}_{exmodel_config['kfolds']}folds/")
preds_path.mkdir(exist_ok=True)

for library in ['xgboost', 'lightgbm', 'catboost']:
    (preds_path/library).mkdir(exist_ok=True)

# %%
dump(xgboost_preds, Path(preds_path/'xgboost/xgboost_preds_dict.joblib'))

# %%
dump(lightgbm_preds, Path(preds_path/'lightgbm/lightgbm_preds_dict.joblib'))

# %%
dump(catboost_preds, Path(preds_path/'catboost/catboost_preds_dict.joblib'))

# %%
sample_df = pd.read_csv(datapath/'sample_solution.csv')

# %%
final_xgboost_preds = (xgboost_preds[0] + xgboost_preds[1] + xgboost_preds[2] + xgboost_preds[3] + xgboost_preds[4]) / 5
final_lightgbm_preds = (lightgbm_preds[0] + lightgbm_preds[1] + lightgbm_preds[2] + lightgbm_preds[3] + lightgbm_preds[4]) / 5
final_catboost_preds = (catboost_preds[0] + catboost_preds[1] + catboost_preds[2] + catboost_preds[3] + catboost_preds[4]) / 5

# %%
print(final_xgboost_preds[:10])
print(final_lightgbm_preds[:10])
print(final_catboost_preds[:10])

# %%
sample_df.loc[:, 'claim'] = final_xgboost_preds

# %%
sample_df.head()

# %%
submission_path = datapath/'submissions'
submission_path.mkdir(exist_ok=True)

# %%
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_xgboost-mean.csv", index=False)

# %%
sample_df.loc[:, 'claim'] = final_lightgbm_preds
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_lightgbm-mean.csv", index=False)

# %%
sample_df.loc[:, 'claim'] = final_catboost_preds
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_catboost-mean.csv", index=False)

# %%
ensemble_preds = (final_xgboost_preds + final_lightgbm_preds + final_catboost_preds) / 3

# %%
sample_df.loc[:, 'claim'] = ensemble_preds
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_ensemble-equal_model_and_fold_weight_mean.csv", index=False)

# %%
ensemble_preds = 0.4*final_xgboost_preds + 0.3*final_lightgbm_preds + 0.3*final_catboost_preds

# %%
sample_df.loc[:, 'claim'] = ensemble_preds
sample_df.to_csv(submission_path/f"{config_run['name']}_{exmodel_config['kfolds']}folds_ensemble-0.4xgboost_0.3lightgbm_0.3catboost-equal_fold_weight_mean.csv", index=False)

# %% [markdown]
# # Ensembling with CatBoost

# %%
catboost_models = {}
saved_models_path = Path('/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/models/CatBoost_ensemble_20210831_144245_5folds/')
for fold in range(5):
    catboost_models[fold] = load(filename=Path(saved_models_path/f'catboost_fold{fold}_model.joblib'))

# %%
catboost_models
# Out:
# {0: <catboost.core.CatBoostRegressor at 0x7f1b154ecfa0>,
#  1: <catboost.core.CatBoostRegressor at 0x7f1b1548a880>,
#  2: <catboost.core.CatBoostRegressor at 0x7f1b154ec0a0>,
#  3: <catboost.core.CatBoostRegressor at 0x7f1b1548ac40>,
#  4: <catboost.core.CatBoostRegressor at 0x7f1b154ecdf0>}

# %%
catboost_preds = {}
for fold in catboost_models.keys():
    catboost_preds[fold] = catboost_models[fold].predict(X_test_scaled)

# %%
final_catboost_preds = (catboost_preds[0] + catboost_preds[1] + catboost_preds[2] + catboost_preds[3] + catboost_preds[4]) / 5

# %%
ensemble_preds = 0.6 * final_catboost_preds + 0.4 * final_preds

# %%
ensemble_preds[:10], final_catboost_preds[:10], final_preds[:10]
# Out:
# (array([8.40583658, 4.58774964, 8.32465697, 7.18375788, 7.13135284,
#         9.67367649, 9.96252577, 5.89393404, 7.22270917, 7.53612671]),
#  array([8.67110053, 4.62450053, 8.6372614 , 7.22330665, 6.92239076,
#         9.70097104, 9.97590847, 5.72130089, 7.33351626, 7.44252341]),
#  array([8.00794  , 4.5326233, 7.85575  , 7.1244345, 7.444796 , 9.632734 ,
#         9.9424515, 6.1528835, 7.0564985, 7.6765313], dtype=float32))

# %%
final_ensemble_preds = 0.65 * final_catboost_preds + 0.35 * final_preds

# %%
final_ensemble_preds[:10], final_catboost_preds[:10], final_preds[:10]
# Out:
# (array([8.4389943 , 4.5923435 , 8.36373235, 7.18870129, 7.10523255,
#         9.67708804, 9.96419843, 5.87235472, 7.23656006, 7.52442615]),
#  array([8.67110053, 4.62450053, 8.6372614 , 7.22330665, 6.92239076,
#         9.70097104, 9.97590847, 5.72130089, 7.33351626, 7.44252341]),
#  array([8.00794  , 4.5326233, 7.85575  , 7.1244345, 7.444796 , 9.632734 ,
#         9.9424515, 6.1528835, 7.0564985, 7.6765313], dtype=float32))

# %%
sample_df.loc[:, 'loss'] = final_ensemble_preds

# %%
sample_df.head()
# Out:
#        id      loss
# 0  250000  8.438994
# 1  250001  4.592343
# 2  250002  8.363732
# 3  250003  7.188701
# 4  250004  7.105233

# %%
sample_df.to_csv('XGBoost0.35-Catboost0.65_ensemble_20210831_no_feature_gen.csv', index=False)

# %% [markdown]
# # Experiment - fitting model on full training set

# %%
# applying hold-out before scaling
# X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
#                                                       test_size=config['test_size'], 
#                                                       random_state=config['random_state']
#                                                      )
# scaling (i.e. normalizing)
scaler = config['scaler']()
X_s = scaler.fit_transform(X)
X_test_s = scaler.fit_transform(X_test)

# selecting features
selector = config['feature_selector'](score_func=config["feature_selection_scoring"], 
                                      k=config['k_best'])
X_fs = selector.fit_transform(X_s, y)
X_test_fs = X_test_s[:, selector.get_support()]

model = XGBRegressor(
    tree_method=config['tree_method'],
    booster=config['booster'],
    n_estimators=config['n_estimators'], 
    max_depth=config['max_depth'],
    learning_rate=config['learning_rate'], 
    test_size=config['test_size'],
    subsample=config['subsample'],
    random_state=config['random_state'],
    n_jobs=config['n_jobs'], 
    verbosity=config['verbosity'], 
)
#     wandb.log({'params': model.get_params()}) # logging model parameters
model.fit(X_fs, y)#, callbacks=[wandb.xgboost.wandb_callback()])
# Out:
# [12:11:15] WARNING: ../src/learner.cc:573:
# Parameters: { "test_size" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRegressor(base_score=0.5, booster='dart', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1522, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=400, n_jobs=-1, num_parallel_tree=1, random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              test_size=0.2, tree_method='auto', validate_parameters=1,
#              verbosity=1)

# %%
y_test_preds = model.predict(X_test_fs)
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
sample_df = pd.read_csv(datapath/'sample_submission.csv')

# %%
sample_df.loc[:, 'loss'] = y_test_preds

# %%
sample_df.head()
# Out:
#        id      loss
# 0  250000  8.027956
# 1  250001  4.305676
# 2  250002  7.300106
# 3  250003  6.988875
# 4  250004  7.316631

# %%
sample_df.to_csv('202108241211_XGBoost_fullset.csv', index=False)
