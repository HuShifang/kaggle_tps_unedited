# %% [markdown]
# Notebook for doing inference only with an ensemble -- experiments are conducted elsewhere. Model is as stated; `MaxAbsScaler` and `SelectKBest(k=80)` seem to be the best options as of 20210824. (Though model hyperparams haven't been fine-tuned with the scaler and the feature selector as of yet.) **And they should be, since performance is down!**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# general ML tooling
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
import wandb
from wandb.xgboost import wandb_callback
# import timm
from pathlib import Path
import os
import math
import seaborn as sns
from datetime import datetime

from catboost import CatBoostRegressor
from xgboost import XGBRegressor
# from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MaxAbsScaler, StandardScaler, MinMaxScaler, PolynomialFeatures
from sklearn.feature_selection import SelectKBest, f_regression
from joblib import dump, load
# feature engineering tools
# from sklearn.feature_selection import mutual_info_regression
# import featuretools as ft

# %%
# %matplotlib inline
# %config Completer.use_jedi = False
os.environ['WANDB_NOTEBOOK_NAME'] = 'XGBoost_ensemble_20210830.ipynb'
config = {
    # model config
    "model":XGBRegressor,
    "tree_method": "auto", # set to 'gpu_hist' to try GPU if available
    "booster": 'dart', # dart may be marginally better, but will opt for this quicker approach as a default
    "n_estimators": 1000, 
    "max_depth": 3,
    "learning_rate": 0.1522,
    "test_size": 0.2,
    "scaler": MaxAbsScaler,
#     "task_type": "GPU", # for CatBoost only
#     "reg_alpha": 2.8,
#     "reg_lambda": 3.987,
#     "feature_selector": SelectKBest,
#     "k_best": 80,
#     "feature_selection_scoring": f_regression,
    'random_state': 42,
    'subsample': 1,
    'n_jobs': -1,
    'verbosity': 1,
    'k_folds': 5,
    'features_created': True,
    'feature_creator': PolynomialFeatures,
}

config_run = {
    # wandb config:
    'name': f"{os.environ['WANDB_NOTEBOOK_NAME'][:-6]}_{datetime.now().strftime('%H%M%S')}", # just removes the .ipynb extension, leaving the notebook filename's stem
    'tags': ['XGBoost', 'kfold', 'scaling', 'feature-creation', 'feature-selection'],
    'notes': "Running most of the parameters from the run j7tlo010 from the sweep b2zv3fsy, the most successful yet; just increasing n_estimators from 400 to 1000 and adding k-fold, feature generation/selection, etc",
}

# %%
datapath = Path('/media/sf/easystore/kaggle_data/tabular_playgrounds/202108_august/')

# %%
# df = pd.read_csv(datapath/'train.csv', index_col='id', low_memory=False)
# df.index.name = None
# df.to_feather(path='./dataset_df.feather')

# load unaltered dataset
df = pd.read_feather(path='dataset_df.feather')
df.index.name = 'id'

# %%
y = df.loss

# %% [markdown]
# # Feature Creation and Selection

# %%
# load all the polynomialfeatures generated with `PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)`
# X_np = np.load(datapath/'X_poly_unscaled.npy')
# X = pd.DataFrame(X_np)

# %%
# X.columns

# %%
# prep features from unaltered dataset
features = [x for x in df.columns if x != 'loss']
X = df[features]

# %%
# generation polynomial features
poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
X_poly = poly.fit_transform(X)

# %%
X_poly_names = poly.get_feature_names(X.columns)
# X_poly_names[100:150]
features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
checks = [feature in X_poly_names for feature in features]
# checks

# %%
X = pd.DataFrame(X_poly, columns=X_poly_names)

# %%
X = X[features[1:]]

# %% [markdown]
# # Scaling
# Now, going to scale using `MaxAbsScaler`

# %%
scaler = config['scaler']()
X_scaled = scaler.fit_transform(X)
# X_scaled_df = pd.DataFrame(X_scaled, columns=X_poly_names)

# %% [markdown]
# # K-fold Cross-validation

# %%
# ACTUALLY probably better to save those as pickles or .npy files; I'll generate them later, regardless
# results = {} # for storing k-fold models' predictions

# %%
kfold = KFold(n_splits=config['k_folds'], shuffle=True, random_state=config['random_state'])

# %%
def train(X_train, X_valid, y_train, y_valid, config):#, scaler): # passed in via config dict for now
    """
    Basic training function. Note that some of the options passed via the argument are
    in fact hard-coded in, to avoid inconveniences.
    :param config: dict with things to be logged in WandB, some to be used in function
    """
    
    
    wandb.init(
        project="202108_Kaggle_tabular_playground",
        save_code=True,
        tags=config_run['tags'],
        name=config_run['name'],
        notes=config_run['notes'],
        config=config)   
        
    # applying hold-out before scaling
#     X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
#                                                           test_size=config['test_size'], 
#                                                           random_state=config['random_state']
#                                                          )
    
    # strictly speaking should do the below, but doing beforehand faster and fine in this context
    # scaling (i.e. normalizing)
#     scaler = config['scaler']()
#     X_train_s = scaler.fit_transform(X_train)
#     X_valid_s = scaler.fit_transform(X_valid)
    
    # selecting features
#     selector = config['feature_selector'](score_func=config["feature_selection_scoring"], 
#                                           k=config['k_best'])
#     X_train_fs = selector.fit_transform(X_train_s, y_train)
#     X_valid_fs = X_valid_s[:, selector.get_support()] # ensures same features are used in validation

#     # split the dataset
#     model = CatBoostRegressor(
#         n_estimators=config['n_estimators'],
#         learning_rate=config['learning_rate'],
#         max_depth=config['max_depth'],
#         task_type=config['task_type'],
# #         n_jobs=config['n_jobs'],
# #         verbosity=config['verbosity'],
# #         subsample=config['subsample'],
#         random_state=config['random_state'],
# #         bootstrap_type=config['bootstrap_type'],
# #         device:config['device']
#     ) 

    model = XGBRegressor(
        tree_method=config['tree_method'],
        booster=config['booster'],
        n_estimators=config['n_estimators'], 
        max_depth=config['max_depth'],
        learning_rate=config['learning_rate'], 
#         test_size=config['test_size'],
        subsample=config['subsample'],
        reg_alpha=config['reg_alpha'],
        reg_lambda=config['reg_lambda'],
        random_state=config['random_state'],
        n_jobs=config['n_jobs'], 
        verbosity=config['verbosity'], 
    )
#     wandb.log({'params': model.get_params()}) # logging model parameters
    model.fit(X_train, y_train, callbacks=[wandb.xgboost.wandb_callback()])
    y_preds = model.predict(X_valid)
    mse = mean_squared_error(y_valid, y_preds)
    rmse = math.sqrt(abs(mse))
    wandb.log({'mse':mse, 'rmse':rmse})
    print(f"MSE is {mse}\nRMSE is {rmse}")   
#     wandb.finish()   
    return model

# %%
models = {}

# %%
model_path = Path(f"./models/{config_run['name']}_{config['k_folds']}folds/")
(model_path).mkdir(exist_ok=True)

# %%
for fold, (train_ids, valid_ids) in enumerate(kfold.split(X,y)):
#     if fold == 0:
#         continue
#     else:
    print(f"FOLD {fold}")
    print("-----------------------------------------")
    X_train, X_valid = X_scaled[train_ids], X_scaled[valid_ids] # requires X to be a numpy.ndarray
    y_train, y_valid = y[train_ids], y[valid_ids]
    model = train(X_train, X_valid, y_train, y_valid, config)
    wandb.log({'fold': fold})
    models[fold] = model
    dump(model, Path(model_path/f"catboost_fold{fold}_model.joblib"))
    wandb.finish()
# Out:
# FOLD 0
# -----------------------------------------
# 0:	learn: 7.9425840	total: 4.1ms	remaining: 10.2s
# 1:	learn: 7.9405393	total: 8.12ms	remaining: 10.1s
# 2:	learn: 7.9386151	total: 11.4ms	remaining: 9.51s
# 3:	learn: 7.9366608	total: 15.8ms	remaining: 9.84s
# 4:	learn: 7.9350258	total: 19.5ms	remaining: 9.72s
# 5:	learn: 7.9336366	total: 23.5ms	remaining: 9.79s
# 6:	learn: 7.9321268	total: 26.9ms	remaining: 9.58s
# 7:	learn: 7.9307351	total: 31.4ms	remaining: 9.78s
# 8:	learn: 7.9295057	total: 35ms	remaining: 9.7s
# 9:	learn: 7.9282183	total: 38.5ms	remaining: 9.59s
# 10:	learn: 7.9272820	total: 42.4ms	remaining: 9.59s
# 11:	learn: 7.9260192	total: 46.9ms	remaining: 9.72s
# 12:	learn: 7.9249946	total: 50.5ms	remaining: 9.67s
# 13:	learn: 7.9239624	total: 53.9ms	remaining: 9.57s
# 14:	learn: 7.9229613	total: 57.9ms	remaining: 9.59s
# 15:	learn: 7.9219729	total: 61.7ms	remaining: 9.58s
# 16:	learn: 7.9209198	total: 65.5ms	remaining: 9.57s
# 17:	learn: 7.9200309	total: 69.4ms	remaining: 9.56s
# 18:	learn: 7.9191660	total: 72.8ms	remaining: 9.5s
# 19:	learn: 7.9182968	total: 76.1ms	remaining: 9.44s
# 20:	learn: 7.9174257	total: 80.3ms	remaining: 9.48s
# 21:	learn: 7.9165185	total: 84ms	remaining: 9.46s
# 22:	learn: 7.9156797	total: 87.3ms	remaining: 9.41s
# 23:	learn: 7.9149580	total: 90.5ms	remaining: 9.34s
# 24:	learn: 7.9141576	total: 94.4ms	remaining: 9.35s
# 25:	learn: 7.9134907	total: 98.4ms	remaining: 9.36s
# 26:	learn: 7.9127912	total: 102ms	remaining: 9.36s
# 27:	learn: 7.9120885	total: 106ms	remaining: 9.36s
# 28:	learn: 7.9112945	total: 109ms	remaining: 9.31s
# 29:	learn: 7.9105951	total: 113ms	remaining: 9.28s
# 30:	learn: 7.9098767	total: 117ms	remaining: 9.31s
# 31:	learn: 7.9091551	total: 121ms	remaining: 9.32s
# 32:	learn: 7.9085166	total: 124ms	remaining: 9.3s
# 33:	learn: 7.9078442	total: 128ms	remaining: 9.3s
# 34:	learn: 7.9072062	total: 132ms	remaining: 9.31s
# 35:	learn: 7.9066102	total: 136ms	remaining: 9.28s
# 36:	learn: 7.9059886	total: 139ms	remaining: 9.26s
# 37:	learn: 7.9054586	total: 142ms	remaining: 9.22s
# 38:	learn: 7.9049250	total: 146ms	remaining: 9.21s
# 39:	learn: 7.9043978	total: 149ms	remaining: 9.19s
# 40:	learn: 7.9038250	total: 153ms	remaining: 9.18s
# 41:	learn: 7.9032680	total: 157ms	remaining: 9.18s
# 42:	learn: 7.9028470	total: 160ms	remaining: 9.15s
# 43:	learn: 7.9022696	total: 163ms	remaining: 9.12s
# 44:	learn: 7.9017549	total: 167ms	remaining: 9.1s
# 45:	learn: 7.9013274	total: 170ms	remaining: 9.06s
# 46:	learn: 7.9008234	total: 173ms	remaining: 9.02s
# 47:	learn: 7.9003225	total: 176ms	remaining: 8.98s
# 48:	learn: 7.8998826	total: 179ms	remaining: 8.96s
# 49:	learn: 7.8993981	total: 183ms	remaining: 8.97s
# 50:	learn: 7.8988708	total: 186ms	remaining: 8.95s
# 51:	learn: 7.8983489	total: 189ms	remaining: 8.91s
# 52:	learn: 7.8978266	total: 192ms	remaining: 8.88s
# 53:	learn: 7.8973388	total: 195ms	remaining: 8.84s
# 54:	learn: 7.8968893	total: 199ms	remaining: 8.83s
# 55:	learn: 7.8963713	total: 202ms	remaining: 8.81s
# 56:	learn: 7.8958926	total: 205ms	remaining: 8.8s
# 57:	learn: 7.8954078	total: 208ms	remaining: 8.77s
# 58:	learn: 7.8949649	total: 211ms	remaining: 8.74s
# 59:	learn: 7.8943372	total: 214ms	remaining: 8.71s
# 60:	learn: 7.8938258	total: 217ms	remaining: 8.68s
# 61:	learn: 7.8932896	total: 220ms	remaining: 8.66s
# 62:	learn: 7.8927273	total: 224ms	remaining: 8.65s
# 63:	learn: 7.8923048	total: 226ms	remaining: 8.62s
# 64:	learn: 7.8918810	total: 229ms	remaining: 8.59s
# 65:	learn: 7.8914479	total: 232ms	remaining: 8.57s
# 66:	learn: 7.8910313	total: 235ms	remaining: 8.54s
# 67:	learn: 7.8905646	total: 238ms	remaining: 8.53s
# 68:	learn: 7.8902411	total: 241ms	remaining: 8.5s
# 69:	learn: 7.8898634	total: 244ms	remaining: 8.47s
# 70:	learn: 7.8895089	total: 247ms	remaining: 8.45s
# 71:	learn: 7.8891226	total: 250ms	remaining: 8.43s
# 72:	learn: 7.8886846	total: 253ms	remaining: 8.41s
# 73:	learn: 7.8882958	total: 256ms	remaining: 8.4s
# 74:	learn: 7.8879221	total: 259ms	remaining: 8.38s
# 75:	learn: 7.8875281	total: 262ms	remaining: 8.37s
# 76:	learn: 7.8872112	total: 265ms	remaining: 8.35s
# 77:	learn: 7.8868330	total: 269ms	remaining: 8.34s
# 78:	learn: 7.8865186	total: 272ms	remaining: 8.33s
# 79:	learn: 7.8862028	total: 275ms	remaining: 8.31s
# 80:	learn: 7.8857733	total: 278ms	remaining: 8.3s
# 81:	learn: 7.8854534	total: 281ms	remaining: 8.29s
# 82:	learn: 7.8850187	total: 284ms	remaining: 8.28s
# 83:	learn: 7.8847413	total: 287ms	remaining: 8.26s
# 84:	learn: 7.8844689	total: 290ms	remaining: 8.24s
# 85:	learn: 7.8841870	total: 293ms	remaining: 8.22s
# 86:	learn: 7.8839061	total: 296ms	remaining: 8.21s
# 87:	learn: 7.8835509	total: 299ms	remaining: 8.21s
# 88:	learn: 7.8832119	total: 302ms	remaining: 8.19s
# 89:	learn: 7.8827831	total: 305ms	remaining: 8.18s
# 90:	learn: 7.8824282	total: 308ms	remaining: 8.16s
# 91:	learn: 7.8821495	total: 312ms	remaining: 8.16s
# 92:	learn: 7.8818748	total: 315ms	remaining: 8.15s
# 93:	learn: 7.8815373	total: 318ms	remaining: 8.14s
# 94:	learn: 7.8812172	total: 321ms	remaining: 8.12s
# 95:	learn: 7.8807649	total: 324ms	remaining: 8.11s
# 96:	learn: 7.8804702	total: 327ms	remaining: 8.11s
# 97:	learn: 7.8802186	total: 331ms	remaining: 8.11s
# 98:	learn: 7.8798956	total: 335ms	remaining: 8.11s
# 99:	learn: 7.8795898	total: 337ms	remaining: 8.09s
# 100:	learn: 7.8792661	total: 340ms	remaining: 8.08s
# 101:	learn: 7.8788756	total: 344ms	remaining: 8.08s
# 102:	learn: 7.8785363	total: 347ms	remaining: 8.07s
# 103:	learn: 7.8782749	total: 350ms	remaining: 8.06s
# 104:	learn: 7.8780153	total: 354ms	remaining: 8.06s
# 105:	learn: 7.8776675	total: 356ms	remaining: 8.05s
# 106:	learn: 7.8774047	total: 360ms	remaining: 8.04s
# 107:	learn: 7.8771013	total: 363ms	remaining: 8.03s
# 108:	learn: 7.8767569	total: 366ms	remaining: 8.02s
# 109:	learn: 7.8764773	total: 369ms	remaining: 8.03s
# 110:	learn: 7.8762659	total: 372ms	remaining: 8.02s
# 111:	learn: 7.8760472	total: 376ms	remaining: 8.01s
# 112:	learn: 7.8758260	total: 379ms	remaining: 8s
# 113:	learn: 7.8756984	total: 382ms	remaining: 7.99s
# 114:	learn: 7.8754736	total: 385ms	remaining: 7.98s
# 115:	learn: 7.8752429	total: 388ms	remaining: 7.97s
# 116:	learn: 7.8749359	total: 391ms	remaining: 7.96s
# 117:	learn: 7.8746819	total: 394ms	remaining: 7.95s
# 118:	learn: 7.8743273	total: 397ms	remaining: 7.94s
# 119:	learn: 7.8740609	total: 400ms	remaining: 7.94s
# 120:	learn: 7.8738259	total: 404ms	remaining: 7.93s
# 121:	learn: 7.8735761	total: 406ms	remaining: 7.92s
# 122:	learn: 7.8733665	total: 409ms	remaining: 7.91s
# 123:	learn: 7.8731169	total: 412ms	remaining: 7.9s
# 124:	learn: 7.8728546	total: 416ms	remaining: 7.89s
# 125:	learn: 7.8726269	total: 419ms	remaining: 7.89s
# 126:	learn: 7.8723408	total: 422ms	remaining: 7.89s
# 127:	learn: 7.8720528	total: 425ms	remaining: 7.88s
# 128:	learn: 7.8718041	total: 429ms	remaining: 7.88s
# 129:	learn: 7.8715650	total: 432ms	remaining: 7.88s
# 130:	learn: 7.8713477	total: 435ms	remaining: 7.87s
# 131:	learn: 7.8710158	total: 439ms	remaining: 7.87s
# 132:	learn: 7.8706302	total: 442ms	remaining: 7.86s
# 133:	learn: 7.8703675	total: 446ms	remaining: 7.87s
# 134:	learn: 7.8700057	total: 449ms	remaining: 7.86s
# 135:	learn: 7.8698199	total: 452ms	remaining: 7.85s
# 136:	learn: 7.8695985	total: 455ms	remaining: 7.84s
# 137:	learn: 7.8693348	total: 458ms	remaining: 7.83s
# 138:	learn: 7.8691277	total: 461ms	remaining: 7.83s
# 139:	learn: 7.8688424	total: 464ms	remaining: 7.82s
# 140:	learn: 7.8686444	total: 467ms	remaining: 7.81s
# 141:	learn: 7.8683702	total: 470ms	remaining: 7.81s
# 142:	learn: 7.8681488	total: 474ms	remaining: 7.8s
# 143:	learn: 7.8679391	total: 477ms	remaining: 7.8s
# 144:	learn: 7.8676687	total: 480ms	remaining: 7.8s
# 145:	learn: 7.8673798	total: 483ms	remaining: 7.79s
# 146:	learn: 7.8671624	total: 486ms	remaining: 7.78s
# 147:	learn: 7.8669530	total: 490ms	remaining: 7.79s
# 148:	learn: 7.8667579	total: 493ms	remaining: 7.78s
# 149:	learn: 7.8665177	total: 496ms	remaining: 7.77s
# 150:	learn: 7.8662980	total: 499ms	remaining: 7.77s
# 151:	learn: 7.8660419	total: 502ms	remaining: 7.76s
# 152:	learn: 7.8658124	total: 506ms	remaining: 7.77s
# 153:	learn: 7.8657164	total: 509ms	remaining: 7.76s
# 154:	learn: 7.8655270	total: 512ms	remaining: 7.75s
# 155:	learn: 7.8653264	total: 515ms	remaining: 7.74s
# 156:	learn: 7.8651589	total: 518ms	remaining: 7.73s
# 157:	learn: 7.8649841	total: 524ms	remaining: 7.77s
# 158:	learn: 7.8647660	total: 531ms	remaining: 7.82s
# 159:	learn: 7.8645731	total: 536ms	remaining: 7.83s
# 160:	learn: 7.8643023	total: 542ms	remaining: 7.87s
# 161:	learn: 7.8640381	total: 549ms	remaining: 7.92s
# 162:	learn: 7.8638238	total: 555ms	remaining: 7.95s
# 163:	learn: 7.8635981	total: 562ms	remaining: 8s
# 164:	learn: 7.8634236	total: 567ms	remaining: 8.03s
# 165:	learn: 7.8632147	total: 574ms	remaining: 8.07s
# 166:	learn: 7.8630147	total: 581ms	remaining: 8.11s
# 167:	learn: 7.8628182	total: 584ms	remaining: 8.11s
# 168:	learn: 7.8626277	total: 590ms	remaining: 8.14s
# 169:	learn: 7.8624525	total: 598ms	remaining: 8.19s
# 170:	learn: 7.8622417	total: 602ms	remaining: 8.19s
# 171:	learn: 7.8620354	total: 605ms	remaining: 8.18s
# 172:	learn: 7.8618401	total: 617ms	remaining: 8.3s
# 173:	learn: 7.8615829	total: 624ms	remaining: 8.34s
# 174:	learn: 7.8613952	total: 630ms	remaining: 8.36s
# 175:	learn: 7.8611892	total: 633ms	remaining: 8.35s
# 176:	learn: 7.8609446	total: 640ms	remaining: 8.4s
# 177:	learn: 7.8607586	total: 647ms	remaining: 8.44s
# 178:	learn: 7.8605693	total: 652ms	remaining: 8.46s
# 179:	learn: 7.8604376	total: 660ms	remaining: 8.5s
# 180:	learn: 7.8602137	total: 665ms	remaining: 8.52s
# 181:	learn: 7.8600274	total: 672ms	remaining: 8.55s
# 182:	learn: 7.8599103	total: 679ms	remaining: 8.6s
# 183:	learn: 7.8597172	total: 686ms	remaining: 8.63s
# 184:	learn: 7.8595417	total: 693ms	remaining: 8.67s
# 185:	learn: 7.8593397	total: 696ms	remaining: 8.66s
# 186:	learn: 7.8591507	total: 703ms	remaining: 8.7s
# 187:	learn: 7.8589462	total: 710ms	remaining: 8.73s
# 188:	learn: 7.8587633	total: 713ms	remaining: 8.72s
# 189:	learn: 7.8586195	total: 716ms	remaining: 8.71s
# 190:	learn: 7.8583958	total: 719ms	remaining: 8.69s
# 191:	learn: 7.8581531	total: 722ms	remaining: 8.68s
# 192:	learn: 7.8579361	total: 725ms	remaining: 8.67s
# 193:	learn: 7.8577500	total: 728ms	remaining: 8.65s
# 194:	learn: 7.8575960	total: 731ms	remaining: 8.64s
# 195:	learn: 7.8573972	total: 734ms	remaining: 8.63s
# 196:	learn: 7.8571273	total: 737ms	remaining: 8.62s
# 197:	learn: 7.8569511	total: 741ms	remaining: 8.61s
# 198:	learn: 7.8567872	total: 744ms	remaining: 8.6s
# 199:	learn: 7.8565428	total: 747ms	remaining: 8.59s
# 200:	learn: 7.8563878	total: 749ms	remaining: 8.57s
# 201:	learn: 7.8562259	total: 752ms	remaining: 8.55s
# 202:	learn: 7.8560658	total: 755ms	remaining: 8.54s
# 203:	learn: 7.8559156	total: 758ms	remaining: 8.53s
# 204:	learn: 7.8557772	total: 761ms	remaining: 8.52s
# 205:	learn: 7.8556107	total: 764ms	remaining: 8.51s
# 206:	learn: 7.8553628	total: 767ms	remaining: 8.5s
# 207:	learn: 7.8552397	total: 770ms	remaining: 8.49s
# 208:	learn: 7.8549994	total: 773ms	remaining: 8.47s
# 209:	learn: 7.8548450	total: 776ms	remaining: 8.46s
# 210:	learn: 7.8546206	total: 779ms	remaining: 8.45s
# 211:	learn: 7.8544803	total: 782ms	remaining: 8.44s
# 212:	learn: 7.8543294	total: 785ms	remaining: 8.43s
# 213:	learn: 7.8542157	total: 788ms	remaining: 8.42s
# 214:	learn: 7.8541012	total: 792ms	remaining: 8.41s
# 215:	learn: 7.8539140	total: 795ms	remaining: 8.4s
# 216:	learn: 7.8537173	total: 798ms	remaining: 8.39s
# 217:	learn: 7.8535524	total: 801ms	remaining: 8.39s
# 218:	learn: 7.8533149	total: 804ms	remaining: 8.38s
# 219:	learn: 7.8531290	total: 808ms	remaining: 8.37s
# 220:	learn: 7.8529456	total: 811ms	remaining: 8.36s
# 221:	learn: 7.8528167	total: 814ms	remaining: 8.35s
# 222:	learn: 7.8526168	total: 817ms	remaining: 8.34s
# 223:	learn: 7.8524270	total: 820ms	remaining: 8.33s
# 224:	learn: 7.8523076	total: 823ms	remaining: 8.32s
# 225:	learn: 7.8520981	total: 826ms	remaining: 8.31s
# 226:	learn: 7.8518928	total: 829ms	remaining: 8.3s
# 227:	learn: 7.8517240	total: 833ms	remaining: 8.29s
# 228:	learn: 7.8515683	total: 836ms	remaining: 8.29s
# 229:	learn: 7.8514228	total: 838ms	remaining: 8.27s
# 230:	learn: 7.8512954	total: 841ms	remaining: 8.26s
# 231:	learn: 7.8511139	total: 844ms	remaining: 8.25s
# 232:	learn: 7.8509388	total: 847ms	remaining: 8.24s
# 233:	learn: 7.8507557	total: 851ms	remaining: 8.24s
# 234:	learn: 7.8506108	total: 854ms	remaining: 8.23s
# 235:	learn: 7.8504159	total: 857ms	remaining: 8.22s
# 236:	learn: 7.8502621	total: 861ms	remaining: 8.22s
# 237:	learn: 7.8500662	total: 864ms	remaining: 8.21s
# 238:	learn: 7.8499076	total: 867ms	remaining: 8.2s
# 239:	learn: 7.8497013	total: 870ms	remaining: 8.19s
# 240:	learn: 7.8495481	total: 873ms	remaining: 8.19s
# 241:	learn: 7.8494226	total: 877ms	remaining: 8.19s
# 242:	learn: 7.8492092	total: 880ms	remaining: 8.18s
# 243:	learn: 7.8490356	total: 883ms	remaining: 8.17s
# 244:	learn: 7.8489273	total: 887ms	remaining: 8.16s
# 245:	learn: 7.8487802	total: 890ms	remaining: 8.16s
# 246:	learn: 7.8486378	total: 894ms	remaining: 8.15s
# 247:	learn: 7.8485425	total: 897ms	remaining: 8.14s
# 248:	learn: 7.8484021	total: 901ms	remaining: 8.14s
# 249:	learn: 7.8482581	total: 904ms	remaining: 8.14s
# 250:	learn: 7.8480609	total: 909ms	remaining: 8.14s
# 251:	learn: 7.8479293	total: 912ms	remaining: 8.13s
# 252:	learn: 7.8477573	total: 915ms	remaining: 8.12s
# 253:	learn: 7.8476382	total: 918ms	remaining: 8.11s
# 254:	learn: 7.8475158	total: 921ms	remaining: 8.11s
# 255:	learn: 7.8474024	total: 925ms	remaining: 8.11s
# 256:	learn: 7.8472642	total: 931ms	remaining: 8.13s
# 257:	learn: 7.8471380	total: 938ms	remaining: 8.15s
# 258:	learn: 7.8469720	total: 942ms	remaining: 8.15s
# 259:	learn: 7.8467732	total: 945ms	remaining: 8.14s
# 260:	learn: 7.8466381	total: 948ms	remaining: 8.13s
# 261:	learn: 7.8465238	total: 952ms	remaining: 8.13s
# 262:	learn: 7.8464049	total: 955ms	remaining: 8.12s
# 263:	learn: 7.8462344	total: 957ms	remaining: 8.11s
# 264:	learn: 7.8461118	total: 960ms	remaining: 8.1s
# 265:	learn: 7.8459636	total: 964ms	remaining: 8.09s
# 266:	learn: 7.8458400	total: 967ms	remaining: 8.09s
# 267:	learn: 7.8457062	total: 970ms	remaining: 8.08s
# 268:	learn: 7.8454962	total: 973ms	remaining: 8.07s
# 269:	learn: 7.8454203	total: 977ms	remaining: 8.07s
# 270:	learn: 7.8452814	total: 980ms	remaining: 8.06s
# 271:	learn: 7.8450918	total: 984ms	remaining: 8.06s
# 272:	learn: 7.8449165	total: 987ms	remaining: 8.05s
# 273:	learn: 7.8447409	total: 990ms	remaining: 8.04s
# 274:	learn: 7.8446310	total: 992ms	remaining: 8.03s
# 275:	learn: 7.8444407	total: 995ms	remaining: 8.02s
# 276:	learn: 7.8443005	total: 999ms	remaining: 8.02s
# 277:	learn: 7.8439770	total: 1s	remaining: 8.01s
# 278:	learn: 7.8438415	total: 1s	remaining: 8s
# 279:	learn: 7.8436340	total: 1.01s	remaining: 8s
# 280:	learn: 7.8435085	total: 1.01s	remaining: 7.99s
# 281:	learn: 7.8433631	total: 1.01s	remaining: 7.99s
# 282:	learn: 7.8433026	total: 1.02s	remaining: 7.98s
# 283:	learn: 7.8432002	total: 1.02s	remaining: 7.97s
# 284:	learn: 7.8430441	total: 1.02s	remaining: 7.96s
# 285:	learn: 7.8427380	total: 1.03s	remaining: 7.96s
# 286:	learn: 7.8425407	total: 1.03s	remaining: 7.96s
# 287:	learn: 7.8423995	total: 1.03s	remaining: 7.95s
# 288:	learn: 7.8422267	total: 1.04s	remaining: 7.94s
# 289:	learn: 7.8421094	total: 1.04s	remaining: 7.93s
# 290:	learn: 7.8420099	total: 1.04s	remaining: 7.93s
# 291:	learn: 7.8418187	total: 1.05s	remaining: 7.92s
# 292:	learn: 7.8417157	total: 1.05s	remaining: 7.91s
# 293:	learn: 7.8415863	total: 1.05s	remaining: 7.9s
# 294:	learn: 7.8414393	total: 1.05s	remaining: 7.89s
# 295:	learn: 7.8413016	total: 1.06s	remaining: 7.88s
# 296:	learn: 7.8412231	total: 1.06s	remaining: 7.88s
# 297:	learn: 7.8410302	total: 1.06s	remaining: 7.87s
# 298:	learn: 7.8408922	total: 1.07s	remaining: 7.87s
# 299:	learn: 7.8407646	total: 1.07s	remaining: 7.86s
# 300:	learn: 7.8406081	total: 1.07s	remaining: 7.85s
# 301:	learn: 7.8404381	total: 1.08s	remaining: 7.84s
# 302:	learn: 7.8403135	total: 1.08s	remaining: 7.83s
# 303:	learn: 7.8401741	total: 1.08s	remaining: 7.82s
# 304:	learn: 7.8400702	total: 1.09s	remaining: 7.82s
# 305:	learn: 7.8399410	total: 1.09s	remaining: 7.81s
# 306:	learn: 7.8398093	total: 1.09s	remaining: 7.8s
# 307:	learn: 7.8396865	total: 1.09s	remaining: 7.79s
# 308:	learn: 7.8395293	total: 1.1s	remaining: 7.79s
# 309:	learn: 7.8393817	total: 1.1s	remaining: 7.78s
# 310:	learn: 7.8392327	total: 1.1s	remaining: 7.78s
# 311:	learn: 7.8390762	total: 1.11s	remaining: 7.77s
# 312:	learn: 7.8389454	total: 1.11s	remaining: 7.77s
# 313:	learn: 7.8388143	total: 1.11s	remaining: 7.76s
# 314:	learn: 7.8387330	total: 1.12s	remaining: 7.75s
# 315:	learn: 7.8385872	total: 1.12s	remaining: 7.75s
# 316:	learn: 7.8385225	total: 1.12s	remaining: 7.74s
# 317:	learn: 7.8384527	total: 1.13s	remaining: 7.73s
# 318:	learn: 7.8382766	total: 1.13s	remaining: 7.72s
# 319:	learn: 7.8381991	total: 1.13s	remaining: 7.72s
# 320:	learn: 7.8380782	total: 1.14s	remaining: 7.71s
# 321:	learn: 7.8379184	total: 1.14s	remaining: 7.7s
# 322:	learn: 7.8377787	total: 1.14s	remaining: 7.69s
# 323:	learn: 7.8376227	total: 1.14s	remaining: 7.68s
# 324:	learn: 7.8374875	total: 1.15s	remaining: 7.67s
# 325:	learn: 7.8373557	total: 1.15s	remaining: 7.67s
# 326:	learn: 7.8372466	total: 1.15s	remaining: 7.67s
# 327:	learn: 7.8371082	total: 1.16s	remaining: 7.66s
# 328:	learn: 7.8369241	total: 1.16s	remaining: 7.65s
# 329:	learn: 7.8368134	total: 1.16s	remaining: 7.65s
# 330:	learn: 7.8367133	total: 1.17s	remaining: 7.64s
# 331:	learn: 7.8365359	total: 1.17s	remaining: 7.63s
# 332:	learn: 7.8364865	total: 1.17s	remaining: 7.63s
# 333:	learn: 7.8363448	total: 1.18s	remaining: 7.62s
# 334:	learn: 7.8361400	total: 1.18s	remaining: 7.61s
# 335:	learn: 7.8359731	total: 1.18s	remaining: 7.61s
# 336:	learn: 7.8358462	total: 1.18s	remaining: 7.6s
# 337:	learn: 7.8357058	total: 1.19s	remaining: 7.59s
# 338:	learn: 7.8355954	total: 1.19s	remaining: 7.59s
# 339:	learn: 7.8354741	total: 1.19s	remaining: 7.58s
# 340:	learn: 7.8353730	total: 1.2s	remaining: 7.57s
# 341:	learn: 7.8352569	total: 1.2s	remaining: 7.56s
# 342:	learn: 7.8351404	total: 1.2s	remaining: 7.55s
# 343:	learn: 7.8349917	total: 1.2s	remaining: 7.55s
# 344:	learn: 7.8348204	total: 1.21s	remaining: 7.54s
# 345:	learn: 7.8345995	total: 1.21s	remaining: 7.54s
# 346:	learn: 7.8344875	total: 1.21s	remaining: 7.53s
# 347:	learn: 7.8343816	total: 1.22s	remaining: 7.52s
# 348:	learn: 7.8342511	total: 1.22s	remaining: 7.52s
# 349:	learn: 7.8341557	total: 1.22s	remaining: 7.51s
# 350:	learn: 7.8340184	total: 1.23s	remaining: 7.5s
# 351:	learn: 7.8338956	total: 1.23s	remaining: 7.5s
# 352:	learn: 7.8337491	total: 1.23s	remaining: 7.5s
# 353:	learn: 7.8336550	total: 1.24s	remaining: 7.49s
# 354:	learn: 7.8335129	total: 1.24s	remaining: 7.48s
# 355:	learn: 7.8334111	total: 1.24s	remaining: 7.48s
# 356:	learn: 7.8332962	total: 1.24s	remaining: 7.47s
# 357:	learn: 7.8331794	total: 1.25s	remaining: 7.46s
# 358:	learn: 7.8330349	total: 1.25s	remaining: 7.46s
# 359:	learn: 7.8329752	total: 1.25s	remaining: 7.45s
# 360:	learn: 7.8328989	total: 1.26s	remaining: 7.45s
# 361:	learn: 7.8327128	total: 1.26s	remaining: 7.45s
# 362:	learn: 7.8326244	total: 1.26s	remaining: 7.44s
# 363:	learn: 7.8325114	total: 1.27s	remaining: 7.43s
# 364:	learn: 7.8324163	total: 1.27s	remaining: 7.43s
# 365:	learn: 7.8322347	total: 1.27s	remaining: 7.42s
# 366:	learn: 7.8321485	total: 1.27s	remaining: 7.41s
# 367:	learn: 7.8320297	total: 1.28s	remaining: 7.41s
# 368:	learn: 7.8319209	total: 1.28s	remaining: 7.4s
# 369:	learn: 7.8317645	total: 1.28s	remaining: 7.39s
# 370:	learn: 7.8316084	total: 1.29s	remaining: 7.39s
# 371:	learn: 7.8315302	total: 1.29s	remaining: 7.38s
# 372:	learn: 7.8313757	total: 1.29s	remaining: 7.37s
# 373:	learn: 7.8312592	total: 1.3s	remaining: 7.37s
# 374:	learn: 7.8311643	total: 1.3s	remaining: 7.36s
# 375:	learn: 7.8310322	total: 1.3s	remaining: 7.36s
# 376:	learn: 7.8308959	total: 1.3s	remaining: 7.35s
# 377:	learn: 7.8307423	total: 1.31s	remaining: 7.35s
# 378:	learn: 7.8306328	total: 1.31s	remaining: 7.34s
# 379:	learn: 7.8305175	total: 1.31s	remaining: 7.34s
# 380:	learn: 7.8304377	total: 1.32s	remaining: 7.33s
# 381:	learn: 7.8303448	total: 1.32s	remaining: 7.33s
# 382:	learn: 7.8302395	total: 1.32s	remaining: 7.32s
# 383:	learn: 7.8301162	total: 1.33s	remaining: 7.31s
# 384:	learn: 7.8299684	total: 1.33s	remaining: 7.31s
# 385:	learn: 7.8298384	total: 1.33s	remaining: 7.31s
# 386:	learn: 7.8296833	total: 1.34s	remaining: 7.3s
# 387:	learn: 7.8295466	total: 1.34s	remaining: 7.29s
# 388:	learn: 7.8293917	total: 1.34s	remaining: 7.29s
# 389:	learn: 7.8292838	total: 1.35s	remaining: 7.29s
# 390:	learn: 7.8291804	total: 1.35s	remaining: 7.28s
# 391:	learn: 7.8290277	total: 1.35s	remaining: 7.28s
# 392:	learn: 7.8289086	total: 1.36s	remaining: 7.27s
# 393:	learn: 7.8287968	total: 1.36s	remaining: 7.27s
# 394:	learn: 7.8287288	total: 1.36s	remaining: 7.26s
# 395:	learn: 7.8286391	total: 1.37s	remaining: 7.26s
# 396:	learn: 7.8285034	total: 1.37s	remaining: 7.25s
# 397:	learn: 7.8284315	total: 1.37s	remaining: 7.25s
# 398:	learn: 7.8282623	total: 1.38s	remaining: 7.24s
# 399:	learn: 7.8281543	total: 1.38s	remaining: 7.24s
# 400:	learn: 7.8280314	total: 1.38s	remaining: 7.24s
# 401:	learn: 7.8279317	total: 1.39s	remaining: 7.23s
# 402:	learn: 7.8278014	total: 1.39s	remaining: 7.22s
# 403:	learn: 7.8276941	total: 1.39s	remaining: 7.22s
# 404:	learn: 7.8275948	total: 1.4s	remaining: 7.22s
# 405:	learn: 7.8275069	total: 1.4s	remaining: 7.21s
# 406:	learn: 7.8273699	total: 1.4s	remaining: 7.21s
# 407:	learn: 7.8272272	total: 1.4s	remaining: 7.2s
# 408:	learn: 7.8271352	total: 1.41s	remaining: 7.19s
# 409:	learn: 7.8270247	total: 1.41s	remaining: 7.19s
# 410:	learn: 7.8269218	total: 1.41s	remaining: 7.19s
# 411:	learn: 7.8267976	total: 1.42s	remaining: 7.18s
# 412:	learn: 7.8266605	total: 1.42s	remaining: 7.18s
# 413:	learn: 7.8265899	total: 1.42s	remaining: 7.17s
# 414:	learn: 7.8264222	total: 1.43s	remaining: 7.17s
# 415:	learn: 7.8263484	total: 1.43s	remaining: 7.17s
# 416:	learn: 7.8261520	total: 1.43s	remaining: 7.16s
# 417:	learn: 7.8260510	total: 1.44s	remaining: 7.16s
# 418:	learn: 7.8259622	total: 1.44s	remaining: 7.15s
# 419:	learn: 7.8258591	total: 1.44s	remaining: 7.15s
# 420:	learn: 7.8257655	total: 1.45s	remaining: 7.14s
# 421:	learn: 7.8256412	total: 1.45s	remaining: 7.14s
# 422:	learn: 7.8255604	total: 1.45s	remaining: 7.13s
# 423:	learn: 7.8254089	total: 1.46s	remaining: 7.13s
# 424:	learn: 7.8252962	total: 1.46s	remaining: 7.13s
# 425:	learn: 7.8251629	total: 1.46s	remaining: 7.12s
# 426:	learn: 7.8250323	total: 1.47s	remaining: 7.12s
# 427:	learn: 7.8249428	total: 1.47s	remaining: 7.11s
# 428:	learn: 7.8248102	total: 1.47s	remaining: 7.11s
# 429:	learn: 7.8246633	total: 1.48s	remaining: 7.1s
# 430:	learn: 7.8245604	total: 1.48s	remaining: 7.1s
# 431:	learn: 7.8243814	total: 1.48s	remaining: 7.09s
# 432:	learn: 7.8242581	total: 1.48s	remaining: 7.09s
# 433:	learn: 7.8240846	total: 1.49s	remaining: 7.08s
# 434:	learn: 7.8239574	total: 1.49s	remaining: 7.08s
# 435:	learn: 7.8238296	total: 1.49s	remaining: 7.07s
# 436:	learn: 7.8237360	total: 1.5s	remaining: 7.07s
# 437:	learn: 7.8236373	total: 1.5s	remaining: 7.06s
# 438:	learn: 7.8235203	total: 1.5s	remaining: 7.06s
# 439:	learn: 7.8233909	total: 1.51s	remaining: 7.05s
# 440:	learn: 7.8232611	total: 1.51s	remaining: 7.05s
# 441:	learn: 7.8231122	total: 1.51s	remaining: 7.05s
# 442:	learn: 7.8230087	total: 1.52s	remaining: 7.04s
# 443:	learn: 7.8228882	total: 1.52s	remaining: 7.04s
# 444:	learn: 7.8227402	total: 1.52s	remaining: 7.03s
# 445:	learn: 7.8226246	total: 1.53s	remaining: 7.03s
# 446:	learn: 7.8225050	total: 1.53s	remaining: 7.02s
# 447:	learn: 7.8224101	total: 1.53s	remaining: 7.02s
# 448:	learn: 7.8223136	total: 1.54s	remaining: 7.02s
# 449:	learn: 7.8222235	total: 1.54s	remaining: 7.01s
# 450:	learn: 7.8221477	total: 1.54s	remaining: 7s
# 451:	learn: 7.8220541	total: 1.54s	remaining: 7s
# 452:	learn: 7.8220058	total: 1.55s	remaining: 7s
# 453:	learn: 7.8219045	total: 1.55s	remaining: 6.99s
# 454:	learn: 7.8217955	total: 1.55s	remaining: 6.99s
# 455:	learn: 7.8216443	total: 1.56s	remaining: 6.98s
# 456:	learn: 7.8215615	total: 1.56s	remaining: 6.98s
# 457:	learn: 7.8214327	total: 1.56s	remaining: 6.97s
# 458:	learn: 7.8213074	total: 1.57s	remaining: 6.97s
# 459:	learn: 7.8212326	total: 1.57s	remaining: 6.96s
# 460:	learn: 7.8211204	total: 1.57s	remaining: 6.96s
# 461:	learn: 7.8210581	total: 1.57s	remaining: 6.95s
# 462:	learn: 7.8210226	total: 1.58s	remaining: 6.95s
# 463:	learn: 7.8209312	total: 1.58s	remaining: 6.94s
# 464:	learn: 7.8208411	total: 1.58s	remaining: 6.93s
# 465:	learn: 7.8207404	total: 1.59s	remaining: 6.93s
# 466:	learn: 7.8206611	total: 1.59s	remaining: 6.92s
# 467:	learn: 7.8205428	total: 1.59s	remaining: 6.92s
# 468:	learn: 7.8204431	total: 1.6s	remaining: 6.92s
# 469:	learn: 7.8203491	total: 1.6s	remaining: 6.91s
# 470:	learn: 7.8202743	total: 1.6s	remaining: 6.91s
# 471:	learn: 7.8201765	total: 1.61s	remaining: 6.9s
# 472:	learn: 7.8200889	total: 1.61s	remaining: 6.9s
# 473:	learn: 7.8199907	total: 1.61s	remaining: 6.89s
# 474:	learn: 7.8199230	total: 1.61s	remaining: 6.89s
# 475:	learn: 7.8198312	total: 1.62s	remaining: 6.88s
# 476:	learn: 7.8197503	total: 1.62s	remaining: 6.88s
# 477:	learn: 7.8196570	total: 1.62s	remaining: 6.87s
# 478:	learn: 7.8195703	total: 1.63s	remaining: 6.87s
# 479:	learn: 7.8194824	total: 1.63s	remaining: 6.86s
# 480:	learn: 7.8193679	total: 1.63s	remaining: 6.86s
# 481:	learn: 7.8192321	total: 1.64s	remaining: 6.86s
# 482:	learn: 7.8191265	total: 1.64s	remaining: 6.85s
# 483:	learn: 7.8190405	total: 1.64s	remaining: 6.84s
# 484:	learn: 7.8189520	total: 1.65s	remaining: 6.84s
# 485:	learn: 7.8188493	total: 1.65s	remaining: 6.83s
# 486:	learn: 7.8187614	total: 1.65s	remaining: 6.83s
# 487:	learn: 7.8186722	total: 1.65s	remaining: 6.82s
# 488:	learn: 7.8185251	total: 1.66s	remaining: 6.82s
# 489:	learn: 7.8184180	total: 1.66s	remaining: 6.81s
# 490:	learn: 7.8182990	total: 1.66s	remaining: 6.81s
# 491:	learn: 7.8182034	total: 1.67s	remaining: 6.8s
# 492:	learn: 7.8180349	total: 1.67s	remaining: 6.8s
# 493:	learn: 7.8178747	total: 1.67s	remaining: 6.79s
# 494:	learn: 7.8177462	total: 1.68s	remaining: 6.79s
# 495:	learn: 7.8176569	total: 1.68s	remaining: 6.79s
# 496:	learn: 7.8175885	total: 1.68s	remaining: 6.78s
# 497:	learn: 7.8174852	total: 1.69s	remaining: 6.78s
# 498:	learn: 7.8173838	total: 1.69s	remaining: 6.77s
# 499:	learn: 7.8172655	total: 1.69s	remaining: 6.77s
# 500:	learn: 7.8172003	total: 1.7s	remaining: 6.76s
# 501:	learn: 7.8170883	total: 1.7s	remaining: 6.76s
# 502:	learn: 7.8170097	total: 1.7s	remaining: 6.75s
# 503:	learn: 7.8169070	total: 1.7s	remaining: 6.75s
# 504:	learn: 7.8168117	total: 1.71s	remaining: 6.74s
# 505:	learn: 7.8166946	total: 1.71s	remaining: 6.74s
# 506:	learn: 7.8165267	total: 1.71s	remaining: 6.74s
# 507:	learn: 7.8163486	total: 1.72s	remaining: 6.73s
# 508:	learn: 7.8162478	total: 1.72s	remaining: 6.73s
# 509:	learn: 7.8161064	total: 1.72s	remaining: 6.72s
# 510:	learn: 7.8159907	total: 1.73s	remaining: 6.72s
# 511:	learn: 7.8159181	total: 1.73s	remaining: 6.71s
# 512:	learn: 7.8158202	total: 1.73s	remaining: 6.71s
# 513:	learn: 7.8156801	total: 1.74s	remaining: 6.71s
# 514:	learn: 7.8155630	total: 1.74s	remaining: 6.7s
# 515:	learn: 7.8155064	total: 1.74s	remaining: 6.7s
# 516:	learn: 7.8154011	total: 1.74s	remaining: 6.69s
# 517:	learn: 7.8153285	total: 1.75s	remaining: 6.69s
# 518:	learn: 7.8152402	total: 1.75s	remaining: 6.68s
# 519:	learn: 7.8151363	total: 1.75s	remaining: 6.68s
# 520:	learn: 7.8150409	total: 1.76s	remaining: 6.67s
# 521:	learn: 7.8148676	total: 1.76s	remaining: 6.67s
# 522:	learn: 7.8147268	total: 1.76s	remaining: 6.66s
# 523:	learn: 7.8146078	total: 1.76s	remaining: 6.66s
# 524:	learn: 7.8144379	total: 1.77s	remaining: 6.65s
# 525:	learn: 7.8143605	total: 1.77s	remaining: 6.65s
# 526:	learn: 7.8142898	total: 1.77s	remaining: 6.64s
# 527:	learn: 7.8141388	total: 1.78s	remaining: 6.64s
# 528:	learn: 7.8140370	total: 1.78s	remaining: 6.63s
# 529:	learn: 7.8139567	total: 1.78s	remaining: 6.63s
# 530:	learn: 7.8138473	total: 1.79s	remaining: 6.62s
# 531:	learn: 7.8137171	total: 1.79s	remaining: 6.62s
# 532:	learn: 7.8135936	total: 1.79s	remaining: 6.62s
# 533:	learn: 7.8134861	total: 1.8s	remaining: 6.61s
# 534:	learn: 7.8134227	total: 1.8s	remaining: 6.61s
# 535:	learn: 7.8133437	total: 1.8s	remaining: 6.6s
# 536:	learn: 7.8132426	total: 1.8s	remaining: 6.6s
# 537:	learn: 7.8131562	total: 1.81s	remaining: 6.6s
# 538:	learn: 7.8130881	total: 1.81s	remaining: 6.59s
# 539:	learn: 7.8129994	total: 1.81s	remaining: 6.59s
# 540:	learn: 7.8128868	total: 1.82s	remaining: 6.58s
# 541:	learn: 7.8128180	total: 1.82s	remaining: 6.58s
# 542:	learn: 7.8127108	total: 1.82s	remaining: 6.57s
# 543:	learn: 7.8125956	total: 1.83s	remaining: 6.57s
# 544:	learn: 7.8125098	total: 1.83s	remaining: 6.57s
# 545:	learn: 7.8124484	total: 1.83s	remaining: 6.56s
# 546:	learn: 7.8123594	total: 1.84s	remaining: 6.56s
# 547:	learn: 7.8122772	total: 1.84s	remaining: 6.56s
# 548:	learn: 7.8120964	total: 1.84s	remaining: 6.55s
# 549:	learn: 7.8119975	total: 1.85s	remaining: 6.55s
# 550:	learn: 7.8119175	total: 1.85s	remaining: 6.54s
# 551:	learn: 7.8118554	total: 1.85s	remaining: 6.54s
# 552:	learn: 7.8118138	total: 1.86s	remaining: 6.54s
# 553:	learn: 7.8117408	total: 1.86s	remaining: 6.53s
# 554:	learn: 7.8116212	total: 1.86s	remaining: 6.53s
# 555:	learn: 7.8115031	total: 1.86s	remaining: 6.52s
# 556:	learn: 7.8114362	total: 1.87s	remaining: 6.52s
# 557:	learn: 7.8113021	total: 1.87s	remaining: 6.52s
# 558:	learn: 7.8111776	total: 1.88s	remaining: 6.51s
# 559:	learn: 7.8110768	total: 1.88s	remaining: 6.51s
# 560:	learn: 7.8109481	total: 1.88s	remaining: 6.5s
# 561:	learn: 7.8108549	total: 1.88s	remaining: 6.5s
# 562:	learn: 7.8107836	total: 1.89s	remaining: 6.49s
# 563:	learn: 7.8106773	total: 1.89s	remaining: 6.49s
# 564:	learn: 7.8105803	total: 1.89s	remaining: 6.49s
# 565:	learn: 7.8105147	total: 1.9s	remaining: 6.48s
# 566:	learn: 7.8104206	total: 1.9s	remaining: 6.48s
# 567:	learn: 7.8103188	total: 1.9s	remaining: 6.48s
# 568:	learn: 7.8102526	total: 1.91s	remaining: 6.47s
# 569:	learn: 7.8100973	total: 1.91s	remaining: 6.47s
# 570:	learn: 7.8099702	total: 1.91s	remaining: 6.46s
# 571:	learn: 7.8098956	total: 1.92s	remaining: 6.46s
# 572:	learn: 7.8097826	total: 1.92s	remaining: 6.45s
# 573:	learn: 7.8096636	total: 1.92s	remaining: 6.45s
# 574:	learn: 7.8095403	total: 1.93s	remaining: 6.45s
# 575:	learn: 7.8094283	total: 1.93s	remaining: 6.44s
# 576:	learn: 7.8093076	total: 1.93s	remaining: 6.44s
# 577:	learn: 7.8092083	total: 1.94s	remaining: 6.44s
# 578:	learn: 7.8090838	total: 1.94s	remaining: 6.43s
# 579:	learn: 7.8090003	total: 1.94s	remaining: 6.43s
# 580:	learn: 7.8088895	total: 1.95s	remaining: 6.43s
# 581:	learn: 7.8087720	total: 1.95s	remaining: 6.43s
# 582:	learn: 7.8086791	total: 1.95s	remaining: 6.42s
# 583:	learn: 7.8084935	total: 1.96s	remaining: 6.42s
# 584:	learn: 7.8084313	total: 1.96s	remaining: 6.41s
# 585:	learn: 7.8083574	total: 1.96s	remaining: 6.41s
# 586:	learn: 7.8082559	total: 1.97s	remaining: 6.41s
# 587:	learn: 7.8080769	total: 1.97s	remaining: 6.4s
# 588:	learn: 7.8079578	total: 1.97s	remaining: 6.4s
# 589:	learn: 7.8078662	total: 1.98s	remaining: 6.4s
# 590:	learn: 7.8078118	total: 1.98s	remaining: 6.39s
# 591:	learn: 7.8076844	total: 1.98s	remaining: 6.39s
# 592:	learn: 7.8075739	total: 1.99s	remaining: 6.38s
# 593:	learn: 7.8074545	total: 1.99s	remaining: 6.38s
# 594:	learn: 7.8073139	total: 1.99s	remaining: 6.38s
# 595:	learn: 7.8072213	total: 2s	remaining: 6.37s
# 596:	learn: 7.8071355	total: 2s	remaining: 6.37s
# 597:	learn: 7.8070696	total: 2s	remaining: 6.36s
# 598:	learn: 7.8069501	total: 2s	remaining: 6.36s
# 599:	learn: 7.8068383	total: 2.01s	remaining: 6.36s
# 600:	learn: 7.8067381	total: 2.01s	remaining: 6.36s
# 601:	learn: 7.8066577	total: 2.01s	remaining: 6.35s
# 602:	learn: 7.8065982	total: 2.02s	remaining: 6.35s
# 603:	learn: 7.8064771	total: 2.02s	remaining: 6.34s
# 604:	learn: 7.8063420	total: 2.02s	remaining: 6.34s
# 605:	learn: 7.8062356	total: 2.03s	remaining: 6.34s
# 606:	learn: 7.8061309	total: 2.03s	remaining: 6.33s
# 607:	learn: 7.8060396	total: 2.03s	remaining: 6.33s
# 608:	learn: 7.8059798	total: 2.04s	remaining: 6.33s
# 609:	learn: 7.8059157	total: 2.04s	remaining: 6.32s
# 610:	learn: 7.8057296	total: 2.04s	remaining: 6.32s
# 611:	learn: 7.8056185	total: 2.05s	remaining: 6.31s
# 612:	learn: 7.8055423	total: 2.05s	remaining: 6.31s
# 613:	learn: 7.8054385	total: 2.05s	remaining: 6.3s
# 614:	learn: 7.8053591	total: 2.06s	remaining: 6.3s
# 615:	learn: 7.8052812	total: 2.06s	remaining: 6.3s
# 616:	learn: 7.8051896	total: 2.06s	remaining: 6.29s
# 617:	learn: 7.8050762	total: 2.06s	remaining: 6.29s
# 618:	learn: 7.8049170	total: 2.07s	remaining: 6.28s
# 619:	learn: 7.8048565	total: 2.07s	remaining: 6.28s
# 620:	learn: 7.8047319	total: 2.07s	remaining: 6.28s
# 621:	learn: 7.8046576	total: 2.08s	remaining: 6.27s
# 622:	learn: 7.8045500	total: 2.08s	remaining: 6.27s
# 623:	learn: 7.8044148	total: 2.08s	remaining: 6.26s
# 624:	learn: 7.8043126	total: 2.09s	remaining: 6.26s
# 625:	learn: 7.8042082	total: 2.09s	remaining: 6.25s
# 626:	learn: 7.8041665	total: 2.09s	remaining: 6.25s
# 627:	learn: 7.8040720	total: 2.1s	remaining: 6.25s
# 628:	learn: 7.8039794	total: 2.1s	remaining: 6.24s
# 629:	learn: 7.8038180	total: 2.1s	remaining: 6.24s
# 630:	learn: 7.8037321	total: 2.1s	remaining: 6.23s
# 631:	learn: 7.8036354	total: 2.11s	remaining: 6.23s
# 632:	learn: 7.8035479	total: 2.11s	remaining: 6.22s
# 633:	learn: 7.8034374	total: 2.11s	remaining: 6.22s
# 634:	learn: 7.8033506	total: 2.12s	remaining: 6.21s
# 635:	learn: 7.8032701	total: 2.12s	remaining: 6.21s
# 636:	learn: 7.8031571	total: 2.12s	remaining: 6.2s
# 637:	learn: 7.8030526	total: 2.12s	remaining: 6.2s
# 638:	learn: 7.8029341	total: 2.13s	remaining: 6.2s
# 639:	learn: 7.8028524	total: 2.13s	remaining: 6.19s
# 640:	learn: 7.8027540	total: 2.13s	remaining: 6.19s
# 641:	learn: 7.8026922	total: 2.14s	remaining: 6.18s
# 642:	learn: 7.8026156	total: 2.14s	remaining: 6.18s
# 643:	learn: 7.8025099	total: 2.14s	remaining: 6.18s
# 644:	learn: 7.8024506	total: 2.15s	remaining: 6.17s
# 645:	learn: 7.8022933	total: 2.15s	remaining: 6.17s
# 646:	learn: 7.8022074	total: 2.15s	remaining: 6.16s
# 647:	learn: 7.8021311	total: 2.15s	remaining: 6.16s
# 648:	learn: 7.8019930	total: 2.16s	remaining: 6.16s
# 649:	learn: 7.8019068	total: 2.16s	remaining: 6.15s
# 650:	learn: 7.8017915	total: 2.16s	remaining: 6.15s
# 651:	learn: 7.8016976	total: 2.17s	remaining: 6.14s
# 652:	learn: 7.8015822	total: 2.17s	remaining: 6.14s
# 653:	learn: 7.8014931	total: 2.17s	remaining: 6.13s
# 654:	learn: 7.8014063	total: 2.18s	remaining: 6.13s
# 655:	learn: 7.8013332	total: 2.18s	remaining: 6.13s
# 656:	learn: 7.8011881	total: 2.18s	remaining: 6.12s
# 657:	learn: 7.8011204	total: 2.19s	remaining: 6.12s
# 658:	learn: 7.8010422	total: 2.19s	remaining: 6.11s
# 659:	learn: 7.8009410	total: 2.19s	remaining: 6.11s
# 660:	learn: 7.8008721	total: 2.19s	remaining: 6.11s
# 661:	learn: 7.8007365	total: 2.2s	remaining: 6.1s
# 662:	learn: 7.8006234	total: 2.2s	remaining: 6.1s
# 663:	learn: 7.8005465	total: 2.2s	remaining: 6.09s
# 664:	learn: 7.8004138	total: 2.21s	remaining: 6.09s
# 665:	learn: 7.8002779	total: 2.21s	remaining: 6.09s
# 666:	learn: 7.8001987	total: 2.21s	remaining: 6.08s
# 667:	learn: 7.8001337	total: 2.22s	remaining: 6.08s
# 668:	learn: 7.8000423	total: 2.22s	remaining: 6.07s
# 669:	learn: 7.7999715	total: 2.22s	remaining: 6.07s
# 670:	learn: 7.7998423	total: 2.23s	remaining: 6.07s
# 671:	learn: 7.7996869	total: 2.23s	remaining: 6.06s
# 672:	learn: 7.7995590	total: 2.23s	remaining: 6.06s
# 673:	learn: 7.7994721	total: 2.23s	remaining: 6.05s
# 674:	learn: 7.7993464	total: 2.24s	remaining: 6.05s
# 675:	learn: 7.7992868	total: 2.24s	remaining: 6.04s
# 676:	learn: 7.7992362	total: 2.24s	remaining: 6.04s
# 677:	learn: 7.7991528	total: 2.25s	remaining: 6.03s
# 678:	learn: 7.7990932	total: 2.25s	remaining: 6.03s
# 679:	learn: 7.7990022	total: 2.25s	remaining: 6.03s
# 680:	learn: 7.7988772	total: 2.25s	remaining: 6.02s
# 681:	learn: 7.7987743	total: 2.26s	remaining: 6.02s
# 682:	learn: 7.7986928	total: 2.26s	remaining: 6.01s
# 683:	learn: 7.7985986	total: 2.27s	remaining: 6.01s
# 684:	learn: 7.7985479	total: 2.27s	remaining: 6.01s
# 685:	learn: 7.7984582	total: 2.27s	remaining: 6.01s
# 686:	learn: 7.7983687	total: 2.27s	remaining: 6s
# 687:	learn: 7.7982511	total: 2.28s	remaining: 6s
# 688:	learn: 7.7981219	total: 2.28s	remaining: 5.99s
# 689:	learn: 7.7980427	total: 2.28s	remaining: 5.99s
# 690:	learn: 7.7979597	total: 2.29s	remaining: 5.99s
# 691:	learn: 7.7978702	total: 2.29s	remaining: 5.98s
# 692:	learn: 7.7977766	total: 2.29s	remaining: 5.98s
# 693:	learn: 7.7976682	total: 2.29s	remaining: 5.97s
# 694:	learn: 7.7975858	total: 2.3s	remaining: 5.97s
# 695:	learn: 7.7974720	total: 2.3s	remaining: 5.97s
# 696:	learn: 7.7974146	total: 2.31s	remaining: 5.96s
# 697:	learn: 7.7973092	total: 2.31s	remaining: 5.96s
# 698:	learn: 7.7972293	total: 2.31s	remaining: 5.96s
# 699:	learn: 7.7971373	total: 2.32s	remaining: 5.96s
# 700:	learn: 7.7970581	total: 2.32s	remaining: 5.95s
# 701:	learn: 7.7969664	total: 2.32s	remaining: 5.95s
# 702:	learn: 7.7968240	total: 2.33s	remaining: 5.95s
# 703:	learn: 7.7967096	total: 2.33s	remaining: 5.94s
# 704:	learn: 7.7966146	total: 2.33s	remaining: 5.94s
# 705:	learn: 7.7964662	total: 2.33s	remaining: 5.93s
# 706:	learn: 7.7963729	total: 2.34s	remaining: 5.93s
# 707:	learn: 7.7962603	total: 2.34s	remaining: 5.93s
# 708:	learn: 7.7961539	total: 2.35s	remaining: 5.93s
# 709:	learn: 7.7960387	total: 2.35s	remaining: 5.92s
# 710:	learn: 7.7959987	total: 2.35s	remaining: 5.92s
# 711:	learn: 7.7958813	total: 2.35s	remaining: 5.91s
# 712:	learn: 7.7957921	total: 2.36s	remaining: 5.91s
# 713:	learn: 7.7956802	total: 2.36s	remaining: 5.91s
# 714:	learn: 7.7956093	total: 2.37s	remaining: 5.9s
# 715:	learn: 7.7955423	total: 2.37s	remaining: 5.9s
# 716:	learn: 7.7954670	total: 2.37s	remaining: 5.89s
# 717:	learn: 7.7953765	total: 2.37s	remaining: 5.89s
# 718:	learn: 7.7953140	total: 2.38s	remaining: 5.89s
# 719:	learn: 7.7952120	total: 2.38s	remaining: 5.88s
# 720:	learn: 7.7951193	total: 2.38s	remaining: 5.88s
# 721:	learn: 7.7950234	total: 2.39s	remaining: 5.88s
# 722:	learn: 7.7949407	total: 2.39s	remaining: 5.87s
# 723:	learn: 7.7948695	total: 2.39s	remaining: 5.87s
# 724:	learn: 7.7947492	total: 2.4s	remaining: 5.87s
# 725:	learn: 7.7946052	total: 2.4s	remaining: 5.86s
# 726:	learn: 7.7945596	total: 2.4s	remaining: 5.86s
# 727:	learn: 7.7944580	total: 2.4s	remaining: 5.86s
# 728:	learn: 7.7943585	total: 2.41s	remaining: 5.85s
# 729:	learn: 7.7943005	total: 2.41s	remaining: 5.85s
# 730:	learn: 7.7942344	total: 2.41s	remaining: 5.84s
# 731:	learn: 7.7941372	total: 2.42s	remaining: 5.84s
# 732:	learn: 7.7940285	total: 2.42s	remaining: 5.84s
# 733:	learn: 7.7939611	total: 2.42s	remaining: 5.83s
# 734:	learn: 7.7938829	total: 2.43s	remaining: 5.83s
# 735:	learn: 7.7938043	total: 2.43s	remaining: 5.82s
# 736:	learn: 7.7937026	total: 2.43s	remaining: 5.82s
# 737:	learn: 7.7936400	total: 2.44s	remaining: 5.82s
# 738:	learn: 7.7935108	total: 2.44s	remaining: 5.81s
# 739:	learn: 7.7934145	total: 2.44s	remaining: 5.81s
# 740:	learn: 7.7933151	total: 2.44s	remaining: 5.8s
# 741:	learn: 7.7932480	total: 2.45s	remaining: 5.8s
# 742:	learn: 7.7931172	total: 2.45s	remaining: 5.8s
# 743:	learn: 7.7930033	total: 2.46s	remaining: 5.79s
# 744:	learn: 7.7928538	total: 2.46s	remaining: 5.79s
# 745:	learn: 7.7927447	total: 2.46s	remaining: 5.79s
# 746:	learn: 7.7926571	total: 2.46s	remaining: 5.78s
# 747:	learn: 7.7925493	total: 2.47s	remaining: 5.78s
# 748:	learn: 7.7924396	total: 2.47s	remaining: 5.78s
# 749:	learn: 7.7923382	total: 2.48s	remaining: 5.78s
# 750:	learn: 7.7922689	total: 2.48s	remaining: 5.77s
# 751:	learn: 7.7921794	total: 2.48s	remaining: 5.77s
# 752:	learn: 7.7920065	total: 2.48s	remaining: 5.77s
# 753:	learn: 7.7919442	total: 2.49s	remaining: 5.76s
# 754:	learn: 7.7918246	total: 2.49s	remaining: 5.76s
# 755:	learn: 7.7917437	total: 2.49s	remaining: 5.75s
# 756:	learn: 7.7916523	total: 2.5s	remaining: 5.75s
# 757:	learn: 7.7915708	total: 2.5s	remaining: 5.75s
# 758:	learn: 7.7914726	total: 2.5s	remaining: 5.74s
# 759:	learn: 7.7913593	total: 2.51s	remaining: 5.74s
# 760:	learn: 7.7912573	total: 2.51s	remaining: 5.73s
# 761:	learn: 7.7911764	total: 2.51s	remaining: 5.73s
# 762:	learn: 7.7910975	total: 2.52s	remaining: 5.73s
# 763:	learn: 7.7910279	total: 2.52s	remaining: 5.72s
# 764:	learn: 7.7909191	total: 2.52s	remaining: 5.72s
# 765:	learn: 7.7908453	total: 2.52s	remaining: 5.71s
# 766:	learn: 7.7907525	total: 2.53s	remaining: 5.71s
# 767:	learn: 7.7906210	total: 2.53s	remaining: 5.71s
# 768:	learn: 7.7905164	total: 2.53s	remaining: 5.7s
# 769:	learn: 7.7904201	total: 2.54s	remaining: 5.7s
# 770:	learn: 7.7903658	total: 2.54s	remaining: 5.7s
# 771:	learn: 7.7902808	total: 2.54s	remaining: 5.69s
# 772:	learn: 7.7902144	total: 2.55s	remaining: 5.69s
# 773:	learn: 7.7901008	total: 2.55s	remaining: 5.69s
# 774:	learn: 7.7899503	total: 2.55s	remaining: 5.68s
# 775:	learn: 7.7898813	total: 2.56s	remaining: 5.68s
# 776:	learn: 7.7898427	total: 2.56s	remaining: 5.67s
# 777:	learn: 7.7897680	total: 2.56s	remaining: 5.67s
# 778:	learn: 7.7896942	total: 2.56s	remaining: 5.67s
# 779:	learn: 7.7895735	total: 2.57s	remaining: 5.66s
# 780:	learn: 7.7894557	total: 2.57s	remaining: 5.66s
# 781:	learn: 7.7893989	total: 2.57s	remaining: 5.66s
# 782:	learn: 7.7893174	total: 2.58s	remaining: 5.65s
# 783:	learn: 7.7892590	total: 2.58s	remaining: 5.65s
# 784:	learn: 7.7891518	total: 2.58s	remaining: 5.64s
# 785:	learn: 7.7891078	total: 2.59s	remaining: 5.64s
# 786:	learn: 7.7890311	total: 2.59s	remaining: 5.63s
# 787:	learn: 7.7889402	total: 2.59s	remaining: 5.63s
# 788:	learn: 7.7888244	total: 2.59s	remaining: 5.63s
# 789:	learn: 7.7887062	total: 2.6s	remaining: 5.62s
# 790:	learn: 7.7886116	total: 2.6s	remaining: 5.62s
# 791:	learn: 7.7885040	total: 2.6s	remaining: 5.62s
# 792:	learn: 7.7884280	total: 2.61s	remaining: 5.61s
# 793:	learn: 7.7883246	total: 2.61s	remaining: 5.61s
# 794:	learn: 7.7882829	total: 2.61s	remaining: 5.6s
# 795:	learn: 7.7881696	total: 2.62s	remaining: 5.6s
# 796:	learn: 7.7880919	total: 2.62s	remaining: 5.59s
# 797:	learn: 7.7879587	total: 2.62s	remaining: 5.59s
# 798:	learn: 7.7878900	total: 2.62s	remaining: 5.59s
# 799:	learn: 7.7878036	total: 2.63s	remaining: 5.58s
# 800:	learn: 7.7877349	total: 2.63s	remaining: 5.58s
# 801:	learn: 7.7876527	total: 2.63s	remaining: 5.58s
# 802:	learn: 7.7875766	total: 2.64s	remaining: 5.57s
# 803:	learn: 7.7874852	total: 2.64s	remaining: 5.57s
# 804:	learn: 7.7874325	total: 2.64s	remaining: 5.56s
# 805:	learn: 7.7873012	total: 2.65s	remaining: 5.56s
# 806:	learn: 7.7872258	total: 2.65s	remaining: 5.56s
# 807:	learn: 7.7871384	total: 2.65s	remaining: 5.55s
# 808:	learn: 7.7870399	total: 2.65s	remaining: 5.55s
# 809:	learn: 7.7869442	total: 2.66s	remaining: 5.54s
# 810:	learn: 7.7868328	total: 2.66s	remaining: 5.54s
# 811:	learn: 7.7867403	total: 2.66s	remaining: 5.54s
# 812:	learn: 7.7866447	total: 2.67s	remaining: 5.53s
# 813:	learn: 7.7865336	total: 2.67s	remaining: 5.53s
# 814:	learn: 7.7864270	total: 2.67s	remaining: 5.53s
# 815:	learn: 7.7862703	total: 2.67s	remaining: 5.52s
# 816:	learn: 7.7861618	total: 2.68s	remaining: 5.52s
# 817:	learn: 7.7860577	total: 2.68s	remaining: 5.51s
# 818:	learn: 7.7859518	total: 2.68s	remaining: 5.51s
# 819:	learn: 7.7857819	total: 2.69s	remaining: 5.51s
# 820:	learn: 7.7857026	total: 2.69s	remaining: 5.5s
# 821:	learn: 7.7856413	total: 2.69s	remaining: 5.5s
# 822:	learn: 7.7855543	total: 2.7s	remaining: 5.5s
# 823:	learn: 7.7854910	total: 2.7s	remaining: 5.49s
# 824:	learn: 7.7853654	total: 2.7s	remaining: 5.49s
# 825:	learn: 7.7852893	total: 2.71s	remaining: 5.49s
# 826:	learn: 7.7852270	total: 2.71s	remaining: 5.48s
# 827:	learn: 7.7851522	total: 2.71s	remaining: 5.48s
# 828:	learn: 7.7850861	total: 2.71s	remaining: 5.47s
# 829:	learn: 7.7849390	total: 2.72s	remaining: 5.47s
# 830:	learn: 7.7848542	total: 2.72s	remaining: 5.46s
# 831:	learn: 7.7846712	total: 2.72s	remaining: 5.46s
# 832:	learn: 7.7845999	total: 2.73s	remaining: 5.46s
# 833:	learn: 7.7845225	total: 2.73s	remaining: 5.45s
# 834:	learn: 7.7844313	total: 2.73s	remaining: 5.45s
# 835:	learn: 7.7843821	total: 2.74s	remaining: 5.45s
# 836:	learn: 7.7842199	total: 2.74s	remaining: 5.45s
# 837:	learn: 7.7841310	total: 2.74s	remaining: 5.44s
# 838:	learn: 7.7840568	total: 2.75s	remaining: 5.44s
# 839:	learn: 7.7839652	total: 2.75s	remaining: 5.43s
# 840:	learn: 7.7838888	total: 2.75s	remaining: 5.43s
# 841:	learn: 7.7837648	total: 2.75s	remaining: 5.42s
# 842:	learn: 7.7836280	total: 2.76s	remaining: 5.42s
# 843:	learn: 7.7835429	total: 2.76s	remaining: 5.42s
# 844:	learn: 7.7834700	total: 2.77s	remaining: 5.42s
# 845:	learn: 7.7833913	total: 2.77s	remaining: 5.41s
# 846:	learn: 7.7832667	total: 2.77s	remaining: 5.41s
# 847:	learn: 7.7831983	total: 2.77s	remaining: 5.41s
# 848:	learn: 7.7830531	total: 2.78s	remaining: 5.4s
# 849:	learn: 7.7829895	total: 2.78s	remaining: 5.4s
# 850:	learn: 7.7829217	total: 2.79s	remaining: 5.4s
# 851:	learn: 7.7828356	total: 2.79s	remaining: 5.39s
# 852:	learn: 7.7827441	total: 2.79s	remaining: 5.39s
# 853:	learn: 7.7826872	total: 2.79s	remaining: 5.39s
# 854:	learn: 7.7826319	total: 2.8s	remaining: 5.38s
# 855:	learn: 7.7825565	total: 2.8s	remaining: 5.38s
# 856:	learn: 7.7824591	total: 2.81s	remaining: 5.38s
# 857:	learn: 7.7824032	total: 2.81s	remaining: 5.37s
# 858:	learn: 7.7823743	total: 2.81s	remaining: 5.37s
# 859:	learn: 7.7822940	total: 2.81s	remaining: 5.37s
# 860:	learn: 7.7822230	total: 2.82s	remaining: 5.36s
# 861:	learn: 7.7821115	total: 2.82s	remaining: 5.36s
# 862:	learn: 7.7820380	total: 2.82s	remaining: 5.36s
# 863:	learn: 7.7819214	total: 2.83s	remaining: 5.35s
# 864:	learn: 7.7818873	total: 2.83s	remaining: 5.35s
# 865:	learn: 7.7818275	total: 2.83s	remaining: 5.34s
# 866:	learn: 7.7817511	total: 2.84s	remaining: 5.34s
# 867:	learn: 7.7816425	total: 2.84s	remaining: 5.34s
# 868:	learn: 7.7815339	total: 2.84s	remaining: 5.34s
# 869:	learn: 7.7814472	total: 2.85s	remaining: 5.33s
# 870:	learn: 7.7813881	total: 2.85s	remaining: 5.33s
# 871:	learn: 7.7813309	total: 2.85s	remaining: 5.33s
# 872:	learn: 7.7811921	total: 2.85s	remaining: 5.32s
# 873:	learn: 7.7811117	total: 2.86s	remaining: 5.32s
# 874:	learn: 7.7810141	total: 2.86s	remaining: 5.32s
# 875:	learn: 7.7809119	total: 2.87s	remaining: 5.31s
# 876:	learn: 7.7808065	total: 2.87s	remaining: 5.31s
# 877:	learn: 7.7807551	total: 2.87s	remaining: 5.31s
# 878:	learn: 7.7806610	total: 2.88s	remaining: 5.3s
# 879:	learn: 7.7805620	total: 2.88s	remaining: 5.3s
# 880:	learn: 7.7804695	total: 2.88s	remaining: 5.3s
# 881:	learn: 7.7803496	total: 2.89s	remaining: 5.29s
# 882:	learn: 7.7802185	total: 2.89s	remaining: 5.29s
# 883:	learn: 7.7801468	total: 2.89s	remaining: 5.29s
# 884:	learn: 7.7800312	total: 2.9s	remaining: 5.29s
# 885:	learn: 7.7799695	total: 2.9s	remaining: 5.28s
# 886:	learn: 7.7799075	total: 2.9s	remaining: 5.28s
# 887:	learn: 7.7798101	total: 2.9s	remaining: 5.28s
# 888:	learn: 7.7797172	total: 2.91s	remaining: 5.27s
# 889:	learn: 7.7796809	total: 2.91s	remaining: 5.27s
# 890:	learn: 7.7795919	total: 2.92s	remaining: 5.27s
# 891:	learn: 7.7794977	total: 2.92s	remaining: 5.26s
# 892:	learn: 7.7794123	total: 2.92s	remaining: 5.26s
# 893:	learn: 7.7793393	total: 2.92s	remaining: 5.25s
# 894:	learn: 7.7792390	total: 2.93s	remaining: 5.25s
# 895:	learn: 7.7790960	total: 2.93s	remaining: 5.25s
# 896:	learn: 7.7790205	total: 2.93s	remaining: 5.24s
# 897:	learn: 7.7789286	total: 2.94s	remaining: 5.24s
# 898:	learn: 7.7788341	total: 2.94s	remaining: 5.24s
# 899:	learn: 7.7787660	total: 2.94s	remaining: 5.23s
# 900:	learn: 7.7786551	total: 2.95s	remaining: 5.23s
# 901:	learn: 7.7785770	total: 2.95s	remaining: 5.23s
# 902:	learn: 7.7784835	total: 2.95s	remaining: 5.22s
# 903:	learn: 7.7784031	total: 2.96s	remaining: 5.22s
# 904:	learn: 7.7783025	total: 2.96s	remaining: 5.22s
# 905:	learn: 7.7781801	total: 2.96s	remaining: 5.21s
# 906:	learn: 7.7781187	total: 2.97s	remaining: 5.21s
# 907:	learn: 7.7779875	total: 2.97s	remaining: 5.21s
# 908:	learn: 7.7778959	total: 2.97s	remaining: 5.2s
# 909:	learn: 7.7777760	total: 2.98s	remaining: 5.2s
# 910:	learn: 7.7776462	total: 2.98s	remaining: 5.2s
# 911:	learn: 7.7775642	total: 2.98s	remaining: 5.19s
# 912:	learn: 7.7774652	total: 2.98s	remaining: 5.19s
# 913:	learn: 7.7772936	total: 2.99s	remaining: 5.18s
# 914:	learn: 7.7772315	total: 2.99s	remaining: 5.18s
# 915:	learn: 7.7771492	total: 2.99s	remaining: 5.18s
# 916:	learn: 7.7770213	total: 3s	remaining: 5.17s
# 917:	learn: 7.7769332	total: 3s	remaining: 5.17s
# 918:	learn: 7.7768470	total: 3s	remaining: 5.17s
# 919:	learn: 7.7767593	total: 3.01s	remaining: 5.16s
# 920:	learn: 7.7766960	total: 3.01s	remaining: 5.16s
# 921:	learn: 7.7766365	total: 3.01s	remaining: 5.16s
# 922:	learn: 7.7765330	total: 3.02s	remaining: 5.15s
# 923:	learn: 7.7764163	total: 3.02s	remaining: 5.15s
# 924:	learn: 7.7763375	total: 3.02s	remaining: 5.15s
# 925:	learn: 7.7762308	total: 3.02s	remaining: 5.14s
# 926:	learn: 7.7760517	total: 3.03s	remaining: 5.14s
# ...
# 2199:	learn: 7.6697510	total: 7.22s	remaining: 985ms
# 2200:	learn: 7.6696727	total: 7.23s	remaining: 982ms
# 2201:	learn: 7.6695968	total: 7.23s	remaining: 979ms
# 2202:	learn: 7.6694964	total: 7.23s	remaining: 975ms
# 2203:	learn: 7.6694380	total: 7.24s	remaining: 972ms
# 2204:	learn: 7.6693435	total: 7.24s	remaining: 969ms
# 2205:	learn: 7.6692562	total: 7.24s	remaining: 965ms
# 2206:	learn: 7.6691642	total: 7.25s	remaining: 962ms
# 2207:	learn: 7.6690866	total: 7.25s	remaining: 959ms
# 2208:	learn: 7.6690123	total: 7.25s	remaining: 955ms
# 2209:	learn: 7.6689331	total: 7.26s	remaining: 952ms
# 2210:	learn: 7.6688435	total: 7.26s	remaining: 949ms
# 2211:	learn: 7.6687470	total: 7.26s	remaining: 946ms
# 2212:	learn: 7.6686498	total: 7.27s	remaining: 942ms
# 2213:	learn: 7.6685898	total: 7.27s	remaining: 939ms
# 2214:	learn: 7.6685354	total: 7.27s	remaining: 936ms
# 2215:	learn: 7.6684193	total: 7.28s	remaining: 933ms
# 2216:	learn: 7.6683463	total: 7.28s	remaining: 929ms
# 2217:	learn: 7.6682827	total: 7.28s	remaining: 926ms
# 2218:	learn: 7.6682100	total: 7.29s	remaining: 923ms
# 2219:	learn: 7.6681673	total: 7.29s	remaining: 920ms
# 2220:	learn: 7.6680848	total: 7.29s	remaining: 916ms
# 2221:	learn: 7.6679867	total: 7.3s	remaining: 913ms
# 2222:	learn: 7.6679010	total: 7.3s	remaining: 910ms
# 2223:	learn: 7.6678227	total: 7.3s	remaining: 906ms
# 2224:	learn: 7.6677431	total: 7.3s	remaining: 903ms
# 2225:	learn: 7.6676832	total: 7.31s	remaining: 900ms
# 2226:	learn: 7.6676118	total: 7.31s	remaining: 896ms
# 2227:	learn: 7.6675514	total: 7.32s	remaining: 893ms
# 2228:	learn: 7.6674898	total: 7.32s	remaining: 890ms
# 2229:	learn: 7.6674318	total: 7.32s	remaining: 886ms
# 2230:	learn: 7.6673887	total: 7.32s	remaining: 883ms
# 2231:	learn: 7.6673040	total: 7.33s	remaining: 880ms
# 2232:	learn: 7.6672068	total: 7.33s	remaining: 877ms
# 2233:	learn: 7.6671093	total: 7.33s	remaining: 873ms
# 2234:	learn: 7.6670421	total: 7.34s	remaining: 870ms
# 2235:	learn: 7.6669058	total: 7.34s	remaining: 867ms
# 2236:	learn: 7.6668357	total: 7.35s	remaining: 864ms
# 2237:	learn: 7.6667252	total: 7.36s	remaining: 861ms
# 2238:	learn: 7.6665762	total: 7.36s	remaining: 858ms
# 2239:	learn: 7.6664907	total: 7.36s	remaining: 854ms
# 2240:	learn: 7.6663962	total: 7.36s	remaining: 851ms
# 2241:	learn: 7.6663097	total: 7.37s	remaining: 848ms
# 2242:	learn: 7.6662403	total: 7.37s	remaining: 845ms
# 2243:	learn: 7.6661428	total: 7.37s	remaining: 841ms
# 2244:	learn: 7.6660746	total: 7.38s	remaining: 838ms
# 2245:	learn: 7.6660107	total: 7.38s	remaining: 835ms
# 2246:	learn: 7.6659305	total: 7.38s	remaining: 831ms
# 2247:	learn: 7.6658874	total: 7.39s	remaining: 828ms
# 2248:	learn: 7.6658274	total: 7.39s	remaining: 825ms
# 2249:	learn: 7.6657821	total: 7.39s	remaining: 821ms
# 2250:	learn: 7.6656888	total: 7.39s	remaining: 818ms
# 2251:	learn: 7.6656200	total: 7.4s	remaining: 815ms
# 2252:	learn: 7.6655538	total: 7.4s	remaining: 811ms
# 2253:	learn: 7.6654579	total: 7.41s	remaining: 808ms
# 2254:	learn: 7.6654061	total: 7.41s	remaining: 805ms
# 2255:	learn: 7.6653444	total: 7.41s	remaining: 802ms
# 2256:	learn: 7.6652678	total: 7.41s	remaining: 798ms
# 2257:	learn: 7.6652319	total: 7.42s	remaining: 795ms
# 2258:	learn: 7.6651680	total: 7.42s	remaining: 792ms
# 2259:	learn: 7.6650665	total: 7.42s	remaining: 788ms
# 2260:	learn: 7.6650173	total: 7.42s	remaining: 785ms
# 2261:	learn: 7.6648708	total: 7.43s	remaining: 782ms
# 2262:	learn: 7.6648151	total: 7.43s	remaining: 778ms
# 2263:	learn: 7.6646843	total: 7.43s	remaining: 775ms
# 2264:	learn: 7.6645545	total: 7.44s	remaining: 772ms
# 2265:	learn: 7.6644993	total: 7.44s	remaining: 768ms
# 2266:	learn: 7.6644393	total: 7.44s	remaining: 765ms
# 2267:	learn: 7.6643799	total: 7.45s	remaining: 762ms
# 2268:	learn: 7.6643320	total: 7.45s	remaining: 758ms
# 2269:	learn: 7.6642596	total: 7.45s	remaining: 755ms
# 2270:	learn: 7.6641621	total: 7.46s	remaining: 752ms
# 2271:	learn: 7.6640662	total: 7.46s	remaining: 749ms
# 2272:	learn: 7.6640146	total: 7.47s	remaining: 746ms
# 2273:	learn: 7.6639497	total: 7.47s	remaining: 742ms
# 2274:	learn: 7.6638845	total: 7.47s	remaining: 739ms
# 2275:	learn: 7.6637781	total: 7.47s	remaining: 736ms
# 2276:	learn: 7.6636281	total: 7.48s	remaining: 733ms
# 2277:	learn: 7.6635609	total: 7.49s	remaining: 730ms
# 2278:	learn: 7.6634601	total: 7.5s	remaining: 727ms
# 2279:	learn: 7.6634232	total: 7.5s	remaining: 724ms
# 2280:	learn: 7.6633534	total: 7.5s	remaining: 720ms
# 2281:	learn: 7.6632898	total: 7.51s	remaining: 717ms
# 2282:	learn: 7.6632151	total: 7.51s	remaining: 714ms
# 2283:	learn: 7.6631436	total: 7.51s	remaining: 710ms
# 2284:	learn: 7.6630669	total: 7.51s	remaining: 707ms
# 2285:	learn: 7.6630082	total: 7.52s	remaining: 704ms
# 2286:	learn: 7.6629479	total: 7.52s	remaining: 701ms
# 2287:	learn: 7.6628771	total: 7.52s	remaining: 697ms
# 2288:	learn: 7.6627613	total: 7.53s	remaining: 694ms
# 2289:	learn: 7.6626944	total: 7.53s	remaining: 691ms
# 2290:	learn: 7.6626526	total: 7.53s	remaining: 687ms
# 2291:	learn: 7.6625763	total: 7.54s	remaining: 684ms
# 2292:	learn: 7.6625280	total: 7.54s	remaining: 681ms
# 2293:	learn: 7.6624053	total: 7.54s	remaining: 677ms
# 2294:	learn: 7.6623750	total: 7.54s	remaining: 674ms
# 2295:	learn: 7.6622803	total: 7.55s	remaining: 671ms
# 2296:	learn: 7.6622001	total: 7.55s	remaining: 667ms
# 2297:	learn: 7.6621123	total: 7.55s	remaining: 664ms
# 2298:	learn: 7.6620647	total: 7.56s	remaining: 661ms
# 2299:	learn: 7.6620112	total: 7.56s	remaining: 657ms
# 2300:	learn: 7.6619253	total: 7.56s	remaining: 654ms
# 2301:	learn: 7.6618679	total: 7.57s	remaining: 651ms
# 2302:	learn: 7.6618040	total: 7.57s	remaining: 648ms
# 2303:	learn: 7.6617407	total: 7.57s	remaining: 644ms
# 2304:	learn: 7.6616454	total: 7.58s	remaining: 641ms
# 2305:	learn: 7.6615400	total: 7.58s	remaining: 638ms
# 2306:	learn: 7.6614770	total: 7.58s	remaining: 634ms
# 2307:	learn: 7.6613889	total: 7.58s	remaining: 631ms
# 2308:	learn: 7.6612949	total: 7.59s	remaining: 628ms
# 2309:	learn: 7.6612316	total: 7.59s	remaining: 624ms
# 2310:	learn: 7.6611562	total: 7.59s	remaining: 621ms
# 2311:	learn: 7.6610642	total: 7.6s	remaining: 618ms
# 2312:	learn: 7.6609885	total: 7.6s	remaining: 614ms
# 2313:	learn: 7.6609073	total: 7.6s	remaining: 611ms
# 2314:	learn: 7.6608492	total: 7.61s	remaining: 608ms
# 2315:	learn: 7.6607934	total: 7.61s	remaining: 605ms
# 2316:	learn: 7.6607529	total: 7.61s	remaining: 601ms
# 2317:	learn: 7.6607026	total: 7.62s	remaining: 598ms
# 2318:	learn: 7.6606521	total: 7.62s	remaining: 595ms
# 2319:	learn: 7.6605548	total: 7.62s	remaining: 591ms
# 2320:	learn: 7.6604445	total: 7.62s	remaining: 588ms
# 2321:	learn: 7.6603665	total: 7.63s	remaining: 585ms
# 2322:	learn: 7.6602794	total: 7.63s	remaining: 581ms
# 2323:	learn: 7.6602134	total: 7.63s	remaining: 578ms
# 2324:	learn: 7.6601276	total: 7.64s	remaining: 575ms
# 2325:	learn: 7.6600300	total: 7.64s	remaining: 572ms
# 2326:	learn: 7.6599328	total: 7.64s	remaining: 568ms
# 2327:	learn: 7.6598848	total: 7.65s	remaining: 565ms
# 2328:	learn: 7.6598055	total: 7.65s	remaining: 562ms
# 2329:	learn: 7.6597249	total: 7.65s	remaining: 558ms
# 2330:	learn: 7.6596753	total: 7.66s	remaining: 555ms
# 2331:	learn: 7.6595897	total: 7.66s	remaining: 552ms
# 2332:	learn: 7.6594589	total: 7.66s	remaining: 548ms
# 2333:	learn: 7.6594092	total: 7.66s	remaining: 545ms
# 2334:	learn: 7.6593616	total: 7.67s	remaining: 542ms
# 2335:	learn: 7.6592934	total: 7.67s	remaining: 539ms
# 2336:	learn: 7.6592020	total: 7.67s	remaining: 535ms
# 2337:	learn: 7.6591576	total: 7.68s	remaining: 532ms
# 2338:	learn: 7.6590998	total: 7.68s	remaining: 529ms
# 2339:	learn: 7.6590554	total: 7.68s	remaining: 525ms
# 2340:	learn: 7.6590149	total: 7.69s	remaining: 522ms
# 2341:	learn: 7.6589219	total: 7.69s	remaining: 519ms
# 2342:	learn: 7.6588883	total: 7.69s	remaining: 516ms
# 2343:	learn: 7.6588080	total: 7.7s	remaining: 512ms
# 2344:	learn: 7.6587535	total: 7.7s	remaining: 509ms
# 2345:	learn: 7.6587039	total: 7.7s	remaining: 506ms
# 2346:	learn: 7.6586569	total: 7.71s	remaining: 502ms
# 2347:	learn: 7.6585965	total: 7.71s	remaining: 499ms
# 2348:	learn: 7.6585136	total: 7.71s	remaining: 496ms
# 2349:	learn: 7.6584300	total: 7.72s	remaining: 493ms
# 2350:	learn: 7.6583667	total: 7.72s	remaining: 489ms
# 2351:	learn: 7.6582194	total: 7.72s	remaining: 486ms
# 2352:	learn: 7.6581692	total: 7.73s	remaining: 483ms
# 2353:	learn: 7.6581241	total: 7.73s	remaining: 479ms
# 2354:	learn: 7.6580347	total: 7.74s	remaining: 476ms
# 2355:	learn: 7.6579691	total: 7.74s	remaining: 473ms
# 2356:	learn: 7.6578688	total: 7.74s	remaining: 470ms
# 2357:	learn: 7.6578179	total: 7.75s	remaining: 467ms
# 2358:	learn: 7.6577663	total: 7.75s	remaining: 463ms
# 2359:	learn: 7.6576795	total: 7.75s	remaining: 460ms
# 2360:	learn: 7.6576161	total: 7.76s	remaining: 457ms
# 2361:	learn: 7.6575606	total: 7.76s	remaining: 453ms
# 2362:	learn: 7.6574829	total: 7.77s	remaining: 450ms
# 2363:	learn: 7.6573563	total: 7.77s	remaining: 447ms
# 2364:	learn: 7.6572799	total: 7.77s	remaining: 444ms
# 2365:	learn: 7.6571868	total: 7.78s	remaining: 440ms
# 2366:	learn: 7.6570977	total: 7.78s	remaining: 437ms
# 2367:	learn: 7.6570092	total: 7.78s	remaining: 434ms
# 2368:	learn: 7.6569015	total: 7.79s	remaining: 431ms
# 2369:	learn: 7.6568009	total: 7.79s	remaining: 427ms
# 2370:	learn: 7.6567731	total: 7.79s	remaining: 424ms
# 2371:	learn: 7.6566834	total: 7.8s	remaining: 421ms
# 2372:	learn: 7.6566275	total: 7.8s	remaining: 417ms
# 2373:	learn: 7.6565642	total: 7.8s	remaining: 414ms
# 2374:	learn: 7.6565021	total: 7.8s	remaining: 411ms
# 2375:	learn: 7.6564404	total: 7.81s	remaining: 408ms
# 2376:	learn: 7.6563960	total: 7.81s	remaining: 404ms
# 2377:	learn: 7.6563222	total: 7.82s	remaining: 401ms
# 2378:	learn: 7.6562631	total: 7.82s	remaining: 398ms
# 2379:	learn: 7.6562063	total: 7.82s	remaining: 394ms
# 2380:	learn: 7.6561462	total: 7.83s	remaining: 391ms
# 2381:	learn: 7.6561025	total: 7.83s	remaining: 388ms
# 2382:	learn: 7.6560522	total: 7.83s	remaining: 385ms
# 2383:	learn: 7.6559980	total: 7.83s	remaining: 381ms
# 2384:	learn: 7.6559258	total: 7.84s	remaining: 378ms
# 2385:	learn: 7.6558386	total: 7.84s	remaining: 375ms
# 2386:	learn: 7.6558053	total: 7.84s	remaining: 371ms
# 2387:	learn: 7.6557230	total: 7.85s	remaining: 368ms
# 2388:	learn: 7.6556074	total: 7.85s	remaining: 365ms
# 2389:	learn: 7.6555539	total: 7.85s	remaining: 362ms
# 2390:	learn: 7.6554667	total: 7.86s	remaining: 358ms
# 2391:	learn: 7.6553896	total: 7.86s	remaining: 355ms
# 2392:	learn: 7.6553197	total: 7.86s	remaining: 352ms
# 2393:	learn: 7.6552322	total: 7.87s	remaining: 348ms
# 2394:	learn: 7.6551796	total: 7.87s	remaining: 345ms
# 2395:	learn: 7.6550800	total: 7.87s	remaining: 342ms
# 2396:	learn: 7.6550118	total: 7.88s	remaining: 339ms
# 2397:	learn: 7.6549605	total: 7.88s	remaining: 335ms
# 2398:	learn: 7.6548475	total: 7.88s	remaining: 332ms
# 2399:	learn: 7.6547214	total: 7.89s	remaining: 329ms
# 2400:	learn: 7.6546022	total: 7.89s	remaining: 325ms
# 2401:	learn: 7.6545287	total: 7.89s	remaining: 322ms
# 2402:	learn: 7.6544484	total: 7.9s	remaining: 319ms
# 2403:	learn: 7.6543765	total: 7.9s	remaining: 315ms
# 2404:	learn: 7.6543030	total: 7.9s	remaining: 312ms
# 2405:	learn: 7.6542207	total: 7.91s	remaining: 309ms
# 2406:	learn: 7.6541574	total: 7.91s	remaining: 306ms
# 2407:	learn: 7.6540705	total: 7.91s	remaining: 302ms
# 2408:	learn: 7.6539908	total: 7.91s	remaining: 299ms
# 2409:	learn: 7.6539402	total: 7.92s	remaining: 296ms
# 2410:	learn: 7.6538729	total: 7.92s	remaining: 292ms
# 2411:	learn: 7.6537909	total: 7.92s	remaining: 289ms
# 2412:	learn: 7.6537259	total: 7.92s	remaining: 286ms
# 2413:	learn: 7.6536589	total: 7.93s	remaining: 282ms
# 2414:	learn: 7.6535711	total: 7.93s	remaining: 279ms
# 2415:	learn: 7.6535106	total: 7.93s	remaining: 276ms
# 2416:	learn: 7.6534264	total: 7.94s	remaining: 273ms
# 2417:	learn: 7.6533404	total: 7.94s	remaining: 269ms
# 2418:	learn: 7.6532813	total: 7.94s	remaining: 266ms
# 2419:	learn: 7.6531729	total: 7.95s	remaining: 263ms
# 2420:	learn: 7.6530948	total: 7.95s	remaining: 259ms
# 2421:	learn: 7.6530164	total: 7.95s	remaining: 256ms
# 2422:	learn: 7.6529445	total: 7.96s	remaining: 253ms
# 2423:	learn: 7.6528874	total: 7.96s	remaining: 250ms
# 2424:	learn: 7.6528416	total: 7.96s	remaining: 246ms
# 2425:	learn: 7.6527792	total: 7.96s	remaining: 243ms
# 2426:	learn: 7.6526933	total: 7.97s	remaining: 240ms
# 2427:	learn: 7.6525950	total: 7.97s	remaining: 236ms
# 2428:	learn: 7.6524898	total: 7.97s	remaining: 233ms
# 2429:	learn: 7.6524114	total: 7.98s	remaining: 230ms
# 2430:	learn: 7.6523392	total: 7.98s	remaining: 226ms
# 2431:	learn: 7.6522761	total: 7.98s	remaining: 223ms
# 2432:	learn: 7.6521905	total: 7.99s	remaining: 220ms
# 2433:	learn: 7.6521102	total: 7.99s	remaining: 217ms
# 2434:	learn: 7.6520308	total: 7.99s	remaining: 213ms
# 2435:	learn: 7.6519373	total: 7.99s	remaining: 210ms
# 2436:	learn: 7.6518465	total: 8s	remaining: 207ms
# 2437:	learn: 7.6517691	total: 8s	remaining: 203ms
# 2438:	learn: 7.6516773	total: 8s	remaining: 200ms
# 2439:	learn: 7.6516250	total: 8.01s	remaining: 197ms
# 2440:	learn: 7.6515332	total: 8.01s	remaining: 194ms
# 2441:	learn: 7.6514704	total: 8.02s	remaining: 190ms
# 2442:	learn: 7.6514067	total: 8.02s	remaining: 187ms
# 2443:	learn: 7.6513244	total: 8.02s	remaining: 184ms
# 2444:	learn: 7.6512463	total: 8.02s	remaining: 181ms
# 2445:	learn: 7.6511689	total: 8.03s	remaining: 177ms
# 2446:	learn: 7.6510895	total: 8.03s	remaining: 174ms
# 2447:	learn: 7.6510159	total: 8.03s	remaining: 171ms
# 2448:	learn: 7.6509486	total: 8.04s	remaining: 167ms
# 2449:	learn: 7.6508689	total: 8.04s	remaining: 164ms
# 2450:	learn: 7.6508055	total: 8.04s	remaining: 161ms
# 2451:	learn: 7.6507153	total: 8.04s	remaining: 157ms
# 2452:	learn: 7.6506732	total: 8.05s	remaining: 154ms
# 2453:	learn: 7.6505755	total: 8.05s	remaining: 151ms
# 2454:	learn: 7.6505300	total: 8.05s	remaining: 148ms
# 2455:	learn: 7.6504611	total: 8.06s	remaining: 144ms
# 2456:	learn: 7.6503670	total: 8.06s	remaining: 141ms
# 2457:	learn: 7.6503147	total: 8.06s	remaining: 138ms
# 2458:	learn: 7.6502140	total: 8.07s	remaining: 135ms
# 2459:	learn: 7.6501412	total: 8.07s	remaining: 131ms
# 2460:	learn: 7.6500222	total: 8.07s	remaining: 128ms
# 2461:	learn: 7.6499941	total: 8.08s	remaining: 125ms
# 2462:	learn: 7.6499036	total: 8.08s	remaining: 121ms
# 2463:	learn: 7.6498301	total: 8.08s	remaining: 118ms
# 2464:	learn: 7.6497873	total: 8.09s	remaining: 115ms
# 2465:	learn: 7.6497229	total: 8.09s	remaining: 112ms
# 2466:	learn: 7.6496006	total: 8.09s	remaining: 108ms
# 2467:	learn: 7.6495588	total: 8.1s	remaining: 105ms
# 2468:	learn: 7.6494925	total: 8.1s	remaining: 102ms
# 2469:	learn: 7.6493699	total: 8.1s	remaining: 98.4ms
# 2470:	learn: 7.6492558	total: 8.11s	remaining: 95.1ms
# 2471:	learn: 7.6491650	total: 8.11s	remaining: 91.8ms
# 2472:	learn: 7.6490898	total: 8.11s	remaining: 88.6ms
# 2473:	learn: 7.6489924	total: 8.11s	remaining: 85.3ms
# 2474:	learn: 7.6488953	total: 8.12s	remaining: 82ms
# 2475:	learn: 7.6488362	total: 8.12s	remaining: 78.7ms
# 2476:	learn: 7.6488091	total: 8.12s	remaining: 75.4ms
# 2477:	learn: 7.6487175	total: 8.13s	remaining: 72.1ms
# 2478:	learn: 7.6486348	total: 8.13s	remaining: 68.9ms
# 2479:	learn: 7.6485561	total: 8.13s	remaining: 65.6ms
# 2480:	learn: 7.6485070	total: 8.13s	remaining: 62.3ms
# 2481:	learn: 7.6484479	total: 8.14s	remaining: 59ms
# 2482:	learn: 7.6483642	total: 8.14s	remaining: 55.7ms
# 2483:	learn: 7.6482704	total: 8.14s	remaining: 52.5ms
# 2484:	learn: 7.6481763	total: 8.15s	remaining: 49.2ms
# 2485:	learn: 7.6481014	total: 8.15s	remaining: 45.9ms
# 2486:	learn: 7.6480726	total: 8.15s	remaining: 42.6ms
# 2487:	learn: 7.6479827	total: 8.16s	remaining: 39.3ms
# 2488:	learn: 7.6478942	total: 8.16s	remaining: 36.1ms
# 2489:	learn: 7.6477846	total: 8.16s	remaining: 32.8ms
# 2490:	learn: 7.6476764	total: 8.17s	remaining: 29.5ms
# 2491:	learn: 7.6476287	total: 8.17s	remaining: 26.2ms
# 2492:	learn: 7.6475761	total: 8.17s	remaining: 22.9ms
# 2493:	learn: 7.6475238	total: 8.18s	remaining: 19.7ms
# 2494:	learn: 7.6474175	total: 8.18s	remaining: 16.4ms
# 2495:	learn: 7.6473414	total: 8.18s	remaining: 13.1ms
# 2496:	learn: 7.6472851	total: 8.19s	remaining: 9.84ms
# 2497:	learn: 7.6472178	total: 8.19s	remaining: 6.56ms
# 2498:	learn: 7.6471534	total: 8.19s	remaining: 3.28ms
# 2499:	learn: 7.6470520	total: 8.2s	remaining: 0us
# MSE is 61.65329378101654
# RMSE is 7.851961142352688

# %%
#     dump(preds, f"./preds/{config_rn['name']}/xgboost_fold{fold}_preds.joblib")

# %% [markdown]
# # Inference

# %%
test_df = pd.read_csv(datapath/'test.csv', index_col='id', low_memory=False)

# %%
test_df.head()
# Out:
#               f0   f1        f2        f3          f4        f5         f6  \
# id
# 250000  0.812665   15 -1.239120 -0.893251    295.5770  15.87120   23.04360
# 250001  0.190344  131 -0.501361  0.801921     64.8866   3.09703  344.80500
# 250002  0.919671   19 -0.057382  0.901419  11961.2000  16.39650  273.24000
# 250003  0.860985   19 -0.549509  0.471799   7501.6000   2.80698   71.08170
# 250004  0.313229   89  0.588509  0.167705   2931.2600   4.34986    1.57187
#
#               f7         f8       f9  ...       f90        f91       f92  \
# id                                    ...
# 250000  0.942256  29.898000  1.11394  ...  0.446389   -422.332  -1.44630
# 250001  0.807194  38.421900  1.09695  ...  0.377179  10352.200  21.06270
# 250002 -0.003300  37.940000  1.15222  ...  0.990140   3224.020  -2.25287
# 250003  0.792136   0.395235  1.20157  ...  1.396880   9689.760  14.77150
# 250004  1.118300   7.754630  1.16807  ...  0.862502   2693.350  44.18050
#
#             f93       f94        f95      f96       f97       f98       f99
# id
# 250000  1.69075  1.059300  -3.010570  1.94664  0.529470  1.386950   8.78767
# 250001  1.84351  0.251895   4.440570  1.90309  0.248534  0.863881  11.79390
# 250002  1.55100 -0.559157  17.838600  1.83385  0.931796  2.336870   9.05400
# 250003  1.41390  0.329272   0.802437  2.23251  0.893348  1.359470   4.84833
# 250004  1.58020 -0.191021  26.253000  2.68238  0.361923  1.532800   3.70660
#
# [5 rows x 100 columns]

# %% [markdown]
# (Here's where encapsulating the transformations in a pipeline would come in handy. But I'll do it manually for now.)

# %%
features = [x for x in test_df.columns if x != 'loss']
X_test = test_df[features] # this is just for naming consistency

# %% [markdown]
# Now, let's get the features the model was trained on and subset the test set's features accordingly

# %%
# generation polynomial features
poly = PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)
X_test_poly = poly.fit_transform(X_test)

# %%
X_test_poly_names = poly.get_feature_names(X_test.columns)
# X_poly_names[100:150]
features = pd.read_csv('X_candidates_20210827.csv').columns

# %%
# checks = [feature in X_test_poly_names for feature in features]
# checks

# %%
X_test_final = pd.DataFrame(X_test_poly, columns=X_test_poly_names)

# %%
X_test_final = X_test_final[features[1:]]

# %% [markdown]
# # Scaling
# Now, going to scale using `MaxAbsScaler`

# %%
scaler = config['scaler']()
X_test_scaled = scaler.fit_transform(X_test_final)
# X_scaled_df = pd.DataFrame(X_scaled, columns=X_poly_names)

# %%
# applying hold-out before scaling
# X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
#                                                       test_size=config['test_size'], 
#                                                       random_state=config['random_state']
#                                                      )
# # scaling (i.e. normalizing)
# scaler = config['scaler']()
# X_train_s = scaler.fit_transform(X_train)
# X_test_s = scaler.fit_transform(X_test)

# # selecting features
# selector = config['feature_selector'](score_func=config["feature_selection_scoring"], 
#                                       k=config['k_best'])
# X_train_fs = selector.fit_transform(X_train_s, y_train)
# X_test_fs = X_test_s[:, selector.get_support()]

# model = XGBRegressor(
#     tree_method=config['tree_method'],
#     booster=config['booster'],
#     n_estimators=config['n_estimators'], 
#     max_depth=config['max_depth'],
#     learning_rate=config['learning_rate'], 
#     test_size=config['test_size'],
#     subsample=config['subsample'],
#     random_state=config['random_state'],
#     n_jobs=config['n_jobs'], 
#     verbosity=config['verbosity'], 
# )
# #     wandb.log({'params': model.get_params()}) # logging model parameters
# model.fit(X_train_fs, y_train)#, callbacks=[wandb.xgboost.wandb_callback()])

# %%
models
# Out:
# {0: <catboost.core.CatBoostRegressor at 0x7fb514136a60>,
#  1: <catboost.core.CatBoostRegressor at 0x7fb5141369d0>,
#  2: <catboost.core.CatBoostRegressor at 0x7fb4ec7ea070>,
#  3: <catboost.core.CatBoostRegressor at 0x7fb514136a30>,
#  4: <catboost.core.CatBoostRegressor at 0x7fb514136970>}

# %% [markdown]
# Now, iterate over the dict containing the models trained on the 5 folds, and store the predictions in a new dict `preds`
# **OR**
# load from a directory.

# %%
# loaded_models = {}
# saved_models_path = Path('/home/sf/Dropbox/code_cloud/python_code/kaggle/tabular_playgrounds/aug2021/models/inference_ensemble_20210828_204126_5folds/')
# for fold in range(5):
#     loaded_models[fold] = load(filename=Path(saved_models_path/f'xgboost_fold{fold}_model.joblib'))

# %%
# models = loaded_models

# %%
preds = {}
for fold in models.keys():
    preds[fold] = models[fold].predict(X_test_scaled)

# %%
sample_df = pd.read_csv(datapath/'sample_submission.csv')

# %%
type(preds[0])
# Out:
# numpy.ndarray

# %%
final_preds = (preds[0] + preds[1] + preds[2] + preds[3] + preds[4]) / 5

# %%
final_preds[:10]
# Out:
# array([ 7.14460925,  4.91404505,  8.45173994,  8.06273655,  7.56350513,
#        10.01107509,  9.47364953,  6.89087186,  7.55784743,  7.62919071])

# %%
sample_df.loc[:, 'loss'] = final_preds

# %%
sample_df.head()
# Out:
#        id      loss
# 0  250000  7.144609
# 1  250001  4.914045
# 2  250002  8.451740
# 3  250003  8.062737
# 4  250004  7.563505

# %%
sample_df.to_csv('202108302123_XGBoost_n-est1000per.csv', index=False)

# %% [markdown]
# # Experiment - fitting model on full training set

# %%
# applying hold-out before scaling
# X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
#                                                       test_size=config['test_size'], 
#                                                       random_state=config['random_state']
#                                                      )
# scaling (i.e. normalizing)
scaler = config['scaler']()
X_s = scaler.fit_transform(X)
X_test_s = scaler.fit_transform(X_test)

# selecting features
selector = config['feature_selector'](score_func=config["feature_selection_scoring"], 
                                      k=config['k_best'])
X_fs = selector.fit_transform(X_s, y)
X_test_fs = X_test_s[:, selector.get_support()]

model = XGBRegressor(
    tree_method=config['tree_method'],
    booster=config['booster'],
    n_estimators=config['n_estimators'], 
    max_depth=config['max_depth'],
    learning_rate=config['learning_rate'], 
    test_size=config['test_size'],
    subsample=config['subsample'],
    random_state=config['random_state'],
    n_jobs=config['n_jobs'], 
    verbosity=config['verbosity'], 
)
#     wandb.log({'params': model.get_params()}) # logging model parameters
model.fit(X_fs, y)#, callbacks=[wandb.xgboost.wandb_callback()])
# Out:
# [12:11:15] WARNING: ../src/learner.cc:573:
# Parameters: { "test_size" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRegressor(base_score=0.5, booster='dart', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1522, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=400, n_jobs=-1, num_parallel_tree=1, random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              test_size=0.2, tree_method='auto', validate_parameters=1,
#              verbosity=1)

# %%
y_test_preds = model.predict(X_test_fs)
# Out:
# /home/sf/anaconda3/envs/tabular/lib/python3.8/site-packages/xgboost/data.py:112: UserWarning: Use subset (sliced data) of np.ndarray is not recommended because it will generate extra copies and increase memory consumption
#   warnings.warn(

# %%
sample_df = pd.read_csv(datapath/'sample_submission.csv')

# %%
sample_df.loc[:, 'loss'] = y_test_preds

# %%
sample_df.head()
# Out:
#        id      loss
# 0  250000  8.027956
# 1  250001  4.305676
# 2  250002  7.300106
# 3  250003  6.988875
# 4  250004  7.316631

# %%
sample_df.to_csv('202108241211_XGBoost_fullset.csv', index=False)
